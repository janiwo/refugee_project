# %% [markdown]
# # Candidate merging and related preprocessing

# %% [markdown]
# Import relevant packages for the following parts

# %%
#python libraries
import stanza
from stanza_batch import batch

import nltk
from nltk.corpus import wordnet
import numpy as np
import pandas as pd
import os
import re
import csv
from tqdm import tqdm
import time
from collections import Counter, defaultdict


# self written modules
import preprocessing

import candidate_processing as cand_prep
import candidate_extraction as cand_ex

"""import candidate_extraction as cand_ex
from ekphrasis.classes.segmenter import Segmenter
seg = Segmenter() """

from ekphrasis.classes.tokenizer import Tokenizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# Reading english - 1grams ...
# Reading english - 1grams ...
# Reading english - 2grams ...
# C:\ProgramData\Anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# ## 1. We import the data

# %%
moria_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_moria.csv" # for Moria


def read_event_df(data_url):
    directory_path = os.getcwd() + "/../../../" + data_url 
    event_df = pd.read_csv(directory_path, index_col=0)
    event_df.reset_index(drop=True, inplace=True)
    print(f'loaded {event_df.shape[0]} tweets!')
    return event_df

# pick the df 
event_df = read_event_df(moria_url)[:1000]
#channel_df = read_event_df(channel_url)
event_df['text_clean']= event_df['text'].apply(preprocessing.preprocess_tweets)
# Out:
# loaded 92806 tweets!

# %%
FILE_PATH = "/Users/nikodemicek/Dropbox (CBS)/Master thesis data"
USERS_PATH = FILE_PATH + "/df_users.csv"
# Read the users csv
df_users = pd.read_csv(USERS_PATH)

# Drop unnecessary index column
df_users.drop("Unnamed: 0", axis=1, inplace=True)

df_users.head()

# Create dict that maps usernames to actual names
mapping = dict(df_users[["username","name"]].values)
mapping = {f'@{key}': value for key, value in mapping.items()}


def resolve_username_to_name(text):
    new_text = text
    for word in text.split(" "):
        if word in mapping:
            new_text = new_text.replace(word,mapping[word])
    return new_text

tqdm.pandas()
event_df['text_clean'] = event_df['text_clean'].progress_apply(resolve_username_to_name)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|███████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 63221.50it/s]

# %%
event_df[['text','text_clean']].head(20)
# Out:
#                                                  text  \
# 0   Canada's immigrant population is 20%, USA is 1...
# 1   Hi @EUHomeAffairs @Place_Beauvau @BMI_Bund @uk...
# 2   #Greece Dozens of Asylum seekers, who face the...
# 3   Hmmm? Maybe not, Spain is the COVID-19 hot spo...
# 4   Greece to evict over 10,000 refugees from shel...
# 5   Refugees can find information on their asylum ...
# 6   @TheRickWilson America is literally on fire af...
# 7   -ACCEPTING ALL REFUGEES-\nWhy YOU should come ...
# 8   These white guys? Fire @ArtAcevedo you support...
# 9   @BostonFire on scene at 240 Silver St S. Bosto...
# 10  @GovAbbott I as a citizen of this country ask ...
# 11  House burns in Harewood, three people displace...
# 12  @CrezthSA @FluffyTet A cop tried to fire bomb ...
# 13  #देश_चलाना_खेल_नही_है Earlier migrant labourer...
# 14  #MetroDAT responded to a fire in #WestRoxbury ...
# 15  #MetroDAT are responding to a fire in #SouthBo...
# 16  750 Muslim migrants from Greek refugee camps t...
# 17  I'm wondering: do Trump supporters watch Avata...
# 18  Hi @EUHomeAffairs @Place_Beauvau @BMI_Bund @uk...
# 19  @AgentSmith_51 @Aabhas24 Yes, I can understand...
#
#                                            text_clean
# 0   Canada' s immigrant population is 20%, USA is ...
# 1   Hi EUHomeAffairs @Place_Beauvau Bundesminister...
# 2   greece Dozens of Asylum seekers, who face the ...
# 3   Hmmm? Maybe not, Spain is the COVID - 19 hot s...
# 4   Greece to evict over 10,000 refugees from shel...
# 5   Refugees can find information on their asylum ...
# 6   America is literally on fire after 3 1 / 2 yea...
# 7   - ACCEPTING ALL REFUGEES - Why YOU should come...
# 8   These white guys? Fire Chief Art Acevedo you s...
# 9   on scene at 240 Silver St S . Boston for a two...
# 10  I as a citizen of this country ask you to inve...
# 11  House burns in Harewood, three people displace...
# 12  A cop tried to fire bomb a building full of im...
# 13  _ _ _ _ Earlier migrant labourers went home ev...
# 14  metro dat responded to a fire in west roxbury ...
# 15  metro dat are responding to a fire in south bo...
# 16  750 Muslim migrants from Greek refugee camps t...
# 17  I' m wondering: do Trump supporters watch Avat...
# 18  Hi EUHomeAffairs @Place_Beauvau Bundesminister...
# 19  Yes, I can understand Islamic brotherhood . I ...

# %%
from stanza.server import CoreNLPClient
from nltk.tokenize import sent_tokenize

def extract_corefs(event_df, all=True):

    #corefs_list = list()
    #tweets_list = list(event_df)

    #so we have control over whether we extract only np or coref candidates
    #nps = True if all == True or all == 'nps' else False
    #corefs = True if all == True or all == 'corefs' else False
    
    with CoreNLPClient(annotators=["tokenize,ssplit,pos,lemma,parse,coref,ner,depparse"], properties ={'coref.algorithm' : 'neural'}, timeout=600000, memory='8G') as client:

        def get_coref_chains(tweet,client=client):

            ann = client.annotate(tweet)        
            tweet_chains = ann.corefChain
            all_chains = list()
            all_locs = list()
            print(tweet)
            
            for chain in tweet_chains:
                chain_words = list()
                word_locs = list()
                # Loop through every mention of this chain
                for mention in chain.mention:
                    # Get the sentence in which this mention is located, and get the words which are part of this mention
                    words_list = ann.sentence[mention.sentenceIndex].token[mention.beginIndex:mention.endIndex]
                    #build a string out of the words of this mention
                    ment_word = ' '.join([word.word for word in words_list])
                    
                    identified_words_loc = (mention.sentenceIndex,mention.beginIndex,mention.endIndex)
                    chain_words.append(ment_word)
                    word_locs.append(identified_words_loc)
                    
                #the corefering words will be stored alongside the index of their representative in a tuple
                coref_group = (chain_words,chain.representative)
                #coref_cand = coref_group[0][coref_group[1]]
                all_chains.append(coref_group)
                all_locs.append(word_locs)
            
            print(all_locs)
            print(all_chains)
            tweet = sent_tokenize(tweet)
            print(tweet)
            
            
            
                for mention in word_locs:
                tweet[mention[0]][mention[1]:mention[2]] =    """   

            return all_chains
        # get noun phrases with tregex using get_noun_phrases function
        #print('extracting noun phrases...')
        tqdm.pandas()
        #noun_phrase_list = list(event_df.progress_apply(get_noun_phrases,args=(client,"tokenize,ssplit,pos,lemma,parse")))
        #noun_phrase_list = [get_noun_phrases(client,tweets_list[tweet_id], annotators="tokenize,ssplit,pos,lemma,parse") for tweet_id in tqdm(range(len(tweets_list)))]


        print('extracting coreference chains...')
        # get coreference chains using the .annotate method of client handled by get_coref_chain function  

        corefs_list = list(event_df.progress_apply(get_coref_chains))
        #for tweet_id in tqdm(range(len(tweets_list))):
            #coref_chains = [chain for chain in get_coref_chain(event_df[tweet_id],client)] 

        #corefs_list.append(['no_candidate']) if len(corefs_list) == 0 else corefs_list.append(coref_chains)
                
             

    return corefs_list

event_corefs = extract_corefs(event_df['text_clean'])
# Out:
# 2021-04-09 20:15:14 INFO: Writing properties to tmp file: corenlp_server-d2456746daec4c62.props
# 2021-04-09 20:15:14 INFO: Starting server with command: java -Xmx8G -cp C:\Users\nikodemicek\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 600000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-d2456746daec4c62.props -annotators tokenize,ssplit,pos,lemma,parse,coref,ner,depparse -preload -outputFormat serialized
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]
# extracting coreference chains...
#   0%|▏                                                                              | 2/1000 [00:29<4:06:14, 14.80s/it]
# Canada' s immigrant population is 20%, USA is 13% . We' re not of fire . We have systematic racism for sure, the difference is not electing leadership stoking the fire & getting elected on " I hate the same people you hate ".
# []
# []
# ["Canada' s immigrant population is 20%, USA is 13% .", "We' re not of fire .", 'We have systematic racism for sure, the difference is not electing leadership stoking the fire & getting elected on " I hate the same people you hate ".']
#   0%|▏                                                                              | 3/1000 [00:34<3:14:39, 11.72s/it]
# Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions . Will you act now to leave no one behind and save lives?
# []
# []
# ['Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions .', 'Will you act now to leave no one behind and save lives?']
#   0%|▎                                                                              | 4/1000 [00:37<2:32:24,  9.18s/it]
# greece Dozens of Asylum seekers, who face the risk of becoming homeless due to the end of accommodation support, gathered in protest outside UNHCR in athens' ESTIA' is an accommodation programme funded by the EU & implemented by UNHCR with Greek NGOs
# [[(0, 25, 26), (0, 42, 43)]]
# [(['UNHCR', 'UNHCR'], 0)]
# ["greece Dozens of Asylum seekers, who face the risk of becoming homeless due to the end of accommodation support, gathered in protest outside UNHCR in athens' ESTIA' is an accommodation programme funded by the EU & implemented by UNHCR with Greek NGOs"]
#   1%|▍                                                                              | 6/1000 [00:38<1:18:43,  4.75s/it]
# Hmmm? Maybe not, Spain is the COVID - 19 hot spot now and Greece still has immigrant camps don' t they . They might not want to risk more infection.
# [[(1, 16, 21), (2, 0, 1), (1, 21, 22)]]
# [(["immigrant camps don ' t", 'They', 'they'], 0)]
# ['Hmmm?', "Maybe not, Spain is the COVID - 19 hot spot now and Greece still has immigrant camps don' t they .", 'They might not want to risk more infection.']
# Greece to evict over 10,000 refugees from shelters
# []
# []
# ['Greece to evict over 10,000 refugees from shelters']
#   1%|▌                                                                              | 7/1000 [00:39<1:02:19,  3.77s/it]
# Refugees can find information on their asylum procedures on these boards . Today in the Moria Monitor, we address the communication channels at Camp Moria in Lesvos: leave no one behind
# [[(0, 0, 1), (0, 5, 6)]]
# [(['Refugees', 'their'], 0)]
# ['Refugees can find information on their asylum procedures on these boards .', 'Today in the Moria Monitor, we address the communication channels at Camp Moria in Lesvos: leave no one behind']
#   1%|▋                                                                                | 8/1000 [00:42<54:15,  3.28s/it]
# America is literally on fire after 3 1 / 2 years of racially targeted speeches, rallies, tweets at POC, immigrants, members of Congress, athletes & celebrities by Donald Trump . Now 105,000 dead Americans later, Trump just moved quicker to stop Antifa than he did to stop COVID19.
# [[(1, 14, 15), (0, 32, 34), (1, 6, 7)]]
# [(['he', 'Donald Trump', 'Trump'], 1)]
# ['America is literally on fire after 3 1 / 2 years of racially targeted speeches, rallies, tweets at POC, immigrants, members of Congress, athletes & celebrities by Donald Trump .', 'Now 105,000 dead Americans later, Trump just moved quicker to stop Antifa than he did to stop COVID19.']
#   1%|▋                                                                                | 9/1000 [00:45<56:32,  3.42s/it]
# - ACCEPTING ALL REFUGEES - Why YOU should come to Canada! - tiim Horton - we live in igloos so da fire only melts it - cool funny polar bear - cold so fire will only help - everyone is too nice to riot - ccnada - we have hot chip and timbim - coupon for wendys - no one lie
# []
# []
# ['- ACCEPTING ALL REFUGEES - Why YOU should come to Canada!', '- tiim Horton - we live in igloos so da fire only melts it - cool funny polar bear - cold so fire will only help - everyone is too nice to riot - ccnada - we have hot chip and timbim - coupon for wendys - no one lie']
#   1%|▊                                                                               | 10/1000 [00:46<43:19,  2.63s/it]
# These white guys? Fire Chief Art Acevedo you support illegal immigrants your job is to arrest the illegals . Why because they are here unlawfully.
# [[(1, 13, 15), (2, 2, 3)]]
# [(['the illegals', 'they'], 0)]
# ['These white guys?', 'Fire Chief Art Acevedo you support illegal immigrants your job is to arrest the illegals .', 'Why because they are here unlawfully.']
#   1%|▉                                                                               | 11/1000 [00:47<35:38,  2.16s/it]
# on scene at 240 Silver St S . Boston for a two story wood frame home . Fire has been outed quickly and companies are making up . 4 people have been displaced . BFD - FIU on way to investigate . Damages est around $50,000.
# []
# []
# ['on scene at 240 Silver St S .', 'Boston for a two story wood frame home .', 'Fire has been outed quickly and companies are making up .', '4 people have been displaced .', 'BFD - FIU on way to investigate .', 'Damages est around $50,000.']
#   1%|▉                                                                               | 12/1000 [00:48<28:49,  1.75s/it]
# I as a citizen of this country ask you to investigate this man . Remove him from office! He supports illegal immigrants . Made an unbelievably racist statement blaming White people . Fire this god awful excuse for a police Chief.
# [[(1, 1, 2), (2, 0, 1), (0, 11, 13)]]
# [(['him', 'He', 'this man'], 2)]
# ['I as a citizen of this country ask you to investigate this man .', 'Remove him from office!', 'He supports illegal immigrants .', 'Made an unbelievably racist statement blaming White people .', 'Fire this god awful excuse for a police Chief.']
#   1%|█                                                                               | 13/1000 [00:49<22:58,  1.40s/it]
# House burns in Harewood, three people displaced Dog unaccounted for after house fire Sunday evening
# []
# []
# ['House burns in Harewood, three people displaced Dog unaccounted for after house fire Sunday evening']
#   1%|█                                                                               | 14/1000 [00:49<18:31,  1.13s/it]
# A cop tried to fire bomb a building full of immigrants? The same one antifa swore to avenge? Again why make up these conspiracies
# []
# []
# ['A cop tried to fire bomb a building full of immigrants?', 'The same one antifa swore to avenge?', 'Again why make up these conspiracies']
#   2%|█▏                                                                            | 15/1000 [01:04<1:24:29,  5.15s/it]
# _ _ _ _ Earlier migrant labourers went home even on foot; now are cancelling rail tickets: those who reached home wants to come back for work: wages are not sufficient at home & under MGNREGA . Govt would again be under fire for insufficient workers at plants . covid 19
# []
# []
# ['_ _ _ _ Earlier migrant labourers went home even on foot; now are cancelling rail tickets: those who reached home wants to come back for work: wages are not sufficient at home & under MGNREGA .', 'Govt would again be under fire for insufficient workers at plants .', 'covid 19']
#   2%|█▏                                                                            | 16/1000 [01:04<1:00:58,  3.72s/it]
# metro dat responded to a fire in west roxbury where 3 people are reported displaced.
# []
# []
# ['metro dat responded to a fire in west roxbury where 3 people are reported displaced.']
#   2%|█▎                                                                              | 17/1000 [01:04<44:06,  2.69s/it]
# metro dat are responding to a fire in south boston where 4 people are reported displaced.
# []
# []
# ['metro dat are responding to a fire in south boston where 4 people are reported displaced.']
#   2%|█▍                                                                              | 18/1000 [01:05<32:45,  2.00s/it]
# 750 Muslim migrants from Greek refugee camps to be relocated to France The definition of insanity is doing . . . . "
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France The definition of insanity is doing .', '.', '.', '. "']
#   2%|█▌                                                                              | 19/1000 [01:06<29:05,  1.78s/it]
# I' m wondering: do Trump supporters watch Avatar and root for the Fire Nation? Or do they root for Aang and just pretend like the environmentalism, acceptance of refugees, and all that doesn' t conflict with everything they stand for in real life?
# [[(1, 2, 3), (0, 6, 8), (1, 26, 27)]]
# [(['they', 'Trump supporters', 'they'], 1)]
# ["I' m wondering: do Trump supporters watch Avatar and root for the Fire Nation?", "Or do they root for Aang and just pretend like the environmentalism, acceptance of refugees, and all that doesn' t conflict with everything they stand for in real life?"]
#   2%|█▌                                                                              | 20/1000 [01:07<27:21,  1.68s/it]
# Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions . Will you act now to leave no one behind and save lives?
# []
# []
# ['Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions .', 'Will you act now to leave no one behind and save lives?']
#   2%|█▊                                                                              | 22/1000 [01:09<17:57,  1.10s/it]
# Yes, I can understand Islamic brotherhood . I can see why countries in gulf are baying for each other' s blood . How they refused to entertain Pakistanis or Rohingyas? How the Turks, supposedly your ancestors, stripped of Afgan, BD and other refugees and left them at Greek border.
# [[(1, 0, 1), (0, 2, 3)], [(3, 14, 16), (3, 18, 19)], [(2, 1, 2), (1, 4, 7)]]
# [(['I', 'I'], 1), (['other refugees', 'them'], 0), (['they', 'countries in gulf'], 1)]
# ['Yes, I can understand Islamic brotherhood .', "I can see why countries in gulf are baying for each other' s blood .", 'How they refused to entertain Pakistanis or Rohingyas?', 'How the Turks, supposedly your ancestors, stripped of Afgan, BD and other refugees and left them at Greek border.']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   2%|█▊                                                                              | 23/1000 [01:10<17:59,  1.10s/it]
# Can you hear a mother' s hidden sound shouts: help my children? Can you feel a father' s hidden fire that burns him because of lack solution? Can you measure the loss of school for a child? If yes, so you can hear, feel & measure the suffering of Iraqi refugees
# [[(0, 1, 2), (0, 12, 13)], [(1, 3, 7), (1, 11, 12)], [(2, 1, 2), (3, 4, 5)]]
# [(['you', 'my'], 0), (["a father ' s", 'him'], 0), (['you', 'you'], 0)]
# ["Can you hear a mother' s hidden sound shouts: help my children?", "Can you feel a father' s hidden fire that burns him because of lack solution?", 'Can you measure the loss of school for a child?', 'If yes, so you can hear, feel & measure the suffering of Iraqi refugees']
#   2%|█▉                                                                              | 24/1000 [01:10<15:32,  1.05it/s]
# Talk about potentially adding fuel to a fire . . . this ruling could spell the end of protection from deportation for about 700K immigrants brought to the US as children.
# []
# []
# ['Talk about potentially adding fuel to a fire .', '.', '.', 'this ruling could spell the end of protection from deportation for about 700K immigrants brought to the US as children.']
#   2%|██                                                                              | 25/1000 [01:11<12:07,  1.34it/s]
# Nigeria: International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims
# []
# []
# ['Nigeria: International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims']
#   3%|██                                                                              | 26/1000 [01:12<15:25,  1.05it/s]
# HA . Protestors dont set fire to churches . BLACK PEOPLE dont set fire to churches . (And I love how all of a sudden its about immigrants small businesses just so you cannot look racist) proper training isnt going to put Derek Chauvin in jail or bring Ppl back
# []
# []
# ['HA .', 'Protestors dont set fire to churches .', 'BLACK PEOPLE dont set fire to churches .', '(And I love how all of a sudden its about immigrants small businesses just so you cannot look racist) proper training isnt going to put Derek Chauvin in jail or bring Ppl back']
#   3%|██▏                                                                             | 27/1000 [01:13<14:59,  1.08it/s]
# Stoking hatred and fear of others sounds like smart politics, humans are so easily manipulated by gaslighters and snake oil peddlers . Eventually, fire rages, hard to extinguish . Immigrants, brown and black people, lgbt and transgender kids all targeted by GOP.
# []
# []
# ['Stoking hatred and fear of others sounds like smart politics, humans are so easily manipulated by gaslighters and snake oil peddlers .', 'Eventually, fire rages, hard to extinguish .', 'Immigrants, brown and black people, lgbt and transgender kids all targeted by GOP.']
#   3%|██▏                                                                             | 28/1000 [01:14<15:28,  1.05it/s]
# I say we fire all the cops . Who you all calling when you need help? A terrorist, gang member, illegal immigrant, drug lord, child sex trafficker? Will they all put their lives on the line for you? No . My husband did for years . You get out there, do the job . Didn' t think so.
# [[(3, 1, 2), (3, 4, 5)], [(0, 0, 1), (5, 0, 1)]]
# [(['they', 'their'], 0), (['I', 'My'], 0)]
# ['I say we fire all the cops .', 'Who you all calling when you need help?', 'A terrorist, gang member, illegal immigrant, drug lord, child sex trafficker?', 'Will they all put their lives on the line for you?', 'No .', 'My husband did for years .', 'You get out there, do the job .', "Didn' t think so."]
#   3%|██▍                                                                             | 30/1000 [01:14<08:56,  1.81it/s]
# International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims in Nigeria: nigeria
# [[(0, 15, 16), (0, 13, 14)]]
# [(['nigeria', 'Nigeria'], 1)]
# ['International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims in Nigeria: nigeria']
# Thousands face homelessness in greek refugee relocation push
# []
# []
# ['Thousands face homelessness in greek refugee relocation push']
# Thousands face homelessness in Greek refugee relocationpush
# []
# []
# ['Thousands face homelessness in Greek refugee relocationpush']
#   3%|██▌                                                                             | 32/1000 [01:15<06:40,  2.42it/s]
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   3%|██▋                                                                             | 33/1000 [01:15<05:28,  2.94it/s]
# RIOT BETWEEN ANTI - ASYLUM SEEKERS AND POLICE IN GREECE
# []
# []
# ['RIOT BETWEEN ANTI - ASYLUM SEEKERS AND POLICE IN GREECE']
#   3%|██▋                                                                             | 34/1000 [01:16<12:20,  1.30it/s]
# I' d like to see data on the percentage of schools c1900 in England and the US that taught Greek and Roman myths and histories like they were heirs to grand legacies, while also never accepting Greek or Italian immigrants as pupils
# [[(0, 20, 23), (0, 27, 28)]]
# [(['Greek and Roman', 'they'], 0)]
# ["I' d like to see data on the percentage of schools c1900 in England and the US that taught Greek and Roman myths and histories like they were heirs to grand legacies, while also never accepting Greek or Italian immigrants as pupils"]
#   4%|██▊                                                                             | 35/1000 [01:18<14:02,  1.15it/s]
# Which UK people do the airlines see using their quarantined flights? Business travel, is not coming back soon, even without quarantine Brexit is scuppering contractors, job moves Spain and Greece (& other holiday destinations) have banned Brits Maybe refugees from broken Britain
# [[(0, 1, 3), (0, 8, 9)]]
# [(['UK people', 'their'], 0)]
# ['Which UK people do the airlines see using their quarantined flights?', 'Business travel, is not coming back soon, even without quarantine Brexit is scuppering contractors, job moves Spain and Greece (& other holiday destinations) have banned Brits Maybe refugees from broken Britain']
#   4%|██▉                                                                             | 36/1000 [01:18<10:56,  1.47it/s]
# Coronavirus Concerns Grow in Migrant, Refugee Camp in Greece - Balkan Insight
# []
# []
# ['Coronavirus Concerns Grow in Migrant, Refugee Camp in Greece - Balkan Insight']
#   4%|██▉                                                                             | 37/1000 [01:20<20:20,  1.27s/it]
# I posted on my Facebook Andrew helping others page after given one way ticket to Greece when I was homeless courtesy of ssfa and made my way back to the uk met many refugees had one place on there mind' s get to the uk not surprised numbers have doubled
# [[(0, 30, 31), (0, 44, 46)], [(0, 0, 1), (0, 17, 18), (0, 3, 4), (0, 25, 26)]]
# [(['uk', 'the uk'], 1), (['I', 'I', 'my', 'my'], 0)]
# ["I posted on my Facebook Andrew helping others page after given one way ticket to Greece when I was homeless courtesy of ssfa and made my way back to the uk met many refugees had one place on there mind' s get to the uk not surprised numbers have doubled"]
#   4%|███                                                                             | 38/1000 [01:21<15:34,  1.03it/s]
# Nigeria: International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims
# []
# []
# ['Nigeria: International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims']
#   4%|███▏                                                                            | 40/1000 [01:22<11:31,  1.39it/s]
# What about Italy? The only terrorist attack we had in decades was about a white guy opening fire on migrants . And also, racism is even in the smallest, insignificant things . Every day things we do without even notice . Racism has no country, it is a problem basically everywhere.
# [[(1, 4, 5), (3, 3, 4)]]
# [(['we', 'we'], 0)]
# ['What about Italy?', 'The only terrorist attack we had in decades was about a white guy opening fire on migrants .', 'And also, racism is even in the smallest, insignificant things .', 'Every day things we do without even notice .', 'Racism has no country, it is a problem basically everywhere.']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   4%|███▎                                                                            | 41/1000 [01:22<09:51,  1.62it/s]
# THEY ARE NOT FECKING GREEK!!! They are in a GREEK refugee camp EUs problem NOT SCOTLANDS
# [[(0, 0, 1), (1, 0, 1)]]
# [(['THEY', 'They'], 0)]
# ['THEY ARE NOT FECKING GREEK!!!', 'They are in a GREEK refugee camp EUs problem NOT SCOTLANDS']
#   4%|███▎                                                                            | 42/1000 [01:23<12:25,  1.29it/s]
# Thousands face homelessness in Greek refugee relocation pushThe British Minister of Health says the Corona virus has caused him to lose his sense of taste and smell . Here' s why this might happen
# [[(0, 18, 19), (0, 21, 22), (0, 7, 12)]]
# [(['him', 'his', 'pushThe British Minister of Health'], 2)]
# ['Thousands face homelessness in Greek refugee relocation pushThe British Minister of Health says the Corona virus has caused him to lose his sense of taste and smell .', "Here' s why this might happen"]
#   4%|███▌                                                                            | 44/1000 [01:26<13:46,  1.16it/s]
# The burning of St . Johns Church is an inexcusable act of violence . Arson is not protest . It was the antecedents of todays anti - immigrant extremists that burned churches to terrorize . DC needs to put the fire out . Protesters did not do this.
# []
# []
# ['The burning of St .', 'Johns Church is an inexcusable act of violence .', 'Arson is not protest .', 'It was the antecedents of todays anti - immigrant extremists that burned churches to terrorize .', 'DC needs to put the fire out .', 'Protesters did not do this.']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   5%|███▋                                                                            | 46/1000 [01:26<08:13,  1.93it/s]
# Coronavirus Concerns Grow in Migrant, Refugee Camp in GREECE
# []
# []
# ['Coronavirus Concerns Grow in Migrant, Refugee Camp in GREECE']
# Greece to evict over 10,000 refugees from shelters
# []
# []
# ['Greece to evict over 10,000 refugees from shelters']
#   5%|███▊                                                                            | 47/1000 [01:26<06:35,  2.41it/s]
# Volunteers restore church in Lesvos trashed by illegal immigrants
# []
# []
# ['Volunteers restore church in Lesvos trashed by illegal immigrants']
# Thousands face homelessness in Greek refugee relocation push via @yahooph
#   5%|███▊                                                                            | 48/1000 [01:26<05:31,  2.87it/s]
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push via @yahooph']
#   5%|███▉                                                                            | 49/1000 [01:28<10:24,  1.52it/s]
# Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions . Will you act now to leave no one behind and save lives?
# []
# []
# ['Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions .', 'Will you act now to leave no one behind and save lives?']
#   5%|████                                                                            | 50/1000 [01:28<08:32,  1.85it/s]
# did you overhear that Greece fears border standoff with Turkey over migrants' return
# []
# []
# ["did you overhear that Greece fears border standoff with Turkey over migrants' return"]
#   5%|████▏                                                                           | 52/1000 [01:29<07:09,  2.21it/s]
# Actor Sonu Sood is now under fire just days after being showered with praises for arranging for buses for migrant workers from Mumbai . Reason? He met Maharashtra Governor Bhagat Singh Koshiyari
# [[(0, 0, 3), (2, 0, 1)]]
# [(['Actor Sonu Sood', 'He'], 0)]
# ['Actor Sonu Sood is now under fire just days after being showered with praises for arranging for buses for migrant workers from Mumbai .', 'Reason?', 'He met Maharashtra Governor Bhagat Singh Koshiyari']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   5%|████▏                                                                           | 53/1000 [01:29<05:55,  2.67it/s]
# Thousands face homelessness in Greek refugee relocation push [ARTICLE] news
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push [ARTICLE] news']
#   6%|████▍                                                                           | 55/1000 [01:31<10:43,  1.47it/s]
# Corneli Ernst, a member of the european parliament, criticized greece by saying the decision could leave many refugees homeless and without financial means, partly due to the suspension of public services as a result of the novel coronavirus pandemic.
# []
# []
# ['Corneli Ernst, a member of the european parliament, criticized greece by saying the decision could leave many refugees homeless and without financial means, partly due to the suspension of public services as a result of the novel coronavirus pandemic.']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   6%|████▍                                                                           | 56/1000 [01:32<08:22,  1.88it/s]
# Neither . . They are migrants from Turkey currently in Greek camps . .
# []
# []
# ['Neither .', '.', 'They are migrants from Turkey currently in Greek camps .', '.']
#   6%|████▌                                                                           | 57/1000 [01:35<21:19,  1.36s/it]
# Remember this: The entire world, save the Axis of Evil, were Anti - fascists in WWII . Also reread Mt25 : 31 - 46 . In it, Christ teaches us that those who support attacks on poor / sick / hungry / stranger [immigrant] will be cast " into the everlasting fire created for the devil . . . "
# []
# []
# ['Remember this: The entire world, save the Axis of Evil, were Anti - fascists in WWII .', 'Also reread Mt25 : 31 - 46 .', 'In it, Christ teaches us that those who support attacks on poor / sick / hungry / stranger [immigrant] will be cast " into the everlasting fire created for the devil .', '.', '. "']
#   6%|████▋                                                                           | 58/1000 [01:36<18:46,  1.20s/it]
# I will dedicate my vote to fire Donald Trump to all green card holders and undocumented immigrants who cannot vote, but who also suffer massively from his failed Presidency . trump resign now
# [[(0, 0, 1), (0, 3, 4)], [(0, 7, 9), (0, 28, 29)]]
# [(['I', 'my'], 0), (['Donald Trump', 'his'], 0)]
# ['I will dedicate my vote to fire Donald Trump to all green card holders and undocumented immigrants who cannot vote, but who also suffer massively from his failed Presidency .', 'trump resign now']
#   6%|████▋                                                                           | 59/1000 [01:36<16:59,  1.08s/it]
# INTERNATIONAL NEWS Thousands face homelessness in Greek refugee relocation push The country was recovering from a decade - long debt crisis and jobs were already scarce before the coronavirus pandemic . Read more >
# []
# []
# ['INTERNATIONAL NEWS Thousands face homelessness in Greek refugee relocation push The country was recovering from a decade - long debt crisis and jobs were already scarce before the coronavirus pandemic .', 'Read more >']
#   6%|████▊                                                                           | 60/1000 [01:37<15:03,  1.04it/s]
# FUCK . THAT . BTW, it isnt Greek migrants, it is Syrian, Somali and Sub - Saharan African refugees . They are just in a CAMP in Greece.
# [[(3, 0, 1), (2, 9, 18)]]
# [(['They', 'Syrian , Somali and Sub - Saharan African refugees'], 1)]
# ['FUCK .', 'THAT .', 'BTW, it isnt Greek migrants, it is Syrian, Somali and Sub - Saharan African refugees .', 'They are just in a CAMP in Greece.']
#   6%|████▉                                                                           | 61/1000 [01:38<12:25,  1.26it/s]
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
#   6%|█████                                                                           | 63/1000 [01:38<07:45,  2.01it/s]
# Greek refugees . Come off it . How disingenuous is this headline? Later in the article " refugees currently residing in Greece ".
# []
# []
# ['Greek refugees .', 'Come off it .', 'How disingenuous is this headline?', 'Later in the article " refugees currently residing in Greece ".']
# metro dat is assisting 5 people displaced from a fire in roxbury
# []
# []
# ['metro dat is assisting 5 people displaced from a fire in roxbury']
#   6%|█████                                                                           | 64/1000 [01:39<11:21,  1.37it/s]
# WATCH IN FULL | Aid workers in the Moria camp on the island of Lesbos support tens of thousands of migrants and refugees, while still trying to respect social distancing . But that' s an almost impossible ask in a camp as overcrowded as this one.
# []
# []
# ['WATCH IN FULL | Aid workers in the Moria camp on the island of Lesbos support tens of thousands of migrants and refugees, while still trying to respect social distancing .', "But that' s an almost impossible ask in a camp as overcrowded as this one."]
#   7%|█████▎                                                                          | 66/1000 [01:40<08:31,  1.83it/s]
# Greece starts moving more than 11,200 refugees out of flats, hotels, and camps to make room for other asylum seekers currently living in dismal camps
# []
# []
# ['Greece starts moving more than 11,200 refugees out of flats, hotels, and camps to make room for other asylum seekers currently living in dismal camps']
# Volunteers restore church in Lesvos trashed by illegal immigrants
# []
# []
# ['Volunteers restore church in Lesvos trashed by illegal immigrants']
#   7%|█████▍                                                                          | 68/1000 [01:40<05:32,  2.80it/s]
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   7%|█████▌                                                                          | 70/1000 [01:42<07:01,  2.21it/s]
# Urging @LordMayorNottm @CllrDavidMellen & people of Notts to support the pledge to relocate asylum seekers from Aegean hotspot camps . Im from Notts & have seen 1st hand the inhumane conditions of Moria Refugee Camp - Pls sign the Petition! europe must act
# []
# []
# ['Urging @LordMayorNottm @CllrDavidMellen & people of Notts to support the pledge to relocate asylum seekers from Aegean hotspot camps .', 'Im from Notts & have seen 1st hand the inhumane conditions of Moria Refugee Camp - Pls sign the Petition!', 'europe must act']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   7%|█████▋                                                                          | 71/1000 [01:42<05:25,  2.85it/s]
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#   7%|█████▊                                                                          | 73/1000 [01:42<04:08,  3.73it/s]
# Thousands of migrants face homelessness amid GREECE' S relocation scheme
# []
# []
# ["Thousands of migrants face homelessness amid GREECE' S relocation scheme"]
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
#   7%|█████▉                                                                          | 74/1000 [01:42<03:30,  4.40it/s]
# Thousands face homelessness in Greek refugee relocation push [ARTICLE ]
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push [ARTICLE ]']
#   8%|██████                                                                          | 75/1000 [01:43<03:50,  4.01it/s]
# Volunteers restore church in Lesvos trashed by illegal immigrants June 01 , 2020 at 07 : 45AM
# []
# []
# ['Volunteers restore church in Lesvos trashed by illegal immigrants June 01 , 2020 at 07 : 45AM']
#   8%|██████                                                                          | 76/1000 [01:44<08:04,  1.91it/s]
# Authorities in Greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness
# [[(0, 2, 3), (0, 19, 21)], [(0, 36, 37), (0, 26, 29)]]
# [(['Greece', 'the mainland'], 0), (['them', 'other asylum seekers'], 1)]
# ['Authorities in Greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness']
# Greek refugees! Why are they refugees?
# [[(0, 0, 3), (1, 2, 3)]]
# [(['Greek refugees !', 'they'], 0)]
# ['Greek refugees!', 'Why are they refugees?']
#   8%|██████▏                                                                         | 78/1000 [01:45<09:29,  1.62it/s]
# Authorities in greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness: AFP News Agency
# [[(0, 36, 37), (0, 26, 29)]]
# [(['them', 'other asylum seekers'], 1)]
# ['Authorities in greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness: AFP News Agency']
#   8%|██████▎                                                                         | 79/1000 [01:46<07:48,  1.96it/s]
# You do realize that Antifa attempted to fire bomb a building full of immigrants right? And also this
# []
# []
# ['You do realize that Antifa attempted to fire bomb a building full of immigrants right?', 'And also this']
#   8%|██████▍                                                                         | 80/1000 [01:46<07:02,  2.18it/s]
# They are not Greek refugees Lorraine . They are economic migrants that are in Greece and really should be sent back to where the came from.
# [[(0, 0, 1), (1, 0, 1)]]
# [(['They', 'They'], 0)]
# ['They are not Greek refugees Lorraine .', 'They are economic migrants that are in Greece and really should be sent back to where the came from.']
#   8%|██████▍                                                                         | 81/1000 [01:47<10:23,  1.47it/s]
# They aren' t greek at all . I' m certain that the snp will open the doors at set the table for them all . We will all be branded terrible racists & told to shut up otherwise we will be ostracized . It' s an EU issue now not ours . They' re economic migrants.
# [[(2, 13, 14), (2, 0, 1), (3, 8, 9)]]
# [(['we', 'We', 'ours'], 1)]
# ["They aren' t greek at all .", "I' m certain that the snp will open the doors at set the table for them all .", 'We will all be branded terrible racists & told to shut up otherwise we will be ostracized .', "It' s an EU issue now not ours .", "They' re economic migrants."]
#   8%|██████▌                                                                         | 82/1000 [01:48<11:52,  1.29it/s]
# A total of 229 asylum - seekers arrived on Lesvos since early May . 16 of those are held in quarantine in a bus in Mytilene port despite the dangers that the crowded conditions pose to them during the COVID - 19 pandemic refugees gr
# [[(1, 0, 3), (1, 22, 23)]]
# [(['16 of those', 'them'], 0)]
# ['A total of 229 asylum - seekers arrived on Lesvos since early May .', '16 of those are held in quarantine in a bus in Mytilene port despite the dangers that the crowded conditions pose to them during the COVID - 19 pandemic refugees gr']
#   8%|██████▋                                                                         | 83/1000 [01:48<09:23,  1.63it/s]
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
# 750 Muslim migrants from Greek refugee camps to be relocated to France
#   8%|██████▊                                                                         | 85/1000 [01:49<06:07,  2.49it/s]
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
#   9%|██████▉                                                                         | 86/1000 [01:49<05:14,  2.91it/s]
# Turkey announces it will start another migrant crisis with Greece after coronavirus via Greekcitytimes
# [[(0, 0, 1), (0, 2, 3)]]
# [(['Turkey', 'it'], 0)]
# ['Turkey announces it will start another migrant crisis with Greece after coronavirus via Greekcitytimes']
#   9%|███████                                                                         | 88/1000 [01:50<06:19,  2.40it/s]
# Glasgow Must Act Petition launched 2 ask Glasgow City Council 2 take 1500 refugees / asylum seekers from Greek refugee camps . Glasgow Must Act, the Glasgow branch of Europe Must Act, launched the petition on March 17th asking the Council 2 provide shelter
# [[(0, 0, 1), (1, 0, 1), (1, 5, 6)]]
# [(['Glasgow', 'Glasgow', 'Glasgow'], 0)]
# ['Glasgow Must Act Petition launched 2 ask Glasgow City Council 2 take 1500 refugees / asylum seekers from Greek refugee camps .', 'Glasgow Must Act, the Glasgow branch of Europe Must Act, launched the petition on March 17th asking the Council 2 provide shelter']
# Thousands face homelessness in Greek refugee relocation push via FRANCE 24
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push via FRANCE 24']
#   9%|███████                                                                         | 89/1000 [01:51<08:22,  1.81it/s]
# 750 Muslim migrants from Greek refugee camps to be relocated to France to be placed (by the French government) in the queue for free transportation to the uk . There you go, finished the report properly
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France to be placed (by the French government) in the queue for free transportation to the uk .', 'There you go, finished the report properly']
#   9%|███████▏                                                                        | 90/1000 [01:52<09:38,  1.57it/s]
# To some of us, there' s not gulls or gardens or ginger beer, and Greece has never been an option . Some of us has lived like refugees / prisoners at the same time for ever.
# [[(0, 3, 4), (1, 2, 3)]]
# [(['us', 'us'], 0)]
# ["To some of us, there' s not gulls or gardens or ginger beer, and Greece has never been an option .", 'Some of us has lived like refugees / prisoners at the same time for ever.']
#   9%|███████▎                                                                        | 91/1000 [01:53<13:07,  1.15it/s]
# ( thread part2) A Syrian man with his wife and family, protest against the eviction from their accommodation and the blocking of their cash card assistance outside UN office in athens greece.
# [[(0, 18, 19), (0, 24, 25), (0, 8, 12)]]
# [(['their', 'their', 'his wife and family'], 2)]
# ['( thread part2) A Syrian man with his wife and family, protest against the eviction from their accommodation and the blocking of their cash card assistance outside UN office in athens greece.']
#   9%|███████▎                                                                        | 92/1000 [01:55<15:58,  1.06s/it]
# Amidst a barrage of calls over the last 48 hrs, at mindnight approx 40 ofd personnel responded to a fire in the rear of a building on Lee St . Crews limited the spread w / minimal damage to the building itself, primarily cars . 12 people displaced, but thankfully no injuries.
# [[(0, 25, 27), (1, 9, 11), (1, 11, 12)]]
# [(['a building', 'the building', 'itself'], 0)]
# ['Amidst a barrage of calls over the last 48 hrs, at mindnight approx 40 ofd personnel responded to a fire in the rear of a building on Lee St .', 'Crews limited the spread w / minimal damage to the building itself, primarily cars .', '12 people displaced, but thankfully no injuries.']
#   9%|███████▍                                                                        | 93/1000 [01:56<16:42,  1.11s/it]
# Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions . Will you act now to leave no one behind and save lives?
# []
# []
# ['Hi EUHomeAffairs @Place_Beauvau Bundesministerium des Innern, für Bau und Heimat Home Office @Justitiedep @ministerieJenV thousands of refugees are at risk of covid 19 on Greek islands due to crowded unsanitary conditions .', 'Will you act now to leave no one behind and save lives?']
#   9%|███████▌                                                                        | 94/1000 [01:57<15:40,  1.04s/it]
# Europe Must Act to protect these vulnerable families and all those living in the refugee camps on the Greek Aegean islands . Please sign our petition in your local area! 2 / 3 Aberdeen: Edinburgh: Glasgow :
# []
# []
# ['Europe Must Act to protect these vulnerable families and all those living in the refugee camps on the Greek Aegean islands .', 'Please sign our petition in your local area!', '2 / 3 Aberdeen: Edinburgh: Glasgow :']
#  10%|███████▌                                                                        | 95/1000 [01:57<12:28,  1.21it/s]
# 750 Muslim migrants from Greek refugee camps to be relocated to France
# []
# []
# ['750 Muslim migrants from Greek refugee camps to be relocated to France']
#  10%|███████▋                                                                        | 96/1000 [01:57<09:40,  1.56it/s]
# Covid - 19 and refugees, asylum seekers, and migrants in Greece
# []
# []
# ['Covid - 19 and refugees, asylum seekers, and migrants in Greece']
#  10%|███████▊                                                                        | 97/1000 [01:58<10:12,  1.47it/s]
# Tell us about the Greek Islands tourist income . Would you like it to crash and burn and be like Lesbos (shown)? Olive groves destroyed, churches vandalised, no tourist income , 50,000 migrants destroying communities . A real Green vision for Europe greece
# [[(1, 3, 4), (0, 3, 8)]]
# [(['it', 'the Greek Islands tourist income'], 1)]
# ['Tell us about the Greek Islands tourist income .', 'Would you like it to crash and burn and be like Lesbos (shown)?', 'Olive groves destroyed, churches vandalised, no tourist income , 50,000 migrants destroying communities .', 'A real Green vision for Europe greece']
#  10%|███████▊                                                                        | 98/1000 [01:59<09:50,  1.53it/s]
# Raining and lighting here in overcrowded moria camp . These vulnerable migrants have to wait hours to see doctors, asylum procedures, food, shower and toilet, . . EU tents are very fragile with many holes . refugeesgr
# []
# []
# ['Raining and lighting here in overcrowded moria camp .', 'These vulnerable migrants have to wait hours to see doctors, asylum procedures, food, shower and toilet, .', '.', 'EU tents are very fragile with many holes .', 'refugeesgr']
#  10%|███████▉                                                                        | 99/1000 [01:59<08:30,  1.77it/s]
# Covid - 19 and refugees, asylum seekers, and migrants in Greece
# []
# []
# ['Covid - 19 and refugees, asylum seekers, and migrants in Greece']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
# Thousands face homelessness in Greek refugee relocation push
#  10%|███████▉                                                                       | 101/1000 [01:59<06:21,  2.36it/s]
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#  10%|████████▏                                                                      | 103/1000 [02:00<05:32,  2.70it/s]
# No one has protested the deaths of Americans killed illegal immigrants or rioted or looted or became fire bugs or demanded justice for them . @realDonaldTrump
# [[(0, 23, 24), (0, 9, 11)]]
# [(['them', 'illegal immigrants'], 1)]
# ['No one has protested the deaths of Americans killed illegal immigrants or rioted or looted or became fire bugs or demanded justice for them .', '@realDonaldTrump']
# Petition launched asking Glasgow City Council to accept 1500 Greek refugees
# []
# []
# ['Petition launched asking Glasgow City Council to accept 1500 Greek refugees']
#  10%|████████▏                                                                      | 104/1000 [02:00<04:20,  3.44it/s]
# Volunteers restore church in Lesvos trashed by illegal immigrants
# []
# []
# ['Volunteers restore church in Lesvos trashed by illegal immigrants']
# Thatll be the Greek refugees
# []
# []
# ['Thatll be the Greek refugees']
#  11%|████████▎                                                                      | 106/1000 [02:01<04:01,  3.70it/s]
# Translation : 750 Muslim illegal migrants from Greek illegal migrant camps, to be relocated to the UK.
# []
# []
# ['Translation : 750 Muslim illegal migrants from Greek illegal migrant camps, to be relocated to the UK.']
#  11%|████████▍                                                                      | 107/1000 [02:01<06:08,  2.43it/s]
# A show of solidarity in an area which drew many migrants before its gentrification . Richmond Greek restaurants band together with' ' slogan.
# [[(0, 5, 14), (0, 12, 13)]]
# [(['an area which drew many migrants before its gentrification', 'its'], 0)]
# ['A show of solidarity in an area which drew many migrants before its gentrification .', "Richmond Greek restaurants band together with' ' slogan."]
#  11%|████████▌                                                                      | 108/1000 [02:03<09:47,  1.52it/s]
# Meanwhile in Athens, a protest takes place outside of UNHCR Greece . greece government' s plan is to stop hosting some asylum - seekers with recognized refugee status in camps and EU subsidized apartments and hotels as of June 1st . Some 10.000 might be affected.
# []
# []
# ['Meanwhile in Athens, a protest takes place outside of UNHCR Greece .', "greece government' s plan is to stop hosting some asylum - seekers with recognized refugee status in camps and EU subsidized apartments and hotels as of June 1st .", 'Some 10.000 might be affected.']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#  11%|████████▊                                                                      | 111/1000 [02:04<07:24,  2.00it/s]
# Authorities in greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness
# [[(0, 36, 37), (0, 26, 29)]]
# [(['them', 'other asylum seekers'], 1)]
# ['Authorities in greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness']
# Thousands face homelessness in Greek refugee relocation push
# []
# []
# ['Thousands face homelessness in Greek refugee relocation push']
#  11%|████████▊                                                                      | 112/1000 [02:04<06:12,  2.38it/s]
# International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims: nigeria
# []
# []
# ['International Agencies Step Up Aid to Thousands of Refugee Camp Fire Victims: nigeria']
#  11%|████████▉                                                                      | 113/1000 [02:05<07:50,  1.89it/s]
# Great sympathy with Greeks but frankly with the numbers of migrants they have in their country I will give Greece a miss - so no worries about my wanting to go there.
# [[(0, 14, 15), (0, 7, 11), (0, 11, 12)]]
# [(['their', 'the numbers of migrants', 'they'], 1)]
# ['Great sympathy with Greeks but frankly with the numbers of migrants they have in their country I will give Greece a miss - so no worries about my wanting to go there.']
#  11%|█████████                                                                      | 114/1000 [02:06<10:16,  1.44it/s]
# A Petition for Lord Provost Philip Braat, Leader of Glasgow City Council Susan Aitken, and Councillors of Glasgow: GLASGOW MUST ACT! Pledge to relocate refugees and asylum seekers from the Aegean Island camps NOW! - Sign the Petition! via @ChangeOrg_India
# [[(0, 19, 20), (0, 21, 22)]]
# [(['Glasgow', 'GLASGOW'], 0)]
# ['A Petition for Lord Provost Philip Braat, Leader of Glasgow City Council Susan Aitken, and Councillors of Glasgow: GLASGOW MUST ACT!', 'Pledge to relocate refugees and asylum seekers from the Aegean Island camps NOW!', '- Sign the Petition!', 'via @ChangeOrg_India']
# Greek refugees??? Eh???
# []
# []
# ['Greek refugees???', 'Eh??', '?']
#  12%|█████████▏                                                                     | 116/1000 [02:08<10:10,  1.45it/s]
# The facility in Malakasa is to be the first controlled - access refugee and migrant facility in mainland greece, stated Migration and Asylum Minister Νότης Μηταράκης - Notis Mitarachi on Monday, speaking to MEGA TV
# []
# []
# ['The facility in Malakasa is to be the first controlled - access refugee and migrant facility in mainland greece, stated Migration and Asylum Minister Νότης Μηταράκης - Notis Mitarachi on Monday, speaking to MEGA TV']
#  12%|█████████▎                                                                     | 118/1000 [02:08<06:18,  2.33it/s]
# Greece Process to move migrants out of facilities begins on Monday [@Ekathimerni ]
# []
# []
# ['Greece Process to move migrants out of facilities begins on Monday [@Ekathimerni ]']
# Irish woman staging online exhibition for refugees in Greece -
# []
# []
# ['Irish woman staging online exhibition for refugees in Greece -']
#  12%|█████████▍                                                                     | 120/1000 [02:09<05:45,  2.55it/s]
# ' We must show that our reputation for openness & hospitality is more than a clich . We have done this before . Now we must do it again' Europe Must Act . Petition launched asking glasgow to accept Greek refugees refugees welcome
# [[(0, 1, 2), (1, 0, 1), (2, 1, 2), (0, 5, 6)], [(1, 3, 4), (2, 4, 5)]]
# [(['We', 'We', 'we', 'our'], 0), (['this', 'it'], 0)]
# ["' We must show that our reputation for openness & hospitality is more than a clich .", 'We have done this before .', "Now we must do it again' Europe Must Act .", 'Petition launched asking glasgow to accept Greek refugees refugees welcome']
# Irish woman staging online exhibition for refugees in GREECE
# []
# []
# ['Irish woman staging online exhibition for refugees in GREECE']
#  12%|█████████▌                                                                     | 121/1000 [02:10<09:25,  1.55it/s]
# This is today, refugees across greece who have had their status for more than a month will have to find their own accommodation, which in reality often means homelessness . Claiming asylum doesnt end the struggle, it is 1 step . More support needed to provide shelter & safety.
# [[(0, 4, 17), (0, 21, 22), (0, 10, 11)]]
# [(['refugees across greece who have had their status for more than a month', 'their', 'their'], 0)]
# ['This is today, refugees across greece who have had their status for more than a month will have to find their own accommodation, which in reality often means homelessness .', 'Claiming asylum doesnt end the struggle, it is 1 step .', 'More support needed to provide shelter & safety.']
#  12%|█████████▋                                                                     | 122/1000 [02:11<11:54,  1.23it/s]
# Authorities in Greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness
# [[(0, 2, 3), (0, 19, 21)], [(0, 36, 37), (0, 26, 29)]]
# [(['Greece', 'the mainland'], 0), (['them', 'other asylum seekers'], 1)]
# ['Authorities in Greece are to start moving more than 11,200 people out of flats, hotels and camps on the mainland, to make room for other asylum seekers currently living in dismal island camps leaving them facing homelessness']
#  12%|█████████▋                                                                     | 123/1000 [02:12<10:06,  1.45it/s]
# Naturally . Does anyone still believe that any of our political parties want to reduce immigration? Boris Govt Makes Special Deal to Fly In Migrants from Greece via Breitbart News
# []
# []
# ['Naturally .', 'Does anyone still believe that any of our political parties want to reduce immigration?', 'Boris Govt Makes Special Deal to Fly In Migrants from Greece via Breitbart News']
#  12%|█████████▉                                                                     | 125/1000 [02:12<07:47,  1.87it/s]
# What Greek refugees Greece not in war zone and not running from persecution so who are these probably scum coming leaving wives to get into UK and do what
# []
# []
# ['What Greek refugees Greece not in war zone and not running from persecution so who are these probably scum coming leaving wives to get into UK and do what']
# the _ new arab Thousands face homelessness in Greek refugee relocation push iraq
# []
# []
# ['the _ new arab Thousands face homelessness in Greek refugee relocation push iraq']
#  13%|█████████▉                                                                     | 126/1000 [02:15<15:28,  1.06s/it]
# Greek Police still harass African and South Asian immigrants and Roma ppl at higher rates than white Greek ppl, but given the percentage of these populations are lower than in US the Greek police enforce a lot of classist violence, frequently targeting various left movements.
# [[(0, 0, 2), (0, 32, 35)]]
# [(['Greek Police', 'the Greek police'], 1)]
# ['Greek Police still harass African and South Asian immigrants and Roma ppl at higher rates than white Greek ppl, but given the percentage of these populations are lower than in US the Greek police enforce a lot of classist violence, frequently targeting various left movements.']
#  13%|█████████▉                                                                     | 126/1000 [02:16<15:44,  1.08s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-4ae95443b79d> in <module>
#      70     return corefs_list
#      71
# ---> 72 event_corefs = extract_corefs(event_df['text_clean'])
#
# <ipython-input-18-4ae95443b79d> in extract_corefs(event_df, all)
#      60         # get coreference chains using the .annotate method of client handled by get_coref_chain function
#      61
# ---> 62         corefs_list = list(event_df.progress_apply(get_coref_chains))
#      63         #for tweet_id in tqdm(range(len(tweets_list))):
#      64             #coref_chains = [chain for chain in get_coref_chain(event_df[tweet_id],client)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py in inner(df, func, *args, **kwargs)
#     795                 # on the df using our wrapper (which provides bar updating)
#     796                 try:
# --> 797                     return getattr(df, df_function)(wrapper, **kwargs)
#     798                 finally:
#     799                     t.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py in wrapper(*args, **kwargs)
#     790                     # take a fast or slow code path; so stop when t.total==t.n
#     791                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 792                     return func(*args, **kwargs)
#     793
#     794                 # Apply the provided function (in **kwargs)
#
# <ipython-input-18-4ae95443b79d> in get_coref_chains(tweet, client)
#      15         def get_coref_chains(tweet,client=client):
#      16
# ---> 17             ann = client.annotate(tweet)
#      18             tweet_chains = ann.corefChain
#      19             all_chains = list()
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\server\client.py in annotate(self, text, annotators, output_format, properties, reset_default, **kwargs)
#     518         if reset_default is None:
#     519             reset_default = False
# --> 520         r = self._request(text.encode('utf-8'), request_properties, reset_default, **kwargs)
#     521         if request_properties["outputFormat"] == "json":
#     522             return r.json()
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\server\client.py in _request(self, buf, properties, reset_default, **kwargs)
#     449                               params={'properties': str(properties), 'resetDefault': str(reset_default).lower()},
#     450                               data=buf, headers={'content-type': ctype},
# --> 451                               timeout=(self.timeout*2)/1000, **kwargs)
#     452             r.raise_for_status()
#     453             return r
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
sent = ['Refugees can find information on their asylum procedures on these boards .', 'Today in the Moria Monitor, we address the communication channels at Camp Moria in Lesvos: leave no one behind']

loc = [[(0, 0, 1), (0, 5, 6)]]
words = [(['Refugees', 'their'], 0)]


for word in words[0]:
    

for word,lc in zip(words[0][0],loc[0]):
    sent[lc[0]][lc[1]:lc[2]] = word

# %% [markdown]
# ## 3. We instantiate stanza english language module

# %%
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ needed when running first time ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#

#stanza.download("en")

#stanza.install_corenlp()

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# loading the pipeline
en_nlp = stanza.Pipeline("en", tokenize_pretokenized=True, ner_batch_size=4096)
# Out:
# 2021-04-09 18:15:56 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-04-09 18:15:56 INFO: Use device: cpu
# 2021-04-09 18:15:56 INFO: Loading: tokenize
# 2021-04-09 18:15:56 INFO: Loading: pos
# 2021-04-09 18:15:56 INFO: Loading: lemma
# 2021-04-09 18:15:56 INFO: Loading: depparse
# 2021-04-09 18:15:58 INFO: Loading: sentiment
# 2021-04-09 18:16:00 INFO: Loading: ner
# 2021-04-09 18:16:02 INFO: Done loading processors!

# %%
import pickle

def pickle_files(file_name, file_to_dump):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path +  fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, 'wb') as fp:
        pickle.dump(file_to_dump, fp)

def load_pickle(file_name):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path + fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, "rb") as input_file:
        return pickle.load(input_file)

# %%
def load_event_data(event_name):
    assert event_name in ['moria','tigray','channel','all','beirut'], f"Oh no! We do not analyze {event_name} event"
    
    print(f'Loading {event_name} data...')
    try:
        #sample = 2000
        event_np_list = load_pickle(event_name + '_np_list')#[1000:sample]
        event_crf_list = load_pickle(event_name + '_crf_list')#[1000:sample]
        event_tagged_tweets = load_pickle(event_name + '_tagged_tweets')#[1000:sample]
        
        return event_np_list,event_crf_list,event_tagged_tweets
    except:
        print(f'The {event_name} files not found! Run candidate_extraction.py file on the {eventname}_df')
        return None

# %%
def pipeline(event_name):
    
    ####  ~~~~~~~~~~~~~~~~~~~~~ 1. LOAD THE DATA ~~~~~~~~~~~~~~~~~~~~~
    event_np_list,event_crf_list,event_tagged_tweets = load_event_data(event_name)
    
    
    ####  ~~~~~~~~~~~~~~~~~~~~~ 2. GET POS AND NER TAGS ~~~~~~~~~~~~~~~~~~~~~
    # get easily accessible list of tuples (POS-tags of each word, NER-tags of each named entity) 
    tweet_tags = cand_prep.get_tweet_tags(event_tagged_tweets) 
    
    
    ####  ~~~~~~~~~~~~~~~~~~~~~ 3. PREPROCESS CANDIDATES ~~~~~~~~~~~~~~~~~~~~~
    # ~~~~~~~~~~~~ processing of noun phrases ~~~~~~~~~~~~~~~~~~~~~
    print(f'Processing {event_name} noun phrase candidates...')
    
    tqdm.pandas()
    # remove NP candidates longer than threshold and remove all child NPs of parent NPs
    event_np_list = cand_prep.remove_long_nps(event_np_list)
    event_np_list = cand_prep.remove_child_nps(event_np_list) 
    #event_np_list = remove_weird_chars(event_np_list)
    event_np_list = cand_prep.remove_char(event_np_list,'@')

    event_np_list = [['no_candidate'] if len(noun_ps)==0 or noun_ps ==' ' else noun_ps for noun_ps in event_np_list ]
    
    #print(event_np_list)
    print(f'Tagging {event_name} noun phrase candidates...')
    #tag all tweets and save them in a list    

    #tagged_np_cands = batched_np_list.progress_apply(en_nlp)
    tagged_np_cands = [en_nlp('\n\n'.join(tweet_batch)) for tweet_batch in tqdm(event_np_list)]
    #tagged_np_cands = [tagged_cand for tagged_cand in tqdm(batch(batched_np_list, en_nlp, batch_size=6000))]

    np_cand_heads = [cand_prep.get_cand_heads(tweet_cands) for tweet_cands in tagged_np_cands]
    #print(np_cand_heads)
    
    np_and_cand_list = cand_prep.get_cand_type(event_np_list,np_cand_heads, tweet_tags)
    #print(event_np_list)
          
    # ~~~~~~~~~~~~ processing of coref candidates ~~~~~~~~~~~~~~~~~~~~~
    print(f'Processing {event_name} coreference candidates...')    
    
    #extract only the representative mentions as representative phrases of candidates
    event_crf_list = [[coref_group[0][coref_group[1]] for coref_group in tweet_corefs] for tweet_corefs in event_crf_list]
    
    #event_crf_list = remove_weird_chars(event_crf_list)
    event_crf_list = cand_prep.remove_char(event_crf_list,'@')

    event_crf_list = [['no_candidate'] if len(crf_ps)==0 else crf_ps for crf_ps in event_crf_list ]
    
    print(f'Tagging {event_name} coreference candidates...')       
    #tag all tweets and save them in a list    
    #batched_coref_list = cand_prep.prep_candlist_for_batching(event_crf_list)
    #print(batched_coref_list)
    tagged_coref_cands = [en_nlp('\n\n'.join(tweet_batch)) for tweet_batch in tqdm(event_crf_list)]
    #tagged_coref_cands = [tagged_cand for tagged_cand in tqdm(batch(batched_coref_list, en_nlp, batch_size=6000))] 
    #print(tagged_coref_cands)
        
    coref_cand_heads = [cand_prep.get_cand_heads(tweet_cands) for tweet_cands in tagged_coref_cands]
          
    coref_and_cand_list = cand_prep.get_cand_type(event_crf_list, coref_cand_heads, tweet_tags)
          
    # ~~~~~~~~~~~~~~~~~~~~ combining candidate lists ~~~~~~~~~~~~~~~~~~~~~~~~~~~
    #concatenate corefs and noun phrase lists
    nps_cands = [cand for cands in np_and_cand_list for cand in cands]
    crf_cands = [cand for cands in coref_and_cand_list for cand in cands]
    #candidate_list = coref_and_cand_list + np_and_cand_list
    #print(f'Len = {len(candidate_list)} should be 2x amount of tweets')
    #print(len(nps_cands), len(crf_cands))
    #unpack list of lists into one list
    candidate_list = nps_cands + crf_cands
    print(f'The amount of all candidates is {len(candidate_list)} -  nps: {len(nps_cands)}, crfs:{len(crf_cands)}')
          
    nps_tagged = [sent for tagged_cand in tagged_np_cands for sent in tagged_cand.sentences ]
    crf_tagged = [sent for tagged_cand in tagged_coref_cands for sent in tagged_cand.sentences ]
    print(len(nps_tagged), len(crf_tagged))
    all_cands_tagged = nps_tagged + crf_tagged

        
    #print(len(candidate_list),'vs', len(all_cands_tagged))
    cand_df = pd.DataFrame(
        {'candidates': candidate_list,
         'cand_tags': all_cands_tagged
        })

    cand_df['cand_text'] = cand_df.candidates.apply(lambda x: x[0])
    cand_df['cand_len'] = cand_df.cand_text.apply(lambda x: len(x.split()))


    count_cands = Counter(cand_df['cand_text'])
    cand_df['cand_freq'] = cand_df["cand_text"].map(count_cands)
    
    #count_cands[cand_df['cand_text']]
    #count_sorted = sorted(count_cands.items(),key=lambda x: x[1],reverse=True)
    cand_df.columns = cand_df.columns.str.strip()
    
          
    # we sort the candidates by their length
    cand_df.sort_values('cand_freq', ascending=False,inplace=True)

    #cand_df = cand_df[cand_df.cand_text not in  ['no_candidate', 'candidate_to_be_removed']]

    cand_df.reset_index(drop=True, inplace = True)
    #remove dummy candidates that were used to avoid errors

    print(len(cand_df))
    cand_df = cand_df[cand_df.cand_text != 'candidate_to_be_removed']
    cand_df = cand_df[cand_df.cand_text != 'no_candidate']
    len(cand_df)
    cand_df.reset_index(drop=True,inplace=True)
          
    return cand_df
          
          
moria_cands = pipeline('moria')

pickle_files('moria_cands_df', moria_cands)

# %% [markdown]
# ## 4. We apply stanza module on the tweets to get NER and POS tags. We do it in batches to speed things up.

# %% [markdown]
# ## 5. As initial WCL candidates, we extract noun phrases (NPs) and coreference chains.
#
# ## We do so using CoreNLPClient wrapper
#
# ### SOME PREPROCESSING NEEDED
# * remove links - check
# * remove # from hashtags? - check
# * remove/merge mentions? - check
#
#
# * remove recurring texts (signatures of news media) - any new spotted should be added in preprocessing file's '__remove_tweet_signatures__' function
# * remove posts of some accounts (refugee_list)
# * exclude NERs that tag numbers - should we mark phrase as NE if the head is not NE? - check
# * play around with candidate types
# * optimize code and make it neater

# %% [markdown]
# ## 6. We keep only NPs shorter than 20 words and remove children of parent NPs

# %% [markdown]
# ## 7. We get the heads of noun phrases (in batches)

# %% [markdown]
# ## 8. We define candidate types

# %% [markdown]
# ## 9. We assign candidate types to noun phrase candidates

# %% [markdown]
# ## 10. We get coreference chains candidates from the tweet corpus

# %% [markdown]
# ## 11. We determine candidate's type for representative mentions of coref candidates (in batches)

# %% [markdown]
# ## 12. We combine the candidate lists for candidate merging
#
# We organize candidates in a list sorted by their number of phrases

# %%
moria_cands = load_pickle('moria_cands_df')

# %%
beirut_whatmerged = load_pickle('beirut_whatmerged2')

# %%
beirut_whatmerged
# Out:
# defaultdict(list,
#             {'lebanon': ['lebanese',
#               'all those foreign fighters from lebanon and syria',
#               'the percentage of palestinian refugees in lebanon and syria',
#               '_ iraqi _ in lebanon',
#               'syrian and lebanon',
#               'ordeal in lebanon',
#               'months stranded in lebanon',
#               'your presence in lebanon',
#               'jrs lebanon',
#               'helping refugees in lebanon',
#               'the workforce in jordan & lebanon',
#               'csos in lebanon',
#               'our section in lebanon',
#               'the mountains of lebanon',
#               'many institutions in lebanon',
#               'ally with lebanon',
#               'a palestinian born in lebanon',
#               'pal in lebanon',
#               'dspr lebanon',
#               'the beauty of lebanon',
#               'pains of syrian and lebanon refugees',
#               'destabilization of lebanon',
#               'the syrian pen - seller in lebanon',
#               'their arab cousins in lebanon and jordan and syria',
#               'palestinian civil defense in lebanon',
#               'the national evangelical synod of syria and lebanon',
#               'political dominance in lebanon',
#               'i long for my parents in lebanon',
#               'sheltering in lebanon',
#               'one third of the country of lebanon',
#               'el kaa lebanon',
#               'eg tyre , lebanon',
#               'the genuine owners of lebanon',
#               'syria sheltered in lebanon',
#               'a buddy from lebanon',
#               'a humanitarian corridor between lebanon and israel',
#               'her main journalistic beat in lebanon',
#               'conflicting feelings about the country of lebanon',
#               'many middle eastern like lebanon',
#               'lebanese staying in lebanon',
#               'eg tyre, lebanon',
#               'lions in lebanon',
#               'macrons vow of a new lebanon',
#               'enclaves as little lebanon',
#               'spent time in lebanon and jordan',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               "you' re wanting to help in lebanon",
#               'the pogroms against us in iraq and lebanon',
#               'the cb of lebanon',
#               'the rejection of syria and lebanon',
#               'refugee nurses from lebanon',
#               'existing in lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'refugee cps in jordan and lebanon',
#               'nicaragua and lebanon',
#               'hills of lebanon',
#               'newcomers from lebanon',
#               'syrian live smatter syrian refugee camp in lebanon',
#               'shia power, witch reshaped south lebanon and beirut',
#               'any revenue to lebanon'],
#              'i': ['my', 'myself', 'clive and i', "that' s okay with you"],
#              'lebanese government': ['the syrian goverment'],
#              'you': ['your',
#               'yourself',
#               'its going to make you',
#               'personal - which says more about you than me',
#               "you' re cool with that as you",
#               'im just letting you',
#               "that' s okay with you"],
#              'migrant domestic workers in lebanon - sign the petition': ['lebanon - sign the petition'],
#              'refugees': ['a refugee',
#               'hundreds of syrian refugees',
#               'millions of refugees',
#               'the largest number of refugees per capita',
#               'returnees in syria + refugees',
#               'her family share as syrian refugees in lebanon',
#               'university scholarships to help refugees and lebanese nationals',
#               'plo the refugees would be safe',
#               'supporting refugees',
#               'cash transfers to syrian refugees in lebanon',
#               'lots of refugees',
#               'forever a cradle for refugees',
#               'a wave of refugees from lebanon',
#               'the sephardic songs of jewish refugees',
#               'cash aid transfer for palestinian refugees',
#               'a syrian refugees camp burned in libanon many families',
#               'syrian refugees already facing extreme poverty',
#               'waves of refugees',
#               'the naturalization of refugees',
#               'the heightened vulnerability of palestine refugees in lebanon',
#               'palestinian refugees plo came with them',
#               'the beirut blast many refugees are homeless',
#               'aids being given to refugees',
#               'hordes of refugees',
#               'make you refugees',
#               'demands of lebanese people and the many refugees',
#               'the potential flood of refugees',
#               'radio 4 on refugees and lebanon',
#               'the guise of refugees',
#               'ethiopia - 7 3 3 k deport afghan refugees',
#               'coronaviruszl, climate and refugees',
#               'the floodgates of refugees fleeing to europe',
#               'resettling syrian refugees from lebanon',
#               'the returning of the syrian refugees to their country',
#               'neuklln famous for many refugees',
#               'vilifying refugees',
#               'its jails & the refugees',
#               'aoun and others refugees',
#               'stays of syrian refugees',
#               'three quarters of the refugees in lebanon',
#               'the refugees qualification',
#               'no more suffrage & refugees',
#               'dinner with lebanon refugees',
#               'illegal abusive pushbacks by cyprus of migrants , refugees',
#               'the planning for a massacre of palestinian refugees',
#               'added awfulness , the many syrian refugees',
#               'potential inflows of refugees',
#               'the compulsory recruitment plus ~ 1.5 million refugees',
#               'education provisions and planning for refugees',
#               'syrian refugees did nt flee to sharia',
#               'palestinian refugees in the south housed',
#               '50,000 lebanese civillians and palestinian refugees - and thats',
#               'the permanent afflux of refugees',
#               'the dynamics between syrian refugees',
#               'the heavy lifting with refugees',
#               'trophies syrian refugees',
#               'the bulk of the first set of palestinian refugees',
#               'pregnancies for refugees',
#               'confrontations between refugees & the local population',
#               'the confrontation between refugees',
#               '$1billion received in support of refugees',
#               'fire ravages homes of syrian refugees in  south lebanon',
#               'ongoing for syrian refugees bienvenidos',
#               'common with the refugees of syria',
#               'the greatgrandchildren of the actual refugees',
#               'palestinian refugees they didnt anticipate plo',
#               'lebanon4 syrian refugees (c excell',
#               'war torn lebanon as refugees',
#               'no neutralization for refugees or workers',
#               'the mass deportations of palestinian refugees',
#               'claimed refugees',
#               'this whole we welcomed lebanese refugees',
#               'all perpetrated by refugees',
#               'a modicum of human decency for immigrants and refugees',
#               'demonizing refugees',
#               'refugees in lebanon not subjected to education',
#               'the sufferings of children refugees in our country',
#               'our acceptance of refugees to your country',
#               'lebanon much higher than others - - palestinian refugees',
#               'highly populated with refugees',
#               'lebanon being classified as stateless refugees'],
#              'them': ['us', 'several of them'],
#              'lebanese ministry of foreign affairs': ['refugee affairs',
#               'hamas office of refugee affairs',
#               'the ministries of public services and immigration affairs'],
#              'beirut': ['the port of beirut',
#               'syrian and lebanon',
#               'salam beirut',
#               'the outskirts of beirut',
#               'adjacent sabra neighborhood of beirut',
#               'the belly dancers of beirut',
#               'a mural in beirut',
#               'addis ababa to beirut',
#               'the dust cloud over beloved beirut',
#               'the footage from beirut',
#               'the communication sites calling us to beirut',
#               'an ideas associate living in beirut , lebanon',
#               'a missionary in beirut',
#               'his niece in beirut',
#               'neji , a syrian refugee in beirut',
#               'klm south of beirut',
#               'the vicinity of the lebanese capital beirut',
#               'bishop of beirut',
#               'beirut & chateau musar',
#               'caf in beirut',
#               'the southwest of beirut',
#               'shia power, witch reshaped south lebanon and beirut'],
#              'the petition': ['lebanon - sign the petition'],
#              'us': ['me', 'anyways im glad one of us'],
#              'lebanese migrants': ['smuggling migrants',
#               'lebanon hrw: cyprus pushed back lebanon migrants'],
#              'me': ['him', 'personal - which says more about you than me'],
#              'israel': ['palestinians',
#               'gaza',
#               'the israelis',
#               'israeli',
#               'the creation of israel',
#               'so - called palestinians',
#               'nato and israel',
#               'tension with israel',
#               'threats from israel',
#               'a humanitarian corridor between lebanon and israel',
#               'popular committees of palestinians of syria in lebanon',
#               'no coincidence israel and morocco',
#               'netanyahu',
#               'the parallel between the palestinians / israelis'],
#              'syria': ['syrians',
#               'iran',
#               'all those foreign fighters from lebanon and syria',
#               'the percentage of palestinian refugees in lebanon and syria',
#               'damascus',
#               'syrian and lebanon',
#               'the human beings from syria',
#               'large swathes of syria',
#               'arab countries such as lebanon and syria practice apartheid',
#               'pains of syrian and lebanon refugees',
#               'their arab cousins in lebanon and jordan and syria',
#               'talal from syria',
#               'laf invading parts of syria',
#               'the national evangelical synod of syria and lebanon',
#               'the utter horrors of syria',
#               '" inaction & proxy wars in syria / libya',
#               'the syrian & lebanese economies',
#               'damascus representatives of russia , iran , china and lebanon',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               'ammar ali ali from the palestinian refugees from syria',
#               'the rejection of syria and lebanon',
#               'lebanese and syrians - worrisome',
#               'common with the refugees of syria',
#               'a slang used in syria & lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'the armenian refugee colonies in syria'],
#              'he': ['im assuming he'],
#              's': ['tw s'],
#              'people': ['people who was around lebanese people are great',
#               'its so strange that people',
#               'estimated at6 , 825,445 people'],
#              'unrwa': ['unwra',
#               'director of unrwa in lebanon',
#               'palestine refugee camps & unrwa installations',
#               'memo unrwa',
#               'deputy commissioner - general of unrwa',
#               'the complete dependency of unrwa'],
#              'their homes': ['houses', 'syrian refugee dwellings'],
#              'she': ['her', 'the armenian chick she'],
#              'unhcr': ['unchr',
#               'a top donor to unhcrlebanon unhcr supporting'],
#              'more': ['less'],
#              'fire': ['blaze',
#               'fires',
#               'riot police fire tear gas',
#               'the arsonists of the syrian refugee camp fire'],
#              'palestinians': ['hamas',
#               'gaza',
#               'arabs',
#               'the israelis',
#               '3500 palestinian and lebanese civilians',
#               'israeli',
#               'xenophobic attitudes towards syrian and palestinian refugees',
#               'so - called palestinians',
#               'women palestinian refugees in lebanon can not be separated from the greater system of discrimination against palestinians',
#               'more shit tones of palestinians',
#               'invasion, occupations and slaughters of lebanese and palestinian refugees',
#               'i sort of separate between syrians and palestinians',
#               'but the worst disenfranchisement of palestinians actually',
#               'license for israel to genocide remaining palestinians',
#               'gazans',
#               'the dispossession of the palestinians',
#               'popular committees of palestinians of syria in lebanon',
#               'the parallel between the palestinians / israelis'],
#              'im': ['ahmed , im', 'iam'],
#              'the country': ['the nation',
#               'total islamization of the country',
#               'the most popular in our country'],
#              'turkey': ['the turkish',
#               'no erdogen fan but turkey',
#               'dumbass , turkey'],
#              'europe': ['germans in eastern europe',
#               'flow heading for europe'],
#              'lebanese immigrants': ['a lebanese immigrant',
#               'the grandson of some of the first lebanese immigrants',
#               'granddaughter of lebanese immigrants',
#               'where migrants',
#               'a descendent of those early lebanese immigrants',
#               'recent spaniard and lebanese immigrants',
#               'a grandchild of lebanese immigrants to canada',
#               'another strop about a dozen illegal immigrants',
#               'the top ten destinations of lebanese immigrants',
#               'too ~ classy ~ to be immigrants',
#               'a stranglehold on the the immigrants',
#               'its an artifact of lebanese immigrants',
#               'lebanese immigrants purchase',
#               'the bringing of muslim immigrants',
#               'the curse of lebanese immigrants'],
#              'her': ['herself'],
#              'the explosion': ['beirut blast',
#               'the hardest hit by the beirut port explosion',
#               'the wake of the beirut explosion',
#               'lost everything in the beirut explosion',
#               'advantage of the beirut explosion',
#               'responsible for the beirut explosion',
#               'the epicenter of the explosion',
#               'the ramifications of the port explosion',
#               'the writings on the beirut port explosion'],
#              'armenia': ['azerbaijan',
#               'armenian',
#               'the king of armenia',
#               'nikol pashinan saying that karabakh is armenia'],
#              'lebanese': ['syrian and lebanon',
#               '3500 palestinian and lebanese civilians',
#               'even less sympathy among lebanese',
#               'hizbullah',
#               'syrian and lebanese pro - independence societies',
#               'some filipino chinese or lebanese',
#               'both lebanese and syrian respondents',
#               'a very lebanese charles corm',
#               'pains of syrian and lebanon refugees',
#               'the jordanians and lebanese',
#               'both irish and lebanese',
#               'the syrian & lebanese economies',
#               'palestinian refugees, iranian and syrian political hacks',
#               'vulnerable lebanese and syrian refugee schoolchildren',
#               "shi'a lebanese",
#               'the unity of lebanese',
#               'syrians, libyans, tunisians & lebanese',
#               'congrats to the syrian & lebanese entrepreneurs',
#               'kataeb / hizbullah',
#               'the reactions of some lebanese',
#               'lebanese and syrians - worrisome',
#               'iranian, lebanese and somali smuggling rings'],
#              'the world': ['the most powerful in the world',
#               'immigrants world wide'],
#              'cyprus': ['migrants sailing to cyprus',
#               'asylum lawyers in cyprus'],
#              'help': ['offered help'],
#              'beirut blast': ['helpless - again - by beirut blast',
#               'beirut blasts',
#               'the hardest hit by the beirut port explosion',
#               'beirut blast possible human heartbeat'],
#              'your': ['yourself', 'yours'],
#              'money': ['funds',
#               'food, clothing and money',
#               'another donate without money',
#               'chuck money',
#               'syria spend their money'],
#              'syrians': ['syrian and lebanon',
#               'cause millions of syrians',
#               'iranians',
#               'the egyptians',
#               'both lebanese and syrian respondents',
#               'the jordanians and lebanese',
#               'i sort of separate between syrians and palestinians',
#               'lebanese and syrians - worrisome',
#               'popular committees of palestinians of syria in lebanon',
#               'por mister prince julio csar cardona syrians'],
#              'refugee camps': ['lebanon camp',
#               'palestinian familys in refugee camps',
#               'digital content in refugee camps',
#               'my clients who were living in these camps',
#               'informal systems foster small camps',
#               'their imprisonment in palestiain refugee camps',
#               'guerrilla bases and refugee camps'],
#              'a refugee': ['lebanese refugee claims',
#               'un refugee chief pledges',
#               'four generations in an armenian refugee',
#               'supporting refugees',
#               'my unhcr refugee file',
#               'email lebanse deadbeat refugee',
#               'hind a syrian refugee',
#               'the naturalization of refugees',
#               'aids being given to refugees',
#               'make you refugees',
#               'holistic views by palestine refugee',
#               'mouna sleiman , 58 , refugee from syria',
#               'the permanent afflux of refugees',
#               'these themes in all frontline refugee',
#               'local / refugee / migrant - owned sm es',
#               'a memorial in shatila refugee',
#               'the endorsement of a lebanese refugee',
#               'the mass deportations of palestinian refugees',
#               'a lebanese refugee next <3 eurovision',
#               'sex tape of a lebanon refugee',
#               'lebanon refugee entry pickup'],
#              'the uk': ['britain'],
#              'nothing': ['anything'],
#              '38 years': ['decades',
#               '6 months',
#               'a decade',
#               'this 6 years ago'],
#              'extreme poverty': ['persecution, assault and poverty',
#               'syrian refugees already facing extreme poverty',
#               'the threshold of poverty in lebanon',
#               'the fringes of poverty and homelessness',
#               'thousands of families slipping further into poverty'],
#              'un': ['rt un',
#               'u.n.',
#               'legal goverments known by un',
#               'shi el un'],
#              'palestine': ['the liberation of palestine'],
#              'hezbollah': ['all those foreign fighters from lebanon and syria',
#               'hamas',
#               'syrian and lebanon',
#               'nasrallah',
#               'hizballah',
#               'hizbullah',
#               'right to be there just like hezbollah',
#               'hezbullah',
#               'terrorist hizballah rule',
#               'lebanese christian cleric seen to criticize hezbollah',
#               "shi'a lebanese",
#               'kataeb / hizbullah',
#               'dar al - fatwa after blaze hezbollah',
#               'no hizbollah'],
#              '1': ['4',
#               '2',
#               'the 3 8',
#               '5',
#               '3',
#               '6',
#               '7',
#               '9',
#               'over 1',
#               'close to 1',
#               '1 / 1: paul'],
#              'many': ['its wonderful so many'],
#              'the streets': ['the street'],
#              'support': ['the outpouring of rightful support',
#               'offering support & solidarity'],
#              'france': ['the french',
#               'jordon and lebanon vs germany / france vs uk'],
#              'shelter': ['shelters', 'the girls get shelter & food'],
#              'children': ['a child',
#               'my parents',
#               'kids',
#               'the dreams of iraqi refugee children',
#               'adults skipping meals to provide for their children',
#               'their wives and children',
#               'afraid your children or grand - parents',
#               'there including 240 refugee children'],
#              'azerbaijan': ['ukraine', 'aliyev', 'kazakhstan'],
#              'a lot': ['its a lot cheaper'],
#              'these health, economic and political conditions': ['several health, economic and political crises',
#               'ongoing economic',
#               'the hearth of a political and economic crisis',
#               'poor socio - economic conditions',
#               'a multiplicity of factors - economic & political'],
#              'food': ['grain and food'],
#              'dire consequences for the failed unrwa administration': ['the unrwa administration'],
#              'thousands': ['tens of thousands'],
#              'everyone': ['everybody', 'an antisemite and everyone knows it'],
#              'iran': ['iranians',
#               'this dog of iran',
#               'damascus representatives of russia , iran , china and lebanon',
#               'lebanon ahead of iran'],
#              'the massacre': ['an unforgettable grief the massacre',
#               'no has ever been held accountable for this massacre',
#               'the planning for a massacre of palestinian refugees'],
#              'the middle of a 36 - hour slaughter': ['the slaughter'],
#              'god': ['allah', 'almighty'],
#              'citizenship': ['some proof of lebanese citizenship'],
#              'ethnic beirut armenians': ['racial slurs such as fuck armenians',
#               'the refugee label on armenians',
#               'resettlements of syrian armenians and lebanese armenians'],
#              'lebanese phalangist militias and the israeli military': ['our military',
#               'forming militias and armies',
#               'the dissolution of the militias'],
#              'a lebanese immigrant': ['joseph azar , a lebanese immigrant',
#               'lebanese immigrant thats seen first hand',
#               'recent spaniard and lebanese immigrants',
#               'mansour farah , a lebanese immigrant',
#               'lebanese immigrant half black half latino',
#               'adopted lebanese immigrant',
#               'm embarrassed that you an immigrant',
#               'an indian philosopher & immigrant'],
#              'hundreds of syrian refugees': ['millions of refugees',
#               'hordes of refugees',
#               'the permanent afflux of refugees'],
#              'the situation': ["' t bear this situation",
#               'further exacerbated the situation'],
#              'solidarity': ['offering support & solidarity',
#               'a strong expression of international solidarity'],
#              'funds': ['rt fund'],
#              'millions of refugees': ['55 million support package for syrian refugees',
#               'plo the refugees would be safe',
#               'supporting refugees',
#               'lots of refugees',
#               'a syrian refugees camp burned in libanon many families',
#               'waves of refugees',
#               'palestinian refugees plo came with them',
#               'lebanon has to manage 3.1 million refugees',
#               'aids being given to refugees',
#               'hordes of refugees',
#               'make you refugees',
#               'demands of lebanese people and the many refugees',
#               'the potential flood of refugees',
#               'excess of 1 million refugees',
#               'the guise of refugees',
#               'coronaviruszl, climate and refugees',
#               'the returning of the syrian refugees to their country',
#               'neuklln famous for many refugees',
#               'uk took less than 2 millions of syrian refugees',
#               'its jails & the refugees',
#               'illegal abusive pushbacks by cyprus of migrants , refugees',
#               'the compulsory recruitment plus ~ 1.5 million refugees',
#               'the permanent afflux of refugees',
#               'the greatgrandchildren of the actual refugees',
#               'the expense of a million azerbaijani refugees',
#               'the mass deportations of palestinian refugees',
#               'claimed refugees',
#               'demonizing refugees',
#               'the sufferings of children refugees in our country',
#               'lebanon much higher than others - - palestinian refugees'],
#              'a little girl': ['a syrian woman',
#               'a boy',
#               'saama al - khouri, nine year old syrian girl'],
#              'the agency': ['muse mohammed for the unmigration agency',
#               'the apt spox of agency'],
#              'life': ['pursuit of a better life', 'every facet of life'],
#              'anything': ['something', 'anybody', 'special or anything'],
#              'all those foreign fighters from lebanon and syria': ['the percentage of palestinian refugees in lebanon and syria',
#               '_ iraqi _ in lebanon',
#               'syrian and lebanon',
#               'hizbullah',
#               'dspr lebanon',
#               'arab countries such as lebanon and syria practice apartheid',
#               'pains of syrian and lebanon refugees',
#               'destabilization of lebanon',
#               'their arab cousins in lebanon and jordan and syria',
#               'the national evangelical synod of syria and lebanon',
#               'the syrian & lebanese economies',
#               'a humanitarian corridor between lebanon and israel',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               'ammar ali ali from the palestinian refugees from syria',
#               'the rejection of syria and lebanon',
#               'a slang used in syria & lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'nicaragua and lebanon',
#               'no hizbollah'],
#              'anyone': ['someone', 'anybody'],
#              'peace': ['lasting and just peace',
#               'agents of peace',
#               'rel of peace',
#               'the principal of peace'],
#              'this man in video': ['the video'],
#              'lebanese families': ['beirut grieving families and those'],
#              'mexico': ['flour tortillas in mexico', 'the conquest of mexico'],
#              'the war': ['wars',
#               'israels war machine',
#               'country ravaged by civil war',
#               'the depths of the lebanese civil war',
#               'no genocidal war raged against us',
#               'a republican incumbent war veteran'],
#              'crisis': ['a political crisis had a refugee crisis',
#               'economic collapses and the coronavirus crisis',
#               'the backdrop of a devastating economic crisis',
#               'knee - deep in crisis',
#               'multiple of crisis',
#               'the new variables of the crisis in the country',
#               'an important element in its financial crisis'],
#              'the region': ['all regions'],
#              'sept': ['aug', 'oct', 'nov', 'dec', 'feb'],
#              'edward francis arab': ['edward arab'],
#              'the kafala system': ['no health systems',
#               'the horrific kafala sytem'],
#              'access': ['lack of access'],
#              'the investigations': ['an international investigation committee, lebanese judiciary',
#               'a probe',
#               'an inquiry'],
#              '4': ['2', 'the 3 8', '5', '3', '6', '7', '9', 'over 1'],
#              'the middle east': ['north',
#               'the south',
#               'the african horn and middle east',
#               'the rivera of the mid east'],
#              'their land': ['their lands',
#               'plots of land in northern alberta'],
#              'the protection': ['livelihood classes child protection psychosocial support',
#               'the principles of refugee protection'],
#              'my family': ['moayad obeid and his family',
#               'your great country l and my family',
#               'ethiopian family joyful as migrant daughter'],
#              'macron': ['emmanuel macron'],
#              '16 , 1982, lebanese christian militiamen': ['lebanese phalange militiamen allied with israel'],
#              'the level of the arab countries': ['the donor countries',
#               'developing countries'],
#              'the video': ['videos'],
#              'their tents': ['stuck in tents',
#               'a tent',
#               'the burning down of refugees tents yesterday'],
#              'the water': ['electricity and water contaminated with human excrement'],
#              'a great danger': ['a threat'],
#              'germany': ['austria',
#               'germans in eastern europe',
#               'jordon and lebanon vs germany / france vs uk',
#               'a german'],
#              'several health, economic and political crises': ['ongoing economic',
#               'the hearth of a political and economic crisis',
#               'a major economic and financial cris',
#               'a multiplicity of factors - economic & political'],
#              '2': ['the 3 8', '5', '3', '6', '7', '9', 'over 1'],
#              'the percentage of palestinian refugees in lebanon and syria': ['syrian and lebanon',
#               'returnees in syria + refugees',
#               'her family share as syrian refugees in lebanon',
#               'xenophobic attitudes towards syrian and palestinian refugees',
#               'cash transfers to syrian refugees in lebanon',
#               'lock - down, beirut and refugees',
#               'syrian refugees are paid in lbp in lebanon',
#               'dspr lebanon',
#               'arab countries such as lebanon and syria practice apartheid',
#               'pains of syrian and lebanon refugees',
#               'destabilization of lebanon',
#               'a wave of refugees from lebanon',
#               'their arab cousins in lebanon and jordan and syria',
#               'the national evangelical synod of syria and lebanon',
#               'the lebanese treat its refugees worse then animals saudi',
#               'the heightened vulnerability of palestine refugees in lebanon',
#               'women palestinian refugees in lebanon can not be separated from the greater system of discrimination against palestinians',
#               'of economic recession , ineffectual political leadership and refugees from syria',
#               'radio 4 on refugees and lebanon',
#               'some draconian prohibitions against refugees taking jobs in lebanon',
#               'invasion, occupations and slaughters of lebanese and palestinian refugees',
#               'resettling syrian refugees from lebanon',
#               'keeping the refugees in lebanon  _',
#               'aoun and others refugees',
#               'three quarters of the refugees in lebanon',
#               'the 85,000 jews who escaped from the middle east and north africa they do nt get mentioned they are 3 million palestinian refugees in israel non in lebanon',
#               'a humanitarian corridor between lebanon and israel',
#               'many uprooted by the conflict in syria',
#               'lebanon and syria refusing citizenship to 4th generation descendants of palestine refugees',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               'ammar ali ali from the palestinian refugees from syria',
#               'eighty - nine percent of syrian refugees in lebanon',
#               'the rejection of syria and lebanon',
#               'common with the refugees of syria',
#               'popular committees of palestinians of syria in lebanon',
#               'refugees in lebanon not subjected to education'],
#              'education': ['" homeschooling without a home " refugee education',
#               'artisanship and education',
#               'lecturing or education'],
#              'women': ['these three men', 'important story, these women'],
#              'the donor countries': ['long wait in the host countries',
#               'developing countries',
#               'dependents in their home countries',
#               'many are hoping their home countries',
#               'fewer than many countries',
#               '0.9 percentage points in both countries',
#               'the long waiting in the host countries',
#               'several safe countries 2 freeload',
#               'loads of countries outside the eu'],
#              'my wife': ['their sick daughter',
#               'this mother',
#               'my husband',
#               'my two daughters'],
#              'yourself': ['yourselves'],
#              'decades': ['a decade', "it' s been similarly for many decades"],
#              'trump': ['president trump',
#               'donald trump',
#               'immigration ceremony - trump',
#               'tiffany trump',
#               'doles trump'],
#              'a fight': ['fighting', 'your fights'],
#              'assad': ['the war criminal bashar al assad',
#               'irgc and assad',
#               'arson perpetrated by lebanon / assad',
#               'badi assad',
#               'hafez al assad',
#               'asma al - akhras bashar al - assad'],
#              'amin': ['idi amin'],
#              'pressure': ['this demonstrating the enormous pressure'],
#              'someone': ['somebody'],
#              'plight of syrian refugees in lebanon': ['her family share as syrian refugees in lebanon',
#               'cash transfers to syrian refugees in lebanon',
#               'a wave of refugees from lebanon',
#               'the heightened vulnerability of palestine refugees in lebanon',
#               'radio 4 on refugees and lebanon',
#               'resettling syrian refugees from lebanon',
#               'three quarters of the refugees in lebanon',
#               'the plights of these migrants in lebanon',
#               'fire ravages homes of syrian refugees in  south lebanon'],
#              'asylum': ['lebanon and some explicitly requested asylum',
#               'haveto declare asylum'],
#              'sidon': ['municipality of sidon , lebanon'],
#              'school': ['schools', 'the basement of my beirut school'],
#              'assistance': ['expanded assistance and protection programming'],
#              'hamas': ['gaza',
#               'haniyeh',
#               'abbas',
#               'hizbullah',
#               'fatah',
#               'no hizbollah'],
#              'north': ['the south'],
#              'the international community': ['the lgbtiq + community',
#               'one single individu from the syrian community'],
#              'plo': ['israel arming plo'],
#              'my heart': ['heavy on every palestinians heart'],
#              'the vaccine': ['vaccines',
#               'vaccination',
#               'vaccinate / offer vaccines'],
#              'cant': ['thats',
#               'wont',
#               'me being told i cant',
#               'privileged for i cant'],
#              'shattered glass': ['shards of broken glass flying through the air'],
#              'a deplorable abuse of human rights': ['human rights',
#               'the radar for human rights abuses'],
#              'human rights': ['international human rights obligations',
#               'the minimum of human rights',
#               'basic of human rights'],
#              'britain': ['the british'],
#              'egypt': ['the egyptians'],
#              'corruption': ['clear evidence of the corruption of that administration',
#               'chaos, distruction & corruption',
#               'guardians of corruption'],
#              'their employers': ['their employer',
#               '1 recommending all employers'],
#              'any medications': ['medicines', 'her weekly medication', 'meds'],
#              'youtube': ['le .\xa0.\xa0. via youtube',
#               'the beirut banger via youtube'],
#              'august': ['september',
#               'march',
#               'october',
#               'june',
#               'february',
#               'july',
#               'january',
#               'may',
#               'april to may'],
#              'the iraqis': ['iraq', 'fault of being iraqis'],
#              'revenge attacks': ['an arson attack',
#               'bombings',
#               'the intensification of threats & attacks against those'],
#              'a problem': ['problems',
#               'to solve the very complicated problem'],
#              'racism': ['racist',
#               'misogyny or racism',
#               'colorism / racism',
#               'ongoing activist against racism and other forms of intolerance',
#               'ur mind racism homophobic and another',
#               'discord / infighting / hate / racism',
#               'zero evince of racism',
#               'religious homophobia'],
#              'sweden': ['denmark', 'norway', 'swedes', 'finland'],
#              'their homeland': ['lovely souvenirs of my homeland'],
#              'lebanese citizens': ['a citizen',
#               'non - citizens',
#               'struggling economy for regular citizens'],
#              "i' m": ['appx 7 m'],
#              'reunion their sick daughter': ['their sick daughter'],
#              'the supervision and protection of ariel sharon': ['ariel sharon'],
#              'night': ['tomorrow evening', 'our afternoon'],
#              '+': ['amdg +', 'lgbtqia +'],
#              'networks': ['alliances and networks'],
#              'the largest number of refugees per capita': ['lots of refugees',
#               'the permanent afflux of refugees'],
#              '36 hours': ['three days'],
#              'muslim immigrant communities': ['new clusters in marginalized communities',
#               'local contexts & vulnerable communities',
#               'a wide variety of highly marginalized communities',
#               'lgbt + communities'],
#              'gaza': ['israeli',
#               'nablus to rafah',
#               'a widow and her children in gaza',
#               'wb / gaza',
#               'gazans'],
#              'the 3 8': ['5', '3', '6', '7', '9'],
#              'iraq': ['afghanistan',
#               'hiring mercenaries from afghanistan , iraq , lebanon and pakistan'],
#              'my arab friend': ['friends'],
#              'asylum seekers': ['brid suggest asylum seekers'],
#              'australia': ['lebanese australians', 'an australian'],
#              'greece': ['the greek', 'the savior of greece'],
#              'unicef': ['who & unicef urge'],
#              'christians': ['muslims',
#               'ethnic cleansing of the native christians',
#               'your hate of jews & christians',
#               'many catholics',
#               'the relevance of coptic christians',
#               'finance the christians',
#               'lebanese melkites and catholics'],
#              'my name': ['names', 'his surname'],
#              'need': ['the are resilient but need our help'],
#              'damascus': ['syrian and lebanon',
#               'the mass murderer in damascus'],
#              'a difference': ['smart, happy, resourceful the one difference'],
#              'the link': ['links'],
#              '_ iraqi _ in lebanon': ['syrian and lebanon',
#               '3500 palestinian and lebanese civilians',
#               'dspr lebanon',
#               'military aged males from syria and lebanon',
#               'the pogroms against us in iraq and lebanon',
#               'popular committees of palestinians of syria in lebanon'],
#              'the canadian economy': ['ongoing economic',
#               'dying or the economy',
#               'the foundations of its economy',
#               'a complete reconfiguration of its economy',
#               'the economy being wrecked by corrupt politicians'],
#              'africa': ['the african continent',
#               'the fastest growing in africa'],
#              'a child': ['a child my mum fostered children in care'],
#              'their jobs': ['many losing their jobs'],
#              'boats': ['boat',
#               'the arrival of four boats',
#               'few desperates on boats'],
#              'the future': ['bleak the future'],
#              'sunday': ['tuesday',
#               'wednesday',
#               'monday',
#               'saturday',
#               'thursday'],
#              'cold blood': ['his blood pumping under my skin'],
#              'lebanon court': ['the courts',
#               'palestinian supreme court justices and mps'],
#              'the port of beirut': ['salam beirut',
#               'the outskirts of beirut',
#               'adjacent sabra neighborhood of beirut',
#               'the southwest of beirut'],
#              'coronavirus': ['contracting coronavirus'],
#              'winter': ['harsh winters'],
#              'response': ['their responses',
#               'the emergency response mechanism'],
#              '- ongoing anti - government protests': ['lebanon panicked - ongoing anti - government protests',
#               'the revolutions and the protests'],
#              'israeli forces': ['a negative of external forces'],
#              'your donations': ['a donation'],
#              'chaos and hardship': ['new hardships',
#               'economic hardship',
#               'turmoil and additional hardships'],
#              '6 months': ['three days', 'recent weeks', 'this 6 years ago'],
#              'example': ['instance'],
#              '5': ['3', '6', '7', '9', 'over 1'],
#              'these three men': ['robert kennedy some men'],
#              'muslims': ['muslim',
#               'moslems',
#               'all muslims black latino asian'],
#              '3': ['6', '7', '9', 'over 1'],
#              'reuters': ['afp'],
#              'its doors': ['the door'],
#              'ngos': ['an ngo', 'the mol and some ngos', 'ingos'],
#              'capita': ['large per capita'],
#              'the grandson of some of the first lebanese immigrants': ['lt. edward arab who was a soldier , a lawyer and grandson of some of the earliest lebanese immigrants to nova scotia',
#               'granddaughter of lebanese immigrants',
#               'rob turfe , usma 90 , the grandson of a lebanese immigrant , he and his brother',
#               'col james jabara, the son of lebanese immigrants',
#               'a descendent of those early lebanese immigrants',
#               'recent spaniard and lebanese immigrants',
#               'a grandchild of lebanese immigrants to canada'],
#              'corrupt politicians': ['these shit corrupt politicans',
#               'lebanese politicos'],
#              'their sick daughter': ['my father',
#               'this mother',
#               'the son',
#               'my husband',
#               'my sister',
#               'my two daughters',
#               'justicefor ayah our muslim sister',
#               'ethiopian family joyful as migrant daughter',
#               'his grandmother'],
#              'the most vulnerable': ['exclusion of the most vulnerable'],
#              'a solution': ['solutions'],
#              'the mediterranean': ['the jewel of the mediterranean'],
#              'tripoli': ['two mosques in tripoli'],
#              'slaves': ['damn, more african slaves just rescued in lebanon'],
#              'ethiopia': ['ethiopians',
#               'ethiopian',
#               'two adopted sons from ethiopia',
#               'eritrea'],
#              'vaccines': ['vaccinate / offer vaccines', 'vaccinations'],
#              'arabs': ['the israelis',
#               'i sort of separate between syrians and palestinians',
#               'delegitimize muslim arabs as foriegn invaders',
#               'the dispossession of the palestinians',
#               'the parallel between the palestinians / israelis'],
#              'a few hundred': ['a few thousand'],
#              'hospitals': ['hospital',
#               'the good functioning of public hospitals',
#               'a saturation of its hospitals'],
#              'injustice and hunger': ['hunger'],
#              'many professions': ['our profession',
#               'certain well paying professions'],
#              'guys': ['this guy', 'the young guys tshirt'],
#              'her hearing': ['hearings', 'faith comes by hearing'],
#              'syrian and lebanon': ['xenophobic attitudes towards syrian and palestinian refugees',
#               'hizbullah',
#               'syrian and lebanese pro - independence societies',
#               'some filipino chinese or lebanese',
#               'dspr lebanon',
#               'both lebanese and syrian respondents',
#               'arab countries such as lebanon and syria practice apartheid',
#               'a very lebanese charles corm',
#               'pains of syrian and lebanon refugees',
#               'destabilization of lebanon',
#               'the jordanians and lebanese',
#               'their arab cousins in lebanon and jordan and syria',
#               'talal from syria',
#               'the national evangelical synod of syria and lebanon',
#               'both irish and lebanese',
#               'the syrian & lebanese economies',
#               'palestinian refugees, iranian and syrian political hacks',
#               'el kaa lebanon',
#               'eg tyre , lebanon',
#               'vulnerable lebanese and syrian refugee schoolchildren',
#               'a humanitarian corridor between lebanon and israel',
#               "shi'a lebanese",
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               'congrats to the syrian & lebanese entrepreneurs',
#               'kataeb / hizbullah',
#               'the rejection of syria and lebanon',
#               'existing in lebanon',
#               'lebanese and syrians - worrisome',
#               'a slang used in syria & lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'nicaragua and lebanon',
#               'sixty - two syrians returning from lebanon',
#               'shia power, witch reshaped south lebanon and beirut'],
#              'the population as a whole': ['a tenth of the uks population',
#               'a fourth of lebanons population',
#               'no responsibily for a hostile population'],
#              'local youths and camp residents': ['residents',
#               'clash between camp residents and youths'],
#              'brazil': ['argentina', 'brazilian'],
#              'the area': ['kesrouan and the area'],
#              'the impact': ["they' re just a few of the impact"],
#              'the right': ['hezbollahs political wing right'],
#              'relief efforts': ['relief effort'],
#              'power': ['the lebanese put in power'],
#              'our partners': ['rescue teams + partners'],
#              'ive': ['kenneth ive'],
#              'team': ['dave and the csi team'],
#              'the brink': ['the precipice'],
#              'my dad': ['my father',
# ...
#               'a descendent of those early lebanese immigrants',
#               'recent spaniard and lebanese immigrants',
#               'a grandchild of lebanese immigrants to canada',
#               'my mother immigrated here from poland and my grandma'],
#              'ukraine': ['latvia', 'kazakhstan', 'belarus or hungary'],
#              'your fascism': ['a right wing fascist'],
#              'a workshop': ['workshops'],
#              'my grandpa': ['my granddad'],
#              'whos ancestors': ['lebanese descendents',
#               'my last immigrant ancestor',
#               'your forefathers'],
#              'the currency': ['an 80% depreciation of its currency',
#               '19 new normal digital currency economics'],
#              'pal in lebanon': ['dspr lebanon'],
#              'praying fir lebanese people and all the immigrants': ['a multitude of immigrants'],
#              'dspr lebanon': ['director of unrwa in lebanon',
#               'arab countries such as lebanon and syria practice apartheid',
#               'the beauty of lebanon',
#               'pains of syrian and lebanon refugees',
#               'destabilization of lebanon',
#               'their arab cousins in lebanon and jordan and syria',
#               'palestinian civil defense in lebanon',
#               'the national evangelical synod of syria and lebanon',
#               'rising pressure: portrayals of syrian despair in lebanon',
#               'i long for my parents in lebanon',
#               'sheltering in lebanon',
#               'one third of the country of lebanon',
#               'el kaa lebanon',
#               'eg tyre , lebanon',
#               'syria sheltered in lebanon',
#               'a humanitarian corridor between lebanon and israel',
#               'many middle eastern like lebanon',
#               'lebanese staying in lebanon',
#               'eg tyre, lebanon',
#               'lions in lebanon',
#               'enclaves as little lebanon',
#               'spent time in lebanon and jordan',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               "you' re wanting to help in lebanon",
#               'the pogroms against us in iraq and lebanon',
#               'the cb of lebanon',
#               'the rejection of syria and lebanon',
#               'refugee nurses from lebanon',
#               'existing in lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'refugee cps in jordan and lebanon',
#               'nicaragua and lebanon',
#               'hills of lebanon',
#               'newcomers from lebanon',
#               'syrian live smatter syrian refugee camp in lebanon',
#               'shia power, witch reshaped south lebanon and beirut'],
#              'greek orthodox': ['russian orthodoxy'],
#              'a netflix doc': ['docs'],
#              'a corrupt ruling elite': ['their hateful incompetence of the elite'],
#              '1500 rate': ['high unemployment rates'],
#              'the tories': ['conservatives'],
#              'riad salameh': ['iad salameh',
#               'abdel nasser',
#               'bassam al - hallak',
#               'salameh'],
#              'iad salameh': ['salameh'],
#              'payments': ['payment'],
#              'this idiot': ['a complete moron'],
#              'both lebanese and syrian respondents': ['the jordanians and lebanese',
#               'both irish and lebanese',
#               'the syrian & lebanese economies',
#               'palestinian refugees, iranian and syrian political hacks',
#               'vulnerable lebanese and syrian refugee schoolchildren',
#               "shi'a lebanese",
#               'syrians, libyans, tunisians & lebanese',
#               'congrats to the syrian & lebanese entrepreneurs',
#               'lebanese and syrians - worrisome'],
#              'right wing lebanese nationalists': ['hezbollahs political wing right'],
#              'lebanon have been over - exploited': ['the most marginalized and exploited'],
#              'keith': ['scott', 'jeff', 'james jeffrey', 'jim'],
#              'eating pork - but': ['the teasing we got for eating pita bread'],
#              'a polish aunt of mind': ['his grandmother'],
#              'mustafa': ['walaa ali al ali',
#               'luqman salim and hisham al - hashemi',
#               'khaled',
#               'kassem and mohamad'],
#              'january': ['may', 'april to may'],
#              'dismantling the zionist entity': ['the same entity'],
#              'outrage': ['your anger', 'little outcry'],
#              'kareem': ['jamal'],
#              'the winners of the mun refugee challenge': ['the latest challenge'],
#              'their responses': ['the evaluations of previous responses'],
#              'afghans fleeing the taliban': ['insurgents'],
#              'abdel nasser': ['mohamed',
#               'walaa ali al ali',
#               'bassam al - hallak',
#               'sameeh mahmoud',
#               'khaled',
#               'boshra and safaa',
#               'walid',
#               'kassem and mohamad',
#               'oussama obeid'],
#              'a downward spiral': ["recent years' downward spiral"],
#              'the online': ['daily mail online'],
#              'oxfam': ['cordaid and oxfam novib'],
#              'mexican cuisine': ['the delicacies'],
#              'abdullah hammoud': ['hammoud',
#               'bourj hammoud',
#               'kassem and mohamad'],
#              'more oppression': ['soviet repression'],
#              'your games': ['the game', 'toys and games'],
#              'high speeds': ['speed'],
#              'criminals rebel': ['the islamist rebels'],
#              'doncaster': ['gateshead'],
#              'arab countries such as lebanon and syria practice apartheid': ['their arab cousins in lebanon and jordan and syria',
#               'damascus representatives of russia , iran , china and lebanon',
#               'military aged males from syria and lebanon',
#               'the rejection of syria and lebanon',
#               'popular committees of palestinians of syria in lebanon'],
#              'a very lebanese charles corm': ['the jordanians and lebanese'],
#              'fanatical zionist settlers': ['a pair of lebanese settlers'],
#              'hammoud': ['bourj hammoud'],
#              'our peacekeepers': ['peacekeeping'],
#              'dec': ['feb'],
#              'rubber dinghies': ['dinghy'],
#              'frustration': ['your anger', 'disgust'],
#              '13 - year - old manal': ['8 - month - old mayar',
#               '10 - year - old batoul',
#               'omar khaled , an 11 - year - old in akkar',
#               '13 - year - old rami',
#               '13 - year - old hamzi el hassan',
#               'an 11 - year - old in akkar',
#               '11 year old wardi',
#               'saama al - khouri, nine year old syrian girl',
#               '4 - year - old layan'],
#              'housekeepers, nannies and carers': ['housekeepers, carers or nannies'],
#              'a millionaire': ['lebanese billionaire'],
#              'the failure': ['an escape goat for policy failure',
#               'systemic dysfunction and failure'],
#              'survivor of sabra and shatila massacre': ['the palestinian refugees massacred in sabra and shatila'],
#              'hicham kayed': ['bassam al - hallak',
#               'basma el husseiny',
#               'sameeh mahmoud',
#               'kayed',
#               'kassem and mohamad'],
#              'birth certificates': ['a certificate'],
#              'migrant domestic laborers in lebanon': ['najdeh lebanon',
#               'the dehumanization of african workers in lebanon'],
#              'the structure': ['the reception structures'],
#              'relief items': ['500 boxes filled with essential food items'],
#              'this incredible model for coexistence': ['the utopia of a coexistence of communities'],
#              'the last sentence of the article': ['essence of this sentence'],
#              'pains of syrian and lebanon refugees': ['a wave of refugees from lebanon',
#               'their arab cousins in lebanon and jordan and syria',
#               'the national evangelical synod of syria and lebanon',
#               'the lebanese treat its refugees worse then animals saudi',
#               'the heightened vulnerability of palestine refugees in lebanon',
#               'women palestinian refugees in lebanon can not be separated from the greater system of discrimination against palestinians',
#               'of economic recession , ineffectual political leadership and refugees from syria',
#               'radio 4 on refugees and lebanon',
#               'the syrian & lebanese economies',
#               'some draconian prohibitions against refugees taking jobs in lebanon',
#               'invasion, occupations and slaughters of lebanese and palestinian refugees',
#               'resettling syrian refugees from lebanon',
#               'keeping the refugees in lebanon  _',
#               'aoun and others refugees',
#               'three quarters of the refugees in lebanon',
#               'vulnerable lebanese and syrian refugee schoolchildren',
#               'lebanon and syria refusing citizenship to 4th generation descendants of palestine refugees',
#               'the syrian, lebanese and african refugees bypass countries',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'military aged males from syria and lebanon',
#               'ammar ali ali from the palestinian refugees from syria',
#               'the rejection of syria and lebanon',
#               'the plights of these migrants in lebanon',
#               'lebanese and syrians - worrisome',
#               'common with the refugees of syria',
#               'popular committees of palestinians of syria in lebanon',
#               'a physiotherapist working with refugees in lebanon',
#               'refugees in lebanon not subjected to education',
#               'the topic of lebanese and palestinian refugees feud'],
#              'white liberals': ['democrats', 'a proper liberal'],
#              'the druze': ['the golani and galilean druze'],
#              'the palestinian refugees massacred in sabra and shatila': ['wisal from shatila'],
#              'feeling': ['lebanese canadian feel'],
#              'our sisters': ['her siblings',
#               'evil far from our brothers & sisters'],
#              'destabilization of lebanon': ['their arab cousins in lebanon and jordan and syria',
#               'palestinian civil defense in lebanon',
#               'the national evangelical synod of syria and lebanon',
#               'rising pressure: portrayals of syrian despair in lebanon',
#               'traitors of lebanon',
#               'a humanitarian corridor between lebanon and israel',
#               'many middle eastern like lebanon',
#               'military aged males from syria and lebanon',
#               'the pogroms against us in iraq and lebanon',
#               'the rejection of syria and lebanon',
#               'existing in lebanon',
#               'popular committees of palestinians of syria in lebanon',
#               'nicaragua and lebanon'],
#              'her siblings': ['uncles , cousins , and friends'],
#              'missing': ['their tally of the missing',
#               '41 confirmed dead and two still missing'],
#              'moses': ['juliet moses'],
#              'viewers': ['the viewer'],
#              'lgbtq +': ['lgbtqia +'],
#              'mariam': ['halima al haj ali'],
#              'dangers': ['beirut explosion, migrant perils'],
#              'the sweetest districts and streets in beirut': ['adjacent sabra neighborhood of beirut'],
#              'prisons': ['pows in israeli prisons',
#               'inmates in other lebanon prisons'],
#              'the dangerous stockpile': ['- medical stockpiles'],
#              'the mistreatment': ['the marginalization and mistreatment of syrian refugees'],
#              'their courage': ['steadfastness and bravery'],
#              'agreements': ['the abraham accords'],
#              "you think it'": ['ignorant of you to think everyone'],
#              'kenyans in lebanon': ['the jordanians and lebanese'],
#              'cummings': ['the unapologetic johnson and cummings'],
#              '8 - month - old mayar': ['10 - year - old batoul',
#               '11 year old wardi',
#               '4 - year - old layan'],
#              'a bill for cleanup after the beirut blast': ['the cleanup'],
#              'freezing temperatures': ['temperature below zero and snow storms'],
#              'slovenia': ['its involvement> lithuania',
#               'latvia',
#               'bulgaria or albania',
#               'croatia',
#               'slovakia'],
#              'ages': ['warrior since ages'],
#              'the flow of refugees that destabilize countries': ['many destroy documents, refugees from more extreme muslims countries'],
#              'a wave of refugees from lebanon': ['tide of migrants fleeing lebanon',
#               'waves of refugees',
#               'the heightened vulnerability of palestine refugees in lebanon',
#               'women palestinian refugees in lebanon can not be separated from the greater system of discrimination against palestinians',
#               'of economic recession , ineffectual political leadership and refugees from syria',
#               'radio 4 on refugees and lebanon',
#               'some draconian prohibitions against refugees taking jobs in lebanon',
#               'resettling syrian refugees from lebanon',
#               'keeping the refugees in lebanon  _',
#               'three quarters of the refugees in lebanon',
#               'lebanon and syria refusing citizenship to 4th generation descendants of palestine refugees',
#               '" the war followed me from syria to lebanon " ahmed staifi a syrian refugee',
#               'the permanent afflux of refugees',
#               'ammar ali ali from the palestinian refugees from syria',
#               'fire ravages homes of syrian refugees in  south lebanon',
#               'common with the refugees of syria',
#               'refugees in lebanon not subjected to education'],
#              'some morons': ['those assholes', 'a complete moron'],
#              'tracking migrants': ['where migrants',
#               'a mix of caucasus migrants',
#               'iomlebanon please protect them migrants'],
#              'our fx reserves': ['reserve'],
#              'the scots': ['plantation resembles the ulster scots on ni'],
#              'interview': ['rubin interview'],
#              'difficult': ['sti very difficult'],
#              'mothers': ['his fathers', 'lebanese moms'],
#              'oh': ['wow'],
#              'other cultures': ['different religions and cultures',
#               'people often caught between two cultures'],
#              'lebanon elimination of corruption refugees': ['the terror acts of refugees'],
#              'starvation': ['many already destitute and facing starvation'],
#              'may': ['april to may', 'feb'],
#              'experts': ['trauma specialists'],
#              'democrats': ['better dems', 'republicans and there'],
#              'cancer': ['cancers'],
#              'antisemitism': ['islamophobia'],
#              'their sponsors': ['[m] ost of these sponsors'],
#              'minnesota': ['minneapolis'],
#              'the jordanians and lebanese': ['the lebanese treat its refugees worse then animals saudi',
#               'both irish and lebanese',
#               'the syrian & lebanese economies',
#               'i sort of separate between syrians and palestinians',
#               'vulnerable lebanese and syrian refugee schoolchildren',
#               "shi'a lebanese",
#               'the unity of lebanese',
#               'syrians, libyans, tunisians & lebanese',
#               'lebanese and syrians - worrisome',
#               'popular committees of palestinians of syria in lebanon'],
#              ...})

# %% [markdown]
# ### First merging step

# %%
#
# THIS IS THE FIRST MERGING STEP
#

        
def merging_step1(candidate_list):
    """
    In the first merging step, we merge two candidates if the head of each of their representative phrase 
     is identical by string comparison.
    """

    indices_to_remove = set()
    for up_cand_id in tqdm(range(len(candidate_list))):   

        if up_cand_id in indices_to_remove:
            continue
        up_cand = candidate_list[up_cand_id]    
            
        for low_cand_id in range(up_cand_id+1,len(candidate_list)):
            low_cand = candidate_list[low_cand_id]

            if up_cand[1].lower() == low_cand[1].lower():# and upper_cand[3] == lower_cand[3]:


                indices_to_remove.add(low_cand_id)

                
    return indices_to_remove


def merge_indices(cand_df,indices_to_remove):                

    print(f'Initial amount of candidates: {len(cand_df)}')                
    #print(len(sorted(indices_to_remove)))

    #for index in reversed(sorted(indices_to_remove)):
    cand_df.drop(indices_to_remove,inplace=True)
        
    cand_df.reset_index(drop=True,inplace=True)
    print(f'Amount of candidates: {len(cand_df)}, after removing {len(sorted(indices_to_remove))} indices') 
    return cand_df

# %%
event_cands_merged

# %%
for cand in cand_df['candidates']:
    print(cand[1], cand[3])

# %% [markdown]
# ### Second merging step
#
# We merge 2 candidates if their sets of phrases heads are semantically similar

# %%
import gensim

#load the GoogleNews 300dim model (fix path)
model = gensim.models.KeyedVectors.load_word2vec_format(r'C:\Users\nikodemicek\Dropbox (CBS)\Master thesis data\GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
from gensim.models import Word2Vec

event_series = event_df['text'].apply(lambda x: x.split(' '))
model_moria = Word2Vec(event_series,size=200)

# %%
model.most_similar('refugee')
# Out:
# [('refugees', 0.8041340112686157),
#  ('asylum_seeker', 0.7111446857452393),
#  ('asylum_seekers', 0.6694400906562805),
#  ('Refugee', 0.6444518566131592),
#  ('refugee_status', 0.6259119510650635),
#  ('asylum', 0.6098962426185608),
#  ('refugee_resettlement', 0.6018669605255127),
#  ('UNHCR', 0.5838466882705688),
#  ('displaced_persons', 0.5829589366912842),
#  ('Refugees', 0.5805562734603882)]

# %%
model_moria.most_similar('moria')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('lesbos', 0.7489250302314758),
#  ('Eleonas', 0.6656873226165771),
#  ('La', 0.664945125579834),
#  ('Mae', 0.6619389057159424),
#  ('Moria.', 0.6439236402511597),
#  ('#Lipa', 0.6374841332435608),
#  ('Lipa', 0.633926510810852),
#  ('Karatepe', 0.6262264847755432),
#  ('#Jerusalem,', 0.610672116279602),
#  ('Karen', 0.6037241220474243)]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine
import numpy as np

def merging_step2(candidate_list):
    
    indices_to_remove = set()
    
    for upper_cand_id in tqdm(range(len(candidate_list))):     
        upper_cand = candidate_list[upper_cand_id]
        
        up_cand_mean_vec = phrase_heads_avg_vector(upper_cand[2])
        
        for lower_cand_id in range(upper_cand_id+1,len(candidate_list)): 
            lower_cand = candidate_list[lower_cand_id]
            #print(f'for index {candidate_list.index(longer_cand)} checking the index {candidate_list.index(cand)}')
            #if candidate_list[longer_cand][1] == candidate_list[cand][1]:
                #print(f'matching "{longer_cand}" with "{cand}"')
            low_cand_mean_vec = phrase_heads_avg_vector(lower_cand[2])

            if upper_cand[3] == lower_cand[3]:
                #try:
                    #print(1-cosine(long_cand_mean_vec,cand_mean_vec))
                    #print(long_cand_mean_vec.reshape(-1,1).shape, cand_mean_vec.reshape(1,-1).shape)
                    if 1-cosine(up_cand_mean_vec,low_cand_mean_vec) >= 0.7:
                        #print(f'matching "{longer_cand}" with "{cand}"') 
                        indices_to_remove.add(lower_cand_id)
                        what_merged2[upper_cand[0].lower()].append(lower_cand[0].lower())
                        
                #except AttributeError:
                    #pass

            else:

                if 1-cosine(up_cand_mean_vec,low_cand_mean_vec) >= 0.8:
                    #print(f'matching "{longer_cand}" with "{cand}"') 
                    indices_to_remove.add(lower_cand_id)
                    what_merged2[upper_cand[0].lower()].append(lower_cand[0].lower())



    return indices_to_remove

def phrase_heads_avg_vector(phrase_set):
    phrase_head_vectors = []
    for phrase_head in phrase_set:    
        try:
            phrase_head_vectors.append(model[phrase_head])
        except KeyError:
            phrase_head_vectors.append(np.NaN)
    #phrase_head_vectors = [model[phrase_head] for phrase_head in phrase_set]
    if len(phrase_head_vectors) != 0:
        return np.mean(phrase_head_vectors,axis=0)
    else: 
        return np.NaN

# %%
list(event_cands_merged['cand_text'])

# %%
for cand in cand_df['candidates']:
    print(cand[1], cand[3])

# %% [markdown]
# ## Third merging step representative labeling
#
# currently working on average cosine similarity of each phrase in the candidate - maybe not optimal, maybe it will be better with a different threshold

# %%
from sklearn.cluster import AffinityPropagation

from sklearn.metrics.pairwise import cosine_similarity

def merging_step3(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:  
        #the head of noun phrase is marked with value 0 for the word.head
        cand_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]
        #np_pos_tags = {word.text: word.xpos for sent in doc.sentences for word in sent.words}
        #print(np_heads_pos)
        cand_labeling_phrases = []
        for word, head, pos in cand_heads_pos:
            #head-1 because the pointer to head does not use 0 index
            if (pos == 'JJ' or pos=='VBN') and 'NN' in cand_heads_pos[head-1][2]:
                cand_labeling_phrases.append(f'{word}_{cand_heads_pos[head-1][0]}')
        phrases.append(cand_labeling_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for up_cand_id in range(len(candidate_list)):     
        up_cand = candidate_list[up_cand_id]
        up_cand_vectors = phrases_vectors(phrases[up_cand_id])
        if len(up_cand_vectors)==0:
            pass
        else:
            for low_cand_id in range(up_cand_id+1,len(candidate_list)): 
                low_cand = candidate_list[low_cand_id]
                low_cand_vectors = phrases_vectors(phrases[low_cand_id])
                if len(low_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(up_cand_vectors),len(low_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(up_cand_vectors)):
                        for j in range(len(low_cand_vectors)):

                            sim_matrix[i][j] = 1-cosine(up_cand_vectors[i],low_cand_vectors[j])

                    # can we compute matrix mean like this? 
                    #print(sim_matrix)
                    if np.mean(sim_matrix) > 0.6:
                        #print(f'{longer_cand} and {cand} are {numpy.mean(sim_matrix)} similar' )
                        indices_to_remove.add(low_cand_id)
                        what_merged3[up_cand[0].lower()].append(low_cand[0].lower())
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove
                


def phrases_vectors(cand_phrases):
    
#for cand_phrases in phrases:
    #print(cand_phrases)
    cand_phrase_vectors = []
    for phrase in cand_phrases:
        try:
            cand_phrase_vectors.append(model[phrase])
            #print(f'for existing phrase "{phrase}" the vector is {model[phrase][0]}')
        except KeyError:
            phrase_words = phrase.split('_')
            #print(model[phrase_words[1]])
            try:
                phrase_vectors = [model[phrase_word] for phrase_word in phrase_words]
                #print(f'for phrase "{phrase}" avg vector is "{sum(phrase_vectors)/len(phrase_vectors)}') 
                cand_phrase_vectors.append(sum(phrase_vectors)/len(phrase_vectors))
            except KeyError:
                cand_phrase_vectors.append(np.NaN)
    #print(len(cand_phrase_vectors))
    return cand_phrase_vectors
    
 
#event_cands_merged = merge_indices(event_cands_merged, merging_step3(event_cands_merged))
#print(indices_to_remove)

# %%
what_merged3

# %% [markdown]
# ### Merging step 4

# %%
# missing the second method - we check for the lexical identity of specific stems in multiple candidates.

def merging_step4(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:

        #the head of noun phrase is marked with value 0 for the word.head
        cand_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]

        #print(np_heads_pos)
        cand_compound_phrases = []
        for word, head, pos in cand_heads_pos:
            #i = np_heads_pos.index((word, head, pos))
            #print(np_heads_pos)
            #print(np_heads_pos[i])
            #print(np_heads_pos[head-1])
            #'NN' in np_heads_pos[head-1][2] and
            try:
                #if 'NN' in pos and 'NN' in cand_heads_pos[i+1][2] : 
                    #cand_compound_phrases.append(f'{word}_{cand_heads_pos[i+1][0]}')
                if 'NN' in pos and 'NN' in cand_heads_pos[head-1][2]:
                    cand_compound_phrases.append(f'{word}_{cand_heads_pos[head-1][0]}')
            except IndexError:
                pass
        phrases.append(cand_compound_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for up_cand_id in range(len(candidate_list)):     
        up_cand = candidate_list[up_cand_id]
        up_cand_vectors = phrases_vectors(phrases[up_cand_id])
        if len(up_cand_vectors)==0:
            pass
        else:
            for low_cand_id in range(up_cand_id+1,len(candidate_list)):
                low_cand = candidate_list[low_cand_id]
                low_cand_vectors = phrases_vectors(phrases[low_cand_id])
                if len(low_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(up_cand_vectors),len(low_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(up_cand_vectors)):
                        for j in range(len(low_cand_vectors)):
                            #print(cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)))
                            sim_matrix[i][j] = 1-cosine(up_cand_vectors[i],low_cand_vectors[j])
                            """if cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.4:                
                                sim_matrix[i][j] = 2
                            elif cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.2:
                                sim_matrix[i][j] = 1
                            else:
                                sim_matrix[i][j] = 0"""

                    #print(sim_matrix, up_cand,low_cand)            
                    if np.mean(sim_matrix) > 0.6:
                        print(f'{up_cand_id} and {low_cand_id} are {np.mean(sim_matrix)} similar' )
                        indices_to_remove.add(low_cand_id)
                        what_merged4[up_cand[0].lower()].append(low_cand[0].lower())
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove


#event_cands_merged = merge_indices(event_cands_merged, merging_step4(event_cands_merged))
#print(merging_step4(candidate_list))

# %%
what_merged

# %% [markdown]
# ### Merging step 5

# %%
what_merged1,what_merged2,what_merged3,what_merged4 = defaultdict(list), defaultdict(list), defaultdict(list), defaultdict(list)
event_cands = moria_cands

event_cands_merged = merge_indices(event_cands, merging_step1(event_cands['candidates']))

# %%
event_cands_merged = merge_indices(event_cands_merged, merging_step2(event_cands_merged['candidates']))

what_merged2

# %%
event_cands_merged = merge_indices(event_cands_merged, merging_step3(event_cands_merged))

what_merged3

# %%
event_cands_merged = merge_indices(event_cands_merged, merging_step4(event_cands_merged))
what_merged4

# %%
pickle_files('moria_cands_merged',event_cands_merged)
pickle_files('moria_whatmerged2',what_merged2)
pickle_files('moria_whatmerged3',what_merged3)
pickle_files('moria_whatmerged4',what_merged4)

# %% [markdown]
# ## Frame identification

# %%
"""frame_properties = {'affection':['affection','attachment', 'devotion', 'fondness','love','passion'],
                    'refusal': ['refusal','declination','denial','disallowance','nay','no'],
                    'trustworthiness':['trustworthiness','integrity','accuracy','credibility','authenticity','fairness'],
                    'no trustworthiness':['falsehood','dishonesty','unfairness','deceit','corruption'],
                    'reason': ['reason','logic','sense','rationale','argument','justification'],
                    'unreason/irrationality': ['unreason','irrationality','fallaciousness','unsoundness'],
                    'easiness': ['easiness','simplicity','obviousness','ease','comfort'],
                    'difficulty': ['difficulty','adversity','hardship','crisis','obstacle','trouble' ],
                    'honor': ['honor', 'dignity','esteem','reputation','praise'],
                    'dishonor': ['disgrace','dishonor','reproach','opprobrium']}""" #from Hamborg's paper

# from paper Shifting the refugee narratives? by Greussing & Boomgaarden (2015)
frame_properties = {'settlement':['settlement','accomodation','permanent','temporary','barracks','accommodated','tent','camp', 'shelter'],
                   'reception':['quota', 'distribution', 'limit', 'selection','reception','together','asylum','receive'],
                    'security':['security', 'border','crossing','fence','control','flow'],
                    'criminality':['officer','terror','suspicion','crime','offense','police','trafficking','suspect'],
                    'economisation':['euro','economic','million','thousand','cost','money'],
                    'humanitarian':['humane','voluntary','help','support','aid','care','solidarity'],
                    'victimization':['fight','victim','war','dead','rescued','state'],
                    'integration': ['labour','employed','unemployed','integration','positive'],
                    
                    #from hamborg
                    'affection':['affection','attachment', 'devotion', 'fondness','love','passion'],
                    'refusal': ['refusal','declination','denial','disallowance','nay','no'],
                    'trustworthiness':['trustworthiness','integrity','accuracy','credibility','authenticity','fairness'],
                    'no trustworthiness':['falsehood','dishonesty','unfairness','deceit','corruption'],
                    'reason': ['reason','logic','sense','rationale','argument','justification'],
                    'irrationality': ['unreason','irrationality','fallaciousness','unsoundness'],
                    'easiness': ['easiness','simplicity','obviousness','ease','comfort'],
                    'difficulty': ['difficulty','adversity','hardship','crisis','obstacle','trouble' ],
                    'honor': ['honor', 'dignity','esteem','reputation','praise'],
                    'dishonor': ['disgrace','dishonor','reproach','opprobrium']
                   
                   }

# %%
what_merged2 = load_pickle('beirut_whatmerged3')
what_merged2

# %%
#import conceptnet_lite as cn
import gensim
import gensim.downloader as api

#model = gensim.models.KeyedVectors.load_word2vec_format(r"C:/Users/niol19ac/Dropbox (CBS)/Master thesis data/GoogleNews-vectors-negative300.bin.gz", binary=True)

manual_cands = ['refugee','migrant','greece','turkey','syria','beirut','immigrant','aoun']


# to run on the server we should use larger model according to the paper - "conceptnet-numberbatch-17-06-300"
model = api.load("glove-twitter-200")

# %%
from nltk.corpus import stopwords
from collections import defaultdict
import nltk

nltk.download('stopwords')

stop_words = list(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer

lemma = WordNetLemmatizer()

print('preprocessing tweets...')
tqdm.pandas()
tweets_corpus = list(event_df['text'].progress_apply(preprocessing.preprocess_tweets))


print('assigning frame properties to words from tweets...')
word_properties = defaultdict(dict)
for i in tqdm(tweets_corpus):
    tweet_words = [word.lower() for word in i.split() if word not in stop_words and len(word)>1]
    for word in tweet_words:
        #print(word)
        word = lemma.lemmatize(word)
        property_list = []
        #print(list(frame_properties.keys()))
        for prop in list(frame_properties.keys()):
            #print(frame_properties[prop])
            
            try:
                #print(f'sim of {word}, {prop} is {model.similarity(word, prop)}')
                weights = [model.similarity(word, seed) for seed in frame_properties[prop]]
                #print(weights)
                if max(weights)>0.4:
                    word_properties[word][prop] = max(weights)
            except KeyError:
                pass
            



print(word_properties)

# %%
tagged_tweets = load_pickle('beirut_tagged_tweets')
coref_chains = load_pickle('moria_crf_list')

#coref_chains[2]

# %%
for tweet_id in range(len(tagged_tweets))[:10]:
    print(coref_chains[tweet_id])
    print(tagged_tweets[tweet_id].text)

# %%
from collections import defaultdict
# import these modules 
from nltk.stem import WordNetLemmatizer 
from nltk.corpus.reader.wordnet import NOUN
import numpy as np
  
lemma = WordNetLemmatizer() 

cand_frames = defaultdict(list)

framed_words = pd.DataFrame(columns=['word','date',list(frame_properties.keys())])

event_df[['date','time']] = event_df['created_at'].str.split(' ',expand=True)


for tweet_id in tqdm(range(len(tagged_tweets))):
    #print(tweet)
    cand_words = [[word.id, word.text,word.head] for sent in tagged_tweets[tweet_id].sentences for word in sent.words]
    #print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
    #print(len(cand_df['candidates']))
    for cand in manual_cands:#event_merged_cands['candidates']:
            # lemmatize representative head of candidate 
            rep_head = cand #lemma.lemmatize(cand[1].lower(),pos=NOUN)
            
            if rep_head in tagged_tweets[tweet_id].text.lower() and len(rep_head)>1:
                #find all dependencies of the phrase head
                for related in range(len(cand_words)):
                    cand_word_lemma = lemma.lemmatize(cand_words[related][1].lower())
                    #print(f'Yes it is, related = {lemma.lemmatize(cand_heads[related][1].lower(),pos=NOUN)}')
                    #lemma.lemmatize(cand_heads[related][1].lower(),pos=NOUN)
                    if rep_head == cand_word_lemma:
                        related_word = lemma.lemmatize(cand_words[cand_words[related][2]-1][1].lower())
                        cand_frames['word'].append(rep_head)
                        cand_frames['date'].append(event_df['date'][tweet_id])
                        #cand_frames['word'].append(phrase_head)
                        for frame_property in list(frame_properties.keys()):
                            #print(frame_property)

                            try:
                                #print(word_properties[phrase_head][frame_property])
                                cand_frames[frame_property].append(word_properties[related_word][frame_property])

                            except KeyError:
                                #print('Error')
                                #cand_frames[frame_property].append(word_properties['tent'][frame_property])
                                cand_frames[frame_property].append(np.NaN)
                                

                    #print(len(cand_frames[frame_property]))
                    
                #print('\n')
                
                
                """for frame_property in list(frame_properties.keys()):
                    for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    #print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                            #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                        except KeyError:
                            pass"""
                        #[cand_frames[seed_word][cand].append(model.similarity(print(f'{cand} is related to {np_heads[np_heads[related][2]+1][1]}') if cand == np_heads[related][1] else print('nej') for related in range(len(np_heads))]
            #print(get_head(cand))
            #print(np_heads[19][1])
            #[f(x) if condition else g(x) for x in sequence]
            #[print(np_heads[np_heads[related][2]-1]) if get_head(cand)==np_heads[related][1] else print('hi') for related in range(len(np_heads))]

            
#became ___ (vb and vbx)
#(VP sit/VB (PP on/IN (NP the/DT mat/NN))))) 

#common phrases = migrant camp, covid case, covid test

#cand_frames

# %%
print(cand_frames.keys())

framed_words = pd.DataFrame.from_dict(cand_frames)

#framed_words[framed_words['word']=='migrants'].tail(50)

#framed_words = framed_words.dropna(subset=['settlement', 'reception', 'security', 'criminality', 'economisation', 'humanitarian', 'victimization', 'integration', 'affection', 'refusal', 'trustworthiness', 'no trustworthiness', 'reason', 'unreason/irrationality', 'easiness', 'difficulty', 'honor', 'dishonor'],how='all')

framed_words

# %%
the_word = 'refugee'

merged_frames = framed_words.copy()

#framed_words[framed_words['date']=='2020-09-04']

merged_frames['no trustworthiness'] = - merged_frames['no trustworthiness']
merged_frames['refusal'] = - merged_frames['refusal']
merged_frames['unreason/irrationality'] = -merged_frames['unreason/irrationality']
merged_frames['difficulty'] = -merged_frames['difficulty'] 
merged_frames['dishonor'] = -merged_frames['dishonor']


trust = ['trustworthiness', 'no trustworthiness']
honor = ['honor', 'dishonor']
affection = ['affection','refusal']
reason = ['reason','unreason/irrationality']
easiness = ['easiness','difficulty']

merged_frames = pd.lreshape(merged_frames,
                        {'reason':reason, 'honor':honor,'affection':affection,'trust':trust,'easiness':easiness},
                       dropna=False)


merged_frames = merged_frames[merged_frames['word'] == the_word]

aggr_frames = merged_frames.groupby(['word','date'],as_index=False).mean()
frame_size = merged_frames.groupby(['word','date'],as_index=False).size()

aggr_frames

# %%
import plotly.express as px
from plotly.subplots import make_subplots

fig = make_subplots(specs=[[{"secondary_y": True}]])


ax1 = px.line(aggr_frames, x="date", y=['settlement'],render_mode='webgl')

ax2 = px.line(frame_size, x="date", y=['size'],render_mode='webgl')

ax2.update_traces(yaxis='y2')
fig.add_traces(ax1.data + ax2.data)

fig.for_each_trace(lambda t: t.update(line=dict(color=t.marker.color)))

fig.show()

# %%
fig = px.line(aggr_frames, x="date", y=['difficulty','easiness'], title=f'Frame bias towards {the_word}')
fig.show()

# %% [markdown]
# # TESTING:

# %%
# batching the tweets speeds the model considerably and is enabled by splitting sentences using '\n\n' 
from stanza_batch import batch
from nltk.tokenize import sent_tokenize

# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(tweets_corpus)[:50] 
for tweet in range(len(all_tweets_list)):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if tweet_sentokenized == []:
        tweet_sentokenized.append('empty_tweet')
        print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=1000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text

# %%
for tweet in tqdm(range(len(tweets_corpus))):
    print(tweets_corpus[tweet])
    np_heads = [[word.id, word.text,word.head,word.deprel] for sent in tagged_tweets[tweet].sentences for word in sent.words]
    print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in tagged_tweets[tweet].sentences for word in sent.words], sep='\n')
    #print(np_heads)
    ph_ids = set([np_heads[i][2] for i in range(len(np_heads))])
    ph_words = [np_heads[i-1][1] for i in ph_ids]

    word_pairs = [(np_heads[word][1], np_heads[np_heads[word][2]-1][1]) for word in range(len(np_heads)) if np_heads[word][2] != 0]
    #print(word_pairs)
    
    compounds = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if 'compound' in np_heads[i][3]]
    print(compounds)
    
    advmods = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='advmod']
    print(advmods)
    
    amods = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='amod']
    print(amods)
    for pair in word_pairs:
        phrase = pair[0]+'_'+pair[1]

    #print(model.most_similar('illegal_immigrant'))

    
    """#print(len(cand_df['candidates']))
    candidate_list = cand_df['candidates']
    for cand in cand_df['candidates']:
        #print(cand[2])
        #print(get_head(str(cand)))
        for phrase_head in cand[2]:
            #print(phrase_head)
            #if str(cand[1]) in str(tweet):
            if str(phrase_head) in str(tweet) and len(phrase_head)>2:
                #print(phrase_head)
                ph_words = [np_heads[i-1][1] for i in phrase_heads]
                #print(ph_words)
                for related in range(len(np_heads)):
                    if phrase_head == np_heads[related][1]:
                        pass
                        #print(f'checking {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                  for frame_property in list(frame_properties.keys()):
                        for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    #cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                                #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                                except KeyError:
                                pass"""
