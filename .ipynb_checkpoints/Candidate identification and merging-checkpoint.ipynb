# %% [markdown]
# ## Part 3 Loading Data & EDA

# %% [markdown]
# Import relevant packages for the following parts

# %%
import numpy as np
import pandas as pd
import math
import re
import sys

from gensim.models.word2vec import Word2Vec

import matplotlib.pyplot as plt
# %matplotlib inline
import preprocess

plt.style.use('ggplot')
#from preprocessing import get_processed_data, load_data
import csv
import stanza

from tqdm import tqdm

import time

# %% [markdown]
# ### Import data cleaned by using the selfwritten preprocessing module

# %%
event_df = pd.read_csv('moria_no_duplicates.csv', index_col=0)
# given event date, split the dataset to pre and post event dfs

event_date = '2020-09-09'

#moria_df[['Date','Time']] = moria_df['Date Short'].astype(str).str.split(' ', 1, expand=True)
# create pre and post event partition
pre_event = event_df[event_df['Date Short'] < event_date]
post_event = event_df[event_df['Date Short'] >= event_date]

print('total tweets: ', event_df.shape[0])
print('Pre event tweets: ',pre_event.shape[0])
print('Post event tweets: ',post_event.shape[0])
# Out:
# total tweets:  18203
# Pre event tweets:  3311
# Post event tweets:  14892

# %%
event_df.head()
# Out:
#                   Date                                                URL  \
# 0  04-Sep-2020 11:52PM  https://twitter.com/SophieTBHonest/statuses/13...
# 1  04-Sep-2020 11:44PM  https://twitter.com/WarWorl/statuses/130199956...
# 2  04-Sep-2020 11:36PM  https://twitter.com/brownrecluse101/statuses/1...
# 3  04-Sep-2020 10:59PM  https://twitter.com/sbaslan22/statuses/1301988...
# 4  04-Sep-2020 10:47PM  https://twitter.com/SophieTBHonest/statuses/13...
#
#                                            Tweet Raw        Influencer  \
# 0  @sztiv5 @Juliivan_ Yes, why? Why it wasn’t goo...   @sophietbhonest
# 1  @GoTurkey ISIS refuge. Wouldn't go to Turkey i...          @warworl
# 2  Greece must improve refugee overcrowding, UN w...  @brownrecluse101
# 3  @ThisIsOzcan @Nervana_1 @EGozuguzelli 1/3 Law?...        @sbaslan22
# 4  @Juliivan_ @sztiv5 Anyway, how did the asylum ...   @sophietbhonest
#
#           Country Language  Reach  Engagement    AVE Sentiment  ...      Time  \
# 0       Australia  English     45         NaN   0.42   Neutral  ...  11:52 PM
# 1  United Kingdom  English      5         NaN   0.05   Neutral  ...  11:44 PM
# 2         Unknown  English   1348         NaN  12.47   Neutral  ...  11:36 PM
# 3          Turkey  English    315         NaN   2.91   Neutral  ...  10:59 PM
# 4       Australia  English     45         NaN   0.42   Neutral  ...  10:47 PM
#
#      State        City Hashtags                                      Mentions  \
# 0      NaN         NaN       []                       ['sztiv5', 'Juliivan_']
# 1  England  Ravenstone       []                                  ['GoTurkey']
# 2      NaN         NaN       []                                            []
# 3   Edirne   Uzunköprü       []  ['ThisIsOzcan', 'Nervana_1', 'EGozuguzelli']
# 4      NaN         NaN       []                       ['Juliivan_', 'sztiv5']
#
#                 Linked Content Retweet Quote Tweet  \
# 0                           []   False       False
# 1                           []   False       False
# 2  ['https://t.co/UDM4GDMcmo']   False       False
# 3                           []   False       False
# 4                           []   False       False
#
#                                          Tweet Clean  \
# 0  yes, why? why it wasnt good to apply for asylu...
# 1  isis refuge. wouldn't go to turkey if i was pa...
# 2  greece must improve refugee overcrowding, un w...
# 3  /3 law? let the idle stuff. all rights of the ...
# 4  anyway, how did the asylum seekers ended up at...
#
#                                   Tweet Clean Tokens
# 0  ['wasnt', 'good', 'apply', 'asylum', 'greece',...
# 1  ['refuge', 'would', 'turkey', 'paid', 'likely'...
# 2  ['greece', 'must', 'improve', 'refugee', 'over...
# 3  ['idle', 'stuff', 'right', 'turkish', 'minorit...
# 4  ['anyway', 'asylum', 'seeker', 'ended', 'borde...
#
# [5 rows x 32 columns]

# %%
list(event_df["Tweet Raw"])[:100]
# Out:
# ['@sztiv5 @Juliivan_ Yes, why? Why it wasn’t good to apply for asylum in Greece, MAC, SER or CRO or BUL, together 3 EU members before HU? They must get help in the first safe country as asylum seeker,not in the 5th. No law says you can pick and choose and get it.',
#  "@GoTurkey ISIS refuge. Wouldn't go to Turkey if I was paid. You're likely to get your head lopped off if you stray off the beaten track. Go to Christian Greece and be safe while enjoying a similar climate to islamic turkey",
#  'Greece must improve refugee overcrowding, UN warns https://t.co/UDM4GDMcmo',
#  '@ThisIsOzcan @Nervana_1 @EGozuguzelli 1/3 Law? Let the idle stuff. All rights of the Turkish minority in Greece were taken away. Where is the law? Refugees are not accepted into the EU. Where is the law? Western states divided the states in the Middle East and Africa for underground resources. Where is the law?',
#  '@Juliivan_ @sztiv5 Anyway, how did the asylum seekers ended up at HU borders? They must have had a long journey through Greece, where they must apply for help, yet they travelled through multiple more countries, why?',
#  'I never loved #photograpy pushing aesthetic into #news cause it is a potential embellishments of hard facts and harsh reality.I like raw realism. Did I pass this boundary using @FiLMiCPro #firstlight this week in #Lesbos infamous Moria #migrants camp? That’s a big question4me https://t.co/rlEZP5mXmd',
#  '@YOsmanli1453 @ArisKallimachos @GreeceMFA ManfredWeber: It must be made clear that Europe and Germany are on the side of Greece. The German MFA must be careful not to be blackmailed in fear of a new refugee crisis.',
#  "Refugee Covid case sparks 'closed camps' fears on Lesbos | Greece | The Guardian https://t.co/hp8JcOf8dB",
#  '9PM Coronavirus UK LIVE: Leeds on brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#  "@Iceman070259590 @OPCW @realDonaldTrump @mikepompeo Are you sure you' re talking about France and not Turkey? Turkey has invaded parts of Syria, bombs Iraq, conducts a proxy war in Libya creating refugees. On top of that, it violates Greece's and Cyprus' sovereignties. Not to mention that it provides safe heaven for Hamas.",
#  '@realPR_Phoenix @DrEstella @BravoTV Raquel Bessudo is Isaac Bessudo’s widow. The Bessudos were Sephardic Jewish immigrants from Salonica, Greece. Raquel’s parents were Polish Jews. Raquel is blonde and blue eyed though',
#  '@Mproyklis @fragoua @LearnerLerner @mr_markjacobs Most of them immigrated to Greece by their will.',
#  '@maskeIiyorum First you stuff they Turkey, then you bake it, and at last you eat it!!! Be kind to your women, they are very welcome to seek asylum in Greece just like your army and people are doing. Leaving crazy ruled Turkey. Ah Siktir',
#  'Five years later: How September 5th, 2015, became a #Crossroads for the #Migration crisis | DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey',
#  'Record numbers of illegal migrants crossing into the United States as the United Kingdom right now and only Greece seems to keep the border under control. It worries me this is part of the new normal - @WashTimes https://t.co/1kcyzbLICS',
#  'Refugee virus cases spark fears in Lesbos. (Guardian) Story: https://t.co/ocQHAk5gZf',
#  '@fundabezos @dimi_par @Arda7517 @HSajwanization Illegal immigration is not a problem of GREECE or EUROPE.....',
#  '@kaitlancollins 2. From severe claustrophobia his entire life. Both men were not losers they knew why they enlisted it was to appease their Fathers by giving thanks to America for taking them in as immigrants from Greece in 1914. The Trump family never once walking in military boots.',
#  'Greece pushes back 10 refugees, including three children with disabilities. Those refugees were fleeing Erdogan. Greece is betraying european union values. @coe @Europarl_EN @vonderleyen @NachoSAmor @hrw https://t.co/ESiuIqr6jc @tr724 aracılığıyla',
#  'https://t.co/L9k1uLNc97 Two high ranking UN Refugee Agency officials on Friday ended a visit to Greece calling for a drastic improvement in the living conditions of refugees in camps, Anadolu Agency reports. UNHCR’s Assistant High Commissioners for Protection and O ...',
#  'UN: Greece must improve refugee\xa0overcrowding https://t.co/QArN0pGNlz',
#  '@TerribleWyvern Switzerland? But honestly, I reckon its more likely to happen in the Balkans. Greece stranded a bunch of illegal immigrants in the middle of the sea. Plus theres the growing tension with Turkey. So a stronger, motivated govt might just start booting out Erdogans ersatz invaders.',
#  "@ghost_wales To be fair, since when did the EU stop illegal immigration? I don't think the people of Greece got that particular memo.....",
#  'For 4 years, we have offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support to child & youth #refugees in northern Greece. With your help, we can continue this work for another 4 years in another 4 countries. Please donate: https://t.co/Gv3840hqCh',
#  "Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/2EiOcJOBMf",
#  '@Ishaxk0 @VinceVole @EmmanuelCohen65 @DonnyBoy12 So how do you explain mass immigration into Sweden, Austria, Norway, Finland, Denmark, Greece, or pressure on Poland, Bulgaria, Hungary, Slovenia, Serbia & other European countries to accept mass migration?',
#  '@swissquiz @Paul_Phillips20 @chaipatel0 @Nigel_Farage In 2018, the #UK received applications for #Asylum for 37,453 people (including #dependants). This is far less than #Germany (162,000), #France (110,000), #Greece (65,000) and #Italy (49,000).',
#  'Enterprise Greece is joining in this effort, as they aim to migrate their many services and resources online by the end of the year. And their strategic partnership with @eBay will further boost Greek SMEs, ensuring that they can access such a high-level international platform.',
#  "UNHCR's Assistant High Commissioners visit Greece, discuss refugee protection challenges and urge more support https://t.co/narldvFNQ5 https://t.co/G0ntxgzdgG",
#  '@McFaul I worked in a couple of refugee camps in Greece & WiFi there was a given, more or less a basic human right like water and food, as they were people who often had very few possessions with them but a smart phone was precious & the only means of contact to their relatives.',
#  "@Complyordie4 @guardian He shouldn't be there. He was granted asylum and had left for Athens in July. In August he returned to Lesvos and lived in a tent next to the official camp. Anarchy reigns in Moria. Nobody follows the rules.There have been deadly attacks. This is why closed camps are a necessity.",
#  '@NicAthens @ManfredWeber @HeikoMaas Erdoğan holds the cards. He can unless ya million refugees and what would Greece do',
#  '@Richard021051 @MigrationWatch Belgium: 1/10 of UK size, 1/2 of asylum seekers. Greece: 1/2 of UK size, twice of asylum seekers.',
#  "@1Fubar It was obvious many would be infected, that's the issue with the migrants Erdogan is pushing into Greece from Turkey.",
#  "@guardian The infected person, a 40 year old man, was granted asylum. He left from the camp in July, went to Athens and returned to Moria in August, to live in a tent next to the camp. (Didn't think it's Hell) Closed camps will give an oversight and put an end to the anarchy in Moria!",
#  'In Greece we have had very constructive and open exchanges with authorities on the need to safeguard the right to seek asylum, to ensure access to territory for those in need of protection and to investigate the reports of pushbacks at land and sea: https://t.co/8IUcI3sJCl',
#  'Greece has opened its arms to thousands of refugees. However, critical issues urgently need to be addressed. Asst. High Commissioners for Protection & Operations, @GillianTriggs & @RaoufMazou, conclude their visit to 🇬🇷 with a message of solidarity. https://t.co/lfrOmvMDMg https://t.co/oFGzJj03bA',
#  '@tomyork5 @trtworld Btw, why should I take refuge in a 3rd class eastern European country like #Greece, while I already living the life you could not even imagine, in a country that has been your dreams for centuries, let alone the economy of Greece that needs Turkish tourists? Welcome t real world. https://t.co/hriifehDf4',
#  '@tomyork5 @trtworld speaking of which, this is how #Greece behave towards real refugees https://t.co/HbS7NW9WYO',
#  '@tomyork5 @trtworld This is no surprise that Greece shelters those FETÖ members who attempted a failed coup in Turkey. Defining these fugitive terrorists as asylum seekers is precisely a definition worthy of a people who have competed with the PKK over the issue of being more lowness. https://t.co/SLFeNaztJs',
#  '@MigrationWatch Greece seems to have a sensible solution not sure why this has not been suggested? Surly a smallish length would be enough to make the direct route not direct? https://t.co/tBV5XMso8O',
#  'During their visit to Greece, UNHCR’s Assistant High Commissioners @GillianTriggs & @RaoufMazou met with refugees, discussed with authorities and NGOs refugee protection challenges & repeated the call for more support and EU solidarity. https://t.co/DmuUK7tRel',
#  '@Dardanoi25 @protoALB @Arjan @bardylius @TeamAlbanians @Deni_Hoxha @FPodrimja More evidence comes out that Illyrian/Albanian migration into Greece has been happening for thousands of years (not just with Arvanites) and Illyrians may have had a larger presence in mainland Greece than previously thought.',
#  '@vtaonmtdiyene @trtworld Feel good for you that you have pro-government opinion. Else you would be in prison, afraid to talk or asking asylum from Greece. https://t.co/OoVOPzR2Ug',
#  "@WW3Info @NicAthens @AlexanKazamias @WilliamCDoll @TamelaTweets @Pirgakis @JFCrisp @RaphJustine @Rakinas_A #Gas Exploration have created tension between Turkey-Greece. This Dialogue won't work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset. Erdogan Greed for Gas will not end with Sanctions #ThirdWorldWar #RafaleJets #Mediterranean",
#  'I covered the migrant crises in 2015, traveling the migrant route up through Greece to Macedonia and then near Kosovo border and to Serbia and Hungary. I met many nice local people on the way who hosted me and spoke to me.',
#  '#covid19Gr #refugeesGr #Lesvos @MSFgreece on #Moria camp lockdown :Covid is used as an excuse to limit freedoms and rights of people seeking safety in Europe https://t.co/xIbCWkpyLL',
#  'The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece',
#  "@tomyork5 Those who seek refuge in Greece, those who want to make a coup. Because they know that Greece loves this kind of people. Use some brain. Don't always shout with your own perspective. What you call freedom of expression is terrorist propaganda and doing it is a crime.",
#  'Authorities in Greece have placed the Moria #refugee camp on the island of Lesbos under quarantine after the confirmation of the first coronavirus infection in the notoriously overcrowded facility. https://t.co/7LIWIhTngH',
#  "@229Leckie @MontgomeryClif8 @scot_unionist @paulmasonnews by 2040 the north shore of the med will have the climate of the south, no tomatoes in Spain, grain in Italy, grapes in south France or olives in Greece; Europe will have 200 million European climate refugees. Who even knows if there will be an EU or what it's rules are by 2040",
#  "People should spare Greece for a moment but don't get me wrong. I'm not defending them after it emerged they threw 1000 immigrants into the ocean & left them to die.... but why should this poor nation carry this burden yet the world was silent when Obama destroyed Libya.",
#  "@AmysGotBirds @DonaldJTrumpJr To start this war, Erdogan and Turkey (which is part of NATO) has allowed Syrian refugees into his country...only they aren't Syrian. They are Afghani, Somali, and Iraqi. He is allowing these refugees to flood into Greece, and Europe. They are armed with guns and tear gas.",
#  'UNHCR’s Assistant High Commissioners visit #Greece, discuss #refugee protection challenges and issues relating to access to territory & asylum, living conditions on mainland & islands, the management of the #COVID19 response, integration https://t.co/0dZTraZGi3 https://t.co/E411e2Cp8P',
#  '#DevelopmentNewsUpdate Over 200,000 lone #child #migrants left to #uncertain #fates in #Europe Read the full article at https://t.co/sv8bIVmKO0 #Europe #riskofexploitation #children #safety #Greece #detentionofchildren #conflict #protectionbeyondreach #migrants #twentylakhs https://t.co/lMiEC07BYe',
#  '@realPR_Phoenix @DrEstella Estella’s family immigrated from Greece and Lithuania and became wealthy by owning a toy factory',
#  "@Nicolas98869551 @Marflo66036248 @Esref_Doguu Who does say this? Is it a Greek? It is The Greece which has made a hole in Syrian Refugees' boats and which has beat Syrian Refugees, which has stolen Refugees' money. 😂😂😂",
#  'If your kids have gone #BackToSchool, do you suddenly appreciate the time you have for other things? SOS provide childcare to families who are struggling, so parents/carers can study or find work. Find out more about our work in a refugee camp in Lesvos ➡️ https://t.co/t8GEChlGFg https://t.co/oWWet2GJex',
#  '@devilxbrain @ragipsoylu Take the 5+ million refugees and then https://t.co/XXT3mjLDCs if you care for them.I can easily say they are living in much better conditions in Turkey compared to Greece.',
#  '#Greece and its people have shown great hospitality for 100 of thousands #refugees and #migrants since 2015. But a lot remains to be done to meet critical needs and improve conditions on islands. We need continued solidarity from #EU and European States. https://t.co/LivzhA3RXL',
#  "Wales has added Portugal and parts of Greek Island on the list not to visit, yet England does not #torychaos #Covid_19 Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/jefOiklxow",
#  'We’re all in this together and no one should be left behind! The #refugees in Greek islands must be urgently protected from #COVID19 – Take action now and send an email to Prime Minister of #Greece, @primeministergr to act immediately! #coronavirus https://t.co/NQOH3cOVbD',
#  '#Attention!!!! Illegal immigrant try to steal a local mini market in #Soufli , #Greece!!! @akrokentrwos https://t.co/wiowPSF8pF',
#  'A photo to give you an impression of the food in #Moria. If you guess what it is, it will be delivered free of charge for one month. #Delicious #EU #Refugees #LeaveNoOneBehind #SaveThem',
#  '@griko84 @BwanaPjotr @fk_akis @MEMRIReports You said Muslim factions that Greece dosnt melt in betwen them it does so yea. Greece gives enoug of a fu* to support Assad and open realtionship with him so yea. If its our mess then EU should stop melding into it too. But it does so yea. Take the refugees then.',
#  "#Moria: A food strike takes place. ~100 refugees have blocked the supply of ready-made food to protest against the poor quality of the it. More bad than good it's supplied by a private/public joint venture. #LeaverNoOneBehind #RefugeesGR",
#  '@YinkaOgundipe @EmmanuelAcho Well obviously you don’t know Giannis story. He had nothing until he was 17. Because he was born in Greece and Nigerian embassy in Athens refused him a passport cause his parents left Nigeria as refugees.Only after Greece gave him one , Nigeria said they will suit',
#  'Greece has shown great solidarity towards 1000s of refugees + asylum-seekers. There are critical gaps + issues that need addressing. Other EU States need to also show solidarity including by relocating vulnerable asylum seekers. The situation is manageable https://t.co/MWxUHH0sZb',
#  '@YavuzBiH @fk_akis @MEMRIReports 1)EU is not supporting Assad 2) if you are gonna blame Greece for any ME wars (that Turkey takes part in), colonialism or anything else, try harder. By the way, less than 15% of current “refugees” in Greece are from Syria.',
#  '1st #Covid_19 case confirmed in #Moria. Within 10 days, #Coronavirus could sweep through the overcrowded #refugee camp, with devastating consequences. We need URGENT FUNDS to keep our clinic doors open and purchase vital medication and equipment. #DONATE: https://t.co/a1gCVgOdcR',
#  'Lesbos refugee camp in quarantine due to Somali migrant infected with coronavirus https://t.co/qBdLXSjkdG',
#  '@Tarzan35715351 @0khalodi0 Unfortunately it’s a fact that ISIS member find a passage through illegal immigration in Europe. And most likely you referring to some NATO members. Portugal never funded neither Greece as an example and neither agreed.',
#  "@maximusmadham @EndGameWW3 Maybe you speak for Albanian greeks. I don't give a shit about anyone of them. I only support greeks that living in Greece not traitors and refugees",
#  'There are critical issues that must be addressed, incl the urgent need 2 drastically improve living conditions +reduce overcrowding at the reception facilities on the Aegean Islands - @RaoufMazou on #Greece #asylum #Europe #Solidarity https://t.co/H3yhHqly4g via @refugees',
#  'Greece and its people have shown tremendous solidarity and compassion with thousands of refugees and asylum-seekers, despite all the challenges the country has faced, including a severe economic crisis and now the COVID-19 pandemic - @RaoufMazou https://t.co/WDVFsQS0sk',
#  'Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 https://t.co/j9bKQUVcBR #Greece #news',
#  '@bethvaughan15 @SueSuezep @Jacob_Rees_Mogg Britain still done far less asylum applications than other European country, Germany, France and Greece did a hell of a lot more....',
#  'fight for hope - the states should not push people seeking asylum back to unsafe countries! is this what happens in the Aegean sea? #migrants #refugees #AsylumSeekers #Turkey #Ankara #Greece #Syria #Iraq #MiddleEast #Pakistan #Afghanistan #Honduras #ElSalvador #Mexico #Guatemala https://t.co/ROQxjEgfjA',
#  "@sarianpaul1 @pritipatel This idea that the uk is being overwhelmed is absolute pure dogshite. 85% of the world's refugees live in countries adjacent to the one their fled. The uk took 3 x less asylum applications than France last year, 4x less than Germany, 2x less than Spain and Greece. Get over it.",
#  '@0khalodi0 In Greece the majority of immigrants are from Pakistan and Afghanistan and Bagladesh. It was not long ago when the catch an ISIS member in Spain. Guess from where passed first, Greece! Europe is in danger.',
#  "Refugee Covid case sparks 'closed camps' fears on Lesbos | Global development | The Guardian : https://t.co/90q629G4gV #santé",
#  "@no_eyed_ryan I'm Greek, many in America consider Greeks white because white westerners claimed our culture, history and ethnic heritage as theirs. Greek immigrants didn't leave their culture behind in fact they suffered under white supremacy both in Greece and in white colonised countries.",
#  '@devilxbrain @ragipsoylu You are hypocritical. Greece closes the gates for your so called ‘poor’ refugees. So what makes them better ?',
#  "@DrManha84708484 @Eos303 @Nervana_1 @EGozuguzelli Did you ever see Greeks that go to Turkey and ask for asylum? The answer is NO. But we see thousands of Turks every day that come to Greece and ask for asylum. What's wrong with Turkey?",
#  'Migrant shelter for unsupervised minors in Greece quarantined following coronavirus outbreak — RT World News https://t.co/qeh1vETr89',
#  '#COVID19 measures in #Greece #AsylumSeekers & #Refugees on #Lesbos. When will those poor people be rescued from this living hell? https://t.co/tzqE7pT812',
#  "@gerdosi @paulmelzer1 @nmlinguaphile The funniest thing is no country closed its borders to stop it. It was to slow the spread. History (the Cordon Sanitaire&more), recent flare ups in TX&Florida (migrants from Mexico&Caribbean), Greece early closing vs Spain' s late 1,etc. are facts undermining your general stateme",
#  '@lk2015r @LevidisStefanos When I started my fieldwork in İzmir in 2008 summer, pushed back refugees were telling me their experiences at sea. There were also sent back migrants according to the bilateral agreement who had detention experience in Greece.',
#  "@DartmoorSounds @guyverhofstadt i'll be going to the Cayman Islands! FOR MY WINTER BREAK! Where you going in the EU, Sunlit EU beaches with dead migrants on you mean! due to the EU not caring about people crossing sea's in little boats! greece and now the Channel yet still they do nothing",
#  'This is the second year that we have supported this Appeal for Hope and Kindness. All of the money will be used to provide nappies for babies in Refugee camps in #Greece. Donations will bring hope to a mother and comfort to her baby. #FiveForHope https://t.co/jWuPRixilI https://t.co/j99DHJ2ldK',
#  'Current UNHCR numbers #Lesvos: 14,007 #refugeesgr reside on island. Majority from #Afghanistan (76%), #Syria (7%) and Democratic Republic of the #Congo (7%). Women account for 23% of population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old. /1 https://t.co/4OTIv9tk3X',
#  '@CllrBarryLewis Anyway, we still have a responsibility to take at least some of these people in if they need it. Otherwise your line of reasoning suggests Italy and Greece, or the other primary landing countries, should basically take all the refugees, which hardly seems fair.',
#  'Greece has a deadly new migration policy – and all of Europe is to blame | Every time Athens pushes a refugee boat away, it’s the result of an entire continent acting in its perceived self-interest https://t.co/9sEKKQ6tBy https://t.co/Im5ShhraQF',
#  'COVID-19: Greece reports first coronavirus case in Moria migrant camp on Lesbos https://t.co/wWgaCNZ6UE',
#  '@jensstoltenberg @EGozuguzelli @RTErdogan @NATO Greek militans kil.ling poor immigrants. Racist unlawfull greece. https://t.co/ZKkNKqDgXI',
#  "War conflicts, migrations, diseases... That's how a waterless region is💧 From EIT we are facing that problem by getting together the best ideas in our online event #InnowiseChallengeLabs. Join the Greece event on 15 september at 4 PM! 🇬🇷",
#  '@EastMedMonitor 4 million migrants housed in turkey!if Greece gets its 12 mile maritime territory all turkey needs to do is get them to walk into the sea and they are in the EU in many areas😂😂😂',
#  "@_ErcanButun @LegendofBaba You are to be https://t.co/uQO4C8nZCw fooled all these poor people that the borders are open and you carried them by thousands to enter Greece.Your sneaky political game didn't succeed. You are animals for manipulating refuges.",
#  'The first recorded coronavirus case in Moria refugee camp on Lesbos, where just under 13,000 people are l..... to leave. Check on https://t.co/5jbWReoMR1 @scwacy',
#  "@hvvnfd @jedijig @KostasAntLavdas @jensstoltenberg I thing this didn't go on because Turkey want just the Aegean but Greece want both aegean and kastelorizo eez. In any case that are history now Greece propose it and Turkey refuge. This is the truth."]

# %%
stanza.download("en")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 31.9MB/s]
# 2021-02-23 22:11:49 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|█████| 411M/411M [03:28<00:00, 1.97MB/s]
# 2021-02-23 22:15:26 INFO: Finished downloading models and saved to C:\Users\nikodemicek\stanza_resources.

# %%
en_nlp = stanza.Pipeline("en")
# Out:
# 2021-02-23 22:15:26 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-02-23 22:15:26 INFO: Use device: cpu
# 2021-02-23 22:15:26 INFO: Loading: tokenize
# 2021-02-23 22:15:26 INFO: Loading: pos
# 2021-02-23 22:15:26 INFO: Loading: lemma
# 2021-02-23 22:15:26 INFO: Loading: depparse
# 2021-02-23 22:15:27 INFO: Loading: sentiment
# 2021-02-23 22:15:28 INFO: Loading: ner
# 2021-02-23 22:15:29 INFO: Done loading processors!

# %%
start = time.time()
en_doc = event_df["Tweet Raw"][:100].apply(en_nlp)
end = time.time()
print(f"Preprocessing the data took {end-start} seconds.")
# Out:
# Preprocessing the data took 201.91080117225647 seconds.

# %%
en_doc.iloc[1].sentences[0]
# Out:
# [
#   {
#     "id": 1,
#     "text": "@GoTurkey",
#     "lemma": "@GoTurkey",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 3,
#     "deprel": "compound",
#     "misc": "start_char=0|end_char=9",
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "ISIS",
#     "lemma": "ISIS",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 3,
#     "deprel": "compound",
#     "misc": "start_char=10|end_char=14",
#     "ner": "S-ORG"
#   },
#   {
#     "id": 3,
#     "text": "refuge",
#     "lemma": "refuge",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 0,
#     "deprel": "root",
#     "misc": "start_char=15|end_char=21",
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 3,
#     "deprel": "punct",
#     "misc": "start_char=21|end_char=22",
#     "ner": "O"
#   }
# ]

# %%
directory = None ##ADD DIRECTORY HERE
stanza.install_corenlp(directory)
# Out:
# 2021-02-23 22:20:31 INFO: Installing CoreNLP package into export CORENLP_HOME=/path/to/stanford-corenlp-4.1.0...
# Downloading http://nlp.stanford.edu/software/stanford-corenlp-latest.zip: 100%|█████| 505M/505M [08:02<00:00, 1.05MB/s]

# %%
from stanza.server import CoreNLPClient

# get noun phrases with tregex
def noun_phrases(_client, _text, _annotators=None):
    pattern = 'NP'
    matches = _client.tregex(_text,pattern,annotators=_annotators)
    return [sentence[match_id]['spanString'] for sentence in matches['sentences'] for match_id in sentence]

# %%
noun_phrase_list = []
anns_list = []
with CoreNLPClient(timeout=30000, memory='16G') as client:
    for tweet in tqdm(event_df["Tweet Raw"][:100]):
        noun_phrase = noun_phrases(client,str(tweet),_annotators="tokenize,ssplit,pos,lemma,parse")
        noun_phrase_list.append(noun_phrase)
        #noun_phrases(client,event_df["Tweet Raw"][:100],_annotators="tokenize,ssplit,pos,lemma,parse")
# Out:
# 2021-02-23 23:18:21 INFO: Writing properties to tmp file: corenlp_server-dfd06ada3d5049c4.props
# 2021-02-23 23:18:21 INFO: Starting server with command: java -Xmx16G -cp export CORENLP_HOME=/path/to/stanford-corenlp-4.1.0\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 30000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-dfd06ada3d5049c4.props -preload -outputFormat serialized
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:12<00:00,  1.32s/it]

# %%
noun_phrase_list
# Out:
# [['@sztiv5 @Juliivan_ Yes, why?',
#   '@sztiv5',
#   '@Juliivan_ Yes, why',
#   '@Juliivan_',
#   'it',
#   'asylum in Greece, MAC, SER or CRO or BUL',
#   'asylum in Greece, MAC, SER or CRO',
#   'asylum',
#   'Greece, MAC, SER or CRO',
#   'BUL',
#   '3 EU members',
#   'HU',
#   'They',
#   'help',
#   'the first safe country as asylum seeker',
#   'the first safe country',
#   'asylum seeker',
#   'the 5th',
#   'No law',
#   'you',
#   'it'],
#  ['@GoTurkey ISIS',
#   'refuge',
#   'Turkey',
#   'I',
#   'You',
#   'your head',
#   'you',
#   'the beaten track',
#   'Christian Greece',
#   'a similar climate',
#   'islamic turkey'],
#  ['Greece', 'refugee overcrowding', 'UN', 'https://t.co/UDM4GDMcmo'],
#  ['@ThisIsOzcan @Nervana_1 @EGozuguzelli',
#   '1/3',
#   'Law',
#   'the idle stuff',
#   'All rights of the Turkish minority in Greece',
#   'All rights',
#   'the Turkish minority in Greece',
#   'the Turkish minority',
#   'Greece',
#   'the law',
#   'Refugees',
#   'the EU',
#   'the law',
#   'Western states',
#   'the states',
#   'the Middle East and Africa',
#   'the Middle East',
#   'Africa',
#   'underground resources',
#   'the law'],
#  ['@Juliivan_ @sztiv5',
#   'the asylum seekers',
#   'HU borders',
#   'They',
#   'a long journey',
#   'Greece',
#   'they',
#   'help',
#   'they',
#   'multiple more countries'],
#  ['I',
#   '#photograpy pushing aesthetic into #news',
#   '#photograpy',
#   'aesthetic',
#   '#news',
#   'it',
#   'a potential embellishments of hard facts and harsh reality.I like raw realism',
#   'a potential embellishments of hard facts',
#   'a potential embellishments',
#   'hard facts',
#   'harsh reality.I like raw realism',
#   'harsh reality.I',
#   'raw realism',
#   'I',
#   'this boundary',
#   '@FiLMiCPro',
#   'this week',
#   '#Lesbos infamous Moria #migrants camp',
#   '#Lesbos',
#   'infamous Moria #migrants',
#   'camp',
#   'That’s a big question4me',
#   'That’s',
#   'a big question4me',
#   'https://t.co/rlEZP5mXmd'],
#  ['@YOsmanli1453 @ArisKallimachos @GreeceMFA ManfredWeber',
#   '@YOsmanli1453 @ArisKallimachos',
#   '@GreeceMFA ManfredWeber',
#   'It',
#   'Europe and Germany',
#   'the side of Greece',
#   'the side',
#   'Greece',
#   'The German MFA',
#   'fear of a new refugee crisis',
#   'fear',
#   'a new refugee crisis'],
#  ['Refugee Covid',
#   "case sparks 'closed camps' fears on",
#   "case sparks 'closed camps' fears",
#   "case sparks 'closed camps'",
#   "case sparks '",
#   'Lesbos',
#   'Greece',
#   'The',
#   'Guardian',
#   'https://t.co/hp8JcOf8dB'],
#  ['9PM Coronavirus UK',
#   'Leeds on brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   'Leeds',
#   'brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   'brink of lockdown',
#   'brink',
#   'lockdown',
#   'outbreak at asylum seeker hostel in Birmingham',
#   'outbreak',
#   'asylum seeker hostel in Birmingham',
#   'asylum seeker hostel',
#   'Birmingham',
#   'Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   'Greece chaos Stories',
#   '2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   '2 sources',
#   'Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   'Photo',
#   'Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn',
#   'Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak',
#   'https://t.co/FOn9kkanHn'],
#  ['@Iceman070259590',
#   '@OPCW @realDonaldTrump @mikepompeo',
#   "you sure you' re talking about France",
#   'you sure you',
#   'you',
#   'you',
#   'France',
#   'Turkey',
#   'Turkey',
#   'parts of Syria',
#   'parts',
#   'Syria',
#   'bombs Iraq',
#   'bombs',
#   'Iraq',
#   'a proxy war in Libya',
#   'a proxy war',
#   'Libya',
#   'refugees',
#   'top of that',
#   'top',
#   'that',
#   'it',
#   "Greece's and Cyprus' sovereignties",
#   "Greece's and Cyprus'",
#   "Greece's",
#   "Cyprus'",
#   'it',
#   'safe heaven for Hamas',
#   'safe heaven',
#   'Hamas'],
#  ['@realPR_Phoenix @DrEstella @BravoTV Raquel Bessudo',
#   'Isaac Bessudo’s widow',
#   'Isaac Bessudo’s',
#   'The Bessudos',
#   'Sephardic Jewish immigrants from Salonica, Greece',
#   'Sephardic Jewish immigrants',
#   'Salonica, Greece',
#   'Raquel’s parents',
#   'Raquel’s',
#   'Polish Jews',
#   'Raquel'],
#  ['@Mproyklis @fragoua @LearnerLerner',
#   'Most of them',
#   'Most',
#   'them',
#   'Greece',
#   'their will'],
#  ['@maskeIiyorum First',
#   'you',
#   'they',
#   'Turkey',
#   'you',
#   'it',
#   'you',
#   'it',
#   'your women',
#   'they',
#   'asylum',
#   'Greece',
#   'your army and people',
#   'Turkey',
#   'Siktir'],
#  ['Five years later: How September 5th, 2015, became a #Crossroads for the #Migration crisis | DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey',
#   'Five years later',
#   'Five years',
#   'September 5th, 2015,',
#   'September 5th',
#   '2015',
#   'a #Crossroads',
#   'the #Migration crisis | DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey',
#   'the #Migration',
#   'crisis',
#   'DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey'],
#  ['Record numbers of illegal migrants',
#   'Record numbers',
#   'illegal migrants',
#   'the United States',
#   'the United Kingdom',
#   'Greece',
#   'the border',
#   'control',
#   'It',
#   'me',
#   'this',
#   'part of the new normal - @WashTimes',
#   'part',
#   'the new normal - @WashTimes',
#   'https://t.co/1kcyzbLICS'],
#  ['Refugee virus cases',
#   'fears in Lesbos',
#   'fears',
#   'Lesbos',
#   '(Guardian) Story: https://t.co/ocQHAk5gZf',
#   '(Guardian) Story',
#   'https://t.co/ocQHAk5gZf'],
#  ['@fundabezos @dimi_par @Arda7517 @HSajwanization Illegal immigration',
#   '@fundabezos',
#   '@dimi_par @Arda7517 @HSajwanization Illegal immigration',
#   'a problem of GREECE or EUROPE',
#   'a problem',
#   'GREECE or EUROPE'],
#  ['@kaitlancollins 2.',
#   'severe claustrophobia',
#   'his entire life',
#   'Both men',
#   'losers they knew why they enlisted it was to appease their Fathers by giving thanks to America for taking them in as immigrants from Greece in 1914',
#   'losers',
#   'they',
#   'they',
#   'it',
#   'their Fathers',
#   'America',
#   'them',
#   'immigrants from Greece',
#   'immigrants',
#   'Greece',
#   '1914',
#   'The Trump family',
#   'military boots'],
#  ['Greece',
#   '10 refugees, including three children with disabilities',
#   '10 refugees',
#   'three children with disabilities',
#   'three children',
#   'disabilities',
#   'Those refugees',
#   'Erdogan',
#   'Greece',
#   'european union values',
#   '@coe @Europarl_EN',
#   '@vonderleyen @NachoSAmor @hrw',
#   'https://t.co/ESiuIqr6jc @tr724 arac?l???yla'],
#  ['https://t.co/L9k1uLNc97',
#   'Two',
#   'UN Refugee Agency officials on Friday ended a visit to Greece calling for a drastic improvement in the living conditions of refugees in camps, Anadolu Agency reports',
#   'UN Refugee Agency',
#   'officials on Friday',
#   'officials',
#   'Friday',
#   'a visit',
#   'Greece',
#   'a drastic improvement in the living conditions of refugees in camps',
#   'a drastic improvement',
#   'the living conditions of refugees in camps',
#   'the living conditions',
#   'refugees in camps',
#   'refugees',
#   'camps',
#   'Anadolu Agency',
#   'UNHCR’s Assistant High Commissioners for Protection and O ...',
#   'UNHCR’s Assistant High Commissioners',
#   'UNHCR’s',
#   'Protection and O',
#   'Protection',
#   'O'],
#  ['UN: Greece must improve refugee\xa0overcrowding https://t.co/QArN0pGNlz',
#   'UN',
#   'Greece',
#   'refugee\xa0overcrowding',
#   'https://t.co/QArN0pGNlz'],
#  ['@TerribleWyvern Switzerland?',
#   'I',
#   'its more likely',
#   'the Balkans',
#   'Greece',
#   'a bunch of illegal immigrants',
#   'a bunch',
#   'illegal immigrants',
#   'the middle of the sea',
#   'the middle',
#   'the sea',
#   'the growing tension with Turkey',
#   'the growing tension',
#   'Turkey',
#   'a stronger, motivated govt',
#   'Erdogans ersatz invaders',
#   'Erdogans',
#   'ersatz invaders'],
#  ['@ghost_wales',
#   'the EU',
#   'illegal immigration',
#   'I',
#   'the people of Greece',
#   'the people',
#   'Greece',
#   'that particular memo'],
#  ['4 years',
#   'we',
#   'offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support to child & youth #refugees in northern Greece',
#   'offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support to child',
#   'offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support',
#   '#trauma-sensitive, identity',
#   '#trauma-sensitive',
#   'identity',
#   'child',
#   'youth #refugees in northern Greece',
#   'youth #refugees',
#   'northern Greece',
#   'your help',
#   'we',
#   'this work for another 4 years',
#   'this work',
#   'another 4 years',
#   'another 4 countries',
#   'https://t.co/Gv3840hqCh'],
#  ['Refugee Covid',
#   "case sparks 'closed camps' fears on Lesbos",
#   "case sparks 'closed camps' fears",
#   "case sparks 'closed camps'",
#   "case sparks '",
#   'Lesbos',
#   'https://t.co/2EiOcJOBMf'],
#  ['@Ishaxk0 @VinceVole @EmmanuelCohen65 @DonnyBoy12',
#   'you',
#   'mass immigration',
#   'Sweden, Austria, Norway, Finland, Denmark, Greece, or pressure',
#   'Poland, Bulgaria, Hungary, Slovenia, Serbia & other European countries',
#   'Poland, Bulgaria, Hungary, Slovenia, Serbia',
#   'other European countries',
#   'mass migration'],
#  ['@swissquiz @Paul_Phillips20',
#   '@chaipatel0 @Nigel_Farage',
#   '2018',
#   'the #UK',
#   'applications',
#   '#Asylum',
#   '37,453 people',
#   '#dependants',
#   'This',
#   '#Germany (162,000), #France (110,000), #Greece (65,000) and #Italy (49,000)',
#   '#Germany (162,000)',
#   '162,000',
#   '#France (110,000)',
#   '110,000',
#   '#Greece (65,000)',
#   '65,000',
#   '#Italy (49,000)',
#   '49,000'],
#  ['Enterprise Greece',
#   'this effort',
#   'they',
#   'their many services and resources',
#   'the end of the year',
#   'the end',
#   'the year',
#   'their strategic partnership with @eBay',
#   'their strategic partnership',
#   '@eBay',
#   'Greek SMEs',
#   'they',
#   'such a high-level international platform'],
#  ["UNHCR's Assistant High Commissioners visit Greece",
#   "UNHCR's Assistant High Commissioners visit",
#   "UNHCR's",
#   'Greece',
#   'refugee protection challenges',
#   'more support https://t.co/narldvFNQ5',
#   'https://t.co/G0ntxgzdgG'],
#  ['@McFaul',
#   'I',
#   'a couple of refugee camps',
#   'a couple',
#   'refugee camps',
#   'Greece & WiFi',
#   'there',
#   'a given, more or less a basic human right like water and food',
#   'a given, more or less a basic human right',
#   'a basic',
#   'water and food',
#   'they',
#   'people who often had very few possessions with them',
#   'people',
#   'very few possessions',
#   'them',
#   'a smart phone',
#   'precious & the only means of contact',
#   'precious',
#   'the only means of contact',
#   'the only means',
#   'contact',
#   'their relatives'],
#  ['@Complyordie4',
#   'He',
#   'He',
#   'asylum',
#   'Athens',
#   'July',
#   'August',
#   'he',
#   'Lesvos',
#   'a tent',
#   'the official camp',
#   'Anarchy',
#   'Moria',
#   'Nobody',
#   'the rules.There',
#   'deadly attacks',
#   'This',
#   'closed camps',
#   'a necessity'],
#  ['@NicAthens @ManfredWeber @HeikoMaas Erdo?an',
#   'the cards',
#   'He',
#   'ya',
#   'million refugees',
#   'Greece'],
#  ['@Richard021051 @MigrationWatch Belgium',
#   '1/10 of UK size, 1/2 of asylum seekers',
#   '1/10',
#   'UK size',
#   '1/2 of asylum seekers',
#   '1/2',
#   'asylum seekers',
#   'Greece: 1/2 of UK size, twice of asylum seekers.',
#   'Greece',
#   '1/2 of UK size',
#   '1/2',
#   'UK size',
#   'asylum seekers'],
#  ['1Fubar',
#   'It',
#   'many',
#   'that',
#   'the issue with the migrants Erdogan is pushing into Greece from Turkey',
#   'the issue',
#   'the migrants Erdogan is pushing into Greece from Turkey',
#   'the migrants',
#   'Erdogan',
#   'Greece',
#   'Turkey'],
#  ['@guardian The infected person, a 40 year old man,',
#   '@guardian The infected person',
#   'a 40 year old man',
#   '40 year',
#   'asylum',
#   'He',
#   'the camp in July',
#   'the camp',
#   'July',
#   'Athens',
#   'Moria',
#   'August',
#   'a tent',
#   'the camp',
#   'it',
#   'Hell',
#   'Closed camps',
#   'an oversight',
#   'an end',
#   'the anarchy in Moria',
#   'the anarchy',
#   'Moria'],
#  ['Greece',
#   'we',
#   'very constructive and open exchanges',
#   'authorities on the need to safeguard the right to seek asylum, to ensure access to territory for those in need of protection and to investigate the reports of pushbacks at land and sea',
#   'authorities',
#   'the need to safeguard the right to seek asylum, to ensure access to territory for those in need of protection and to investigate the reports of pushbacks at land and sea',
#   'the right',
#   'asylum',
#   'access',
#   'territory for those in need of protection',
#   'territory',
#   'those in need of protection',
#   'those',
#   'need of protection',
#   'need',
#   'protection',
#   'the reports of pushbacks',
#   'the reports',
#   'pushbacks',
#   'land and sea',
#   'https://t.co/8IUcI3sJCl'],
#  ['Greece',
#   'its arms',
#   'thousands of refugees',
#   'thousands',
#   'refugees',
#   'critical issues',
#   'Asst. High Commissioners for Protection & Operations, @GillianTriggs & @RaoufMazou',
#   'Asst. High Commissioners',
#   'Protection & Operations, @GillianTriggs & @RaoufMazou',
#   'their visit',
#   '?? with a message of solidarity',
#   '??',
#   'a message of solidarity',
#   'a message',
#   'solidarity',
#   'https://t.co/lfrOmvMDMg',
#   'https://t.co/oFGzJj03bA'],
#  ['@tomyork5 @trtworld Btw, why should I take refuge in a 3rd class eastern European country like #Greece, while I already living the life you could not even imagine, in a country that has been your dreams for centuries, let alone the economy of Greece that needs Turkish tourists?',
#   '@tomyork5 @trtworld Btw',
#   'I',
#   'refuge in a 3rd class eastern European country',
#   'refuge',
#   'a 3rd class eastern European country',
#   '#Greece',
#   'I',
#   'the life you could not even imagine',
#   'the life',
#   'you',
#   'a country that has been your dreams for centuries',
#   'a country',
#   'your dreams',
#   'centuries',
#   'the economy of Greece that needs Turkish tourists',
#   'the economy of Greece',
#   'the economy',
#   'Greece',
#   'Turkish tourists',
#   'real world',
#   'https://t.co/hriifehDf4'],
#  ['@tomyork5 @trtworld speaking of which',
#   '@tomyork5 @trtworld speaking',
#   'which',
#   'this',
#   '#Greece',
#   'real refugees',
#   'https://t.co/HbS7NW9WYO'],
#  ['@tomyork5 @trtworld This',
#   '@tomyork5 @trtworld',
#   'This',
#   'no surprise that Greece shelters those FETÖ members who attempted a failed coup in Turkey',
#   'no surprise',
#   'Greece',
#   'those FETÖ members who attempted a failed coup in Turkey',
#   'those FETÖ members',
#   'a failed coup in Turkey',
#   'a failed coup',
#   'Turkey',
#   'these fugitive terrorists',
#   'asylum seekers',
#   'a definition',
#   'a people who have competed with the PKK over the issue of being more lowness',
#   'a people',
#   'the PKK over the issue of being more lowness',
#   'the PKK',
#   'the issue of being more lowness',
#   'the issue',
#   'more lowness',
#   'https://t.co/SLFeNaztJs'],
#  ['@MigrationWatch Greece',
#   'a sensible solution',
#   'this',
#   'Surly a smallish length',
#   'the direct route',
#   'https://t.co/tBV5XMso8O'],
#  ['their visit to Greece',
#   'their visit',
#   'Greece',
#   'UNHCR’s Assistant High Commissioners @GillianTriggs & @RaoufMazou',
#   'UNHCR’s Assistant High Commissioners',
#   'UNHCR’s',
#   '@GillianTriggs & @RaoufMazou',
#   'refugees, discussed with authorities and NGOs refugee protection challenges',
#   'refugees',
#   'authorities and NGOs refugee protection challenges',
#   'authorities',
#   'NGOs refugee protection challenges',
#   'NGOs',
#   'refugee protection challenges',
#   'the call',
#   'more support and EU solidarity',
#   'more support',
#   'EU solidarity',
#   'https://t.co/DmuUK7tRel'],
#  ['@Dardanoi25 @protoALB @Arjan @bardylius @TeamAlbanians @Deni_Hoxha @FPodrimja More evidence',
#   '@Dardanoi25 @protoALB @Arjan @bardylius @TeamAlbanians @Deni_Hoxha',
#   '@FPodrimja More evidence',
#   '@FPodrimja',
#   'Illyrian/Albanian migration into Greece',
#   'Illyrian/Albanian migration',
#   'Greece',
#   'thousands of years (not just with Arvanites)',
#   'thousands',
#   'years',
#   'Arvanites',
#   'Illyrians',
#   'a larger presence',
#   'mainland Greece'],
#  ['@vtaonmtdiyene @trtworld',
#   'you',
#   'you',
#   'pro-government opinion',
#   'Else you',
#   'prison, afraid to talk or asking asylum from Greece',
#   'prison',
#   'asylum',
#   'Greece',
#   'https://t.co/OoVOPzR2Ug'],
#  ['@WW3Info @NicAthens @AlexanKazamias @WilliamCDoll @TamelaTweets @Pirgakis @JFCrisp @RaphJustine @Rakinas_A #Gas Exploration',
#   '@WW3Info @NicAthens @AlexanKazamias @WilliamCDoll @TamelaTweets @Pirgakis',
#   '@JFCrisp @RaphJustine @Rakinas_A #Gas Exploration',
#   'tension between Turkey-Greece',
#   'tension',
#   'Turkey-Greece',
#   'This Dialogue',
#   'Earlier Greece',
#   'Earlier',
#   'Greece',
#   'migrants',
#   'Turkish water with which Turkey was Upset',
#   'Turkish water',
#   'Turkey',
#   'Erdogan Greed for Gas',
#   'Erdogan Greed',
#   'Gas',
#   'Sanctions #ThirdWorldWar #RafaleJets #Mediterranean'],
#  ['I',
#   'the migrant crises in 2015',
#   'the migrant crises',
#   '2015',
#   'the migrant route',
#   'Greece',
#   'Macedonia',
#   'Kosovo border',
#   'Serbia and Hungary',
#   'I',
#   'many nice local people',
#   'the way who hosted me and spoke to me',
#   'the way',
#   'me',
#   'me'],
#  ['#covid19Gr #refugeesGr #Lesvos @MSFgreece on #Moria camp lockdown',
#   '#covid19Gr #refugeesGr #Lesvos @MSFgreece',
#   '#Moria camp lockdown',
#   'Covid',
#   'an excuse',
#   'freedoms and rights of people seeking safety in Europe https://t.co/xIbCWkpyLL',
#   'freedoms and rights of people seeking safety in Europe',
#   'freedoms and rights',
#   'people seeking safety in Europe',
#   'people',
#   'safety',
#   'Europe'],
#  ['The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece',
#   'The largest terrorist organization in the world, the names of the Syrian refugees',
#   'The largest terrorist organization',
#   'the world, the names of the Syrian refugees',
#   'the world',
#   'the names of the Syrian refugees',
#   'the names',
#   'the Syrian refugees',
#   'Bulgaria',
#   'Greece'],
#  ['@tomyork5',
#   'Those who seek refuge in Greece, those who want to make a coup',
#   'Those who seek refuge in Greece',
#   'Those',
#   'refuge',
#   'Greece',
#   'those who want to make a coup',
#   'those',
#   'a coup',
#   'they',
#   'Greece',
#   'this kind of people',
#   'this kind',
#   'people',
#   'some brain',
#   'your own perspective',
#   'you',
#   'freedom of expression',
#   'freedom',
#   'expression',
#   'terrorist propaganda',
#   'it',
#   'a crime'],
#  ['Authorities in Greece',
#   'Authorities',
#   'Greece',
#   'the Moria #refugee camp on the island of Lesbos',
#   'the Moria #refugee camp',
#   'the island of Lesbos',
#   'the island',
#   'Lesbos',
#   'quarantine',
#   'the confirmation of the first coronavirus infection in the notoriously overcrowded facility',
#   'the confirmation',
#   'the first coronavirus infection in the notoriously overcrowded facility',
#   'the first coronavirus infection',
#   'the notoriously overcrowded facility',
#   'https://t.co/7LIWIhTngH'],
#  ['229Leckie @MontgomeryClif8 @scot_unionist @paulmasonnews by 2040',
#   '229Leckie @MontgomeryClif8 @scot_unionist @paulmasonnews',
#   '2040',
#   'the north shore of the med',
#   'the north shore',
#   'the med',
#   'the climate of the south, no tomatoes in Spain, grain in Italy, grapes in south France or olives in Greece',
#   'the climate of the south',
#   'the climate',
#   'the south',
#   'no tomatoes in Spain',
#   'no tomatoes',
#   'Spain',
#   'grain in Italy',
#   'grain',
#   'Italy',
#   'grapes in south France',
#   'grapes',
#   'south France',
#   'olives in Greece',
#   'olives',
#   'Greece',
#   'Europe',
#   '200 million European climate refugees',
#   'there',
#   'an EU',
#   'it',
#   'rules are by 2040',
#   'rules',
#   '2040'],
#  ['People',
#   'Greece for a moment',
#   'Greece',
#   'a moment',
#   'me',
#   'I',
#   'them',
#   'it',
#   'they',
#   '1000 immigrants',
#   'the ocean',
#   'them',
#   'this poor nation',
#   'this burden',
#   'the world',
#   'Obama',
#   'Libya'],
#  ['@AmysGotBirds @DonaldJTrumpJr To start this war, Erdogan and Turkey (which is part of NATO) has allowed Syrian refugees into his country',
#   '@AmysGotBirds @DonaldJTrumpJr To start this war, Erdogan and Turkey (which is part of NATO)',
#   '@AmysGotBirds @DonaldJTrumpJr',
#   'this war, Erdogan and Turkey',
#   'part of NATO',
#   'part',
#   'NATO',
#   'Syrian refugees',
#   'his country',
#   'they',
#   'They',
#   'Afghani, Somali, and Iraqi',
#   'Afghani',
#   'Somali',
#   'Iraqi',
#   'He',
#   'these refugees',
#   'flood',
#   'Greece, and Europe',
#   'They',
#   'guns and tear gas',
#   'guns',
#   'tear gas'],
#  ['UNHCR’s Assistant High Commissioners visit #Greece',
#   'UNHCR’s Assistant High Commissioners visit',
#   'UNHCR’s',
#   '#Greece',
#   '#refugee protection challenges and issues',
#   'access',
#   'territory & asylum, living conditions on mainland & islands, the management of the #COVID19 response,',
#   'territory & asylum',
#   'living conditions on mainland & islands, the management of the #COVID19 response,',
#   'living conditions',
#   'mainland & islands, the management of the #COVID19 response,',
#   'mainland & islands',
#   'the management of the #COVID19 response',
#   'the management',
#   'the #COVID19 response',
#   'integration https://t.co/0dZTraZGi3',
#   'https://t.co/E411e2Cp8P'],
#  ['#DevelopmentNewsUpdate',
#   '200,000 lone #child #migrants',
#   '#uncertain',
#   '#Europe',
#   'the full article',
#   'https://t.co/sv8bIVmKO0 #Europe #riskofexploitation #children #safety #Greece #detentionofchildren #conflict #protectionbeyondreach #migrants #twentylakhs https://t.co/lMiEC07BYe'],
#  ['@realPR_Phoenix @DrEstella Estella’s family',
#   '@realPR_Phoenix @DrEstella Estella’s',
#   'Greece and Lithuania',
#   'a toy factory'],
#  ['@Nicolas98869551 @Marflo66036248 @Esref_Doguu Who does say this?',
#   '@Nicolas98869551 @Marflo66036248 @Esref_Doguu',
#   'this',
#   'it',
#   'a Greek',
#   'It',
#   "The Greece which has made a hole in Syrian Refugees' boats and which has beat Syrian Refugees, which has stolen Refugees' money",
#   'The Greece',
#   "a hole in Syrian Refugees' boats",
#   'a hole',
#   "Syrian Refugees' boats",
#   "Syrian Refugees'",
#   "Syrian Refugees, which has stolen Refugees' money",
#   'Syrian Refugees',
#   "Refugees' money",
#   "Refugees'"],
#  ['your kids',
#   '#BackToSchool',
#   'you',
#   'the time you have for other things',
#   'the time',
#   'you',
#   'other things',
#   'SOS',
#   'childcare',
#   'families who are struggling',
#   'families',
#   'parents/carers',
#   'parents',
#   'carers',
#   'work',
#   'more',
#   'our work',
#   'a refugee camp in Lesvos ??',
#   'a refugee camp',
#   'Lesvos ??',
#   'https://t.co/t8GEChlGFg',
#   'https://t.co/oWWet2GJex'],
#  ['@devilxbrain @ragipsoylu',
#   'the 5+ million refugees and then https://t.co/XXT3mjLDCs if you care for them.I can easily say they are living in much better conditions in Turkey compared to Greece',
#   'the 5+ million refugees',
#   'https://t.co/XXT3mjLDCs if you care for them.I can easily say they are living in much better conditions in Turkey compared to Greece',
#   'https://t.co/XXT3mjLDCs',
#   'you',
#   'them.I',
#   'they',
#   'much better conditions in Turkey',
#   'much better conditions',
#   'Turkey',
#   'Greece'],
#  ['#Greece and its people',
#   '#Greece',
#   'its people',
#   'great hospitality',
#   '100 of thousands #refugees and #migrants since 2015',
#   '100',
#   'thousands #refugees and #migrants since 2015',
#   'thousands #refugees and #migrants',
#   '2015',
#   'a lot',
#   'critical needs',
#   'conditions',
#   'islands',
#   'We',
#   'continued solidarity',
#   '#EU and European States',
#   'https://t.co/LivzhA3RXL'],
#  ['Wales',
#   'Portugal and parts of Greek Island on the list',
#   'Portugal',
#   'parts of Greek Island on the list',
#   'parts',
#   'Greek Island on the list',
#   'Greek Island',
#   'the list',
#   'England',
#   "#torychaos #Covid_19 Refugee Covid case sparks 'closed camps' fears",
#   '#torychaos #Covid_19 Refugee Covid',
#   "case sparks 'closed camps' fears",
#   "case sparks 'closed camps'",
#   "case sparks '",
#   'Lesbos https://t.co/jefOiklxow'],
#  ['We',
#   'all in this',
#   'all',
#   'this',
#   'no one',
#   'The #refugees in Greek islands',
#   'The #refugees',
#   'Greek islands',
#   '#COVID19 – Take action now and send an email to Prime Minister of #Greece, @primeministergr',
#   '#COVID19',
#   'Take action now and send an email to Prime Minister of #Greece, @primeministergr',
#   'action',
#   'an email',
#   'Prime Minister',
#   '#Greece, @primeministergr',
#   '#coronavirus',
#   'https://t.co/NQOH3cOVbD'],
#  ['#Attention!!!!',
#   'Illegal immigrant',
#   'a local mini market',
#   '#Soufli , #Greece',
#   '@akrokentrwos',
#   'https://t.co/wiowPSF8pF'],
#  ['A photo to give you an impression of the food in #Moria.',
#   'you',
#   'an impression of the food in #Moria',
#   'an impression',
#   'the food in #Moria',
#   'the food',
#   '#Moria',
#   'you',
#   'it',
#   'it',
#   'charge',
#   'one month',
#   '#Delicious #EU',
#   '#Refugees #LeaveNoOneBehind #SaveThem'],
#  ['@griko84 @BwanaPjotr',
#   '@MEMRIReports You said Muslim factions that Greece dosnt melt in betwen them',
#   '@MEMRIReports You said Muslim factions that Greece dosnt melt in',
#   '@MEMRIReports',
#   'You',
#   'Muslim factions that',
#   'Muslim factions',
#   'Greece dosnt melt',
#   'them',
#   'it',
#   'Greece',
#   'enoug of a fu',
#   'enoug',
#   'a fu',
#   'Assad and open realtionship with him',
#   'Assad',
#   'open realtionship with him',
#   'open realtionship',
#   'him',
#   'its our mess',
#   'its',
#   'our mess',
#   'EU',
#   'it',
#   'it',
#   'the refugees'],
#  ['#Moria',
#   'A food strike',
#   'place',
#   '~100 refugees',
#   'the supply of ready-made food',
#   'the supply',
#   'ready-made food',
#   'the poor quality of the it',
#   'the poor quality',
#   'the it',
#   'it',
#   'a private/public joint venture',
#   '#LeaverNoOneBehind #RefugeesGR'],
#  ['@YinkaOgundipe @EmmanuelAcho Well',
#   'you',
#   'Giannis story',
#   'He',
#   'nothing',
#   'he',
#   '17',
#   'he',
#   'Greece',
#   'Nigerian embassy in Athens',
#   'Nigerian embassy',
#   'Athens',
#   'him',
#   'a passport',
#   'his parents',
#   'Nigeria',
#   'refugees.Only',
#   'Greece',
#   'him',
#   'one',
#   'Nigeria',
#   'they'],
#  ['Greece',
#   'great solidarity',
#   '1000s of refugees + asylum-seekers',
#   '1000s',
#   'refugees + asylum-seekers',
#   'refugees',
#   'asylum-seekers',
#   'There',
#   'critical gaps + issues that need addressing',
#   'critical gaps + issues',
#   'critical gaps',
#   'issues',
#   'Other EU States',
#   'solidarity',
#   'vulnerable asylum seekers',
#   'The situation',
#   'https://t.co/MWxUHH0sZb'],
#  ['@YavuzBiH',
#   '@MEMRIReports 1)EU is not supporting Assad 2',
#   '@MEMRIReports 1)',
#   '1',
#   'EU',
#   'Assad 2',
#   'you',
#   'Greece for any ME wars (that Turkey takes part in)',
#   'Greece',
#   'any ME wars',
#   'Turkey',
#   'part',
#   'colonialism or anything else',
#   'colonialism',
#   'anything else',
#   'the way',
#   'less than 15% of current “refugees” in Greece',
#   'less than 15%',
#   'current “refugees” in Greece',
#   'current “refugees”',
#   'Greece',
#   'Syria'],
#  ['1st #Covid_19 case',
#   '#Moria',
#   '10 days',
#   '#Coronavirus',
#   'the overcrowded #refugee camp',
#   'devastating consequences',
#   'We',
#   'URGENT FUNDS',
#   'our clinic doors',
#   'purchase vital medication and equipment',
#   'purchase vital medication',
#   'equipment',
#   '#DONATE',
#   'https://t.co/a1gCVgOdcR'],
#  ['Lesbos refugee',
#   'quarantine',
#   'Somali migrant infected with coronavirus',
#   'Somali migrant',
#   'coronavirus',
#   'https://t.co/qBdLXSjkdG'],
#  ['@Tarzan35715351',
#   '0khalodi0',
#   'it’s a fact that ISIS member find a passage through illegal immigration in Europe',
#   'it’s a fact',
#   'it’s',
#   'a fact',
#   'ISIS member',
#   'a passage',
#   'illegal immigration in Europe',
#   'illegal immigration',
#   'Europe',
#   'you',
#   'some NATO members',
#   'Portugal',
#   'Greece',
#   'an example and',
#   'an example'],
#  ['@maximusmadham @EndGameWW3',
#   'you',
#   'Albanian greeks',
#   'I',
#   'a shit',
#   'anyone of them',
#   'anyone',
#   'them',
#   'I',
#   'greeks that living in Greece not traitors and refugees',
#   'greeks',
#   'Greece',
#   'traitors and refugees'],
#  ['There',
#   'critical issues that must be addressed, incl the urgent need 2',
#   'critical issues that must be addressed',
#   'critical issues',
#   'incl the urgent need 2',
#   'incl',
#   'the urgent need 2',
#   'the urgent need',
#   '2',
#   'conditions +reduce overcrowding at the reception facilities on the Aegean Islands - @RaoufMazou on #Greece #asylum #Europe #Solidarity https://t.co/H3yhHqly4g',
#   'conditions +reduce overcrowding at the reception facilities on the Aegean Islands - @RaoufMazou on #Greece #asylum #Europe #Solidarity',
#   'overcrowding',
#   'the reception',
#   'the Aegean Islands',
#   '@RaoufMazou',
#   '#Greece #asylum',
#   '@refugees'],
#  ['Greece and its people',
#   'Greece',
#   'its people',
#   'tremendous solidarity and compassion',
#   'thousands of refugees and asylum-seekers',
#   'thousands',
#   'refugees and asylum-seekers',
#   'refugees',
#   'asylum-seekers',
#   'all the challenges the country has faced',
#   'all the challenges',
#   'the country',
#   'a severe economic crisis and now the COVID-19 pandemic - @RaoufMazou',
#   'a severe economic crisis',
#   'now the COVID-19 pandemic - @RaoufMazou',
#   'https://t.co/WDVFsQS0sk'],
#  ['Viotia Refugee Detention Camp in GREECE',
#   'Viotia Refugee Detention Camp',
#   'GREECE',
#   'Down',
#   'COVID-19',
#   'https://t.co/j9bKQUVcBR',
#   '#news'],
#  ['@bethvaughan15 @SueSuezep @Jacob_Rees_Mogg Britain',
#   'far less asylum applications',
#   'other European country',
#   'Germany, France and Greece',
#   'a hell of a lot',
#   'a hell',
#   'a lot'],
#  ['fight for hope - the states',
#   'fight',
#   'hope - the states',
#   'hope',
#   'the states',
#   'people',
#   'asylum',
#   'unsafe countries',
#   'this',
#   'the Aegean sea',
#   '#migrants',
#   '#refugees',
#   '#AsylumSeekers',
#   '#Turkey #Ankara',
#   '#Greece #Syria',
#   '#Iraq #MiddleEast #Pakistan',
#   '#Afghanistan #Honduras #ElSalvador',
#   '#Mexico #Guatemala https://t.co/ROQxjEgfjA'],
#  ['@sarianpaul1 @pritipatel This idea that the uk is being overwhelmed',
#   '@sarianpaul1 @pritipatel This idea',
#   '@sarianpaul1 @pritipatel',
#   'This idea',
#   'the uk',
#   'absolute pure dogshite',
#   "85% of the world's refugees",
#   '85%',
#   "the world's refugees",
#   "the world's",
#   'countries',
#   'the one their fled',
#   'the one',
#   'their',
#   'The uk',
#   '3 x less asylum applications',
#   '3 x',
#   'France',
#   '4x less than Germany, 2x less',
#   '4x',
#   'Germany, 2x',
#   'Spain and Greece',
#   'it'],
#  ['0khalodi0',
#   'Greece',
#   'the majority of immigrants',
#   'the majority',
#   'immigrants',
#   'Pakistan and Afghanistan and Bagladesh',
#   'It',
#   'the catch an ISIS member',
#   'the catch',
#   'an ISIS member',
#   'Spain',
#   'Greece',
#   'Europe',
#   'danger'],
#  ['Refugee Covid',
#   "case sparks 'closed camps' fears on",
#   "case sparks 'closed camps' fears",
#   "case sparks 'closed camps'",
#   "case sparks '",
#   'Lesbos',
#   'Global development',
#   'The',
#   'Guardian : https://t.co/90q629G4gV',
#   'Guardian',
#   'https://t.co/90q629G4gV',
#   '#santé'],
#  ["@no_eyed_ryan I'm Greek, many in America",
#   '@no_eyed_ryan',
#   'I',
#   'Greek, many in America',
#   'Greek, many',
#   'America',
#   'Greeks',
#   'white westerners',
#   'our culture, history and ethnic heritage',
#   'our culture',
#   'history',
#   'ethnic heritage',
#   'theirs',
#   'Greek immigrants',
#   'their culture',
#   'fact they suffered under white supremacy both in Greece and in white colonised countries',
#   'fact',
#   'they',
#   'white supremacy',
#   'Greece',
#   'white colonised countries'],
#  ['@devilxbrain @ragipsoylu',
#   'You',
#   'Greece',
#   'the gates for your so called ‘poor’ refugees',
#   'the gates',
#   'your so called',
#   '‘poor’ refugees',
#   'them'],
#  ['@DrManha84708484 @Eos303 @Nervana_1 @EGozuguzelli',
#   'you',
#   'Greeks that go to Turkey',
#   'Greeks',
#   'Turkey',
#   'asylum',
#   'The answer',
#   'we',
#   'thousands of Turks every day that come to Greece and ask for asylum',
#   'thousands',
#   'Turks every day that come to Greece and ask for asylum',
#   'Turks every day',
#   'Turks',
#   'every day',
#   'Greece',
#   'asylum',
#   'Turkey'],
#  ['Migrant shelter for unsupervised minors in Greece',
#   'Migrant shelter',
#   'unsupervised minors in Greece',
#   'unsupervised minors',
#   'Greece',
#   'coronavirus outbreak — RT',
#   'World News',
#   'https://t.co/qeh1vETr89'],
#  ['#COVID19 measures in #Greece #AsylumSeekers & #Refugees on #Lesbos.',
#   '#COVID19 measures',
#   '#Greece #AsylumSeekers & #Refugees on #Lesbos',
#   '#Greece #AsylumSeekers & #Refugees',
#   '#Lesbos',
#   'those poor people',
#   'this living hell',
#   'https://t.co/tzqE7pT812'],
#  ['@gerdosi @paulmelzer1 @nmlinguaphile The funniest thing is no country',
#   '@gerdosi @paulmelzer1',
#   'The funniest thing',
#   'no country',
#   'its borders',
#   'it',
#   'It',
#   'the spread',
#   'History',
#   'the Cordon Sanitaire&more',
#   'the Cordon Sanitaire',
#   'more',
#   "recent flare ups in TX&Florida (migrants from Mexico&Caribbean), Greece early closing vs Spain' s late 1",
#   'recent flare ups in TX&Florida (migrants from Mexico&Caribbean)',
#   'recent flare ups',
#   'TX&Florida (migrants from Mexico&Caribbean)',
#   'migrants from Mexico&Caribbean',
#   'migrants',
#   'Mexico&Caribbean',
#   "Greece early closing vs Spain' s late 1",
#   'Greece',
#   "closing vs Spain' s late 1",
#   'closing',
#   "Spain' s late 1",
#   "Spain' s",
#   "Spain'",
#   '1',
#   'facts undermining your general stateme',
#   'facts',
#   'your general stateme'],
#  ['@lk2015r @LevidisStefanos When I started my fieldwork in ?zmir in 2008 summer',
#   '@lk2015r @LevidisStefanos',
#   'I',
#   'my fieldwork',
#   '?zmir',
#   '2008 summer',
#   'refugees',
#   'me',
#   'their experiences',
#   'sea',
#   'There',
#   'migrants',
#   'the bilateral agreement who had detention experience in Greece',
#   'the bilateral agreement',
#   'detention experience in Greece',
#   'detention experience',
#   'Greece'],
#  ['@DartmoorSounds @guyverhofstadt',
#   'i',
#   'the Cayman Islands',
#   'MY WINTER',
#   'you',
#   'the EU',
#   'Sunlit EU beaches with dead migrants on you',
#   'Sunlit EU beaches',
#   'dead migrants on you',
#   'dead migrants',
#   'you',
#   'the EU',
#   'people crossing',
#   'people',
#   "sea's in little boats",
#   "sea's",
#   'little boats',
#   'greece and now the Channel',
#   'greece',
#   'now the Channel',
#   'they',
#   'nothing'],
#  ['This',
#   'the second year that we have supported this Appeal for Hope and Kindness',
#   'the second year',
#   'we',
#   'this Appeal for Hope and Kindness',
#   'this Appeal',
#   'Hope and Kindness',
#   'All of the money',
#   'All',
#   'the money',
#   'nappies for babies in Refugee camps',
#   'nappies',
#   'babies in Refugee camps',
#   'babies',
#   'Refugee camps',
#   '#Greece',
#   'Donations',
#   'hope',
#   'a mother and comfort to her baby',
#   'a mother and comfort',
#   'her baby',
#   '#FiveForHope https://t.co/jWuPRixilI',
#   'https://t.co/j99DHJ2ldK'],
#  ['Current UNHCR numbers #Lesvos',
#   'Current UNHCR numbers',
#   '#Lesvos',
#   '14,007 #refugeesgr',
#   'island',
#   'Majority',
#   '#Afghanistan (76%), #Syria (7%) and Democratic Republic of the #Congo (7%)',
#   '#Afghanistan (76%)',
#   '#Afghanistan',
#   '76%',
#   '#Syria (7%)',
#   '7%',
#   'Democratic Republic of the #Congo (7%)',
#   'Democratic Republic',
#   'the #Congo',
#   '7%',
#   'Women',
#   '23% of population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old',
#   '23%',
#   'population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old',
#   'population & children',
#   '39%, of whom more than 7 out of 10 are younger than 12 years old',
#   '39%',
#   'more than 7 out of 10',
#   '12 years',
#   '/1',
#   'https://t.co/4OTIv9tk3X'],
#  ['@CllrBarryLewis',
#   'we',
#   'a responsibility to take at least some of these people in if they need it',
#   'at least some of these people',
#   'at least some',
#   'these people',
#   'they',
#   'it',
#   'your line of reasoning',
#   'your line',
#   'reasoning',
#   'Italy and Greece, or the other primary landing countries,',
#   'Italy and Greece',
#   'the other primary landing countries',
#   'all the refugees, which hardly seems fair',
#   'all the refugees'],
#  ['Greece',
#   'a deadly new migration policy – and all of Europe is to blame | Every time Athens pushes a refugee boat away',
#   'a deadly new migration policy – and all of Europe is to blame',
#   'a deadly new migration',
#   'policy – and all of Europe',
#   'policy –',
#   'all of Europe',
#   'all',
#   'Europe',
#   'Every time Athens pushes a refugee boat away',
#   'Every time',
#   'Athens',
#   'a refugee boat',
#   'it’s the result of an entire continent',
#   'it’s',
#   'the result',
#   'an entire continent',
#   'its perceived self-interest https://t.co/9sEKKQ6tBy',
#   'https://t.co/Im5ShhraQF'],
#  ['COVID-19: Greece reports first coronavirus case in Moria migrant camp on Lesbos https://t.co/wWgaCNZ6UE',
#   'COVID-19',
#   'Greece',
#   'first coronavirus case in Moria migrant camp',
#   'first coronavirus case',
#   'Moria migrant camp',
#   'Lesbos',
#   'https://t.co/wWgaCNZ6UE'],
#  ['@jensstoltenberg @EGozuguzelli',
#   '@RTErdogan @NATO Greek',
#   'militans kil.ling poor immigrants',
#   'militans',
#   'poor immigrants',
#   'Racist unlawfull greece.',
#   'https://t.co/ZKkNKqDgXI'],
#  ['War conflicts, migrations, diseases... That',
#   'War conflicts',
#   'migrations',
#   'diseases',
#   'That',
#   'a waterless region',
#   'EIT',
#   'we',
#   'that problem',
#   'the best ideas in our online event #InnowiseChallengeLabs',
#   'the best ideas',
#   'our online event #InnowiseChallengeLabs',
#   'the Greece event',
#   '15 september at 4 PM',
#   '15 september',
#   '4 PM'],
#  ['@EastMedMonitor',
#   '4 million migrants',
#   'turkey!if',
#   'Greece',
#   'its 12 mile maritime territory',
#   'turkey',
#   'them',
#   'the sea',
#   'they',
#   'the EU in many areas',
#   'the EU',
#   'many areas'],
#  ['@_ErcanButun @LegendofBaba You are to be https://t.co/uQO4C8nZCw fooled all these poor people that the borders are open and you carried them by thousands to enter Greece.Your sneaky political game',
#   '@_ErcanButun @LegendofBaba',
#   'You',
#   'https://t.co/uQO4C8nZCw fooled all these poor people that the borders are open and you carried them by thousands to enter Greece.Your sneaky political game',
#   'https://t.co/uQO4C8nZCw',
#   'all these poor people',
#   'the borders',
#   'you',
#   'them',
#   'thousands',
#   'Greece.Your sneaky political game',
#   'Greece.Your',
#   'sneaky political game',
#   'You',
#   'animals for manipulating refuges',
#   'animals',
#   'refuges'],
#  ['The first recorded coronavirus case in Moria refugee camp on Lesbos, where just under 13,000 people are l.....',
#   'The first recorded coronavirus',
#   'case in Moria refugee',
#   'case',
#   'Moria refugee',
#   'camp on Lesbos, where just under 13,000 people are l....',
#   'camp on Lesbos',
#   'camp',
#   'Lesbos',
#   'just under 13,000 people',
#   'https://t.co/5jbWReoMR1 @scwacy'],
#  ['@hvvnfd @jedijig @KostasAntLavdas @jensstoltenberg',
#   'I thing',
#   'this',
#   'Turkey',
#   'just the Aegean',
#   'Greece',
#   'both aegean and kastelorizo eez',
#   'any case that are history',
#   'any case',
#   'history',
#   'now Greece',
#   'it and Turkey refuge',
#   'it',
#   'Turkey refuge',
#   'This',
#   'the truth']]
