# %% [markdown]
# # Candidate merging and related preprocessing

# %% [markdown]
# Import relevant packages for the following parts

# %%
#python libraries
import stanza
import nltk
from nltk.corpus import wordnet
import numpy as np
import pandas as pd
import os
import re
import csv
from tqdm import tqdm
import time

# self written modules
import preprocessing
import candidate_processing as cand_prep
import candidate_extraction as cand_ex
# Out:
# Reading english - 1grams ...
# Reading english - 1grams ...
# Reading english - 2grams ...
# C:\ProgramData\Anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# ## 1. We import the data and split them based on the event date

# %%
#data_url = r"CBS - Copenhagen Business School\Kick-Ass Master Thesis - General\Data\moria-data/moria_no_duplicates.csv"
beirut_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_beirut.csv" # for Beirut
tigray_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_tigray.csv" # for Tigray
channel_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_channel.csv" # for Channel
moria_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_moria.csv" # for Moria
all_url = r"Dropbox (CBS)/Master thesis data/df_tweets.csv" # for all

def read_dataframe(data_url):
    directory_path = os.getcwd() + "/../../../" + data_url 
    event_df = pd.read_csv(directory_path, index_col=0)
    event_df.reset_index(drop=True, inplace=True)
    print('total tweets: ', event_df.shape[0])
    return event_df

#beirut_df = read_dataframe(beirut_url)
tigray_df = read_dataframe(tigray_url)
channel_df = read_dataframe(channel_url)
moria_df = read_dataframe(moria_url)
#all_df = read_dataframe(all_url)
# Out:
# total tweets:  180779
# total tweets:  604536
# total tweets:  92806

# %% [markdown]
# ## 2. We preprocess the data using the function from self-written preprocessing module

# %%
# see the description of the method in the preprocessing module
beirut_tweets = preprocessing.preprocess_tweets(beirut_df['text'])
tigray_tweets = preprocessing.preprocess_tweets(tigray_df['text'])
channel_tweets = preprocessing.preprocess_tweets(channel_df['text'])
moria_tweets = preprocessing.preprocess_tweets(moria_df['text'])
#all_tweets = preprocessing.preprocess_tweets(all_df['text'])
# Out:
#   0%|                                                                                        | 0/24511 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# 100%|███████████████████████████████████████████████████████████████████████████| 24511/24511 [02:13<00:00, 184.07it/s]
#  52%|███████████████████████████████████████                                    | 94204/180779 [37:38<27:19, 52.80it/s]

# %% [markdown]
# ## 3. We instantiate stanza english language module

# %%
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ needed when running first time ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#

#stanza.download("en")

#directory = '../../export CORENLP_HOME=' ##ADD DIRECTORY HERE
#stanza.install_corenlp()

#import os
#os.environ["CORENLP_HOME"] = directory

# %%
en_nlp = stanza.Pipeline("en", ner_batch_size=8192)
# Out:
# 2021-03-26 08:26:47 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-03-26 08:26:47 INFO: Use device: cpu
# 2021-03-26 08:26:47 INFO: Loading: tokenize
# 2021-03-26 08:26:47 INFO: Loading: pos
# 2021-03-26 08:26:47 INFO: Loading: lemma
# 2021-03-26 08:26:47 INFO: Loading: depparse
# 2021-03-26 08:26:48 INFO: Loading: sentiment
# 2021-03-26 08:26:48 INFO: Loading: ner
# 2021-03-26 08:26:49 INFO: Done loading processors!

# %%
import pickle
import os

def pickle_files(file_name, file_to_dump):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path +  fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, 'wb') as fp:
        pickle.dump(file_to_dump, fp)

def load_pickle(file_name):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path + fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, "rb") as input_file:
        return pickle.load(input_file)

# %%
# extract noun_phrase and coreference candidates, as well as tag tweets using cand_ex.candidate_identification function

# to show progress of apply function
tqdm.pandas()

moria_tweets = moria_df['text'].progress_apply(preprocessing.preprocess_tweets)
moria_np_list, moria_tagged_tweets = cand_ex.candidate_identification(moria_tweets,en_nlp,10000)

pickle_files('moria_np_list',moria_np_list)
pickle_files('moria_tagged_tweets',moria_tagged_tweets)

tigray_tweets = tigray_df['text'].progress_apply(preprocessing.preprocess_tweets)
tigray_np_list, tigray_tagged_tweets = cand_ex.candidate_identification(tigray_tweets,en_nlp,10000)

pickle_files('tigray_np_list',tigray_np_list)
pickle_files('tigray_tagged_tweets',tigray_tagged_tweets)
                                                                    
                                                                    
channel_tweets = channel_df['text'].progress_apply(preprocessing.preprocess_tweets)
channel_np_list, channel_tagged_tweets = cand_ex.candidate_identification(channel_tweets,en_nlp,10000)

pickle_files('channel_np_list',channel_np_list)
pickle_files('channel_tagged_tweets',channel_tagged_tweets)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████████████████████████████████████████████████████████████████████| 92806/92806 [00:50<00:00, 1848.79it/s]
# 0it [00:00, ?it/s]
# annotating the tweet corpus...

# %% [markdown]
# ## 4. We apply stanza module on the tweets to get NER and POS tags. We do it in batches to speed things up.

# %%
from stanza_batch import batch
from nltk.tokenize import sent_tokenize

#~~~ check how much faster it is with "\n\n"
# the sampled_df series should be converted to list so we avoid slowing things down with iteration
all_tweets_list = list(sampled_df) 

tagged_tweets = [tweet for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=3000))] # Default batch size is 32

tagged_tweets[0].text
# Out:
# 200it [00:44,  4.53it/s]
# 'I read all your books professor, and even waited on you when you came to Ilili, this tweet gave so much confidence because we did this . And we also did Jerusalem and Beirut next week in a non a7zab related kitchen skin inthe game'

# %%
# get easily accessible list of tuples (POS-tags of each word, NER-tags of each named entity) 
tweet_tags = cand_prep.get_tweet_tags(tagged_tweets) 
#print(tweet_tags)

#get a set of all NER tags existing in corpus - check which one are found in corpus

tweet_tags_set = set()
for tweet in tweet_tags:
    tweet_ner_tags = set(tweet[1].values())
    tweet_tags_set.update(tweet_ner_tags)

print(tweet_tags_set)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 19994.78it/s]
# {'FAC', 'CARDINAL', 'QUANTITY', 'ORG', 'TIME', 'ORDINAL', 'LANGUAGE', 'NORP', 'LOC', 'LAW', 'GPE', 'EVENT', 'DATE', 'WORK_OF_ART', 'PERSON'}

# %% [markdown]
# ## 5. As initial WCL candidates, we extract noun phrases (NPs) and coreference chains.
#
# ## We do so using CoreNLPClient wrapper
#
# ### SOME PREPROCESSING NEEDED
# * remove links - check
# * remove # from hashtags? - check
# * remove/merge mentions? - check
#
#
# * remove recurring texts (signatures of news media) - any new spotted should be added in preprocessing file's '__remove_tweet_signatures__' function
# * remove posts of some accounts (refugee_list)
# * exclude NERs that tag numbers - should we mark phrase as NE if the head is not NE? - check
# * play around with candidate types
# * optimize code and make it neater

# %%
import candidate_extraction as cand_ex

noun_phrase_list, corefs_list = cand_ex.extract_candidates(sampled_df)
# Out:
# 2021-03-22 21:40:04 INFO: Writing properties to tmp file: corenlp_server-dac4812596094d5d.props
# 2021-03-22 21:40:04 INFO: Starting server with command: java -Xmx16G -cp C:\Users\nikodemicek\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 300000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-dac4812596094d5d.props -annotators tokenize,ssplit,pos,lemma,parse,coref,ner,udfeats,depparse -preload -outputFormat serialized
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# extracting noun phrases...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:18<00:00,  1.88s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# extracting coreference chains...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.03s/it]

# %%
#Store the noun phrases in the pickle file
import pickle

with open('beirut_nps', 'wb') as fp:
    pickle.dump(noun_phrase_list, fp)

with open('beirut_crfs','wb') as fp:
    pickle.dump(corefs_list, fp)

# %%
#removing the spaces around dashes, slashes and apostrophes should increase stanza's ability to parse sentence correctly
noun_phrase_list = [[np.replace(' - ','-') for np in nps] for nps in noun_phrase_list]
noun_phrase_list = [[np.replace(' / ','/') for np in nps] for nps in noun_phrase_list]
noun_phrase_list = [[np.replace(" ' ","'") for np in nps] for nps in noun_phrase_list]

# %%
# Load NPs and corefs from pickle file
import pickle

with open(r"beirut_nps", "rb") as input_file:
    noun_phrase_list = pickle.load(input_file)

with open(r"beirut_nps", "rb") as input_file:
    corefs_list = pickle.load(input_file)

# %% [markdown]
# ## 6. We keep only NPs shorter than 20 words and remove children of parent NPs

# %%
def get_cand_len(cand_list):
    # calculates number of candidates in the corpus
    sum_len = 0
    for tweet_cands in cand_list:
        sum_len += len(tweet_cands)
    return sum_len

print(get_cand_len(noun_phrase_list))

def remove_long_nps(noun_phrase_list):
    for tweet_id in range(len(noun_phrase_list)):
        #print(noun_phrase_list[tweet_id])
        #reverse the list of tweets nps so we avoid moving indexes and leaving out some phrases 
        for noun_p in reversed(noun_phrase_list[tweet_id]):
            i = noun_phrase_list[tweet_id].index(noun_p)
            np_split = noun_p.split()
            if len(np_split) > 19:
                noun_phrase_list[tweet_id].remove(noun_phrase_list[tweet_id][i])
    return noun_phrase_list


noun_phrase_list = remove_long_nps(noun_phrase_list)
print(get_cand_len(noun_phrase_list))
# Out:
# 132
# 132

# %%
def remove_child_nps(noun_phrase_list):
    # remove the child NPs and keep only parents, run until the sum_len stops decreasing
    after_removal_len = 0
    while after_removal_len != get_cand_len(noun_phrase_list):
        after_removal_len = get_cand_len(noun_phrase_list)
        for tweet_nps in noun_phrase_list:
            for noun_p in range(len(tweet_nps)):
                try:
                    #if the subsequent noun_p (child np) is contained in the current one, remove the child np
                    if tweet_nps[noun_p].find(tweet_nps[noun_p+1]) != -1:
                        tweet_nps.remove(tweet_nps[noun_p+1])
                        
                #ignore the error caused with end of the list
                except IndexError:
                    pass
    return noun_phrase_list

def remove_mention(noun_phrase_list):
    return [[np.replace('@','') for np in nps ] for nps in noun_phrase_list ]    

print(get_cand_len(noun_phrase_list))

noun_phrase_list = remove_child_nps(noun_phrase_list)
noun_phrase_list = remove_mention(noun_phrase_list)

print(get_cand_len(noun_phrase_list))
# Out:
# 73
# 73

# %% [markdown]
# ## 7. We get the heads of noun phrases (in batches)

# %%
#tag all tweets and save them in a list    
batched_np_list = cand_prep.prep_candlist_for_batching(noun_phrase_list)
#print(batched_np_list)


tagged_np_cands = [tagged_cand for tagged_cand in batch(batched_np_list, en_nlp, batch_size=6000)]# Default batch size is 32
tagged_np_cands
# Out:
# ['i\\n\\nall your books\\n\\nprofessor\\n\\nyou\\n\\nilili\\n\\nthis tweet\\n\\nso much confidence\\n\\nwe\\n\\nthis\\n\\nwe\\n\\njerusalem and beirut\\n\\na non a7zab related kitchen skin inthe game', 'my grandfather\\n\\na lebanese immigrant\\n\\nthe second wave\\n\\nnormandy\\n\\nim\\n\\nhis blood pumping under my skin', 'migrant _ workers _ lives _ matter lets not forget lebanese racism\\n\\nkafala', 'more than a dozen refugees in eastern lebanon\\n\\nthe coronavirus, which shows the vulnerability of refugees in the country, many of whom live in crowded, poor conditions', 'a lovely way\\n\\nthe week\\n\\ninspiring art\\n\\nthe beautiful creations\\n\\nyoung people\\n\\nlebanon who are proving in their own way that everyone counts in the fight against covid 19, including refugees\\n\\nyou\\n\\nyours', "we\\n\\nthat people\\n\\npeople, just as modern - day lebanese\\n\\nphoenicians and modern - day iranians\\n\\npersians\\n\\nthe only difference being we\\n\\nour land for generations\\n\\nthat doesn' t\\n\\nour identity one iota", 'the civil war in lebanon\\n\\nthe 1 9 7 0 s typical white person comment\\n\\n(im not surprised just shocked)\\n\\nan australian reporter\\n\\nthe strong prescence of lebanese migrant and australian born citizens in this country', 'i\\n\\nthat\\n\\nprimary / high school kids\\n\\nlebanese / italian\\n\\nimmigrants\\n\\n80 to 100 years\\n\\nit\\n\\nlebanese\\n\\na number\\n\\ni', 'confinement measures\\n\\nmental health issues\\n\\nthey\\n\\nlebanons refugee population\\n\\nsyrians\\n\\nlebanon\\n\\nsafety\\n\\nit\\n\\nall', 'mrs\\n\\na lot of material on the web visit\\n\\nisrael talk\\n\\nthe people\\n\\nthe israeli arabs ask them if they live badly\\n\\nthe druze talk\\n\\nthe lebanese christian refugees\\n\\nthey\\n\\na crime\\n\\nall the peace schemes proposed by israel', 'those migrant workers\\n\\ndiscussions about lebanon and its toxic nationality too idc i will call it out\\n\\namerican prison systems as modern slavery too\\n\\nyour part\\n\\nsomeone\\n\\nthe uae', 'their money / aid\\n\\npower and bias\\n\\nline their pockets\\n\\nthe subject matter\\n\\nislamic killing yemenis ignoring palestinians ignoring syria allowing the much poorer lebanon jordan\\n\\nturkey\\n\\nthe millions of refugees (our brothers)', "migrants working in lebanon\\n\\nthe economic downturn of the country as well as new daily realities\\n\\nthe ongoing covid 19 pandemic\\n\\nmany\\n\\nthe country\\n\\nhome either - at least not without their employers' consent", 'the global coronavirus pandemic\\n\\nthe pre - existing crisis\\n\\nlebanon\\n\\n26 deaths and 1,172\\n\\ncases\\n\\n16 among syrian refugees', 'mr .\\n\\nmartin\\n\\ni\\n\\na message\\n\\nthe red cross\\n\\ngeneva\\n\\nmr\\n\\nmatthew\\n\\nme\\n\\ni\\n\\na result\\n\\ni\\n\\na refugee in lebanon\\n\\ni\\n\\nthe red cross\\n\\nyou', 'the audacity to think you understand the pain when most countries in the region including\\n\\nan exploitative system for migrant workers\\n\\nkafala\\n\\n3 - lebanon\\n\\na long track record of abuse and borderline slavery with migrant workers', 'the west bank, gaza strip, and refugee camps in lebanon and jordan\\n\\nurgent humanitarian relief\\n\\nrisk communities and hospitals\\n\\nthem\\n\\nfood, infection control supplies, medical equipment, and building new departments', 'study\\n\\nancient canaanites\\n\\nmodern populations archaeology', 'refugees\\n\\nracism, harassment, and the possibility of deportation\\n\\nthey\\n\\ncases of covid - 19\\n\\nrefugeespartner\\n\\nthe plight of syrian refugees\\n\\nlebanon\\n\\nthe coronavirus and an economic collapse', 'there\\n\\nmore examples in more cities\\n\\ni\\n\\ndetroit\\n\\nmy grandfather, the son of lebanese immigrants,\\n\\na store\\n\\none of these neighborhoods\\n\\nfirst hand\\n\\nthe aftermath of i - 94 cutting through vibrant communities', 'my grandfather\\n\\nfascism\\n\\nww2\\n\\nhe\\n\\na 1 st generation canadian born from lebanese immigrants', 'the case\\n\\na  ...

# %%
tagged_np_cands
# Out:
# [[
#    [
#      {
#        "id": 1,
#        "text": "i\\n\\nall",
#        "lemma": "i\\n\\nall",
#        "upos": "VERB",
#        "xpos": "VB",
#        "feats": "Mood=Imp|VerbForm=Fin",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=0|end_char=8",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "your",
#        "lemma": "you",
#        "upos": "PRON",
#        "xpos": "PRP$",
#        "feats": "Person=2|Poss=Yes|PronType=Prs",
#        "head": 3,
#        "deprel": "nmod:poss",
#        "misc": "start_char=9|end_char=13",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "books\\n\\nprofessor\\n\\nyou\\n\\nilili\\n\\nthis",
#        "lemma": "books\\n\\nprofessor\\n\\nyou\\n\\nilili\\n\\nthis",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 1,
#        "deprel": "obj",
#        "misc": "start_char=14|end_char=56",
#        "ner": "O"
#      }
#    ],
#    [
#      {
#        "id": 1,
#        "text": "tweet\\n\\nso",
#        "lemma": "tweet\\n\\nso",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=57|end_char=68",
#        "ner": "O"
#      }
#    ],
#    [
#      {
#        "id": 1,
#        "text": "much",
#        "lemma": "much",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 2,
#        "deprel": "amod",
#        "misc": "start_char=69|end_char=73",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "confidence\\n\\nwe\\n\\nthis\\n\\nwe\\n\\njerusalem",
#        "lemma": "confidence\\n\\nwe\\n\\nthis\\n\\nwe\\n\\njerusalem",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=74|end_char=117",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 9,
#        "deprel": "cc",
#        "misc": "start_char=118|end_char=121",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "beirut\\n\\na",
#        "lemma": "beirut\\n\\na",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 5,
#        "deprel": "amod",
#        "misc": "start_char=122|end_char=133",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "non",
#        "lemma": "non",
#        "upos": "X",
#        "xpos": "FW",
#        "head": 6,
#        "deprel": "compound",
#        "misc": "start_char=134|end_char=137",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "a7zab",
#        "lemma": "a7zab",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "compound",
#        "misc": "start_char=138|end_char=143",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "related",
#        "lemma": "related",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=144|end_char=151",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "kitchen",
#        "lemma": "kitchen",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "compound",
#        "misc": "start_char=152|end_char=159",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "skin",
#        "lemma": "skin",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 2,
#        "deprel": "conj",
#        "misc": "start_char=160|end_char=164",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "inthe",
#        "lemma": "inthe",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 11,
#        "deprel": "case",
#        "misc": "start_char=165|end_char=170",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "game",
#        "lemma": "game",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "nmod",
#        "misc": "start_char=171|end_char=175",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "my",
#        "lemma": "my",
#        "upos": "PRON",
#        "xpos": "PRP$",
#        "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#        "head": 8,
#        "deprel": "nmod:poss",
#        "misc": "start_char=0|end_char=2",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "grandfather\\n\\na",
#        "lemma": "grandfather\\n\\na",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 8,
#        "deprel": "compound",
#        "misc": "start_char=3|end_char=19",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "lebanese",
#        "lemma": "lebanese",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 8,
#        "deprel": "amod",
#        "misc": "start_char=20|end_char=28",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "immigrant\\n\\nthe",
#        "lemma": "immigrant\\n\\nthe",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 8,
#        "deprel": "compound",
#        "misc": "start_char=29|end_char=45",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "second",
#        "lemma": "second",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos|NumType=Ord",
#        "head": 8,
#        "deprel": "amod",
#        "misc": "start_char=46|end_char=52",
#        "ner": "S-ORDINAL"
#      },
#      {
#        "id": 6,
#        "text": "wave\\n\\nnormandy",
#        "lemma": "wave\\n\\nnormandy",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 8,
#        "deprel": "amod",
#        "misc": "start_char=53|end_char=69",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "\\n\\nim\\n\\nhis",
#        "lemma": "\\n\\nim\\n\\nhis",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 8,
#        "deprel": "compound",
#        "misc": "start_char=69|end_char=82",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "blood",
#        "lemma": "blood",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=83|end_char=88",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "pumping",
#        "lemma": "pump",
#        "upos": "VERB",
#        "xpos": "VBG",
#        "feats": "VerbForm=Ger",
#        "head": 8,
#        "deprel": "acl",
#        "misc": "start_char=89|end_char=96",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "under",
#        "lemma": "under",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 12,
#        "deprel": "case",
#        "misc": "start_char=97|end_char=102",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "my",
#        "lemma": "my",
#        "upos": "PRON",
#        "xpos": "PRP$",
#        "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#        "head": 12,
#        "deprel": "nmod:poss",
#        "misc": "start_char=103|end_char=105",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "skin",
#        "lemma": "skin",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "obl",
#        "misc": "start_char=106|end_char=110",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "migrant",
#        "lemma": "migrant",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Sing",
#        "head": 3,
#        "deprel": "compound",
#        "misc": "start_char=0|end_char=7",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "_",
#        "lemma": "_",
#        "upos": "SYM",
#        "xpos": "NFP",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=8|end_char=9",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "workers",
#        "lemma": "worker",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=10|end_char=17",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "_",
#        "lemma": "_",
#        "upos": "SYM",
#        "xpos": "NFP",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=18|end_char=19",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "lives",
#        "lemma": "life",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 3,
#        "deprel": "parataxis",
#        "misc": "start_char=20|end_char=25",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "_",
#        "lemma": "_",
#        "upos": "SYM",
#        "xpos": "NFP",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=26|end_char=27",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "matter",
#        "lemma": "matter",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 10,
#        "deprel": "nsubj",
#        "misc": "start_char=28|end_char=34",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "lets",
#        "lemma": "let",
#        "upos": "AUX",
#        "xpos": "VBZ",
#        "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#        "head": 10,
#        "deprel": "aux",
#        "misc": "start_char=35|end_char=39",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "not",
#        "lemma": "not",
#        "upos": "PART",
#        "xpos": "RB",
#        "head": 10,
#        "deprel": "advmod",
#        "misc": "start_char=40|end_char=43",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "forget",
#        "lemma": "forget",
#        "upos": "VERB",
#        "xpos": "VB",
#        "feats": "VerbForm=Inf",
#        "head": 3,
#        "deprel": "parataxis",
#        "misc": "start_char=44|end_char=50",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "lebanese",
#        "lemma": "lebanese",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 12,
#        "deprel": "amod",
#        "misc": "start_char=51|end_char=59",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "racism\\n\\nkafala",
#        "lemma": "racism\\n\\nkafala",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 10,
#        "deprel": "obj",
#        "misc": "start_char=60|end_char=76",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "more",
#        "lemma": "more",
#        "upos": "ADJ",
#        "xpos": "JJR",
#        "feats": "Degree=Cmp",
#        "head": 5,
#        "deprel": "advmod",
#        "misc": "start_char=0|end_char=4",
#        "ner": "B-CARDINAL"
#      },
#      {
#        "id": 2,
#        "text": "than",
#        "lemma": "than",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 5,
#        "deprel": "case",
#        "misc": "start_char=5|end_char=9",
#        "ner": "I-CARDINAL"
#      },
#      {
#        "id": 3,
#        "text": "a",
#        "lemma": "a",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Ind|PronType=Art",
#        "head": 5,
#        "deprel": "det",
#        "misc": "start_char=10|end_char=11",
#        "ner": "I-CARDINAL"
#      },
#      {
#        "id": 4,
#        "text": "dozen",
#        "lemma": "dozen",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 5,
#        "deprel": "amod",
#        "misc": "start_char=12|end_char=17",
#        "ner": "E-CARDINAL"
#      },
#      {
#        "id": 5,
#        "text": "refugees",
#        "lemma": "refuge",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 24,
#        "deprel": "obl",
#        "misc": "start_char=18|end_char=26",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 9,
#        "deprel": "case",
#        "misc": "start_char=27|end_char=29",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "eastern",
#        "lemma": "eastern",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=30|end_char=37",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "lebanon\\n\\nthe",
#        "lemma": "lebanon\\n\\nthe",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "compound",
#        "misc": "start_char=38|end_char=52",
#        "ner": "B-LOC"
#      },
#      {
#        "id": 9,
#        "text": "coronavirus",
#        "lemma": "coronavirus",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 5,
#        "deprel": "nmod",
#        "misc": "start_char=53|end_char=64",
#        "ner": "E-LOC"
#      },
#      {
#        "id": 10,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 12,
#        "deprel": "punct",
#        "misc": "start_char=64|end_char=65",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "which",
#        "lemma": "which",
#        "upos": "PRON",
#        "xpos": "WDT",
#        "feats": "PronType=Rel",
#        "head": 12,
#        "deprel": "nsubj",
#        "misc": "start_char=66|end_char=71",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "shows",
#        "lemma": "show",
#        "upos": "VERB",
#        "xpos": "VBZ",
#        "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#        "head": 9,
#        "deprel": "acl:relcl",
#        "misc": "start_char=72|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 14,
#        "deprel": "det",
#        "misc": "start_char=78|end_char=81",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "vulnerability",
#        "lemma": "vulnerability",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 12,
#        "deprel": "obj",
#        "misc": "start_char=82|end_char=95",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "of",
#        "lemma": "of",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 16,
#        "deprel": "case",
#        "misc": "start_char=96|end_char=98",
#        "ner": "O"
#      },
#      {
#        "id": 16,
#        "text": "refugees",
#        "lemma": "refuge",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 14,
#        "deprel": "nmod",
#        "misc": "start_char=99|end_char=107",
#        "ner": "O"
#      },
#      {
#        "id": 17,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 19,
#        "deprel": "case",
#        "misc": "start_char=108|end_char=110",
#        "ner": "O"
#      },
#      {
#        "id": 18,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 19,
#        "deprel": "det",
#        "misc": "start_char=111|end_char=114",
#        "ner": "O"
#      },
#      {
#        "id": 19,
#        "text": "country",
#        "lemma": "country",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 16,
#        "deprel": "nmod",
#        "misc": "start_char=115|end_char=122",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 24,
#        "deprel": "punct",
#        "misc": "start_char=122|end_char=123",
#        "ner": "O"
#      },
#      {
#        "id": 21,
#        "text": "many",
#        "lemma": "many",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 24,
#        "deprel": "nsubj",
#        "misc": "start_char=124|end_char=128",
#        "ner": "O"
#      },
#      {
#        "id": 22,
#        "text": "of",
#        "lemma": "of",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 23,
#        "deprel": "case",
#        "misc": "start_char=129|end_char=131",
#        "ner": "O"
#      },
#      {
#        "id": 23,
#        "text": "whom",
#        "lemma": "whom",
#        "upos": "PRON",
#        "xpos": "WP",
#        "feats": "PronType=Int",
#        "head": 21,
#        "deprel": "obl",
#        "misc": "start_char=132|end_char=136",
#        "ner": "O"
#      },
#      {
#        "id": 24,
#        "text": "live",
#        "lemma": "live",
#        "upos": "VERB",
#        "xpos": "VBP",
#        "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=137|end_char=141",
#        "ner": "O"
#      },
#      {
#        "id": 25,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 29,
#        "deprel": "case",
#        "misc": "start_char=142|end_char=144",
#        "ner": "O"
#      },
#      {
#        "id": 26,
#        "text": "crowded",
#        "lemma": "crowded",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 29,
#        "deprel": "amod",
#        "misc": "start_char=145|end_char=152",
#        "ner": "O"
#      },
#      {
#        "id": 27,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 29,
#        "deprel": "punct",
#        "misc": "start_char=152|end_char=153",
#        "ner": "O"
#      },
#      {
#        "id": 28,
#        "text": "poor",
#        "lemma": "poor",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 29,
#        "deprel": "amod",
#        "misc": "start_char=154|end_char=158",
#        "ner": "O"
#      },
#      {
#        "id": 29,
#        "text": "conditions",
#        "lemma": "condition",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 24,
#        "deprel": "obl",
#        "misc": "start_char=159|end_char=169",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "a",
#        "lemma": "a",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Ind|PronType=Art",
#        "head": 3,
#        "deprel": "det",
#        "misc": "start_char=0|end_char=1",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "lovely",
#        "lemma": "lovely",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 3,
#        "deprel": "amod",
#        "misc": "start_char=2|end_char=8",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "way\\n\\nthe",
#        "lemma": "way\\n\\nthe",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=9|end_char=19",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "week\\n\\ninspiring",
#        "lemma": "weekununspire",
#        "upos": "VERB",
#        "xpos": "VBG",
#        "feats": "VerbForm=Ger",
#        "head": 3,
#        "deprel": "acl",
#        "misc": "start_char=20|end_char=37",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "art\\n\\nthe",
#        "lemma": "art\\n\\nthe",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 7,
#        "deprel": "amod",
#        "misc": "start_char=38|end_char=48",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "beautiful",
#        "lemma": "beautiful",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 7,
#        "deprel": "amod",
#        "misc": "start_char=49|end_char=58",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "creations",
#        "lemma": "creation",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 4,
#        "deprel": "obj",
#        "misc": "start_char=59|end_char=68",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "\\n\\nyoung",
#        "lemma": "\\n\\nyoung",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=68|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "people\\n\\nlebanon",
#        "lemma": "people\\n\\nlebanon",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 7,
#        "deprel": "appos",
#        "misc": "start_char=78|end_char=95",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "who",
#        "lemma": "who",
#        "upos": "PRON",
#        "xpos": "WP",
#        "feats": "PronType=Rel",
#        "head": 12,
#        "deprel": "nsubj",
#        "misc": "start_char=96|end_char=99",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "are",
#        "lemma": "be",
#        "upos": "AUX",
#        "xpos": "VBP",
#        "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#        "head": 12,
#        "deprel": "aux",
#        "misc": "start_char=100|end_char=103",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "proving",
#        "lemma": "prove",
#        "upos": "VERB",
#        "xpos": "VBG",
#        "feats": "Tense=Pres|VerbForm=Part",
#        "head": 9,
#        "deprel": "acl:relcl",
#        "misc": "start_char=104|end_char=111",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 16,
#        "deprel": "case",
#        "misc": "start_char=112|end_char=114",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "their",
#        "lemma": "they",
#        "upos": "PRON",
#        "xpos": "PRP$",
#        "feats": "Number=Plur|Person=3|Poss=Yes|PronType=Prs",
#        "head": 16,
#        "deprel": "nmod:poss",
#        "misc": "start_char=115|end_char=120",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "own",
#        "lemma": "own",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 16,
#        "deprel": "amod",
#        "misc": "start_char=121|end_char=124",
#        "ner": "O"
#      },
#      {
#        "id": 16,
#        "text": "way",
#        "lemma": "way",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 12,
#        "deprel": "obl",
#        "misc": "start_char=125|end_char=128",
#        "ner": "O"
#      },
#      {
#        "id": 17,
#        "text": "that",
#        "lemma": "that",
#        "upos": "PRON",
#        "xpos": "WDT",
#        "feats": "PronType=Rel",
#        "head": 19,
#        "deprel": "obj",
#        "misc": "start_char=129|end_char=133",
#        "ner": "O"
#      },
#      {
#        "id": 18,
#        "text": "everyone",
#        "lemma": "everyone",
#        "upos": "PRON",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 19,
#        "deprel": "nsubj",
#        "misc": "start_char=134|end_char=142",
#        "ner": "O"
#      },
#      {
#        "id": 19,
#        "text": "counts",
#        "lemma": "count",
#        "upos": "VERB",
#        "xpos": "VBZ",
#        "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#        "head": 16,
#        "deprel": "acl:relcl",
#        "misc": "start_char=143|end_char=149",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 22,
#        "deprel": "case",
#        "misc": "start_char=150|end_char=152",
#        "ner": "O"
#      },
#      {
#        "id": 21,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 22,
#        "deprel": "det",
#        "misc": "start_char=153|end_char=156",
#        "ner": "O"
#      },
#      {
#        "id": 22,
#        "text": "fight",
#        "lemma": "fight",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 19,
#        "deprel": "obl",
#        "misc": "start_char=157|end_char=162",
#        "ner": "O"
#      },
#      {
#        "id": 23,
#        "text": "against",
#        "lemma": "against",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 24,
#        "deprel": "case",
#        "misc": "start_char=163|end_char=170",
#        "ner": "O"
#      },
#      {
#        "id": 24,
#        "text": "covid",
#        "lemma": "covid",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 22,
#        "deprel": "nmod",
#        "misc": "start_char=171|end_char=176",
#        "ner": "O"
#      },
#      {
#        "id": 25,
#        "text": "19",
#        "lemma": "19",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 24,
#        "deprel": "nummod",
#        "misc": "start_char=177|end_char=179",
#        "ner": "S-CARDINAL"
#      },
#      {
#        "id": 26,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 24,
#        "deprel": "punct",
#        "misc": "start_char=179|end_char=180",
#        "ner": "O"
#      },
#      {
#        "id": 27,
#        "text": "including",
#        "lemma": "include",
#        "upos": "VERB",
#        "xpos": "VBG",
#        "feats": "VerbForm=Ger",
#        "head": 28,
#        "deprel": "case",
#        "misc": "start_char=181|end_char=190",
#        "ner": "O"
#      },
#      {
#        "id": 28,
#        "text": "refugees\\n\\nyou\\n\\nyours",
#        "lemma": "refugees\\n\\nyou\\n\\nyours",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 24,
#        "deprel": "nmod",
#        "misc": "start_char=191|end_char=215",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "we\\n\\nthat",
#        "lemma": "we\\n\\nthat",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 2,
#        "deprel": "amod",
#        "misc": "start_char=0|end_char=10",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "people\\n\\npeople",
#        "lemma": "people\\n\\npeople",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 23,
#        "deprel": "nsubj",
#        "misc": "start_char=11|end_char=27",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 23,
#        "deprel": "punct",
#        "misc": "start_char=27|end_char=28",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "just",
#        "lemma": "just",
#        "upos": "ADV",
#        "xpos": "RB",
#        "head": 14,
#        "deprel": "advmod",
#        "misc": "start_char=29|end_char=33",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "as",
#        "lemma": "as",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 14,
#        "deprel": "case",
#        "misc": "start_char=34|end_char=36",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "modern",
#        "lemma": "modern",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 8,
#        "deprel": "amod",
#        "misc": "start_char=37|end_char=43",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "-",
#        "lemma": "-",
#        "upos": "PUNCT",
#        "xpos": "HYPH",
#        "head": 8,
#        "deprel": "punct",
#        "misc": "start_char=44|end_char=45",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "day",
#        "lemma": "day",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 14,
#        "deprel": "compound",
#        "misc": "start_char=46|end_char=49",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "lebanese\\n\\nphoenicians",
#        "lemma": "lebanese\\n\\nphoenicians",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 14,
#        "deprel": "amod",
#        "misc": "start_char=50|end_char=73",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 13,
#        "deprel": "cc",
#        "misc": "start_char=74|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "modern",
#        "lemma": "modern",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 13,
#        "deprel": "amod",
#        "misc": "start_char=78|end_char=84",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "-",
#        "lemma": "-",
#        "upos": "PUNCT",
#        "xpos": "HYPH",
#        "head": 13,
#        "deprel": "punct",
#        "misc": "start_char=85|end_char=86",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "day",
#        "lemma": "day",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "conj",
#        "misc": "start_char=87|end_char=90",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "iranians\\n\\npersians",
#        "lemma": "iraniansuansuansians",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 23,
#        "deprel": "obl",
#        "misc": "start_char=91|end_char=111",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "\\n\\nthe",
#        "lemma": "\\n\\nthe",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 17,
#        "deprel": "det",
#        "misc": "start_char=111|end_char=118",
#        "ner": "O"
#      },
#      {
#        "id": 16,
#        "text": "only",
#        "lemma": "only",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 17,
#        "deprel": "amod",
#        "misc": "start_char=119|end_char=123",
#        "ner": "O"
#      },
#      {
#        "id": 17,
#        "text": "difference",
#        "lemma": "difference",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 23,
#        "deprel": "nsubj",
#        "misc": "start_char=124|end_char=134",
#        "ner": "O"
#      },
#      {
#        "id": 18,
#        "text": "being",
#        "lemma": "be",
#        "upos": "AUX",
#        "xpos": "VBG",
#        "feats": "VerbForm=Ger",
#        "head": 19,
#        "deprel": "aux:pass",
#        "misc": "start_char=135|end_char=140",
#        "ner": "O"
#      },
#      {
#        "id": 19,
#        "text": "we\\n\\nour",
#        "lemma": "we\\n\\nour",
#        "upos": "VERB",
#        "xpos": "VBN",
#        "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#        "head": 17,
#        "deprel": "acl",
#        "misc": "start_char=141|end_char=150",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": "land",
#        "lemma": "land",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 19,
#        "deprel": "xcomp",
#        "misc": "start_char=151|end_char=155",
#        "ner": "O"
#      },
#      {
#        "id": 21,
#        "text": "for",
#        "lemma": "for",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 22,
#        "deprel": "case",
#        "misc": "start_char=156|end_char=159",
#        "ner": "O"
#      },
#      {
#        "id": 22,
#        "text": "generations\\n\\nthat",
#        "lemma": "generations\\n\\nthat",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 20,
#        "deprel": "nmod",
#        "misc": "start_char=160|end_char=179",
#        "ner": "O"
#      },
#      {
#        "id": 23,
#        "text": "doesn",
#        "lemma": "doesn",
#        "upos": "VERB",
#        "xpos": "VBZ",
#        "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=180|end_char=185",
#        "ner": "O"
#      },
#      {
#        "id": 24,
#        "text": "'",
#        "lemma": "'",
#        "upos": "PUNCT",
#        "xpos": "``",
#        "head": 23,
#        "deprel": "punct",
#        "misc": "start_char=185|end_char=186",
#        "ner": "O"
#      },
#      {
#        "id": 25,
#        "text": "t\\n\\nour",
#        "lemma": "t\\n\\nour",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 27,
#        "deprel": "amod",
#        "misc": "start_char=187|end_char=195",
#        "ner": "O"
#      },
#      {
#        "id": 26,
#        "text": "identity",
#        "lemma": "identity",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 27,
#        "deprel": "compound",
#        "misc": "start_char=196|end_char=204",
#        "ner": "O"
#      },
#      {
#        "id": 27,
#        "text": "one",
#        "lemma": "one",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 23,
#        "deprel": "obj",
#        "misc": "start_char=205|end_char=208",
#        "ner": "O"
#      },
#      {
#        "id": 28,
#        "text": "iota",
#        "lemma": "iota",
#        "upos": "PUNCT",
#        "xpos": "''",
#        "head": 23,
#        "deprel": "punct",
#        "misc": "start_char=209|end_char=213",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 3,
#        "deprel": "det",
#        "misc": "start_char=0|end_char=3",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "civil",
#        "lemma": "civil",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 3,
#        "deprel": "amod",
#        "misc": "start_char=4|end_char=9",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "war",
#        "lemma": "war",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 14,
#        "deprel": "nsubj",
#        "misc": "start_char=10|end_char=13",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 5,
#        "deprel": "case",
#        "misc": "start_char=14|end_char=16",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "lebanon\\n\\nthe",
#        "lemma": "lebanon\\n\\nthe",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 14,
#        "deprel": "nmod:poss",
#        "misc": "start_char=17|end_char=31",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "1",
#        "lemma": "1",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 5,
#        "deprel": "nummod",
#        "misc": "start_char=32|end_char=33",
#        "ner": "S-CARDINAL"
#      },
#      {
#        "id": 7,
#        "text": "9",
#        "lemma": "9",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 9,
#        "deprel": "compound",
#        "misc": "start_char=34|end_char=35",
#        "ner": "S-CARDINAL"
#      },
#      {
#        "id": 8,
#        "text": "7",
#        "lemma": "7",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 9,
#        "deprel": "compound",
#        "misc": "start_char=36|end_char=37",
#        "ner": "B-QUANTITY"
#      },
#      {
#        "id": 9,
#        "text": "0",
#        "lemma": "0",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 13,
#        "deprel": "nmod:poss",
#        "misc": "start_char=38|end_char=39",
#        "ner": "I-QUANTITY"
#      },
#      {
#        "id": 10,
#        "text": "s",
#        "lemma": "'s",
#        "upos": "PART",
#        "xpos": "POS",
#        "head": 9,
#        "deprel": "case",
#        "misc": "start_char=40|end_char=41",
#        "ner": "E-QUANTITY"
#      },
#      {
#        "id": 11,
#        "text": "typical",
#        "lemma": "typical",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 14,
#        "deprel": "amod",
#        "misc": "start_char=42|end_char=49",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "white",
#        "lemma": "white",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 13,
#        "deprel": "amod",
#        "misc": "start_char=50|end_char=55",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "person",
#        "lemma": "person",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 14,
#        "deprel": "compound",
#        "misc": "start_char=56|end_char=62",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "comment\\n\\n",
#        "lemma": "comment\\n\\n",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=63|end_char=74",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "(",
#        "lemma": "(",
#        "upos": "PUNCT",
#        "xpos": "-LRB-",
#        "head": 18,
#        "deprel": "punct",
#        "misc": "start_char=74|end_char=75",
#        "ner": "O"
#      },
#      {
#        "id": 16,
#        "text": "im",
#        "lemma": "be",
#        "upos": "AUX",
#        "xpos": "VBZ",
#        "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#        "head": 18,
#        "deprel": "aux:pass",
#        "misc": "start_char=75|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 17,
#        "text": "not",
#        "lemma": "not",
#        "upos": "PART",
#        "xpos": "RB",
#        "head": 18,
#        "deprel": "advmod",
#        "misc": "start_char=78|end_char=81",
#        "ner": "O"
#      },
#      {
#        "id": 18,
#        "text": "surprised",
#        "lemma": "surprise",
#        "upos": "VERB",
#        "xpos": "VBN",
#        "feats": "Tense=Past|VerbForm=Part",
#        "head": 14,
#        "deprel": "parataxis",
#        "misc": "start_char=82|end_char=91",
#        "ner": "O"
#      },
#      {
#        "id": 19,
#        "text": "just",
#        "lemma": "just",
#        "upos": "ADV",
#        "xpos": "RB",
#        "head": 20,
#        "deprel": "advmod",
#        "misc": "start_char=92|end_char=96",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": "shocked",
#        "lemma": "shocked",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 18,
#        "deprel": "xcomp",
#        "misc": "start_char=97|end_char=104",
#        "ner": "O"
#      },
#      {
#        "id": 21,
#        "text": ")",
#        "lemma": ")",
#        "upos": "PUNCT",
#        "xpos": "-RRB-",
#        "head": 18,
#        "deprel": "punct",
#        "misc": "start_char=104|end_char=105",
#        "ner": "O"
#      },
#      {
#        "id": 22,
#        "text": "\\",
#        "lemma": "\"",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 27,
#        "deprel": "punct",
#        "misc": "start_char=105|end_char=106",
#        "ner": "O"
#      },
#      {
#        "id": 23,
#        "text": "n\\nan",
#        "lemma": "n\\nan",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 27,
#        "deprel": "amod",
#        "misc": "start_char=106|end_char=111",
#        "ner": "O"
#      },
#      {
#        "id": 24,
#        "text": "australian",
#        "lemma": "australian",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 25,
#        "deprel": "amod",
#        "misc": "start_char=112|end_char=122",
#        "ner": "O"
#      },
#      {
#        "id": 25,
#        "text": "reporter\\n\\nthe",
#        "lemma": "reporter\\n\\nthe",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 27,
#        "deprel": "compound",
#        "misc": "start_char=123|end_char=138",
#        "ner": "O"
#      },
#      {
#        "id": 26,
#        "text": "strong",
#        "lemma": "strong",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 27,
#        "deprel": "amod",
#        "misc": "start_char=139|end_char=145",
#        "ner": "O"
#      },
#      {
#        "id": 27,
#        "text": "prescence",
#        "lemma": "prescence",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 14,
#        "deprel": "appos",
#        "misc": "start_char=146|end_char=155",
#        "ner": "O"
#      },
#      {
#        "id": 28,
#        "text": "of",
#        "lemma": "of",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 34,
#        "deprel": "case",
#        "misc": "start_char=156|end_char=158",
#        "ner": "O"
#      },
#      {
#        "id": 29,
#        "text": "lebanese",
#        "lemma": "lebanese",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 34,
#        "deprel": "amod",
#        "misc": "start_char=159|end_char=167",
#        "ner": "S-NORP"
#      },
#      {
#        "id": 30,
#        "text": "migrant",
#        "lemma": "migrant",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 34,
#        "deprel": "amod",
#        "misc": "start_char=168|end_char=175",
#        "ner": "O"
#      },
#      {
#        "id": 31,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 32,
#        "deprel": "cc",
#        "misc": "start_char=176|end_char=179",
#        "ner": "O"
#      },
#      {
#        "id": 32,
#        "text": "australian",
#        "lemma": "australian",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 30,
#        "deprel": "conj",
#        "misc": "start_char=180|end_char=190",
#        "ner": "O"
#      },
#      {
#        "id": 33,
#        "text": "born",
#        "lemma": "bear",
#        "upos": "VERB",
#        "xpos": "VBN",
#        "feats": "Tense=Past|VerbForm=Part",
#        "head": 34,
#        "deprel": "amod",
#        "misc": "start_char=191|end_char=195",
#        "ner": "O"
#      },
#      {
#        "id": 34,
#        "text": "citizens",
#        "lemma": "citizen",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 27,
#        "deprel": "nmod",
#        "misc": "start_char=196|end_char=204",
#        "ner": "O"
#      },
#      {
#        "id": 35,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 37,
#        "deprel": "case",
#        "misc": "start_char=205|end_char=207",
#        "ner": "O"
#      },
#      {
#        "id": 36,
#        "text": "this",
#        "lemma": "this",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Number=Sing|PronType=Dem",
#        "head": 37,
#        "deprel": "det",
#        "misc": "start_char=208|end_char=212",
#        "ner": "O"
#      },
#      {
#        "id": 37,
#        "text": "country",
#        "lemma": "country",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 34,
#        "deprel": "nmod",
#        "misc": "start_char=213|end_char=220",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "i\\n\\nthat\\n\\nprimary",
#        "lemma": "i\\n\\nthat\\n\\nprimary",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 5,
#        "deprel": "compound",
#        "misc": "start_char=0|end_char=20",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "/",
#        "lemma": "/",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=21|end_char=22",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "high",
#        "lemma": "high",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 4,
#        "deprel": "amod",
#        "misc": "start_char=23|end_char=27",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "school",
#        "lemma": "school",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 5,
#        "deprel": "compound",
#        "misc": "start_char=28|end_char=34",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "kids\\n\\nlebanese",
#        "lemma": "kids\\n\\nlebanese",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=35|end_char=51",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "/",
#        "lemma": "/",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 7,
#        "deprel": "punct",
#        "misc": "start_char=52|end_char=53",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "italian\\n\\nimmigrants",
#        "lemma": "italianqnummigrants",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 5,
#        "deprel": "conj",
#        "misc": "start_char=54|end_char=75",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "\\n\\",
#        "lemma": "\\n\\",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 13,
#        "deprel": "case",
#        "misc": "start_char=75|end_char=78",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "n80",
#        "lemma": "n80",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 13,
#        "deprel": "nummod",
#        "misc": "start_char=78|end_char=81",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "to",
#        "lemma": "to",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 11,
#        "deprel": "case",
#        "misc": "start_char=82|end_char=84",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "100",
#        "lemma": "100",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 9,
#        "deprel": "nmod",
#        "misc": "start_char=85|end_char=88",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "years\\n\\nit\\n\\nlebanese\\n\\na",
#        "lemma": "years\\n\\nit\\n\\nlebanese\\n\\na",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 13,
#        "deprel": "amod",
#        "misc": "start_char=89|end_char=117",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "number\\n\\ni",
#        "lemma": "number\\n\\ni",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 7,
#        "deprel": "nmod",
#        "misc": "start_char=118|end_char=129",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "confinement",
#        "lemma": "confinement",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 4,
#        "deprel": "compound",
#        "misc": "start_char=0|end_char=11",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "measures\\n\\nmental",
#        "lemma": "measures\\n\\nmental",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 4,
#        "deprel": "amod",
#        "misc": "start_char=12|end_char=30",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "health",
#        "lemma": "health",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 4,
#        "deprel": "compound",
#        "misc": "start_char=31|end_char=37",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "issues\\n\\nthey\\n\\nlebanons",
#        "lemma": "issuesunutheyuns",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=38|end_char=64",
#        "ner": "O"
#      }
#    ],
#    [
#      {
#        "id": 1,
#        "text": "refugee",
#        "lemma": "refugee",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=65|end_char=72",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "population\\n\\nsyrians\\n\\nlebanon\\n\\nsafety\\n\\nit\\n\\nall",
#        "lemma": "population\\n\\nsyrians\\n\\nlebanon\\n\\nsafety\\n\\nit\\n\\nall",
#        "upos": "X",
#        "xpos": "ADD",
#        "head": 1,
#        "deprel": "list",
#        "misc": "start_char=73|end_char=128",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "mrs\\n\\na",
#        "lemma": "mrs\\n\\na",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Ind|PronType=Art",
#        "head": 2,
#        "deprel": "det",
#        "misc": "start_char=0|end_char=8",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "lot",
#        "lemma": "lot",
#        "upos": "NOUN",
#        "xpos": "NN",
# ...
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 20,
#        "deprel": "amod",
#        "misc": "start_char=156|end_char=180",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": "leaders\\n\\nthose",
#        "lemma": "leaders\\n\\nthose",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 12,
#        "deprel": "obl",
#        "misc": "start_char=181|end_char=197",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 2,
#        "deprel": "det",
#        "misc": "start_char=0|end_char=3",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "palestinians",
#        "lemma": "palestinians",
#        "upos": "PROPN",
#        "xpos": "NNPS",
#        "feats": "Number=Plur",
#        "head": 4,
#        "deprel": "nsubj",
#        "misc": "start_char=4|end_char=16",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "\\n\\nrefugees\\n\\ndire",
#        "lemma": "\\n\\nrefugees\\n\\ndire",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 4,
#        "deprel": "amod",
#        "misc": "start_char=16|end_char=36",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "straits",
#        "lemma": "strait",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=37|end_char=44",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 6,
#        "deprel": "cc",
#        "misc": "start_char=45|end_char=48",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "penniless",
#        "lemma": "penniless",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 4,
#        "deprel": "conj",
#        "misc": "start_char=49|end_char=58",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": ".",
#        "lemma": ".",
#        "upos": "PUNCT",
#        "xpos": ".",
#        "head": 4,
#        "deprel": "punct",
#        "misc": "start_char=59|end_char=60",
#        "ner": "O"
#      }
#    ],
#    [
#      {
#        "id": 1,
#        "text": ".",
#        "lemma": ".",
#        "upos": "PUNCT",
#        "xpos": ".",
#        "head": 2,
#        "deprel": "punct",
#        "misc": "start_char=61|end_char=62",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": ".\\n\\n",
#        "lemma": ".sn",
#        "upos": "VERB",
#        "xpos": "VB",
#        "feats": "Mood=Imp|VerbForm=Fin",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=63|end_char=68",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 5,
#        "deprel": "det",
#        "misc": "start_char=68|end_char=71",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "arab",
#        "lemma": "arab",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 5,
#        "deprel": "amod",
#        "misc": "start_char=72|end_char=76",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "states",
#        "lemma": "state",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 2,
#        "deprel": "obj",
#        "misc": "start_char=77|end_char=83",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 8,
#        "deprel": "punct",
#        "misc": "start_char=83|end_char=84",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 8,
#        "deprel": "cc",
#        "misc": "start_char=85|end_char=88",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "lebanon",
#        "lemma": "lebanon",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 5,
#        "deprel": "conj",
#        "misc": "start_char=89|end_char=96",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "amongst",
#        "lemma": "amongst",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 10,
#        "deprel": "case",
#        "misc": "start_char=97|end_char=104",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "them",
#        "lemma": "they",
#        "upos": "PRON",
#        "xpos": "PRP",
#        "feats": "Case=Acc|Number=Plur|Person=3|PronType=Prs",
#        "head": 8,
#        "deprel": "nmod",
#        "misc": "start_char=105|end_char=109",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 2,
#        "deprel": "punct",
#        "misc": "start_char=109|end_char=110",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "\\n\\nit\\n\\n",
#        "lemma": "\\n\\nit\\n\\n",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 2,
#        "deprel": "parataxis",
#        "misc": "start_char=110|end_char=120",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "\"",
#        "lemma": "\"",
#        "upos": "PUNCT",
#        "xpos": "``",
#        "head": 20,
#        "deprel": "punct",
#        "misc": "start_char=120|end_char=121",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 20,
#        "deprel": "det",
#        "misc": "start_char=122|end_char=125",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "beirut",
#        "lemma": "beirut",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 20,
#        "deprel": "compound",
#        "misc": "start_char=126|end_char=132",
#        "ner": "O"
#      },
#      {
#        "id": 16,
#        "text": "muslim",
#        "lemma": "muslim",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 20,
#        "deprel": "amod",
#        "misc": "start_char=133|end_char=139",
#        "ner": "O"
#      },
#      {
#        "id": 17,
#        "text": "weekly",
#        "lemma": "weekly",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 20,
#        "deprel": "amod",
#        "misc": "start_char=140|end_char=146",
#        "ner": "O"
#      },
#      {
#        "id": 18,
#        "text": "kul",
#        "lemma": "kul",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 20,
#        "deprel": "compound",
#        "misc": "start_char=147|end_char=150",
#        "ner": "O"
#      },
#      {
#        "id": 19,
#        "text": "-",
#        "lemma": "-",
#        "upos": "PUNCT",
#        "xpos": "HYPH",
#        "head": 20,
#        "deprel": "punct",
#        "misc": "start_char=151|end_char=152",
#        "ner": "O"
#      },
#      {
#        "id": 20,
#        "text": "shay",
#        "lemma": "shay",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 12,
#        "deprel": "obl",
#        "misc": "start_char=153|end_char=157",
#        "ner": "O"
#      },
#      {
#        "id": 21,
#        "text": ",",
#        "lemma": ",",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 20,
#        "deprel": "punct",
#        "misc": "start_char=157|end_char=158",
#        "ner": "O"
#      },
#      {
#        "id": 22,
#        "text": "aug",
#        "lemma": "aug",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 20,
#        "deprel": "appos",
#        "misc": "start_char=159|end_char=162",
#        "ner": "O"
#      },
#      {
#        "id": 23,
#        "text": ".\\n\\n19\\n\\n1951",
#        "lemma": ".\\n\\n19\\n\\n1951",
#        "upos": "NUM",
#        "xpos": "CD",
#        "feats": "NumType=Card",
#        "head": 20,
#        "deprel": "appos",
#        "misc": "start_char=163|end_char=178",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "lebanese",
#        "lemma": "lebanese",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 3,
#        "deprel": "amod",
#        "misc": "start_char=0|end_char=8",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "government\\n\\nend",
#        "lemma": "government\\n\\nend",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 3,
#        "deprel": "compound",
#        "misc": "start_char=9|end_char=26",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "kafala\\n\\njustice",
#        "lemma": "kafala\\n\\njustice",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=27|end_char=44",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 5,
#        "deprel": "cc",
#        "misc": "start_char=45|end_char=48",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "dignity",
#        "lemma": "dignity",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 3,
#        "deprel": "conj",
#        "misc": "start_char=49|end_char=56",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "for",
#        "lemma": "for",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 9,
#        "deprel": "case",
#        "misc": "start_char=57|end_char=60",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "migrant",
#        "lemma": "migrant",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=61|end_char=68",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "domestic",
#        "lemma": "domestic",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=69|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "workers",
#        "lemma": "worker",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 3,
#        "deprel": "nmod",
#        "misc": "start_char=78|end_char=85",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 11,
#        "deprel": "case",
#        "misc": "start_char=86|end_char=88",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "lebanon",
#        "lemma": "lebanon",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "nmod",
#        "misc": "start_char=89|end_char=96",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "-",
#        "lemma": "-",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=97|end_char=98",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "sign",
#        "lemma": "sign",
#        "upos": "VERB",
#        "xpos": "VB",
#        "feats": "Mood=Imp|VerbForm=Fin",
#        "head": 3,
#        "deprel": "parataxis",
#        "misc": "start_char=99|end_char=103",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 15,
#        "deprel": "det",
#        "misc": "start_char=104|end_char=107",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "petition\\n\\nchange",
#        "lemma": "petition\\n\\nchange",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 13,
#        "deprel": "obj",
#        "misc": "start_char=108|end_char=126",
#        "ner": "O"
#      }
#    ]
#  ],
#  [
#    [
#      {
#        "id": 1,
#        "text": "lebanese",
#        "lemma": "lebanese",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 3,
#        "deprel": "amod",
#        "misc": "start_char=0|end_char=8",
#        "ner": "O"
#      },
#      {
#        "id": 2,
#        "text": "government\\n\\nend",
#        "lemma": "government\\n\\nend",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 3,
#        "deprel": "compound",
#        "misc": "start_char=9|end_char=26",
#        "ner": "O"
#      },
#      {
#        "id": 3,
#        "text": "kafala\\n\\njustice",
#        "lemma": "kafala\\n\\njustice",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 0,
#        "deprel": "root",
#        "misc": "start_char=27|end_char=44",
#        "ner": "O"
#      },
#      {
#        "id": 4,
#        "text": "and",
#        "lemma": "and",
#        "upos": "CCONJ",
#        "xpos": "CC",
#        "head": 5,
#        "deprel": "cc",
#        "misc": "start_char=45|end_char=48",
#        "ner": "O"
#      },
#      {
#        "id": 5,
#        "text": "dignity",
#        "lemma": "dignity",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 3,
#        "deprel": "conj",
#        "misc": "start_char=49|end_char=56",
#        "ner": "O"
#      },
#      {
#        "id": 6,
#        "text": "for",
#        "lemma": "for",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 9,
#        "deprel": "case",
#        "misc": "start_char=57|end_char=60",
#        "ner": "O"
#      },
#      {
#        "id": 7,
#        "text": "migrant",
#        "lemma": "migrant",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=61|end_char=68",
#        "ner": "O"
#      },
#      {
#        "id": 8,
#        "text": "domestic",
#        "lemma": "domestic",
#        "upos": "ADJ",
#        "xpos": "JJ",
#        "feats": "Degree=Pos",
#        "head": 9,
#        "deprel": "amod",
#        "misc": "start_char=69|end_char=77",
#        "ner": "O"
#      },
#      {
#        "id": 9,
#        "text": "workers",
#        "lemma": "worker",
#        "upos": "NOUN",
#        "xpos": "NNS",
#        "feats": "Number=Plur",
#        "head": 3,
#        "deprel": "nmod",
#        "misc": "start_char=78|end_char=85",
#        "ner": "O"
#      },
#      {
#        "id": 10,
#        "text": "in",
#        "lemma": "in",
#        "upos": "ADP",
#        "xpos": "IN",
#        "head": 11,
#        "deprel": "case",
#        "misc": "start_char=86|end_char=88",
#        "ner": "O"
#      },
#      {
#        "id": 11,
#        "text": "lebanon",
#        "lemma": "lebanon",
#        "upos": "PROPN",
#        "xpos": "NNP",
#        "feats": "Number=Sing",
#        "head": 9,
#        "deprel": "nmod",
#        "misc": "start_char=89|end_char=96",
#        "ner": "O"
#      },
#      {
#        "id": 12,
#        "text": "-",
#        "lemma": "-",
#        "upos": "PUNCT",
#        "xpos": ",",
#        "head": 3,
#        "deprel": "punct",
#        "misc": "start_char=97|end_char=98",
#        "ner": "O"
#      },
#      {
#        "id": 13,
#        "text": "sign",
#        "lemma": "sign",
#        "upos": "VERB",
#        "xpos": "VB",
#        "feats": "Mood=Imp|VerbForm=Fin",
#        "head": 3,
#        "deprel": "parataxis",
#        "misc": "start_char=99|end_char=103",
#        "ner": "O"
#      },
#      {
#        "id": 14,
#        "text": "the",
#        "lemma": "the",
#        "upos": "DET",
#        "xpos": "DT",
#        "feats": "Definite=Def|PronType=Art",
#        "head": 15,
#        "deprel": "det",
#        "misc": "start_char=104|end_char=107",
#        "ner": "O"
#      },
#      {
#        "id": 15,
#        "text": "petition",
#        "lemma": "petition",
#        "upos": "NOUN",
#        "xpos": "NN",
#        "feats": "Number=Sing",
#        "head": 13,
#        "deprel": "obj",
#        "misc": "start_char=108|end_char=116",
#        "ner": "O"
#      }
#    ]
#  ]]

# %%
def get_cand_heads(tagged_cands):
    # each candidate will be stored as [(set_of_phrases_heads), cand_rep_head] 
    return [[set([cand.words[word.head-1].text for word in cand.words]), 
             [word.text for word in cand.words if word.head == 0]] #the root of NP has value 0 
             for cand in tagged_cands.sentences]


np_cand_heads = [get_cand_heads(tweet_cands) for tweet_cands in tagged_np_cands]
print(np_cand_heads)

#[print(tagged_np_cand.text) for tagged_np_cand in tagged_np_cands]
# Out:
# [[[{'i\\n\\nall', 'books\\n\\nprofessor\\n\\nyou\\n\\nilili\\n\\nthis'}, ['i\\n\\nall']], [{'tweet\\n\\nso'}, ['tweet\\n\\nso']], [{'skin', 'game', 'non', 'a7zab', 'confidence\\n\\nwe\\n\\nthis\\n\\nwe\\n\\njerusalem'}, ['confidence\\n\\nwe\\n\\nthis\\n\\nwe\\n\\njerusalem']]], [[{'blood', 'pumping', 'skin'}, ['blood']]], [[{'racism\\n\\nkafala', 'forget', 'workers'}, ['workers']]], [[{'shows', 'live', 'vulnerability', 'country', 'whom', 'many', 'conditions', 'refugees', 'coronavirus'}, ['live']]], [[{'covid', 'way', 'fight', 'creations', 'refugees\\n\\nyou\\n\\nyours', 'proving', 'counts', 'week\\n\\ninspiring', 'people\\n\\nlebanon', 'way\\n\\nthe'}, ['way\\n\\nthe']]], [[{'generations\\n\\nthat', 'land', 'people\\n\\npeople', 'iota', 'iranians\\n\\npersians', 'day', 'difference', 'we\\n\\nour', 'lebanese\\n\\nphoenicians', 'one', 'doesn'}, ['doesn']]], [[{'war', 'person', 'lebanon\\n\\nthe', 'surprised', '0', 'prescence', 'migrant', 'australian', 'country', 'comment\\n\\n', 'reporter\\n\\nthe', 'citizens', 'shocked'}, ['comment\\n\\n']]], [[{'number\\n\\ni', 'high', 'italian\\n\\nimmigrants', '100', 'n80', 'school', 'kids\\n\\nlebanese'}, ['kids\\n\\nlebanese']]], [[{'issues\\n\\nthey\\n\\nlebanons'}, ['issues\\n\\nthey\\n\\nlebanons']], [{'population\\n\\nsyrians\\n\\nlebanon\\n\\nsafety\\n\\nit\\n\\nall', 'refugee'}, ['refugee']]], [[{'israel', 'crime\\n\\nall', 'proposed', 'live', 'ask', 'lot', 'visit\\n\\nisrael', '\\n\\nthe', 'schemes', 'arabs', 'material', 'talk\\n\\nthe'}, ['ask']]], [[{'call', '\\n\\ndiscussions', 'idc', 'too\\n\\nyour', 'workers', 'lebanon', 'systems', 'uae', 'nationality', 'slavery'}, ['call']]], [[{'subject', 'palestinians', ')', 'yemenis', 'poorer', 'jordan\\n\\nturkey', 'bias\\n\\nline', 'money', 'brothers', 'ignoring', 'aid\\n\\npower', 'killing', 'millions', 'allowing', 'refugees'}, ['aid\\n\\npower']]], [[{'consent', 'migrants', 'downturn', 'covid', 'at', 'country', 'employers', 'working', 'as', 'country\\n\\nhome'}, ['migrants']]], [[{'pre', '1,172\\n\\ncases\\n\\n16', 'deaths', 'refugees'}, ['pre']]], [[{'cross\\n\\ngeneva\\n\\nmr\\n\\nmatthew\\n\\nme\\n\\ni\\n\\na', 'mr'}, ['mr']], [{'cross\\n\\nyou', 'refugee'}, ['refugee']]], [[{'audacity', 'understand', 'countries', 'system', 'abuse', 'n\\nkafala\\n\\n3', 'pain', 'think', 'record', 'workers', 'slavery'}, ['audacity']]], [[{'camps', 'jordan\\n\\nurgent', 'supplies', 'equipment', 'departments', 'building', 'strip', 'lebanon', 'communities', 'bank', 'hospitals\\n\\nthem\\n\\nfood'}, ['bank']]], [[{'archaeology', 'populations'}, ['archaeology']]], [[{'possibility', 'deportation\\n\\nthey\\n\\ncases', 'refugees\\n\\nracism', 'covid', 'harassment', 'collapse', '19\\n\\nrefugeespartner\\n\\nthe', 'plight', 'coronavirus'}, ['refugees\\n\\nracism']]], [[{'cutting', 'immigrants', 'examples', 'grandfather', 'communities', 'i', 'store\\n\\none', 'aftermath', 'neighborhoods', 'son'}, ['examples']]], [[{'grandfather\\n\\nfascism\\n\\nww2\\n\\nhe\\n\\na'}, ['grandfather\\n\\nfascism\\n\\nww2\\n\\nhe\\n\\na']], [{'st', 'immigrants', 'born', 'generation'}, ['born']]], [[{'killed', 'convention\\n\\npeople\\n\\nplaces', 'likely', 'tortured', 'denied', 'immigrant\\n\\na'}, ['denied']]], [[{'you\\n\\nt\\n\\nanything\\n\\ncanadian'}, ['you\\n\\nt\\n\\nanything\\n\\ncanadian']], [{'lebanon\\n\\nyou\\n\\ncanada', 'practices', 'refugee', 'anti'}, ['refugee']]], [[{'war', '11\\n\\nit', 'ravaged', 'woman', 'country', 'saw', 'man', '.\\n\\ni\\n\\nracist', 'life\\n\\n9', 'son'}, ['son']]], [[{'perhaps', 'say', 'help', 'disaster', 'france\\n\\nthere\\n\\nno', 'uk\\n\\nall', 'question', 'housing', 'ireland', 'millions', 'could', 'survivors', 'case', 'refugees'}, ['case']]], [[{'saying', 'irony', 'immigrant'}, ['irony']]], [[{'research', 'covid', 'summary', 'stay', 'english', 'pandemic', 'cant\\n\\nhome', 'refugees'}, ['refugees']]], [[{'hide', 'experience\\n\\nthis\\n\\nan', 'loser', 'leg', 'minister', '\\n\\npeople\\n\\nthis\\n\\nyou\\n\\n'}, ['minister']]], [[{'se ...

# %% [markdown]
# ## 8. We define candidate types

# %%
#dictionary to assign candidate types based on named entities and part of speech tags
#the key tuple consists of (isNE, lexicographer type, plural)
cand_types_dict = {(True,'PERSON',None):'person-ne',
              (True,'NORP',None):'person-ne',
              (True,'PERSON','plural'):'person-nes',
              (True,'NORP','plural'):'person-nes',
              (False,'PERSON',None):'person-nn',
              (False,'PERSON','plural'):'person-nns',
              (True,'ORG',None):'group-ne',
              (True,'FAC',None):'group-ne',
              (False,'ORG',None):'group',
              (True,'LOC',None):'loc-ne',
              (True,'GPE',None):'loc-ne',
              (False, 'LOC',None):'loc'
            }

# %%
from collections import Counter

#test syntactic categories on all heads of noun phrases
list_of_cand_types = [cand_prep.get_synt_category(cand[1][0]) for tweet_cands in np_cand_heads for cand in tweet_cands]
    
count_types = Counter(list_of_cand_types)
print(count_types)
# Out:
# Counter({None: 1064, 'PERSON': 162, 'ORG': 134, 'LOC': 74})

# %% [markdown]
# ## 9. We assign candidate types to noun phrase candidates

# %%
# label the noun phrases with the candidate types
print(noun_phrase_list)

np_and_cand_list = cand_prep.get_cand_type(noun_phrase_list,np_cand_heads, tweet_tags, cand_types_dict)
print(np_and_cand_list)
# Out:
#   8%|██████                                                                          | 15/200 [00:00<00:01, 141.51it/s]
# [['it', 'asylum in greece, mac, ser or cro or bul', '3 eu members', 'hu', 'they', 'help', 'the first safe country as asylum seeker', 'the 5', 'no law', 'you', 'it'], ['isis refuge .', "wouldn' t", 'turkey', 'i', "you' re likely to get your head", 'the beaten track', 'christian greece', 'a similar climate', 'islamic turkey'], ['greece', 'refugee overcrowding', 'un'], ['1 / 3', 'law', 'the idle stuff', 'all rights of the turkish minority in greece', 'the law', 'refugees', 'the eu', 'the law', 'western states', 'the states', 'the middle east and africa', 'underground resources', 'the law'], ['the asylum seekers', 'hu borders', 'they', 'a long journey', 'greece', 'they', 'help', 'they', 'multiple more countries'], ['i', 'photo gr apy', 'aesthetic', 'news', 'it', 'a potential embellishments of hard facts and harsh reality', 'i', 'raw realism', 'i', 'this boundary using filmicpro first light this week in lesbos infamous moria migrants camp', 'a big question4me'], ['manfredweber', 'it', 'europe and germany', 'the side of greece', 'the german mfa', 'fear of a new refugee crisis'], ["refugee covid case sparks' closed camps' fears on lesbos"], ['9pm coronavirus uk', 'leeds', 'brink of lockdown, outbreak at asylum seeker hostel in birmingham and greece chaos stories from 2 sources birmingham'], ["you' re", 'france and not turkey', 'parts of syria', 'bombs iraq', 'a proxy war in libya', 'refugees', 'top of that', 'it', "greece' s and cyprus' sovereignties", 'it', 'safe heaven for hamas'], ['raquel bessudo', 'isaac bessudos widow', 'the bessudos', 'sephardic jewish immigrants from salonica, greece', 'raquels parents', 'polish jews', 'raquel'], ['most of them', 'greece', 'their will'], ['you', 'they', 'turkey', 'you', 'it', 'you', 'it', 'your women', 'they', 'asylum', 'greece', 'your army and people', 'turkey', 'siktir'], ['five years later: how september 5th, 2015, became a crossroads for the migration crisis - - budapest'], ['record numbers of illegal migrants', 'the united states', 'the united kingdom', 'greece', 'the border', 'control', 'it', 'me', 'this', 'part of the new normal'], ['refugee virus cases', 'fears in lesbos'], ['illegal immigration', 'a problem of greece or europe'], ['severe claustrophobia', 'his entire life', 'both men', 'losers', 'they', 'it', 'their fathers', 'america', 'them', 'immigrants from greece', '1914', 'the trump family', 'military boots'], ['greece', '10 refugees, including three children with disabilities', 'those refugees', 'erdogan', 'greece', 'european union values', 'coe europarl_en', 'vonderleyen nachosamor hrw', 'tr724 araclyla'], ['two high ranking un refugee agency officials on friday', 'a visit', 'greece', 'a drastic improvement in the living conditions of refugees in camps', 'anadolu agency', 'unhcrs assistant high commissioners for protection and o .\xa0.\xa0.'], ['un', 'greece', 'refugeeovercrowding'], ['switzerland?', 'i', 'its more likely', 'the balkans', 'greece', 'a bunch of illegal immigrants', 'the middle of the sea', 'the growing tension with turkey', 'a stronger, motivated govt', 'erdogans ersatz invaders'], ['the eu', 'illegal immigration', 'i', 't', 'the people of greece', 'that particular memo'], ['4 years', 'we', 'offered high - quality, trauma - sensitive, identity - informed pss & education support to child', 'youth refugees in northern greece', 'your help', 'we', 'this work for another 4 years', 'another 4 countries'], ["refugee covid case sparks' closed camps' fears on lesbos"], ['you', 'mass immigration', 'sweden, austria, norway, finland, denmark, greece, or pressure', 'poland, bulgaria, hungary, slovenia, serbia & other european countries', 'mass migration'], ['2018', 'the uk', 'applications', 'asylum', '37,453 people (including dependants)', 'this', 'germany (162,000), france (110,000), greece (65,000) and italy (49,000)'], ['enterprise greece', 'this effort', 'they', 'their many services and resources', 'the end of the year', 'their strategic partnership with ebay', 'greek  ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 126.18it/s]
# [[('it', 'it', {'it'}, 'misc'), ('asylum in greece, mac, ser or cro or bul', 'asylum', {'mac', 'asylum', 'greece', 'bul', 'cro', 'ser'}, 'group'), ('3 eu members', 'members', {'members'}, 'person-nes'), ('hu', 'hu', {'hu'}, 'misc'), ('they', 'they', {'they'}, 'misc'), ('help', 'help', {'help'}, 'person-nn'), ('the first safe country as asylum seeker', 'country', {'country', 'seeker'}, 'group-ne'), ('the 5', '5', {'5'}, 'misc'), ('no law', 'law', {'law'}, 'misc'), ('you', 'you', {'you'}, 'misc'), ('it', 'it', {'it'}, 'misc')], [('isis refuge .', 'refuge', {'refuge', '.'}, 'loc'), ("wouldn' t", 't', {'t'}, 'misc'), ('turkey', 'turkey', {'turkey'}, 'misc'), ('i', 'i', {'i'}, 'misc'), ("you' re likely to get your head", 'likely', {'likely', 'get', 'head'}, 'misc'), ('the beaten track', 'track', {'track'}, 'loc'), ('christian greece', 'greece', {'greece'}, 'misc'), ('a similar climate', 'climate', {'climate'}, 'misc'), ('islamic turkey', 'turkey', {'turkey'}, 'misc')], [('greece', 'greece', {'greece'}, 'misc'), ('refugee overcrowding', 'overcrowding', {'overcrowding'}, 'group'), ('un', 'un', {'un'}, 'group')], [('1 / 3', '3', {'3'}, 'misc'), ('law', 'law', {'law'}, 'misc'), ('the idle stuff', 'stuff', {'stuff'}, 'loc'), ('all rights of the turkish minority in greece', 'rights', {'minority', 'greece', 'rights'}, 'loc'), ('the law', 'law', {'law'}, 'misc'), ('refugees', 'refugees', {'refugees'}, 'person-nn'), ('the eu', 'eu', {'eu'}, 'group'), ('the law', 'law', {'law'}, 'misc'), ('western states', 'states', {'states'}, 'group'), ('the states', 'states', {'states'}, 'group'), ('the middle east and africa', 'east', {'east', 'africa'}, 'misc'), ('underground resources', 'resources', {'resources'}, 'misc'), ('the law', 'law', {'law'}, 'misc')], [('the asylum seekers', 'seekers', {'seekers'}, 'person-nns'), ('hu borders', 'borders', {'borders'}, 'misc'), ('they', 'they', {'they'}, 'misc'), ('a long journey', 'journey', {'journey'}, 'misc'), ('greece', 'greece', {'greece'}, 'misc'), ('they', 'they', {'they'}, 'misc'), ('help', 'help', {'help'}, 'person-nn'), ('they', 'they', {'they'}, 'misc'), ('multiple more countries', 'countries', {'countries'}, 'group')], [('i', 'i', {'i'}, 'person-nn'), ('photo gr apy', 'apy', {'gr', 'apy'}, 'misc'), ('aesthetic', 'aesthetic', {'aesthetic'}, 'misc'), ('news', 'news', {'news'}, 'misc'), ('it', 'it', {'it'}, 'misc'), ('a potential embellishments of hard facts and harsh reality', 'embellishments', {'facts', 'reality', 'embellishments'}, 'misc'), ('i', 'i', {'i'}, 'person-nn'), ('raw realism', 'realism', {'realism'}, 'misc'), ('i', 'i', {'i'}, 'person-nn'), ('this boundary using filmicpro first light this week in lesbos infamous moria migrants camp', 'boundary', {'using', 'migrants', 'week', 'boundary', 'camp', 'lesbos', 'light'}, 'loc-ne'), ('a big question4me', 'question4', {'me', 'question4'}, 'misc')], [('manfredweber', 'manfredweber', {'manfredweber'}, 'misc'), ('it', 'it', {'it'}, 'misc'), ('europe and germany', 'europe', {'europe', 'germany'}, 'misc'), ('the side of greece', 'side', {'greece', 'side'}, 'loc'), ('the german mfa', 'mfa', {'mfa'}, 'misc'), ('fear of a new refugee crisis', 'fear', {'fear', 'crisis'}, 'misc')], [("refugee covid case sparks' closed camps' fears on lesbos", 'sparks', {'camps', 'sparks', 'covid', 'fears', 'lesbos', 'case'}, 'misc')], [('9pm coronavirus uk', 'pm', {'pm', 'uk'}, 'misc'), ('leeds', 'leeds', {'leeds'}, 'misc'), ('brink of lockdown, outbreak at asylum seeker hostel in birmingham and greece chaos stories from 2 sources birmingham', 'brink', {'brink', 'birmingham', 'lockdown', 'sources', 'stories', 'outbreak', 'seeker', 'chaos', 'hostel'}, 'misc')], [("you' re", 'you', {'re', 'you'}, 'misc'), ('france and not turkey', 'france', {'turkey', 'france'}, 'misc'), ('parts of syria', 'parts', {'syria', 'parts'}, 'loc'), ('bombs iraq', 'bombs', {'iraq', 'bombs'}, 'misc'), ('a proxy war in libya', 'war', {'war', 'libya'}, 'misc'), ('refugees', 'refugees', {'refugees'}, ' ...

# %%
from collections import Counter

# couunt occurence of each candidate type
cand_type_count = [np[3] for nps in np_and_cand_list if nps != None for np in nps ]
    
counts = Counter(cand_type_count)
print(counts)
len(cand_type_count)
# Out:
# Counter({'misc': 1055, 'group': 127, 'person-nns': 89, 'loc': 67, 'person-nn': 60, 'person-nes': 16, 'loc-ne': 10, 'group-ne': 8, 'person-ne': 2})
# 1434

# %% [markdown]
# ## 10. We get coreference chains candidates from the tweet corpus

# %%
from stanza.server import CoreNLPClient
dict_of_tweet_corefs = {}
#corefs = []
with CoreNLPClient(properties={'annotators': 'coref', 'coref.algorithm' : 'statistical'}, memory='16G') as client:
    for tweet_index in tqdm(range(len(sampled_df))):
        tweet_corefs=[]
        #print(f'Coreferences for the tweet {list(event_df["Tweet Raw"]).index(tweet)} are:')
        for chain in cand_prep.get_coref_chain(sampled_df[tweet_index],client):
            tweet_corefs.append(chain)
            #print(' <-> '.join(chain),'\n')
        #corefs.append(tweet_corefs)
        dict_of_tweet_corefs[tweet_index] = tweet_corefs

dict_of_tweet_corefs
# Out:
# 2021-03-21 15:36:21 INFO: Writing properties to tmp file: corenlp_server-f5a2a01a25ca4ce7.props
# 2021-03-21 15:36:21 INFO: Starting server with command: java -Xmx16G -cp C:\Users\nikodemicek\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-f5a2a01a25ca4ce7.props -preload -outputFormat serialized
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [02:32<00:00,  1.32it/s]
# {0: [(['No law', 'it'], 0)],
#  1: [(['You', 'your', 'you'], 0)],
#  2: [],
#  3: [(['the law', 'the law', 'the law'], 0)],
#  4: [(['They', 'they', 'the asylum seekers', 'they'], 2)],
#  5: [(['I', 'I', 'I'], 0), (['aesthetic', 'it'], 0)],
#  6: [],
#  7: [],
#  8: [(['Birmingham', 'birmingham'], 0)],
#  9: [(['you', 'you'], 0), (['Turkey', 'it', 'it', 'Turkey'], 3)],
#  10: [(['The Bessudos', 'Isaac Bessudos'], 1),
#   (['Raquel Bessudo', 'Raquel'], 0)],
#  11: [(['them', 'their'], 0)],
#  12: [(['you', 'you', 'your', 'your', 'you'], 1),
#   (['it', 'it'], 1),
#   (['they', 'they'], 0)],
#  13: [],
#  14: [(['It', 'Greece'], 1)],
#  15: [],
#  16: [],
#  17: [(['their', 'Both men', 'they', 'them', 'they'], 1)],
#  18: [(['Those refugees',
#     '10 refugees , including three children with disabilities'],
#    1),
#   (['Greece', 'Greece'], 0)],
#  19: [(['UN Refugee Agency', 'Anadolu Agency'], 0)],
#  20: [],
#  21: [],
#  22: [],
#  23: [(['we', 'we'], 0)],
#  24: [],
#  25: [],
#  26: [],
#  27: [(['they', 'Enterprise Greece', 'their', 'they', 'their'], 1)],
#  28: [],
#  29: [(['they', 'their', 'them'], 0)],
#  30: [(['He', 'He', 'he'], 0)],
#  31: [(['Erdoan', 'He'], 0)],
#  32: [(['UK', 'UK'], 0), (['UK size', 'UK size'], 0)],
#  33: [],
#  34: [(['He', 'The infected person , a 40 year old man'], 1),
#   (['the camp', 'the camp'], 0),
#   (['Moria', 'Moria'], 0),
#   (["Didn '", 'it'], 0)],
#  35: [],
#  36: [(['Greece', 'its'], 0),
#   (['their', 'Protection & Operations , @GillianTriggs & @RaoufMazou'], 1)],
#  37: [(['Greece', 'greece'], 1), (['I', 'I'], 1), (['your', 'you'], 1)],
#  38: [],
#  39: [],
#  40: [],
#  41: [],
#  42: [],
#  43: [(['you', 'you', 'you'], 1)],
#  44: [(['Turkey', 'Turkey'], 1)],
#  45: [(['I', 'me', 'I', 'me'], 0)],
#  46: [],
#  47: [],
#  48: [(["Don '", 'you', 'your'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Those who seek refuge in Greece , those who want to make a coup', 'they'],
#    0),
#   (['it', 'freedom of expression'], 1)],
#  49: [],
#  50: [(['2040', '2040'], 0), (['EU', 'it'], 0)],
#  51: [(['this poor nation', 'it'], 0),
#   (['People', 'them', 'them', 'they'], 0),
#   (['I', 'me'], 1)],
#  52: [(['He', 'his', 'Erdogan'], 2),
#   (['They', 'Syrian refugees', 'They', 'they'], 1)],
#  53: [],
#  54: [],
#  55: [],
#  56: [(['it', 'It'], 0)],
#  57: [(['you', 'your', 'you'], 1)],
#  58: [(['the 5 + million refugees', 'they', 'them'], 0)],
#  59: [],
#  60: [],
#  61: [],
#  62: [],
#  63: [(['it', 'it'], 0), (['you', 'you'], 1)],
#  64: [(['Greece', 'its', 'it', 'Greece', 'it'], 3), (['him', 'Assad'], 1)],
#  65: [(['it', 'it', 'the supply of ready - made food'], 2)],
#  66: [(['Nigeria', 'Nigeria'], 0),
#   (['him', 'He', 'his', 'he', 'he', 'him'], 1)],
#  67: [],
#  68: [(['Assad', 'you'], 0), (['Greece', 'Greece'], 0)],
#  69: [(['We', 'our'], 0)],
#  70: [],
#  71: [],
#  72: [(['you', 'I', 'I'], 0)],
#  73: [],
#  74: [(['Greece', 'its', 'the country'], 0)],
#  75: [],
#  76: [],
#  77: [],
#  78: [(['The uk', 'the uk', 'it'], 1),
#   (['their', "the world ' s refugees"], 1)],
#  79: [],
#  80: [],
#  81: [(['Greek immigrants', 'their', 'they'], 0),
#   (['our', 'theirs'], 0),
#   (['our culture', 'their culture'], 0)],
#  82: [(['You', 'your'], 0), (['them', 'your so called poor refugees'], 1)],
#  83: [(['Turkey', 'Turkey'], 0)],
#  84: [],
#  85: [],
#  86: [(['It', 'The funniest thing', 'its', 'it'], 1)],
#  87: [(['me', 'I', 'my'], 1), (['their', 'refugees'], 1)],
#  88: [(['people', 'they'], 0),
#   (['i', 'MY'], 0),
#   (['you', 'you'], 1),
#   (['the EU', 'EU'], 0)],
#  89: [],
#  90: [],
#  91: [(['these people', 'they'], 0), (['it', 'a responsibility'], 1)],
#  92: [(['Athens', 'its', 'its'], 0)],
#  93: [],
#  94: [],
#  95: [(['we', 'our'], 0)],
#  96: [(['Greece', 'its'], 0), (['them', '4 million migrants', 'they'], 1)],
#  97: [(['them', 'the borders'], 1), (['you', 'You', 'Your', 'You'], 1)],
#  98: [],
#  99: [(['both aegean and kastelorizo eez', 'This'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (["this didn '", 'it'], 0)],
#  100: [(['greece and europe', 'their', 'them'], 0),
#   (['Eedogan', 'he', 'he'], 0)],
#  101: [(['you', 'you'], 1), (['my', 'I'], 1)],
#  102: [(['you', 'you', 'you', 'you'], 1)],
#  103: [(['you', 'you'], 1),
#   (['I', 'I', 'I'], 0),
#   (['Iraq', 'Iraq'], 0),
#   (['Greece', 'Greece'], 0)],
#  104: [],
#  105: [],
#  106: [(['They', 'Eastern Europe'], 1)],
#  107: [(['the bosses', 'they'], 0)],
#  108: [(['their', 'they'], 1)],
#  109: [],
#  110: [(['you', 'your', 'you'], 0)],
#  111: [],
#  112: [(['them', 'people'], 1), (['it', 'NYT', 'it'], 1)],
#  113: [(['My', 'I', 'my', 'my', 'I'], 0)],
#  114: [(['They', 'they', 'Those illegally coming by dinghy', 'they'], 2)],
#  115: [(['Anastasa Sikiaridi', 'her'], 0)],
#  116: [(['others', 'their'], 0),
#   (['Our', 'we'], 0),
#   (['all those', 'them'], 0)],
#  117: [],
#  118: [],
#  119: [],
#  120: [(['you', 'you'], 0)],
#  121: [(['them all', 'they', 'the asylum seekers'], 2)],
#  122: [],
#  123: [],
#  124: [(['the asylum system', 'it'], 0)],
#  125: [],
#  126: [],
#  127: [(['you', 'you'], 0), (['them', 'the migrants'], 1)],
#  128: [],
#  129: [(['vulnerable children', 'their'], 0)],
#  130: [(['that', '5 billion euros'], 1),
#   (['you', 'you'], 0),
#   (['they', 'they', 'they'], 1)],
#  131: [(['turkey', 'they'], 0)],
#  132: [],
#  133: [],
#  134: [(['I', 'I'], 0),
#   (['it', 'The situation'], 1),
#   (['very few people saying it', 'their'], 0)],
#  135: [(['Greece', 'Greece', 't blame Greece'], 2),
#   (['they', 'the refugees', 'their'], 1)],
#  136: [],
#  137: [],
#  138: [(['Turkey', 'Turkey'], 1)],
#  139: [(['him', 'Mr Stoltenberg'], 1),
#   (['they', 'Greece', 'They', 'they'], 1),
#   (['EU', 'EU'], 0)],
#  140: [],
#  141: [(['Moria migrant camp on Lesbos',
#     'the overcrowded migrant camp of Moria on the island of Lesbos'],
#    1),
#   (['Moria', 'Moria'], 1),
#   (['Lesbos', 'Lesbos'], 0),
#   (['Sept 2 ( Reuters ) - Greece', 'its'], 0)],
#  142: [(['you', 'i', 'I'], 1),
#   (['they', 'they', 'they', 'france Germany and Greece', 'they'], 3)],
#  143: [],
#  144: [(['Most people', 'their'], 0), (['you', 'you'], 1)],
#  145: [(['the U.K.', 'the U.K.', 'the U.K.'], 0)],
#  146: [],
#  147: [(['them', 'children and pregnant women'], 1),
#   (['@MSF', 'its', 'we'], 0)],
#  148: [],
#  149: [(['i', 'I', 'I'], 0), (['the EU', 'the French / EU'], 1)],
#  150: [],
#  151: [],
#  152: [],
#  153: [(['you', 'you', 'your'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (['they', 'they', '6 million Syrian refugees in Turkey', 'these refugees'],
#    2),
#   (['greece', 'Greece'], 1)],
#  154: [(['it', 'Greece'], 1),
#   (['Central Europe', 'it', 'it'], 0),
#   (['their', 'their'], 1)],
#  155: [(['the UK', 'the UK'], 1)],
#  156: [(['them', 'they', 'they', 'they', 'everyone'], 4), (['you', 'you'], 0)],
#  157: [],
#  158: [],
#  159: [],
#  160: [],
#  161: [],
#  162: [(['Turkey', 'Turkey', 'Turkey'], 0),
#   (['Greece', 'Greece', 'Greece'], 0)],
#  163: [(['we', 'our'], 0),
#   (['the UK', 'the UK'], 0),
#   (['Matt', 'My', 'I', 'I', 'my', 'my'], 0)],
#  164: [(['the uk', 'the uk'], 1), (['refugees', 'they'], 0)],
#  165: [(['Its', 'Its', 'Moria', 'it'], 2)],
#  166: [(['you', 'your'], 0),
#   (['Everyone', 'their'], 0),
#   (['your money', 'it'], 0),
#   (['We', 'ourselves'], 0)],
#  167: [],
#  168: [(['we', 'the EU', "the EU '"], 2),
#   (['you', 'you'], 1),
#   (["the EU ' s member countries", 'them'], 0)],
#  169: [(['the camp', 'the overcrowded moria camp'], 1)],
#  170: [(['This', 'This'], 0)],
#  171: [(['just for unidentified migrant bodies from the Mediterranean',
#     'these unnamed bodies'],
#    0)],
#  172: [(['I', 'my', 'me', 'I'], 0), (['He', 'him'], 0), (['they', 'them'], 0)],
#  173: [],
#  174: [],
#  175: [(['our', 'our', 'our'], 2)],
#  176: [(['WE', 'our'], 0), (['@RuhiLoren', 'they'], 0)],
#  177: [(['us', 'our'], 0), (['YOU', 'you'], 0)],
#  178: [(['Erdogan', 'He'], 0),
#   (['we', 'its', 'MSM', 'the problem'], 2),
#   (['Greece', 'it'], 0)],
#  179: [],
#  180: [(['we', 'we'], 0)],
#  181: [(['Spring', 'spring'], 0)],
#  182: [],
#  183: [],
#  184: [],
#  185: [(['its citizens', 'their'], 0), (['Its', 'its', 'its'], 0)],
#  186: [],
#  187: [],
#  188: [(['Greece', 'they'], 0)],
#  189: [(['Moria Camp', "the camp ' s"], 0),
#   (['it',
#     'it',
#     "the first confirmed case of Covid - 19 within the camp ' s population"],
#    2)],
#  190: [],
#  191: [(['they', 'them', 'they'], 0), (['Luvvie Flakes', 'these migrant'], 0)],
#  192: [(['you', 'I', 'you'], 0), (['it', 'The EU', 'They', 'they'], 1)],
#  193: [(['the need for teacher compassion', 'It'], 0), (['me', 'I', 'my'], 0)],
#  194: [],
#  195: [(['Greece', 'its'], 0)],
#  196: [],
#  197: [(['Omfg', 'you', 'you', 'you'], 0),
#   (['They', 'italian immigrants in greece'], 1)],
#  198: [],
#  199: [(['them', 'them'], 0)]}

# %%
with open('sample_crfs', 'wb') as fp:
    pickle.dump(dict_of_tweet_corefs, fp)

dict_of_tweet_corefs
# Out:
# {0: [(['No law', 'it'], 0)],
#  1: [(['You', 'your', 'you'], 0)],
#  2: [],
#  3: [(['the law', 'the law', 'the law'], 0)],
#  4: [(['They', 'they', 'the asylum seekers', 'they'], 2)],
#  5: [(['I', 'I', 'I'], 0), (['aesthetic', 'it'], 0)],
#  6: [],
#  7: [],
#  8: [(['Birmingham', 'birmingham'], 0)],
#  9: [(['you', 'you'], 0), (['Turkey', 'it', 'it', 'Turkey'], 3)],
#  10: [(['The Bessudos', 'Isaac Bessudos'], 1),
#   (['Raquel Bessudo', 'Raquel'], 0)],
#  11: [(['them', 'their'], 0)],
#  12: [(['you', 'you', 'your', 'your', 'you'], 1),
#   (['it', 'it'], 1),
#   (['they', 'they'], 0)],
#  13: [],
#  14: [(['It', 'Greece'], 1)],
#  15: [],
#  16: [],
#  17: [(['their', 'Both men', 'they', 'them', 'they'], 1)],
#  18: [(['Those refugees',
#     '10 refugees , including three children with disabilities'],
#    1),
#   (['Greece', 'Greece'], 0)],
#  19: [(['UN Refugee Agency', 'Anadolu Agency'], 0)],
#  20: [],
#  21: [],
#  22: [],
#  23: [(['we', 'we'], 0)],
#  24: [],
#  25: [],
#  26: [],
#  27: [(['they', 'Enterprise Greece', 'their', 'they', 'their'], 1)],
#  28: [],
#  29: [(['they', 'their', 'them'], 0)],
#  30: [(['He', 'He', 'he'], 0)],
#  31: [(['Erdoan', 'He'], 0)],
#  32: [(['UK', 'UK'], 0), (['UK size', 'UK size'], 0)],
#  33: [],
#  34: [(['He', 'The infected person , a 40 year old man'], 1),
#   (['the camp', 'the camp'], 0),
#   (['Moria', 'Moria'], 0),
#   (["Didn '", 'it'], 0)],
#  35: [],
#  36: [(['Greece', 'its'], 0),
#   (['their', 'Protection & Operations , @GillianTriggs & @RaoufMazou'], 1)],
#  37: [(['Greece', 'greece'], 1), (['I', 'I'], 1), (['your', 'you'], 1)],
#  38: [],
#  39: [],
#  40: [],
#  41: [],
#  42: [],
#  43: [(['you', 'you', 'you'], 1)],
#  44: [(['Turkey', 'Turkey'], 1)],
#  45: [(['I', 'me', 'I', 'me'], 0)],
#  46: [],
#  47: [],
#  48: [(["Don '", 'you', 'your'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Those who seek refuge in Greece , those who want to make a coup', 'they'],
#    0),
#   (['it', 'freedom of expression'], 1)],
#  49: [],
#  50: [(['2040', '2040'], 0), (['EU', 'it'], 0)],
#  51: [(['this poor nation', 'it'], 0),
#   (['People', 'them', 'them', 'they'], 0),
#   (['I', 'me'], 1)],
#  52: [(['He', 'his', 'Erdogan'], 2),
#   (['They', 'Syrian refugees', 'They', 'they'], 1)],
#  53: [],
#  54: [],
#  55: [],
#  56: [(['it', 'It'], 0)],
#  57: [(['you', 'your', 'you'], 1)],
#  58: [(['the 5 + million refugees', 'they', 'them'], 0)],
#  59: [],
#  60: [],
#  61: [],
#  62: [],
#  63: [(['it', 'it'], 0), (['you', 'you'], 1)],
#  64: [(['Greece', 'its', 'it', 'Greece', 'it'], 3), (['him', 'Assad'], 1)],
#  65: [(['it', 'it', 'the supply of ready - made food'], 2)],
#  66: [(['Nigeria', 'Nigeria'], 0),
#   (['him', 'He', 'his', 'he', 'he', 'him'], 1)],
#  67: [],
#  68: [(['Assad', 'you'], 0), (['Greece', 'Greece'], 0)],
#  69: [(['We', 'our'], 0)],
#  70: [],
#  71: [],
#  72: [(['you', 'I', 'I'], 0)],
#  73: [],
#  74: [(['Greece', 'its', 'the country'], 0)],
#  75: [],
#  76: [],
#  77: [],
#  78: [(['The uk', 'the uk', 'it'], 1),
#   (['their', "the world ' s refugees"], 1)],
#  79: [],
#  80: [],
#  81: [(['Greek immigrants', 'their', 'they'], 0),
#   (['our', 'theirs'], 0),
#   (['our culture', 'their culture'], 0)],
#  82: [(['You', 'your'], 0), (['them', 'your so called poor refugees'], 1)],
#  83: [(['Turkey', 'Turkey'], 0)],
#  84: [],
#  85: [],
#  86: [(['It', 'The funniest thing', 'its', 'it'], 1)],
#  87: [(['me', 'I', 'my'], 1), (['their', 'refugees'], 1)],
#  88: [(['people', 'they'], 0),
#   (['i', 'MY'], 0),
#   (['you', 'you'], 1),
#   (['the EU', 'EU'], 0)],
#  89: [],
#  90: [],
#  91: [(['these people', 'they'], 0), (['it', 'a responsibility'], 1)],
#  92: [(['Athens', 'its', 'its'], 0)],
#  93: [],
#  94: [],
#  95: [(['we', 'our'], 0)],
#  96: [(['Greece', 'its'], 0), (['them', '4 million migrants', 'they'], 1)],
#  97: [(['them', 'the borders'], 1), (['you', 'You', 'Your', 'You'], 1)],
#  98: [],
#  99: [(['both aegean and kastelorizo eez', 'This'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (["this didn '", 'it'], 0)],
#  100: [(['greece and europe', 'their', 'them'], 0),
#   (['Eedogan', 'he', 'he'], 0)],
#  101: [(['you', 'you'], 1), (['my', 'I'], 1)],
#  102: [(['you', 'you', 'you', 'you'], 1)],
#  103: [(['you', 'you'], 1),
#   (['I', 'I', 'I'], 0),
#   (['Iraq', 'Iraq'], 0),
#   (['Greece', 'Greece'], 0)],
#  104: [],
#  105: [],
#  106: [(['They', 'Eastern Europe'], 1)],
#  107: [(['the bosses', 'they'], 0)],
#  108: [(['their', 'they'], 1)],
#  109: [],
#  110: [(['you', 'your', 'you'], 0)],
#  111: [],
#  112: [(['them', 'people'], 1), (['it', 'NYT', 'it'], 1)],
#  113: [(['My', 'I', 'my', 'my', 'I'], 0)],
#  114: [(['They', 'they', 'Those illegally coming by dinghy', 'they'], 2)],
#  115: [(['Anastasa Sikiaridi', 'her'], 0)],
#  116: [(['others', 'their'], 0),
#   (['Our', 'we'], 0),
#   (['all those', 'them'], 0)],
#  117: [],
#  118: [],
#  119: [],
#  120: [(['you', 'you'], 0)],
#  121: [(['them all', 'they', 'the asylum seekers'], 2)],
#  122: [],
#  123: [],
#  124: [(['the asylum system', 'it'], 0)],
#  125: [],
#  126: [],
#  127: [(['you', 'you'], 0), (['them', 'the migrants'], 1)],
#  128: [],
#  129: [(['vulnerable children', 'their'], 0)],
#  130: [(['that', '5 billion euros'], 1),
#   (['you', 'you'], 0),
#   (['they', 'they', 'they'], 1)],
#  131: [(['turkey', 'they'], 0)],
#  132: [],
#  133: [],
#  134: [(['I', 'I'], 0),
#   (['it', 'The situation'], 1),
#   (['very few people saying it', 'their'], 0)],
#  135: [(['Greece', 'Greece', 't blame Greece'], 2),
#   (['they', 'the refugees', 'their'], 1)],
#  136: [],
#  137: [],
#  138: [(['Turkey', 'Turkey'], 1)],
#  139: [(['him', 'Mr Stoltenberg'], 1),
#   (['they', 'Greece', 'They', 'they'], 1),
#   (['EU', 'EU'], 0)],
#  140: [],
#  141: [(['Moria migrant camp on Lesbos',
#     'the overcrowded migrant camp of Moria on the island of Lesbos'],
#    1),
#   (['Moria', 'Moria'], 1),
#   (['Lesbos', 'Lesbos'], 0),
#   (['Sept 2 ( Reuters ) - Greece', 'its'], 0)],
#  142: [(['you', 'i', 'I'], 1),
#   (['they', 'they', 'they', 'france Germany and Greece', 'they'], 3)],
#  143: [],
#  144: [(['Most people', 'their'], 0), (['you', 'you'], 1)],
#  145: [(['the U.K.', 'the U.K.', 'the U.K.'], 0)],
#  146: [],
#  147: [(['them', 'children and pregnant women'], 1),
#   (['@MSF', 'its', 'we'], 0)],
#  148: [],
#  149: [(['i', 'I', 'I'], 0), (['the EU', 'the French / EU'], 1)],
#  150: [],
#  151: [],
#  152: [],
#  153: [(['you', 'you', 'your'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (['they', 'they', '6 million Syrian refugees in Turkey', 'these refugees'],
#    2),
#   (['greece', 'Greece'], 1)],
#  154: [(['it', 'Greece'], 1),
#   (['Central Europe', 'it', 'it'], 0),
#   (['their', 'their'], 1)],
#  155: [(['the UK', 'the UK'], 1)],
#  156: [(['them', 'they', 'they', 'they', 'everyone'], 4), (['you', 'you'], 0)],
#  157: [],
#  158: [],
#  159: [],
#  160: [],
#  161: [],
#  162: [(['Turkey', 'Turkey', 'Turkey'], 0),
#   (['Greece', 'Greece', 'Greece'], 0)],
#  163: [(['we', 'our'], 0),
#   (['the UK', 'the UK'], 0),
#   (['Matt', 'My', 'I', 'I', 'my', 'my'], 0)],
#  164: [(['the uk', 'the uk'], 1), (['refugees', 'they'], 0)],
#  165: [(['Its', 'Its', 'Moria', 'it'], 2)],
#  166: [(['you', 'your'], 0),
#   (['Everyone', 'their'], 0),
#   (['your money', 'it'], 0),
#   (['We', 'ourselves'], 0)],
#  167: [],
#  168: [(['we', 'the EU', "the EU '"], 2),
#   (['you', 'you'], 1),
#   (["the EU ' s member countries", 'them'], 0)],
#  169: [(['the camp', 'the overcrowded moria camp'], 1)],
#  170: [(['This', 'This'], 0)],
#  171: [(['just for unidentified migrant bodies from the Mediterranean',
#     'these unnamed bodies'],
#    0)],
#  172: [(['I', 'my', 'me', 'I'], 0), (['He', 'him'], 0), (['they', 'them'], 0)],
#  173: [],
#  174: [],
#  175: [(['our', 'our', 'our'], 2)],
#  176: [(['WE', 'our'], 0), (['@RuhiLoren', 'they'], 0)],
#  177: [(['us', 'our'], 0), (['YOU', 'you'], 0)],
#  178: [(['Erdogan', 'He'], 0),
#   (['we', 'its', 'MSM', 'the problem'], 2),
#   (['Greece', 'it'], 0)],
#  179: [],
#  180: [(['we', 'we'], 0)],
#  181: [(['Spring', 'spring'], 0)],
#  182: [],
#  183: [],
#  184: [],
#  185: [(['its citizens', 'their'], 0), (['Its', 'its', 'its'], 0)],
#  186: [],
#  187: [],
#  188: [(['Greece', 'they'], 0)],
#  189: [(['Moria Camp', "the camp ' s"], 0),
#   (['it',
#     'it',
#     "the first confirmed case of Covid - 19 within the camp ' s population"],
#    2)],
#  190: [],
#  191: [(['they', 'them', 'they'], 0), (['Luvvie Flakes', 'these migrant'], 0)],
#  192: [(['you', 'I', 'you'], 0), (['it', 'The EU', 'They', 'they'], 1)],
#  193: [(['the need for teacher compassion', 'It'], 0), (['me', 'I', 'my'], 0)],
#  194: [],
#  195: [(['Greece', 'its'], 0)],
#  196: [],
#  197: [(['Omfg', 'you', 'you', 'you'], 0),
#   (['They', 'italian immigrants in greece'], 1)],
#  198: [],
#  199: [(['them', 'them'], 0)]}

# %% [markdown]
# ## 11. We determine candidate's type for representative mentions of coref candidates (in batches)

# %%
# Load NPs from pickle file
import pickle

with open(r"sample_crfs", "rb") as input_file:
    dict_of_tweet_corefs = pickle.load(input_file)

# %%
corefs_list = []

#pick out only the representative mention as the candidate's rep. phrase
for tweet_corefs in dict_of_tweet_corefs:
        tw_corefs = [coref[0][coref[1]] for coref in dict_of_tweet_corefs[tweet_corefs]] 
        # empty list would cause problems in the following steps, that is why we append 'no_candidate' to empty lists
        corefs_list.append(tw_corefs) if len(tw_corefs) != 0 else corefs_list.append(['no_candidate'])

corefs_list  = [[crf.replace('@','').lower() for crf in crfs ] for crfs in corefs_list ]     
corefs_list
# Out:
# [['no law'],
#  ['you'],
#  ['no_candidate'],
#  ['the law'],
#  ['the asylum seekers'],
#  ['i', 'aesthetic'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['birmingham'],
#  ['you', 'turkey'],
#  ['isaac bessudos', 'raquel bessudo'],
#  ['them'],
#  ['you', 'it', 'they'],
#  ['no_candidate'],
#  ['greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['both men'],
#  ['10 refugees , including three children with disabilities', 'greece'],
#  ['un refugee agency'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['we'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['enterprise greece'],
#  ['no_candidate'],
#  ['they'],
#  ['he'],
#  ['erdoan'],
#  ['uk', 'uk size'],
#  ['no_candidate'],
#  ['the infected person , a 40 year old man', 'the camp', 'moria', "didn '"],
#  ['no_candidate'],
#  ['greece', 'protection & operations , gilliantriggs & raoufmazou'],
#  ['greece', 'i', 'you'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['turkey'],
#  ['i'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ["don '",
#   'greece',
#   'those who seek refuge in greece , those who want to make a coup',
#   'freedom of expression'],
#  ['no_candidate'],
#  ['2040', 'eu'],
#  ['this poor nation', 'people', 'me'],
#  ['erdogan', 'syrian refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['it'],
#  ['your'],
#  ['the 5 + million refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['it', 'you'],
#  ['greece', 'assad'],
#  ['the supply of ready - made food'],
#  ['nigeria', 'he'],
#  ['no_candidate'],
#  ['assad', 'greece'],
#  ['we'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['no_candidate'],
#  ['greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['the uk', "the world ' s refugees"],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['greek immigrants', 'our', 'our culture'],
#  ['you', 'your so called poor refugees'],
#  ['turkey'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['the funniest thing'],
#  ['i', 'refugees'],
#  ['people', 'i', 'you', 'the eu'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['these people', 'a responsibility'],
#  ['athens'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['we'],
#  ['greece', '4 million migrants'],
#  ['the borders', 'you'],
#  ['no_candidate'],
#  ['both aegean and kastelorizo eez', 'greece', 'turkey', "this didn '"],
#  ['greece and europe', 'eedogan'],
#  ['you', 'i'],
#  ['you'],
#  ['you', 'i', 'iraq', 'greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['eastern europe'],
#  ['the bosses'],
#  ['they'],
#  ['no_candidate'],
#  ['you'],
#  ['no_candidate'],
#  ['people', 'nyt'],
#  ['my'],
#  ['those illegally coming by dinghy'],
#  ['anastasa sikiaridi'],
#  ['others', 'our', 'all those'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['the asylum seekers'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['the asylum system'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you', 'the migrants'],
#  ['no_candidate'],
#  ['vulnerable children'],
#  ['5 billion euros', 'you', 'they'],
#  ['turkey'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['i', 'the situation', 'very few people saying it'],
#  ['t blame greece', 'the refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['turkey'],
#  ['mr stoltenberg', 'greece', 'eu'],
#  ['no_candidate'],
#  ['the overcrowded migrant camp of moria on the island of lesbos',
#   'moria',
#   'lesbos',
#   'sept 2 ( reuters ) - greece'],
#  ['i', 'france germany and greece'],
#  ['no_candidate'],
#  ['most people', 'you'],
#  ['the u.k.'],
#  ['no_candidate'],
#  ['children and pregnant women', 'msf'],
#  ['no_candidate'],
#  ['i', 'the french / eu'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you', 'turkey', '6 million syrian refugees in turkey', 'greece'],
#  ['greece', 'central europe', 'their'],
#  ['the uk'],
#  ['everyone', 'you'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['turkey', 'greece'],
#  ['we', 'the uk', 'matt'],
#  ['the uk', 'refugees'],
#  ['moria'],
#  ['you', 'everyone', 'your money', 'we'],
#  ['no_candidate'],
#  ["the eu '", 'you', "the eu ' s member countries"],
#  ['the overcrowded moria camp'],
#  ['this'],
#  ['just for unidentified migrant bodies from the mediterranean'],
#  ['i', 'he', 'they'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['our'],
#  ['we', 'ruhiloren'],
#  ['us', 'you'],
#  ['erdogan', 'msm', 'greece'],
#  ['no_candidate'],
#  ['we'],
#  ['spring'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['its citizens', 'its'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['greece'],
#  ['moria camp',
#   "the first confirmed case of covid - 19 within the camp ' s population"],
#  ['no_candidate'],
#  ['they', 'luvvie flakes'],
#  ['you', 'the eu'],
#  ['the need for teacher compassion', 'me'],
#  ['no_candidate'],
#  ['greece'],
#  ['no_candidate'],
#  ['omfg', 'italian immigrants in greece'],
#  ['no_candidate'],
#  ['them']]

# %%
#removing the spaces around dashes, slashes and apostrophes should increase stanza's ability to parse sentence correctly
corefs_list = [[crf.replace(' - ','-') for crf in corefs] for corefs in corefs_list]
corefs_list = [[crf.replace(' / ','/') for crf in corefs] for corefs in corefs_list]
corefs_list = [[crf.replace(" ' ","'") for crf in corefs] for corefs in corefs_list]

# %%
#tag all tweets and save them in a list    
tagged_coref_cands = [] 
batched_coref_list = prep_candlist_for_batching(corefs_list)
#print(batched_coref_list)


tagged_coref_cands = [tagged_cand for tagged_cand in batch(batched_coref_list, en_nlp, batch_size=6000)] # Default batch size is 32
#print(tagged_coref_cands)
        
coref_cand_heads = [get_cand_heads(tweet_cands) for tweet_cands in tagged_coref_cands]
coref_cand_heads
# Out:
# [[[{'law'}, ['law']]],
#  [[{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'law'}, ['law']]],
#  [[{'seekers'}, ['seekers']]],
#  [[{'i'}, ['i']], [{'aesthetic'}, ['aesthetic']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'birmingham'}, ['birmingham']]],
#  [[{'you'}, ['you']], [{'turkey'}, ['turkey']]],
#  [[{'bessudos', 'isaac'}, ['isaac']], [{'bessudo', 'raquel'}, ['raquel']]],
#  [[{'them'}, ['them']]],
#  [[{'you'}, ['you']], [{'it'}, ['it']], [{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'men'}, ['men']]],
#  [[{'children', 'disabilities', 'refugees'}, ['refugees']],
#   [{'greece'}, ['greece']]],
#  [[{'agency'}, ['agency']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'they'}, ['they']]],
#  [[{'he'}, ['he']]],
#  [[{'erdoan'}, ['erdoan']]],
#  [[{'uk'}, ['uk']], [{'size'}, ['size']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'man', 'old', 'person', 'year'}, ['person']],
#   [{'camp'}, ['camp']],
#   [{'moria'}, ['moria']],
#   [{"'", 'didn'}, ['didn']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']],
#   [{'gilliantriggs', 'operations', 'protection', 'raoufmazou'},
#    ['protection']]],
#  [[{'greece'}, ['greece']], [{'i'}, ['i']], [{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'turkey'}, ['turkey']]],
#  [[{'i'}, ['i']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{"'", 'don'}, ['don']],
#   [{'greece'}, ['greece']],
#   [{'coup', 'greece', 'make', 'seek', 'those', 'want'}, ['those']],
#   [{'expression', 'freedom'}, ['freedom']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'2040'}, ['2040']], [{'eu'}, ['eu']]],
#  [[{'nation'}, ['nation']], [{'people'}, ['people']], [{'me'}, ['me']]],
#  [[{'erdogan'}, ['erdogan']], [{'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'it'}, ['it']]],
#  [[{'your'}, ['your']]],
#  [[{'million', 'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'it'}, ['it']], [{'you'}, ['you']]],
#  [[{'greece'}, ['greece']], [{'assad'}, ['assad']]],
#  [[{'food', 'made', 'supply'}, ['supply']]],
#  [[{'nigeria'}, ['nigeria']], [{'he'}, ['he']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'assad'}, ['assad']], [{'greece'}, ['greece']]],
#  [[{'we'}, ['we']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'uk'}, ['uk']], [{'refugees', 'world'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'immigrants'}, ['immigrants']],
#   [{'our'}, ['our']],
#   [{'culture'}, ['culture']]],
#  [[{'you'}, ['you']], [{'called', 'refugees'}, ['refugees']]],
#  [[{'turkey'}, ['turkey']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'thing'}, ['thing']]],
#  [[{'i'}, ['i']], [{'refugees'}, ['refugees']]],
#  [[{'people'}, ['people']],
#   [{'i'}, ['i']],
#   [{'you'}, ['you']],
#   [{'eu'}, ['eu']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'responsibility'}, ['responsibility']]],
#  [[{'athens'}, ['athens']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'greece'}, ['greece']], [{'migrants', 'million'}, ['migrants']]],
#  [[{'borders'}, ['borders']], [{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'aegean', 'eez', 'kastelorizo'}, ['eez']],
#   [{'greece'}, ['greece']],
#   [{'turkey'}, ['turkey']],
#   [{"'", 'didn'}, ['didn']]],
#  [[{'europe', 'greece'}, ['greece']], [{'eedogan'}, ['eedogan']]],
#  [[{'you'}, ['you']], [{'i'}, ['i']]],
#  [[{'you'}, ['you']]],
#  [[{'you'}, ['you']],
#   [{'i'}, ['i']],
#   [{'iraq'}, ['iraq']],
#   [{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'europe'}, ['europe']]],
#  [[{'bosses'}, ['bosses']]],
#  [[{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'nyt'}, ['nyt']]],
#  [[{'my'}, ['my']]],
#  [[{'coming', 'dinghy', 'those'}, ['those']]],
#  [[{'anastasa', 'sikiaridi'}, ['anastasa']]],
#  [[{'others'}, ['others']], [{'our'}, ['our']], [{'those'}, ['those']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'seekers'}, ['seekers']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'system'}, ['system']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']], [{'migrants'}, ['migrants']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'children'}, ['children']]],
#  [[{'billion', 'euros'}, ['euros']], [{'you'}, ['you']], [{'they'}, ['they']]],
#  [[{'turkey'}, ['turkey']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'i'}, ['i']],
#   [{'situation'}, ['situation']],
#   [{'few', 'it', 'people', 'saying'}, ['people']]],
#  [[{'blame', 'greece'}, ['blame']], [{'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'turkey'}, ['turkey']]],
#  [[{'mr', 'stoltenberg'}, ['mr']], [{'greece'}, ['greece']], [{'eu'}, ['eu']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'camp', 'island', 'lesbos', 'moria'}, ['camp']],
#   [{'moria'}, ['moria']],
#   [{'lesbos'}, ['lesbos']],
#   [{'greece', 'reuters', 'sept'}, ['sept']]],
#  [[{'i'}, ['i']], [{'germany', 'greece'}, ['germany']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'you'}, ['you']]],
#  [[{'.', 'u.k'}, ['u.k']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'children', 'women'}, ['children']], [{'msf'}, ['msf']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'i'}, ['i']], [{'eu', 'french'}, ['french']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']],
#   [{'turkey'}, ['turkey']],
#   [{'million', 'refugees', 'turkey'}, ['refugees']],
#   [{'greece'}, ['greece']]],
#  [[{'greece'}, ['greece']], [{'europe'}, ['europe']], [{'their'}, ['their']]],
#  [[{'uk'}, ['uk']]],
#  [[{'everyone'}, ['everyone']], [{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'turkey'}, ['turkey']], [{'greece'}, ['greece']]],
#  [[{'we'}, ['we']], [{'uk'}, ['uk']], [{'matt'}, ['matt']]],
#  [[{'uk'}, ['uk']], [{'refugees'}, ['refugees']]],
#  [[{'moria'}, ['moria']]],
#  [[{'you'}, ['you']],
#   [{'everyone'}, ['everyone']],
#   [{'money'}, ['money']],
#   [{'we'}, ['we']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{"'", 'eu'}, ['eu']],
#   [{'you'}, ['you']],
#   [{'countries', 'eu'}, ['countries']]],
#  [[{'camp'}, ['camp']]],
#  [[{'this'}, ['this']]],
#  [[{'bodies', 'mediterranean'}, ['bodies']]],
#  [[{'i'}, ['i']], [{'he'}, ['he']], [{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'our'}, ['our']]],
#  [[{'we'}, ['we']], [{'ruhiloren'}, ['ruhiloren']]],
#  [[{'us'}, ['us']], [{'you'}, ['you']]],
#  [[{'erdogan'}, ['erdogan']], [{'msm'}, ['msm']], [{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'spring'}, ['spring']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'citizens'}, ['citizens']], [{'its'}, ['its']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']]],
#  [[{'camp'}, ['camp']],
#   [{'19', 'camp', 'case', 'covid', 'population'}, ['case']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'they'}, ['they']], [{'flakes'}, ['flakes']]],
#  [[{'you'}, ['you']], [{'eu'}, ['eu']]],
#  [[{'compassion', 'need'}, ['need']], [{'me'}, ['me']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'greece'}, ['greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'omfg'}, ['omfg']], [{'greece', 'immigrants'}, ['immigrants']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'them'}, ['them']]]]

# %%
coref_and_cand_list = cand_prep.get_cand_type(corefs_list, coref_cand_heads, tweet_tags, cand_types_dict, corefs=True)


print(coref_and_cand_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 917.46it/s]
# [[('no law', 'law', {'law'}, 'misc')], [('you', 'you', {'you'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('the law', 'law', {'law'}, 'misc')], [('the asylum seekers', 'seekers', {'seekers'}, 'person-nns')], [('i', 'i', {'i'}, 'person-nn'), ('aesthetic', 'aesthetic', {'aesthetic'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('birmingham', 'birmingham', {'birmingham'}, 'misc')], [('you', 'you', {'you'}, 'misc'), ('turkey', 'turkey', {'turkey'}, 'misc')], [('isaac bessudos', 'isaac', {'bessudos', 'isaac'}, 'misc'), ('raquel bessudo', 'raquel', {'bessudo', 'raquel'}, 'misc')], [('them', 'them', {'them'}, 'misc')], [('you', 'you', {'you'}, 'misc'), ('it', 'it', {'it'}, 'misc'), ('they', 'they', {'they'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('greece', 'greece', {'greece'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('both men', 'men', {'men'}, 'group')], [('10 refugees , including three children with disabilities', 'refugees', {'disabilities', 'children', 'refugees'}, 'person-nes'), ('greece', 'greece', {'greece'}, 'misc')], [('un refugee agency', 'agency', {'agency'}, 'group')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('we', 'we', {'we'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('enterprise greece', 'greece', {'greece'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('they', 'they', {'they'}, 'misc')], [('he', 'he', {'he'}, 'misc')], [('erdoan', 'erdoan', {'erdoan'}, 'misc')], [('uk', 'uk', {'uk'}, 'misc'), ('uk size', 'size', {'size'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('the infected person , a 40 year old man', 'person', {'person', 'old', 'year', 'man'}, 'person-ne'), ('the camp', 'camp', {'camp'}, 'group'), ('moria', 'moria', {'moria'}, 'misc'), ("didn '", 'didn', {'didn', "'"}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('greece', 'greece', {'greece'}, 'misc'), ('protection & operations , gilliantriggs & raoufmazou', 'protection', {'protection', 'operations', 'raoufmazou', 'gilliantriggs'}, 'misc')], [('greece', 'greece', {'greece'}, 'misc'), ('i', 'i', {'i'}, 'misc'), ('you', 'you', {'you'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('you', 'you', {'you'}, 'misc')], [('turkey', 'turkey', {'turkey'}, 'misc')], [('i', 'i', {'i'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [("don '", 'don', {'don', "'"}, 'person-nn'), ('greece', 'greece', {'greece'}, 'misc'), ('those who seek refuge in greece , those who want to make a coup', 'those', {'want', 'seek', 'greece', 'coup', 'make', 'those'}, 'misc'), ('freedom of expression', 'freedom', {'freedom', 'expression'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('2040', '2040', {'2040'}, 'misc'), ('eu', 'eu', {'eu'}, 'group')], [('this poor nation', 'nation', {'nation'}, 'group'), ('people', 'people', {'people'}, 'misc'), ('me', 'me', {'me'}, 'misc')], [('erdogan', 'erdogan', {'erdogan'}, 'misc'), ('syrian refugees', 'refugees', {'refugees'}, 'person-nns')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_ ...

# %% [markdown]
# ## 12. We combine the candidate lists for candidate merging
#
# We organize candidates in a list sorted by their number of phrases

# %%
#concatenate corefs and noun phrase lists
nps_cands = [cand for cands in np_and_cand_list for cand in cands]
crf_cands = [cand for cands in coref_and_cand_list for cand in cands]
#candidate_list = coref_and_cand_list + np_and_cand_list
#print(f'Len = {len(candidate_list)} should be 2x amount of tweets')
print(len(nps_cands), len(crf_cands))
#unpack list of lists into one list
candidate_list = nps_cands + crf_cands
print(f'The amount of all candidates is {len(candidate_list)}')
# Out:
# 1434 288
# The amount of all candidates is 1722

# %%
nps_tagged = [sent for tagged_cand in tagged_np_cands for sent in tagged_cand.sentences ]
crf_tagged = [sent for tagged_cand in tagged_coref_cands for sent in tagged_cand.sentences ]
print(len(nps_tagged), len(crf_tagged))
all_cands_tagged = nps_tagged + crf_tagged
# Out:
# 1434 288

# %%
print(len(candidate_list))
print(len(all_cands_tagged))
# Out:
# 1722
# 1722

# %%
cand_df = pd.DataFrame(
    {'candidates': candidate_list,
     'cand_tags': all_cands_tagged
    })

cand_df['cand_text'] = cand_df.candidates.apply(lambda x: x[0])
cand_df['cand_len'] = cand_df.cand_text.apply(lambda x: len(x.split()))
cand_df.columns = cand_df.columns.str.strip()
cand_df
# Out:
#                                              candidates  \
# 0                                  (it, it, {it}, misc)
# 1     (asylum in greece, mac, ser or cro or bul, asy...
# 2        (3 eu members, members, {members}, person-nes)
# 3                                  (hu, hu, {hu}, misc)
# 4                            (they, they, {they}, misc)
# ...                                                 ...
# 1717  (no_candidate, no_candidate, {no_candidate}, m...
# 1718                         (omfg, omfg, {omfg}, misc)
# 1719  (italian immigrants in greece, immigrants, {gr...
# 1720  (no_candidate, no_candidate, {no_candidate}, m...
# 1721                         (them, them, {them}, misc)
#
#                                               cand_tags  \
# 0     [\n  {\n    "id": 1,\n    "text": "it",\n    "...
# 1     [\n  {\n    "id": 1,\n    "text": "asylum",\n ...
# 2     [\n  {\n    "id": 1,\n    "text": "3",\n    "l...
# 3     [\n  {\n    "id": 1,\n    "text": "hu",\n    "...
# 4     [\n  {\n    "id": 1,\n    "text": "they",\n   ...
# ...                                                 ...
# 1717  [\n  {\n    "id": 1,\n    "text": "no_candidat...
# 1718  [\n  {\n    "id": 1,\n    "text": "omfg",\n   ...
# 1719  [\n  {\n    "id": 1,\n    "text": "italian",\n...
# 1720  [\n  {\n    "id": 1,\n    "text": "no_candidat...
# 1721  [\n  {\n    "id": 1,\n    "text": "them",\n   ...
#
#                                      cand_text  cand_len
# 0                                           it         1
# 1     asylum in greece, mac, ser or cro or bul         9
# 2                                 3 eu members         3
# 3                                           hu         1
# 4                                         they         1
# ...                                        ...       ...
# 1717                              no_candidate         1
# 1718                                      omfg         1
# 1719              italian immigrants in greece         4
# 1720                              no_candidate         1
# 1721                                      them         1
#
# [1722 rows x 4 columns]

# %%
# we sort the candidates by their length

cand_df.sort_values('cand_len', ascending=False,inplace=True)

#cand_df = cand_df[cand_df.cand_text not in  ['no_candidate', 'candidate_to_be_removed']]

cand_df.reset_index(drop=True, inplace = True)
cand_df
#all_cands_tagged.sort(reverse=True,key=get_cand_len(candidate_list))
# Out:
#                                              candidates  \
# 0     (conditions + reduce overcrowding at the recep...
# 1     (access to territory & asylum, living conditio...
# 2     (population & children for 39%, of whom more t...
# 3     (economic migrants who cross developed nations...
# 4     (morocco tunisia libya greece turkey each one ...
# ...                                                 ...
# 1717                           (who, who, {who}, group)
# 1718                  (asylum, asylum, {asylum}, group)
# 1719                            (you, you, {you}, misc)
# 1720                            (you, you, {you}, misc)
# 1721                         (them, them, {them}, misc)
#
#                                               cand_tags  \
# 0     [\n  {\n    "id": 1,\n    "text": "conditions"...
# 1     [\n  {\n    "id": 1,\n    "text": "access",\n ...
# 2     [\n  {\n    "id": 1,\n    "text": "population"...
# 3     [\n  {\n    "id": 1,\n    "text": "economic",\...
# 4     [\n  {\n    "id": 1,\n    "text": "morocco",\n...
# ...                                                 ...
# 1717  [\n  {\n    "id": 1,\n    "text": "who",\n    ...
# 1718  [\n  {\n    "id": 1,\n    "text": "asylum",\n ...
# 1719  [\n  {\n    "id": 1,\n    "text": "you",\n    ...
# 1720  [\n  {\n    "id": 1,\n    "text": "you",\n    ...
# 1721  [\n  {\n    "id": 1,\n    "text": "them",\n   ...
#
#                                               cand_text  cand_len
# 0     conditions + reduce overcrowding at the recept...        19
# 1     access to territory & asylum, living condition...        19
# 2     population & children for 39%, of whom more th...        19
# 3     economic migrants who cross developed nations ...        19
# 4     morocco tunisia libya greece turkey each one o...        19
# ...                                                 ...       ...
# 1717                                                who         1
# 1718                                             asylum         1
# 1719                                                you         1
# 1720                                                you         1
# 1721                                               them         1
#
# [1722 rows x 4 columns]

# %%
#remove dummy candidates that were used to avoid errors

print(len(cand_df))
cand_df = cand_df[cand_df.cand_text != 'candidate_to_be_removed']
cand_df = cand_df[cand_df.cand_text != 'no_candidate']
len(cand_df)
cand_df.reset_index(drop=True,inplace=True)
# Out:
# 1722

# %% [markdown]
# ### First merging step

# %%
#
# THIS IS THE FIRST MERGING STEP
#
        
def merging_step1(candidate_list):
    """
    In the first merging step, we merge two candidates if the head of each of their representative phrase 
     is identical by string comparison.
    """
    indices_to_remove = set()
    for longer_cand in tqdm(range(len(candidate_list))):     
        for cand in range(longer_cand+1,len(candidate_list)): 
            #print(f'for index {candidate_list[longer_cand][1]} checking the index {candidate_list[cand][1]}')

            #performing merging only for NE candidates of the same type
            if 'ne' in candidate_list[longer_cand][3]:
                #mark for merging if the head and its head's cand type is the same for 2 candidates

                if candidate_list[longer_cand][1] == candidate_list[cand][1] and candidate_list[longer_cand][3] == candidate_list[cand][3]:
                    print(f'matching "{longer_cand}" with "{cand}"')
                    #print(f'{candidate_list[longer_cand][1]} ===== {candidate_list[cand][1]}')
                    indices_to_remove.add(cand)
    return indices_to_remove

def merge_indices(cand_df,indices_to_remove):                

    print(f'Initial amount of candidates: {len(cand_df)}')                
    #print(len(sorted(indices_to_remove)))

    for index in reversed(sorted(indices_to_remove)):
        cand_df.drop([index],inplace=True)
        
    cand_df.reset_index(drop=True,inplace=True)
    print(f'Amount of candidates: {len(cand_df)}, after removing {len(sorted(indices_to_remove))} indices') 
    return cand_df


cand_df = merge_indices(cand_df, merging_step1(cand_df['candidates']))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1613/1613 [00:04<00:00, 328.16it/s]
# Initial amount of candidates: 1613
# Amount of candidates: 1613, after removing 0 indices

# %%
cand_df['candidates'][250][0]
# Out:
# '13,000 migrants & asylum seekers'

# %% [markdown]
# ### Second merging step
#
# We merge 2 candidates if their sets of phrases heads are semantically similar

# %%
import gensim

#load the GoogleNews 300dim model (fix path)
model = gensim.models.KeyedVectors.load_word2vec_format(r'C:\Users\nikodemicek\Dropbox (CBS)\Master thesis data\GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine
import numpy as np

#adjust for sets of phrases in the candidate
def merging_step2(candidate_list):
    
    indices_to_remove = set()
    for longer_cand in tqdm(range(len(candidate_list))):     
        i = candidate_list[longer_cand]
        long_cand_mean_vec = phrase_heads_avg_vector(candidate_list[longer_cand][2])
        for cand in range(longer_cand+1,len(candidate_list)): 
            #print(f'for index {candidate_list.index(longer_cand)} checking the index {candidate_list.index(cand)}')
            #if candidate_list[longer_cand][1] == candidate_list[cand][1]:
                #print(f'matching "{longer_cand}" with "{cand}"')
            cand_mean_vec = phrase_heads_avg_vector(candidate_list[cand][2])

            if candidate_list[longer_cand][3] == candidate_list[cand][3]:
                try:
                    #print(1-cosine(long_cand_mean_vec,cand_mean_vec))
                    #print(long_cand_mean_vec.reshape(-1,1).shape, cand_mean_vec.reshape(1,-1).shape)
                    if 1-cosine(long_cand_mean_vec.reshape(-1,1),cand_mean_vec.reshape(-1,1)) >= 0.5:
                        #print(f'matching "{longer_cand}" with "{cand}"') 
                        indices_to_remove.add(cand)
                except AttributeError:
                    pass

            else:
                try:
                    if 1-cosine(long_cand_mean_vec.reshape(-1,1),cand_mean_vec.reshape(-1,1)) >= 0.7:
                        #print(f'matching "{longer_cand}" with "{cand}"') 
                        indices_to_remove.add(cand)
                        
                except AttributeError:
                    pass


    return indices_to_remove

def phrase_heads_avg_vector(phrase_set):
    phrase_head_vectors = []
    for phrase_head in phrase_set:    
        try:
            phrase_head_vectors.append(model[phrase_head])
        except KeyError:
            pass
    #phrase_head_vectors = [model[phrase_head] for phrase_head in phrase_set]
    if len(phrase_head_vectors) != 0:
        return np.mean(phrase_head_vectors,axis=0)
    else: 
        return np.NaN

        

cand_df = merge_indices(cand_df, merging_step2(cand_df['candidates']))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1613/1613 [02:35<00:00, 10.36it/s]
# Initial amount of candidates: 1613
# Amount of candidates: 374, after removing 1239 indices

# %%
cand_df['candidates'][63][2]
# Out:
# {'camps', 'conditions', 'improvement', 'refugees'}

# %% [markdown]
# ## Third merging step representative labeling
#
# currently working on average cosine similarity of each phrase in the candidate - maybe not optimal, maybe it will be better with a different threshold

# %%
from sklearn.cluster import AffinityPropagation

from sklearn.metrics.pairwise import cosine_similarity

def merging_step3(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:  
        #the head of noun phrase is marked with value 0 for the word.head
        np_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]
        #np_pos_tags = {word.text: word.xpos for sent in doc.sentences for word in sent.words}
        #print(np_heads_pos)
        cand_np_phrases = []
        for word, head, pos in np_heads_pos:
            #head-1 because the pointer to head does not use 0 index
            if (pos == 'JJ' or pos=='VBN') and 'NN' in np_heads_pos[head-1][2]:
                cand_np_phrases.append(f'{word}_{np_heads_pos[head-1][0]}')
        phrases.append(cand_np_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for longer_cand in range(len(candidate_list)):     
        i = candidate_list[longer_cand]
        long_cand_vectors = phrases_vectors(phrases[longer_cand])
        if len(long_cand_vectors)==0:
            pass
        else:
            for cand in range(longer_cand+1,len(candidate_list)): 
                short_cand_vectors = phrases_vectors(phrases[cand])
                if len(short_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(long_cand_vectors),len(short_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(long_cand_vectors)):
                        for j in range(len(short_cand_vectors)):

                            sim_matrix[i][j] = cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1))

                                
                    if np.mean(sim_matrix) > 0.3:
                        #print(f'{longer_cand} and {cand} are {numpy.mean(sim_matrix)} similar' )
                        indices_to_remove.add(cand)
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove
                


def phrases_vectors(cand_phrases):
    
#for cand_phrases in phrases:
    #print(cand_phrases)
    cand_phrase_vectors = []
    for phrase in cand_phrases:
        try:
            cand_phrase_vectors.append(model[phrase])
            #print(f'for existing phrase "{phrase}" the vector is {model[phrase][0]}')
        except KeyError:
            phrase_words = phrase.split('_')
            #print(model[phrase_words[1]])
            try:
                phrase_vectors = [model[phrase_word] for phrase_word in phrase_words]
                #print(f'for phrase "{phrase}" avg vector is "{sum(phrase_vectors)/len(phrase_vectors)}') 
                cand_phrase_vectors.append(sum(phrase_vectors)/len(phrase_vectors))
            except KeyError:
                pass
    #print(len(cand_phrase_vectors))
    return cand_phrase_vectors
    
    
cand_df = merge_indices(cand_df, merging_step3(cand_df))
#print(indices_to_remove)
# Out:
# Initial amount of candidates: 374
# Amount of candidates: 297, after removing 77 indices

# %%
for cand in cand_df['cand_text']:
    print(cand)
# Out:
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# UNHCRs Assistant High Commissioners for Protection and O . . .
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# all those rescued on an empty cruise ship
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# Syrian Refugees, which has stolen Refugees' money
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# purchase vital medication and equipment
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# The turkish coast guard arest
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Erdogan Greed for Gas
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# their point of view
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# guns and tear gas
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# enoug of a fu
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# the asylum system
# a sensible solution
# The right wing
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# a smart phone
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# their experiences
# refugee overcrowding
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# Rights groups
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# Anastasa Sikiaridi
# severe claustrophobia
# our culture
# <3 film
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# Heute ab
# gas Exploration
# my home
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# The answer
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# their taxes
# 2018
# He
# there
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Eedogan
# Donations
# self-interest
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# /
# Doctors
# 10000
# @CERCmigration
# Omfg
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece

# %% [markdown]
# ### Merging step 4

# %%
# missing the second method - we check for the lexical identity of specific stems in multiple candidates.

def merging_step4(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:

        #the head of noun phrase is marked with value 0 for the word.head
        np_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]

        #print(np_heads_pos)
        cand_np_phrases = []
        for word, head, pos in np_heads_pos:
            i = np_heads_pos.index((word, head, pos))
            #print(np_heads_pos)
            #print(np_heads_pos[i])
            #print(np_heads_pos[head-1])
            #'NN' in np_heads_pos[head-1][2] and
            try:
                if 'NN' in pos and 'NN' in np_heads_pos[i+1][2] : 
                    cand_np_phrases.append(f'{word}_{np_heads_pos[i+1][0]}')
                if 'NN' in pos and 'NN' in np_heads_pos[head-1][2]:
                    cand_np_phrases.append(f'{word}_{np_heads_pos[head-1][0]}')
            except IndexError:
                pass
        phrases.append(cand_np_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for longer_cand in range(len(candidate_list)):     
        i = candidate_list[longer_cand]
        long_cand_vectors = phrases_vectors(phrases[longer_cand])
        if len(long_cand_vectors)==0:
            pass
        else:
            for cand in range(longer_cand+1,len(candidate_list)): 
                short_cand_vectors = phrases_vectors(phrases[cand])
                if len(short_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(long_cand_vectors),len(short_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(long_cand_vectors)):
                        for j in range(len(short_cand_vectors)):
                            #print(cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)))
                            sim_matrix[i][j] = cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1))
                            """if cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.4:                
                                sim_matrix[i][j] = 2
                            elif cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.2:
                                sim_matrix[i][j] = 1
                            else:
                                sim_matrix[i][j] = 0"""

                                
                    if np.mean(sim_matrix) > 0.6:
                        print(f'{longer_cand} and {cand} are {np.mean(sim_matrix)} similar' )
                        indices_to_remove.add(cand)
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove

cand_df = merge_indices(cand_df, merging_step4(cand_df))
#print(merging_step4(candidate_list))
# Out:
# 2 and 34 are 0.6444906344016393 similar
# 2 and 129 are 0.6352750410636266 similar
# 2 and 142 are 0.6738031804561615 similar
# 29 and 119 are 0.6717105408509573 similar
# 34 and 129 are 0.6940330862998962 similar
# 34 and 142 are 0.6754783987998962 similar
# 49 and 104 are 0.6065908074378967 similar
# 129 and 142 are 0.6704616546630859 similar
# Initial amount of candidates: 297
# Amount of candidates: 292, after removing 5 indices

# %%
for cand in cand_df['cand_text']:
    print(cand)
# Out:
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece

# %% [markdown]
# ### Merging step 5

# %%
for i in event_df['Tweet Raw'][:100]:
    print(i)
# Out:
# @sztiv5 @Juliivan_ Yes, why? Why it wasn’t good to apply for asylum in Greece, MAC, SER or CRO or BUL, together 3 EU members before HU? They must get help in the first safe country as asylum seeker,not in the 5th. No law says you can pick and choose and get it.
# @GoTurkey ISIS refuge. Wouldn't go to Turkey if I was paid. You're likely to get your head lopped off if you stray off the beaten track. Go to Christian Greece and be safe while enjoying a similar climate to islamic turkey
# Greece must improve refugee overcrowding, UN warns https://t.co/UDM4GDMcmo
# @ThisIsOzcan @Nervana_1 @EGozuguzelli 1/3 Law? Let the idle stuff. All rights of the Turkish minority in Greece were taken away. Where is the law? Refugees are not accepted into the EU. Where is the law? Western states divided the states in the Middle East and Africa for underground resources. Where is the law?
# @Juliivan_ @sztiv5 Anyway, how did the asylum seekers ended up at HU borders? They must have had a long journey through Greece, where they must apply for help, yet they travelled through multiple more countries, why?
# I never loved #photograpy pushing aesthetic into #news cause it is a potential embellishments of hard facts and harsh reality.I like raw realism. Did I pass this boundary using @FiLMiCPro #firstlight this week in #Lesbos infamous Moria #migrants camp? That’s a big question4me https://t.co/rlEZP5mXmd
# @YOsmanli1453 @ArisKallimachos @GreeceMFA ManfredWeber: It must be made clear that Europe and Germany are on the side of Greece. The German MFA must be careful not to be blackmailed in fear of a new refugee crisis.
# Refugee Covid case sparks 'closed camps' fears on Lesbos | Greece | The Guardian https://t.co/hp8JcOf8dB
# 9PM Coronavirus UK LIVE: Leeds on brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn
# @Iceman070259590 @OPCW @realDonaldTrump @mikepompeo Are you sure you' re talking about France and not Turkey? Turkey has invaded parts of Syria, bombs Iraq, conducts a proxy war in Libya creating refugees. On top of that, it violates Greece's and Cyprus' sovereignties. Not to mention that it provides safe heaven for Hamas.
# @realPR_Phoenix @DrEstella @BravoTV Raquel Bessudo is Isaac Bessudo’s widow. The Bessudos were Sephardic Jewish immigrants from Salonica, Greece. Raquel’s parents were Polish Jews. Raquel is blonde and blue eyed though
# @Mproyklis @fragoua @LearnerLerner @mr_markjacobs Most of them immigrated to Greece by their will.
# @maskeIiyorum First you stuff they Turkey, then you bake it, and at last you eat it!!! Be kind to your women, they are very welcome to seek asylum in Greece just like your army and people are doing. Leaving crazy ruled Turkey. Ah Siktir
# Five years later: How September 5th, 2015, became a #Crossroads for the #Migration crisis | DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey
# Record numbers of illegal migrants crossing into the United States as the United Kingdom right now and only Greece seems to keep the border under control. It worries me this is part of the new normal - @WashTimes https://t.co/1kcyzbLICS
# Refugee virus cases spark fears in Lesbos. (Guardian) Story: https://t.co/ocQHAk5gZf
# @fundabezos @dimi_par @Arda7517 @HSajwanization Illegal immigration is not a problem of GREECE or EUROPE.....
# @kaitlancollins 2. From severe claustrophobia his entire life. Both men were not losers they knew why they enlisted it was to appease their Fathers by giving thanks to America for taking them in as immigrants from Greece in 1914. The Trump family never once walking in military boots.
# Greece pushes back 10 refugees, including three children with disabilities. Those refugees were fleeing Erdogan. Greece is betraying european union values. @coe @Europarl_EN @vonderleyen @NachoSAmor @hrw https://t.co/ESiuIqr6jc @tr724 aracılığıyla
# https://t.co/L9k1uLNc97 Two high ranking UN Refugee Agency officials on Friday ended a visit to Greece calling for a drastic improvement in the living conditions of refugees in camps, Anadolu Agency reports. UNHCR’s Assistant High Commissioners for Protection and O ...
# UN: Greece must improve refugee overcrowding https://t.co/QArN0pGNlz
# @TerribleWyvern Switzerland? But honestly, I reckon its more likely to happen in the Balkans. Greece stranded a bunch of illegal immigrants in the middle of the sea. Plus theres the growing tension with Turkey. So a stronger, motivated govt might just start booting out Erdogans ersatz invaders.
# @ghost_wales To be fair, since when did the EU stop illegal immigration? I don't think the people of Greece got that particular memo.....
# For 4 years, we have offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support to child & youth #refugees in northern Greece. With your help, we can continue this work for another 4 years in another 4 countries. Please donate: https://t.co/Gv3840hqCh
# Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/2EiOcJOBMf
# @Ishaxk0 @VinceVole @EmmanuelCohen65 @DonnyBoy12 So how do you explain mass immigration into Sweden, Austria, Norway, Finland, Denmark, Greece, or pressure on Poland, Bulgaria, Hungary, Slovenia, Serbia & other European countries to accept mass migration?
# @swissquiz @Paul_Phillips20 @chaipatel0 @Nigel_Farage In 2018, the #UK received applications for #Asylum for 37,453 people (including #dependants). This is far less than #Germany (162,000), #France (110,000), #Greece (65,000) and #Italy (49,000).
# Enterprise Greece is joining in this effort, as they aim to migrate their many services and resources online by the end of the year. And their strategic partnership with @eBay will further boost Greek SMEs, ensuring that they can access such a high-level international platform.
# UNHCR's Assistant High Commissioners visit Greece, discuss refugee protection challenges and urge more support https://t.co/narldvFNQ5 https://t.co/G0ntxgzdgG
# @McFaul I worked in a couple of refugee camps in Greece & WiFi there was a given, more or less a basic human right like water and food, as they were people who often had very few possessions with them but a smart phone was precious & the only means of contact to their relatives.
# @Complyordie4 @guardian He shouldn't be there. He was granted asylum and had left for Athens in July. In August he returned to Lesvos and lived in a tent next to the official camp. Anarchy reigns in Moria. Nobody follows the rules.There have been deadly attacks. This is why closed camps are a necessity.
# @NicAthens @ManfredWeber @HeikoMaas Erdoğan holds the cards. He can unless ya million refugees and what would Greece do
# @Richard021051 @MigrationWatch Belgium: 1/10 of UK size, 1/2 of asylum seekers. Greece: 1/2 of UK size, twice of asylum seekers.
# @1Fubar It was obvious many would be infected, that's the issue with the migrants Erdogan is pushing into Greece from Turkey.
# @guardian The infected person, a 40 year old man, was granted asylum. He left from the camp in July, went to Athens and returned to Moria in August, to live in a tent next to the camp. (Didn't think it's Hell) Closed camps will give an oversight and put an end to the anarchy in Moria!
# In Greece we have had very constructive and open exchanges with authorities on the need to safeguard the right to seek asylum, to ensure access to territory for those in need of protection and to investigate the reports of pushbacks at land and sea: https://t.co/8IUcI3sJCl
# Greece has opened its arms to thousands of refugees. However, critical issues urgently need to be addressed. Asst. High Commissioners for Protection & Operations, @GillianTriggs & @RaoufMazou, conclude their visit to 🇬🇷 with a message of solidarity. https://t.co/lfrOmvMDMg https://t.co/oFGzJj03bA
# @tomyork5 @trtworld Btw, why should I take refuge in a 3rd class eastern European country like #Greece, while I already living the life you could not even imagine, in a country that has been your dreams for centuries, let alone the economy of Greece that needs Turkish tourists? Welcome t real world. https://t.co/hriifehDf4
# @tomyork5 @trtworld speaking of which, this is how #Greece behave towards real refugees https://t.co/HbS7NW9WYO
# @tomyork5 @trtworld This is no surprise that Greece shelters those FETÖ members who attempted a failed coup in Turkey. Defining these fugitive terrorists as asylum seekers is precisely a definition worthy of a people who have competed with the PKK over the issue of being more lowness. https://t.co/SLFeNaztJs
# @MigrationWatch Greece seems to have a sensible solution not sure why this has not been suggested? Surly a smallish length would be enough to make the direct route not direct? https://t.co/tBV5XMso8O
# During their visit to Greece, UNHCR’s Assistant High Commissioners @GillianTriggs & @RaoufMazou met with refugees, discussed with authorities and NGOs refugee protection challenges & repeated the call for more support and EU solidarity. https://t.co/DmuUK7tRel
# @Dardanoi25 @protoALB @Arjan @bardylius @TeamAlbanians @Deni_Hoxha @FPodrimja More evidence comes out that Illyrian/Albanian migration into Greece has been happening for thousands of years (not just with Arvanites) and Illyrians may have had a larger presence in mainland Greece than previously thought.
# @vtaonmtdiyene @trtworld Feel good for you that you have pro-government opinion. Else you would be in prison, afraid to talk or asking asylum from Greece. https://t.co/OoVOPzR2Ug
# @WW3Info @NicAthens @AlexanKazamias @WilliamCDoll @TamelaTweets @Pirgakis @JFCrisp @RaphJustine @Rakinas_A #Gas Exploration have created tension between Turkey-Greece. This Dialogue won't work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset. Erdogan Greed for Gas will not end with Sanctions #ThirdWorldWar #RafaleJets #Mediterranean
# I covered the migrant crises in 2015, traveling the migrant route up through Greece to Macedonia and then near Kosovo border and to Serbia and Hungary. I met many nice local people on the way who hosted me and spoke to me.
# #covid19Gr #refugeesGr #Lesvos @MSFgreece on #Moria camp lockdown :Covid is used as an excuse to limit freedoms and rights of people seeking safety in Europe https://t.co/xIbCWkpyLL
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# @tomyork5 Those who seek refuge in Greece, those who want to make a coup. Because they know that Greece loves this kind of people. Use some brain. Don't always shout with your own perspective. What you call freedom of expression is terrorist propaganda and doing it is a crime.
# Authorities in Greece have placed the Moria #refugee camp on the island of Lesbos under quarantine after the confirmation of the first coronavirus infection in the notoriously overcrowded facility. https://t.co/7LIWIhTngH
# @229Leckie @MontgomeryClif8 @scot_unionist @paulmasonnews by 2040 the north shore of the med will have the climate of the south, no tomatoes in Spain, grain in Italy, grapes in south France or olives in Greece; Europe will have 200 million European climate refugees. Who even knows if there will be an EU or what it's rules are by 2040
# People should spare Greece for a moment but don't get me wrong. I'm not defending them after it emerged they threw 1000 immigrants into the ocean & left them to die.... but why should this poor nation carry this burden yet the world was silent when Obama destroyed Libya.
# @AmysGotBirds @DonaldJTrumpJr To start this war, Erdogan and Turkey (which is part of NATO) has allowed Syrian refugees into his country...only they aren't Syrian. They are Afghani, Somali, and Iraqi. He is allowing these refugees to flood into Greece, and Europe. They are armed with guns and tear gas.
# UNHCR’s Assistant High Commissioners visit #Greece, discuss #refugee protection challenges and issues relating to access to territory & asylum, living conditions on mainland & islands, the management of the #COVID19 response, integration https://t.co/0dZTraZGi3 https://t.co/E411e2Cp8P
# #DevelopmentNewsUpdate Over 200,000 lone #child #migrants left to #uncertain #fates in #Europe Read the full article at https://t.co/sv8bIVmKO0 #Europe #riskofexploitation #children #safety #Greece #detentionofchildren #conflict #protectionbeyondreach #migrants #twentylakhs https://t.co/lMiEC07BYe
# @realPR_Phoenix @DrEstella Estella’s family immigrated from Greece and Lithuania and became wealthy by owning a toy factory
# @Nicolas98869551 @Marflo66036248 @Esref_Doguu Who does say this? Is it a Greek? It is The Greece which has made a hole in Syrian Refugees' boats and which has beat Syrian Refugees, which has stolen Refugees' money. 😂😂😂
# If your kids have gone #BackToSchool, do you suddenly appreciate the time you have for other things? SOS provide childcare to families who are struggling, so parents/carers can study or find work. Find out more about our work in a refugee camp in Lesvos ➡️ https://t.co/t8GEChlGFg https://t.co/oWWet2GJex
# @devilxbrain @ragipsoylu Take the 5+ million refugees and then https://t.co/XXT3mjLDCs if you care for them.I can easily say they are living in much better conditions in Turkey compared to Greece.
# #Greece and its people have shown great hospitality for 100 of thousands #refugees and #migrants since 2015. But a lot remains to be done to meet critical needs and improve conditions on islands. We need continued solidarity from #EU and European States. https://t.co/LivzhA3RXL
# Wales has added Portugal and parts of Greek Island on the list not to visit, yet England does not #torychaos #Covid_19 Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/jefOiklxow
# We’re all in this together and no one should be left behind! The #refugees in Greek islands must be urgently protected from #COVID19 – Take action now and send an email to Prime Minister of #Greece, @primeministergr to act immediately! #coronavirus https://t.co/NQOH3cOVbD
# #Attention!!!! Illegal immigrant try to steal a local mini market in #Soufli , #Greece!!! @akrokentrwos https://t.co/wiowPSF8pF
# A photo to give you an impression of the food in #Moria. If you guess what it is, it will be delivered free of charge for one month. #Delicious #EU #Refugees #LeaveNoOneBehind #SaveThem
# @griko84 @BwanaPjotr @fk_akis @MEMRIReports You said Muslim factions that Greece dosnt melt in betwen them it does so yea. Greece gives enoug of a fu* to support Assad and open realtionship with him so yea. If its our mess then EU should stop melding into it too. But it does so yea. Take the refugees then.
# #Moria: A food strike takes place. ~100 refugees have blocked the supply of ready-made food to protest against the poor quality of the it. More bad than good it's supplied by a private/public joint venture. #LeaverNoOneBehind #RefugeesGR
# @YinkaOgundipe @EmmanuelAcho Well obviously you don’t know Giannis story. He had nothing until he was 17. Because he was born in Greece and Nigerian embassy in Athens refused him a passport cause his parents left Nigeria as refugees.Only after Greece gave him one , Nigeria said they will suit
# Greece has shown great solidarity towards 1000s of refugees + asylum-seekers. There are critical gaps + issues that need addressing. Other EU States need to also show solidarity including by relocating vulnerable asylum seekers. The situation is manageable https://t.co/MWxUHH0sZb
# @YavuzBiH @fk_akis @MEMRIReports 1)EU is not supporting Assad 2) if you are gonna blame Greece for any ME wars (that Turkey takes part in), colonialism or anything else, try harder. By the way, less than 15% of current “refugees” in Greece are from Syria.
# 1st #Covid_19 case confirmed in #Moria. Within 10 days, #Coronavirus could sweep through the overcrowded #refugee camp, with devastating consequences. We need URGENT FUNDS to keep our clinic doors open and purchase vital medication and equipment. #DONATE: https://t.co/a1gCVgOdcR
# Lesbos refugee camp in quarantine due to Somali migrant infected with coronavirus https://t.co/qBdLXSjkdG
# @Tarzan35715351 @0khalodi0 Unfortunately it’s a fact that ISIS member find a passage through illegal immigration in Europe. And most likely you referring to some NATO members. Portugal never funded neither Greece as an example and neither agreed.
# @maximusmadham @EndGameWW3 Maybe you speak for Albanian greeks. I don't give a shit about anyone of them. I only support greeks that living in Greece not traitors and refugees
# There are critical issues that must be addressed, incl the urgent need 2 drastically improve living conditions +reduce overcrowding at the reception facilities on the Aegean Islands - @RaoufMazou on #Greece #asylum #Europe #Solidarity https://t.co/H3yhHqly4g via @refugees
# Greece and its people have shown tremendous solidarity and compassion with thousands of refugees and asylum-seekers, despite all the challenges the country has faced, including a severe economic crisis and now the COVID-19 pandemic - @RaoufMazou https://t.co/WDVFsQS0sk
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 https://t.co/j9bKQUVcBR #Greece #news
# @bethvaughan15 @SueSuezep @Jacob_Rees_Mogg Britain still done far less asylum applications than other European country, Germany, France and Greece did a hell of a lot more....
# fight for hope - the states should not push people seeking asylum back to unsafe countries! is this what happens in the Aegean sea? #migrants #refugees #AsylumSeekers #Turkey #Ankara #Greece #Syria #Iraq #MiddleEast #Pakistan #Afghanistan #Honduras #ElSalvador #Mexico #Guatemala https://t.co/ROQxjEgfjA
# @sarianpaul1 @pritipatel This idea that the uk is being overwhelmed is absolute pure dogshite. 85% of the world's refugees live in countries adjacent to the one their fled. The uk took 3 x less asylum applications than France last year, 4x less than Germany, 2x less than Spain and Greece. Get over it.
# @0khalodi0 In Greece the majority of immigrants are from Pakistan and Afghanistan and Bagladesh. It was not long ago when the catch an ISIS member in Spain. Guess from where passed first, Greece! Europe is in danger.
# Refugee Covid case sparks 'closed camps' fears on Lesbos | Global development | The Guardian : https://t.co/90q629G4gV #santé
# @no_eyed_ryan I'm Greek, many in America consider Greeks white because white westerners claimed our culture, history and ethnic heritage as theirs. Greek immigrants didn't leave their culture behind in fact they suffered under white supremacy both in Greece and in white colonised countries.
# @devilxbrain @ragipsoylu You are hypocritical. Greece closes the gates for your so called ‘poor’ refugees. So what makes them better ?
# @DrManha84708484 @Eos303 @Nervana_1 @EGozuguzelli Did you ever see Greeks that go to Turkey and ask for asylum? The answer is NO. But we see thousands of Turks every day that come to Greece and ask for asylum. What's wrong with Turkey?
# Migrant shelter for unsupervised minors in Greece quarantined following coronavirus outbreak — RT World News https://t.co/qeh1vETr89
# #COVID19 measures in #Greece #AsylumSeekers & #Refugees on #Lesbos. When will those poor people be rescued from this living hell? https://t.co/tzqE7pT812
# @gerdosi @paulmelzer1 @nmlinguaphile The funniest thing is no country closed its borders to stop it. It was to slow the spread. History (the Cordon Sanitaire&more), recent flare ups in TX&Florida (migrants from Mexico&Caribbean), Greece early closing vs Spain' s late 1,etc. are facts undermining your general stateme
# @lk2015r @LevidisStefanos When I started my fieldwork in İzmir in 2008 summer, pushed back refugees were telling me their experiences at sea. There were also sent back migrants according to the bilateral agreement who had detention experience in Greece.
# @DartmoorSounds @guyverhofstadt i'll be going to the Cayman Islands! FOR MY WINTER BREAK! Where you going in the EU, Sunlit EU beaches with dead migrants on you mean! due to the EU not caring about people crossing sea's in little boats! greece and now the Channel yet still they do nothing
# This is the second year that we have supported this Appeal for Hope and Kindness. All of the money will be used to provide nappies for babies in Refugee camps in #Greece. Donations will bring hope to a mother and comfort to her baby. #FiveForHope https://t.co/jWuPRixilI https://t.co/j99DHJ2ldK
# Current UNHCR numbers #Lesvos: 14,007 #refugeesgr reside on island. Majority from #Afghanistan (76%), #Syria (7%) and Democratic Republic of the #Congo (7%). Women account for 23% of population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old. /1 https://t.co/4OTIv9tk3X
# @CllrBarryLewis Anyway, we still have a responsibility to take at least some of these people in if they need it. Otherwise your line of reasoning suggests Italy and Greece, or the other primary landing countries, should basically take all the refugees, which hardly seems fair.
# Greece has a deadly new migration policy – and all of Europe is to blame | Every time Athens pushes a refugee boat away, it’s the result of an entire continent acting in its perceived self-interest https://t.co/9sEKKQ6tBy https://t.co/Im5ShhraQF
# COVID-19: Greece reports first coronavirus case in Moria migrant camp on Lesbos https://t.co/wWgaCNZ6UE
# @jensstoltenberg @EGozuguzelli @RTErdogan @NATO Greek militans kil.ling poor immigrants. Racist unlawfull greece. https://t.co/ZKkNKqDgXI
# War conflicts, migrations, diseases... That's how a waterless region is💧 From EIT we are facing that problem by getting together the best ideas in our online event #InnowiseChallengeLabs. Join the Greece event on 15 september at 4 PM! 🇬🇷
# @EastMedMonitor 4 million migrants housed in turkey!if Greece gets its 12 mile maritime territory all turkey needs to do is get them to walk into the sea and they are in the EU in many areas😂😂😂
# @_ErcanButun @LegendofBaba You are to be https://t.co/uQO4C8nZCw fooled all these poor people that the borders are open and you carried them by thousands to enter Greece.Your sneaky political game didn't succeed. You are animals for manipulating refuges.
# The first recorded coronavirus case in Moria refugee camp on Lesbos, where just under 13,000 people are l..... to leave. Check on https://t.co/5jbWReoMR1 @scwacy
# @hvvnfd @jedijig @KostasAntLavdas @jensstoltenberg I thing this didn't go on because Turkey want just the Aegean but Greece want both aegean and kastelorizo eez. In any case that are history now Greece propose it and Turkey refuge. This is the truth.

# %% [markdown]
# ## Frame identification

# %%
"""frame_properties = {'affection':['affection','attachment', 'devotion', 'fondness','love','passion'],
                    'refusal': ['refusal','declination','denial','disallowance','nay','no'],
                    'trustworthiness':['trustworthiness','integrity','accuracy','credibility','authenticity','fairness'],
                    'no trustworthiness':['falsehood','dishonesty','unfairness','deceit','corruption'],
                    'reason': ['reason','logic','sense','rationale','argument','justification'],
                    'unreason/irrationality': ['unreason','irrationality','fallaciousness','unsoundness'],
                    'easiness': ['easiness','simplicity','obviousness','ease','comfort'],
                    'difficulty': ['difficulty','adversity','hardship','crisis','obstacle','trouble' ],
                    'honor': ['honor', 'dignity','esteem','reputation','praise'],
                    'dishonor': ['disgrace','dishonor','reproach','opprobrium']}""" #from Hamborg's paper

# from paper Shifting the refugee narratives? by Greussing & Boomgaarden (2015)
frame_properties = {'settlement':['settlement','accomodation','permanent','temporary','barracks','accommodated','tent','camp', 'shelter'],
                   'reception':['quota', 'distribution', 'limit', 'selection','reception','together','asylum','receive'],
                    'security':['security', 'border','crossing','fence','control','flow'],
                    'criminality':['officer','terror','suspicion','crime','offense','police','trafficking','suspect'],
                    'economisation':['euro','economic','million','thousand','cost','money'],
                    'humanitarian':['humane','voluntary','help','support','aid','care','solidarity'],
                    'victimization':['islamic','fight','victim','war','dead','rescued','state'],
                    'integration': ['labour','employed','unemployed','integration','positive'],
                    
                    #from hamborg
                    'affection':['affection','attachment', 'devotion', 'fondness','love','passion'],
                    'refusal': ['refusal','declination','denial','disallowance','nay','no'],
                    'trustworthiness':['trustworthiness','integrity','accuracy','credibility','authenticity','fairness'],
                    'no trustworthiness':['falsehood','dishonesty','unfairness','deceit','corruption'],
                    'reason': ['reason','logic','sense','rationale','argument','justification'],
                    'unreason/irrationality': ['unreason','irrationality','fallaciousness','unsoundness'],
                    'easiness': ['easiness','simplicity','obviousness','ease','comfort'],
                    'difficulty': ['difficulty','adversity','hardship','crisis','obstacle','trouble' ],
                    'honor': ['honor', 'dignity','esteem','reputation','praise'],
                    'dishonor': ['disgrace','dishonor','reproach','opprobrium']
                   
                   }

# %%
import conceptnet_lite as cn
import gensim.downloader as api


manual_cands = ['refugee','muslim','migrant','christian','immigrant','israel','arab','syrian']

# to run on the server we should use larger model according to the paper - "conceptnet-numberbatch-17-06-300"
#model = api.load("glove-twitter-200")
# Out:
# [==================================================] 100.0% 758.5/758.5MB downloaded
# @Kkkk09240868
# @0khalodi0
# @POTUS
# Also,
# Eedogan
# has
# been
# documented
# using
# ISIS
# militants
# aka
# terrorists,
# he
# played
# the
# immigrants
# card
# as
# a
# way
# to
# political
# threat
# to
# Europe,
# he
# pushed
# immigrants
# to
# greece
# and
# europe
# for
# their
# own
# death,
# after
# letting
# them
# homeless
# for
# years
# As
# I
# said,
# All
# Muslims
# are
# guilty
# @Nionios1908
# @kitsikis
# Greece
# unable
# to
# cope
# with
# 60
# thousand
# refugees
# with
# a
# population
# of
# 10
# million.
# and
# the
# border
# next
# to
# it
# wants
# a
# country
# of
# 83
# million
# to
# be
# torn
# apart.
# God,
# I've
# never
# seen
# a
# fool
# like
# you
# together
# in
# my
# life.
# the
# problem
# is,
# you're
# all
# idiots.😂
# @hama_ashad
# @realDonaldTrump
# and
# from
# there
# you
# can
# try
# to
# pass
# Europe
# especially
# Greece
# there
# are
# lots
# of
# boats
# you
# know
# but
# you
# have
# to
# know
# you
# might
# die
# from
# all
# of
# that
# this
# refugge
# thing
# is
# very
# fishy
# @hama_ashad
# @realDonaldTrump
# I
# dont
# know.
# I
# dont
# live
# in
# Iraq.
# In
# Europe
# many
# migrants
# walked
# from
# Greece
# to
# Norway/sweden/Germany.
# I
# guess
# you
# can
# do
# the
# same.
# Just
# from
# Iraq
# to
# Greece.
# The
# life
# as
# migrant
# is
# awful
# thogh.
# Must
# live
# in
# awful
# camps
# too
# the
# government
# say
# you
# are
# a
# real
# refugee.
# #travel
# #news
# :
# Migrants:
# MSF,
# cruel
# quarantine
# of
# Moria
# on
# Lesbos
# https://t.co/ghNe7hYHgJ
# @Antignoramus
# @jensstoltenberg
# Happy
# to
# make
# you
# laugh.
# Unfortunately,
# a
# lot
# of
# the
# Turkish
# people,
# lawyers,
# teachers,
# officers,
# judges
# and
# civil
# servants
# are
# either
# in
# jail
# or
# seeking
# asylum
# in
# Europe
# (Greece
# as
# well)
# not
# laughing,
# because
# of
# Erdogan.
# Combined
# with
# his
# warmongering,
# comparisons
# are
# inevitable
# @LucieH20
# @MigrationWatch
# @RosinaFrance
# It's
# a
# shame
# Greece
# learned
# that
# too
# late.
# Where
# as
# Eastern
# Europe
# has
# had
# plans
# in
# place
# from
# the
# start.
# They
# know
# the
# endgame
# of
# allowing
# unmitigated/unchecked
# illegal
# migration
# from
# the
# Middle
# East
# and
# Africa.
# the
# bosses
# Roger
# biland
# Daniele
# Francois
# sins
# 1984
# the
# loive
# of
# kidnapping
# are
# with
# rene
# biland
# the
# kidnapper
# bosses
# they
# order
# sheap
# kidnap
# pay
# for
# e
# vew
# jeer
# arriving
# mountain
# cheese
# shieapnew
# zealand
# greece
# algeria
# club
# med
# migros
# jumbo
# deliveries
# BY
# SYSTEMATIC
# @cappsperhaps
# @pritipatel
# @BritishRedCross
# Why
# do
# they
# travel
# through
# 4/5
# other
# European
# countries
# though
# before
# exercising
# their
# right
# to
# claim
# asylum
# in
# the
# U.K.
# -
# what’s
# wrong
# with
# Greece
# ?
# GLOBALIST
# EU
# NO
# BORDERS:
# Refugee
# Covid
# case
# sparks
# 'closed
# camps'
# fears
# on
# Lesbos
# https://t.co/NXTFgIHBIF
# @RaoufMazou
# @GillianTriggs
# @UNHCRGreece
# Dear
# sir,
# are
# you
# having
# a
# nice
# holiday
# in
# Greece?
# $
# 700
# a
# day
# on
# top
# of
# your
# $
# 20,000
# salary
# to
# see
# what?
# Stay
# in
# Geneva
# and
# host
# 10
# refugees,
# so
# you
# will
# be
# concrete,
# hypocritical
# !!
# @MantiXrmanti
# @PanPan70738015
# @Antignoramus
# @jensstoltenberg
# Only
# thing
# Greece
# is
# now
# famous
# for
# is
# killing
# refugees
# and
# being
# bankrupt.
# @PauloNoggy
# @LegendofBaba
# 2
# claims
# in
# NYT:
# Greece
# is
# taking
# people
# from
# camps
# on
# land
# then
# dumping
# them
# &
# it
# is
# pushing
# back
# boats
# coming
# from
# Turkey
# (it
# is
# doing
# this,
# not
# all
# but
# some
# boats).
# Source
# back
# up
# the
# latter
# claim
# (HRW
# &
# NGOs).
# Former
# claim
# is
# backed
# by
# Turkish
# military
# &
# a
# refugee
# woman.
# Hello
# 🌎
# My
# names
# Mujtaba
# and
# I’m
# from
# Afganistan.
# I
# fled
# my
# home
# with
# my
# family
# seeking
# safety
# and
# I
# am
# now
# trapped
# in
# a
# refugee
# camp
# in
# Greece.
# I’m
# currently
# sat
# like
# thousands
# of
# others
# without
# access
# to…
# https://t.co/jUmepRRpG4
# @DMiliband
# @GaryLineker
# @yasminkadimusic
# @ColmansSeafood
# @RESCUE_UK
# No-one
# had
# issues
# with
# genuine
# refugees
# Those
# illegally
# coming
# by
# dinghy
# are
# NOT
# They
# are
# coming
# from
# SAFE
# France
# and
# should
# claim
# asylum
# there,
# or
# Italy
# or
# Spain
# or
# Greece
# or
# wherever
# they
# first
# reached
# any
# of
# the
# many
# SAFE
# countries
# they
# have
# passed
# through.
# @RESCUEorg
# Anastasía
# Sikiaridi
# is
# sharing
# her
# experience
# On
# the
# integration
# of
# women
# in
# Refugee
# Camps
# in
# Greece
# #iwomenconnector
# #coping2gather
# #Growing2gather
# #LeadingsResilience
# #WomenTechChangMakers
# #Inclusion
# #RefugeeWomen
# #Empowerment
# #NewWomenVoices4EU
# @Nygard776
# @MigrationWatch
# @RosinaFrance
# Countries
# like
# Greece
# &
# Hungary
# that
# have
# land
# borders
# have
# put
# up
# barriers
# to
# stop
# others
# illegally
# crossing
# into
# their
# country.
# Our
# problem
# is
# the
# same
# but
# harder
# to
# solve
# we
# should
# put
# all
# those
# rescued
# on
# an
# empty
# cruise
# ship
# &
# never
# let
# them
# land
# GdnDevelopment:
# Refugee
# Covid
# case
# sparks
# 'closed
# camps'
# fears
# on
# Lesbos
# https://t.co/e8TUfz9V0h
# @reeta_iceburg
# @MigrationWatch
# Hungary,
# Poland
# &
# Greece
# seem
# to
# have
# done
# something
# IRC
# calls
# for
# urgent
# evacuation
# of
# the
# most
# vulnerable
# refugees,
# as
# first
# Coronavirus
# case
# confirmed
# in
# Moria
# https://t.co/8X38yLjb3b
# And
# why
# come
# here
# instead
# of
# staying
# in
# France,
# Greece,
# Spain
# etc?
# If
# English
# is
# the
# only
# foreign
# language
# you
# know,
# you
# will
# have
# a
# better
# chance
# of
# integrating
# and
# understanding
# the
# whole
# asylum
# process.
# @jjstewart84
# @PaulDulson2
# I
# agree
# the
# asylum
# seekers
# matter
# too
# but
# that
# doesn’t
# mean
# we
# have
# to
# take
# them
# all
# no
# matter
# what
# ..
# they
# came
# through
# France
# Germany
# Italy
# Greece
# etc
# and
# I’m
# sure
# the
# ones
# who
# want
# to
# contribute
# and
# have
# something
# to
# offer
# will
# be
# processed
# successfully
# the
# rest
# go
# back
# Refugee
# Covid
# case
# sparks
# ‘closed
# camps’
# fears
# on
# Lesbos
# |
# Global
# development
# https://t.co/MUU9rd0gMr
# @morentinha
# So
# I
# do
# think
# even
# Greece
# has
# to
# be
# more
# tough.
# There’s
# no
# immigrant
# in
# Birmingham.
# Cause
# that’s
# on
# the
# other
# side.
# And
# even
# if
# you
# see
# 5
# in
# UK.
# Imagine
# how
# many
# are
# in
# the
# entrance
# 😉
# (hundreds
# of
# thousands).
# In
# a
# country
# of
# 10M
# people...
# Current
# #MigrationEU
# policies
# trap
# families
# with
# children
# in
# overcrowded
# +
# unsanitary
# camps
# like
# #Moria.
# 🇬🇷
# Greece
# +
# 🇪🇺
# the
# EU
# must
# overhaul
# the
# asylum
# system
# to
# do
# what
# it
# is
# meant
# to
# do:
# protect
# people
# seeking
# safety.
# 👉https://t.co/aB9PPY1kg5
# https://t.co/mYn5rh7Zw7
# Covid
# refugee
# case
# sparks
# fears
# of
# ‘closed
# camps’
# in
# Lesbos
# |
# Global
# development
# https://t.co/7x2PFXjQw5
# https://t.co/JG4XvGtU3Q
# Greece
# imposes
# dangerous
# lockdown
# of
# Moria
# refugee
# camp
# after
# first
# COVID-19
# case
# @LeeMitc_80
# @brim90
# @GaryLineker
# @RESCUE_UK
# Not
# exactly
# fair,
# is
# it?
# First
# safe
# country
# is
# NEVER
# the
# UK!
# Let
# them
# all
# stay
# in
# overcrowded
# camps
# in
# Greece
# or
# Italy,
# while
# we
# don't
# provide
# safe
# routes
# for
# genuine
# refugees?
# Seeking
# asylum
# is
# not
# illegal.
# Unless
# you
# have
# spoken
# to
# the
# migrants,
# you
# can't
# judge
# them!
# #Refugee
# #COVID19
# case
# sparks
# 'closed
# camps'
# fears
# on
# #Lesbos.
# Greek
# government
# suggests
# need
# for
# ‘closed
# and
# controlled’
# structures
# but
# #NGOs
# fear
# virus
# is
# pretext
# for
# increased
# restrictions
# https://t.co/OkANoHpMyT
# via
# @guardian
# #HumanRights
# #Health
# #Dignity
# A
# total
# of
# 118
# migrants
# flew
# from
# Greece
# to
# Germany
# yesterday.
# The
# transfer
# was
# part
# of
# a
# European
# effort
# to
# get
# hundreds
# of
# vulnerable
# children
# and
# their
# close
# family
# members
# out
# of
# camps
# on
# the
# Greek
# islands
# amid
# the
# coronavirus
# pandemic.
# https://t.co/PhJibrIjFx
# @mariathena
# @thedukeoriginal
# Unfair
# and
# condemnable
# that
# Greece
# has
# received
# 5
# billion
# euros
# for
# refugees
# and
# not
# only
# are
# you
# stealing
# that
# and
# they
# get
# none
# but
# you
# come
# and
# take
# photos
# when
# they
# look
# for
# the
# small
# amount
# they
# need
# to
# eat.
# @MughalLife1
# @pacifier8141
# turkey
# gives
# safe
# haven
# to
# israels
# isis
# terrorists
# they
# trade
# with
# israel
# ,
# threaten
# greece
# ,
# remember
# the
# heavy
# handed
# tactics
# on
# peaceful
# turkish
# protestors,
# too
# much
# control
# over
# the
# media
# ,
# threatens
# to
# flood
# europe
# with
# migrants
# Lesbos
# latest:
# The
# first
# recorded
# coronavirus
# case
# in
# Moria
# refugee
# camp
# on
# Lesbos,
# where
# just
# under
# 13,000
# people
# are
# living
# in
# a
# space
# designed
# for
# 3,000,
# has
# led
# to
# fears
# that
# the
# government
# will
# use
# the
# pandemic
# as
# a
# pretext
# to
# create
# closed
# camps.
# https://t.co/2L3TEu9me6
# @TJ97339066
# This
# is
# why
# places
# in
# South-Central
# Italy
# like
# Umbria
# and
# Marche,
# which
# were
# NEVER
# subjected
# to
# migration
# fluxes
# from
# the
# Middle
# East
# as
# the
# city
# of
# Rome,
# are
# genetically
# related
# to
# Southern
# Italy
# and
# Greece
# rather
# than
# to
# Tuscany
# and
# Northern
# Italy.
# @RBryan275
# @AndyEastAnglia
# @PaulCrackne11
# @JMPSimor
# @carolinenokes
# I've
# worked
# in
# Greece
# with
# refugees
# and
# I've
# been
# to
# the
# camps.
# The
# situation
# is
# much
# more
# significant
# there,
# yet
# you
# have
# very
# few
# people
# saying
# it
# is
# destroying
# their
# country.
# @M_a_t_t__O
# @AbuKarol
# @5COUS3
# @Geojblack
# @BarristerSecret
# Well
# if
# we
# supported
# Greece
# with
# a
# lot
# more
# money
# and
# a
# lot
# more
# safe
# transit
# of
# asylum
# seekers
# who
# keep
# rocking
# up
# there,
# the
# refugees
# might
# be
# safely
# processed
# in
# Greece
# before
# they
# come
# to
# the
# UK.
# I
# don't
# blame
# Greece
# for
# letting
# a
# bunch
# go
# on
# their
# way.
# to
# recruit
# mercenaries
# from
# refugee
# populations
# to
# fight
# in
# foreign
# wars.
# However,
# the
# increasingly
# militaristic
# regime
# of
# Recep
# Tayyip
# Erdogan
# has
# been
# hosting
# Hamas
# and
# pushing
# an
# agenda
# that
# has
# seen
# Turkey
# threaten
# Greece,
# France,
# Israel,
# Iraq,
# Syria,
# the
# United
# States
# and-
# @DiCastro2
# @baphometx
# @tvxs
# Greece
# has
# a
# deadly
# new
# migration
# policy
# –
# and
# all
# of
# Europe
# is
# to
# blame
# https://t.co/wfTXUdU6b9
# @gcindemir
# @karsi_dusunce
# @YusufErim34
# and
# how
# could
# there
# be
# a
# security
# issue
# for
# Turkey
# has
# all
# migrants
# coming
# out
# of
# lybia
# go
# to
# Italy's
# and
# Malta's
# waters
# first
# and
# to
# Greece's
# waters
# second
# ?
# I
# don't
# get
# your
# point.
# No
# threat
# at
# all
# for
# Turkey.
# @antouan_hellas
# @jensstoltenberg
# Greece
# has
# actually
# lied
# to
# Mr
# Stoltenberg.
# They
# told
# him,
# they
# are
# ready
# for
# negotiations,
# but
# then
# said
# they
# have
# did
# NOT
# do
# that.
# Well,
# as
# expected
# from
# a
# country,
# whos
# existence
# is
# entirety
# dependend
# of
# EU
# money.
# Wothout
# the
# EU
# greek
# people
# would
# seek
# refuge
# in
# Turkey.
# HAHAHA
# @Susan60190970
# @AndreAp0ll0
# @itvnews
# @emmamurphyitv
# Please
# tell
# me,
# what
# exactly
# do
# you
# know
# about
# the
# asylum
# seekers
# systems
# in
# countries
# like
# France,
# Germany
# and
# Greece?
# Details
# please.
# I'm
# very
# interested
# in
# how
# you
# know
# their
# systems
# are
# flawless
# and
# don't
# discriminate
# 🙃
# via
# @PerilOfAfrica
# #Newsdeck
# COVID-19:
# Greece
# reports
# first
# coronavirus
# case
# in
# Moria
# migrant
# camp
# on
# Lesbos:
# ATHENS,
# Sept
# 2
# (Reuters)
# -
# Greece
# recorded
# its
# first
# coronavirus
# case
# in
# the
# overcrowded
# migrant
# camp
# of
# Moria
# on
# the
# island
# of
# Lesbos
# and
# the…
# https://t.co/O31oc3V6j0
# https://t.co/24C6hWAyVz
# @BenTheSilent
# @AndreAp0ll0
# @itvnews
# @emmamurphyitv
# That's
# not
# what
# i
# said
# refugees
# who
# are
# brought
# in
# through
# the
# proper
# channels
# are
# vetted.
# Do
# you
# watch
# what's
# happening
# france
# Germany
# and
# Greece.
# If
# they
# were
# genuine
# they
# wouldn't
# have
# been
# refused
# asylum
# in
# the
# countries
# they've
# passed
# No
# I
# don't
# think
# they
# are
# all
# criminals
# @SputnikInt
# Greece
# are
# more
# likely
# to
# drown
# the
# refugees.
# Most
# people
# will
# say
# that
# this
# is
# absurd
# but
# if
# you
# closely
# watch
# their
# policies
# on
# #Libya
# &
# #EastMed
# (#Greece
# #Cyprus
# #Turkey)
# and
# on
# the
# migration
# matter
# in
# #Europe,
# you
# will
# realize
# that
# indirectly
# or
# directly
# support
# #MuslimBritherhood
# and
# #PoliticalIslam’
# expansionism.
# @BrendanWoodshed
# Then
# stay
# in
# Spain,
# Greece,
# or
# Italy
# and
# apply
# for
# asylum
# in
# the
# U.K.
# through
# the
# legal
# channels
# .
# Or
# hope
# that
# there
# are
# enough
# people
# in
# the
# U.K.
# willing
# to
# convince
# everyone
# else
# in
# the
# U.K.
# that
# trafficking
# through
# illegal
# routes
# is
# ok
# and
# the
# “correct”
# moral
# response.
# I
# know
# it
# is
# not
# a
# scoop,
# but
# are
# #EU
# countries
# using
# COVID-19
# to
# clamp
# down
# on
# #refugees?
# Rights
# groups
# say
# the
# coronavirus
# pandemic
# has
# given
# #Italy
# and
# #Greece
# a
# chance
# to
# crack
# down
# on
# the
# unwanted
# visitors.
# https://t.co/6TVByVbFYV
# .@MSF
# condemns
# attack
# on
# its
# pediatric
# clinic
# near
# Moria
# refugee
# camp
# in
# Greece
# |
# Lesvos
# field
# coordinator:
# “In
# what
# world
# do
# we
# live
# in
# where
# children
# and
# pregnant
# women
# being
# treated
# by
# doctors
# are
# subject
# to
# people
# throwing
# stones
# at
# them?”
# https://t.co/dKAEMPh1Fm
# https://t.co/UfA1zf5Skc
# @derekc78
# Any
# illegal
# English
# migrants
# trying
# to
# get
# into
# Greece
# https://t.co/8D4nUeJzxI
# @vultan2000
# @itvlondon
# i
# am
# Italian
# I
# am
# fluent
# in
# 4
# languages.
# I
# translate
# documents.
# These
# are
# figures
# from
# Italian
# government.
# Refugee,
# from
# the
# EU..
# really???
# why
# can't
# the
# French
# /EU
# provide
# it.
# To
# reach
# France
# they
# have
# come
# through
# Greece,
# Italy
# or
# Spain.
# All
# Safe
# countries

# %%
from nltk.corpus import stopwords
from collections import defaultdict

stop_words = list(stopwords.words('english'))

print('preprocessing tweets...')
tweets_corpus = list(preprocessing.preprocess_tweets(event_df['Tweet Raw'][200:]))


print('assigning frame properties to words from tweets...')
word_properties = defaultdict(dict)
for i in tqdm(tweets_corpus):
    tweet_words = [word.lower() for word in i.split() if word not in stop_words and len(word)>1]
    for word in tweet_words:
        word = lemma.lemmatize(word)
        property_list = []
        #print(list(frame_properties.keys()))
        for prop in list(frame_properties.keys()):
            #print(frame_properties[prop])
            
            try:
                #print(f'sim of {word}, {prop} is {model.similarity(word, prop)}')
                weights = [model.similarity(word, seed) for seed in frame_properties[prop]]
                #print(weights)
                if max(weights)>0.4:
                    word_properties[word][prop] = max(weights)
            except KeyError:
                pass
            



print(word_properties)
# Out:
#   0%|▎                                                                             | 86/18003 [00:00<00:21, 835.07it/s]
# preprocessing tweets...
# 100%|███████████████████████████████████████████████████████████████████████████| 18003/18003 [00:18<00:00, 951.66it/s]
#   0%|                                                                                        | 0/18003 [00:00<?, ?it/s]
# assigning frame properties to words from tweets...
# 100%|████████████████████████████████████████████████████████████████████████████| 18003/18003 [10:41<00:00, 28.08it/s]
# defaultdict(<class 'dict'>, {'camp': {'settlement': 1.0}, 'case': {'reason': 0.47645345}, 'get': {'reception': 0.50504476}, 'eu': {'victimization': 0.41524222}, 'currency': {'economisation': 0.633761}, 'need': {'humanitarian': 0.46502197}, 'money': {'economisation': 1.0}, 'soros': {'victimization': 0.46909347}, 'germany': {'victimization': 0.40653825}, 'never': {'refusal': 0.4868157}, 'give': {'reception': 0.5135118}, 'nazi': {'victimization': 0.4395619}, 'refugee': {'reception': 0.60989624}, 'wanna': {'affection': 0.45185497}, 'murder': {'criminality': 0.53367186, 'victimization': 0.40415478}, 'without': {'refusal': 0.46807507}, 'there': {'refusal': 0.62095666}, 'cash': {'economisation': 0.6151221}, 'not': {'refusal': 0.52004266}, 'support': {'humanitarian': 1.0}, 'refuge': {'settlement': 0.63942665, 'reception': 0.41259414}, 'want': {'affection': 0.43143085}, 'country': {'victimization': 0.43598586}, 'send': {'reception': 0.46330065}, 'iran': {'victimization': 0.49675876}, 'muslim': {'victimization': 0.7151465}, 'jihadist': {'criminality': 0.6238455, 'victimization': 0.45559162}, 'islam': {'victimization': 0.69595474}, 'gang': {'criminality': 0.48914832}, 'example': {'reason': 0.46280614}, 'financial': {'economisation': 0.56026417, 'difficulty': 0.40237117}, 'needed': {'humanitarian': 0.50178003}, 'help': {'humanitarian': 1.0}, 'helped': {'humanitarian': 0.5614464}, 'million': {'economisation': 1.0}, 'saved': {'victimization': 0.45287922}, 'fair': {'trustworthiness': 0.5022889}, 'arrive': {'reception': 0.41649738}, 'europe': {'victimization': 0.42174834}, 'why': {'reason': 0.61324227}, 'together': {'reception': 1.0}, 'fight': {'victimization': 0.99999994}, 'truth': {'no trustworthiness': 0.5787493}, 'hated': {'affection': 0.4725951}, 'syrian': {'victimization': 0.43796158}, 'settling': {'settlement': 0.43653542}, 'thing': {'reason': 0.55049455}, 'mad': {'affection': 0.413836}, 'anyone': {'refusal': 0.4366851}, 'jew': {'victimization': 0.4302907}, 'thousand': {'economisation': 1.0}, 'fled': {'criminality': 0.40912294}, 'apply': {'reception': 0.4702472}, 'asylum': {'reception': 1.0}, 'escaping': {'victimization': 0.42784286}, 'trust': {'trustworthiness': 0.4252125}, 'border': {'security': 1.0}, 'respect': {'affection': 0.45636123, 'trustworthiness': 0.4757658, 'honor': 0.51692545}, 'billion': {'economisation': 0.80567366}, 'dollar': {'economisation': 0.6061668}, 'detained': {'criminality': 0.4599186, 'victimization': 0.40719983}, 'arrested': {'criminality': 0.5608969}, 'humanity': {'honor': 0.4945985}, 'problem': {'difficulty': 0.53270733}, 'terrorism': {'criminality': 0.8522105, 'victimization': 0.45032072, 'no trustworthiness': 0.4500749}, 'killed': {'victimization': 0.70920515}, 'terrorist': {'criminality': 0.84762025}, 'iraqi': {'victimization': 0.4483014}, 'try': {'humanitarian': 0.5073055}, 'claim': {'reason': 0.42987594}, 'yes': {'refusal': 0.5061716}, 'benefit': {'humanitarian': 0.42392638}, 'russia': {'victimization': 0.43411404}, 'really': {'affection': 0.414828}, 'defense': {'criminality': 0.5541691}, 'pick': {'reception': 0.44349197}, 'european': {'victimization': 0.43040657}, 'spain': {'victimization': 0.4126986}, 'hundred': {'economisation': 0.8323169}, 'democracy': {'honor': 0.4154714}, 'freedom': {'honor': 0.48267972}, 'wish': {'affection': 0.4017677}, 'escape': {'victimization': 0.42087197}, 'seek': {'reception': 0.42984623}, 'kurdish': {'victimization': 0.43375695}, 'know': {'affection': 0.4328893}, 'political': {'economisation': 0.45409435}, 'nation': {'victimization': 0.4697637}, 'appreciate': {'affection': 0.45584023}, 'feel': {'reason': 0.52072036}, 'reason': {'reason': 1.0}, 'protection': {'security': 0.42394572}, 'economic': {'economisation': 1.0}, 'hotel': {'settlement': 0.41771254}, 'received': {'reception': 0.6799966}, 'worry': {'difficulty': 0.40756926}, 'government': {'victimization': 0.45800617}, 'police': {'criminality': 1.0}, 'cruel': {'humanitarian': 0.4713152}, 'crazy': {'affection': 0.4420689 ...

# %%
# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(tweets_corpus)[:200] 

#all_tweets_list = all_tweets_list + ['Muslim refugees is government']

# IF WE DON'T CARE ABOUT (KINDA) LOSING THE TWEETS (BECAUSE WE WILL LOOK AT SENTENCES ONLY) THEN WE CAN BATCH WITH \n\n AND
# SPEED THINGS UP SIGNIFICANTLY

#all_tweets_list = '\n\n'.join(all_tweets_list)
#print(all_tweets_list[:1000])
"""for tweet in tqdm(range(len(all_tweets_list))):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if len(tweet_sentokenized) == 0:
        tweet_sentokenized.append('empty_tweet')
        #print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)"""

"""all_tweets_list = '\n\n'.join(all_tweets_list)  

for tweet_id in range(len(all_tweets_list.split('\n\n'))):
    if len(all_tweets_list[tweet_id]) == 0:
        all_tweets_list[tweet_id] = 'empty_tweet'
#print(all_tweets_list[:1000]"""


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=2000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text

# %%
#Store the noun phrases in the pickle file
import pickle

with open('test_moria_tagged_tweets', 'wb') as fp:
    pickle.dump(tagged_tweets, fp)

# %%
# Load NPs from pickle file
import pickle

with open(r"test_moria_tagged_tweets", "rb") as input_file:
    tagged_tweets = pickle.load(input_file)

# %%
event_df['Date Short'][200]
# Out:
# '2020-09-04'

# %%
from collections import defaultdict
# import these modules 
from nltk.stem import WordNetLemmatizer 
from nltk.corpus.reader.wordnet import NOUN
import numpy as np
  
lemma = WordNetLemmatizer() 

cand_frames = defaultdict(list)

framed_words = pd.DataFrame(columns=['word','date',list(frame_properties.keys())])


for tweet_id in tqdm(range(len(tagged_tweets))):
    #print(tweet)
    cand_words = [[word.id, word.text,word.head] for sent in tagged_tweets[tweet_id].sentences for word in sent.words]
    #print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
    #print(len(cand_df['candidates']))
    for cand in cand_df['candidates']:
            # lemmatize representative head of candidate 
            rep_head = lemma.lemmatize(cand[1].lower(),pos=NOUN)
            
            if rep_head in tagged_tweets[tweet_id].text.lower() and len(rep_head)>1:
                #find all dependencies of the phrase head
                for related in range(len(cand_words)):
                    cand_word_lemma = lemma.lemmatize(cand_words[related][1].lower())
                    #print(f'Yes it is, related = {lemma.lemmatize(cand_heads[related][1].lower(),pos=NOUN)}')
                    #lemma.lemmatize(cand_heads[related][1].lower(),pos=NOUN)
                    if rep_head == cand_word_lemma:
                        related_word = lemma.lemmatize(cand_words[cand_words[related][2]-1][1].lower())
                        cand_frames['word'].append(rep_head)
                        cand_frames['date'].append(event_df['Date Short'][200+tweet_id])
                        #print(f'\n\n checking {phrase_head}_{related_word}')                
                        #cand_frames['word'].append(rep_head)
                        #cand_frames['date'].append(event_df['Date Short'][200+tweet_id])
                        #cand_frames['word'].append(phrase_head)
                        for frame_property in list(frame_properties.keys()):
                            #print(frame_property)

                            try:
                                #print(word_properties[phrase_head][frame_property])
                                cand_frames[frame_property].append(word_properties[related_word][frame_property])

                            except KeyError:
                                #print('Error')
                                #cand_frames[frame_property].append(word_properties['tent'][frame_property])
                                cand_frames[frame_property].append(np.NaN)
                                

                    #print(len(cand_frames[frame_property]))
                    
                #print('\n')
                
                
                """for frame_property in list(frame_properties.keys()):
                    for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    #print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                            #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                        except KeyError:
                            pass"""
                        #[cand_frames[seed_word][cand].append(model.similarity(print(f'{cand} is related to {np_heads[np_heads[related][2]+1][1]}') if cand == np_heads[related][1] else print('nej') for related in range(len(np_heads))]
            #print(get_head(cand))
            #print(np_heads[19][1])
            #[f(x) if condition else g(x) for x in sequence]
            #[print(np_heads[np_heads[related][2]-1]) if get_head(cand)==np_heads[related][1] else print('hi') for related in range(len(np_heads))]

            
#became ___ (vb and vbx)
#(VP sit/VB (PP on/IN (NP the/DT mat/NN))))) 

#common phrases = migrant camp, covid case, covid test

#cand_frames
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 18003/18003 [01:16<00:00, 234.40it/s]

# %%
print(cand_frames.keys())

framed_words = pd.DataFrame.from_dict(cand_frames)

#framed_words[framed_words['word']=='migrants'].tail(50)

framed_words = framed_words.dropna(subset=['settlement', 'reception', 'security', 'criminality', 'economisation', 'humanitarian', 'victimization', 'integration', 'affection', 'refusal', 'trustworthiness', 'no trustworthiness', 'reason', 'unreason/irrationality', 'easiness', 'difficulty', 'honor', 'dishonor'],how='all')

framed_words
# Out:
# dict_keys(['word', 'date', 'settlement', 'reception', 'security', 'criminality', 'economisation', 'humanitarian', 'victimization', 'integration', 'affection', 'refusal', 'trustworthiness', 'no trustworthiness', 'reason', 'unreason/irrationality', 'easiness', 'difficulty', 'honor', 'dishonor'])
#               word        date  settlement  reception  security  criminality  \
# 0          migrant  2020-09-04         1.0        NaN       NaN          NaN
# 2            covid  2020-09-04         NaN        NaN       NaN          NaN
# 3            covid  2020-09-04         NaN        NaN       NaN          NaN
# 4            covid  2020-09-04         NaN        NaN       NaN          NaN
# 5            covid  2020-09-04         NaN        NaN       NaN          NaN
# ...            ...         ...         ...        ...       ...          ...
# 138104       moria  2020-09-16         1.0        NaN       NaN          NaN
# 138106     migrant  2020-09-16         NaN        NaN       NaN          NaN
# 138110      muslim  2020-09-16         NaN        NaN       NaN          NaN
# 138116  government  2020-09-16         NaN   0.400841       NaN          NaN
# 138130     refugee  2020-09-16         NaN        NaN       NaN          1.0
#
#         economisation  humanitarian  victimization  integration  affection  \
# 0                 NaN           NaN            NaN          NaN        NaN
# 2                 NaN           NaN            NaN          NaN        NaN
# 3                 NaN           NaN            NaN          NaN        NaN
# 4                 NaN           NaN            NaN          NaN        NaN
# 5                 NaN           NaN            NaN          NaN        NaN
# ...               ...           ...            ...          ...        ...
# 138104            NaN           NaN            NaN          NaN        NaN
# 138106            NaN           NaN       0.415242          NaN        NaN
# 138110            NaN           NaN            NaN          NaN   0.438872
# 138116            NaN           NaN            NaN          NaN        NaN
# 138130            NaN           NaN            NaN          NaN        NaN
#
#         refusal  trustworthiness  no trustworthiness    reason  \
# 0           NaN              NaN                 NaN       NaN
# 2           NaN              NaN                 NaN  0.476453
# 3           NaN              NaN                 NaN  0.476453
# 4           NaN              NaN                 NaN  0.476453
# 5           NaN              NaN                 NaN  0.476453
# ...         ...              ...                 ...       ...
# 138104      NaN              NaN                 NaN       NaN
# 138106      NaN              NaN                 NaN       NaN
# 138110      NaN              NaN                 NaN       NaN
# 138116      NaN              NaN                 NaN       NaN
# 138130      NaN              NaN            0.461287       NaN
#
#         unreason/irrationality  easiness  difficulty  honor  dishonor
# 0                          NaN       NaN         NaN    NaN       NaN
# 2                          NaN       NaN         NaN    NaN       NaN
# 3                          NaN       NaN         NaN    NaN       NaN
# 4                          NaN       NaN         NaN    NaN       NaN
# 5                          NaN       NaN         NaN    NaN       NaN
# ...                        ...       ...         ...    ...       ...
# 138104                     NaN       NaN         NaN    NaN       NaN
# 138106                     NaN       NaN         NaN    NaN       NaN
# 138110                     NaN       NaN         NaN    NaN       NaN
# 138116                     NaN       NaN         NaN    NaN       NaN
# 138130                     NaN       NaN         NaN    NaN       NaN
#
# [42160 rows x 20 columns]

# %%
framed_words = framed_words[framed_words['word'] == 'refugee']
#framed_words[framed_words['date']=='2020-09-04']

aggr_frames = framed_words.groupby(['word','date'],as_index=False).mean()
aggr_frames.tail(50)
# Out:
#        word        date  settlement  reception  security  criminality  \
# 0   refugee  2020-08-24    0.885650   0.528205       NaN          NaN
# 1   refugee  2020-08-25    0.718840   0.596905       NaN     0.484127
# 2   refugee  2020-08-26    1.000000   0.568230  0.538357          NaN
# 3   refugee  2020-08-27    0.850285   0.502025  0.401450          NaN
# 4   refugee  2020-08-28    1.000000   0.589157  1.000000          NaN
# 5   refugee  2020-08-29    0.881932   0.568262  1.000000     0.451951
# 6   refugee  2020-08-30    1.000000   0.527151  0.621869          NaN
# 7   refugee  2020-08-31    1.000000   0.609896  1.000000     0.717057
# 8   refugee  2020-09-01    1.000000   0.547397  0.401450          NaN
# 9   refugee  2020-09-02    1.000000   0.609896       NaN          NaN
# 10  refugee  2020-09-03    1.000000   0.707803  1.000000     0.558389
# 11  refugee  2020-09-04    1.000000        NaN       NaN          NaN
# 12  refugee  2020-09-05    1.000000   0.804948       NaN     0.718527
# 13  refugee  2020-09-06    1.000000   0.479531  0.703856     0.713882
# 14  refugee  2020-09-07    1.000000   0.653858  1.000000          NaN
# 15  refugee  2020-09-08    0.969908   0.624313       NaN          NaN
# 16  refugee  2020-09-09    0.994096   0.609580  0.637894     0.512945
# 17  refugee  2020-09-10    0.988736   0.554669  0.401450     0.657468
# 18  refugee  2020-09-11    0.979751   0.583132  1.000000     0.564599
# 19  refugee  2020-09-12    0.968758   0.562096  0.839672     0.859641
# 20  refugee  2020-09-13    0.974179   0.605211  0.424221     0.718527
# 21  refugee  2020-09-14    0.973436   0.598067  0.407567          NaN
# 22  refugee  2020-09-15    0.994849   0.601296  0.423946     0.493343
# 23  refugee  2020-09-16    0.995296   0.555949       NaN     0.632171
# 24  refugee  2020-09-17    0.973214   0.568076       NaN     0.780448
# 25  refugee  2020-09-18    0.985211   0.576306  0.700725     0.435584
# 26  refugee  2020-09-19    0.995553   0.604952       NaN          NaN
# 27  refugee  2020-09-20    0.961427   0.654610       NaN          NaN
# 28  refugee  2020-09-21    0.989412   0.555063       NaN     0.560897
# 29  refugee  2020-09-22    0.962629   0.611475  0.423946     0.437054
# 30  refugee  2020-09-23    0.983461   0.570491  0.679343     0.441829
#
#     economisation  humanitarian  victimization  integration  affection  \
# 0        0.861238      0.647149       0.506002          NaN   0.516642
# 1             NaN      0.585392       0.598926          NaN   0.431431
# 2        1.000000      0.463913       0.480653          NaN   0.428018
# 3        0.738238      0.821304       0.463840          NaN   0.417464
# 4        1.000000      0.600940       0.469478          NaN   0.412000
# 5        0.803007      0.494139       0.668953          NaN   1.000000
# 6        1.000000      0.623637       0.501811          NaN   0.420636
# 7        1.000000      1.000000       0.584668          NaN   0.432889
# 8        1.000000      0.753653       0.432260          NaN   0.431431
# 9        0.828203      0.734906       0.442410          NaN   0.432889
# 10            NaN      0.863331       0.623754          NaN   0.432889
# 11            NaN           NaN            NaN          NaN        NaN
# 12       1.000000           NaN       0.756608          NaN   0.431431
# 13       0.810776      1.000000       0.589223          NaN        NaN
# 14       0.802728      0.561446       0.474345          NaN   0.421715
# 15       0.635629      0.686954       0.563048          NaN        NaN
# 16       0.915448      0.743704       0.497917          NaN   0.448782
# 17       0.947918      0.738065       0.484989          NaN   0.454853
# 18       0.976445      0.740603       0.452874          NaN   0.515157
# 19       0.943146      0.766587       0.480654          NaN   0.422395
# 20       0.893788      0.709453       0.495304          NaN   0.423679
# 21       0.881705      0.822516       0.475341          NaN   0.451487
# 22       0.802868      0.879517       0.588222          NaN   0.424137
# 23       0.897073      0.787237       0.534346          NaN   0.413358
# 24       0.905224      0.651069       0.432602          NaN   0.508699
# 25       0.958079      0.789036       0.641595          NaN   0.457276
# 26       0.811452      0.717111       0.424224          NaN   0.424719
# 27       0.831332      0.956118       0.433162          NaN   0.431431
# 28       0.840771      0.890086       0.434880          NaN   0.414828
# 29       1.000000      0.811022       0.585475          NaN   0.415424
# 30       0.723804      0.874008       0.539462          NaN   0.470229
#
#      refusal  trustworthiness  no trustworthiness    reason  \
# 0   0.453999              NaN                 NaN  0.429876
# 1   0.537289              NaN                 NaN       NaN
# 2   0.577606              NaN                 NaN       NaN
# 3   0.500712              NaN                 NaN       NaN
# 4   0.553681              NaN                 NaN  0.429918
# 5   0.520043              NaN            0.602489  0.413419
# 6        NaN              NaN                 NaN  0.524333
# 7   0.441415              NaN            0.461287  0.455918
# 8   0.577606              NaN                 NaN       NaN
# 9   1.000000              NaN                 NaN  0.544848
# 10  0.441415              NaN            0.450075  0.429918
# 11       NaN         0.425213                 NaN       NaN
# 12  0.520043              NaN                 NaN  0.490185
# 13  1.000000              NaN            0.461287  0.468724
# 14  0.525841              NaN                 NaN  0.455442
# 15  0.441415              NaN                 NaN  0.476453
# 16  0.527766         0.475766            0.461287  0.566900
# 17  0.562931              NaN            0.420183  0.510364
# 18  0.529982         0.459270                 NaN  0.436641
# 19  0.513526              NaN            0.602489  0.511643
# 20  0.483655              NaN                 NaN  0.575310
# 21  0.509422              NaN            0.432318  0.413419
# 22  0.593515         0.475766            0.451420  0.455782
# 23  0.492628              NaN            0.446923  0.447846
# 24  0.574573         0.482980            0.474225  0.466383
# 25  0.752644              NaN                 NaN  0.595139
# 26  0.645102              NaN            0.433036       NaN
# 27  0.532637              NaN                 NaN  0.413419
# 28  0.480729              NaN                 NaN  0.476453
# 29  0.509510         0.512670            0.406614  0.476453
# 30  0.471064         0.472950            0.421381       NaN
#
#     unreason/irrationality  easiness  difficulty     honor  dishonor
# 0                      NaN       NaN    0.750321       NaN       NaN
# 1                      NaN  0.416482    0.729447       NaN       NaN
# 2                      NaN       NaN    0.830878       NaN       NaN
# 3                      NaN       NaN    0.422370       NaN       NaN
# 4                      NaN       NaN    0.734831  0.430042       NaN
# 5                      NaN       NaN    0.717828       NaN  0.445651
# 6                      NaN       NaN    1.000000       NaN       NaN
# 7                      NaN       NaN    0.646462       NaN  0.463172
# 8                      NaN       NaN    0.844236  0.439388       NaN
# 9                      NaN       NaN    1.000000       NaN  0.466985
# 10                     NaN       NaN    0.435657       NaN       NaN
# 11                     NaN       NaN         NaN       NaN       NaN
# 12                     NaN       NaN         NaN       NaN       NaN
# 13                     NaN       NaN    0.532707       NaN       NaN
# 14                     NaN       NaN    0.425524  0.494599       NaN
# 15                     NaN       NaN    0.418713       NaN       NaN
# 16                     NaN       NaN    0.767705  0.566848  0.485960
# 17                     NaN  1.000000    0.739275  0.461927  0.736686
# 18                     NaN  0.444927    0.765768  0.733118  0.433781
# 19                     NaN       NaN    0.818329  0.472748  0.579174
# 20                     NaN       NaN    0.793984  0.434989  0.606182
# 21                     NaN       NaN    0.699247  0.473986  0.472463
# 22                     NaN       NaN    0.765223  0.467751  0.497359
# 23                     NaN       NaN    0.849697  0.450897       NaN
# 24                     NaN       NaN    0.892829  0.474703  0.449692
# 25                     NaN       NaN    0.676070  0.404045  0.431770
# 26                     NaN       NaN    0.598528       NaN  0.504475
# 27                     NaN       NaN    0.663262       NaN       NaN
# 28                     NaN       NaN    0.717828       NaN       NaN
# 29                     NaN       NaN    0.834362  0.529340  0.433309
# 30                     NaN       NaN    0.774620  0.456009       NaN

# %%
import plotly.express as px


fig = px.line(aggr_frames, x="date", y=["reason",'affection','reception','settlement'], title=f'Frame bias towards refugees')
fig.show()
# Out:
# <div>                            <div id="e6cd53e3-1b6d-4afe-a41c-888b8d05ef0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6cd53e3-1b6d-4afe-a41c-888b8d05ef0b")) {                    Plotly.newPlot(                        "e6cd53e3-1b6d-4afe-a41c-888b8d05ef0b",                        [{"hovertemplate": "variable=reason<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "reason", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "reason", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-08-24", "2020-08-25", "2020-08-26", "2020-08-27", "2020-08-28", "2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17", "2020-09-18", "2020-09-19", "2020-09-20", "2020-09-21", "2020-09-22", "2020-09-23"], "xaxis": "x", "y": [0.4298759400844574, null, null, null, 0.4299182593822479, 0.41341879963874817, 0.5243328213691711, 0.4559175372123718, null, 0.5448478609323502, 0.4299182593822479, null, 0.4901852458715439, 0.4687236547470093, 0.4554419020811717, 0.4764534533023834, 0.5668996671835581, 0.5103639662265778, 0.43664127588272095, 0.5116427285330636, 0.5753096401691437, 0.41341879963874817, 0.4557819366455078, 0.44784624377886456, 0.4663827419281006, 0.5951392203569412, null, 0.41341879963874817, 0.4764534533023834, 0.4764534533023834, null], "yaxis": "y"}, {"hovertemplate": "variable=affection<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "affection", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "affection", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-08-24", "2020-08-25", "2020-08-26", "2020-08-27", "2020-08-28", "2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17", "2020-09-18", "2020-09-19", "2020-09-20", "2020-09-21", "2020-09-22", "2020-09-23"], "xaxis": "x", "y": [0.5166424959897995, 0.431430846452713, 0.428018182516098, 0.4174640476703644, 0.41199958324432373, 1.0, 0.42063626646995544, 0.43288931250572205, 0.431430846452713, 0.43288931250572205, 0.43288931250572205, null, 0.431430846452713, null, 0.42171521484851837, null, 0.4487821482695066, 0.45485293567180635, 0.5151572048664093, 0.4223945736885071, 0.4236794759829839, 0.45148744753428866, 0.42413676530122757, 0.41335830092430115, 0.5086994282901287, 0.4572756290435791, 0.4247187227010727, 0.431430846452713, 0.41482800245285034, 0.4154238321564414, 0.4702290177345276], "yaxis": "y"}, {"hovertemplate": "variable=reception<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "reception", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "reception", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-08-24", "2020-08-25", "2020-08-26", "2020-08-27", "2020-08-28", "2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17", "2020-09-18", "2020-09-19", "2020-09-20", "2020-09-21", "2020-09-22", "2020-09-23"], "xaxis": "x", "y": [0.5282050848007203, 0.5969050526618958, 0.5682297746340433, 0.5020252108573914, 0.5891567766666412, 0.5682621896266937, 0.5271513130929735, 0.6098962426185608, 0.5473965406417847, 0.6098962426185608, 0.707 ...

# %% [markdown]
# # TESTING:

# %%
# batching the tweets speeds the model considerably and is enabled by splitting sentences using '\n\n' 
from stanza_batch import batch
from nltk.tokenize import sent_tokenize

# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(tweets_corpus)[:50] 
for tweet in range(len(all_tweets_list)):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if tweet_sentokenized == []:
        tweet_sentokenized.append('empty_tweet')
        print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=1000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text
# Out:
# 50it [00:16,  2.99it/s]
# 'Greeces Moria migrant camp quarantined after first Covid - 19 case'

# %%
for tweet in tqdm(range(len(tweets_corpus))):
    print(tweets_corpus[tweet])
    np_heads = [[word.id, word.text,word.head,word.deprel] for sent in tagged_tweets[tweet].sentences for word in sent.words]
    print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in tagged_tweets[tweet].sentences for word in sent.words], sep='\n')
    #print(np_heads)
    ph_ids = set([np_heads[i][2] for i in range(len(np_heads))])
    ph_words = [np_heads[i-1][1] for i in ph_ids]

    word_pairs = [(np_heads[word][1], np_heads[np_heads[word][2]-1][1]) for word in range(len(np_heads)) if np_heads[word][2] != 0]
    #print(word_pairs)
    
    compounds = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if 'compound' in np_heads[i][3]]
    print(compounds)
    
    advmods = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='advmod']
    print(advmods)
    
    amods = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='amod']
    print(amods)
    for pair in word_pairs:
        phrase = pair[0]+'_'+pair[1]

    #print(model.most_similar('illegal_immigrant'))

    
    """#print(len(cand_df['candidates']))
    candidate_list = cand_df['candidates']
    for cand in cand_df['candidates']:
        #print(cand[2])
        #print(get_head(str(cand)))
        for phrase_head in cand[2]:
            #print(phrase_head)
            #if str(cand[1]) in str(tweet):
            if str(phrase_head) in str(tweet) and len(phrase_head)>2:
                #print(phrase_head)
                ph_words = [np_heads[i-1][1] for i in phrase_heads]
                #print(ph_words)
                for related in range(len(np_heads)):
                    if phrase_head == np_heads[related][1]:
                        pass
                        #print(f'checking {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                  for frame_property in list(frame_properties.keys()):
                        for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    #cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                                #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                                except KeyError:
                                pass"""
# Out:
#   0%|                                                                              | 20/18003 [00:00<01:31, 196.07it/s]
# Greeces Moria migrant camp quarantined after first Covid - 19 case
# id: 1	word: Greeces        head id: 0    head: root      deprel: root
# id: 2	word: Moria          head id: 1    head: Greeces   deprel: flat
# id: 3	word: migrant        head id: 4    head: camp      deprel: amod
# id: 4	word: camp           head id: 1    head: Greeces   deprel: appos
# id: 5	word: quarantined    head id: 4    head: camp      deprel: acl
# id: 6	word: after          head id: 11   head: case      deprel: case
# id: 7	word: first          head id: 11   head: case      deprel: amod
# id: 8	word: Covid          head id: 11   head: case      deprel: compound
# id: 9	word: -              head id: 8    head: Covid     deprel: punct
# id: 10	word: 19             head id: 8    head: Covid     deprel: nummod
# id: 11	word: case           head id: 5    head: quarantineddeprel: obl
# [['Covid_case']]
# []
# [['migrant_camp'], ['first_case']]
# 2,000 covid - 19 tests will be carried out at Moria migrant camp
# id: 1	word: 2,000          head id: 2    head: covid     deprel: compound
# id: 2	word: covid          head id: 0    head: root      deprel: root
# id: 3	word: -              head id: 2    head: covid     deprel: punct
# id: 4	word: 19             head id: 5    head: tests     deprel: nummod
# id: 5	word: tests          head id: 8    head: carried   deprel: nsubj:pass
# id: 6	word: will           head id: 8    head: carried   deprel: aux
# id: 7	word: be             head id: 8    head: carried   deprel: aux:pass
# id: 8	word: carried        head id: 2    head: covid     deprel: parataxis
# id: 9	word: out            head id: 8    head: carried   deprel: compound:prt
# id: 10	word: at             head id: 13   head: camp      deprel: case
# id: 11	word: Moria          head id: 13   head: camp      deprel: compound
# id: 12	word: migrant        head id: 13   head: camp      deprel: amod
# id: 13	word: camp           head id: 8    head: carried   deprel: obl
# [['2,000_covid'], ['out_carried'], ['Moria_camp']]
# []
# [['migrant_camp']]
# Greeces overcrowded Moria migrant camp reports FIRST coronavirus case RT WorldNews
# id: 1	word: Greeces        head id: 0    head: root      deprel: root
# id: 2	word: overcrowded    head id: 6    head: reports   deprel: amod
# id: 3	word: Moria          head id: 6    head: reports   deprel: compound
# id: 4	word: migrant        head id: 6    head: reports   deprel: amod
# id: 5	word: camp           head id: 6    head: reports   deprel: compound
# id: 6	word: reports        head id: 1    head: Greeces   deprel: appos
# id: 7	word: FIRST          head id: 9    head: case      deprel: amod
# id: 8	word: coronavirus    head id: 9    head: case      deprel: amod
# id: 9	word: case           head id: 6    head: reports   deprel: appos
# id: 10	word: RT             head id: 9    head: case      deprel: appos
# id: 11	word: WorldNews      head id: 10   head: RT        deprel: flat
# [['Moria_reports'], ['camp_reports']]
# []
# [['overcrowded_reports'], ['migrant_reports'], ['FIRST_case'], ['coronavirus_case']]
# From the time we get in EU Greece became poor . With our own currency we were way better . You need to learn where the free money go . To immigrants, banks and NGO of Soros . Germany bought everything in EU with this politic and never give us the gold that stolen from Nazis
# id: 1	word: From           head id: 3    head: time      deprel: case
# id: 2	word: the            head id: 3    head: time      deprel: det
# id: 3	word: time           head id: 9    head: became    deprel: obl
# id: 4	word: we             head id: 5    head: get       deprel: nsubj
# id: 5	word: get            head id: 3    head: time      deprel: acl:relcl
# id: 6	word: in             head id: 7    head: EU        deprel: case
# id: 7	word: EU             head id: 5    head: get       deprel: obl
# id: 8	word: Greece         head id: 9    head: became    deprel: nsubj
# id: 9	word: became         head id: 0    head: root      deprel: root
# id: 10	word: poor           head id: 9    head: became    deprel: xcomp
# id: 11	word: .              head id: 9    head: became    deprel: punct
# id: 1	word: With           head id: 4    head: currency  deprel: case
# id: 2	word: our            head id: 4    head: currency  deprel: nmod:poss
# id: 3	word: own            head id: 4    head: currency  deprel: amod
# id: 4	word: currency       head id: 8    head: better    deprel: obl
# id: 5	word: we             head id: 8    head: better    deprel: nsubj
# id: 6	word: were           head id: 8    head: better    deprel: cop
# id: 7	word: way            head id: 8    head: better    deprel: advmod
# id: 8	word: better         head id: 0    head: root      deprel: root
# id: 9	word: .              head id: 8    head: better    deprel: punct
# id: 1	word: You            head id: 2    head: need      deprel: nsubj
# id: 2	word: need           head id: 0    head: root      deprel: root
# id: 3	word: to             head id: 4    head: learn     deprel: mark
# id: 4	word: learn          head id: 2    head: need      deprel: xcomp
# id: 5	word: where          head id: 9    head: go        deprel: mark
# id: 6	word: the            head id: 8    head: money     deprel: det
# id: 7	word: free           head id: 8    head: money     deprel: amod
# id: 8	word: money          head id: 9    head: go        deprel: nsubj
# id: 9	word: go             head id: 4    head: learn     deprel: ccomp
# id: 10	word: .              head id: 2    head: need      deprel: punct
# id: 1	word: To             head id: 2    head: immigrantsdeprel: case
# id: 2	word: immigrants     head id: 0    head: root      deprel: root
# id: 3	word: ,              head id: 4    head: banks     deprel: punct
# id: 4	word: banks          head id: 2    head: immigrantsdeprel: conj
# id: 5	word: and            head id: 6    head: NGO       deprel: cc
# id: 6	word: NGO            head id: 2    head: immigrantsdeprel: conj
# id: 7	word: of             head id: 8    head: Soros     deprel: case
# id: 8	word: Soros          head id: 6    head: NGO       deprel: nmod
# id: 9	word: .              head id: 2    head: immigrantsdeprel: punct
# id: 1	word: Germany        head id: 2    head: bought    deprel: nsubj
# id: 2	word: bought         head id: 0    head: root      deprel: root
# id: 3	word: everything     head id: 2    head: bought    deprel: obj
# id: 4	word: in             head id: 5    head: EU        deprel: case
# id: 5	word: EU             head id: 3    head: everythingdeprel: nmod
# id: 6	word: with           head id: 8    head: politic   deprel: case
# id: 7	word: this           head id: 8    head: politic   deprel: det
# id: 8	word: politic        head id: 2    head: bought    deprel: obl
# id: 9	word: and            head id: 11   head: give      deprel: cc
# id: 10	word: never          head id: 11   head: give      deprel: advmod
# id: 11	word: give           head id: 2    head: bought    deprel: conj
# id: 12	word: us             head id: 11   head: give      deprel: iobj
# id: 13	word: the            head id: 14   head: gold      deprel: det
# id: 14	word: gold           head id: 11   head: give      deprel: obj
# id: 15	word: that           head id: 16   head: stolen    deprel: nsubj
# id: 16	word: stolen         head id: 14   head: gold      deprel: acl:relcl
# id: 17	word: from           head id: 18   head: Nazis     deprel: case
# id: 18	word: Nazis          head id: 16   head: stolen    deprel: obl
# []
# [['way_Greece'], ['never_.']]
# [['own_we'], ['free_Greece']]
# contemporary art! And again, mixed with contemporary displays, beach debris from the refugee wave in 2015, Greece . spotted by Ka vonSeiten in @ArtSpotsApp, check it out at Wanna add your own findings? Get the free ArtSpots App for Android :
# id: 1	word: contemporary   head id: 2    head: art       deprel: amod
# id: 2	word: art            head id: 0    head: root      deprel: root
# id: 3	word: !              head id: 2    head: art       deprel: punct
# id: 1	word: And            head id: 4    head: mixed     deprel: cc
# id: 2	word: again          head id: 4    head: mixed     deprel: advmod
# id: 3	word: ,              head id: 4    head: mixed     deprel: punct
# id: 4	word: mixed          head id: 0    head: root      deprel: root
# id: 5	word: with           head id: 7    head: displays  deprel: case
# id: 6	word: contemporary   head id: 7    head: displays  deprel: amod
# id: 7	word: displays       head id: 4    head: mixed     deprel: obl
# id: 8	word: ,              head id: 10   head: debris    deprel: punct
# id: 9	word: beach          head id: 10   head: debris    deprel: compound
# id: 10	word: debris         head id: 7    head: displays  deprel: conj
# id: 11	word: from           head id: 14   head: wave      deprel: case
# id: 12	word: the            head id: 14   head: wave      deprel: det
# id: 13	word: refugee        head id: 14   head: wave      deprel: compound
# id: 14	word: wave           head id: 4    head: mixed     deprel: obl
# id: 15	word: in             head id: 16   head: 2015      deprel: case
# id: 16	word: 2015           head id: 4    head: mixed     deprel: obl
# id: 17	word: ,              head id: 16   head: 2015      deprel: punct
# id: 18	word: Greece         head id: 16   head: 2015      deprel: appos
# id: 19	word: .              head id: 4    head: mixed     deprel: punct
# id: 1	word: spotted        head id: 0    head: root      deprel: root
# id: 2	word: by             head id: 3    head: Ka        deprel: case
# id: 3	word: Ka             head id: 1    head: spotted   deprel: obl
# id: 4	word: vonSeiten      head id: 3    head: Ka        deprel: flat
# id: 5	word: in             head id: 7    head: ArtSpots  deprel: case
# id: 6	word: @              head id: 7    head: ArtSpots  deprel: case
# id: 7	word: ArtSpots       head id: 1    head: spotted   deprel: obl
# id: 1	word: App            head id: 3    head: check     deprel: vocative
# id: 2	word: ,              head id: 3    head: check     deprel: punct
# id: 3	word: check          head id: 0    head: root      deprel: root
# id: 4	word: it             head id: 3    head: check     deprel: obj
# id: 5	word: out            head id: 3    head: check     deprel: compound:prt
# id: 6	word: at             head id: 7    head: Wanna     deprel: case
# id: 7	word: Wanna          head id: 3    head: check     deprel: obl
# id: 8	word: add            head id: 3    head: check     deprel: advcl
# id: 9	word: your           head id: 11   head: findings  deprel: nmod:poss
# id: 10	word: own            head id: 11   head: findings  deprel: amod
# id: 11	word: findings       head id: 8    head: add       deprel: obj
# id: 12	word: ?              head id: 1    head: App       deprel: punct
# id: 1	word: Get            head id: 0    head: root      deprel: root
# id: 2	word: the            head id: 5    head: App       deprel: det
# id: 3	word: free           head id: 5    head: App       deprel: amod
# id: 4	word: ArtSpots       head id: 5    head: App       deprel: compound
# id: 5	word: App            head id: 1    head: Get       deprel: obj
# id: 6	word: for            head id: 7    head: Android   deprel: case
# id: 7	word: Android        head id: 1    head: Get       deprel: obl
# id: 8	word: :              head id: 1    head: Get       deprel: punct
# [['beach_displays'], ['refugee_from'], ['out_!'], ['ArtSpots_again']]
# [['again_And']]
# [['contemporary_art'], ['contemporary_mixed'], ['own_,'], ['free_again']]
# Tbh, they r more likely to ditch Greece . Greece is used by EU to murder & imprison migrants without getting hands dirty, but theres only so much that is worth to them imo? Turkey almost took that job even! (And a stack of EU cash )
# id: 1	word: Tbh            head id: 6    head: likely    deprel: discourse
# id: 2	word: ,              head id: 6    head: likely    deprel: punct
# id: 3	word: they           head id: 6    head: likely    deprel: nsubj
# id: 4	word: r              head id: 6    head: likely    deprel: cop
# id: 5	word: more           head id: 6    head: likely    deprel: advmod
# id: 6	word: likely         head id: 0    head: root      deprel: root
# id: 7	word: to             head id: 8    head: ditch     deprel: mark
# id: 8	word: ditch          head id: 6    head: likely    deprel: xcomp
# id: 9	word: Greece         head id: 8    head: ditch     deprel: obj
# id: 10	word: .              head id: 6    head: likely    deprel: punct
# id: 1	word: Greece         head id: 3    head: used      deprel: nsubj:pass
# id: 2	word: is             head id: 3    head: used      deprel: aux:pass
# id: 3	word: used           head id: 0    head: root      deprel: root
# id: 4	word: by             head id: 5    head: EU        deprel: case
# id: 5	word: EU             head id: 3    head: used      deprel: obl
# id: 6	word: to             head id: 7    head: murder    deprel: mark
# id: 7	word: murder         head id: 3    head: used      deprel: xcomp
# id: 8	word: &              head id: 9    head: imprison  deprel: cc
# id: 9	word: imprison       head id: 7    head: murder    deprel: conj
# id: 10	word: migrants       head id: 7    head: murder    deprel: obj
# id: 11	word: without        head id: 12   head: getting   deprel: mark
# id: 12	word: getting        head id: 7    head: murder    deprel: advcl
# id: 13	word: hands          head id: 14   head: dirty     deprel: compound
# id: 14	word: dirty          head id: 12   head: getting   deprel: xcomp
# id: 15	word: ,              head id: 17   head: theres    deprel: punct
# id: 16	word: but            head id: 17   head: theres    deprel: cc
# id: 17	word: theres         head id: 3    head: used      deprel: conj
# id: 18	word: only           head id: 20   head: much      deprel: advmod
# id: 19	word: so             head id: 20   head: much      deprel: advmod
# id: 20	word: much           head id: 23   head: worth     deprel: advmod
# id: 21	word: that           head id: 23   head: worth     deprel: nsubj
# id: 22	word: is             head id: 23   head: worth     deprel: cop
# id: 23	word: worth          head id: 17   head: theres    deprel: ccomp
# id: 24	word: to             head id: 25   head: them      deprel: case
# id: 25	word: them           head id: 23   head: worth     deprel: obl
# id: 26	word: imo            head id: 23   head: worth     deprel: advmod
# id: 27	word: ?              head id: 3    head: used      deprel: punct
# id: 1	word: Turkey         head id: 3    head: took      deprel: nsubj
# id: 2	word: almost         head id: 3    head: took      deprel: advmod
# id: 3	word: took           head id: 0    head: root      deprel: root
# id: 4	word: that           head id: 5    head: job       deprel: det
# id: 5	word: job            head id: 3    head: took      deprel: obj
# id: 6	word: even           head id: 3    head: took      deprel: advmod
# id: 7	word: !              head id: 3    head: took      deprel: punct
# id: 1	word: (              head id: 4    head: stack     deprel: punct
# id: 2	word: And            head id: 4    head: stack     deprel: cc
# id: 3	word: a              head id: 4    head: stack     deprel: det
# id: 4	word: stack          head id: 0    head: root      deprel: root
# id: 5	word: of             head id: 7    head: cash      deprel: case
# id: 6	word: EU             head id: 7    head: cash      deprel: compound
# id: 7	word: cash           head id: 4    head: stack     deprel: nmod
# id: 8	word: )              head id: 4    head: stack     deprel: punct
# [['hands_by'], ['EU_to']]
# [['more_likely'], ['only_migrants'], ['so_migrants'], ['much_hands'], ['imo_hands'], ['almost_they'], ['even_they']]
# []
# I have written this yesterday . And in today news: Greece reshifting migrants arriving from the sea, as Lampedusa island cannot take in any more of them . And guess where! On ships! Saw video with Afro migrants walking up on big ship! Not the first time that my Tweets became true.
# id: 1	word: I              head id: 3    head: written   deprel: nsubj
# id: 2	word: have           head id: 3    head: written   deprel: aux
# id: 3	word: written        head id: 0    head: root      deprel: root
# id: 4	word: this           head id: 3    head: written   deprel: obj
# id: 5	word: yesterday      head id: 3    head: written   deprel: obl:tmod
# id: 6	word: .              head id: 3    head: written   deprel: punct
# id: 1	word: And            head id: 19   head: take      deprel: cc
# id: 2	word: in             head id: 4    head: news      deprel: case
# id: 3	word: today          head id: 4    head: news      deprel: compound
# id: 4	word: news           head id: 0    head: root      deprel: root
# id: 5	word: :              head id: 4    head: news      deprel: punct
# id: 6	word: Greece         head id: 8    head: migrants  deprel: compound
# id: 7	word: reshifting     head id: 8    head: migrants  deprel: amod
# id: 8	word: migrants       head id: 4    head: news      deprel: appos
# id: 9	word: arriving       head id: 8    head: migrants  deprel: acl
# id: 10	word: from           head id: 12   head: sea       deprel: case
# id: 11	word: the            head id: 12   head: sea       deprel: det
# id: 12	word: sea            head id: 9    head: arriving  deprel: obl
# id: 13	word: ,              head id: 19   head: take      deprel: punct
# id: 14	word: as             head id: 19   head: take      deprel: mark
# id: 15	word: Lampedusa      head id: 16   head: island    deprel: compound
# id: 16	word: island         head id: 19   head: take      deprel: nsubj
# id: 17	word: can            head id: 19   head: take      deprel: aux
# id: 18	word: not            head id: 19   head: take      deprel: advmod
# id: 19	word: take           head id: 7    head: reshiftingdeprel: advcl
# id: 20	word: in             head id: 19   head: take      deprel: compound:prt
# id: 21	word: any            head id: 22   head: more      deprel: det
# id: 22	word: more           head id: 19   head: take      deprel: obj
# id: 23	word: of             head id: 24   head: them      deprel: case
# id: 24	word: them           head id: 22   head: more      deprel: obl
# id: 25	word: .              head id: 4    head: news      deprel: punct
# id: 1	word: And            head id: 2    head: guess     deprel: cc
# id: 2	word: guess          head id: 0    head: root      deprel: root
# id: 3	word: where          head id: 2    head: guess     deprel: mark
# id: 4	word: !              head id: 2    head: guess     deprel: punct
# id: 1	word: On             head id: 2    head: ships     deprel: case
# id: 2	word: ships          head id: 0    head: root      deprel: root
# id: 3	word: !              head id: 2    head: ships     deprel: punct
# id: 1	word: Saw            head id: 0    head: root      deprel: root
# id: 2	word: video          head id: 1    head: Saw       deprel: obj
# id: 3	word: with           head id: 5    head: migrants  deprel: case
# id: 4	word: Afro           head id: 5    head: migrants  deprel: amod
# id: 5	word: migrants       head id: 2    head: video     deprel: nmod
# id: 6	word: walking        head id: 5    head: migrants  deprel: acl
# id: 7	word: up             head id: 6    head: walking   deprel: compound:prt
# id: 8	word: on             head id: 10   head: ship      deprel: case
# id: 9	word: big            head id: 10   head: ship      deprel: amod
# id: 10	word: ship           head id: 6    head: walking   deprel: obl
# id: 11	word: !              head id: 1    head: Saw       deprel: punct
# id: 1	word: Not            head id: 4    head: time      deprel: advmod
# id: 2	word: the            head id: 4    head: time      deprel: det
# id: 3	word: first          head id: 4    head: time      deprel: amod
# id: 4	word: time           head id: 0    head: root      deprel: root
# id: 5	word: that           head id: 8    head: became    deprel: mark
# id: 6	word: my             head id: 7    head: Tweets    deprel: nmod:poss
# id: 7	word: Tweets         head id: 8    head: became    deprel: nsubj
# id: 8	word: became         head id: 4    head: time      deprel: acl:relcl
# id: 9	word: true           head id: 8    head: became    deprel: xcomp
# id: 10	word: .              head id: 4    head: time      deprel: punct
# [['today_this'], ['Greece_in'], ['Lampedusa_from'], ['in_,'], ['up_.']]
# [['not_,'], ['Not_this']]
# [['reshifting_in'], ['Afro_yesterday'], ['big_news'], ['first_this']]
# After First COVID - 19 Case in Moria Refugee Camp, Greece Imposes Dangerou . . . @YouTube
# id: 1	word: After          head id: 6    head: Case      deprel: case
# id: 2	word: First          head id: 6    head: Case      deprel: compound
# id: 3	word: COVID          head id: 6    head: Case      deprel: compound
# id: 4	word: -              head id: 3    head: COVID     deprel: punct
# id: 5	word: 19             head id: 3    head: COVID     deprel: nummod
# id: 6	word: Case           head id: 13   head: Imposes   deprel: obl
# id: 7	word: in             head id: 10   head: Camp      deprel: case
# id: 8	word: Moria          head id: 10   head: Camp      deprel: compound
# id: 9	word: Refugee        head id: 10   head: Camp      deprel: compound
# id: 10	word: Camp           head id: 6    head: Case      deprel: nmod
# id: 11	word: ,              head id: 6    head: Case      deprel: punct
# id: 12	word: Greece         head id: 13   head: Imposes   deprel: nsubj
# id: 13	word: Imposes        head id: 0    head: root      deprel: root
# id: 14	word: Dangerou       head id: 13   head: Imposes   deprel: obj
# id: 15	word: .              head id: 13   head: Imposes   deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: @YouTube       head id: 0    head: root      deprel: root
# [['First_Case'], ['COVID_Case'], ['Moria_Camp'], ['Refugee_Camp']]
# []
# []
# Thessaloniki - Migration Completed - We have completed our migration of our services in Thessaloniki, Greece . Please contact support if youre experiencing any issues.
# id: 1	word: Thessaloniki   head id: 0    head: root      deprel: root
# id: 2	word: -              head id: 1    head: Thessalonikideprel: punct
# id: 3	word: Migration      head id: 4    head: Completed deprel: nsubj
# id: 4	word: Completed      head id: 1    head: Thessalonikideprel: parataxis
# id: 5	word: -              head id: 1    head: Thessalonikideprel: punct
# id: 1	word: We             head id: 3    head: completed deprel: nsubj
# id: 2	word: have           head id: 3    head: completed deprel: aux
# id: 3	word: completed      head id: 0    head: root      deprel: root
# id: 4	word: our            head id: 5    head: migration deprel: nmod:poss
# id: 5	word: migration      head id: 3    head: completed deprel: obj
# id: 6	word: of             head id: 8    head: services  deprel: case
# id: 7	word: our            head id: 8    head: services  deprel: nmod:poss
# id: 8	word: services       head id: 5    head: migration deprel: nmod
# id: 9	word: in             head id: 10   head: Thessalonikideprel: case
# id: 10	word: Thessaloniki   head id: 3    head: completed deprel: obl
# id: 11	word: ,              head id: 10   head: Thessalonikideprel: punct
# id: 12	word: Greece         head id: 10   head: Thessalonikideprel: appos
# id: 13	word: .              head id: 3    head: completed deprel: punct
# id: 1	word: Please         head id: 2    head: contact   deprel: discourse
# id: 2	word: contact        head id: 0    head: root      deprel: root
# id: 3	word: support        head id: 2    head: contact   deprel: obj
# id: 4	word: if             head id: 6    head: experiencingdeprel: mark
# id: 5	word: youre          head id: 6    head: experiencingdeprel: nsubj
# id: 6	word: experiencing   head id: 2    head: contact   deprel: advcl
# id: 7	word: any            head id: 8    head: issues    deprel: det
# id: 8	word: issues         head id: 6    head: experiencingdeprel: obj
# id: 9	word: .              head id: 2    head: contact   deprel: punct
# []
# []
# []
# He is refuge but Greece doesnt accepted to him he want to go to the another country maybe Greece want to send to him back killer to Iran
# id: 1	word: He             head id: 3    head: refuge    deprel: nsubj
# id: 2	word: is             head id: 3    head: refuge    deprel: cop
# id: 3	word: refuge         head id: 0    head: root      deprel: root
# id: 4	word: but            head id: 7    head: accepted  deprel: cc
# id: 5	word: Greece         head id: 7    head: accepted  deprel: nsubj
# id: 6	word: doesnt         head id: 7    head: accepted  deprel: aux
# id: 7	word: accepted       head id: 3    head: refuge    deprel: conj
# id: 8	word: to             head id: 9    head: him       deprel: case
# id: 9	word: him            head id: 7    head: accepted  deprel: obl
# id: 10	word: he             head id: 11   head: want      deprel: nsubj
# id: 11	word: want           head id: 3    head: refuge    deprel: parataxis
# id: 12	word: to             head id: 13   head: go        deprel: mark
# id: 13	word: go             head id: 11   head: want      deprel: xcomp
# id: 14	word: to             head id: 17   head: country   deprel: case
# id: 15	word: the            head id: 17   head: country   deprel: det
# id: 16	word: another        head id: 17   head: country   deprel: det
# id: 17	word: country        head id: 13   head: go        deprel: obl
# id: 18	word: maybe          head id: 20   head: want      deprel: advmod
# id: 19	word: Greece         head id: 20   head: want      deprel: nsubj
# id: 20	word: want           head id: 13   head: go        deprel: advcl
# id: 21	word: to             head id: 22   head: send      deprel: mark
# id: 22	word: send           head id: 20   head: want      deprel: xcomp
# id: 23	word: to             head id: 24   head: him       deprel: case
# id: 24	word: him            head id: 22   head: send      deprel: obl
# id: 25	word: back           head id: 26   head: killer    deprel: advmod
# id: 26	word: killer         head id: 22   head: send      deprel: obj
# id: 27	word: to             head id: 28   head: Iran      deprel: case
# id: 28	word: Iran           head id: 26   head: killer    deprel: nmod
# []
# [['maybe_want'], ['back_killer']]
# []
# Muslims not welcome in Greece are jihadists and they have countries but they want to destabilize Greece . We will not give them chance to survive . . Islam is a cancee
# id: 1	word: Muslims        head id: 7    head: jihadists deprel: nsubj
# id: 2	word: not            head id: 3    head: welcome   deprel: advmod
# id: 3	word: welcome        head id: 1    head: Muslims   deprel: amod
# id: 4	word: in             head id: 5    head: Greece    deprel: case
# id: 5	word: Greece         head id: 3    head: welcome   deprel: obl
# id: 6	word: are            head id: 7    head: jihadists deprel: cop
# id: 7	word: jihadists      head id: 0    head: root      deprel: root
# id: 8	word: and            head id: 10   head: have      deprel: cc
# id: 9	word: they           head id: 10   head: have      deprel: nsubj
# id: 10	word: have           head id: 7    head: jihadists deprel: conj
# id: 11	word: countries      head id: 10   head: have      deprel: obj
# id: 12	word: but            head id: 14   head: want      deprel: cc
# id: 13	word: they           head id: 14   head: want      deprel: nsubj
# id: 14	word: want           head id: 7    head: jihadists deprel: conj
# id: 15	word: to             head id: 16   head: destabilizedeprel: mark
# id: 16	word: destabilize    head id: 14   head: want      deprel: xcomp
# id: 17	word: Greece         head id: 16   head: destabilizedeprel: obj
# id: 18	word: .              head id: 7    head: jihadists deprel: punct
# id: 1	word: We             head id: 4    head: give      deprel: nsubj
# id: 2	word: will           head id: 4    head: give      deprel: aux
# id: 3	word: not            head id: 4    head: give      deprel: advmod
# id: 4	word: give           head id: 0    head: root      deprel: root
# id: 5	word: them           head id: 4    head: give      deprel: iobj
# id: 6	word: chance         head id: 4    head: give      deprel: obj
# id: 7	word: to             head id: 8    head: survive   deprel: mark
# id: 8	word: survive        head id: 6    head: chance    deprel: acl
# id: 9	word: .              head id: 4    head: give      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: Islam          head id: 4    head: cancee    deprel: nsubj
# id: 2	word: is             head id: 4    head: cancee    deprel: cop
# id: 3	word: a              head id: 4    head: cancee    deprel: det
# id: 4	word: cancee         head id: 0    head: root      deprel: root
# []
# [['not_welcome'], ['not_in']]
# [['welcome_Muslims']]
# Greece not jobs for foreigners all this people should return back to their home countries coming back . Islam is a gang as per the courts in a lot of countries like Hungary Greece Angola so those Muslims considered aa constitution of gang . . Islam nor acceptable in Greece
# id: 1	word: Greece         head id: 10   head: return    deprel: nsubj
# id: 2	word: not            head id: 3    head: jobs      deprel: advmod
# id: 3	word: jobs           head id: 10   head: return    deprel: nsubj
# id: 4	word: for            head id: 5    head: foreignersdeprel: case
# id: 5	word: foreigners     head id: 3    head: jobs      deprel: nmod
# id: 6	word: all            head id: 8    head: people    deprel: det:predet
# id: 7	word: this           head id: 8    head: people    deprel: det
# id: 8	word: people         head id: 5    head: foreignersdeprel: appos
# id: 9	word: should         head id: 10   head: return    deprel: aux
# id: 10	word: return         head id: 0    head: root      deprel: root
# id: 11	word: back           head id: 10   head: return    deprel: advmod
# id: 12	word: to             head id: 15   head: countries deprel: case
# id: 13	word: their          head id: 15   head: countries deprel: nmod:poss
# id: 14	word: home           head id: 15   head: countries deprel: compound
# id: 15	word: countries      head id: 11   head: back      deprel: obl
# id: 16	word: coming         head id: 15   head: countries deprel: acl
# id: 17	word: back           head id: 16   head: coming    deprel: advmod
# id: 18	word: .              head id: 10   head: return    deprel: punct
# id: 1	word: Islam          head id: 4    head: gang      deprel: nsubj
# id: 2	word: is             head id: 4    head: gang      deprel: cop
# id: 3	word: a              head id: 4    head: gang      deprel: det
# id: 4	word: gang           head id: 0    head: root      deprel: root
# id: 5	word: as             head id: 8    head: courts    deprel: case
# id: 6	word: per            head id: 8    head: courts    deprel: case
# id: 7	word: the            head id: 8    head: courts    deprel: det
# id: 8	word: courts         head id: 4    head: gang      deprel: nmod
# id: 9	word: in             head id: 11   head: lot       deprel: case
# id: 10	word: a              head id: 11   head: lot       deprel: det
# id: 11	word: lot            head id: 4    head: gang      deprel: nmod
# id: 12	word: of             head id: 13   head: countries deprel: case
# id: 13	word: countries      head id: 11   head: lot       deprel: nmod
# id: 14	word: like           head id: 15   head: Hungary   deprel: case
# id: 15	word: Hungary        head id: 17   head: Angola    deprel: compound
# id: 16	word: Greece         head id: 17   head: Angola    deprel: compound
# id: 17	word: Angola         head id: 13   head: countries deprel: nmod
# id: 18	word: so             head id: 21   head: considereddeprel: advmod
# id: 19	word: those          head id: 20   head: Muslims   deprel: det
# id: 20	word: Muslims        head id: 21   head: considereddeprel: nsubj
# id: 21	word: considered     head id: 4    head: gang      deprel: parataxis
# id: 22	word: aa             head id: 23   head: constitutiondeprel: det
# id: 23	word: constitution   head id: 21   head: considereddeprel: obj
# id: 24	word: of             head id: 25   head: gang      deprel: case
# id: 25	word: gang           head id: 23   head: constitutiondeprel: nmod
# id: 26	word: .              head id: 4    head: gang      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: Islam          head id: 0    head: root      deprel: root
# id: 2	word: nor            head id: 3    head: acceptabledeprel: cc
# id: 3	word: acceptable     head id: 1    head: Islam     deprel: conj
# id: 4	word: in             head id: 5    head: Greece    deprel: case
# id: 5	word: Greece         head id: 1    head: Islam     deprel: nmod
# [['home_countries'], ['Hungary_back'], ['Greece_back']]
# [['not_jobs'], ['back_return'], ['back_coming'], ['so_a']]
# []
# Greeces overcrowded Moria migrant camp reports FIRST coronavirus case First Published on September 2, 2020 @6 : 03am news
# id: 1	word: Greeces        head id: 6    head: reports   deprel: compound
# id: 2	word: overcrowded    head id: 6    head: reports   deprel: amod
# id: 3	word: Moria          head id: 6    head: reports   deprel: compound
# id: 4	word: migrant        head id: 6    head: reports   deprel: amod
# id: 5	word: camp           head id: 6    head: reports   deprel: compound
# id: 6	word: reports        head id: 11   head: Published deprel: nsubj:pass
# id: 7	word: FIRST          head id: 9    head: case      deprel: amod
# id: 8	word: coronavirus    head id: 9    head: case      deprel: amod
# id: 9	word: case           head id: 6    head: reports   deprel: appos
# id: 10	word: First          head id: 11   head: Published deprel: advmod
# id: 11	word: Published      head id: 0    head: root      deprel: root
# id: 12	word: on             head id: 13   head: September deprel: case
# id: 13	word: September      head id: 11   head: Published deprel: obl
# id: 14	word: 2              head id: 13   head: September deprel: nummod
# id: 15	word: ,              head id: 13   head: September deprel: punct
# id: 16	word: 2020           head id: 13   head: September deprel: nummod
# id: 17	word: @              head id: 18   head: 6         deprel: case
# id: 18	word: 6              head id: 11   head: Published deprel: obl
# id: 19	word: :              head id: 22   head: news      deprel: punct
# id: 20	word: 03             head id: 21   head: am        deprel: nummod
# id: 21	word: am             head id: 22   head: news      deprel: compound
# id: 22	word: news           head id: 11   head: Published deprel: obl
# [['Greeces_reports'], ['Moria_reports'], ['camp_reports'], ['am_news']]
# [['First_Published']]
# [['overcrowded_reports'], ['migrant_reports'], ['FIRST_case'], ['coronavirus_case']]
# Where for example was the EU when Greece was in financial shtook . On, could it be it wasn' t in charge of its own currency? Where was the EU when Italy needed help (which by the way it will need a massive bailout soon) when the migrants landed there?
# id: 1	word: Where          head id: 6    head: EU        deprel: advmod
# id: 2	word: for            head id: 3    head: example   deprel: case
# id: 3	word: example        head id: 1    head: Where     deprel: obl
# id: 4	word: was            head id: 6    head: EU        deprel: cop
# id: 5	word: the            head id: 6    head: EU        deprel: det
# id: 6	word: EU             head id: 0    head: root      deprel: root
# id: 7	word: when           head id: 12   head: shtook    deprel: mark
# id: 8	word: Greece         head id: 12   head: shtook    deprel: nsubj
# id: 9	word: was            head id: 12   head: shtook    deprel: cop
# id: 10	word: in             head id: 12   head: shtook    deprel: case
# id: 11	word: financial      head id: 12   head: shtook    deprel: amod
# id: 12	word: shtook         head id: 6    head: EU        deprel: advcl
# id: 13	word: .              head id: 6    head: EU        deprel: punct
# id: 1	word: On             head id: 5    head: be        deprel: advmod
# id: 2	word: ,              head id: 5    head: be        deprel: punct
# id: 3	word: could          head id: 5    head: be        deprel: aux
# id: 4	word: it             head id: 5    head: be        deprel: nsubj
# id: 5	word: be             head id: 0    head: root      deprel: root
# id: 6	word: it             head id: 5    head: be        deprel: expl
# id: 7	word: wasn           head id: 9    head: t         deprel: cop
# id: 8	word: '              head id: 9    head: t         deprel: punct
# id: 9	word: t              head id: 5    head: be        deprel: ccomp
# id: 10	word: in             head id: 11   head: charge    deprel: case
# id: 11	word: charge         head id: 9    head: t         deprel: nmod
# id: 12	word: of             head id: 15   head: currency  deprel: case
# id: 13	word: its            head id: 15   head: currency  deprel: nmod:poss
# id: 14	word: own            head id: 15   head: currency  deprel: amod
# id: 15	word: currency       head id: 11   head: charge    deprel: nmod
# id: 16	word: ?              head id: 5    head: be        deprel: punct
# id: 1	word: Where          head id: 0    head: root      deprel: root
# id: 2	word: was            head id: 1    head: Where     deprel: cop
# id: 3	word: the            head id: 4    head: EU        deprel: det
# id: 4	word: EU             head id: 1    head: Where     deprel: nsubj
# id: 5	word: when           head id: 7    head: needed    deprel: mark
# id: 6	word: Italy          head id: 7    head: needed    deprel: nsubj
# id: 7	word: needed         head id: 1    head: Where     deprel: advcl
# id: 8	word: help           head id: 7    head: needed    deprel: obj
# id: 9	word: (              head id: 16   head: need      deprel: punct
# id: 10	word: which          head id: 16   head: need      deprel: nsubj
# id: 11	word: by             head id: 13   head: way       deprel: case
# id: 12	word: the            head id: 13   head: way       deprel: det
# id: 13	word: way            head id: 16   head: need      deprel: obl
# id: 14	word: it             head id: 16   head: need      deprel: nsubj
# id: 15	word: will           head id: 16   head: need      deprel: aux
# id: 16	word: need           head id: 8    head: help      deprel: acl:relcl
# id: 17	word: a              head id: 19   head: bailout   deprel: det
# id: 18	word: massive        head id: 19   head: bailout   deprel: amod
# id: 19	word: bailout        head id: 16   head: need      deprel: obj
# id: 20	word: soon           head id: 16   head: need      deprel: advmod
# id: 21	word: )              head id: 16   head: need      deprel: punct
# id: 22	word: when           head id: 25   head: landed    deprel: mark
# id: 23	word: the            head id: 24   head: migrants  deprel: det
# id: 24	word: migrants       head id: 25   head: landed    deprel: nsubj
# id: 25	word: landed         head id: 16   head: need      deprel: advcl
# id: 26	word: there          head id: 25   head: landed    deprel: advmod
# id: 27	word: ?              head id: 1    head: Where     deprel: punct
# []
# [['Where_EU'], ['On_the'], ['soon_could'], ['there_of']]
# [['financial_shtook'], ['own_,'], ['massive_it']]
# If the Bucks dont make it to past the Heat is there any chance of Giannis moving to the Raptors?? He must be tight with Masai after he apparently helped his family migrate to Greece
# id: 1	word: If             head id: 5    head: make      deprel: mark
# id: 2	word: the            head id: 3    head: Bucks     deprel: det
# id: 3	word: Bucks          head id: 5    head: make      deprel: nsubj
# id: 4	word: dont           head id: 5    head: make      deprel: aux
# id: 5	word: make           head id: 11   head: is        deprel: advcl
# id: 6	word: it             head id: 5    head: make      deprel: obj
# id: 7	word: to             head id: 10   head: Heat      deprel: mark
# id: 8	word: past           head id: 10   head: Heat      deprel: case
# id: 9	word: the            head id: 10   head: Heat      deprel: det
# id: 10	word: Heat           head id: 5    head: make      deprel: obl
# id: 11	word: is             head id: 0    head: root      deprel: root
# id: 12	word: there          head id: 11   head: is        deprel: expl
# id: 13	word: any            head id: 14   head: chance    deprel: det
# id: 14	word: chance         head id: 11   head: is        deprel: nsubj
# id: 15	word: of             head id: 16   head: Giannis   deprel: case
# id: 16	word: Giannis        head id: 14   head: chance    deprel: nmod
# id: 17	word: moving         head id: 16   head: Giannis   deprel: acl
# id: 18	word: to             head id: 20   head: Raptors   deprel: case
# id: 19	word: the            head id: 20   head: Raptors   deprel: det
# id: 20	word: Raptors        head id: 17   head: moving    deprel: obl
# id: 21	word: ??             head id: 11   head: is        deprel: punct
# id: 1	word: He             head id: 4    head: tight     deprel: nsubj
# id: 2	word: must           head id: 4    head: tight     deprel: aux
# id: 3	word: be             head id: 4    head: tight     deprel: cop
# id: 4	word: tight          head id: 0    head: root      deprel: root
# id: 5	word: with           head id: 6    head: Masai     deprel: case
# id: 6	word: Masai          head id: 4    head: tight     deprel: obl
# id: 7	word: after          head id: 10   head: helped    deprel: mark
# id: 8	word: he             head id: 10   head: helped    deprel: nsubj
# id: 9	word: apparently     head id: 10   head: helped    deprel: advmod
# id: 10	word: helped         head id: 4    head: tight     deprel: advcl
# id: 11	word: his            head id: 12   head: family    deprel: nmod:poss
# id: 12	word: family         head id: 13   head: migrate   deprel: nsubj
# id: 13	word: migrate        head id: 10   head: helped    deprel: xcomp
# id: 14	word: to             head id: 15   head: Greece    deprel: case
# id: 15	word: Greece         head id: 13   head: migrate   deprel: obl
# []
# [['apparently_Heat']]
# []
# Social distancing & basic hygiene measures like handwashing are simply impossible to adhere to in Moria, says IRC' s Dimitra Kalogeropoulou . As covid 19 reaches Moria refugee camp in Lesvos, Greece we' re calling for urgent support . More in @Reuters :
# id: 1	word: Social         head id: 2    head: distancingdeprel: amod
# id: 2	word: distancing     head id: 11   head: impossibledeprel: nsubj
# id: 3	word: &              head id: 6    head: measures  deprel: cc
# id: 4	word: basic          head id: 5    head: hygiene   deprel: amod
# id: 5	word: hygiene        head id: 6    head: measures  deprel: compound
# id: 6	word: measures       head id: 2    head: distancingdeprel: conj
# id: 7	word: like           head id: 8    head: handwashingdeprel: case
# id: 8	word: handwashing    head id: 6    head: measures  deprel: nmod
# id: 9	word: are            head id: 11   head: impossibledeprel: cop
# id: 10	word: simply         head id: 11   head: impossibledeprel: advmod
# id: 11	word: impossible     head id: 18   head: says      deprel: ccomp
# id: 12	word: to             head id: 13   head: adhere    deprel: mark
# id: 13	word: adhere         head id: 11   head: impossibledeprel: xcomp
# id: 14	word: to             head id: 13   head: adhere    deprel: obl
# id: 15	word: in             head id: 16   head: Moria     deprel: case
# id: 16	word: Moria          head id: 13   head: adhere    deprel: obl
# id: 17	word: ,              head id: 18   head: says      deprel: punct
# id: 18	word: says           head id: 0    head: root      deprel: root
# id: 19	word: IRC            head id: 22   head: Dimitra   deprel: nmod:poss
# id: 20	word: '              head id: 19   head: IRC       deprel: case
# id: 21	word: s              head id: 19   head: IRC       deprel: case
# id: 22	word: Dimitra        head id: 18   head: says      deprel: nsubj
# id: 23	word: Kalogeropoulou head id: 22   head: Dimitra   deprel: flat
# id: 24	word: .              head id: 18   head: says      deprel: punct
# id: 1	word: As             head id: 4    head: reaches   deprel: mark
# id: 2	word: covid          head id: 4    head: reaches   deprel: nsubj
# id: 3	word: 19             head id: 2    head: covid     deprel: flat
# id: 4	word: reaches        head id: 15   head: calling   deprel: advcl
# id: 5	word: Moria          head id: 7    head: camp      deprel: compound
# id: 6	word: refugee        head id: 7    head: camp      deprel: compound
# id: 7	word: camp           head id: 4    head: reaches   deprel: obj
# id: 8	word: in             head id: 9    head: Lesvos    deprel: case
# id: 9	word: Lesvos         head id: 7    head: camp      deprel: nmod
# id: 10	word: ,              head id: 12   head: we        deprel: punct
# id: 11	word: Greece         head id: 12   head: we        deprel: compound
# id: 12	word: we             head id: 15   head: calling   deprel: nsubj
# id: 13	word: '              head id: 12   head: we        deprel: punct
# id: 14	word: re             head id: 0    head: root      deprel: root
# id: 15	word: calling        head id: 14   head: re        deprel: xcomp
# id: 16	word: for            head id: 18   head: support   deprel: case
# id: 17	word: urgent         head id: 18   head: support   deprel: amod
# id: 18	word: support        head id: 15   head: calling   deprel: obl
# id: 19	word: .              head id: 15   head: calling   deprel: punct
# id: 1	word: More           head id: 0    head: root      deprel: root
# id: 2	word: in             head id: 4    head: Reuters   deprel: case
# id: 3	word: @              head id: 4    head: Reuters   deprel: case
# id: 4	word: Reuters        head id: 1    head: More      deprel: obl
# id: 5	word: :              head id: 1    head: More      deprel: punct
# [['hygiene_measures'], ['Moria_like'], ['refugee_like'], ['Greece_to']]
# [['simply_impossible']]
# [['Social_distancing'], ['basic_hygiene'], ['urgent_says']]
# Erdogan and his country Turkey is hosting 4.5 million innocent refugees, saved them, shaltered them, protected them . While Italy and Greece were trying to sank refugees boats . If world be fair place you would not call him fascist you would nominate him to Nobel Peace Prize
# id: 1	word: Erdogan        head id: 7    head: hosting   deprel: nsubj
# id: 2	word: and            head id: 4    head: country   deprel: cc
# id: 3	word: his            head id: 4    head: country   deprel: nmod:poss
# id: 4	word: country        head id: 1    head: Erdogan   deprel: conj
# id: 5	word: Turkey         head id: 1    head: Erdogan   deprel: conj
# id: 6	word: is             head id: 7    head: hosting   deprel: aux
# id: 7	word: hosting        head id: 0    head: root      deprel: root
# id: 8	word: 4.5            head id: 9    head: million   deprel: compound
# id: 9	word: million        head id: 11   head: refugees  deprel: nummod
# id: 10	word: innocent       head id: 11   head: refugees  deprel: amod
# id: 11	word: refugees       head id: 7    head: hosting   deprel: obj
# id: 12	word: ,              head id: 13   head: saved     deprel: punct
# id: 13	word: saved          head id: 7    head: hosting   deprel: conj
# id: 14	word: them           head id: 13   head: saved     deprel: obj
# id: 15	word: ,              head id: 16   head: shaltered deprel: punct
# id: 16	word: shaltered      head id: 13   head: saved     deprel: conj
# id: 17	word: them           head id: 16   head: shaltered deprel: obj
# id: 18	word: ,              head id: 19   head: protected deprel: punct
# id: 19	word: protected      head id: 7    head: hosting   deprel: conj
# id: 20	word: them           head id: 19   head: protected deprel: obj
# id: 21	word: .              head id: 7    head: hosting   deprel: punct
# id: 1	word: While          head id: 6    head: trying    deprel: mark
# id: 2	word: Italy          head id: 6    head: trying    deprel: nsubj
# id: 3	word: and            head id: 4    head: Greece    deprel: cc
# id: 4	word: Greece         head id: 2    head: Italy     deprel: conj
# id: 5	word: were           head id: 6    head: trying    deprel: aux
# id: 6	word: trying         head id: 0    head: root      deprel: root
# id: 7	word: to             head id: 8    head: sank      deprel: mark
# id: 8	word: sank           head id: 6    head: trying    deprel: xcomp
# id: 9	word: refugees       head id: 10   head: boats     deprel: compound
# id: 10	word: boats          head id: 8    head: sank      deprel: obj
# id: 11	word: .              head id: 6    head: trying    deprel: punct
# id: 1	word: If             head id: 5    head: place     deprel: mark
# id: 2	word: world          head id: 5    head: place     deprel: nsubj
# id: 3	word: be             head id: 5    head: place     deprel: cop
# id: 4	word: fair           head id: 5    head: place     deprel: amod
# id: 5	word: place          head id: 9    head: call      deprel: advcl
# id: 6	word: you            head id: 9    head: call      deprel: nsubj
# ...
# id: 1	word: Those          head id: 6    head: claimed   deprel: nsubj
# id: 2	word: in             head id: 3    head: France    deprel: case
# id: 3	word: France         head id: 1    head: Those     deprel: nmod
# id: 4	word: could          head id: 6    head: claimed   deprel: aux
# id: 5	word: have           head id: 6    head: claimed   deprel: aux
# id: 6	word: claimed        head id: 0    head: root      deprel: root
# id: 7	word: asylum         head id: 6    head: claimed   deprel: obj
# id: 8	word: in             head id: 14   head: islands   deprel: case
# id: 9	word: Greece         head id: 14   head: islands   deprel: compound
# id: 10	word: /              head id: 11   head: Italy     deprel: cc
# id: 11	word: Italy          head id: 9    head: Greece    deprel: conj
# id: 12	word: /              head id: 13   head: Spanish   deprel: cc
# id: 13	word: Spanish        head id: 14   head: islands   deprel: amod
# id: 14	word: islands        head id: 7    head: asylum    deprel: nmod
# id: 15	word: or             head id: 18   head: came      deprel: cc
# id: 16	word: wherever       head id: 18   head: came      deprel: mark
# id: 17	word: they           head id: 18   head: came      deprel: nsubj
# id: 18	word: came           head id: 6    head: claimed   deprel: conj
# id: 19	word: to             head id: 18   head: came      deprel: obl
# id: 20	word: ,              head id: 21   head: received  deprel: punct
# id: 21	word: received       head id: 6    head: claimed   deprel: conj
# id: 22	word: EU             head id: 23   head: papers    deprel: compound
# id: 23	word: papers         head id: 21   head: received  deprel: obj
# id: 24	word: and            head id: 25   head: travelled deprel: cc
# id: 25	word: travelled      head id: 21   head: received  deprel: conj
# id: 26	word: to             head id: 28   head: UK        deprel: case
# id: 27	word: the            head id: 28   head: UK        deprel: det
# id: 28	word: UK             head id: 25   head: travelled deprel: obl
# id: 29	word: legally        head id: 25   head: travelled deprel: advmod
# id: 30	word: .              head id: 6    head: claimed   deprel: punct
# [['Greece_asylum'], ['EU_wherever']]
# [['legally_came']]
# [['legitimate_means'], ['Spanish_asylum']]
# You forgot to mention the run away Turks who ask for Asylum in Greece . . . they are hundreds . . and don' t worry we protect them better than you lot over there, here they are FREE . . . .
# id: 1	word: You            head id: 2    head: forgot    deprel: nsubj
# id: 2	word: forgot         head id: 0    head: root      deprel: root
# id: 3	word: to             head id: 4    head: mention   deprel: mark
# id: 4	word: mention        head id: 2    head: forgot    deprel: xcomp
# id: 5	word: the            head id: 8    head: Turks     deprel: det
# id: 6	word: run            head id: 8    head: Turks     deprel: compound
# id: 7	word: away           head id: 8    head: Turks     deprel: amod
# id: 8	word: Turks          head id: 4    head: mention   deprel: obj
# id: 9	word: who            head id: 10   head: ask       deprel: nsubj
# id: 10	word: ask            head id: 8    head: Turks     deprel: acl:relcl
# id: 11	word: for            head id: 12   head: Asylum    deprel: case
# id: 12	word: Asylum         head id: 10   head: ask       deprel: obl
# id: 13	word: in             head id: 14   head: Greece    deprel: case
# id: 14	word: Greece         head id: 10   head: ask       deprel: obl
# id: 15	word: .              head id: 2    head: forgot    deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: they           head id: 3    head: hundreds  deprel: nsubj
# id: 2	word: are            head id: 3    head: hundreds  deprel: cop
# id: 3	word: hundreds       head id: 0    head: root      deprel: root
# id: 4	word: .              head id: 3    head: hundreds  deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: and            head id: 16   head: here      deprel: cc
# id: 2	word: don            head id: 16   head: here      deprel: vocative
# id: 3	word: '              head id: 5    head: worry     deprel: punct
# id: 4	word: t              head id: 5    head: worry     deprel: nsubj
# id: 5	word: worry          head id: 2    head: don       deprel: parataxis
# id: 6	word: we             head id: 7    head: protect   deprel: nsubj
# id: 7	word: protect        head id: 5    head: worry     deprel: ccomp
# id: 8	word: them           head id: 7    head: protect   deprel: obj
# id: 9	word: better         head id: 7    head: protect   deprel: advmod
# id: 10	word: than           head id: 12   head: lot       deprel: mark
# id: 11	word: you            head id: 12   head: lot       deprel: nsubj
# id: 12	word: lot            head id: 7    head: protect   deprel: advcl
# id: 13	word: over           head id: 14   head: there     deprel: case
# id: 14	word: there          head id: 12   head: lot       deprel: obl
# id: 15	word: ,              head id: 16   head: here      deprel: punct
# id: 16	word: here           head id: 0    head: root      deprel: root
# id: 17	word: they           head id: 19   head: FREE      deprel: nsubj
# id: 18	word: are            head id: 19   head: FREE      deprel: cop
# id: 19	word: FREE           head id: 16   head: here      deprel: parataxis
# id: 20	word: .              head id: 16   head: here      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# [['run_Turks']]
# [['better_away']]
# [['away_Turks']]
# Doctors Without Borders: Greek Government is enforcing an ill - considered & potentially very damaging & harmful quarantine on moria camp for migrants & asylum seekers on the island of lesbos, greece - Police enforce cruel covid 19 quarantine of camp
# id: 1	word: Doctors        head id: 0    head: root      deprel: root
# id: 2	word: Without        head id: 3    head: Borders   deprel: case
# id: 3	word: Borders        head id: 1    head: Doctors   deprel: nmod
# id: 4	word: :              head id: 1    head: Doctors   deprel: punct
# id: 5	word: Greek          head id: 6    head: Governmentdeprel: amod
# id: 6	word: Government     head id: 8    head: enforcing deprel: nsubj
# id: 7	word: is             head id: 8    head: enforcing deprel: aux
# id: 8	word: enforcing      head id: 1    head: Doctors   deprel: parataxis
# id: 9	word: an             head id: 19   head: quarantinedeprel: det
# id: 10	word: ill            head id: 12   head: considereddeprel: compound
# id: 11	word: -              head id: 12   head: considereddeprel: punct
# id: 12	word: considered     head id: 19   head: quarantinedeprel: amod
# id: 13	word: &              head id: 16   head: damaging  deprel: cc
# id: 14	word: potentially    head id: 16   head: damaging  deprel: advmod
# id: 15	word: very           head id: 16   head: damaging  deprel: advmod
# id: 16	word: damaging       head id: 12   head: considereddeprel: conj
# id: 17	word: &              head id: 18   head: harmful   deprel: cc
# id: 18	word: harmful        head id: 12   head: considereddeprel: conj
# id: 19	word: quarantine     head id: 8    head: enforcing deprel: obj
# id: 20	word: on             head id: 22   head: camp      deprel: case
# id: 21	word: moria          head id: 22   head: camp      deprel: compound
# id: 22	word: camp           head id: 19   head: quarantinedeprel: nmod
# id: 23	word: for            head id: 24   head: migrants  deprel: case
# id: 24	word: migrants       head id: 19   head: quarantinedeprel: nmod
# id: 25	word: &              head id: 27   head: seekers   deprel: cc
# id: 26	word: asylum         head id: 27   head: seekers   deprel: compound
# id: 27	word: seekers        head id: 24   head: migrants  deprel: conj
# id: 28	word: on             head id: 30   head: island    deprel: case
# id: 29	word: the            head id: 30   head: island    deprel: det
# id: 30	word: island         head id: 24   head: migrants  deprel: nmod
# id: 31	word: of             head id: 32   head: lesbos    deprel: case
# id: 32	word: lesbos         head id: 30   head: island    deprel: nmod
# id: 33	word: ,              head id: 37   head: enforce   deprel: punct
# id: 34	word: greece         head id: 36   head: Police    deprel: compound
# id: 35	word: -              head id: 36   head: Police    deprel: punct
# id: 36	word: Police         head id: 37   head: enforce   deprel: nsubj
# id: 37	word: enforce        head id: 1    head: Doctors   deprel: parataxis
# id: 38	word: cruel          head id: 41   head: quarantinedeprel: amod
# id: 39	word: covid          head id: 41   head: quarantinedeprel: compound
# id: 40	word: 19             head id: 39   head: covid     deprel: nummod
# id: 41	word: quarantine     head id: 37   head: enforce   deprel: obj
# id: 42	word: of             head id: 43   head: camp      deprel: case
# id: 43	word: camp           head id: 41   head: quarantinedeprel: nmod
# [['ill_considered'], ['moria_camp'], ['asylum_seekers'], ['greece_Police'], ['covid_quarantine']]
# [['potentially_damaging'], ['very_damaging']]
# [['Greek_Government'], ['considered_quarantine'], ['cruel_quarantine']]
# I have learned so much on here too . Many people also didnt know how badly the Greek refugees from Turkey were treated in Greece also . So many Greeks and Turks have told me they didnt know . This is crazy to me . Our history is so conplciated
# id: 1	word: I              head id: 3    head: learned   deprel: nsubj
# id: 2	word: have           head id: 3    head: learned   deprel: aux
# id: 3	word: learned        head id: 0    head: root      deprel: root
# id: 4	word: so             head id: 5    head: much      deprel: advmod
# id: 5	word: much           head id: 3    head: learned   deprel: advmod
# id: 6	word: on             head id: 7    head: here      deprel: case
# id: 7	word: here           head id: 3    head: learned   deprel: obl
# id: 8	word: too            head id: 3    head: learned   deprel: advmod
# id: 9	word: .              head id: 3    head: learned   deprel: punct
# id: 1	word: Many           head id: 2    head: people    deprel: amod
# id: 2	word: people         head id: 5    head: know      deprel: nsubj
# id: 3	word: also           head id: 5    head: know      deprel: advmod
# id: 4	word: didnt          head id: 5    head: know      deprel: aux
# id: 5	word: know           head id: 0    head: root      deprel: root
# id: 6	word: how            head id: 7    head: badly     deprel: mark
# id: 7	word: badly          head id: 14   head: treated   deprel: advmod
# id: 8	word: the            head id: 10   head: refugees  deprel: det
# id: 9	word: Greek          head id: 10   head: refugees  deprel: amod
# id: 10	word: refugees       head id: 14   head: treated   deprel: nsubj:pass
# id: 11	word: from           head id: 12   head: Turkey    deprel: case
# id: 12	word: Turkey         head id: 10   head: refugees  deprel: nmod
# id: 13	word: were           head id: 14   head: treated   deprel: aux:pass
# id: 14	word: treated        head id: 5    head: know      deprel: ccomp
# id: 15	word: in             head id: 16   head: Greece    deprel: case
# id: 16	word: Greece         head id: 14   head: treated   deprel: obl
# id: 17	word: also           head id: 14   head: treated   deprel: advmod
# id: 18	word: .              head id: 5    head: know      deprel: punct
# id: 1	word: So             head id: 2    head: many      deprel: advmod
# id: 2	word: many           head id: 3    head: Greeks    deprel: amod
# id: 3	word: Greeks         head id: 7    head: told      deprel: nsubj
# id: 4	word: and            head id: 5    head: Turks     deprel: cc
# id: 5	word: Turks          head id: 3    head: Greeks    deprel: conj
# id: 6	word: have           head id: 7    head: told      deprel: aux
# id: 7	word: told           head id: 0    head: root      deprel: root
# id: 8	word: me             head id: 7    head: told      deprel: iobj
# id: 9	word: they           head id: 11   head: know      deprel: nsubj
# id: 10	word: didnt          head id: 11   head: know      deprel: aux
# id: 11	word: know           head id: 7    head: told      deprel: ccomp
# id: 12	word: .              head id: 7    head: told      deprel: punct
# id: 1	word: This           head id: 3    head: crazy     deprel: nsubj
# id: 2	word: is             head id: 3    head: crazy     deprel: cop
# id: 3	word: crazy          head id: 0    head: root      deprel: root
# id: 4	word: to             head id: 5    head: me        deprel: case
# id: 5	word: me             head id: 3    head: crazy     deprel: obl
# id: 6	word: .              head id: 3    head: crazy     deprel: punct
# id: 1	word: Our            head id: 2    head: history   deprel: nmod:poss
# id: 2	word: history        head id: 5    head: conplciateddeprel: nsubj
# id: 3	word: is             head id: 5    head: conplciateddeprel: cop
# id: 4	word: so             head id: 5    head: conplciateddeprel: advmod
# id: 5	word: conplciated    head id: 0    head: root      deprel: root
# []
# [['so_much'], ['much_learned'], ['too_learned'], ['also_much'], ['badly_know'], ['also_know'], ['So_have'], ['so_much']]
# [['Many_have'], ['Greek_Many'], ['many_learned']]
# If SPAIN was the 1 st EU country they set foot in THAT IS WHERE THEY CLAIM ASYLUM SAME GOES FOR GREECE, AND ITALY
# id: 1	word: If             head id: 8    head: country   deprel: mark
# id: 2	word: SPAIN          head id: 8    head: country   deprel: nsubj
# id: 3	word: was            head id: 8    head: country   deprel: cop
# id: 4	word: the            head id: 8    head: country   deprel: det
# id: 5	word: 1              head id: 6    head: st        deprel: nummod
# id: 6	word: st             head id: 8    head: country   deprel: compound
# id: 7	word: EU             head id: 8    head: country   deprel: compound
# id: 8	word: country        head id: 10   head: set       deprel: advcl
# id: 9	word: they           head id: 10   head: set       deprel: nsubj
# id: 10	word: set            head id: 0    head: root      deprel: root
# id: 11	word: foot           head id: 10   head: set       deprel: obj
# id: 12	word: in             head id: 13   head: THAT      deprel: case
# id: 13	word: THAT           head id: 10   head: set       deprel: obl
# id: 14	word: IS             head id: 10   head: set       deprel: parataxis
# id: 15	word: WHERE          head id: 17   head: CLAIM     deprel: mark
# id: 16	word: THEY           head id: 17   head: CLAIM     deprel: nsubj
# id: 17	word: CLAIM          head id: 14   head: IS        deprel: advcl
# id: 18	word: ASYLUM         head id: 17   head: CLAIM     deprel: obj
# id: 19	word: SAME           head id: 20   head: GOES      deprel: nsubj
# id: 20	word: GOES           head id: 17   head: CLAIM     deprel: ccomp
# id: 21	word: FOR            head id: 22   head: GREECE    deprel: case
# id: 22	word: GREECE         head id: 20   head: GOES      deprel: obl
# id: 23	word: ,              head id: 25   head: ITALY     deprel: punct
# id: 24	word: AND            head id: 25   head: ITALY     deprel: cc
# id: 25	word: ITALY          head id: 22   head: GREECE    deprel: conj
# [['st_country'], ['EU_country']]
# []
# []
# Your dictator weaponise the refugees for attack to Greece because you dont have the courage to do by your shelf just like Evros in March hahahaahahahahahhahaha
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-273-ed3548e4b615> in <module>
#       1 for tweet in tqdm(range(len(tweets_corpus))):
#       2     print(tweets_corpus[tweet])
# ----> 3     np_heads = [[word.id, word.text,word.head,word.deprel] for sent in tagged_tweets[tweet].sentences for word in sent.words]
#       4     print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in tagged_tweets[tweet].sentences for word in sent.words], sep='\n')
#       5     #print(np_heads)
#
# IndexError: list index out of range
