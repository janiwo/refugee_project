# %% [markdown]
# # Candidate alignment (merging)
#
# **Necessary files:**
#
#  - event_cands = dataframe with candidates and their meta information
#  - model = embeddings model encoding the event dataset (for the second merging step)

# %%
import stanza  
import pandas as pd

from nltk.tokenize import word_tokenize
import pickle
import os
import re
from tqdm.notebook import tqdm
from collections import Counter, defaultdict


# functions pickle_file and load_pickle merely help with storing pickled files in the event folders on drive
def pickle_file(file_name, file_to_dump):
    directory_path = os.getcwd() + "/../../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path +  fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, 'wb') as fp:
        pickle.dump(file_to_dump, fp)

def load_pickle(file_name):
    directory_path = os.getcwd() + "/../../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path + fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, "rb") as input_file:
        return pickle.load(input_file)

# %% [markdown]
# ### Merging step 1
#   - In the first merging step, we merge two candidates if the head of each of their representative phrase is identical by string comparison. Therefore, we merge candidates if the cand_head column value is equal. We keep the first row from top and sum the cand_freq column to keep count of all merged candidates.
#   - sort by frequency after grouping

# %%
def get_tweet_tags(tagged_tweets):
    """
    Input: pre-tagged tweets
    Output: list of lists containing named entities
    """
    tweet_entities=[]
    excluded_tags = ['CARDINAL', 'DATE', 'QUANTITY', 'TIME', 'PERCENT', 'MONEY', 'ORDINAL']
    for tweet in tqdm(range(len(tagged_tweets))):
            tweet_ner= [ent.text for sent in tagged_tweets[tweet].sentences for ent in sent.ents if ent.type not in excluded_tags]
            tweet_entities.append(tweet_ner)
    return tweet_entities  

def get_ent_head(entity):
    if len(word_tokenize(entity))>1:
        entity_doc = en_nlp(entity)
        #the root of NP has value 0. Since head is only one and stored in a list, we pick item [0]
        return [word.text for tweet_ent in entity_doc.sentences for word in tweet_ent.words if word.head == 0][0]
    else:
        return entity

def process_entity(entity):
    # re.sub removes all non alpanumeric characters (and lower() lowercases)
    # " ".join and split removes the consecutive whitespaces created by replacing characters
    entity = re.sub('[^0-9a-zA-Z]+', ' ', entity.lower())
    return " ".join(entity.split())

def create_entities_df(tagged_tweets):
    
    event_entities = get_tweet_tags(tagged_tweets)
    
    list_of_entities = list()
    for tweet_entities in tqdm(event_entities):
        list_of_entities.append(tweet_entities)

    entity_list = [process_entity(entity) for tweet in list_of_entities for entity in tweet]
    
    #create the count dictionary which will be converted into a df
    counted_entities = Counter(entity_list)
    ent_df = pd.DataFrame(counted_entities.items(),columns=['entity','freq']).sort_values('freq',ascending=False)
    #filter out entities shorter than 2 characters and frequency less than 5
    ent_df = ent_df[ent_df.freq>=5]
    ent_df['len'] = ent_df.entity.apply(lambda x: len(x))
    ent_df = ent_df[ent_df['len']>=2]
    #find head of the entity
    tqdm.pandas()
    ent_df['head'] = ent_df.entity.progress_apply(get_ent_head)
    ent_df.reset_index(drop=True,inplace=True)
    return ent_df[['entity','freq','head']]

def merging_step1(event_name):
    print(f'loading {event_name} tagged tweets...')
    tagged_tweets = load_pickle(f'{event_name}_tagged_tweets')
    ent_df = create_entities_df(tagged_tweets)
    pickle_file(f'{event_name}_ents',ent_df)
    return ent_df

# %%
ent_df = merging_step1('rohingya')
# Out:
# loading rohingya tagged tweets...
#   0%|          | 0/29432 [00:00<?, ?it/s]
#   0%|          | 0/29432 [00:00<?, ?it/s]
#   0%|          | 0/939 [00:00<?, ?it/s]

# %%
ent_df = merging_step1('tigray')
# Out:
# loading tigray tagged tweets...
#   0%|          | 0/42853 [00:00<?, ?it/s]
#   0%|          | 0/42853 [00:00<?, ?it/s]
#   0%|          | 0/1125 [00:00<?, ?it/s]

# %%
ent_df = merging_step1('greece')
# Out:
# loading greece tagged tweets...
#   0%|          | 0/137462 [00:00<?, ?it/s]
#   0%|          | 0/137462 [00:00<?, ?it/s]
#   0%|          | 0/2076 [00:00<?, ?it/s]

# %%
ent_df = merging_step1('channel')
# Out:
# loading channel tagged tweets...
#   0%|          | 0/173758 [00:00<?, ?it/s]
#   0%|          | 0/173758 [00:00<?, ?it/s]
#   0%|          | 0/2679 [00:00<?, ?it/s]

# %% [markdown]
# ## Merging step 2: Similarity using Sentence BERT embeddings

# %%
from sklearn.metrics.pairwise import cosine_similarity

def create_sim_df(event_name, entity_type = 'ents', sim_threshold=0.6):
    event_entities = load_pickle(f'{event_name}_{entity_type}')
    cand_embeddings = load_pickle(f'{event_name}_embeddings_{entity_type}')
    rows_list = []
    sims = cosine_similarity(cand_embeddings)

    for up_cand_id in tqdm(range(len(event_entities))):
        for low_cand_id in range(len(event_entities)):
            dict1 = {}
            # get input row in dictionary format
            # key = col_name
            if sims[up_cand_id][low_cand_id]>sim_threshold:
                dict1.update({'text': event_entities['entity'][up_cand_id], 
                              'text_to_compare':event_entities['entity'][low_cand_id], 
                              'sim':sims[up_cand_id][low_cand_id]}) 
                rows_list.append(dict1)

    sim_df = pd.DataFrame(rows_list)
    return sim_df

# %%
sim_df = create_sim_df('greece')
pickle_file('greece_sim_df_ents',sim_df)
# Out:
#   0%|          | 0/2076 [00:00<?, ?it/s]

# %%
sim_df = create_sim_df('rohingya')
pickle_file('rohingya_sim_df_ents',sim_df)
# Out:
#   0%|          | 0/939 [00:00<?, ?it/s]

# %%
sim_df = create_sim_df('tigray')
pickle_file('tigray_sim_df_ents',sim_df)
# Out:
#   0%|          | 0/1125 [00:00<?, ?it/s]

# %%
sim_df = create_sim_df('channel')
pickle_file('channel_sim_df_ents',sim_df)
# Out:
#   0%|          | 0/2679 [00:00<?, ?it/s]

# %%
sim_df[sim_df.text=='junta'].sort_values('sim',ascending=False)[:20]
# Out:
#        text text_to_compare       sim
# 3026  junta           junta  1.000000
# 3028  junta          juntas  0.891388
# 3027  junta      tplf junta  0.682311

# %%
def flatten(list_of_mixed_types):
    # helper function to convert a list of mixed types (strings and lists) into a list
    flat_list = []
    for element in list_of_mixed_types:
        if isinstance(element,list): 
            flat_list.extend(flatten(element))
        else: 
            flat_list.append(element)
    return flat_list

def align_ents(what_merged):
    
    merged_dict = defaultdict(list)
    merged_ent = set()
    
    for key,value in tqdm(what_merged.items()):
        merged_ent.update(what_merged[key])
        for item in value:
            merged_dict[key].extend(what_merged[key])
            if item in what_merged.keys():
                merged_dict[key].extend(what_merged[item])
                merged_dict[key] = list(set(merged_dict[key]))

        #print('-------loop------')
        for ent,merged in what_merged.items():
            for item2 in merged:
                if item2 in what_merged[key] and item2 in what_merged[ent] and key!=ent:
                    merged_dict[key].extend(what_merged[key] + what_merged[ent])
                    merged_dict[key].append(ent)
                    merged_ent.add(ent)
        merged_dict[key] = list(set(merged_dict[key]))  
        #merged_dict[key].pop(merged_dict[key].index(key))
    return merged_dict

def finalize_ents(merged_dict):
    final_ents = defaultdict()
    check_set = set()
    for key,value in merged_dict.items():
        if key not in check_set:
            final_ents[key] = merged_dict[key]
            check_set.update(merged_dict[key])
    
    for key in final_ents.keys():
        if key in final_ents[key]:
            final_ents[key].pop(final_ents[key].index(key))
            
    # add manual terms to the dict so (refugees and asyslum seekers) and (migrants and immigrants) are together
    final_ents['refugees'] = ['refugee','asylum seeker','asylum seekers']
    final_ents['migrants'] = ['migrant','immigrant','immigrants']
    return final_ents


def merging_step2(entities,sim_df,low_threshold=0.8, high_threshold =0.9, transitive=False): 
    
    what_merged = defaultdict(list)
    merged_ents = set()

    #merge the dataframes so we have information about frequencies of candidates in sim_df
    # use outer join to include the candidates that are not similar to any other candidate (thus not in sim_df)
    merged_df_ = pd.merge(sim_df,entities[entities.freq>=5], how='outer', left_on='text', right_on='entity')
    merged_df = pd.merge(merged_df_,entities[entities.freq>=5], how='outer', left_on='text_to_compare', right_on='entity')
    
    #blank fields in sim_df's text are the candidates that are dissimilar to the rest, pass the value from cand_text
    merged_df.entity_x.fillna(merged_df.entity_y, inplace=True) 
    merged_df.freq_x.fillna(merged_df.freq_y, inplace=True) 
    
    merged_df.drop(['text','text_to_compare'],axis=1,inplace=True)

    # and select only the rows above the lower threshold, so we do not have to filter by it in the loop
    merged_df_small = merged_df[merged_df.sim>low_threshold]

    print(f'finding merged entities...')
    # create an object to iterate over unique candidates
    unique_merged_df = merged_df.groupby(by=['entity_x'], sort = False, as_index=False).agg({'freq_x':'max'}).sort_values('freq_x',ascending=False)

    def get_merged_entities(entity,transitive=False):
        """
        Find which candidates merged into the candidate
        """
        lookup_df = pd.DataFrame({'entity_x': [], 'entity_y':[]})

        if entity not in merged_ents:
            if transitive == False:
                lookup_df = merged_df_small[merged_df_small.entity_x==entity]

                #what_merged[cand].extend(list(lookup_df['candidates']))
                merged_ents.update(list(lookup_df['entity_y']))
            else:
                lookup_df = merged_df_small[(merged_df_small.entity_x==entity) & (merged_df_small.sim>high_threshold)]

            #what_merged[cand].extend(list(lookup_df['candidates']))
            #merged_ents.update(list(lookup_df['entity_y']))
        
        #clean nans 
        lookup_df = lookup_df[~lookup_df['entity_y'].isnull()]
        return list(lookup_df['entity_y'])
    
    tqdm.pandas() 
    unique_merged_df['merged'] =  unique_merged_df.entity_x.progress_apply(get_merged_entities)
    #print(list(unique_merged_df['merged']))
    #convert the dataframe into a dictionary
    for entity,merged_list in tqdm(zip(unique_merged_df['entity_x'],unique_merged_df['merged'])):
        what_merged[entity] = merged_list.copy()
        if transitive:
            for merged_ent in merged_list:
                what_merged[entity].append(get_merged_entities(merged_ent,transitive=True))
        what_merged[entity] = list(set(flatten(what_merged[entity]) ) ) 
    
    return what_merged

# %%
def run_merging_step2(event_name,entity_type='ents',low_threshold=0.8, high_threshold = 0.9, transitive=True):
    sim_df = load_pickle(f'{event_name}_sim_df_{entity_type}')
    entities = load_pickle(f'{event_name}_{entity_type}')

    what_merged = merging_step2(entities,
                                sim_df,
                                low_threshold=low_threshold, 
                                high_threshold=high_threshold,
                                transitive=transitive)
    
    if transitive:
        what_merged = align_ents(what_merged)
    
    if event_name == 'channel' or event_name == 'greece':
        what_merged['germany'].pop(what_merged['germany'].index('austria'))
        what_merged['germany'].pop(what_merged['germany'].index('austrian'))
    
    if event_name == 'greece':
        what_merged['russia'].pop(what_merged['russia'].index('ukraine'))
            
    what_merged = finalize_ents(what_merged)
    #pickle_file(f'{event_name}_final_{entity_type}',final_ents)
    pickle_file(f'{event_name}_what_merged',what_merged)
    return  what_merged #final_ents,

# %%
merged_dict = run_merging_step2('tigray',low_threshold=0.7,high_threshold = 0.9, transitive=False)
# Out:
# finding merged entities...
#   0%|          | 0/1125 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
merged_dict = run_merging_step2('rohingya',low_threshold=0.7,high_threshold = 0.9,transitive=False)
# Out:
# finding merged entities...
#   0%|          | 0/939 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
merged_dict = run_merging_step2('greece',low_threshold=0.7, high_threshold = 0.9,transitive=False)
# Out:
# finding merged entities...
#   0%|          | 0/2076 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
merged_dict = run_merging_step2('channel',low_threshold=0.7,high_threshold=0.85, transitive=False)
# Out:
# finding merged entities...
#   0%|          | 0/2679 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
print(list(merged_dict.keys())[:20])
# Out:
# ['eritrean', 'ethiopia', 'tigray', 'sudan', 'un', 'tplf', 'biden', 'antony blinken', 'abiy ahmed ali', 'amhara', 'un refugee agency', 'kamala harris', 'us', 'africa', 'eu', 'amnesty international', 'yemen', 'uk', 'israel', 'shimelba']

# %%
print(list(merged_dict['turkey']))
# Out:
# ['turkish']

# %%
sim_df[sim_df.text=='english'].sort_values('sim',ascending=False)[:40]
# Out:
#         text  text_to_compare       sim
# 476  english          english  1.000000
# 483  english       englishmen  0.771397
# 479  english      anglo saxon  0.698635
# 482  english       englishman  0.693618
# 480  english            anglo  0.654551
# 481  english            latin  0.630546
# 484  english        uk french  0.609460
# 478  english  english channel  0.609256
# 477  english          england  0.606441

# %% [markdown]
# ### Find frequencies

# %%
from collections import defaultdict
from itertools import combinations

def get_frequencies(what_merged, event_df):
    """
    in part 1: get frequencies of each item in what_merged dictionary from the corpus
    
    in part 2: correct frequencies for repeating terms
    """
    #~~~~ part 1 ~~~~
    freq_dict = defaultdict(list)
    for key in tqdm(what_merged.keys()):
        freq_dict2 = dict()
        c = sum(event_df['text_alphanum'].apply(lambda x: x.count(f' {key} ')))
        freq_dict[key].append(c)
        for item in what_merged[key]:
            c2 = sum(event_df['text_alphanum'].apply(lambda x: x.count(f' {item} ')))
            freq_dict2[item]=c2
        freq_dict[key].append(freq_dict2)
    
    #~~~~ part 2 ~~~~
    
    # Instantiate dict to store individual count for entity and merged count
    freq_counts = defaultdict(dict)
    
    # Iterate over entities
    for ent in freq_dict.keys():
        
        #print(f"Ent: {ent}")
        adj_freq = 0
        
        # Store number of occurences of root entity
        root_freq = freq_dict[ent][0]
        
        # Instantiate empty list where entities are stored that have already been counted
        roots = []
        
        # Integrate main entity into dict of merged entities
        ent_dict = freq_dict[ent][1]
        ent_dict[ent] = freq_dict[ent][0]
        
        # Iterate over merged entities based on their length (in term of tokens) in ascending order
        for merged_ent in sorted(ent_dict.keys(), key = len):
            #print(f"Merged Ent: {merged_ent}")
            
            # Create all possible sub-combinations of entity while keeping the order constant
            # For example: "Greece Turkey Border" yields Greece, Turkey, Border, Greece Turkey, Turkey Border, Greece Turkey Border
            merged_ent_list = merged_ent.split(" ")
            all_slices = [merged_ent_list[s:e] for s, e in combinations(range(len(merged_ent_list)+1), 2)]
            all_slices_strings = [" ".join(l) for l in all_slices]
            
            # Iterate over all entities that have already been counted
            for root in roots:
                
                # Check if any of the substring of current entity has already been counted, if yes don't count it again
                if root in all_slices:
                    #print(f"{merged_ent} was removed to prevent double count. {root} has already been counted")
                    break
            
            # If entity has not been counted, count it and add entity to counted entities
            else:
                roots.append([merged_ent])
                #print(roots)
                adj_freq += ent_dict[merged_ent]
                #print(f"Frequency incremented by {ent_dict[merged_ent]}")
        
        # Update frequency dict
        freq_counts[ent]["Root"] = root_freq
        freq_counts[ent]["Overall"] = adj_freq


    return freq_dict,freq_counts

# %%
event_df = read_event_df(rohingya_url)
what_merged = load_pickle('rohingya_what_merged')

freq_dict,total_freq = get_frequencies(what_merged, event_df)
# Out:
# loaded 29432 tweets!
#   0%|          | 0/553 [00:00<?, ?it/s]

# %%
event_df = read_event_df(tigray_url)
what_merged = load_pickle('tigray_what_merged')

freq_dict,total_freq = get_frequencies(what_merged, event_df)
#freq_dict
# Out:
# loaded 42853 tweets!
#   0%|          | 0/654 [00:00<?, ?it/s]
# Ent: eritrean
# Ent: ethiopia
# Ent: tigray
# Ent: sudan
# Ent: un
# Ent: tplf
# Ent: biden
# Ent: antony blinken
# Ent: abiy ahmed ali
# Ent: amhara
# Ent: un refugee agency
# Ent: kamala harris
# Ent: us
# Ent: africa
# Ent: eu
# Ent: amnesty international
# Ent: yemen
# Ent: uk
# Ent: israel
# Ent: shimelba
# Ent: justin trudeau
# Ent: cnn
# Ent: kenya
# Ent: filippo grandi
# Ent: hitsats
# Ent: the united nations
# Ent: hamdayet
# Ent: mai kadra
# Ent: u ? s ?
# Ent: tegaru
# Ent: marc garneau
# Ent: somalia
# Ent: canada
# Ent: josep borrell
# Ent: houthi
# Ent: bbc news
# Ent: shire
# Ent: english
# Ent: syria
# Ent: axum
# Ent: libya
# Ent: egypt
# Ent: geneva
# Ent: michelle bachelet
# Ent: oromo
# Ent: isaias
# Ent: ali
# Ent: al jazeera
# Ent: addis
# Ent: ant nio guterres
# Ent: mekelle
# Ent: gedaref
# Ent: uganda
# Ent: nrc
# Ent: sanaa
# Ent: france
# Ent: reuters
# Ent: western
# Ent: addis ababa
# Ent: norway
# Ent: covid 19
# Ent: linda thomas
# Ent: italy
# Ent: mekele
# Ent: djibouti
# Ent: world bank
# Ent: adi harush
# Ent: chris coons
# Ent: martin plaut
# Ent: ethiopian human rights commission
# Ent: the associated press
# Ent: washington
# Ent: unicef
# Ent: turkey
# Ent: endf
# Ent: pekka
# Ent: cory booker
# Ent: saudi arabia
# Ent: jan egeland
# Ent: ireland
# Ent: australia
# Ent: uae
# Ent: chinese
# Ent: daniel
# Ent: samri
# Ent: wfp
# Ent: humera
# Ent: germany
# Ent: afp news agency
# Ent: rwanda
# Ent: horn
# Ent: kunama
# Ent: natalia paszkiewicz
# Ent: iran
# Ent: isaias afeworki
# Ent: tigreans
# Ent: usaid
# Ent: mai aini
# Ent: christian
# Ent: daniel bekele
# Ent: antony
# Ent: jewish
# Ent: msf
# Ent: who
# Ent: nigeria
# Ent: edf
# Ent: neamin zeleke
# Ent: asmara
# Ent: karina gould
# Ent: european parliament
# Ent: adwa
# Ent: eri
# Ent: haavisto
# Ent: the washington post
# Ent: metekel
# Ent: trump
# Ent: ap
# Ent: don
# Ent: iom
# Ent: russia
# Ent: iraq
# Ent: hoa
# Ent: darfur
# Ent: belgium
# Ent: sweden
# Ent: ny
# Ent: bob rae
# Ent: price
# Ent: sheraro
# Ent: human rights watch
# Ent: gambella
# Ent: london
# Ent: kat graham
# Ent: mick wallace
# Ent: state department
# Ent: india
# Ent: democrats
# Ent: int l criminal court
# Ent: world food programme
# Ent: muslims
# Ent: kenneth roth
# Ent: junta
# Ent: idp
# Ent: myanmar
# Ent: dia
# Ent: mediterranean
# Ent: the new york times
# Ent: dominic raab
# Ent: many
# Ent: mark lowcock
# Ent: boston
# Ent: vodacom
# Ent: ethio
# Ent: south africa
# Ent: afghanistan
# Ent: estonia
# Ent: priyanka
# Ent: nancy pelosi
# Ent: natalia
# Ent: cease desist
# Ent: khartoum
# Ent: gumuz
# Ent: congo
# Ent: jake tapper
# Ent: voa
# Ent: the security council
# Ent: grandi
# Ent: ilhan omar
# Ent: fontelles
# Ent: shabia
# Ent: afar
# Ent: irob advocacy association
# Ent: nazi
# Ent: maykadra
# Ent: jamal osman
# Ent: gerry simpson
# Ent: vanessa tsehaye
# Ent: japan
# Ent: finland
# Ent: senate
# Ent: lindat g
# Ent: government
# Ent: david beasley
# Ent: senate foreign relations committee
# Ent: chevrierantoine
# Ent: ambmkimani united nations
# Ent: hrw
# Ent: lebanon
# Ent: martin
# Ent: drc
# Ent: act
# Ent: tedros
# Ent: david
# Ent: benishangul
# Ent: the white house
# Ent: icrc
# Ent: obama
# Ent: greenfield
# Ent: myayni
# Ent: hinxax
# Ent: army
# Ent: chad
# Ent: hamdeyat camp
# Ent: mexico
# Ent: hafez ghanem
# Ent: netherlands
# Ent: weeknd
# Ent: hintsats
# Ent: scottmorrison
# Ent: ocha
# Ent: fano
# Ent: kakuma
# Ent: sinai
# Ent: ablinken
# Ent: janez lenar i
# Ent: joe
# Ent: adigrat
# Ent: blue nile
# Ent: benishangul gumuz
# Ent: pakistan
# Ent: texas
# Ent: tekeze
# Ent: world health organization
# Ent: icc
# Ent: daily mail online
# Ent: denmark
# Ent: bangladesh
# Ent: aksum
# Ent: the national
# Ent: downing
# Ent: chris melzer
# Ent: tdf
# Ent: ataye
# Ent: ant nio
# Ent: may ayni
# Ent: genocide
# Ent: red cross
# Ent: shiraro
# Ent: iaa
# Ent: tunaydbah
# Ent: rice
# Ent: wolkait
# Ent: yahoo news
# Ent: hgdef
# Ent: amara
# Ent: isis
# Ent: rakuba
# Ent: meron estefanos
# Ent: city
# Ent: sawa
# Ent: rohingya
# Ent: badme
# Ent: abi adi
# Ent: zecharias zelalem
# Ent: ehrc
# Ent: u ? s ? mission
# Ent: unfpa
# Ent: juba
# Ent: pajok
# Ent: paul
# Ent: abel tesfaye
# Ent: amharic
# Ent: tigray united nations
# Ent: chris
# Ent: ann allen
# Ent: gulf
# Ent: devex
# Ent: switzerland
# Ent: sudan individuals in axum
# Ent: benshangul
# Ent: toronto
# Ent: the mai kadra massacre
# Ent: reuters africa
# Ent: laetitia bader
# Ent: greenfield european parliament
# Ent: dadaab
# Ent: returnees affairs arra
# Ent: ben gurion airport
# Ent: helen clark
# Ent: fana broadcasting corporate s ? c ?
# Ent: migration bureau
# Ent: cbn news
# Ent: ann linde
# Ent: facebook
# Ent: dc
# Ent: moussa faki mahamat
# Ent: yohannes abraham
# Ent: meron
# Ent: npr
# Ent: north korea
# Ent: gonder
# Ent: william davison
# Ent: rashid abdi
# Ent: charles
# Ent: dw news
# Ent: yemane g ? meskel
# Ent: borisjohnson
# Ent: arabic
# Ent: venezuela
# Ent: mogadishu
# Ent: united nations department of state european commission
# Ent: interpol
# Ent: niger
# Ent: undp
# Ent: unesco
# Ent: embassy
# Ent: mikadra
# Ent: himayat
# Ent: micadra
# Ent: cameroon
# Ent: the voice of america
# Ent: pp
# Ent: david malpass
# Ent: copts
# Ent: qatar
# Ent: aden
# Ent: the middle east
# Ent: joe neguse
# Ent: mohamed
# Ent: sara jerving
# Ent: seid mussa omar
# Ent: world
# Ent: holocaust
# Ent: east
# Ent: nima elbagir
# Ent: law
# Ent: house
# Ent: united nations pga
# Ent: gregory meeks
# Ent: secblinken
# Ent: raya
# Ent: alula solomon
# Ent: rob oliphant
# Ent: ethiopias northern tigray region
# Ent: jen psaki
# Ent: ghana
# Ent: europeans
# Ent: greece
# Ent: fao
# Ent: haiti
# Ent: tplf militia
# Ent: militias
# Ent: haben girma
# Ent: esayas
# Ent: raped
# Ent: meles
# Ent: guatemala
# Ent: new zealand
# Ent: we are on the brink of a humanitarian crisis
# Ent: mengistu
# Ent: emmanuel macron
# Ent: bisrat gebremedhin
# Ent: ww2
# Ent: shemelba
# Ent: the telegraph
# Ent: ant nio guterres united nations european commission
# Ent: kassala
# Ent: hcr
# Ent: gondar
# Ent: irc
# Ent: camp
# Ent: jordan
# Ent: sven spengemann
# Ent: bronwyn bruton
# Ent: the oromia region
# Ent: haben
# Ent: nottingham
# Ent: guterres antony
# Ent: tel aviv
# Ent: the nobel prize
# Ent: nima
# Ent: alton
# Ent: denver
# Ent: massacres
# Ent: northern command
# Ent: samantha power
# Ent: kosovo
# Ent: the maikadra genocide fled
# Ent: m xico
# Ent: mali
# Ent: ga
# Ent: agency
# Ent: ocha united nations
# Ent: bayto
# Ent: u ? s ? mission geneva
# Ent: irc international rescue committee
# Ent: orthodox
# Ent: derg
# Ent: ertrean
# Ent: asia
# Ent: ogaden
# Ent: western tigray zone
# Ent: danish refugee council
# Ent: generation
# Ent: uscri
# Ent: tesfahun gobezay
# Ent: el geneina
# Ent: cairo
# Ent: penny wong
# Ent: ag
# Ent: colorado
# Ent: bahirdar
# Ent: netanyahu
# Ent: jutta urpilainen
# Ent: amp
# Ent: ken
# Ent: ahmed
# Ent: cortez
# Ent: tanzanian
# Ent: omna tigray
# Ent: palestinian
# Ent: burundi
# Ent: susan rice
# Ent: weyane
# Ent: jutta
# Ent: red crescent
# Ent: eth
# Ent: african americans
# Ent: biden european commission
# Ent: africa unhcr
# Ent: fbc
# Ent: wukro
# Ent: msf east africa
# Ent: mark
# Ent: ees
# Ent: tigrai militias
# Ent: eu civil protection and humanitarian aid
# Ent: mulu
# Ent: confirmation
# Ent: twitter
# Ent: abyi
# Ent: demeke
# Ent: unocha
# Ent: issayas
# Ent: meaza
# Ent: sky
# Ent: pompeo
# Ent: debretsion
# Ent: abdi latif dahir
# Ent: will brown
# Ent: dx open network
# Ent: young generation
# Ent: gambia
# Ent: mykadra
# Ent: dereje desta
# Ent: the globe and mail
# Ent: simon adams
# Ent: tplf mafia group
# Ent: tedros adhanom
# Ent: charlotte petri gornitzka
# Ent: miakadra
# Ent: imf
# Ent: atlantic council
# Ent: malta
# Ent: ayanna pressley
# Ent: tiger
# Ent: magufuli
# Ent: selam
# Ent: kyle brewster
# Ent: nigsty
# Ent: hutu
# Ent: fbi
# Ent: tunisia
# Ent: fox news
# Ent: great lakes
# Ent: alula
# Ent: trevor noah
# Ent: zeebrugge
# Ent: abel makkonen tesfaye
# Ent: michelle
# Ent: penny
# Ent: john sparks
# Ent: seifesilassie gebremeskel
# Ent: assab
# Ent: maicadra
# Ent: indiana
# Ent: abc news
# Ent: central
# Ent: mycadra
# Ent: gedarif hospital
# Ent: jim risch
# Ent: wa ati
# Ent: the ethopia n govt
# Ent: al shabab
# Ent: central african republic
# Ent: fontelles european commission
# Ent: the geneva conventions
# Ent: charles michel
# Ent: gulag
# Ent: rashaida
# Ent: tmh
# Ent: alex de waal
# Ent: reliefweb
# Ent: ursula von der leyen
# Ent: mozambique
# Ent: mfa
# Ent: poland
# Ent: chagni
# Ent: los angeles
# Ent: north shewa
# Ent: california
# Ent: zewde
# Ent: emmanuel igunza
# Ent: mulubrhane medhane kfleyosus
# Ent: dominicraab
# Ent: shame on
# Ent: catholic
# Ent: meles zenawi
# Ent: human right
# Ent: women
# Ent: fpc
# Ent: the horn of africa
# Ent: abraha
# Ent: yemane
# Ent: tigiray
# Ent: yugoslavia
# Ent: mahalet
# Ent: algeria
# Ent: kakuma refugee camp
# Ent: united nations camps
# Ent: bishoftu
# Ent: greenfield united nations
# Ent: pia
# Ent: jan
# Ent: lampedusa
# Ent: columbus
# Ent: ksa
# Ent: janez
# Ent: bob menendez
# Ent: james duddridge
# Ent: tewodros
# Ent: fisseha tekle
# Ent: seattle
# Ent: guinea
# Ent: afwerki
# Ent: philippe champagne
# Ent: sahel
# Ent: astead
# Ent: welkait
# Ent: oxfam
# Ent: kagame
# Ent: cbs
# Ent: financial times
# Ent: elizabeth warren
# Ent: vanessa
# Ent: jack tapper
# Ent: hague
# Ent: negusti
# Ent: hirut zemene
# Ent: freweyni
# Ent: your report made axum a berlin in ww2
# Ent: samra tesfaye
# Ent: china road
# Ent: melbourne
# Ent: negusti woldeselassie
# Ent: the guardian
# Ent: united
# Ent: bloomberg
# Ent: children
# Ent: amhara fano
# Ent: cuba
# Ent: jagmeet singh
# Ent: iyoba
# Ent: al nejashi
# Ent: pagak
# Ent: mussie zerai
# Ent: ministry of peace
# Ent: justin wilson
# Ent: marxist
# Ent: simon coveney
# Ent: european external action service eeas
# Ent: alexander rondos
# Ent: lisa schlein
# Ent: spain
# Ent: marco mendicino
# Ent: henrietta h ? fore
# Ent: cori bush sen
# Ent: dirty rose
# Ent: kjetil tronvoll
# Ent: morocco
# Ent: bin
# Ent: arra
# Ent: mossad
# Ent: al tanidaba
# Ent: todd young
# Ent: sammy
# Ent: one day seyoum
# Ent: blm
# Ent: monaliza
# Ent: elsa
# Ent: babar baloch
# Ent: mesfin hagos
# Ent: jake sullivan
# Ent: kidane
# Ent: dawit kebede
# Ent: depo provera
# Ent: colombia
# Ent: fed forces
# Ent: ocp
# Ent: time
# Ent: karenbass
# Ent: nubians
# Ent: 40
# Ent: the passport prison
# Ent: portland
# Ent: jeff pearce
# Ent: jeff
# Ent: fed
# Ent: congressmember bass
# Ent: displaced
# Ent: cia
# Ent: labor
# Ent: russian mission un
# Ent: ecc
# Ent: ngesti
# Ent: l onu
# Ent: cameron hudson
# Ent: insecurity allegations of grave distressing human rights abuses
# Ent: sahara
# Ent: north west
# Ent: mulugeta seraw
# Ent: hassan
# Ent: isayas afwork
# Ent: adi harish
# Ent: eu council press
# Ent: zimbabwe
# Ent: sudan refugee camps
# Ent: sierra leone
# Ent: the tigray peoples liberation front
# Ent: bbc tigrinya
# Ent: southern region
# Ent: international development committee
# Ent: liberia
# Ent: jesus
# Ent: msm
# Ent: zebangedena
# Ent: vanessa coeffe
# Ent: nariman el mofty
# Ent: gov
# Ent: woyane
# Ent: welega
# Ent: hungary
# Ent: freweini g sadick
# Ent: operation zur israel
# Ent: ahmad of wimbledon
# Ent: mai cadra
# Ent: tefera
# Ent: vice world news
# Ent: jamaican
# Ent: ant nio vitorino
# Ent: prophet mohammed
# Ent: sally hayden
# Ent: refugees
# Ent: migrants

# %%
event_df = read_event_df(greece_url)
what_merged = load_pickle('greece_what_merged')

freq_dict,total_freq = get_frequencies(what_merged, event_df)
#freq_dict
# Out:
# loaded 137462 tweets!
#   0%|          | 0/1199 [00:00<?, ?it/s]

# %%
event_df = read_event_df(channel_url)
what_merged = load_pickle('channel_what_merged')

freq_dict,total_freq = get_frequencies(what_merged, event_df)
#freq_dict
# Out:
# loaded 173758 tweets!
#   0%|          | 0/1578 [00:00<?, ?it/s]

# %%
Counter(word for tweet in event_df.text_coherent for word in tweet.split(' '))
# Out:
# Counter({'PA': 17,
#          'Ambassador': 42,
#          'in': 76065,
#          'Bosnia': 63,
#          '&': 14992,
#          'Herzegovina': 6,
#          'says': 3320,
#          'life': 1518,
#          'Europe': 23592,
#          'does': 2328,
#          'not': 25482,
#          'fulfil': 27,
#          'refugees': 57656,
#          'dreams': 114,
#          '[': 143,
#          'NEWS]': 5,
#          'Greece': 25816,
#          'plans': 545,
#          'floating': 70,
#          'sea': 1319,
#          'border': 18534,
#          'wall': 331,
#          'to': 136039,
#          'keep': 3063,
#          'out': 5457,
#          'Latest': 103,
#          'Battle': 43,
#          'for': 38361,
#          'Idlib': 3289,
#          'Could': 214,
#          'Send': 273,
#          'Another': 372,
#          'Wave': 177,
#          'of': 84749,
#          'Refugees': 5040,
#          '-': 32289,
#          'Washington': 111,
#          'Institute': 56,
#          'UNHCR': 394,
#          'calls': 690,
#          'decisive': 23,
#          'action': 685,
#          'end': 1414,
#          'alarming': 39,
#          'conditions': 1078,
#          'on': 28604,
#          'Aegean': 709,
#          'islands:': 24,
#          'On': 867,
#          'Samos': 69,
#          '6,782': 1,
#          'people': 14384,
#          'are': 44622,
#          'staying': 181,
#          'a': 51194,
#          'centre': 270,
#          'designed': 91,
#          '660': 2,
#          'Moria': 677,
#          'Lesvos': 669,
#          'is': 54444,
#          'hosting': 859,
#          '18,342': 2,
#          'inside': 624,
#          'facility': 81,
#          '2,200': 13,
#          '.': 186248,
#          'via': 4573,
#          '@refugees': 54,
#          'It': 3996,
#          'your': 8920,
#          'own': 2717,
#          'feet': 59,
#          'sinking': 118,
#          'the': 158413,
#          'mud,': 2,
#          'boy.': 3,
#          'A': 3897,
#          'Plausible': 2,
#          'Solution': 23,
#          'Syrian': 19189,
#          'Refugee': 2255,
#          'Crisis': 476,
#          '|': 2897,
#          'The': 20220,
#          'National': 223,
#          'Interest': 8,
#          'As': 2049,
#          'Lebanese': 109,
#          'economy': 786,
#          'crumbles,': 3,
#          'face': 1150,
#          'their': 15341,
#          'toughest': 16,
#          'winter': 262,
#          'News,': 23,
#          'Lebanon': 619,
#          'News': 2522,
#          'THE': 1095,
#          'DAILY': 26,
#          'STAR': 4,
#          'Israel': 501,
#          'returns': 70,
#          'remains': 223,
#          'refugee': 16011,
#          'Syria': 12374,
#          'Jerusalem': 70,
#          'post': 370,
#          'Kids': 42,
#          'pulled': 69,
#          'from': 27316,
#          'rubble': 29,
#          'after': 5254,
#          'regime': 1958,
#          'aistrikes': 2,
#          'as': 20152,
#          'warn': 51,
#          'its': 9673,
#          'like': 6031,
#          'judgement': 20,
#          'day': 1227,
#          'last': 2057,
#          'rebel': 194,
#          'area': 611,
#          'Digital': 10,
#          'lifeline': 9,
#          'Bulgaria': 932,
#          'and': 82491,
#          'beyond': 286,
#          'World': 1047,
#          'Karachi': 2,
#          'Essed': 33,
#          'against': 6427,
#          'Astana': 23,
#          '2017': 112,
#          'agreement': 791,
#          'sending': 1268,
#          'more': 10613,
#          'than': 5587,
#          '1': 3004,
#          'million': 7288,
#          'Turkish': 15476,
#          'we': 11140,
#          'will': 15788,
#          'send': 2448,
#          'them': 17573,
#          'Greece!': 279,
#          'begin': 139,
#          'establish': 180,
#          'closed': 1434,
#          'migrant': 7966,
#          'camps': 3179,
#          'Up': 158,
#          'Info': 9,
#          'So': 2897,
#          'recap': 1,
#          "there'": 279,
#          'll': 793,
#          'be': 16393,
#          'physical': 60,
#          'barriers': 55,
#          'trade': 271,
#          'inbound': 3,
#          'EU': 31828,
#          'goods': 55,
#          'inspected': 1,
#          'delays,': 1,
#          'red': 112,
#          'tape': 7,
#          'bureaucracy': 16,
#          'immigrants': 12207,
#          'must': 3652,
#          'earn': 115,
#          '23,600': 1,
#          'EHIC': 9,
#          'cards': 66,
#          'gone': 330,
#          'Your': 898,
#          'right': 4171,
#          'move': 1188,
#          'freely': 121,
#          'blue': 85,
#          'passports,': 13,
#          'made': 1782,
#          'France': 735,
#          'brexit': 297,
#          'reality': 416,
#          'Morenthan': 1,
#          'coming': 2001,
#          'dlib': 70,
#          'city': 474,
#          'shall': 157,
#          'Longing': 1,
#          'Go': 404,
#          'Home': 241,
#          'Back': 276,
#          'Time': 338,
#          'trying': 4435,
#          'build': 647,
#          'new': 3810,
#          'lives': 1138,
#          'themselves': 686,
#          'even': 3318,
#          'while': 2343,
#          'they': 22797,
#          'mourn': 6,
#          'homes': 764,
#          'have': 21390,
#          'lost': 719,
#          'Read': 625,
#          'story': 721,
#          'here.': 164,
#          'I': 14637,
#          'dont': 3375,
#          'war': 6861,
#          'hate': 502,
#          'see': 3461,
#          'who': 11350,
#          'suffers': 49,
#          'it': 15447,
#          'And': 4705,
#          'great': 848,
#          'my': 2759,
#          'stand': 3855,
#          'with': 30305,
#          'am': 1351,
#          'fan': 83,
#          'Erdogan': 8897,
#          'but': 10638,
#          'what': 6497,
#          'Assad': 2930,
#          'doing': 1783,
#          'also': 3684,
#          'acceptable': 89,
#          'brutal': 318,
#          'hope': 1148,
#          'best': 706,
#          'humanity': 1026,
#          'our': 6694,
#          'neighbour': 63,
#          'P010': 1,
#          '.)': 406,
#          '35': 91,
#          'year': 1265,
#          'old': 895,
#          'Feras': 1,
#          'Fayyad,': 2,
#          'Denmark,': 16,
#          'can': 7304,
#          'win': 218,
#          'his': 4734,
#          'first': 2021,
#          'Oscar': 27,
#          'Sunday': 184,
#          'night': 376,
#          'His': 245,
#          'Danish': 122,
#          'produced': 63,
#          'film': 114,
#          'shows': 673,
#          'way': 3012,
#          'women': 1689,
#          'make': 2692,
#          'democracy,': 41,
#          'he': 4930,
#          'believes!!': 1,
#          'Rescue': 71,
#          'Iraqi': 358,
#          'asylum': 5349,
#          'seekers': 2702,
#          'long': 1391,
#          'wait': 522,
#          '(4': 22,
#          '7': 547,
#          'years)': 6,
#          'host': 844,
#          'countries': 6341,
#          'reach': 1151,
#          'safe': 2723,
#          'They': 8011,
#          'suffered': 176,
#          'enough': 1621,
#          'need': 3542,
#          'urgent': 325,
#          'help': 5797,
#          'When': 1209,
#          'world': 3378,
#          'fair': 395,
#          'iraqi': 228,
#          'In': 3256,
#          'Turkey': 39544,
#          'Sir': 48,
#          'Im': 700,
#          'worried': 158,
#          'tonight': 122,
#          'about': 9516,
#          '3': 2621,
#          'civilians': 1185,
#          'facing': 455,
#          'frigid': 9,
#          'temperatures': 99,
#          'at': 17082,
#          'risk': 616,
#          'death': 952,
#          'by': 19224,
#          'government': 3160,
#          'forces': 2321,
#          'pray': 134,
#          'tonight.': 16,
#          'Not': 1820,
#          'all': 11850,
#          'were': 6487,
#          'happy': 472,
#          'him': 1428,
#          'never': 1912,
#          'voted': 456,
#          '4': 3236,
#          'political': 1666,
#          'views': 107,
#          'But': 3359,
#          'still': 2357,
#          'reason': 823,
#          'supporters': 127,
#          'attack': 3288,
#          'me': 2083,
#          'This': 6655,
#          'called': 1541,
#          'democracy': 239,
#          'One': 754,
#          'time': 2930,
#          'want': 6934,
#          'existence': 51,
#          'PKK': 222,
#          'near': 1168,
#          'border.': 675,
#          'Europe!': 342,
#          'Amid': 198,
#          'mud': 27,
#          'misery,': 15,
#          'Greek': 21678,
#          'address': 208,
#          'crisis': 6351,
#          'islands': 1854,
#          'met': 326,
#          'scepticism': 3,
#          'Pray': 54,
#          'civilian': 239,
#          'deserve': 260,
#          'this': 14240,
#          'horror': 103,
#          'P013': 1,
#          'UBAT': 16,
#          '2020': 1287,
#          'GREECE': 541,
#          'stop': 5526,
#          'migrants': 26622,
#          '2.7': 17,
#          'kilometer': 9,
#          'barrier': 81,
#          '+': 1926,
#          'Monday,': 52,
#          'GREEK': 344,
#          'POLICE': 54,
#          'used': 1705,
#          'TEAR': 21,
#          'GAS': 21,
#          'LESBOS': 13,
#          'protesting': 154,
#          'law': 1287,
#          'tightening': 18,
#          'procedure': 37,
#          '(bi': 1,
#          'GEZ': 1,
#          'DL!!': 4,
#          ')': 1571,
#          "Use'": 1,
#          "Emergency'": 1,
#          'Powers': 12,
#          'Build': 49,
#          'Migrant': 1472,
#          'Detention': 50,
#          'Centers': 33,
#          'Newsweek': 8,
#          'start': 1035,
#          'setting': 145,
#          'up': 5038,
#          'Al': 882,
#          'Jazeera': 304,
#          'create': 1027,
#          'detention': 510,
#          'centres': 184,
#          'ALL': 369,
#          'Meteoalarm': 1,
#          'Severe': 8,
#          'weather': 159,
#          'Warnings': 3,
#          'europe.': 132,
#          'If': 4480,
#          'concerned': 264,
#          'should': 7439,
#          'let': 2831,
#          'borderland': 3,
#          'cleared': 19,
#          'these': 6643,
#          'Terrorists': 90,
#          'so': 7889,
#          'return': 1490,
#          'home': 1847,
#          'He': 1878,
#          'needs': 1530,
#          'secure': 233,
#          'Let': 607,
#          'Russia': 2845,
#          'deal': 2421,
#          'Kurdish': 382,
#          'threat': 858,
#          'country,': 684,
#          'invited.': 2,
#          'speeds': 4,
#          'creation': 96,
#          'holding': 375,
#          'centers': 224,
#          'ease': 113,
#          'tension': 112,
#          'Snowstorm': 6,
#          'kills': 295,
#          '13': 147,
#          'crossing': 1293,
#          'Iran': 879,
#          'InfoMigrants': 58,
#          'Scrambles': 12,
#          'Riots,': 9,
#          'Protests': 44,
#          'iran': 269,
#          'turkey': 9572,
#          '[Infomigrants': 2,
#          ']': 258,
#          'erdogan': 2169,
#          'choose': 237,
#          '2': 3217,
#          'solutions:': 1,
#          'syrians': 492,
#          'cross': 3012,
#          'territory': 537,
#          'toward': 400,
#          'goal': 153,
#          'reaching': 619,
#          'europe': 3505,
#          'or': 8440,
#          'other': 4788,
#          'parts': 267,
#          'syria': 4021,
#          'Expert': 8,
#          'demographer': 1,
#          'Balanche': 4,
#          'explains': 115,
#          'choice': 313,
#          'depth': 56,
#          '2,000': 335,
#          'refugees,': 4335,
#          'mainly': 256,
#          'Afghans,': 182,
#          'Iranians': 102,
#          'syrians,': 41,
#          'continue': 986,
#          'protest': 332,
#          'camp': 2259,
#          'over': 5718,
#          'delays': 18,
#          'cases,': 58,
#          'inhuman': 209,
#          'living': 1893,
#          'extreme': 196,
#          'overcrowding': 76,
#          'writes': 162,
#          'Mohammed': 41,
#          'Harun': 28,
#          'Arsalai': 12,
#          'Arash': 26,
#          'Yousafzai': 12,
#          "new'": 11,
#          "centres'": 3,
#          'City': 90,
#          'Times': 643,
#          'Get': 366,
#          'students': 124,
#          'under': 3771,
#          '16s': 8,
#          'before': 1647,
#          'stopped': 584,
#          'children': 3795,
#          'could': 2459,
#          'get': 4983,
#          'work': 1814,
#          ',': 2892,
#          '3.8': 15,
#          'internally': 183,
#          'displaced': 2912,
#          'region': 583,
#          'humanitarian': 1945,
#          'assistance': 429,
#          'For': 1196,
#          'many,': 30,
#          'ninth': 27,
#          'consecutive': 14,
#          'away': 1391,
#          'home.': 140,
#          'That': 1196,
#          'was': 8087,
#          'bombing': 857,
#          'an': 7793,
#          'air': 467,
#          'strike!': 2,
#          'army': 1679,
#          'killed': 2387,
#          'nearly': 584,
#          '110': 6,
#          'soldiers': 2036,
#          'tanks!': 1,
#          'which': 3810,
#          'cant': 1166,
#          'take?': 23,
#          'Thats': 512,
#          'fighting!': 4,
#          'full': 1122,
#          'lived': 256,
#          'war,': 533,
#          'parents': 227,
#          'did,': 56,
#          'welcomed': 443,
#          'many': 4535,
#          'Have': 506,
#          'you': 23212,
#          'parents?': 5,
#          'highly': 134,
#          'educated': 95,
#          'well': 1781,
#          'calling': 408,
#          'stupid': 449,
#          'makes': 618,
#          'that': 26329,
#          'them.': 708,
#          'syrian': 2603,
#          'lebanon': 177,
#          'worsening': 67,
#          'amid': 731,
#          'period': 141,
#          'uncertainty,': 17,
#          'including': 960,
#          'growing': 246,
#          'repatriation': 51,
#          'despite': 440,
#          'largely': 98,
#          'unsafe': 109,
#          'Lebanon:': 9,
#          'plea': 31,
#          'food': 798,
#          'snow': 46,
#          'storms': 14,
#          'strike': 259,
#          'offensive,': 32,
#          'began': 238,
#          'December': 330,
#          '2019,': 91,
#          'has': 15805,
#          'caused': 638,
#          '700k': 10,
#          'had': 3201,
#          'population': 1086,
#          'million,': 100,
#          'half': 636,
#          'IDPs': 124,
#          'earlier': 156,
#          'stages': 8,
#          'conflict': 1086,
#          'lot': 1160,
#          'now': 6788,
#          'stranded': 317,
#          'side': 1195,
#          'quote': 28,
#          '90k': 5,
#          'cut': 366,
#          'number': 1363,
#          'unskilled': 165,
#          'How': 2235,
#          'add': 154,
#          'up?': 37,
#          'Since': 468,
#          'December,': 69,
#          'some': 3432,
#          '520,000': 5,
#          'been': 7112,
#          'homes,': 98,
#          'vast': 225,
#          'majority': 809,
#          '80': 145,
#          'percent': 107,
#          'children,': 388,
#          'said': 2812,
#          'David': 182,
#          'Swanson,': 3,
#          'spokesman': 114,
#          'UN': 2407,
#          'Office': 155,
#          'few': 1464,
#          'months!?!?': 1,
#          'pissed': 50,
#          'off': 1934,
#          'because': 4423,
#          'if': 6105,
#          'fighting,': 36,
#          'why': 3823,
#          'join': 332,
#          'knock': 32,
#          'terrorists?': 46,
#          'U': 1261,
#          'S': 621,
#          'leave': 1937,
#          'We': 7211,
#          'occupying': 76,
#          'land': 1623,
#          'illegally.': 53,
#          'cat': 26,
#          'cracked': 8,
#          'vaunted': 3,
#          'code': 15,
#          'accommodation': 55,
#          'God,': 24,
#          'wish': 433,
#          'me.': 56,
#          'Gary': 71,
#          'Skinner': 71,
#          'official:': 45,
#          'Fresh': 28,
#          'wave': 916,
#          'headed': 208,
#          'There': 2754,
#          '400.000': 21,
#          'Kurd': 56,
#          'Turkey;': 32,
#          'how': 4918,
#          'do': 7989,
#          'want?': 40,
#          'e': 353,
#          'us': 3391,
#          'migration': 1878,
#          'Policy:': 2,
#          'Imposing': 4,
#          'Suffering': 11,
#          'deterrence': 29,
#          'Measure': 2,
#          'gave': 647,
#          '12': 254,
#          'Control': 198,
#          'Points': 6,
#          'border!': 186,
#          'causing': 340,
#          'problem': 2772,
#          'take': 5890,
#          'refugees?': 1318,
#          '"': 23205,
#          'Enhancing': 4,
#          'self': 346,
#          'reliance': 25,
#          'increasing': 180,
#          'access': 632,
#          'livelihood': 15,
#          'opportunities': 89,
#          'substantial': 29,
#          'challenge,': 11,
#          'Kemal': 30,
#          'Kirisci': 20,
#          'Brookings': 8,
#          'Institution.': 1,
#          '1972': 1,
#          '5': 1870,
#          'My': 865,
#          'immigrant': 1896,
#          'asked': 503,
#          'front': 453,
#          'extended': 47,
#          'family': 903,
#          'Christmas': 13,
#          'Vice': 29,
#          'President': 1665,
#          '(before': 6,
#          'Greeks': 2105,
#          'went': 489,
#          'all,': 202,
#          'New': 1221,
#          'phone': 178,
#          'Who': 930,
#          'dis?': 1,
#          'Agnew).': 1,
#          'assumed': 16,
#          'VP': 24,
#          'Miss': 7,
#          'Americas': 36,
#          'runner': 4,
#          'up,': 158,
#          'confidently': 3,
#          'answered,': 2,
#          'McGovern!': 1,
#          'helped': 657,
#          'it.': 499,
#          'bet': 111,
#          'one': 4946,
#          'thing': 947,
#          'stopping': 338,
#          'overall': 50,
#          'socialist': 73,
#          'revolution?': 1,
#          'Angery!': 4,
#          'may,': 7,
#          'please': 859,
#          'consider': 272,
#          'yourselves': 44,
#          'introduced': 33,
#          ':)': 169,
#          'Kristen,': 1,
#          'Shawn': 1,
#          'wrote': 122,
#          'beautiful': 187,
#          'book': 145,
#          'friendship': 24,
#          'Once': 200,
#          'Were': 146,
#          'Strangers.': 1,
#          '20': 407,
#          'km': 101,
#          'UPDATE:': 38,
#          'Navy': 103,
#          'present': 182,
#          'libya': 228,
#          'NGO': 327,
#          'recon': 2,
#          'plane': 82,
#          'picked': 53,
#          'G': 34,
#          'class': 152,
#          'frigates': 5,
#          '16nm': 1,
#          'NNE': 1,
#          'Tripoli': 17,
#          '9': 818,
#          'Feb': 160,
#          '0940': 2,
#          'LT': 2,
#          'rescue': 249,
#          'surveillance': 33,
#          'mission.': 5,
#          'fact,': 106,
#          'influx': 885,
#          'due': 1135,
#          'lack': 380,
#          'coherent': 29,
#          'policy': 1442,
#          'solidarity': 735,
#          'Which': 294,
#          'only': 5514,
#          'too': 1795,
#          'much': 2114,
#          'sovereignty': 110,
#          'protecting': 563,
#          'borders': 9987,
#          'Definitely': 27,
#          'something': 820,
#          'improve.': 2,
#          'You': 5668,
#          'nice': 261,
#          'things': 712,
#          'colonized': 11,
#          'FNs': 3,
#          'gov': 290,
#          'education,': 64,
#          'legal': 705,
#          'representation,': 1,
#          'property': 46,
#          'rights': 3144,
#          'any': 4191,
#          'case': 821,
#          'there': 6183,
#          'certainly': 188,
#          'places': 360,
#          'where': 3343,
#          'local': 592,
#          'established': 103,
#          'regional': 107,
#          'control.': 30,
#          'Yesterday': 76,
#          'morning,': 70,
#          'kids': 601,
#          'painted': 24,
#          'colours': 20,
#          'words': 330,
#          'Notara': 3,
#          '26': 99,
#          'squat': 11,
#          'exarcheia,': 1,
#          'athens': 99,
#          'early': 236,
#          'morning': 379,
#          'antiriot': 4,
#          'police': 4795,
#          'attempted': 170,
#          'break': 498,
#          'into': 7765,
#          'defend': 873,
#          "kids'": 2,
#          'joy': 21,
#          'play': 413,
#          'born': 329,
#          'when': 4635,
#          'UK': 3026,
#          'joined': 123,
#          'EEC': 6,
#          'knew': 203,
#          'twenties': 1,
#          'corrupt': 130,
#          'bureaucratic': 11,
#          'nightmare': 67,
#          'fine': 153,
#          'love': 674,
#          'Europe,': 1415,
#          'Love': 76,
#          'come': 3180,
#          'live,': 33,
#          'enrich': 16,
#          'country': 7862,
#          'go': 5581,
#          'holiday': 105,
#          'think': 3204,
#          'would': 5401,
#          'US': 2089,
#          'just': 5921,
#          '*': 1663,
#          'creating': 688,
#          'security': 1472,
#          'problems': 715,
#          '(by': 34,
#          'provoking': 49,
#          'Russia,': 321,
#          'destabilizing': 104,
#          'Middle': 1045,
#          'East': 970,
#          'terrorism': 289,
#          'lots': 240,
#          'refugees).': 30,
#          "Government'": 17,
#          's': 19412,
#          'Immigration': 159,
#          "Plan'": 1,
#          'Will': 689,
#          'Slash': 5,
#          '90,000': 13,
#          'Unskilled': 7,
#          'Migrants': 3877,
#          "Year'": 1,
#          'Via': 168,
#          'Neon': 26,
#          'Nettle': 26,
#          'neon': 15,
#          'nettle': 15,
#          'Name:': 1,
#          'seeker': 187,
#          'Surname:': 1,
#          'oppressed': 76,
#          'Country:': 7,
#          'no': 8862,
#          'homeland': 187,
#          'Address:': 1,
#          'Case:': 1,
#          'fled': 979,
#          'threat,': 44,
#          'resettlement': 286,
#          'exhausted': 30,
#          'Dream:': 1,
#          'live': 2293,
#          'stable': 74,
#          'Brits': 184,
#          'feel': 820,
#          'atone': 1,
#          'imperializing': 2,
#          'entire': 318,
#          'pick': 150,
#          'tiny': 107,
#          'nation': 570,
#          'turned': 515,
#          'rest': 905,
#          'during': 1031,
#          'Holocaust': 53,
#          'then': 3229,
#          'give': 1827,
#          'shit': 483,
#          'going': 2693,
#          'back': 5335,
#          'told': 985,
#          'go.': 71,
#          'Residential': 1,
#          'Schools': 24,
#          "60'": 6,
#          'Scoop': 2,
#          'Reservations': 2,
#          'Inability': 1,
#          'sue': 16,
#          'Canadian': 95,
#          'Etc': 16,
#          'Every': 289,
#          'mentioned': 119,
#          'demonstrably': 2,
#          'false': 235,
#          'Really?': 76,
#          'Tell': 222,
#          'me,': 164,
#          'place': 1219,
#          'armed': 474,
#          'patrolling': 55,
#          'streets,': 20,
#          'farmlands': 1,
#          "they'": 1120,
#          've': 1134,
#          'stolen.': 1,
#          'prove': 144,
#          'largest': 397,
#          'single': 525,
#          'since': 2580,
#          'almost': 728,
#          'nine': 192,
#          'years': 4104,
#          'ago': 757,
#          'Stand': 98,
#          'most': 2494,
#          'vulnerable': 581,
#          'big': 868,
#          'Lammy': 9,
#          'Exposing': 6,
#          'shameful': 207,
#          'government,': 130,
#          'claim': 666,
#          'but,': 55,
#          'BME,': 1,
#          'being': 4357,
#          'deported,': 15,
#          'scandal': 50,
#          'deporting': 79,
#          'europeans': 126,
#          'Lesbos': 1783,
#          'streets': 183,
#          'drop': 97,
#          'below': 203,
#          'freezing': 387,
#          'Canary': 11,
#          'Uses': 45,
#          'Emergency': 74,
#          'More': 1197,
#          'Centres': 10,
#          'Breitbart': 272,
#          'Snow': 15,
#          'worsens': 31,
#          'Wants': 35,
#          'Wall': 94,
#          'Sea': 302,
#          'Stop': 1128,
#          'Boats,': 3,
#          'Sent': 64,
#          'Homeland': 17,
#          'Safe': 122,
#          'MPs': 39,
#          'rounds': 73,
#          'DC': 9,
#          'week': 685,
#          'seemed': 39,
#          'cautious': 7,
#          'condemning': 67,
#          'Russian': 1120,
#          'failure': 230,
#          'restrain': 11,
#          'offensive': 382,
#          'allowing': 591,
#          'Turkey,': 2097,
#          'already': 2714,
#          'million.': 36,
#          'Protests:': 2,
#          'Chaos': 72,
#          '40,000': 49,
#          'amassed': 63,
#          'ton': 12,
#          'believe': 1014,
#          '/': 7964,
#          'taking': 1525,
#          'homelands': 57,
#          'ressources': 6,
#          "There'": 216,
#          'global': 418,
#          'far': 1581,
#          'uprising': 39,
#          'reason,': 55,
#          'exist': 123,
#          'en': 145,
#          'masse': 35,
#          ...})

# %%
print(list(total_freq.keys())[:30])
# Out:
# ['uk', 'france', 'eu', 'priti patel', 'english', 'farage', 'germany', 'bbc', 'calais', 'brexit', 'channel', 'nigel farage', 'dover', 'greece', 'us', 'turkey', 'spain', 'kent', 'italy', 'syria', 'boris', 'un', 'tory', 'london', 'africa', 'dublin', 'muslim', 'libya', 'boris johnson', 'navy']

# %%
word= 'brexit'
#print(dict(sorted(freq_dict.items(), key=lambda item: item[1][0],reverse=True))[word][0])
print(total_freq[word])
print(list(dict(sorted(freq_dict[word][1].items(), key=lambda item: item[1],reverse=True)).keys()))
#dict(sorted(freq_dict[word][1].items(), key=lambda item: item[1],reverse=True))
# Out:
# {'Root': 9861, 'Overall': 10973}
# ['brexit', 'brexiteers', 'brexiters', 'brexit party', 'brexiteer', 'brexit britain', 'the brexit party', 'brexiter', 'brexit uk', 'brexshit', 'brexity', 'brexit france', 'tory brexiteer', 'brexit covid', 'brexidiots', 'brexit england', 'brexiteer mp', 'brexitland']

# %%
total_freq['uk']
# Out:
# {'Root': 3648, 'Overall': 5470}

# %%
dict(sorted(total_freq.items(), key=lambda item: item[1]['Overall'],reverse=True))
# Out:
# {'refugees': {'Root': 21145, 'Overall': 32942},
#  'tigray': {'Root': 26578, 'Overall': 29993},
#  'un refugee agency': {'Root': 2761, 'Overall': 28798},
#  'eritrean': {'Root': 13582, 'Overall': 20870},
#  'ethiopia': {'Root': 9596, 'Overall': 16723},
#  'un': {'Root': 7757, 'Overall': 15617},
#  'tplf': {'Root': 7764, 'Overall': 7883},
#  'sudan': {'Root': 6711, 'Overall': 7395},
#  'genocide': {'Root': 5287, 'Overall': 5287},
#  'who': {'Root': 5072, 'Overall': 5072},
#  'displaced': {'Root': 4851, 'Overall': 4851},
#  'the united nations': {'Root': 439, 'Overall': 4572},
#  'abiy ahmed ali': {'Root': 1420, 'Overall': 4309},
#  'united': {'Root': 3783, 'Overall': 3783},
#  'western tigray zone': {'Root': 14, 'Overall': 3418},
#  'abi adi': {'Root': 21, 'Overall': 3282},
#  'agency': {'Root': 3251, 'Overall': 3251},
#  'biden': {'Root': 3086, 'Overall': 3086},
#  'abraha': {'Root': 19, 'Overall': 3001},
#  'amhara': {'Root': 2626, 'Overall': 2930},
#  'abyi': {'Root': 55, 'Overall': 2893},
#  'eu': {'Root': 1069, 'Overall': 2723},
#  'us': {'Root': 1736, 'Overall': 2711},
#  'migrants': {'Root': 1082, 'Overall': 2663},
#  'human rights watch': {'Root': 887, 'Overall': 2415},
#  'world': {'Root': 2369, 'Overall': 2369},
#  'camp': {'Root': 2333, 'Overall': 2333},
#  'many': {'Root': 2150, 'Overall': 2150},
#  'ahmed': {'Root': 2087, 'Overall': 2101},
#  'act': {'Root': 2052, 'Overall': 2052},
#  'government': {'Root': 1932, 'Overall': 1932},
#  'amnesty international': {'Root': 1174, 'Overall': 1843},
#  'ethiopias northern tigray region': {'Root': 30, 'Overall': 1835},
#  'raped': {'Root': 1203, 'Overall': 1761},
#  'europeans': {'Root': 15, 'Overall': 1644},
#  'women': {'Root': 1559, 'Overall': 1559},
#  'omna tigray': {'Root': 21, 'Overall': 1513},
#  'antony': {'Root': 1493, 'Overall': 1493},
#  'ali': {'Root': 1479, 'Overall': 1481},
#  'tigrai militias': {'Root': 12, 'Overall': 1441},
#  'children': {'Root': 1441, 'Overall': 1441},
#  'mai kadra': {'Root': 589, 'Overall': 1395},
#  'antony blinken': {'Root': 1324, 'Overall': 1361},
#  'western': {'Root': 881, 'Overall': 1286},
#  'africa': {'Root': 780, 'Overall': 1255},
#  'isaias': {'Root': 936, 'Overall': 1178},
#  'massacres': {'Root': 381, 'Overall': 1170},
#  'tigreans': {'Root': 151, 'Overall': 1134},
#  'united nations department of state european commission': {'Root': 14,
#   'Overall': 1106},
#  'european parliament': {'Root': 125, 'Overall': 1094},
#  'joe': {'Root': 1037, 'Overall': 1075},
#  'josep borrell': {'Root': 486, 'Overall': 1044},
#  'army': {'Root': 1027, 'Overall': 1027},
#  'biden european commission': {'Root': 33, 'Overall': 1004},
#  'gov': {'Root': 1000, 'Overall': 1000},
#  'kamala harris': {'Root': 765, 'Overall': 990},
#  'time': {'Root': 983, 'Overall': 983},
#  'axum': {'Root': 979, 'Overall': 979},
#  'eu council press': {'Root': 13, 'Overall': 940},
#  'militias': {'Root': 939, 'Overall': 939},
#  'don': {'Root': 906, 'Overall': 906},
#  'fontelles european commission': {'Root': 8, 'Overall': 893},
#  'hitsats': {'Root': 781, 'Overall': 869},
#  'law': {'Root': 839, 'Overall': 839},
#  'state department': {'Root': 58, 'Overall': 836},
#  'shimelba': {'Root': 764, 'Overall': 788},
#  'africa unhcr': {'Root': 4, 'Overall': 757},
#  'pp': {'Root': 49, 'Overall': 755},
#  'oromo': {'Root': 421, 'Overall': 717},
#  'maicadra': {'Root': 26, 'Overall': 699},
#  'yemen': {'Root': 583, 'Overall': 692},
#  'houthi': {'Root': 374, 'Overall': 668},
#  'ant nio guterres': {'Root': 544, 'Overall': 658},
#  'justin trudeau': {'Root': 423, 'Overall': 643},
#  'isaias afeworki': {'Root': 175, 'Overall': 632},
#  'filippo grandi': {'Root': 522, 'Overall': 607},
#  'sudan refugee camps': {'Root': 157, 'Overall': 595},
#  'grandi': {'Root': 588, 'Overall': 588},
#  'ant nio': {'Root': 581, 'Overall': 581},
#  'int l criminal court': {'Root': 275, 'Overall': 579},
#  'tegaru': {'Root': 447, 'Overall': 562},
#  'guterres antony': {'Root': 28, 'Overall': 561},
#  'bbc news': {'Root': 305, 'Overall': 555},
#  'somalia': {'Root': 284, 'Overall': 548},
#  'shire': {'Root': 538, 'Overall': 538},
#  'cnn': {'Root': 531, 'Overall': 531},
#  'u ? s ? mission geneva': {'Root': 0, 'Overall': 527},
#  'uk': {'Root': 460, 'Overall': 524},
#  'lindat g': {'Root': 281, 'Overall': 524},
#  'danish refugee council': {'Root': 12, 'Overall': 495},
#  'idp': {'Root': 143, 'Overall': 489},
#  'african americans': {'Root': 7, 'Overall': 475},
#  'the geneva conventions': {'Root': 8, 'Overall': 467},
#  'israel': {'Root': 361, 'Overall': 464},
#  'covid 19': {'Root': 356, 'Overall': 463},
#  'city': {'Root': 462, 'Overall': 462},
#  'geneva': {'Root': 437, 'Overall': 437},
#  'fontelles': {'Root': 428, 'Overall': 428},
#  'north west': {'Root': 17, 'Overall': 411},
#  'addis': {'Root': 405, 'Overall': 405},
#  'endf': {'Root': 395, 'Overall': 395},
#  'junta': {'Root': 338, 'Overall': 395},
#  'kenya': {'Root': 325, 'Overall': 375},
#  'canada': {'Root': 308, 'Overall': 373},
#  'adigrat': {'Root': 50, 'Overall': 333},
#  'hamdayet': {'Root': 332, 'Overall': 332},
#  'syria': {'Root': 185, 'Overall': 323},
#  'saudi arabia': {'Root': 93, 'Overall': 320},
#  'shame on': {'Root': 315, 'Overall': 315},
#  'house': {'Root': 313, 'Overall': 313},
#  'al jazeera': {'Root': 299, 'Overall': 307},
#  'samri': {'Root': 226, 'Overall': 296},
#  'issayas': {'Root': 52, 'Overall': 294},
#  'the washington post': {'Root': 132, 'Overall': 286},
#  'ethiopian human rights commission': {'Root': 261, 'Overall': 276},
#  'the new york times': {'Root': 62, 'Overall': 272},
#  'horn': {'Root': 266, 'Overall': 266},
#  'the mai kadra massacre': {'Root': 92, 'Overall': 266},
#  'michelle': {'Root': 264, 'Overall': 264},
#  'haavisto': {'Root': 263, 'Overall': 263},
#  'east': {'Root': 262, 'Overall': 262},
#  'jewish': {'Root': 91, 'Overall': 261},
#  'muslims': {'Root': 51, 'Overall': 257},
#  'ny': {'Root': 116, 'Overall': 252},
#  'italy': {'Root': 132, 'Overall': 248},
#  'unicef': {'Root': 247, 'Overall': 247},
#  'world food programme': {'Root': 204, 'Overall': 244},
#  'isayas afwork': {'Root': 5, 'Overall': 242},
#  'michelle bachelet': {'Root': 240, 'Overall': 240},
#  'sanaa': {'Root': 144, 'Overall': 240},
#  'libya': {'Root': 210, 'Overall': 239},
#  'eri': {'Root': 215, 'Overall': 239},
#  'egypt': {'Root': 202, 'Overall': 236},
#  'pekka': {'Root': 232, 'Overall': 232},
#  'mai aini': {'Root': 144, 'Overall': 229},
#  'linda thomas': {'Root': 210, 'Overall': 227},
#  'iom': {'Root': 223, 'Overall': 223},
#  'norway': {'Root': 85, 'Overall': 219},
#  'the oromia region': {'Root': 14, 'Overall': 217},
#  'central african republic': {'Root': 18, 'Overall': 212},
#  'adi harush': {'Root': 196, 'Overall': 209},
#  'addis ababa': {'Root': 181, 'Overall': 205},
#  'greenfield': {'Root': 203, 'Overall': 203},
#  'uganda': {'Root': 149, 'Overall': 201},
#  'france': {'Root': 179, 'Overall': 198},
#  'jan': {'Root': 197, 'Overall': 197},
#  'mekelle': {'Root': 195, 'Overall': 195},
#  'germany': {'Root': 64, 'Overall': 192},
#  'hrw': {'Root': 106, 'Overall': 191},
#  '40': {'Root': 190, 'Overall': 190},
#  'tplf militia': {'Root': 189, 'Overall': 189},
#  'english': {'Root': 188, 'Overall': 188},
#  'afwerki': {'Root': 187, 'Overall': 187},
#  'reuters': {'Root': 183, 'Overall': 183},
#  'washington': {'Root': 183, 'Overall': 183},
#  'ant nio guterres united nations european commission': {'Root': 14,
#   'Overall': 178},
#  'palestinian': {'Root': 11, 'Overall': 177},
#  'central': {'Root': 174, 'Overall': 174},
#  'msf': {'Root': 172, 'Overall': 172},
#  'the white house': {'Root': 71, 'Overall': 168},
#  'ethio': {'Root': 141, 'Overall': 167},
#  'the security council': {'Root': 32, 'Overall': 167},
#  'martin': {'Root': 165, 'Overall': 165},
#  'human right': {'Root': 134, 'Overall': 164},
#  'chinese': {'Root': 83, 'Overall': 163},
#  'afp news agency': {'Root': 75, 'Overall': 163},
#  'the associated press': {'Root': 131, 'Overall': 158},
#  'kunama': {'Root': 156, 'Overall': 156},
#  'marc garneau': {'Root': 155, 'Overall': 155},
#  'gumuz': {'Root': 148, 'Overall': 155},
#  'nrc': {'Root': 154, 'Overall': 154},
#  'returnees affairs arra': {'Root': 58, 'Overall': 154},
#  'chris': {'Root': 152, 'Overall': 152},
#  'christian': {'Root': 77, 'Overall': 148},
#  'gedaref': {'Root': 146, 'Overall': 146},
#  'world bank': {'Root': 145, 'Overall': 145},
#  'humera': {'Root': 144, 'Overall': 144},
#  'russia': {'Root': 45, 'Overall': 142},
#  'tigiray': {'Root': 14, 'Overall': 142},
#  'icc': {'Root': 140, 'Overall': 140},
#  'uae': {'Root': 129, 'Overall': 139},
#  'metekel': {'Root': 133, 'Overall': 138},
#  'turkey': {'Root': 102, 'Overall': 134},
#  'arra': {'Root': 129, 'Overall': 129},
#  'arabic': {'Root': 21, 'Overall': 124},
#  'mark': {'Root': 121, 'Overall': 121},
#  'martin plaut': {'Root': 100, 'Overall': 120},
#  'democrats': {'Root': 39, 'Overall': 120},
#  'tdf': {'Root': 113, 'Overall': 120},
#  'mekele': {'Root': 119, 'Overall': 119},
#  'fano': {'Root': 115, 'Overall': 115},
#  'jan egeland': {'Root': 107, 'Overall': 113},
#  'darfur': {'Root': 113, 'Overall': 113},
#  'asmara': {'Root': 112, 'Overall': 112},
#  'irob advocacy association': {'Root': 6, 'Overall': 110},
#  'natalia': {'Root': 109, 'Overall': 109},
#  'world health organization': {'Root': 94, 'Overall': 109},
#  'hoa': {'Root': 108, 'Overall': 108},
#  'adwa': {'Root': 105, 'Overall': 105},
#  'rwanda': {'Root': 104, 'Overall': 104},
#  'embassy': {'Root': 104, 'Overall': 104},
#  'ireland': {'Root': 89, 'Overall': 103},
#  'senate': {'Root': 85, 'Overall': 103},
#  'price': {'Root': 101, 'Overall': 101},
#  'sheraro': {'Root': 101, 'Overall': 101},
#  'northern command': {'Root': 71, 'Overall': 101},
#  'the horn of africa': {'Root': 89, 'Overall': 101},
#  'eth': {'Root': 74, 'Overall': 100},
#  'tedros adhanom': {'Root': 58, 'Overall': 100},
#  'tedros': {'Root': 99, 'Overall': 99},
#  'benishangul': {'Root': 99, 'Overall': 99},
#  'mfa': {'Root': 97, 'Overall': 97},
#  'los angeles': {'Root': 14, 'Overall': 97},
#  'iran': {'Root': 64, 'Overall': 95},
#  'twitter': {'Root': 95, 'Overall': 95},
#  'djibouti': {'Root': 94, 'Overall': 94},
#  'hgdef': {'Root': 75, 'Overall': 94},
#  'the maikadra genocide fled': {'Root': 43, 'Overall': 94},
#  'afar': {'Root': 92, 'Overall': 92},
#  'australia': {'Root': 70, 'Overall': 91},
#  'usaid': {'Root': 91, 'Overall': 91},
#  'cory booker': {'Root': 90, 'Overall': 90},
#  'may ayni': {'Root': 52, 'Overall': 90},
#  'chris coons': {'Root': 89, 'Overall': 89},
#  'reuters africa': {'Root': 20, 'Overall': 87},
#  'david': {'Root': 86, 'Overall': 86},
#  'european external action service eeas': {'Root': 86, 'Overall': 86},
#  'khartoum': {'Root': 46, 'Overall': 84},
#  'maykadra': {'Root': 82, 'Overall': 82},
#  'red cross': {'Root': 82, 'Overall': 82},
#  'wfp': {'Root': 81, 'Overall': 81},
#  'trump': {'Root': 81, 'Overall': 81},
#  'kenneth roth': {'Root': 75, 'Overall': 80},
#  'sky': {'Root': 80, 'Overall': 80},
#  'rakuba': {'Root': 60, 'Overall': 79},
#  'laetitia bader': {'Root': 71, 'Overall': 79},
#  'new zealand': {'Root': 11, 'Overall': 79},
#  'daniel bekele': {'Root': 60, 'Overall': 77},
#  'edf': {'Root': 77, 'Overall': 77},
#  'generation': {'Root': 77, 'Overall': 77},
#  'holocaust': {'Root': 76, 'Overall': 76},
#  'daniel': {'Root': 75, 'Overall': 75},
#  'moussa faki mahamat': {'Root': 37, 'Overall': 75},
#  'nigeria': {'Root': 60, 'Overall': 73},
#  'shabia': {'Root': 73, 'Overall': 73},
#  'mark lowcock': {'Root': 70, 'Overall': 70},
#  'blue nile': {'Root': 43, 'Overall': 70},
#  'ap': {'Root': 69, 'Overall': 69},
#  'the middle east': {'Root': 18, 'Overall': 69},
#  'natalia paszkiewicz': {'Root': 68, 'Overall': 68},
#  'gambella': {'Root': 48, 'Overall': 68},
#  'icrc': {'Root': 68, 'Overall': 68},
#  'ocha': {'Root': 68, 'Overall': 68},
#  'yohannes abraham': {'Root': 62, 'Overall': 68},
#  'eu civil protection and humanitarian aid': {'Root': 66, 'Overall': 66},
#  'bob rae': {'Root': 65, 'Overall': 65},
#  'tekeze': {'Root': 43, 'Overall': 65},
#  'russian mission un': {'Root': 65, 'Overall': 65},
#  'l onu': {'Root': 65, 'Overall': 65},
#  'nazi': {'Root': 38, 'Overall': 63},
#  'sweden': {'Root': 40, 'Overall': 62},
#  'benishangul gumuz': {'Root': 49, 'Overall': 62},
#  'hamdeyat camp': {'Root': 51, 'Overall': 61},
#  'irc': {'Root': 61, 'Overall': 61},
#  'hintsats': {'Root': 60, 'Overall': 60},
#  'confirmation': {'Root': 60, 'Overall': 60},
#  'karina gould': {'Root': 59, 'Overall': 59},
#  'amharic': {'Root': 59, 'Overall': 59},
#  'greenfield european parliament': {'Root': 15, 'Overall': 59},
#  'msf east africa': {'Root': 6, 'Overall': 59},
#  'vanessa': {'Root': 59, 'Overall': 59},
#  'fed': {'Root': 59, 'Overall': 59},
#  'gonder': {'Root': 58, 'Overall': 58},
#  'esayas': {'Root': 58, 'Overall': 58},
#  'derg': {'Root': 58, 'Overall': 58},
#  'tanzanian': {'Root': 6, 'Overall': 58},
#  'senate foreign relations committee': {'Root': 55, 'Overall': 55},
#  'tigray united nations': {'Root': 55, 'Overall': 55},
#  'india': {'Root': 44, 'Overall': 54},
#  'congo': {'Root': 54, 'Overall': 54},
#  'meron': {'Root': 54, 'Overall': 54},
#  'weyane': {'Root': 54, 'Overall': 54},
#  'wolkait': {'Root': 28, 'Overall': 53},
#  'yemane': {'Root': 53, 'Overall': 53},
#  'obama': {'Root': 52, 'Overall': 52},
#  'hinxax': {'Root': 52, 'Overall': 52},
#  'ag': {'Root': 8, 'Overall': 51},
#  'insecurity allegations of grave distressing human rights abuses': {'Root': 51,
#   'Overall': 51},
#  'bbc tigrinya': {'Root': 1, 'Overall': 51},
#  'mediterranean': {'Root': 50, 'Overall': 50},
#  'aksum': {'Root': 50, 'Overall': 50},
#  'weeknd': {'Root': 49, 'Overall': 49},
#  'gondar': {'Root': 49, 'Overall': 49},
#  'chevrierantoine': {'Root': 48, 'Overall': 48},
#  'denmark': {'Root': 18, 'Overall': 48},
#  'myanmar': {'Root': 41, 'Overall': 47},
#  'amara': {'Root': 46, 'Overall': 46},
#  'belgium': {'Root': 42, 'Overall': 45},
#  'vanessa tsehaye': {'Root': 45, 'Overall': 45},
#  'kakuma': {'Root': 45, 'Overall': 45},
#  'sawa': {'Root': 45, 'Overall': 45},
#  'lebanon': {'Root': 29, 'Overall': 44},
#  'the telegraph': {'Root': 36, 'Overall': 44},
#  'jutta': {'Root': 44, 'Overall': 44},
#  'kat graham': {'Root': 43, 'Overall': 43},
#  'dominic raab': {'Root': 42, 'Overall': 42},
#  'amhara fano': {'Root': 42, 'Overall': 42},
#  'shiraro': {'Root': 25, 'Overall': 41},
#  'borisjohnson': {'Root': 41, 'Overall': 41},
#  'ertrean': {'Root': 17, 'Overall': 41},
#  'iraq': {'Root': 40, 'Overall': 40},
#  'myayni': {'Root': 40, 'Overall': 40},
#  'chad': {'Root': 40, 'Overall': 40},
#  'isis': {'Root': 40, 'Overall': 40},
#  'meles': {'Root': 40, 'Overall': 40},
#  'south africa': {'Root': 34, 'Overall': 39},
#  'woyane': {'Root': 39, 'Overall': 39},
#  'drc': {'Root': 38, 'Overall': 38},
#  'mexico': {'Root': 30, 'Overall': 38},
#  'jutta urpilainen': {'Root': 38, 'Overall': 38},
#  'migration bureau': {'Root': 17, 'Overall': 37},
#  'orthodox': {'Root': 37, 'Overall': 37},
#  'dia': {'Root': 36, 'Overall': 36},
#  'janez lenar i': {'Root': 36, 'Overall': 36},
#  'mikadra': {'Root': 36, 'Overall': 36},
#  'alton': {'Root': 36, 'Overall': 36},
#  'janez': {'Root': 36, 'Overall': 36},
#  'mick wallace': {'Root': 35, 'Overall': 35},
#  'priyanka': {'Root': 35, 'Overall': 35},
#  'finland': {'Root': 25, 'Overall': 35},
#  'netherlands': {'Root': 25, 'Overall': 35},
#  'iaa': {'Root': 35, 'Overall': 35},
#  'the nobel prize': {'Root': 18, 'Overall': 35},
#  'cease desist': {'Root': 34, 'Overall': 34},
#  'voa': {'Root': 34, 'Overall': 34},
#  'chris melzer': {'Root': 23, 'Overall': 34},
#  'ataye': {'Root': 34, 'Overall': 34},
#  'ehrc': {'Root': 34, 'Overall': 34},
#  'haben': {'Root': 28, 'Overall': 34},
#  'nima': {'Root': 34, 'Overall': 34},
#  'samantha power': {'Root': 34, 'Overall': 34},
#  'ilhan omar': {'Root': 33, 'Overall': 33},
#  'mulu': {'Root': 33, 'Overall': 33},
#  'imf': {'Root': 33, 'Overall': 33},
#  'estonia': {'Root': 32, 'Overall': 32},
#  'the national': {'Root': 32, 'Overall': 32},
#  'unocha': {'Root': 32, 'Overall': 32},
#  'alula': {'Root': 32, 'Overall': 32},
#  'bloomberg': {'Root': 32, 'Overall': 32},
#  'nancy pelosi': {'Root': 31, 'Overall': 31},
#  'jake tapper': {'Root': 31, 'Overall': 31},
#  'niger': {'Root': 31, 'Overall': 31},
#  'uscri': {'Root': 24, 'Overall': 31},
#  'msm': {'Root': 31, 'Overall': 31},
#  'boston': {'Root': 30, 'Overall': 30},
#  'afghanistan': {'Root': 30, 'Overall': 30},
#  'benshangul': {'Root': 25, 'Overall': 30},
#  'bangladesh': {'Root': 29, 'Overall': 29},
#  'zecharias zelalem': {'Root': 29, 'Overall': 29},
#  'the voice of america': {'Root': 29, 'Overall': 29},
#  'raya': {'Root': 29, 'Overall': 29},
#  'bisrat gebremedhin': {'Root': 20, 'Overall': 29},
#  'demeke': {'Root': 29, 'Overall': 29},
#  'kjetil tronvoll': {'Root': 29, 'Overall': 29},
#  'rohingya': {'Root': 28, 'Overall': 28},
#  'interpol': {'Root': 28, 'Overall': 28},
#  'nima elbagir': {'Root': 28, 'Overall': 28},
#  'shemelba': {'Root': 28, 'Overall': 28},
#  'gerry simpson': {'Root': 27, 'Overall': 27},
#  'emmanuel macron': {'Root': 27, 'Overall': 27},
#  'debretsion': {'Root': 27, 'Overall': 27},
#  'ministry of peace': {'Root': 27, 'Overall': 27},
#  'kidane': {'Root': 27, 'Overall': 27},
#  'london': {'Root': 26, 'Overall': 26},
#  'badme': {'Root': 26, 'Overall': 26},
#  'unfpa': {'Root': 26, 'Overall': 26},
#  'irc international rescue committee': {'Root': 26, 'Overall': 26},
#  'neamin zeleke': {'Root': 25, 'Overall': 25},
#  'japan': {'Root': 25, 'Overall': 25},
#  'dadaab': {'Root': 25, 'Overall': 25},
#  'unesco': {'Root': 25, 'Overall': 25},
#  'fao': {'Root': 25, 'Overall': 25},
#  'lampedusa': {'Root': 25, 'Overall': 25},
#  'international development committee': {'Root': 6, 'Overall': 25},
#  'pajok': {'Root': 24, 'Overall': 24},
#  'dc': {'Root': 24, 'Overall': 24},
#  'himayat': {'Root': 24, 'Overall': 24},
#  'dx open network': {'Root': 24, 'Overall': 24},
#  'selam': {'Root': 24, 'Overall': 24},
#  'mai cadra': {'Root': 24, 'Overall': 24},
#  'devex': {'Root': 23, 'Overall': 23},
#  'micadra': {'Root': 23, 'Overall': 23},
#  'kassala': {'Root': 23, 'Overall': 23},
#  'young generation': {'Root': 23, 'Overall': 23},
#  'miakadra': {'Root': 13, 'Overall': 23},
#  'sinai': {'Root': 22, 'Overall': 22},
#  'pakistan': {'Root': 22, 'Overall': 22},
#  'yahoo news': {'Root': 3, 'Overall': 22},
#  'juba': {'Root': 22, 'Overall': 22},
#  'toronto': {'Root': 17, 'Overall': 22},
#  'asia': {'Root': 13, 'Overall': 22},
#  'red crescent': {'Root': 22, 'Overall': 22},
#  'penny': {'Root': 22, 'Overall': 22},
#  'fisseha tekle': {'Root': 15, 'Overall': 22},
#  'david beasley': {'Root': 21, 'Overall': 21},
#  'tunaydbah': {'Root': 21, 'Overall': 21},
#  'meron estefanos': {'Root': 21, 'Overall': 21},
#  'undp': {'Root': 21, 'Overall': 21},
#  'mohamed': {'Root': 21, 'Overall': 21},
#  'ga': {'Root': 11, 'Overall': 21},
#  'ogaden': {'Root': 21, 'Overall': 21},
#  'magufuli': {'Root': 21, 'Overall': 21},
#  'texas': {'Root': 20, 'Overall': 20},
#  'gulf': {'Root': 20, 'Overall': 20},
#  'rashid abdi': {'Root': 20, 'Overall': 20},
#  'fbc': {'Root': 20, 'Overall': 20},
#  'gulag': {'Root': 20, 'Overall': 20},
#  'oxfam': {'Root': 20, 'Overall': 20},
#  'the guardian': {'Root': 20, 'Overall': 20},
#  'ann allen': {'Root': 19, 'Overall': 19},
#  'sudan individuals in axum': {'Root': 19, 'Overall': 19},
#  'facebook': {'Root': 19, 'Overall': 19},
#  'venezuela': {'Root': 14, 'Overall': 19},
#  'secblinken': {'Root': 19, 'Overall': 19},
#  'haiti': {'Root': 13, 'Overall': 19},
#  'amp': {'Root': 14, 'Overall': 19},
#  'tewodros': {'Root': 19, 'Overall': 19},
#  'elsa': {'Root': 19, 'Overall': 19},
#  'ben gurion airport': {'Root': 18, 'Overall': 18},
#  'qatar': {'Root': 18, 'Overall': 18},
#  'mengistu': {'Root': 18, 'Overall': 18},
#  'tesfahun gobezay': {'Root': 18, 'Overall': 18},
#  'burundi': {'Root': 18, 'Overall': 18},
#  'wukro': {'Root': 18, 'Overall': 18},
#  'china road': {'Root': 12, 'Overall': 18},
#  'blm': {'Root': 18, 'Overall': 18},
#  'congressmember bass': {'Root': 18, 'Overall': 18},
#  'haben girma': {'Root': 17, 'Overall': 17},
#  'sven spengemann': {'Root': 17, 'Overall': 17},
#  'kosovo': {'Root': 17, 'Overall': 17},
#  'meaza': {'Root': 17, 'Overall': 17},
#  'mycadra': {'Root': 17, 'Overall': 17},
#  'labor': {'Root': 17, 'Overall': 17},
#  'tefera': {'Root': 17, 'Overall': 17},
#  'ablinken': {'Root': 16, 'Overall': 16},
#  'north korea': {'Root': 16, 'Overall': 16},
#  'ghana': {'Root': 16, 'Overall': 16},
#  'mykadra': {'Root': 16, 'Overall': 16},
#  'tmh': {'Root': 16, 'Overall': 16},
#  'chagni': {'Root': 16, 'Overall': 16},
#  'rice': {'Root': 15, 'Overall': 15},
#  'abel tesfaye': {'Root': 15, 'Overall': 15},
#  'copts': {'Root': 15, 'Overall': 15},
#  'joe neguse': {'Root': 15, 'Overall': 15},
#  'alula solomon': {'Root': 15, 'Overall': 15},
#  'we are on the brink of a humanitarian crisis': {'Root': 15, 'Overall': 15},
#  'm xico': {'Root': 15, 'Overall': 15},
#  'bahirdar': {'Root': 15, 'Overall': 15},
#  'cortez': {'Root': 15, 'Overall': 15},
#  'ecc': {'Root': 15, 'Overall': 15},
#  'adi harish': {'Root': 15, 'Overall': 15},
#  'jamal osman': {'Root': 14, 'Overall': 14},
#  'ann linde': {'Root': 14, 'Overall': 14},
#  'charles': {'Root': 14, 'Overall': 14},
#  'aden': {'Root': 14, 'Overall': 14},
#  'united nations pga': {'Root': 14, 'Overall': 14},
#  'jen psaki': {'Root': 14, 'Overall': 14},
#  'ww2': {'Root': 14, 'Overall': 14},
#  'el geneina': {'Root': 14, 'Overall': 14},
#  'penny wong': {'Root': 14, 'Overall': 14},
#  'trevor noah': {'Root': 14, 'Overall': 14},
#  'charles michel': {'Root': 14, 'Overall': 14},
#  'ursula von der leyen': {'Root': 14, 'Overall': 14},
#  'north shewa': {'Root': 14, 'Overall': 14},
#  'negusti': {'Root': 14, 'Overall': 14},
#  'hassan': {'Root': 14, 'Overall': 14},
#  'cameroon': {'Root': 13, 'Overall': 13},
#  'seid mussa omar': {'Root': 13, 'Overall': 13},
#  'tel aviv': {'Root': 13, 'Overall': 13},
#  'mali': {'Root': 13, 'Overall': 13},
#  'great lakes': {'Root': 13, 'Overall': 13},
#  'assab': {'Root': 13, 'Overall': 13},
#  'catholic': {'Root': 13, 'Overall': 13},
#  'kakuma refugee camp': {'Root': 13, 'Overall': 13},
#  'united nations camps': {'Root': 13, 'Overall': 13},
#  'al nejashi': {'Root': 13, 'Overall': 13},
#  'jeff': {'Root': 13, 'Overall': 13},
#  'helen clark': {'Root': 12, 'Overall': 12},
#  'william davison': {'Root': 12, 'Overall': 12},
#  'mogadishu': {'Root': 12, 'Overall': 12},
#  'gregory meeks': {'Root': 12, 'Overall': 12},
#  'greece': {'Root': 12, 'Overall': 12},
#  'bronwyn bruton': {'Root': 12, 'Overall': 12},
#  'denver': {'Root': 12, 'Overall': 12},
#  'bayto': {'Root': 12, 'Overall': 12},
#  'ken': {'Root': 12, 'Overall': 12},
#  'pompeo': {'Root': 12, 'Overall': 12},
#  'abdi latif dahir': {'Root': 12, 'Overall': 12},
#  'fox news': {'Root': 12, 'Overall': 12},
#  'zeebrugge': {'Root': 12, 'Overall': 12},
#  'meles zenawi': {'Root': 12, 'Overall': 12},
#  'pia': {'Root': 12, 'Overall': 12},
#  'guinea': {'Root': 12, 'Overall': 12},
#  'cia': {'Root': 12, 'Overall': 12},
#  'switzerland': {'Root': 11, 'Overall': 11},
#  'npr': {'Root': 11, 'Overall': 11},
#  'sara jerving': {'Root': 11, 'Overall': 11},
#  'jordan': {'Root': 11, 'Overall': 11},
#  'netanyahu': {'Root': 11, 'Overall': 11},
#  'susan rice': {'Root': 11, 'Overall': 11},
#  'will brown': {'Root': 11, 'Overall': 11},
#  'tplf mafia group': {'Root': 11, 'Overall': 11},
#  'charlotte petri gornitzka': {'Root': 11, 'Overall': 11},
#  'hutu': {'Root': 11, 'Overall': 11},
#  'fbi': {'Root': 11, 'Overall': 11},
#  'john sparks': {'Root': 11, 'Overall': 11},
#  'alex de waal': {'Root': 11, 'Overall': 11},
#  'welkait': {'Root': 11, 'Overall': 11},
#  'cbs': {'Root': 11, 'Overall': 11},
#  'financial times': {'Root': 11, 'Overall': 11},
#  'alexander rondos': {'Root': 11, 'Overall': 11},
#  'one day seyoum': {'Root': 11, 'Overall': 11},
#  'dawit kebede': {'Root': 11, 'Overall': 11},
#  'nubians': {'Root': 5, 'Overall': 11},
#  'sahara': {'Root': 11, 'Overall': 11},
#  'cbn news': {'Root': 10, 'Overall': 10},
#  'nottingham': {'Root': 10, 'Overall': 10},
#  'cairo': {'Root': 10, 'Overall': 10},
#  'ees': {'Root': 10, 'Overall': 10},
#  'malta': {'Root': 10, 'Overall': 10},
#  'nigsty': {'Root': 10, 'Overall': 10},
#  'jagmeet singh': {'Root': 10, 'Overall': 10},
#  'pagak': {'Root': 10, 'Overall': 10},
#  'marxist': {'Root': 10, 'Overall': 10},
#  'monaliza': {'Root': 10, 'Overall': 10},
#  'welega': {'Root': 10, 'Overall': 10},
#  'guatemala': {'Root': 9, 'Overall': 9},
#  'colorado': {'Root': 9, 'Overall': 9},
#  'tiger': {'Root': 9, 'Overall': 9},
#  'abc news': {'Root': 9, 'Overall': 9},
#  'al shabab': {'Root': 9, 'Overall': 9},
#  'rashaida': {'Root': 9, 'Overall': 9},
#  'freweyni': {'Root': 9, 'Overall': 9},
#  'iyoba': {'Root': 9, 'Overall': 9},
#  'simon coveney': {'Root': 9, 'Overall': 9},
#  'dirty rose': {'Root': 9, 'Overall': 9},
#  'liberia': {'Root': 9, 'Overall': 9},
#  'rob oliphant': {'Root': 8, 'Overall': 8},
#  'gambia': {'Root': 8, 'Overall': 8},
#  'tunisia': {'Root': 8, 'Overall': 8},
#  'indiana': {'Root': 8, 'Overall': 8},
#  'reliefweb': {'Root': 8, 'Overall': 8},
#  'poland': {'Root': 8, 'Overall': 8},
#  'dominicraab': {'Root': 8, 'Overall': 8},
#  'ksa': {'Root': 8, 'Overall': 8},
#  'elizabeth warren': {'Root': 8, 'Overall': 8},
#  'negusti woldeselassie': {'Root': 8, 'Overall': 8},
#  'mussie zerai': {'Root': 8, 'Overall': 8},
#  'depo provera': {'Root': 8, 'Overall': 8},
#  'colombia': {'Root': 8, 'Overall': 8},
#  'sierra leone': {'Root': 8, 'Overall': 8},
#  'the tigray peoples liberation front': {'Root': 8, 'Overall': 8},
#  'prophet mohammed': {'Root': 8, 'Overall': 8},
#  'ayanna pressley': {'Root': 7, 'Overall': 7},
#  'seifesilassie gebremeskel': {'Root': 7, 'Overall': 7},
#  'gedarif hospital': {'Root': 7, 'Overall': 7},
#  'zewde': {'Root': 7, 'Overall': 7},
#  'emmanuel igunza': {'Root': 7, 'Overall': 7},
#  'bishoftu': {'Root': 7, 'Overall': 7},
#  'sahel': {'Root': 7, 'Overall': 7},
#  'marco mendicino': {'Root': 7, 'Overall': 7},
#  'al tanidaba': {'Root': 7, 'Overall': 7},
#  'todd young': {'Root': 7, 'Overall': 7},
#  'mesfin hagos': {'Root': 7, 'Overall': 7},
#  'the passport prison': {'Root': 7, 'Overall': 7},
#  'portland': {'Root': 7, 'Overall': 7},
#  'cameron hudson': {'Root': 7, 'Overall': 7},
#  'jesus': {'Root': 7, 'Overall': 7},
#  'operation zur israel': {'Root': 7, 'Overall': 7},
#  'dw news': {'Root': 6, 'Overall': 6},
#  'atlantic council': {'Root': 6, 'Overall': 6},
#  'abel makkonen tesfaye': {'Root': 6, 'Overall': 6},
#  'the ethopia n govt': {'Root': 6, 'Overall': 6},
#  'mozambique': {'Root': 6, 'Overall': 6},
#  'california': {'Root': 6, 'Overall': 6},
#  'fpc': {'Root': 6, 'Overall': 6},
#  'yugoslavia': {'Root': 6, 'Overall': 6},
#  'mahalet': {'Root': 6, 'Overall': 6},
#  'algeria': {'Root': 6, 'Overall': 6},
#  'columbus': {'Root': 6, 'Overall': 6},
#  'james duddridge': {'Root': 6, 'Overall': 6},
#  'seattle': {'Root': 6, 'Overall': 6},
#  'philippe champagne': {'Root': 6, 'Overall': 6},
#  'jack tapper': {'Root': 6, 'Overall': 6},
#  'hague': {'Root': 6, 'Overall': 6},
#  'hirut zemene': {'Root': 6, 'Overall': 6},
#  'your report made axum a berlin in ww2': {'Root': 6, 'Overall': 6},
#  'samra tesfaye': {'Root': 6, 'Overall': 6},
#  'cuba': {'Root': 6, 'Overall': 6},
#  'justin wilson': {'Root': 6, 'Overall': 6},
#  'lisa schlein': {'Root': 6, 'Overall': 6},
#  'morocco': {'Root': 6, 'Overall': 6},
#  'fed forces': {'Root': 6, 'Overall': 6},
#  'southern region': {'Root': 6, 'Overall': 6},
#  'nariman el mofty': {'Root': 6, 'Overall': 6},
#  'vice world news': {'Root': 6, 'Overall': 6},
#  'ambmkimani united nations': {'Root': 5, 'Overall': 5},
#  'hcr': {'Root': 5, 'Overall': 5},
#  'simon adams': {'Root': 5, 'Overall': 5},
#  'kyle brewster': {'Root': 5, 'Overall': 5},
#  'jim risch': {'Root': 5, 'Overall': 5},
#  'kagame': {'Root': 5, 'Overall': 5},
#  'bin': {'Root': 5, 'Overall': 5},
#  'mossad': {'Root': 5, 'Overall': 5},
#  'sammy': {'Root': 5, 'Overall': 5},
#  'babar baloch': {'Root': 5, 'Overall': 5},
#  'jake sullivan': {'Root': 5, 'Overall': 5},
#  'ocp': {'Root': 5, 'Overall': 5},
#  'ngesti': {'Root': 5, 'Overall': 5},
#  'mulugeta seraw': {'Root': 5, 'Overall': 5},
#  'vanessa coeffe': {'Root': 5, 'Overall': 5},
#  'ahmad of wimbledon': {'Root': 5, 'Overall': 5},
#  'jamaican': {'Root': 5, 'Overall': 5},
#  'greenfield united nations': {'Root': 4, 'Overall': 4},
#  'bob menendez': {'Root': 4, 'Overall': 4},
#  'sally hayden': {'Root': 4, 'Overall': 4},
#  'paul': {'Root': 3, 'Overall': 3},
#  'the globe and mail': {'Root': 3, 'Overall': 3},
#  'mulubrhane medhane kfleyosus': {'Root': 3, 'Overall': 3},
#  'melbourne': {'Root': 3, 'Overall': 3},
#  'spain': {'Root': 3, 'Overall': 3},
#  'jeff pearce': {'Root': 3, 'Overall': 3},
#  'zimbabwe': {'Root': 3, 'Overall': 3},
#  'zebangedena': {'Root': 3, 'Overall': 3},
#  'hungary': {'Root': 3, 'Overall': 3},
#  'daily mail online': {'Root': 2, 'Overall': 2},
#  'dereje desta': {'Root': 2, 'Overall': 2},
#  'hafez ghanem': {'Root': 1, 'Overall': 1},
#  'downing': {'Root': 1, 'Overall': 1},
#  'david malpass': {'Root': 1, 'Overall': 1},
#  'freweini g sadick': {'Root': 1, 'Overall': 1},
#  'ant nio vitorino': {'Root': 1, 'Overall': 1},
#  'u ? s ?': {'Root': 0, 'Overall': 0},
#  'vodacom': {'Root': 0, 'Overall': 0},
#  'scottmorrison': {'Root': 0, 'Overall': 0},
#  'u ? s ? mission': {'Root': 0, 'Overall': 0},
#  'fana broadcasting corporate s ? c ?': {'Root': 0, 'Overall': 0},
#  'yemane g ? meskel': {'Root': 0, 'Overall': 0},
#  'ocha united nations': {'Root': 0, 'Overall': 0},
#  'wa ati': {'Root': 0, 'Overall': 0},
#  'astead': {'Root': 0, 'Overall': 0},
#  'henrietta h ? fore': {'Root': 0, 'Overall': 0},
#  'cori bush sen': {'Root': 0, 'Overall': 0},
#  'karenbass': {'Root': 0, 'Overall': 0}}

# %%
freq_dict['sudan']
# Out:
# [6711,
#  {'south sudanese': 44,
#   'sudan refugee': 388,
#   'sudans': 79,
#   'sudan border town': 46,
#   'sudanese': 567,
#   'south sudan': 578,
#   'sudanpmhamdok': 38,
#   's sudan': 19,
#   'eastern sudan': 180,
#   'unhcr sudan': 47,
#   'east sudan': 31}]

# %% [markdown]
# ### To quickly check what merged and play with thresholds

# %%
def make_sim_df_freq(sim_df, event_cands):
    #get frequency of of text column
    sim_df_freq_ = sim_df.merge(event_cands[['entity','freq']],left_on='text',right_on='entity')
    sim_df_freq_ = sim_df_freq_[sim_df_freq_.freq>5]
    #get frequency of of text_to_compare columns
    sim_df_freq = sim_df_freq_.merge(event_cands[['entity','freq']],left_on='text_to_compare',right_on='entity')
    sim_df_freq = sim_df_freq[sim_df_freq.freq_y>5]
    
    sim_df_freq.drop(['entity_x','entity_y'],axis=1,inplace=True)
    return sim_df_freq

def print_info(sim_df, entity,sim=0.7):
    merged = list(sim_df[(sim_df['sim']>sim) & (sim_df['text']==entity)].sort_values('sim',ascending=False)['text_to_compare'])
    #text_freq = max(sim_df[(sim_df['sim']>sim) & (sim_df['text']==entity)]['cand_freq_x'])
    #text_to_compare_freq = sum(sim_df[(sim_df['sim']>sim) & (sim_df['text']==entity)]['cand_freq_y'])
    #print(f'{entity} mentions: {text_freq}. After merging: {text_freq+text_to_compare_freq}')
    #print(merged)
    return merged

# %%
sim_df_freq_anns.sort_values('freq_x',ascending=False)['text'].unique()[:20]
# Out:
# array(['turkey', 'greece', 'europe', 'eu', 'syria', 'erdogan', 'idlib',
#        'russia', 'uk', 'assad', 'germany', 'nato', 'turkish', 'us',
#        'lesbos', 'syrians', 'syrian', 'iran', 'putin', 'bulgaria'],
#       dtype=object)

# %%
sim_df = load_pickle('greece_sim_df_anns')
entities = load_pickle('greece_anns')

sim_df_freq_anns= make_sim_df_freq(sim_df,entities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-047dbf8d1dac> in <module>
#       2 entities = load_pickle('greece_anns')
#       3
# ----> 4 sim_df_freq_anns= make_sim_df_freq(sim_df,entities)
#
# NameError: name 'make_sim_df_freq' is not defined

# %%
sim_df
# Out:
#                  text  text_to_compare       sim
# 0              turkey          erdogan  0.809029
# 1              turkey          turkish  0.880714
# 2              turkey           ankara  0.790253
# 3              turkey          erdoğan  0.809029
# 4              turkey            turks  0.850284
# ...               ...              ...       ...
# 28447336  allah ekber  yahyah farroukh  0.795914
# 28447337       malcom        venezuala  0.673318
# 28447338       malcom  yahyah farroukh  0.691370
# 28447339   the island        venezuala  0.677538
# 28447340    venezuala  yahyah farroukh  0.720481
#
# [28447341 rows x 3 columns]

# %%
entity = 'assad'
sim = 0.85

print_info(sim_df_freq_anns, entity,sim)
# Out:
# ['mr assad',
#  'al-assad',
#  'abu emad',
#  'erdo',
#  'arash yousufi',
#  'alqaeda',
#  'essad',
#  'haftar',
#  'quatar',
#  'zaatari',
#  'afrin',
#  'khaled',
#  'naamat',
#  'ahmet',
#  'hatay',
#  'afgans',
#  'syriza',
#  'iman',
#  'ertogan',
#  'bashar assad',
#  'javid',
#  'anadolu',
#  'afd',
#  'hayat tahrir',
#  'belal khaled',
#  'aq',
#  'asad',
#  'afgani',
#  'ulay',
#  'maaret',
#  'majed',
#  'yarmouk',
#  'afp',
#  'khaled heeba',
#  'esad']

# %%
entity = 'turkey'
sim = 0.85

merged_entities = set()
merged_entities.update(print_info(sim_df_freq_anns, entity,sim))
for merged in print_info(sim_df_freq_anns, entity,sim):
    merged_entities.update(print_info(sim_df_freq_anns, merged, sim=0.9))
    
merged_entities
# Out:
# {'al turkey',
#  'eu turkey',
#  'eu-turkey',
#  'istanbul turkey',
#  'nw turkey',
#  'republic of turkey',
#  'turkey border',
#  'turkey erdogan',
#  'turkey news',
#  'turkey turkey',
#  'turkish',
#  'turkish border',
#  'turkish coast',
#  'turkish gov',
#  'turkish greek',
#  'turkish republic',
#  'turkish state',
#  'turkish-eu',
#  'turks'}
