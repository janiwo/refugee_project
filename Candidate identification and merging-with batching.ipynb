# %% [markdown]
# # Candidate merging and related preprocessing

# %% [markdown]
# Import relevant packages for the following parts

# %%
#python libraries
import stanza
import nltk
from nltk.corpus import wordnet
import numpy as np
import pandas as pd
import os
import re
import csv
from tqdm import tqdm
import time

# self written modules
import preprocessing
import candidate_processing as cand_prep
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading english - 1grams ...
# Reading english - 1grams ...
# Reading english - 2grams ...
# C:\ProgramData\Anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# ## 1. We import the data and split them based on the event date

# %%
data_url = r"CBS - Copenhagen Business School\Kick-Ass Master Thesis - General\Data\moria-data/moria_no_duplicates.csv"
directory_path = os.getcwd() + "/../../../" + data_url 
event_df = pd.read_csv(directory_path, index_col=0)

event_df.reset_index(drop=True, inplace=True)
# given event date, split the dataset to pre and post event dfs

event_date = '2020-09-09'

#moria_df[['Date','Time']] = moria_df['Date Short'].astype(str).str.split(' ', 1, expand=True)
# create pre and post event partition
pre_event = event_df[event_df['Date Short'] < event_date]
post_event = event_df[event_df['Date Short'] >= event_date]

print('total tweets: ', event_df.shape[0])
print('Pre event tweets: ',pre_event.shape[0])
print('Post event tweets: ',post_event.shape[0])
# Out:
# total tweets:  18203
# Pre event tweets:  3311
# Post event tweets:  14892

# %% [markdown]
# ## 2. We preprocess the data using the function from self-written preprocessing module

# %%
# see the description of the method in the preprocessing module
sampled_df = preprocessing.preprocess_tweets(event_df['Tweet Raw'][:200])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 522.17it/s]

# %% [markdown]
# ## 3. We instantiate stanza english language module

# %%
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ needed when running first time ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#

#stanza.download("en")

#directory = '../../export CORENLP_HOME=' ##ADD DIRECTORY HERE
#stanza.install_corenlp()

#import os
#os.environ["CORENLP_HOME"] = directory

# %%
en_nlp = stanza.Pipeline("en", ner_batch_size=4096)
# Out:
# 2021-03-18 22:04:27 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | depparse  | combined  |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-03-18 22:04:27 INFO: Use device: cpu
# 2021-03-18 22:04:27 INFO: Loading: tokenize
# 2021-03-18 22:04:27 INFO: Loading: pos
# 2021-03-18 22:04:28 INFO: Loading: lemma
# 2021-03-18 22:04:28 INFO: Loading: depparse
# 2021-03-18 22:04:29 INFO: Loading: sentiment
# 2021-03-18 22:04:30 INFO: Loading: ner
# 2021-03-18 22:04:31 INFO: Done loading processors!

# %%
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ NOT USED ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# if we did not care about keeping track of tweet indices then we could use this - very fast batching

# set the column width otherwise only truncated tweet will be converted
pd.options.display.max_colwidth = 1000

tweets_txt = sampled_df.to_string(index = False)

# we need 2 new line for batching, if they do not exist, replace 1 line break with two
tweets_txt = tweets_txt if '\n\n' in tweets_txt else tweets_txt.replace('\n','\n\n') 

tweets_txt
# Out:
# "                                               Yes, why? Why it wasnt good to apply for asylum in Greece, MAC, SER or CRO or BUL, together 3 EU members before HU? They must get help in the first safe country as asylum seeker, not in the 5 th . No law says you can pick and choose and get it.\n\n                                                                          ISIS refuge . Wouldn' t go to Turkey if I was paid . You' re likely to get your head lopped off if you stray off the beaten track . Go to Christian Greece and be safe while enjoying a similar climate to islamic turkey\n\n                                                                                                                                                                                                                                                 Greece must improve refugee overcrowding, UN warns\n\n           1 / 3 Law? Let the idle stuff . All rights of the Turkish minority in Greece were taken away . Where is the law? Refugees are not accepted into the EU . Where is the law? Western states divided the states in the Middle East and Africa for underground resources . Where is the law?\n\n                                                                                              Anyway, how did the asylum seekers ended up at HU borders? They must have had a long journey through Greece, where they must apply for help, yet they travelled through multiple more countries, why?\n\n               I never loved photo gr apy pushing aesthetic into news cause it is a potential embellishments of hard facts and harsh reality . I like raw realism . Did I pass this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp? Thats a big question4me\n\n                                                                                                                      ManfredWeber: It must be made clear that Europe and Germany are on the side of Greece . The German MFA must be careful not to be blackmailed in fear of a new refugee crisis.\n\n                                                                                                                                                                                                                                           Refugee Covid case sparks' closed camps' fears on Lesbos\n\n                                                                                                                                             9PM Coronavirus UK LIVE: Leeds on brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham\n\n                Are you sure you' re talking about France and not Turkey? Turkey has invaded parts of Syria, bombs Iraq, conducts a proxy war in Libya creating refugees . On top of that, it violates Greece' s and Cyprus' sovereignties . Not to mention that it provides safe heaven for Hamas.\n\n                                                                                                            Raquel Bessudo is Isaac Bessudos widow . The Bessudos were Sephardic Jewish immigrants from Salonica, Greece . Raquels parents were Polish Jews . Raquel is blonde and blue eyed though\n\n                                                                                                                                                                                                                                                   Most of them immigrated to Greece by their will.\n\n                                                                   First you stuff they Turkey, then you bake it, and at last you eat it!!! Be kind to your women, they are very welcome to seek asylum in Greece just like your army and people are doing . Leaving crazy ruled Turkey . Ah Siktir\n\n                                                                                                                                                                     ...

# %%
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ NOT USED ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# the purpose would be to store all matching candidates, their phrases, phrases heads in a big dataframe

len(stanza_documents)

{stanza_documents[tweet_id]:[stanza_documents[tweet_id].text, ] for tweet_id in range(len(tweets)) for sent in tweets[tweet_id].sentences for word,ent in sent}
# List1  
lst = [[stanza_documents[tweet_id],[stanza_documents[tweet_id].text, ] for tweet_id in range(len(tweets)) for sent in tweets[tweet_id].sentences for word,ent in sent}] 
    
df = pd.DataFrame(lst, columns =['FName', 'LName', 'Age'], dtype = float) 
df
# Out:
# 100

# %% [markdown]
# ## 4. We apply stanza module on the tweets to get NER and POS tags. We do it in batches to speed things up.

# %%
# batching the tweets speeds the model considerably and is enabled by splitting sentences using '\n\n' 
from stanza_batch import batch
from nltk.tokenize import sent_tokenize

# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(sampled_df) 
for tweet in range(len(all_tweets_list)):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if tweet_sentokenized == []:
        tweet_sentokenized.append('empty_tweet')
        print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=1000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text
# Out:
# 0it [00:00, ?it/s]
# empty tweet at index 137
# empty tweet at index 167
# 200it [01:01,  3.26it/s]
# 'Yes, why?\n\nWhy it wasnt good to apply for asylum in Greece, MAC, SER or CRO or BUL, together 3 EU members before HU?\n\nThey must get help in the first safe country as asylum seeker, not in the 5 th .\n\nNo law says you can pick and choose and get it.'

# %%
# get easily accessible list of tuples (POS-tags of each word, NER-tags of each named entity) 
tweet_tags = cand_prep.get_tweet_tags(tagged_tweets) 


#get a set of all NER tags existing in corpus - check which one are found in corpus

tweet_tags_set = set()
for tweet in tweet_tags:
    tweet_ner_tags = set(tweet[1].values())
    tweet_tags_set.update(tweet_ner_tags)

print(tweet_tags_set)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 16661.92it/s]
# {'PERCENT', 'TIME', 'NORP', 'ORDINAL', 'GPE', 'PERSON', 'LANGUAGE', 'PRODUCT', 'EVENT', 'QUANTITY', 'DATE', 'CARDINAL', 'LOC', 'MONEY', 'LAW', 'ORG'}

# %% [markdown]
# ## 5. As initial WCL candidates, we extract noun phrases (NPs) and coreference chains.
#
# ## We do so using CoreNLPClient wrapper
#
# ### SOME PREPROCESSING NEEDED
# * remove links - check
# * remove # from hashtags? - check
# * remove/merge mentions? - check
#
#
# * remove recurring texts (signatures of news media) - any new spotted should be added in preprocessing file's '__remove_tweet_signatures__' function
# * remove posts of some accounts (refugee_list)
# * exclude NERs that tag numbers - should we mark phrase as NE if the head is not NE? - check
# * play around with candidate types
# * optimize code and make it neater

# %%
from stanza.server import CoreNLPClient

noun_phrase_list = []
with CoreNLPClient(timeout=300000, memory='16G') as client:
    for tweet in tqdm(list(sampled_df)):
        # get noun phrases with tregex using get_noun_phrases function
        noun_phrase = cand_prep.get_noun_phrases(client,str(tweet),annotators="tokenize,ssplit,pos,lemma,parse")
        noun_phrase_list.append(noun_phrase)
        #noun_phrases(client,event_df["Tweet Raw"][:100],_annotators="tokenize,ssplit,pos,lemma,parse")
# Out:
# 2021-03-18 22:05:51 INFO: Writing properties to tmp file: corenlp_server-d485d6788767453d.props
# 2021-03-18 22:05:51 INFO: Starting server with command: java -Xmx16G -cp C:\Users\nikodemicek\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 300000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-d485d6788767453d.props -preload -outputFormat serialized
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [03:06<00:00,  1.07it/s]

# %%
noun_phrase_list = [[np.replace(' - ','-') for np in nps] for nps in noun_phrase_list]
noun_phrase_list = [[np.replace(' / ','/') for np in nps] for nps in noun_phrase_list]
noun_phrase_list = [[np.replace(" ' ","'") for np in nps] for nps in noun_phrase_list]

# %%
#Store the noun phrases in the pickle file
import pickle

with open('file_name_to_save', 'wb') as fp:
    pickle.dump(noun_phrase_list, fp)

# %%
# Load NPs from pickle file
import pickle

with open(r"moria_noun_phrases", "rb") as input_file:
    noun_phrase_list = pickle.load(input_file)

#noun_phrase_list

# %% [markdown]
# ## 6. We keep only NPs shorter than 20 words and remove children of parent NPs

# %%
def get_cand_len(cand_list):
    # calculates number of candidates in the corpus
    sum_len = 0
    for tweet_cands in cand_list:
        sum_len += len(tweet_cands)
    return sum_len

print(get_cand_len(noun_phrase_list))


for tweet_nps in noun_phrase_list:
    #reverse the list of tweets nps so we avoid moving indexes and leaving out some phrases 
    for np in reversed(tweet_nps):
        i = tweet_nps.index(np)
        np_split = np.split()
        if len(np_split) > 19:
            tweet_nps.remove(tweet_nps[i])
            
print(get_cand_len(noun_phrase_list))
# Out:
# 2714
# 2692

# %%
# remove the child NPs and keep only parents, run until the sum_len stops decreasing
after_removal_len = 0
while after_removal_len != get_cand_len(noun_phrase_list):
    after_removal_len = get_cand_len(noun_phrase_list)
    for tweet_nps in noun_phrase_list:
        for np in range(len(tweet_nps)):
            try:
                #if the subsequent np (child np) is contained in the current one, remove the child np
                if tweet_nps[np].find(tweet_nps[np+1]) != -1:
                    tweet_nps.remove(tweet_nps[np+1])

            #ignore the error caused with end of the list
            except IndexError:
                pass

print(get_cand_len(noun_phrase_list))
# Out:
# 1430

# %%
noun_phrase_list

# %% [markdown]
# ## 7. We get the heads of noun phrases (in batches)

# %%
#tag all tweets and save them in a list    
tagged_np_cands = [] 
batched_np_list = cand_prep.prep_candlist_for_batching(noun_phrase_list)

for tagged_cand in tqdm(batch(batched_np_list, en_nlp, batch_size=6000)): # Default batch size is 32
        tagged_np_cands.append(tagged_cand)
# Out:
# 0it [00:00, ?it/s]
# empty tweet at index 137
# empty tweet at index 167
# ['it\n\nasylum in Greece, MAC, SER or CRO or BUL\n\n3 EU members\n\nHU\n\nThey\n\nhelp\n\nthe first safe country as asylum seeker\n\nthe 5\n\nNo law\n\nyou\n\nit', "ISIS refuge .\n\nWouldn' t\n\nTurkey\n\nI\n\nYou' re likely to get your head\n\nthe beaten track\n\nChristian Greece\n\na similar climate\n\nislamic turkey", 'Greece\n\nrefugee overcrowding\n\nUN', '1/3\n\nLaw\n\nthe idle stuff\n\nAll rights of the Turkish minority in Greece\n\nthe law\n\nRefugees\n\nthe EU\n\nthe law\n\nWestern states\n\nthe states\n\nthe Middle East and Africa\n\nunderground resources\n\nthe law', 'the asylum seekers\n\nHU borders\n\nThey\n\na long journey\n\nGreece\n\nthey\n\nhelp\n\nthey\n\nmultiple more countries', 'I\n\nphoto gr apy\n\naesthetic\n\nnews\n\nit\n\na potential embellishments of hard facts and harsh reality\n\nI\n\nraw realism\n\nI\n\nthis boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp\n\na big question4me', 'ManfredWeber\n\nIt\n\nEurope and Germany\n\nthe side of Greece\n\nThe German MFA\n\nfear of a new refugee crisis', "Refugee Covid case sparks' closed camps' fears on Lesbos", '9PM Coronavirus UK\n\nLeeds\n\nbrink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham', "you' re\n\nFrance and not Turkey\n\nparts of Syria\n\nbombs Iraq\n\na proxy war in Libya\n\nrefugees\n\ntop of that\n\nit\n\nGreece' s and Cyprus' sovereignties\n\nit\n\nsafe heaven for Hamas", 'Raquel Bessudo\n\nIsaac Bessudos widow\n\nThe Bessudos\n\nSephardic Jewish immigrants from Salonica, Greece\n\nRaquels parents\n\nPolish Jews\n\nRaquel', 'Most of them\n\nGreece\n\ntheir will', 'you\n\nthey\n\nTurkey\n\nyou\n\nit\n\nyou\n\nit\n\nyour women\n\nthey\n\nasylum\n\nGreece\n\nyour army and people\n\nTurkey\n\nSiktir', 'Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest', 'Record numbers of illegal migrants\n\nthe United States\n\nthe United Kingdom\n\nGreece\n\nthe border\n\ncontrol\n\nIt\n\nme\n\nthis\n\npart of the new normal', 'Refugee virus cases\n\nfears in Lesbos', 'Illegal immigration\n\na problem of GREECE or EUROPE', 'severe claustrophobia\n\nhis entire life\n\nBoth men\n\nlosers\n\nthey\n\nit\n\ntheir Fathers\n\nAmerica\n\nthem\n\nimmigrants from Greece\n\n1914\n\nThe Trump family\n\nmilitary boots', 'Greece\n\n10 refugees, including three children with disabilities\n\nThose refugees\n\nErdogan\n\nGreece\n\neuropean union values\n\n@coe @Europarl_EN\n\n@vonderleyen @NachoSAmor @hrw\n\n@tr724 araclyla', 'Two high ranking UN Refugee Agency officials on Friday\n\na visit\n\nGreece\n\na drastic improvement in the living conditions of refugees in camps\n\nAnadolu Agency\n\nUNHCRs Assistant High Commissioners for Protection and O .\xa0.\xa0.', 'UN\n\nGreece\n\nrefugeeovercrowding', 'Switzerland?\n\nI\n\nits more likely\n\nthe Balkans\n\nGreece\n\na bunch of illegal immigrants\n\nthe middle of the sea\n\nthe growing tension with Turkey\n\na stronger, motivated govt\n\nErdogans ersatz invaders', 'the EU\n\nillegal immigration\n\nI\n\nt\n\nthe people of Greece\n\nthat particular memo', '4 years\n\nwe\n\noffered high-quality, trauma-sensitive, identity-informed pss & education support to child & youth refugees in northern Greece\n\nyour help\n\nwe\n\nthis work for another 4 years\n\nanother 4 countries', "Refugee Covid case sparks' closed camps' fears on Lesbos", 'you\n\nmass immigration\n\nSweden, Austria, Norway, Finland, Denmark, Greece, or pressure\n\nPoland, Bulgaria, Hungary, Slovenia, Serbia & other European countries\n\nmass migration', '2018\n\nthe uk\n\napplications\n\nasylum\n\n37,453 people (including dependants)\n\nThis\n\ngermany (162,000), france (110,000), greece (65,000) and italy (49,000)', 'Enterprise Greece\n\nthis effort\n\nthey\n\ntheir many services and resources\n\nthe end of the year\n\ntheir strategic partnership with @eBay\n\nGreek SMEs\n\nthey\n\nsuch a high-level international platform', ...
# 200it [01:05,  3.07it/s]

# %%
np_cand_heads = cand_prep.get_cand_heads(tagged_np_cands)
np_cand_heads
# Out:
# [[[{'it'}, ['it']],
#   [{'BUL', 'CRO', 'Greece', 'MAC', 'SER', 'asylum'}, ['asylum']],
#   [{'members'}, ['members']],
#   [{'HU'}, ['HU']],
#   [{'They'}, ['They']],
#   [{'help'}, ['help']],
#   [{'country', 'seeker'}, ['country']],
#   [{'5'}, ['5']],
#   [{'law'}, ['law']],
#   [{'you'}, ['you']],
#   [{'it'}, ['it']]],
#  [[{'.', 'refuge'}, ['refuge']],
#   [{'Wouldn', 't'}, ['Wouldn']],
#   [{'Turkey'}, ['Turkey']],
#   [{'I'}, ['I']],
#   [{'get', 'head', 'likely'}, ['likely']],
#   [{'track'}, ['track']],
#   [{'Christian', 'Greece'}, ['Christian']],
#   [{'climate'}, ['climate']],
#   [{'turkey'}, ['turkey']]],
#  [[{'Greece'}, ['Greece']],
#   [{'overcrowding'}, ['overcrowding']],
#   [{'UN'}, ['UN']]],
#  [[{'1/3'}, ['1/3']],
#   [{'Law'}, ['Law']],
#   [{'stuff'}, ['stuff']],
#   [{'Greece', 'minority', 'rights'}, ['rights']],
#   [{'law'}, ['law']],
#   [{'Refugees'}, ['Refugees']],
#   [{'EU'}, ['EU']],
#   [{'law'}, ['law']],
#   [{'states'}, ['states']],
#   [{'states'}, ['states']],
#   [{'Africa', 'East'}, ['East']],
#   [{'resources'}, ['resources']],
#   [{'law'}, ['law']]],
#  [[{'seekers'}, ['seekers']],
#   [{'borders'}, ['borders']],
#   [{'They'}, ['They']],
#   [{'journey'}, ['journey']],
#   [{'Greece'}, ['Greece']],
#   [{'they'}, ['they']],
#   [{'help'}, ['help']],
#   [{'they'}, ['they']],
#   [{'countries'}, ['countries']]],
#  [[{'I'}, ['I']],
#   [{'apy', 'gr'}, ['apy']],
#   [{'aesthetic'}, ['aesthetic']],
#   [{'news'}, ['news']],
#   [{'it'}, ['it']],
#   [{'embellishments', 'facts', 'reality'}, ['embellishments']],
#   [{'I'}, ['I']],
#   [{'realism'}, ['realism']],
#   [{'I'}, ['I']],
#   [{'boundary', 'camp', 'lesbos', 'light', 'migrants', 'using', 'week'},
#    ['boundary']],
#   [{'me', 'question4'}, ['question4']]],
#  [[{'ManfredWeber'}, ['ManfredWeber']],
#   [{'It'}, ['It']],
#   [{'Europe', 'Germany'}, ['Europe']],
#   [{'Greece', 'side'}, ['side']],
#   [{'MFA'}, ['MFA']],
#   [{'crisis', 'fear'}, ['fear']]],
#  [[{'Lesbos', 'camps', 'case', 'fears', 'sparks'}, ['sparks']]],
#  [[{'PM', 'UK'}, ['PM']],
#   [{'Leeds'}, ['Leeds']],
#   [{'Birmingham',
#     'Stories',
#     'birmingham',
#     'brink',
#     'chaos',
#     'hostel',
#     'lockdown',
#     'outbreak',
#     'seeker',
#     'sources'},
#    ['brink']]],
#  [[{'re', 'you'}, ['you']],
#   [{'France', 'Turkey'}, ['France']],
#   [{'Syria', 'parts'}, ['parts']],
#   [{'Iraq', 'bombs'}, ['bombs']],
#   [{'Libya', 'war'}, ['war']],
#   [{'refugees'}, ['refugees']],
#   [{'that', 'top'}, ['top']],
#   [{'it'}, ['it']],
#   [{'Cyprus', 'Greece', 'sovereignties'}, ['Greece']],
#   [{'it'}, ['it']],
#   [{'Hamas', 'heaven'}, ['heaven']]],
#  [[{'Bessudo', 'Raquel'}, ['Raquel']],
#   [{'Isaac', 'widow'}, ['widow']],
#   [{'Bessudos'}, ['Bessudos']],
#   [{'Greece', 'Salonica', 'immigrants'}, ['immigrants']],
#   [{'parents'}, ['parents']],
#   [{'Jews'}, ['Jews']],
#   [{'Raquel'}, ['Raquel']]],
#  [[{'Most', 'them'}, ['Most']],
#   [{'Greece'}, ['Greece']],
#   [{'will'}, ['will']]],
#  [[{'you'}, ['you']],
#   [{'they'}, ['they']],
#   [{'Turkey'}, ['Turkey']],
#   [{'you'}, ['you']],
#   [{'it'}, ['it']],
#   [{'you'}, ['you']],
#   [{'it'}, ['it']],
#   [{'women'}, ['women']],
#   [{'they'}, ['they']],
#   [{'asylum'}, ['asylum']],
#   [{'Greece'}, ['Greece']],
#   [{'army', 'people'}, ['army']],
#   [{'Turkey'}, ['Turkey']],
#   [{'Siktir'}, ['Siktir']]],
#  [[{'2015',
#     '5th',
#     'became',
#     'budapest',
#     'crisis',
#     'crossroads',
#     'later',
#     'years'},
#    ['became']]],
#  [[{'migrants', 'numbers'}, ['numbers']],
#   [{'States'}, ['States']],
#   [{'Kingdom'}, ['Kingdom']],
#   [{'Greece'}, ['Greece']],
#   [{'border'}, ['border']],
#   [{'control'}, ['control']],
#   [{'It'}, ['It']],
#   [{'me'}, ['me']],
#   [{'this'}, ['this']],
#   [{'normal', 'part'}, ['part']]],
#  [[{'cases', 'virus'}, ['cases']], [{'Lesbos', 'fears'}, ['fears']]],
#  [[{'immigration'}, ['immigration']],
#   [{'EUROPE', 'GREECE', 'problem'}, ['problem']]],
#  [[{'claustrophobia'}, ['claustrophobia']],
#   [{'life'}, ['life']],
#   [{'men'}, ['men']],
#   [{'losers'}, ['losers']],
#   [{'they'}, ['they']],
#   [{'it'}, ['it']],
#   [{'Fathers'}, ['Fathers']],
#   [{'America'}, ['America']],
#   [{'them'}, ['them']],
#   [{'Greece', 'immigrants'}, ['immigrants']],
#   [{'1914'}, ['1914']],
#   [{'family'}, ['family']],
#   [{'boots'}, ['boots']]],
#  [[{'Greece'}, ['Greece']],
#   [{'children', 'disabilities', 'refugees'}, ['refugees']],
#   [{'refugees'}, ['refugees']],
#   [{'Erdogan'}, ['Erdogan']],
#   [{'Greece'}, ['Greece']],
#   [{'union', 'values'}, ['values']],
#   [{'@Europarl_EN', '@coe'}, ['@coe']],
#   [{'@hrw', '@vonderleyen'}, ['@vonderleyen']],
#   [{'@tr724', 'araclyla'}, ['@tr724']]],
#  [[{'Agency', 'Friday', 'officials', 'ranking'}, ['officials']],
#   [{'visit'}, ['visit']],
#   [{'Greece'}, ['Greece']],
#   [{'camps', 'conditions', 'improvement', 'refugees'}, ['improvement']],
#   [{'Agency'}, ['Agency']],
#   [{'. .', 'Commissioners', 'O', 'Protection', 'UNHCRs'}, ['UNHCRs']]],
#  [[{'UN'}, ['UN']],
#   [{'Greece'}, ['Greece']],
#   [{'refugeeovercrowding'}, ['refugeeovercrowding']]],
#  [[{'?', 'Switzerland'}, ['Switzerland']],
#   [{'I'}, ['I']],
#   [{'likely'}, ['likely']],
#   [{'Balkans'}, ['Balkans']],
#   [{'Greece'}, ['Greece']],
#   [{'bunch', 'immigrants'}, ['bunch']],
#   [{'middle', 'sea'}, ['middle']],
#   [{'Turkey', 'tension'}, ['tension']],
#   [{'govt'}, ['govt']],
#   [{'invaders'}, ['invaders']]],
#  [[{'EU'}, ['EU']],
#   [{'immigration'}, ['immigration']],
#   [{'I'}, ['I']],
#   [{'t'}, ['t']],
#   [{'Greece', 'people'}, ['people']],
#   [{'memo'}, ['memo']]],
#  [[{'years'}, ['years']],
#   [{'we'}, ['we']],
#   [{'-quality',
#     'Greece',
#     'child',
#     'education',
#     'identity',
#     'offered',
#     'pss',
#     'refugees',
#     'support',
#     'youth'},
#    ['offered']],
#   [{'help'}, ['help']],
#   [{'we'}, ['we']],
#   [{'work', 'years'}, ['work']],
#   [{'countries'}, ['countries']]],
#  [[{'Lesbos', 'camps', 'case', 'fears', 'sparks'}, ['sparks']]],
#  [[{'you'}, ['you']],
#   [{'immigration'}, ['immigration']],
#   [{'Austria', 'Denmark', 'Finland', 'Greece', 'Norway', 'Sweden', 'pressure'},
#    ['Sweden']],
#   [{'Bulgaria', 'Hungary', 'Poland', 'Serbia', 'Slovenia', 'countries'},
#    ['Poland']],
#   [{'migration'}, ['migration']]],
#  [[{'2018'}, ['2018']],
#   [{'uk'}, ['uk']],
#   [{'applications'}, ['applications']],
#   [{'asylum'}, ['asylum']],
#   [{')', 'dependants', 'people'}, ['people']],
#   [{'This'}, ['This']],
#   [{')',
#     '110,000',
#     '162,000',
#     '49,000',
#     '65,000',
#     'france',
#     'germany',
#     'greece',
#     'italy'},
#    ['germany']]],
#  [[{'Greece'}, ['Greece']],
#   [{'effort'}, ['effort']],
#   [{'they'}, ['they']],
#   [{'resources', 'services'}, ['services']],
#   [{'end', 'year'}, ['end']],
#   [{'Bay', 'partnership'}, ['partnership']],
#   [{'SMEs'}, ['SMEs']],
#   [{'they'}, ['they']],
#   [{'level', 'platform'}, ['platform']]],
#  [[{'Commissioners', 'Greece', 'UNHCR', 'visit'}, ['visit']],
#   [{'challenges', 'protection'}, ['challenges']],
#   [{'support'}, ['support']]],
#  [[{'I'}, ['I']],
#   [{'Greece', 'WiFi', 'camps', 'couple'}, ['couple']],
#   [{'there'}, ['there']],
#   [{'food', 'less', 'more', 'right', 'water'}, ['right']],
#   [{'they'}, ['they']],
#   [{'few', 'had', 'people', 'possessions', 'them'}, ['people']],
#   [{'phone'}, ['phone']],
#   [{'contact', 'means'}, ['means']],
#   [{'relatives'}, ['relatives']]],
#  [[{'He'}, ['He']],
#   [{'t'}, ['t']],
#   [{'He'}, ['He']],
#   [{'asylum'}, ['asylum']],
#   [{'Athens'}, ['Athens']],
#   [{'July'}, ['July']],
#   [{'August'}, ['August']],
#   [{'he'}, ['he']],
#   [{'Lesvos'}, ['Lesvos']],
#   [{'tent'}, ['tent']],
#   [{'camp'}, ['camp']],
#   [{'Anarchy'}, ['Anarchy']],
#   [{'Moria'}, ['Moria']],
#   [{'Nobody'}, ['Nobody']],
#   [{'rules'}, ['rules']],
#   [{'There'}, ['There']],
#   [{'attacks'}, ['attacks']],
#   [{'This'}, ['This']],
#   [{'camps'}, ['camps']],
#   [{'necessity'}, ['necessity']]],
#  [[{'Erdoan'}, ['Erdoan']],
#   [{'cards'}, ['cards']],
#   [{'He'}, ['He']],
#   [{'ya'}, ['ya']],
#   [{'refugees'}, ['refugees']],
#   [{'Greece'}, ['Greece']]],
#  [[{'Belgium'}, ['Belgium']],
#   [{'1/10', '2', 'seekers', 'size'}, ['1/10']],
#   [{'.', '1', '2', 'Greece', 'seekers', 'size', 'twice'}, ['Greece']]],
#  [[{'It'}, ['It']],
#   [{'many'}, ['many']],
#   [{'s'}, ['s']],
#   [{'issue'}, ['issue']],
#   [{'migrants'}, ['migrants']],
#   [{'Erdogan'}, ['Erdogan']],
#   [{'Greece'}, ['Greece']],
#   [{'Turkey'}, ['Turkey']]],
#  [[{',', 'man', 'old', 'person', 'year'}, ['person']],
#   [{'asylum'}, ['asylum']],
#   [{'He'}, ['He']],
#   [{'July', 'camp'}, ['camp']],
#   [{'Athens'}, ['Athens']],
#   [{'August'}, ['August']],
#   [{'tent'}, ['tent']],
#   [{'camp'}, ['camp']],
#   [{'it', 'think'}, ['think']],
#   [{'Hell', 'camps'}, ['camps']],
#   [{'oversight'}, ['oversight']],
#   [{'end'}, ['end']],
#   [{'Moria', 'anarchy'}, ['anarchy']]],
#  [[{'Greece'}, ['Greece']],
#   [{'we'}, ['we']],
#   [{'constructive', 'exchanges', 'open'}, ['exchanges']],
#   [{'authorities'}, ['authorities']],
#   [{'right'}, ['right']],
#   [{'asylum'}, ['asylum']],
#   [{'access'}, ['access']],
#   [{'need', 'protection', 'territory', 'those'}, ['territory']],
#   [{'pushbacks', 'reports'}, ['reports']],
#   [{'land', 'sea'}, ['land']]],
#  [[{'Greece'}, ['Greece']],
#   [{'arms'}, ['arms']],
#   [{'refugees', 'thousands'}, ['thousands']],
#   [{'issues'}, ['issues']],
#   [{'.', 'Asst'}, ['Asst']],
#   [{'@Raouf', 'Commissioners', 'GillianTriggs', 'Operations', 'Protection'},
#    ['Commissioners']],
#   [{'Mazou'}, ['Mazou']],
#   [{'visit'}, ['visit']],
#   [{'message', 'solidarity'}, ['message']]],
#  [[{'I'}, ['I']],
#   [{'class', 'country', 'refuge'}, ['refuge']],
#   [{'greece'}, ['greece']],
#   [{'I'}, ['I']],
#   [{'imagine', 'life'}, ['life']],
#   [{'centuries', 'country', 'dreams'}, ['country']],
#   [{'Greece', 'economy', 'needs', 'tourists'}, ['economy']],
#   [{'world'}, ['world']]],
#  [[{'this'}, ['this']],
#   [{'greece'}, ['greece']],
#   [{'refugees'}, ['refugees']]],
#  [[{'This'}, ['This']],
#   [{'Turkey', 'attempted', 'coup', 'members', 'shelters', 'surprise'},
#    ['surprise']],
#   [{'terrorists'}, ['terrorists']],
#   [{'seekers'}, ['seekers']],
#   [{'definition'}, ['definition']],
#   [{'PKK', 'competed', 'issue', 'lowness', 'people'}, ['people']]],
#  [[{'Greece'}, ['Greece']],
#   [{'solution'}, ['solution']],
#   [{'this'}, ['this']],
#   [{'Surly', 'length'}, ['Surly']],
#   [{'route'}, ['route']]],
#  [[{'Greece', 'visit'}, ['visit']],
#   [{'@RaoufMazou', 'Commissioners', 'GillianTriggs'}, ['Commissioners']],
#   [{'NGOs',
#     'authorities',
#     'challenges',
#     'discussed',
#     'protection',
#     'refugees'},
#    ['refugees']],
#   [{'call'}, ['call']],
#   [{'solidarity', 'support'}, ['support']]],
#  [[{'evidence'}, ['evidence']],
#   [{'Albanian', 'Greece', 'migration'}, ['migration']],
#   [{')', 'Arvanites', 'thousands', 'years'}, ['thousands']],
#   [{'Illyrians'}, ['Illyrians']],
#   [{'presence'}, ['presence']],
#   [{'Greece'}, ['Greece']]],
#  [[{'you'}, ['you']],
#   [{'opinion'}, ['opinion']],
#   [{'you'}, ['you']],
#   [{'Greece', 'afraid', 'asking', 'prison', 'talk'}, ['prison']]],
#  [[{'Exploration'}, ['Exploration']],
#   [{'Greece', 'tension'}, ['tension']],
#   [{'Dialogue'}, ['Dialogue']],
#   [{'Greece', 'Upset', 'migrants', 'pushed', 'water', 'which', 'work'},
#    ['pushed']],
#   [{'Gas', 'Greed'}, ['Greed']],
#   [{'war'}, ['war']]],
#  [[{'I'}, ['I']],
#   [{'2015', 'crises'}, ['crises']],
#   [{'route'}, ['route']],
#   [{'Greece'}, ['Greece']],
#   [{'Macedonia'}, ['Macedonia']],
#   [{'border'}, ['border']],
#   [{'Hungary', 'Serbia'}, ['Serbia']],
#   [{'I'}, ['I']],
#   [{'people'}, ['people']],
#   [{'hosted', 'me', 'spoke', 'way'}, ['way']]],
#  [[{'covid', 'refugees'}, ['refugees']],
#   [{'lesvos'}, ['lesvos']],
#   [{'camp', 'lockdown'}, ['lockdown']],
#   [{'Covid'}, ['Covid']],
#   [{'excuse'}, ['excuse']],
#   [{'Europe', 'freedoms', 'people', 'rights', 'safety', 'seeking'},
#    ['freedoms']]],
#  [[{'Greece', 'enter', 'names', 'organization', 'refugees', 'world'},
#    ['organization']]],
#  [[{'.', 'Greece', 'Those', 'coup', 'make', 'seek', 'those', 'want'},
#    ['Those']],
#   [{'they'}, ['they']],
#   [{'Greece'}, ['Greece']],
#   [{'kind', 'people'}, ['kind']],
#   [{'brain'}, ['brain']],
#   [{'Don', 't'}, ['Don']],
#   [{'perspective'}, ['perspective']],
#   [{'expression', 'freedom'}, ['freedom']],
#   [{'propaganda'}, ['propaganda']],
#   [{'it'}, ['it']],
#   [{'crime'}, ['crime']]],
#  [[{'Authorities', 'Greece'}, ['Authorities']],
#   [{'Lesbos', 'camp', 'island'}, ['camp']],
#   [{'quarantine'}, ['quarantine']],
#   [{'confirmation', 'facility', 'infection', 'overcrowded'},
#    ['confirmation']]],
#  [[{'2040'}, ['2040']],
#   [{'med', 'shore'}, ['shore']],
#   [{'climate', 'south'}, ['climate']],
#   [{'Spain', 'tomatoes'}, ['tomatoes']],
#   [{'Italy', 'grain'}, ['grain']],
#   [{'France', 'grapes'}, ['grapes']],
#   [{'Greece', 'olives'}, ['olives']],
#   [{'Europe'}, ['Europe']],
#   [{'million', 'refugees'}, ['refugees']],
#   [{'EU', 'be', 'it', 'what'}, ['EU']],
#   [{'s'}, ['s']],
#   [{'rules'}, ['rules']],
#   [{'2040'}, ['2040']]],
#  [[{'People'}, ['People']],
#   [{'Greece', 'moment'}, ['Greece']],
#   [{'I'}, ['I']],
#   [{'defending', 'it'}, ['defending']],
#   [{'they'}, ['they']],
#   [{'immigrants'}, ['immigrants']],
#   [{'ocean'}, ['ocean']],
#   [{'them'}, ['them']],
#   [{'nation'}, ['nation']],
#   [{'burden'}, ['burden']],
#   [{'world'}, ['world']],
#   [{'Obama'}, ['Obama']],
#   [{'Libya'}, ['Libya']]],
#  [[{'war'}, ['war']],
#   [{')', 'Erdogan', 'NATO', 'Turkey', 'part'}, ['Erdogan']],
#   [{'refugees'}, ['refugees']],
#   [{'country'}, ['country']],
#   [{'they'}, ['they']],
#   [{'Syrian'}, ['Syrian']],
#   [{'They'}, ['They']],
#   [{'Afghani', 'Iraqi', 'Somali'}, ['Afghani']],
#   [{'He'}, ['He']],
#   [{'refugees'}, ['refugees']],
#   [{'flood'}, ['flood']],
#   [{'Europe', 'Greece'}, ['Greece']],
#   [{'They'}, ['They']],
#   [{'gas', 'guns'}, ['guns']]],
#  [[{'Commissioners', 'greece', 'visit'}, ['visit']],
#   [{'challenges', 'issues', 'protection'}, ['challenges']],
#   [{'access',
#     'asylum',
#     'conditions',
#     'covid',
#     'integration',
#     'islands',
#     'living',
#     'mainland',
#     'management',
#     'response',
#     'territory'},
#    ['access']]],
#  [[{'news', 'update'}, ['update']],
#   [{'child'}, ['child']],
#   [{'europe', 'fates'}, ['fates']],
#   [{'article'}, ['article']],
#   [{'europe'}, ['europe']]],
#  [[{'family'}, ['family']],
#   [{'Greece', 'Lithuania'}, ['Greece']],
#   [{'factory'}, ['factory']]],
#  [[{'this'}, ['this']],
#   [{'it'}, ['it']],
#   [{'Greek'}, ['Greek']],
#   [{'It'}, ['It']],
#   [{'Greece'}, ['Greece']],
#   [{'Refugees', 'boats', 'hole'}, ['hole']],
#   [{'Refugees', 'money', 'stolen'}, ['Refugees']]],
#  [[{'kids'}, ['kids']],
#   [{'school'}, ['school']],
#   [{'have', 'things', 'time'}, ['time']],
#   [{'SOS'}, ['SOS']],
#   [{'childcare'}, ['childcare']],
#   [{'families', 'struggling'}, ['families']],
#   [{'carers'}, ['carers']],
#   [{'work'}, ['work']],
#   [{'more'}, ['more']],
#   [{'work'}, ['work']],
#   [{'Lesvos', 'camp'}, ['camp']]],
#  [[{'million', 'refugees', 'then'}, ['refugees']],
#   [{'you'}, ['you']],
#   [{'them'}, ['them']],
#   [{'I'}, ['I']],
#   [{'they'}, ['they']],
#   [{'Turkey', 'better', 'conditions'}, ['conditions']],
#   [{'Greece'}, ['Greece']]],
#  [[{'greece', 'people'}, ['greece']],
#   [{'hospitality'}, ['hospitality']],
#   [{'100', '2015', 'migrants', 'refugees', 'thousands'}, ['100']],
#   [{'lot'}, ['lot']],
#   [{'needs'}, ['needs']],
#   [{'conditions'}, ['conditions']],
#   [{'islands'}, ['islands']],
#   [{'We'}, ['We']],
#   [{'solidarity'}, ['solidarity']],
#   [{'States', 'eu'}, ['States']]],
#  [[{'Wales'}, ['Wales']],
#   [{'Island', 'Portugal', 'list', 'parts'}, ['Portugal']],
#   [{'England'}, ['England']],
#   [{'Covid', 'chaos', 'covid'}, ['covid']],
#   [{'camps', 'fears', 'sparks'}, ['sparks']],
#   [{'Lesbos'}, ['Lesbos']]],
#  [[{'all', 'this'}, ['all']],
#   [{'one'}, ['one']],
#   [{'islands', 'refugees'}, ['refugees']],
#   [{'19', 'covid'}, ['covid']],
#   [{'action'}, ['action']],
#   [{'email'}, ['email']],
#   [{'@primeministergr', 'Minister', 'greece'}, ['Minister']],
#   [{'coronavirus'}, ['coronavirus']]],
#  [[{'!!!!', 'attention'}, ['attention']],
#   [{'immigrant'}, ['immigrant']],
#   [{'market'}, ['market']],
#   [{'soufli'}, ['soufli']],
#   [{'greece'}, ['greece']],
#   [{'@akrokentrwos'}, ['@akrokentrwos']]],
#  [[{'.', 'food', 'give', 'impression', 'moria', 'photo'}, ['photo']],
#   [{'it'}, ['it']],
#   [{'charge'}, ['charge']],
#   [{'month'}, ['month']]],
#  [[{'You'}, ['You']],
#   [{'factions'}, ['factions']],
#   [{'melt'}, ['melt']],
#   [{'them'}, ['them']],
#   [{'Greece'}, ['Greece']],
#   [{'enoug', 'fu'}, ['enoug']],
#   [{'Assad', 'him', 'realtionship'}, ['Assad']],
#   [{'mess'}, ['mess']],
#   [{'EU'}, ['EU']],
#   [{'it'}, ['it']],
#   [{'refugees'}, ['refugees']]],
#  [[{'moria'}, ['moria']],
#   [{'strike'}, ['strike']],
#   [{'place'}, ['place']],
#   [{'refugees'}, ['refugees']],
#   [{'food', 'made', 'supply'}, ['supply']],
#   [{'it', 'quality'}, ['quality']],
#   [{'.', 'bad', 'it', 'private', 'public', 'supplied', 'venture'},
#    ['supplied']],
#   [{'behind', 'leaver', 'one'}, ['leaver']]],
#  [[{'you'}, ['you']],
#   [{'Giannis', 'story'}, ['Giannis']],
#   [{'He'}, ['He']],
#   [{'nothing'}, ['nothing']],
#   [{'he'}, ['he']],
#   [{'17'}, ['17']],
#   [{'he'}, ['he']],
#   [{'Greece'}, ['Greece']],
#   [{'Athens', 'embassy'}, ['embassy']],
#   [{'him'}, ['him']],
#   [{'passport'}, ['passport']],
#   [{'parents'}, ['parents']],
#   [{'Nigeria'}, ['Nigeria']],
#   [{'refugees'}, ['refugees']],
#   [{'Greece'}, ['Greece']],
#   [{'him'}, ['him']],
#   [{'one'}, ['one']],
#   [{'Nigeria'}, ['Nigeria']],
#   [{'they'}, ['they']]],
#  [[{'Greece'}, ['Greece']],
#   [{'0', 'solidarity'}, ['solidarity']],
#   [{'0', 'refugees', 'seekers'}, ['0']],
#   [{'There'}, ['There']],
#   [{'addressing', 'gaps', 'issues', 'need'}, ['gaps']],
#   [{'States'}, ['States']],
#   [{'solidarity'}, ['solidarity']],
#   [{'seekers'}, ['seekers']],
#   [{'situation'}, ['situation']]],
#  [[{'EU'}, ['EU']],
#   [{'2', 'Assad'}, ['Assad']],
#   [{'you'}, ['you']],
#   [{'anything', 'colonialism', 'else', 'takes', 'that', 'wars'}, ['wars']],
#   [{'way'}, ['way']],
#   [{'%', '15', 'Greece', 'less', 'refugees'}, ['%']],
#   [{'Syria'}, ['Syria']]],
#  [[{'covid', 'st'}, ['st']],
#   [{'case', 'confirmed', 'moria'}, ['confirmed']],
#   [{'days'}, ['days']],
#   [{'coronavirus'}, ['coronavirus']],
#   [{'camp'}, ['camp']],
#   [{'consequences'}, ['consequences']],
#   [{'We'}, ['We']],
#   [{'FUNDS'}, ['FUNDS']],
#   [{'doors'}, ['doors']],
#   [{'equipment', 'medication', 'purchase'}, ['purchase']]],
#  [[{'refugee'}, ['refugee']],
#   [{'quarantine'}, ['quarantine']],
#   [{'coronavirus', 'infected', 'migrant'}, ['migrant']]],
#  [[{'Europe', 'fact', 'find', 'immigration', 'member', 'passage'}, ['fact']],
#   [{'you'}, ['you']],
#   [{'members'}, ['members']],
#   [{'Portugal'}, ['Portugal']],
#   [{'Greece'}, ['Greece']],
#   [{'and', 'example'}, ['example']]],
#  [[{'you'}, ['you']],
#   [{'greeks'}, ['greeks']],
#   [{'I'}, ['I']],
#   [{'t'}, ['t']],
#   [{'shit'}, ['shit']],
#   [{'anyone', 'them'}, ['anyone']],
#   [{'I'}, ['I']],
#   [{'Greece', 'greeks', 'living', 'refugees', 'traitors'}, ['greeks']]],
#  [[{'There'}, ['There']],
#   [{'2', 'addressed', 'issues', 'need'}, ['issues']],
#   [{'-@RaoufMazou',
#     '@refugees',
#     'Islands',
#     'conditions',
#     'facilities',
#     'reduce',
#     'solidarity'},
#    ['conditions']]],
#  [[{'Greece', 'people'}, ['Greece']],
#   [{'compassion', 'solidarity'}, ['solidarity']],
#   [{'refugees', 'seekers', 'thousands'}, ['thousands']],
#   [{'challenges', 'country', 'faced'}, ['challenges']],
#   [{'19', 'COVID', 'crisis', 'pandemic-@RaoufMazou'}, ['crisis']]],
#  [[{'COVID', 'Camp', 'GREECE', 'Locked', 'greece'}, ['Camp']]],
#  [[{'Britain'}, ['Britain']],
#   [{'applications', 'less'}, ['applications']],
#   [{'country'}, ['country']],
#   [{'France', 'Germany', 'Greece'}, ['Germany']],
#   [{'hell', 'lot'}, ['hell']]],
#  [[{'fight', 'hope', 'states'}, ['fight']],
#   [{'people'}, ['people']],
#   [{'asylum'}, ['asylum']],
#   [{'countries'}, ['countries']],
#   [{'this'}, ['this']],
#   [{'sea'}, ['sea']],
#   [{'migrants'}, ['migrants']]],
#  [[{'idea', 'overwhelmed', 'uk'}, ['idea']],
#   [{'dogshite'}, ['dogshite']],
#   [{'%', 'refugees', 'world'}, ['%']],
#   [{'countries'}, ['countries']],
#   [{'fled', 'one'}, ['one']],
#   [{'uk'}, ['uk']],
#   [{'3', 'applications', 'less'}, ['applications']],
#   [{'France'}, ['France']],
#   [{'x'}, ['x']],
#   [{'Germany'}, ['Germany']],
#   [{'Greece', 'Spain', 'less', 'x'}, ['less']],
#   [{'it'}, ['it']]],
#  [[{'Greece'}, ['Greece']],
#   [{'immigrants', 'majority'}, ['majority']],
#   [{'Afghanistan', 'Bagladesh', 'Pakistan'}, ['Pakistan']],
#   [{'It'}, ['It']],
#   [{'catch', 'member'}, ['catch']],
#   [{'Spain'}, ['Spain']],
#   [{'Greece'}, ['Greece']],
#   [{'Europe'}, ['Europe']],
#   [{'danger'}, ['danger']]],
#  [[{'Lesbos', 'camps', 'case', 'development', 'fears', 'sant', 'sparks'},
#    ['sparks']]],
#  [[{'I'}, ['I']],
#   [{'America', 'm', 'many'}, ['m']],
#   [{'Greeks'}, ['Greeks']],
#   [{'westerners'}, ['westerners']],
#   [{'culture'}, ['culture']],
#   [{'heritage', 'history'}, ['history']],
#   [{'theirs'}, ['theirs']],
#   [{'immigrants', 't'}, ['t']],
#   [{'culture'}, ['culture']],
#   [{'Greece', 'countries', 'suffered', 'supremacy'}, ['suffered']]],
#  [[{'You'}, ['You']],
#   [{'Greece'}, ['Greece']],
#   [{'called', 'gates', 'refugees'}, ['gates']],
#   [{'them'}, ['them']]],
#  [[{'you'}, ['you']],
#   [{'Greeks', 'Turkey', 'ask', 'asylum', 'go'}, ['Greeks']],
#   [{'answer'}, ['answer']],
#   [{'Greece', 'Turks', 'ask', 'asylum', 'come', 'day', 'thousands'},
#    ['thousands']],
#   [{'Turkey'}, ['Turkey']]],
#  [[{'Greece', 'minors', 'shelter'}, ['shelter']],
#   [{'News', 'outbreak'}, ['outbreak']]],
#  [[{'asylum', 'covid', 'measures'}, ['measures']],
#   [{'refugees', 'seekers'}, ['seekers']],
#   [{'lesbos'}, ['lesbos']],
#   [{'people'}, ['people']],
#   [{'hell'}, ['hell']]],
#  [[{'thing'}, ['thing']],
#   [{'borders', 'closed', 'country', 'it', 'stop'}, ['closed']],
#   [{'It'}, ['It']],
#   [{'spread'}, ['spread']],
#   [{'History'}, ['History']],
#   [{'Sanitaire', 'more'}, ['Sanitaire']],
#   [{')', 'Caribbean', 'Florida', 'Mexico', 'TX', 'migrants', 'ups'}, ['ups']],
#   [{'Greece'}, ['Greece']],
#   [{'1', 'Spain', 'closing', 'etc'}, ['closing']],
#   [{'facts'}, ['facts']],
#   [{'stateme'}, ['stateme']]],
#  [[{'I'}, ['I']],
#   [{'fieldwork'}, ['fieldwork']],
#   [{'2008', 'summer', 'zmir'}, ['zmir']],
#   [{'refugees'}, ['refugees']],
#   [{'me'}, ['me']],
#   [{'experiences'}, ['experiences']],
#   [{'sea'}, ['sea']],
#   [{'There'}, ['There']],
#   [{'migrants'}, ['migrants']],
#   [{'Greece', 'agreement', 'experience', 'had'}, ['agreement']]],
#  [[{'i'}, ['i']],
#   [{'Islands'}, ['Islands']],
#   [{'WINTER'}, ['WINTER']],
#   [{'EU'}, ['EU']],
#   [{'beaches', 'migrants', 'you'}, ['beaches']],
#   [{'EU'}, ['EU']],
#   [{'boats', 'crossing', 'sea'}, ['crossing']],
#   [{'Channel', 'greece'}, ['greece']],
#   [{'they'}, ['they']],
#   [{'nothing'}, ['nothing']]],
#  [[{'This'}, ['This']],
#   [{'Appeal', 'Hope', 'Kindness', 'supported', 'year'}, ['year']],
#   [{'All', 'money'}, ['All']],
#   [{'babies', 'camps', 'nappies'}, ['nappies']],
#   [{'greece'}, ['greece']],
#   [{'Donations'}, ['Donations']],
#   [{'baby', 'comfort', 'mother'}, ['mother']],
#   [{'five', 'hope'}, ['five']]],
#  [[{'.', 'island', 'lesvos', 'numbers', 'refugees', 'reside'}, ['lesvos']],
#   [{'Majority'}, ['Majority']],
#   [{'%', ')', 'Republic', 'afghanistan', 'congo', 'syria'}, ['afghanistan']],
#   [{'Women'}, ['Women']],
#   [{'%'}, ['%']],
#   [{'%',
#     '10',
#     '7',
#     'children',
#     'more',
#     'old',
#     'population',
#     'whom',
#     'years',
#     'younger'},
#    ['population']],
#   [{'1'}, ['1']]],
#  [[{'we'}, ['we']],
#   [{'it', 'least', 'need', 'people', 'responsibility', 'some', 'take'},
#    ['responsibility']],
#   [{'line', 'reasoning'}, ['line']],
#   [{',', 'Greece', 'Italy', 'countries'}, ['Italy']],
#   [{'fair', 'refugees', 'seems'}, ['refugees']]],
#  [[{'Athens', 'time'}, ['time']],
#   [{'boat'}, ['boat']],
#   [{'acting', 'continent', 'perceived', 'result'}, ['result']],
#   [{'self-interest'}, ['self-interest']]],
#  [[{'19', 'COVID'}, ['COVID']],
#   [{'Greece'}, ['Greece']],
#   [{'camp', 'case'}, ['case']],
#   [{'Lesbos'}, ['Lesbos']]],
#  [[{'.', 'kil', 'militans'}, ['kil']],
#   [{'.', 'immigrants'}, ['immigrants']],
#   [{'.', 'greece'}, ['greece']]],
#  [[{'conflicts', 'diseases', 'migrations'}, ['conflicts']],
#   [{'That', 'region', 's'}, ['s']],
#   [{'EIT'}, ['EIT']],
#   [{'we'}, ['we']],
#   [{'problem'}, ['problem']],
#   [{'challenge', 'ideas', 'labs'}, ['ideas']],
#   [{'event'}, ['event']],
#   [{'PM', 'september'}, ['september']]],
#  [[{'migrants', 'million'}, ['migrants']],
#   [{'turkey'}, ['turkey']],
#   [{'Greece'}, ['Greece']],
#   [{'do', 'mile', 'needs', 'territory', 'turkey'}, ['territory']],
#   [{'them'}, ['them']],
#   [{'sea'}, ['sea']],
#   [{'they'}, ['they']],
#   [{'EU', 'areas'}, ['EU']]],
#  [[{'people'}, ['people']],
#   [{'borders'}, ['borders']],
#   [{'you'}, ['you']],
#   [{'them'}, ['them']],
#   [{'thousands'}, ['thousands']],
#   [{'Greece'}, ['Greece']],
#   [{'didn', 'game', 't'}, ['didn']],
#   [{'animals', 'manipulating', 'refuges'}, ['animals']]],
#  [[{'case'}, ['case']],
#   [{'Lesbos', 'camp'}, ['camp']],
#   [{'people'}, ['people']],
#   [{'@scwacy'}, ['@scwacy']]],
#  [[{'I'}, ['I']],
#   [{'Aegean', 'go', 'thing', 'want'}, ['thing']],
#   [{'Greece'}, ['Greece']],
#   [{'aegean', 'eez', 'kastelorizo'}, ['eez']],
#   [{'case', 'history'}, ['case']],
#   [{'Greece'}, ['Greece']],
#   [{'Turkey', 'it', 'refuge'}, ['refuge']],
#   [{'This'}, ['This']],
#   [{'truth'}, ['truth']]],
#  [[{'Eedogan'}, ['Eedogan']],
#   [{'militants'}, ['militants']],
#   [{'terrorists'}, ['terrorists']],
#   [{'he'}, ['he']],
#   [{'card'}, ['card']],
#   [{'threat', 'way'}, ['way']],
#   [{'Europe'}, ['Europe']],
#   [{'he'}, ['he']],
#   [{'immigrants'}, ['immigrants']],
#   [{'europe', 'greece'}, ['greece']],
#   [{'death'}, ['death']],
#   [{'them'}, ['them']],
#   [{'years'}, ['years']],
#   [{'I'}, ['I']],
#   [{'Muslims'}, ['Muslims']]],
#  [[{'Greece'}, ['Greece']],
#   [{'refugees', 'thousand'}, ['refugees']],
#   [{'million', 'population'}, ['population']],
#   [{'border'}, ['border']],
#   [{'it'}, ['it']],
#   [{'country', 'million'}, ['country']],
#   [{'God'}, ['God']],
#   [{'I'}, ['I']],
#   [{'fool', 'you'}, ['fool']],
#   [{'life'}, ['life']],
#   [{'problem'}, ['problem']],
#   [{'idiots', 'you'}, ['you']]],
#  [[{'Europe'}, ['Europe']],
#   [{'Greece'}, ['Greece']],
#   [{'there'}, ['there']],
#   [{'lots'}, ['lots']],
#   [{'boats'}, ['boats']],
#   [{'you'}, ['you']],
#   [{'all', 'fishy', 'thing'}, ['fishy']]],
#  [[{'I'}, ['I']],
#   [{'Iraq'}, ['Iraq']],
#   [{'Europe'}, ['Europe']],
#   [{'migrants'}, ['migrants']],
#   [{'Greece'}, ['Greece']],
#   [{'Germany', 'Norway', 'sweden'}, ['Norway']],
#   [{'I'}, ['I']],
#   [{'you'}, ['you']],
#   [{'same'}, ['same']],
#   [{'Iraq'}, ['Iraq']],
#   [{'Greece'}, ['Greece']],
#   [{'life', 'migrant'}, ['life']],
#   [{'thogh'}, ['thogh']],
#   [{'camps'}, ['camps']],
#   [{'government'}, ['government']],
#   [{'you'}, ['you']],
#   [{'refugee'}, ['refugee']]],
#  [[{'news'}, ['news']],
#   [{'Migrants', 'quarantine'}, ['Migrants']],
#   [{'Moria'}, ['Moria']],
#   [{'Lesbos'}, ['Lesbos']]],
#  [[{'you'}, ['you']],
#   [{'judges', 'lawyers', 'lot', 'officers', 'people', 'servants', 'teachers'},
#    ['lot']],
#   [{'jail'}, ['jail']],
#   [{')', 'Europe', 'Greece', 'as', 'asylum'}, ['asylum']],
#   [{'Erdogan'}, ['Erdogan']],
#   [{'warmongering'}, ['warmongering']],
#   [{'comparisons'}, ['comparisons']]],
#  [[{'.', 'late', 'learned', 'shame'}, ['shame']],
#   [{'Europe'}, ['Europe']],
#   [{'place', 'plans'}, ['plans']],
#   [{'start'}, ['start']],
#   [{'They'}, ['They']],
#   [{'Africa',
#     'East',
#     'allowing',
#     'endgame',
#     'migration',
#     'unchecked',
#     'unmitigated'},
#    ['endgame']]],
#  [[{'bosses'}, ['bosses']],
#   [{'Francois', 'Roger'}, ['Roger']],
#   [{'1984', 'kidnapping', 'loive', 'rene'}, ['1984']],
#   [{'bosses'}, ['bosses']],
#   [{'they'}, ['they']],
#   [{'e', 'jeer', 'kidnap', 'pay'}, ['kidnap']],
#   [{'BY', 'cheese', 'club', 'deliveries', 'jumbo'}, ['cheese']]],
#  [[{'they'}, ['they']],
#   [{'5', 'countries'}, ['countries']],
#   [{'right'}, ['right']],
#   [{'U.K.', 'asylum', 'whats', 'wrong'}, ['asylum']],
#   [{'Greece'}, ['Greece']]],
#  [[{'EU'}, ['EU']],
#   [{'BORDERS'}, ['BORDERS']],
#   [{'Covid'}, ['Covid']],
#   [{'case'}, ['case']],
#   [{'Lesbos', 'camps', 'fears'}, ['fears']]],
#  [[{'sir'}, ['sir']],
#   [{'you'}, ['you']],
#   [{'Greece', 'holiday'}, ['holiday']],
#   [{'$', '700'}, ['$']],
#   [{'day'}, ['day']],
#   [{'$', 'salary', 'see', 'top', 'what'}, ['top']],
#   [{'Geneva', 'host', 'refugees'}, ['Geneva']],
#   [{'you'}, ['you']]],
#  [[{'famous', 'for', 'thing'}, ['thing']], [{'refugees'}, ['refugees']]],
#  [[{'NYT', 'claims'}, ['claims']],
#   [{'Greece'}, ['Greece']],
#   [{'camps', 'people'}, ['people']],
#   [{'land'}, ['land']],
#   [{'them'}, ['them']],
#   [{'Turkey', 'all', 'boats', 'coming', 'doing'}, ['boats']],
#   [{'Source'}, ['Source']],
#   [{')', 'HRW', 'NGOs', 'claim'}, ['claim']],
#   [{'claim'}, ['claim']],
#   [{'military', 'woman'}, ['military']]],
#  [[{'names'}, ['names']],
#   [{'Afganistan', 'Im', 'Mujtaba'}, ['Mujtaba']],
#   [{'home'}, ['home']],
#   [{'family'}, ['family']],
#   [{'safety'}, ['safety']],
#   [{'I'}, ['I']],
#   [{'Greece', 'camp'}, ['camp']],
#   [{'Im'}, ['Im']],
#   [{'others', 'thousands'}, ['thousands']],
#   [{'access'}, ['access']]],
#  [[{'No-one'}, ['No-one']],
#   [{'issues'}, ['issues']],
#   [{'refugees'}, ['refugees']],
#   [{'Those', 'coming', 'dinghy'}, ['Those']],
#   [{'They'}, ['They']],
#   [{'SAFE'}, ['SAFE']],
#   [{'France'}, ['France']],
#   [{'asylum'}, ['asylum']],
#   [{'Greece', 'Italy', 'Spain'}, ['Italy']],
#   [{'they'}, ['they']],
#   [{'any', 'countries'}, ['any']],
#   [{'they'}, ['they']]],
#  [[{'Anastasa', 'Sikiaridi'}, ['Anastasa']],
#   [{'experience'}, ['experience']],
#   [{'integration', 'women'}, ['integration']],
#   [{'Camps'}, ['Camps']],
#   [{'men'}, ['men']],
#   [{'connector'}, ['connector']]],
#  [[{'Countries', 'Greece', 'Hungary', 'borders', 'have'}, ['Countries']],
#   [{'barriers'}, ['barriers']],
#   [{'others'}, ['others']],
#   [{'country'}, ['country']],
#   [{'problem'}, ['problem']],
#   [{'we'}, ['we']],
#   [{'rescued', 'ship', 'those'}, ['those']],
#   [{'them'}, ['them']]],
#  [[{'GdnDevelopment'}, ['GdnDevelopment']],
#   [{'Lesbos', 'camps', 'case', 'fears', 'sparks'}, ['sparks']]],
#  [[{'Greece', 'Hungary', 'Poland'}, ['Hungary']],
#   [{'something'}, ['something']]],
#  [[{'IRC'}, ['IRC']],
#   [{'evacuation', 'refugees', 'vulnerable'}, ['evacuation']],
#   [{'case'}, ['case']],
#   [{'Moria'}, ['Moria']]],
#  [[{'France', 'Greece', 'etc'}, ['France']],
#   [{'English'}, ['English']],
#   [{'know', 'language'}, ['language']],
#   [{'chance', 'integrating', 'process', 'understanding'}, ['chance']]],
#  [[{'I'}, ['I']],
#   [{'seekers'}, ['seekers']],
#   [{'that'}, ['that']],
#   [{'we'}, ['we']],
#   [{'them'}, ['them']],
#   [{'all'}, ['all']],
#   [{'they'}, ['they']],
#   [{'France', 'Greece', 'etc'}, ['France']],
#   [{'Im'}, ['Im']],
#   [{'contribute', 'have', 'offer', 'ones', 'something', 'want'}, ['ones']],
#   [{'rest'}, ['rest']]],
#  [[{'Covid'}, ['Covid']],
#   [{'sparks'}, ['sparks']],
#   [{'fears'}, ['fears']],
#   [{'Lesbos'}, ['Lesbos']]],
#  [[{'I'}, ['I']],
#   [{'Greece'}, ['Greece']],
#   [{'Birmingham', 'immigrant'}, ['immigrant']],
#   [{'thats'}, ['thats']],
#   [{'side'}, ['side']],
#   [{'you'}, ['you']],
#   [{'5'}, ['5']],
#   [{'UK'}, ['UK']],
#   [{'entrance'}, ['entrance']],
#   [{'hundreds', 'thousands'}, ['hundreds']],
#   [{'M', 'country', 'people'}, ['country']]],
#  [[{'.',
#     'camps',
#     'children',
#     'eu',
#     'families',
#     'moria',
#     'overcrowded',
#     'policies',
#     'trap',
#     'unsanitary'},
#    ['trap']],
#   [{'EU', 'Greece'}, ['Greece']],
#   [{'system'}, ['system']],
#   [{'it'}, ['it']],
#   [{'people'}, ['people']],
#   [{'safety'}, ['safety']]],
#  [[{'case'}, ['case']], [{'Lesbos', 'camps', 'fears'}, ['fears']]],
#  [[{'Greece'}, ['Greece']],
#   [{'camp', 'lockdown'}, ['lockdown']],
#   [{'COVID', 'case'}, ['COVID']]],
#  [[{'it'}, ['it']],
#   [{'country'}, ['country']],
#   [{'UK'}, ['UK']],
#   [{'them'}, ['them']],
#   [{'all'}, ['all']],
#   [{'Greece', 'Italy', 'camps'}, ['camps']],
#   [{'we'}, ['we']],
#   [{'t'}, ['t']],
#   [{'routes'}, ['routes']],
#   [{'refugees'}, ['refugees']],
#   [{'asylum'}, ['asylum']],
#   [{'you'}, ['you']],
#   [{'migrants'}, ['migrants']],
#   [{'you'}, ['you']],
#   [{'them'}, ['them']]],
#  [[{'19', 'covid'}, ['covid']],
#   [{'camps', 'fears', 'lesbos', 'sparks'}, ['fears']],
#   [{'government'}, ['government']],
#   [{'need'}, ['need']],
#   [{'closed', 'controlled', 'structures'}, ['structures']],
#   [{'os'}, ['os']],
#   [{'virus'}, ['virus']],
#   [{'pretext', 'restrictions', 'rights'}, ['pretext']]],
#  [[{'migrants', 'total'}, ['total']],
#   [{'Greece'}, ['Greece']],
#   [{'Germany'}, ['Germany']],
#   [{'transfer'}, ['transfer']],
#   [{'part'}, ['part']],
#   [{'children', 'hundreds', 'members'}, ['hundreds']],
#   [{'camps', 'islands'}, ['camps']],
#   [{'pandemic'}, ['pandemic']]],
#  [[{'Greece'}, ['Greece']],
#   [{'billion', 'euros'}, ['euros']],
#   [{'refugees'}, ['refugees']],
#   [{'you'}, ['you']],
#   [{'that'}, ['that']],
#   [{'none'}, ['none']],
#   [{'you'}, ['you']],
#   [{'amount', 'eat', 'look', 'need', 'photos'}, ['photos']]],
#  [[{'turkey'}, ['turkey']],
#   [{'haven', 'israels'}, ['haven']],
#   [{'israel', 'terrorists', 'trade'}, ['terrorists']],
#   [{'greece'}, ['greece']],
#   [{'handed', 'protestors', 'tactics'}, ['tactics']],
#   [{'control', 'media'}, ['control']],
#   [{'europe'}, ['europe']],
#   [{'migrants'}, ['migrants']]],
#  [[{'latest'}, ['latest']],
#   [{'case'}, ['case']],
#   [{'refugee'}, ['refugee']],
#   [{',', '3,000', 'Lesbos', 'camp', 'designed', 'living', 'people', 'space'},
#    ['camp']],
#   [{'fears'}, ['fears']],
#   [{'government'}, ['government']],
#   [{'pandemic'}, ['pandemic']],
#   [{'camps', 'create', 'pretext'}, ['pretext']]],
#  [[{'This'}, ['This']],
#   [{'Italy', 'Marche', 'South', 'Umbria', 'places'}, ['places']],
#   [{'fluxes'}, ['fluxes']],
#   [{'East'}, ['East']],
#   [{'Rome', 'city'}, ['city']],
#   [{'Greece', 'Italy'}, ['Italy']],
#   [{'Italy', 'Tuscany'}, ['Tuscany']]],
#  [[{'I'}, ['I']],
#   [{'Greece'}, ['Greece']],
#   [{'refugees'}, ['refugees']],
#   [{'I'}, ['I']],
#   [{'camps'}, ['camps']],
#   [{'situation'}, ['situation']],
#   [{'you'}, ['you']],
#   [{'country', 'destroying', 'few', 'people', 'saying'}, ['people']]],
#  [[{'we'}, ['we']],
#   [{'Greece'}, ['Greece']],
#   [{'keep',
#     'lot',
#     'money',
#     'more',
#     'rocking',
#     'safe',
#     'seekers',
#     'there',
#     'transit'},
#    ['money']],
#   [{'refugees'}, ['refugees']],
#   [{'Greece'}, ['Greece']],
#   [{'they'}, ['they']],
#   [{'UK'}, ['UK']],
#   [{'I'}, ['I']],
#   [{'blame'}, ['blame']],
#   [{'Greece'}, ['Greece']],
#   [{'bunch'}, ['bunch']],
#   [{'way'}, ['way']]],
#  [[{'mercenaries'}, ['mercenaries']],
#   [{'populations'}, ['populations']],
#   [{'wars'}, ['wars']],
#   [{'Erdogan', 'Recep', 'militaristic', 'regime'}, ['regime']],
#   [{'Hamas'}, ['Hamas']],
#   [{'France',
#     'Greece',
#     'Iraq',
#     'Israel',
#     'States',
#     'Syria',
#     'agenda',
#     'and',
#     'seen',
#     'threaten'},
#    ['agenda']]],
#  [[{'candidate_to_be_removed'}, ['candidate_to_be_removed']]],
#  [[{'there'}, ['there']],
#   [{'issue'}, ['issue']],
#   [{'coming', 'lybia', 'migrants'}, ['migrants']],
#   [{'Greece', 'Italy', 'Malta', 'second', 'waters'}, ['waters']],
#   [{'point'}, ['point']],
#   [{'.', 'Turkey', 'all', 'threat'}, ['threat']]],
#  [[{'Greece'}, ['Greece']],
#   [{'Mr', 'Stoltenberg'}, ['Mr']],
#   [{'They'}, ['They']],
#   [{'him'}, ['him']],
#   [{'they'}, ['they']],
#   [{'negotiations'}, ['negotiations']],
#   [{'they'}, ['they']],
#   [{'that'}, ['that']],
#   [{'country'}, ['country']],
#   [{'existence'}, ['existence']],
#   [{'dependend', 'money'}, ['dependend']],
#   [{'EU'}, ['EU']],
#   [{'people'}, ['people']],
#   [{'refuge'}, ['refuge']],
#   [{'Turkey'}, ['Turkey']],
#   [{'HAHAHA'}, ['HAHAHA']]],
#  [[{'me'}, ['me']],
#   [{'seekers'}, ['seekers']],
#   [{'France', 'Germany', 'Greece', 'countries', 'systems'}, ['systems']],
#   [{'Details'}, ['Details']],
#   [{'interested', 'know', 'systems'}, ['interested']],
#   [{'discriminate'}, ['discriminate']]],
#  [[{'19', '@PerilOfAfrica'}, ['@PerilOfAfrica']],
#   [{'camp', 'case'}, ['case']],
#   [{'ATHENS', 'Greece', 'Reuters', 'Sept'}, ['ATHENS']],
#   [{'case'}, ['case']],
#   [{'Moria', 'camp'}, ['camp']],
#   [{'Lesbos', 'island', 'the'}, ['island']]],
#  [[{'brought', 'channels', 'refugees', 's', 'said', 'what'}, ['s']],
#   [{'you'}, ['you']],
#   [{'what'}, ['what']],
#   [{'s'}, ['s']],
#   [{'Germany', 'Greece'}, ['Germany']],
#   [{'asylum', 'countries', 'don', 'passed', 't'}, ['asylum']],
#   [{'criminals'}, ['criminals']]],
#  [[{'Greece'}, ['Greece']], [{'refugees'}, ['refugees']]],
#  [[{'people'}, ['people']],
#   [{'this'}, ['this']],
#   [{'you'}, ['you']],
#   [{'policies'}, ['policies']],
#   [{')', 'east', 'libya', 'med', 'turkey'}, ['med']],
#   [{'europe', 'matter'}, ['matter']],
#   [{'you'}, ['you']],
#   [{'britherhood', 'expansionism', 'political'}, ['expansionism']]],
#  [[{'Greece', 'Italy', 'Spain'}, ['Spain']],
#   [{'U.K.', 'asylum'}, ['asylum']],
#   [{'channels'}, ['channels']],
#   [{'there'}, ['there']],
#   [{'U.K.',
#     'convince',
#     'everyone',
#     'people',
#     'routes',
#     'trafficking',
#     'willing'},
#    ['willing']],
#   [{'response'}, ['response']]],
#  [[{'I'}, ['I']],
#   [{'it'}, ['it']],
#   [{'scoop'}, ['scoop']],
#   [{'countries'}, ['countries']],
#   [{'19', 'COVID'}, ['COVID']],
#   [{'refugees'}, ['refugees']],
#   [{'groups'}, ['groups']],
#   [{'pandemic'}, ['pandemic']],
#   [{'greece', 'italy'}, ['italy']],
#   [{'chance', 'crack', 'visitors'}, ['chance']]],
#  [[{'@MSF'}, ['@MSF']],
#   [{'attack', 'camp', 'clinic'}, ['attack']],
#   [{'Greece'}, ['Greece']],
#   [{'Lesvos'}, ['Lesvos']],
#   [{':', 'coordinator'}, ['coordinator']],
#   [{'in', 'live', 'world'}, ['live']],
#   [{'children', 'doctors', 'treated', 'women'}, ['treated']],
#   [{'them', 'throwing'}, ['throwing']]],
#  [[{'migrants'}, ['migrants']], [{'Greece'}, ['Greece']]],
#  [[{'i'}, ['i']],
#   [{'I'}, ['I']],
#   [{'languages'}, ['languages']],
#   [{'I'}, ['I']],
#   [{'documents'}, ['documents']],
#   [{'These'}, ['These']],
#   [{'figures', 'government'}, ['figures']],
#   [{'Refugee'}, ['Refugee']],
#   [{'EU'}, ['EU']],
#   [{'EU', 'French', 't'}, ['t']],
#   [{'it'}, ['it']],
#   [{'France'}, ['France']],
#   [{'they'}, ['they']],
#   [{'Greece', 'Italy', 'Spain'}, ['Greece']],
#   [{'countries'}, ['countries']]],
#  [[{'Here'}, ['Here']],
#   [{'numbers', 'seekers'}, ['numbers']],
#   [{'arent'}, ['arent']],
#   [{'populations'}, ['populations']],
#   [{'you'}, ['you']],
#   [{'UK'}, ['UK']],
#   [{'France', 'Germany', 'Spain', 'fraction', 'taken', 'those'}, ['fraction']],
#   [{'.', 'Greece'}, ['Greece']]],
#  [[{'UPDATE'}, ['UPDATE']],
#   [{'greece'}, ['greece']],
#   [{'Athens', 'camp'}, ['camp']],
#   [{'covid'}, ['covid']],
#   [{'outbreak'}, ['outbreak']],
#   [{'updates'}, ['updates']]],
#  [[{'seekers'}, ['seekers']],
#   [{'France', 'Germany', 'Greece', 'Spain', 'UK'}, ['Germany']]],
#  [[{'you'}, ['you']],
#   [{'death'}, ['death']],
#   [{'unemployment'}, ['unemployment']],
#   [{'crossings'}, ['crossings']],
#   [{'Turkey', 'million', 'refugees'}, ['refugees']],
#   [{'greece'}, ['greece']],
#   [{'they'}, ['they']],
#   [{'you'}, ['you']],
#   [{'Greece', 'population'}, ['population']],
#   [{'million'}, ['million']],
#   [{'refugees'}, ['refugees']],
#   [{'million'}, ['million']],
#   [{'they'}, ['they']],
#   [{'workplaces'}, ['workplaces']]],
#  [[{'Europe'}, ['Europe']],
#   [{'countries', 'extremism', 'migration'}, ['countries']],
#   [{'ppl', 's'}, ['ppl']],
#   [{'point', 'view'}, ['point']],
#   [{'Greece'}, ['Greece']],
#   [{'culture', 'heritage', 'part', 'protection', 'worthy'}, ['part']]],
#  [[{'statement'}, ['statement']],
#   [{'Ugandans'}, ['Ugandans']],
#   [{'passports'}, ['passports']],
#   [{'issue'}, ['issue']],
#   [{'Patel', 'Priti'}, ['Priti']],
#   [{'France',
#     'Germany',
#     'Greece',
#     'Italy',
#     'Spain',
#     'UK',
#     'come',
#     'cross',
#     'migrants',
#     'nations',
#     'such'},
#    ['migrants']]],
#  [[{'.'}, ['.']],
#   [{'everyone'}, ['everyone']],
#   [{'Greece'}, ['Greece']],
#   [{'they'}, ['they']],
#   [{'look', 'ocean', 'people', 'you'}, ['people']],
#   [{'them'}, ['them']],
#   [{'they'}, ['they']],
#   [{'passport', 'you'}, ['passport']],
#   [{'they'}, ['they']],
#   [{'immigrants'}, ['immigrants']]],
#  [[{':', 'strawberries', 'taste'}, ['taste']],
#   [{'exploitation', 'labour'}, ['exploitation']],
#   [{'8', 'greece'}, ['greece']],
#   [{'exporter', 'strawberries'}, ['exporter']],
#   [{'world'}, ['world']],
#   [{'exploitation'}, ['exploitation']]],
#  [[{'officials'}, ['officials']],
#   [{'Greece', 'paid', 'vacations'}, ['vacations']]],
#  [[{'Greece'}, ['Greece']], [{'greece', 'policy'}, ['policy']]],
#  [[{'10,000', 'migrants'}, ['migrants']],
#   [{'Greece'}, ['Greece']],
#   [{'authorities'}, ['authorities']],
#   [{'migrants', 'thousands'}, ['thousands']],
#   [{'Greece'}, ['Greece']],
#   [{'sea'}, ['sea']],
#   [{'cooperation', 'guard', 'lack'}, ['lack']],
#   [{'country', 'minister'}, ['minister']],
#   [{'Wed'}, ['Wed']]],
#  [[{'Questions'}, ['Questions']],
#   [{'Asylum'}, ['Asylum']],
#   [{'5', 'Greece'}, ['Greece']]],
#  [[{'demand', 'grounds', 'make'}, ['grounds']],
#   [{'.', 'France', 'hide', 'tourists'}, ['hide']],
#   [{'.', 'attack', 'boats', 'doesn'}, ['doesn']],
#   [{'branches'}, ['branches']],
#   [{'Greece'}, ['Greece']],
#   [{'reality'}, ['reality']]],
#  [[{'Matt'}, ['Matt']],
#   [{'we'}, ['we']],
#   [{'.', 'Gr'}, ['Gr']],
#   [{'Grandmother', 'knew'}, ['Grandmother']],
#   [{'Russia'}, ['Russia']],
#   [{'Greece'}, ['Greece']],
#   [{'Cyprus', 'Turkey', 'invaded'}, ['Cyprus']],
#   [{'family'}, ['family']],
#   [{'UK'}, ['UK']],
#   [{'wing'}, ['wing']],
#   [{'citizens', 'history', 'scapegoating'}, ['scapegoating']],
#   [{'I'}, ['I']],
#   [{'UK'}, ['UK']],
#   [{'Ill'}, ['Ill']],
#   [{'truth'}, ['truth']]],
#  [[{'F'}, ['F']],
#   [{'it'}, ['it']],
#   [{'asylum', 'uk'}, ['asylum']],
#   [{'convention'}, ['convention']],
#   [{'refugees'}, ['refugees']],
#   [{'they'}, ['they']],
#   [{'G'}, ['G']],
#   [{'uk'}, ['uk']],
#   [{'Yr', 'applications', 'fewer'}, ['applications']],
#   [{'Germany'}, ['Germany']],
#   [{'x'}, ['x']],
#   [{'France'}, ['France']],
#   [{'x'}, ['x']],
#   [{'Greece', 'Spain'}, ['Spain']]],
#  [[{'Moria', 'years'}, ['years']],
#   [{'same'}, ['same']],
#   [{'it'}, ['it']],
#   [{'.', 'Europe', 'conditions', 'hold', 'long', 'stain'}, ['stain']]],
#  [[{'you'}, ['you']],
#   [{'money'}, ['money']],
#   [{'Everyone'}, ['Everyone']],
#   [{'country'}, ['country']],
#   [{'it'}, ['it']],
#   [{'We'}, ['We']],
#   [{'ourselves'}, ['ourselves']],
#   [{'Africans'}, ['Africans']],
#   [{'Greece'}, ['Greece']],
#   [{'immigrants'}, ['immigrants']],
#   [{'middle', 'sea'}, ['middle']]],
#  [[{'candidate_to_be_removed'}, ['candidate_to_be_removed']]],
#  [[{'2', 'EU', 'countries', 'going', 'keep', 're', 'supporting'}, ['re']],
#   [{'Cyprus', 'Greece'}, ['Greece']],
#   [{'we'}, ['we']],
#   [{'EU'}, ['EU']],
#   [{'&', 'nothing'}, ['nothing']],
#   [{'you'}, ['you']],
#   [{'118', 'all', 'immigrants', 'them'}, ['all']]],
#  [[{'today'}, ['today']],
#   [{'19', 'COVID', 'camp', 'operation'}, ['operation']],
#   [{'EODY', 'health'}, ['health']],
#   [{'migrants', 'refugees', 'tests'}, ['tests']],
#   [{'Unit', 'camp', 'operates', 'vicinity'}, ['Unit']]],
#  [[{'This'}, ['This']],
#   [{'thing', 'though', 'you'}, ['thing']],
#   [{'This'}, ['This']],
#   [{'millions', 'refugees'}, ['millions']],
#   [{'flow'}, ['flow']],
#   [{'Greece'}, ['Greece']],
#   [{'dumbfuck'}, ['dumbfuck']]],
#  [[{'Cemeteries', 'Mediterranean', 'bodies'}, ['Cemeteries']],
#   [{'Tunisia',
#     'Turkey',
#     'bodies',
#     'family',
#     'lost',
#     'one',
#     'represents',
#     'searching'},
#    ['represents']],
#   [{'deaths'}, ['deaths']]],
#  [[{'I'}, ['I']],
#   [{'Greece'}, ['Greece']],
#   [{'Syrian', 'husband'}, ['husband']],
#   [{'He'}, ['He']],
#   [{'they'}, ['they']],
#   [{'me'}, ['me']],
#   [{'I'}, ['I']],
#   [{'guns', 'had', 'him', 'others', 'police'}, ['him']],
#   [{'them'}, ['them']],
#   [{'guns'}, ['guns']],
#   [{'seekers'}, ['seekers']],
#   [{'1'}, ['1']],
#   [{'/'}, ['/']]],
#  [[{'we'}, ['we']],
#   [{'Greece'}, ['Greece']],
#   [{'migrants'}, ['migrants']],
#   [{'sea'}, ['sea']]],
#  [[{'COVID', 'Camp', 'Case'}, ['COVID']],
#   [{'Greece'}, ['Greece']],
#   [{'Quarantine'}, ['Quarantine']],
#   [{'Doctors'}, ['Doctors']],
#   [{'Borders', 'MSF'}, ['Borders']]],
#  [[{'boss', 'care', 'health', 'lives', 'state'}, ['state']],
#   [{'matters'}, ['matters']],
#   [{'19', 'COVID'}, ['COVID']],
#   [{'exploitation', 'workers'}, ['exploitation']],
#   [{'Greece', 'ensure', 'food'}, ['Greece']],
#   [{'.', 'matter', 'stories'}, ['matter']],
#   [{'@CERCmigration'}, ['@CERCmigration']],
#   [{'borders'}, ['borders']]],
#  [[{'@RuhiLoren', 'ECSTATIC', 'WE', 'able', 'funds', 'k', 'release'}, ['WE']],
#   [{'greece', 'team'}, ['team']],
#   [{'they'}, ['they']],
#   [{'needed', 'shoes'}, ['shoes']],
#   [{'hundreds', 'refugees'}, ['hundreds']],
#   [{'Chios', 'camps'}, ['camps']],
#   [{'impossible'}, ['impossible']],
#   [{'72', 'hours', 'less', 'thanks'}, ['thanks']],
#   [{'YOU'}, ['YOU']]],
#  [[{'YOU'}, ['YOU']],
#   [{'LOT'}, ['LOT']],
#   [{'72', 'hours', 'less'}, ['hours']],
#   [{'goal', 'k'}, ['goal']],
#   [{'k'}, ['k']],
#   [{'.', 'HUNDREDS', 'greece', 'need', 'refugees', 's', 'shoes'}, ['s']],
#   [{'you'}, ['you']],
#   [{'joy', 'partners', 'us'}, ['us']],
#   [{'motivation'}, ['motivation']]],
#  [[{'we'}, ['we']],
#   [{'France', 'Germany', 'Italy', 'Sweden', 'incidents', 'unreported'},
#    ['unreported']],
#   [{'obvious'}, ['obvious']],
#   [{'problem'}, ['problem']],
#   [{'Greece'}, ['Greece']],
#   [{'flashpoint'}, ['flashpoint']],
#   [{'Erdogan'}, ['Erdogan']],
#   [{'migrants'}, ['migrants']],
#   [{'He'}, ['He']],
#   [{'EU'}, ['EU']],
#   [{'Empire', 'seem'}, ['Empire']]],
#  [[{'10,000'}, ['10,000']],
#   [{'migrants'}, ['migrants']],
#   [{'Greece'}, ['Greece']]],
#  [[{'Greece', 'Italy'}, ['Greece']],
#   [{'them'}, ['them']],
#   [{'Europe', 'rest'}, ['rest']],
#   [{'%', 'refugees'}, ['%']],
#   [{'we'}, ['we']],
#   [{',', 'any', 'jobs', 'wing'}, ['any']],
#   [{'you'}, ['you']],
#   [{'we'}, ['we']]],
#  [[{'Spring'}, ['Spring']],
#   [{'time'}, ['time']],
#   [{'behaviour', 'breeding', 'chance'}, ['chance']],
#   [{'memory'}, ['memory']],
#   [{'Plovers'}, ['Plovers']],
#   [{'Lesbos', 'island'}, ['island']],
#   [{'I'}, ['I']],
#   [{'migration'}, ['migration']],
#   [{'photography'}, ['photography']]],
#  [[{'Minister'}, ['Minister']],
#   [{'10000'}, ['10000']],
#   [{'Migrants'}, ['Migrants']],
#   [{'Greece', 'Times', 'York'}, ['Greece']]],
#  [[{'Heute', 'ab'}, ['Heute']],
#   [{'16'}, ['16']],
#   [{'Uhr', 'auf'}, ['Uhr']],
#   [{'Holzmarkt', 'dem'}, ['dem']],
#   [{'one'}, ['one']]],
#  [[{'.', 'Service', 'microsite', 'replaces'}, ['microsite']],
#   [{'asylum', 'information', 'visit'}, ['information']]],
#  [[{'.', 'fi', 'kin', 'novel', 'sounds', 'treatise'}, ['kin']],
#   [{'Greece', 'issues', 'resolve'}, ['issues']],
#   [{'citizens'}, ['citizens']],
#   [{'taxes'}, ['taxes']],
#   [{'borders'}, ['borders']],
#   [{'migration', 'weapons'}, ['weapons']]],
#  [[{'collaboration', 'room', 'roommate', 'work'}, ['room']],
#   [{'athens', 'proposals'}, ['proposals']],
#   [{'ideas', 'opportunities', 'supply'}, ['supply']],
#   [{'return'}, ['return']],
#   [{'!', 'Thanks', 'universe'}, ['Thanks']],
#   [{'film'}, ['film']]],
#  [[{'Germany', 'Populism'}, ['Populism']],
#   [{'study'}, ['study']],
#   [{'anything', 'lies'}, ['lies']],
#   [{'millions', 'refugees'}, ['millions']],
#   [{'statement'}, ['statement']],
#   [{'people'}, ['people']],
#   [{'million'}, ['million']],
#   [{'lockdown'}, ['lockdown']],
#   [{'Greece', 'Turkey'}, ['Turkey']]],
#  [[{'Greece'}, ['Greece']],
#   [{'they'}, ['they']],
#   [{'immigrants'}, ['immigrants']],
#   [{'sea'}, ['sea']]],
#  [[{'Camp'}, ['Camp']],
#   [{'quarantine'}, ['quarantine']],
#   [{'authorities'}, ['authorities']],
#   [{'Covid', 'camp', 'case', 'population'}, ['case']],
#   [{'3,000', 'capacity', 'less', 'persons'}, ['capacity']],
#   [{'migrants', 'seekers'}, ['migrants']]],
#  [[{'Refugeegr', 'work'}, ['work']],
#   [{'others'}, ['others']],
#   [{'groups', 'led', 'work'}, ['work']],
#   [{'more'}, ['more']],
#   [{'refugees'}, ['refugees']]],
#  [[{'Flakes'}, ['Flakes']],
#   [{'problems'}, ['problems']],
#   [{'i'}, ['i']],
#   [{'!', 'riots'}, ['riots']],
#   [{'assault', 'ect'}, ['assault']],
#   [{'migrant'}, ['migrant']],
#   [{'+', 'France', 'Germany', 'Greece', 'Italy', 'Poland', 'Sweden', 'eu'},
#    ['eu']],
#   [{'Hungary'}, ['Hungary']],
#   [{'Problems'}, ['Problems']],
#   [{'they'}, ['they']],
#   [{'any', 'haven', 'taken'}, ['haven']],
#   [{'them'}, ['them']],
#   [{'they'}, ['they']]],
#  [[{'you'}, ['you']],
#   [{'France', 'Germany', 'Greece', 'Italy', 'safe'}, ['France']],
#   [{'EU'}, ['EU']],
#   [{'rules'}, ['rules']],
#   [{'Refugees'}, ['Refugees']],
#   [{'they'}, ['they']],
#   [{'it'}, ['it']],
#   [{'They'}, ['They']],
#   [{'migrants', 'refugees'}, ['migrants']],
#   [{'I'}, ['I']],
#   [{'you'}, ['you']],
#   [{'.', 'one'}, ['one']],
#   [{'.', 'no'}, ['no']]],
#  [[{'Voices', 'conference', 'discussions'}, ['Voices']],
#   [{'compassion', 'need'}, ['need']],
#   [{'It'}, ['It']],
#   [{'me'}, ['me']],
#   [{'acts'}, ['acts']],
#   [{'people'}, ['people']],
#   [{'I'}, ['I']],
#   [{'data'}, ['data']],
#   [{'Greece'}, ['Greece']],
#   [{'1'}, ['1']],
#   [{'/'}, ['/']]],
#  [[{'Asst', 'Commissioners', 'w'}, ['Commissioners']],
#   [{'Operations', 'Protection'}, ['Operations']],
#   [{'We'}, ['We']],
#   [{'UNHCRs', 'helping', 'migrants', 'seekers', 'work'}, ['UNHCRs']],
#   [{'cases', 'covid'}, ['cases']],
#   [{'RICs', 'low'}, ['RICs']],
#   [{'US'}, ['US']],
#   [{'$', 'million'}, ['$']],
#   [{'UNHCR', 'agencies'}, ['UNHCR']],
#   [{'19', 'COVID', 'Greece'}, ['COVID']]],
#  [[{'Greece', 'people'}, ['Greece']],
#   [{'compassion', 'solidarity'}, ['solidarity']],
#   [{'protection', 'refugees', 'safety', 'seekers', 'sought', 'thousands'},
#    ['thousands']],
#   [{'I'}, ['I']],
#   [{'@Raouf'}, ['@Raouf']],
#   [{'@UNHCRGreece', 'Mazou'}, ['Mazou']],
#   [{'we'}, ['we']],
#   [{'more'}, ['more']],
#   [{'efforts', 'refugees', 'support'}, ['efforts']]],
#  [[{'something', 'todays'}, ['something']],
#   [{'Greece', 'refugees'}, ['refugees']],
#   [{'This'}, ['This']],
#   [{'War', 'World'}, ['War']],
#   [{'!!!', 'happening', 'refugees'}, ['refugees']]],
#  [[{'Omfg'}, ['Omfg']],
#   [{'you'}, ['you']],
#   [{'latinos'}, ['latinos']],
#   [{'term'}, ['term']],
#   [{'US'}, ['US']],
#   [{'americans'}, ['americans']],
#   [{'you'}, ['you']],
#   [{'germany', 'immigrants'}, ['immigrants']],
#   [{'europeans'}, ['europeans']],
#   [{'you'}, ['you']],
#   [{'greece', 'immigrants'}, ['immigrants']],
#   [{'Latinos'}, ['Latinos']],
#   [{'They'}, ['They']]],
#  [[{'7000'}, ['7000']],
#   [{'Turks', 'beginning', 'year'}, ['Turks']],
#   [{'asylum'}, ['asylum']],
#   [{'Greece'}, ['Greece']],
#   [{'people'}, ['people']],
#   [{'Erdogan'}, ['Erdogan']]],
#  [[{'We'}, ['We']],
#   [{'arest', 'coast', 'guard'}, ['guard']],
#   [{'passing', 'ski', 'them', 'waters'}, ['them']],
#   [{'Ubtil'}, ['Ubtil']],
#   [{'Greece'}, ['Greece']],
#   [{'turks'}, ['turks']],
#   [{'who'}, ['who']],
#   [{'asylum'}, ['asylum']]]]

# %% [markdown]
# ## 8. We define candidate types

# %%
#dictionary to assign candidate types based on named entities and part of speech tags
#the key tuple consists of (isNE, lexicographer type, plural)
cand_types_dict = {(True,'PERSON',None):'person-ne',
              (True,'NORP',None):'person-ne',
              (True,'PERSON','plural'):'person-nes',
              (True,'NORP','plural'):'person-nes',
              (False,'PERSON',None):'person-nn',
              (False,'PERSON','plural'):'person-nns',
              (True,'ORG',None):'group-ne',
              (True,'FAC',None):'group-ne',
              (False,'ORG',None):'group',
              (True,'LOC',None):'loc-ne',
              (True,'GPE',None):'loc-ne',
              (False, 'LOC',None):'loc'
            }

# %%
from collections import Counter

#test syntactic categories on all heads of noun phrases
list_of_cand_types = [cand_prep.get_synt_category(cand[1][0]) for tweet_cands in np_cand_heads for cand in tweet_cands]
    
count_types = Counter(list_of_cand_types)
print(count_types)
# Out:
# Counter({None: 1069, 'PERSON': 162, 'ORG': 134, 'LOC': 74})

# %% [markdown]
# ## 9. We assign candidate types to noun phrase candidates

# %%
# label the noun phrases with the candidate types
np_and_cand_list = cand_prep.get_cand_type(noun_phrase_list,np_cand_heads, tweet_tags, cand_types_dict)
print(np_and_cand_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 164.42it/s]
# [[('it', 'it', {'it'}, 'misc'), ('asylum in Greece, MAC, SER or CRO or BUL', 'asylum', {'Greece', 'MAC', 'asylum', 'CRO', 'BUL', 'SER'}, 'group-ne'), ('3 EU members', 'members', {'members'}, 'person-nes'), ('HU', 'HU', {'HU'}, 'group-ne'), ('They', 'They', {'They'}, 'misc'), ('help', 'help', {'help'}, 'person-nn'), ('the first safe country as asylum seeker', 'country', {'seeker', 'country'}, 'group-ne'), ('the 5', '5', {'5'}, 'misc'), ('No law', 'law', {'law'}, 'misc'), ('you', 'you', {'you'}, 'misc'), ('it', 'it', {'it'}, 'misc')], [('ISIS refuge .', 'refuge', {'.', 'refuge'}, 'loc-ne'), ("Wouldn' t", 'Wouldn', {'Wouldn', 't'}, 'misc'), ('Turkey', 'Turkey', {'Turkey'}, 'loc-ne'), ('I', 'I', {'I'}, 'group'), ("You' re likely to get your head", 'likely', {'get', 'head', 'likely'}, 'misc'), ('the beaten track', 'track', {'track'}, 'loc'), ('Christian Greece', 'Christian', {'Christian', 'Greece'}, 'person-ne'), ('a similar climate', 'climate', {'climate'}, 'misc'), ('islamic turkey', 'turkey', {'turkey'}, 'misc')], [('Greece', 'Greece', {'Greece'}, 'loc-ne'), ('refugee overcrowding', 'overcrowding', {'overcrowding'}, 'group'), ('UN', 'UN', {'UN'}, 'group-ne')], [('1/3', '1/3', {'1/3'}, 'misc'), ('Law', 'Law', {'Law'}, 'misc'), ('the idle stuff', 'stuff', {'stuff'}, 'loc'), ('All rights of the Turkish minority in Greece', 'rights', {'minority', 'Greece', 'rights'}, 'loc-ne'), ('the law', 'law', {'law'}, 'misc'), ('Refugees', 'Refugees', {'Refugees'}, 'person-nns'), ('the EU', 'EU', {'EU'}, 'group-ne'), ('the law', 'law', {'law'}, 'misc'), ('Western states', 'states', {'states'}, 'group-ne'), ('the states', 'states', {'states'}, 'group'), ('the Middle East and Africa', 'East', {'East', 'Africa'}, 'loc-ne'), ('underground resources', 'resources', {'resources'}, 'misc'), ('the law', 'law', {'law'}, 'misc')], [('the asylum seekers', 'seekers', {'seekers'}, 'person-nns'), ('HU borders', 'borders', {'borders'}, 'misc'), ('They', 'They', {'They'}, 'misc'), ('a long journey', 'journey', {'journey'}, 'misc'), ('Greece', 'Greece', {'Greece'}, 'loc-ne'), ('they', 'they', {'they'}, 'misc'), ('help', 'help', {'help'}, 'person-nn'), ('they', 'they', {'they'}, 'misc'), ('multiple more countries', 'countries', {'countries'}, 'group')], [('I', 'I', {'I'}, 'misc'), ('photo gr apy', 'apy', {'gr', 'apy'}, 'misc'), ('aesthetic', 'aesthetic', {'aesthetic'}, 'misc'), ('news', 'news', {'news'}, 'misc'), ('it', 'it', {'it'}, 'misc'), ('a potential embellishments of hard facts and harsh reality', 'embellishments', {'facts', 'embellishments', 'reality'}, 'misc'), ('I', 'I', {'I'}, 'misc'), ('raw realism', 'realism', {'realism'}, 'misc'), ('I', 'I', {'I'}, 'misc'), ('this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp', 'boundary', {'using', 'camp', 'light', 'migrants', 'lesbos', 'week', 'boundary'}, 'loc-ne'), ('a big question4me', 'question4', {'question4', 'me'}, 'misc')], [('ManfredWeber', 'ManfredWeber', {'ManfredWeber'}, 'misc'), ('It', 'It', {'It'}, 'misc'), ('Europe and Germany', 'Europe', {'Germany', 'Europe'}, 'loc-ne'), ('the side of Greece', 'side', {'side', 'Greece'}, 'loc-ne'), ('The German MFA', 'MFA', {'MFA'}, 'group-ne'), ('fear of a new refugee crisis', 'fear', {'fear', 'crisis'}, 'misc')], [("Refugee Covid case sparks' closed camps' fears on Lesbos", 'sparks', {'sparks', 'fears', 'camps', 'Lesbos', 'case'}, 'misc')], [('9PM Coronavirus UK', 'PM', {'UK', 'PM'}, 'misc'), ('Leeds', 'Leeds', {'Leeds'}, 'loc-ne'), ('brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham', 'brink', {'chaos', 'brink', 'Birmingham', 'birmingham', 'sources', 'lockdown', 'outbreak', 'hostel', 'Stories', 'seeker'}, 'misc')], [("you' re", 'you', {'you', 're'}, 'misc'), ('France and not Turkey', 'France', {'Turkey', 'France'}, 'loc-ne'), ('parts of Syria', 'parts', {'Syria', 'parts'}, 'loc-ne'), ('bombs Iraq', 'bombs', {'Iraq', 'bombs'}, 'misc'), ('a proxy war in Libya ...

# %%
from collections import Counter

# couunt occurence of each candidate type
cand_type_count = [np[3] for nps in np_and_cand_list if nps != None for np in nps ]
    
counts = Counter(cand_type_count)
print(counts)
# Out:
# Counter({'misc': 853, 'loc-ne': 197, 'group-ne': 76, 'person-nns': 73, 'group': 69, 'loc': 50, 'person-ne': 43, 'person-nes': 42, 'person-nn': 29})

# %% [markdown]
# ## 10. We get coreference chains candidates from the tweet corpus

# %%
from stanza.server import CoreNLPClient
dict_of_tweet_corefs = {}
#corefs = []
with CoreNLPClient(properties={'annotators': 'coref', 'coref.algorithm' : 'statistical'}, memory='16G') as client:
    for tweet_index in tqdm(range(len(sampled_df))):
        tweet_corefs=[]
        #print(f'Coreferences for the tweet {list(event_df["Tweet Raw"]).index(tweet)} are:')
        for chain in cand_prep.get_coref_chain(sampled_df[tweet_index],client):
            tweet_corefs.append(chain)
            #print(' <-> '.join(chain),'\n')
        #corefs.append(tweet_corefs)
        dict_of_tweet_corefs[tweet_index] = tweet_corefs

dict_of_tweet_corefs
# Out:
# 2021-03-18 22:10:17 INFO: Writing properties to tmp file: corenlp_server-045b60b08d594fa6.props
# 2021-03-18 22:10:17 INFO: Starting server with command: java -Xmx16G -cp C:\Users\nikodemicek\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-045b60b08d594fa6.props -preload -outputFormat serialized
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [02:39<00:00,  1.26it/s]
# {0: [(['No law', 'it'], 0)],
#  1: [(['You', 'your', 'you'], 0)],
#  2: [],
#  3: [(['the law', 'the law', 'the law'], 0)],
#  4: [(['They', 'they', 'the asylum seekers', 'they'], 2)],
#  5: [(['I', 'I', 'I'], 0), (['aesthetic', 'it'], 0)],
#  6: [],
#  7: [],
#  8: [(['Birmingham', 'birmingham'], 0)],
#  9: [(['you', 'you'], 0), (['Turkey', 'it', 'it', 'Turkey'], 3)],
#  10: [(['The Bessudos', 'Isaac Bessudos'], 1),
#   (['Raquel Bessudo', 'Raquel'], 0)],
#  11: [(['them', 'their'], 0)],
#  12: [(['you', 'you', 'your', 'your', 'you'], 1),
#   (['it', 'it'], 1),
#   (['they', 'they'], 0)],
#  13: [],
#  14: [(['It', 'Greece'], 1)],
#  15: [],
#  16: [],
#  17: [(['their', 'Both men', 'they', 'them', 'they'], 1)],
#  18: [(['Those refugees',
#     '10 refugees , including three children with disabilities'],
#    1),
#   (['Greece', 'Greece'], 0)],
#  19: [(['UN Refugee Agency', 'Anadolu Agency'], 0)],
#  20: [],
#  21: [],
#  22: [],
#  23: [(['we', 'we'], 0)],
#  24: [],
#  25: [],
#  26: [],
#  27: [(['they', 'Enterprise Greece', 'their', 'they', 'their'], 1)],
#  28: [],
#  29: [(['they', 'their', 'them'], 0)],
#  30: [(['He', 'He', 'he'], 0)],
#  31: [(['Erdoan', 'He'], 0)],
#  32: [(['UK', 'UK'], 0), (['UK size', 'UK size'], 0)],
#  33: [],
#  34: [(['He', 'The infected person , a 40 year old man'], 1),
#   (['the camp', 'the camp'], 0),
#   (['Moria', 'Moria'], 0),
#   (["Didn '", 'it'], 0)],
#  35: [],
#  36: [(['Greece', 'its'], 0),
#   (['their', 'Protection & Operations , @GillianTriggs & @RaoufMazou'], 1)],
#  37: [(['Greece', 'greece'], 1), (['I', 'I'], 1), (['your', 'you'], 1)],
#  38: [],
#  39: [],
#  40: [],
#  41: [],
#  42: [],
#  43: [(['you', 'you', 'you'], 1)],
#  44: [(['Turkey', 'Turkey'], 1)],
#  45: [(['I', 'me', 'I', 'me'], 0)],
#  46: [],
#  47: [],
#  48: [(["Don '", 'you', 'your'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Those who seek refuge in Greece , those who want to make a coup', 'they'],
#    0),
#   (['it', 'freedom of expression'], 1)],
#  49: [],
#  50: [(['2040', '2040'], 0), (['EU', 'it'], 0)],
#  51: [(['this poor nation', 'it'], 0),
#   (['People', 'them', 'them', 'they'], 0),
#   (['I', 'me'], 1)],
#  52: [(['He', 'his', 'Erdogan'], 2),
#   (['They', 'Syrian refugees', 'They', 'they'], 1)],
#  53: [],
#  54: [],
#  55: [],
#  56: [(['it', 'It'], 0)],
#  57: [(['you', 'your', 'you'], 1)],
#  58: [(['the 5 + million refugees', 'they', 'them'], 0)],
#  59: [],
#  60: [],
#  61: [],
#  62: [],
#  63: [(['it', 'it'], 0), (['you', 'you'], 1)],
#  64: [(['Greece', 'its', 'it', 'Greece', 'it'], 3), (['him', 'Assad'], 1)],
#  65: [(['it', 'it', 'the supply of ready - made food'], 2)],
#  66: [(['Nigeria', 'Nigeria'], 0),
#   (['him', 'He', 'his', 'he', 'he', 'him'], 1)],
#  67: [],
#  68: [(['Assad', 'you'], 0), (['Greece', 'Greece'], 0)],
#  69: [(['We', 'our'], 0)],
#  70: [],
#  71: [],
#  72: [(['you', 'I', 'I'], 0)],
#  73: [],
#  74: [(['Greece', 'its', 'the country'], 0)],
#  75: [],
#  76: [],
#  77: [],
#  78: [(['The uk', 'the uk', 'it'], 1),
#   (['their', "the world ' s refugees"], 1)],
#  79: [],
#  80: [],
#  81: [(['Greek immigrants', 'their', 'they'], 0),
#   (['our', 'theirs'], 0),
#   (['our culture', 'their culture'], 0)],
#  82: [(['You', 'your'], 0), (['them', 'your so called poor refugees'], 1)],
#  83: [(['Turkey', 'Turkey'], 0)],
#  84: [],
#  85: [],
#  86: [(['It', 'The funniest thing', 'its', 'it'], 1)],
#  87: [(['me', 'I', 'my'], 1), (['their', 'refugees'], 1)],
#  88: [(['people', 'they'], 0),
#   (['i', 'MY'], 0),
#   (['you', 'you'], 1),
#   (['the EU', 'EU'], 0)],
#  89: [],
#  90: [],
#  91: [(['these people', 'they'], 0), (['it', 'a responsibility'], 1)],
#  92: [(['Athens', 'its', 'its'], 0)],
#  93: [],
#  94: [],
#  95: [(['we', 'our'], 0)],
#  96: [(['Greece', 'its'], 0), (['them', '4 million migrants', 'they'], 1)],
#  97: [(['them', 'the borders'], 1), (['you', 'You', 'Your', 'You'], 1)],
#  98: [],
#  99: [(['both aegean and kastelorizo eez', 'This'], 0),
#   (['Greece', 'Greece'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (["this didn '", 'it'], 0)],
#  100: [(['greece and europe', 'their', 'them'], 0),
#   (['Eedogan', 'he', 'he'], 0)],
#  101: [(['you', 'you'], 1), (['my', 'I'], 1)],
#  102: [(['you', 'you', 'you', 'you'], 1)],
#  103: [(['you', 'you'], 1),
#   (['I', 'I', 'I'], 0),
#   (['Iraq', 'Iraq'], 0),
#   (['Greece', 'Greece'], 0)],
#  104: [],
#  105: [],
#  106: [(['They', 'Eastern Europe'], 1)],
#  107: [(['the bosses', 'they'], 0)],
#  108: [(['their', 'they'], 1)],
#  109: [],
#  110: [(['you', 'your', 'you'], 0)],
#  111: [],
#  112: [(['them', 'people'], 1), (['it', 'NYT', 'it'], 1)],
#  113: [(['My', 'I', 'my', 'my', 'I'], 0)],
#  114: [(['They', 'they', 'Those illegally coming by dinghy', 'they'], 2)],
#  115: [(['Anastasa Sikiaridi', 'her'], 0)],
#  116: [(['others', 'their'], 0),
#   (['Our', 'we'], 0),
#   (['all those', 'them'], 0)],
#  117: [],
#  118: [],
#  119: [],
#  120: [(['you', 'you'], 0)],
#  121: [(['them all', 'they', 'the asylum seekers'], 2)],
#  122: [],
#  123: [],
#  124: [(['the asylum system', 'it'], 0)],
#  125: [],
#  126: [],
#  127: [(['you', 'you'], 0), (['them', 'the migrants'], 1)],
#  128: [],
#  129: [(['vulnerable children', 'their'], 0)],
#  130: [(['that', '5 billion euros'], 1),
#   (['you', 'you'], 0),
#   (['they', 'they', 'they'], 1)],
#  131: [(['turkey', 'they'], 0)],
#  132: [],
#  133: [],
#  134: [(['I', 'I'], 0),
#   (['it', 'The situation'], 1),
#   (['very few people saying it', 'their'], 0)],
#  135: [(['Greece', 'Greece', 't blame Greece'], 2),
#   (['they', 'the refugees', 'their'], 1)],
#  136: [],
#  137: [],
#  138: [(['Turkey', 'Turkey'], 1)],
#  139: [(['him', 'Mr Stoltenberg'], 1),
#   (['they', 'Greece', 'They', 'they'], 1),
#   (['EU', 'EU'], 0)],
#  140: [],
#  141: [(['Moria migrant camp on Lesbos',
#     'the overcrowded migrant camp of Moria on the island of Lesbos'],
#    1),
#   (['Moria', 'Moria'], 1),
#   (['Lesbos', 'Lesbos'], 0),
#   (['Sept 2 ( Reuters ) - Greece', 'its'], 0)],
#  142: [(['you', 'i', 'I'], 1),
#   (['they', 'they', 'they', 'france Germany and Greece', 'they'], 3)],
#  143: [],
#  144: [(['Most people', 'their'], 0), (['you', 'you'], 1)],
#  145: [(['the U.K.', 'the U.K.', 'the U.K.'], 0)],
#  146: [],
#  147: [(['them', 'children and pregnant women'], 1),
#   (['@MSF', 'its', 'we'], 0)],
#  148: [],
#  149: [(['i', 'I', 'I'], 0), (['the EU', 'the French / EU'], 1)],
#  150: [],
#  151: [],
#  152: [],
#  153: [(['you', 'you', 'your'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (['they', 'they', '6 million Syrian refugees in Turkey', 'these refugees'],
#    2),
#   (['greece', 'Greece'], 1)],
#  154: [(['it', 'Greece'], 1),
#   (['Central Europe', 'it', 'it'], 0),
#   (['their', 'their'], 1)],
#  155: [(['the UK', 'the UK'], 1)],
#  156: [(['them', 'they', 'they', 'they', 'everyone'], 4), (['you', 'you'], 0)],
#  157: [],
#  158: [],
#  159: [],
#  160: [],
#  161: [],
#  162: [(['Turkey', 'Turkey', 'Turkey'], 0),
#   (['Greece', 'Greece', 'Greece'], 0)],
#  163: [(['we', 'our'], 0),
#   (['the UK', 'the UK'], 0),
#   (['Matt', 'My', 'I', 'I', 'my', 'my'], 0)],
#  164: [(['the uk', 'the uk'], 1), (['refugees', 'they'], 0)],
#  165: [(['Its', 'Its', 'Moria', 'it'], 2)],
#  166: [(['you', 'your'], 0),
#   (['Everyone', 'their'], 0),
#   (['your money', 'it'], 0),
#   (['We', 'ourselves'], 0)],
#  167: [],
#  168: [(['we', 'the EU', "the EU '"], 2),
#   (['you', 'you'], 1),
#   (["the EU ' s member countries", 'them'], 0)],
#  169: [(['the camp', 'the overcrowded moria camp'], 1)],
#  170: [(['This', 'This'], 0)],
#  171: [(['just for unidentified migrant bodies from the Mediterranean',
#     'these unnamed bodies'],
#    0)],
#  172: [(['I', 'my', 'me', 'I'], 0), (['He', 'him'], 0), (['they', 'them'], 0)],
#  173: [],
#  174: [],
#  175: [(['our', 'our', 'our'], 2)],
#  176: [(['WE', 'our'], 0), (['@RuhiLoren', 'they'], 0)],
#  177: [(['us', 'our'], 0), (['YOU', 'you'], 0)],
#  178: [(['Erdogan', 'He'], 0),
#   (['we', 'its', 'MSM', 'the problem'], 2),
#   (['Greece', 'it'], 0)],
#  179: [],
#  180: [(['we', 'we'], 0)],
#  181: [(['Spring', 'spring'], 0)],
#  182: [],
#  183: [],
#  184: [],
#  185: [(['its citizens', 'their'], 0), (['Its', 'its', 'its'], 0)],
#  186: [],
#  187: [],
#  188: [(['Greece', 'they'], 0)],
#  189: [(['Moria Camp', "the camp ' s"], 0),
#   (['it',
#     'it',
#     "the first confirmed case of Covid - 19 within the camp ' s population"],
#    2)],
#  190: [],
#  191: [(['they', 'them', 'they'], 0), (['Luvvie Flakes', 'these migrant'], 0)],
#  192: [(['you', 'I', 'you'], 0), (['it', 'The EU', 'They', 'they'], 1)],
#  193: [(['the need for teacher compassion', 'It'], 0), (['me', 'I', 'my'], 0)],
#  194: [],
#  195: [(['Greece', 'its'], 0)],
#  196: [],
#  197: [(['Omfg', 'you', 'you', 'you'], 0),
#   (['They', 'italian immigrants in greece'], 1)],
#  198: [],
#  199: [(['them', 'them'], 0)]}

# %%
with open('moria_tweet_corefs', 'wb') as fp:
    pickle.dump(dict_of_tweet_corefs, fp)

dict_of_tweet_corefs
# Out:
# {0: [(['No law', 'it'], 0)],
#  1: [(['You', 'your', 'you'], 0)],
#  2: [],
#  3: [(['the law', 'the law', 'the law'], 0)],
#  4: [(['They', 'they', 'the asylum seekers', 'they'], 2)],
#  5: [(['#photograpy pushing aesthetic', 'it'], 0), (['I', 'I'], 0)],
#  6: [(['@GreeceMFA ManfredWeber', 'It'], 0)],
#  7: [],
#  8: [],
#  9: [(['Turkey', 'Turkey', 'it', 'it'], 0), (['you', 'you'], 0)],
#  10: [(['Raquel',
#     'Raquel',
#     '@realPR_Phoenix @DrEstella @BravoTV Raquel Bessudo',
#     'Isaac Bessudo'],
#    2)],
#  11: [(['@Mproyklis @fragoua @LearnerLerner', 'them', 'their'], 0)],
#  12: [(['you', 'you', 'your', 'your', 'you'], 1),
#   (['it', 'it'], 1),
#   (['they', 'they'], 0)],
#  13: [],
#  14: [(['It', 'Greece'], 1)],
#  15: [],
#  16: [],
#  17: [(['their', 'Both men', 'they', 'them', 'they'], 1)],
#  18: [(['Those refugees',
#     '10 refugees , including three children with disabilities'],
#    1),
#   (['Greece', 'Greece'], 0)],
#  19: [(['Anadolu Agency', 'UN Refugee Agency'], 1)],
#  20: [],
#  21: [],
#  22: [],
#  23: [(['we', 'we'], 0)],
#  24: [],
#  25: [],
#  26: [],
#  27: [(['they', 'Enterprise Greece', 'their', 'they', 'their'], 1)],
#  28: [],
#  29: [(['they', 'their', 'them'], 0)],
#  30: [(['He', 'He', 'he'], 1)],
#  31: [],
#  32: [(['UK', 'UK'], 1), (['UK size', 'UK size'], 1)],
#  33: [],
#  34: [(['the camp', 'it', 'the camp'], 0),
#   (['He', '@guardian The infected person , a 40 year old man'], 1),
#   (['Moria', 'Moria'], 0)],
#  35: [],
#  36: [(['Greece', 'its'], 0),
#   (['their', 'Protection & Operations , @GillianTriggs & @RaoufMazou'], 1)],
#  37: [(['I', 'I'], 1), (['your', 'you'], 1)],
#  38: [],
#  39: [],
#  40: [],
#  41: [],
#  42: [],
#  43: [(['you', 'you', 'you'], 1)],
#  44: [(['Turkey - Greece', 'Earlier Greece'], 0)],
#  45: [(['I', 'me', 'I', 'me'], 0)],
#  46: [],
#  47: [],
#  48: [(['Greece', 'Greece'], 1),
#   (['it', 'freedom of expression'], 1),
#   (['you', 'your'], 1)],
#  49: [],
#  50: [(['2040', '2040'], 1), (['Europe', 'it'], 0)],
#  51: [(['People', 'them', 'them', 'they'], 0),
#   (['I', 'me'], 1),
#   (['it', 'this poor nation'], 1)],
#  52: [(['@AmysGotBirds @DonaldJTrumpJr', 'He', 'his'], 0),
#   (['They', 'They', 'Syrian refugees', 'they'], 2)],
#  53: [],
#  54: [],
#  55: [],
#  56: [(['@Nicolas98869551 @Marflo66036248 @Esref_Doguu', 'it', 'It'], 0)],
#  57: [(['your', 'you', 'you'], 0)],
#  58: [(['@devilxbrain @ragipsoylu', 'they'], 0)],
#  59: [],
#  60: [],
#  61: [],
#  62: [],
#  63: [(['it', 'it'], 0), (['you', 'you'], 1)],
#  64: [(['Greece', 'its', 'it', 'Greece', 'it'], 3),
#   (['it', '@griko84 @BwanaPjotr'], 1),
#   (['him', 'Assad'], 1)],
#  65: [(['it', 'it', 'the supply of ready - made food'], 2)],
#  66: [(['him', 'He', 'his', 'he', 'he', 'him'], 1),
#   (['they', 'his parents'], 1),
#   (['Nigeria', 'Nigeria'], 1)],
#  67: [],
#  68: [(['Greece', 'Greece'], 1)],
#  69: [(['We', 'our'], 0)],
#  70: [],
#  71: [],
#  72: [(['Albanian greeks', 'them'], 0), (['I', 'I', 'you'], 2)],
#  73: [],
#  74: [(['Greece', 'its', 'the country'], 0)],
#  75: [],
#  76: [],
#  77: [],
#  78: [(['The uk', 'it', 'the uk'], 2),
#   (['their', "the world 's refugees"], 1)],
#  79: [],
#  80: [],
#  81: [(['our', 'theirs'], 0),
#   (['our culture', 'their culture'], 0),
#   (['Greek immigrants', 'their', 'they'], 0)],
#  82: [(['You', 'your'], 0), (['them', 'your so called ‘ poor ’ refugees'], 1)],
#  83: [(['Turkey', 'Turkey'], 1)],
#  84: [],
#  85: [],
#  86: [(['it',
#     'It',
#     '@gerdosi @paulmelzer1 @nmlinguaphile The funniest thing',
#     'its'],
#    2)],
#  87: [(['me', 'I', 'my'], 1), (['refugees', 'their'], 0)],
#  88: [(['people', 'they'], 0),
#   (['i', 'MY'], 0),
#   (['you', 'you'], 1),
#   (['the EU', 'EU'], 0)],
#  89: [],
#  90: [],
#  91: [(['these people', 'they'], 0), (['it', 'a responsibility'], 1)],
#  92: [(['Athens', 'its', 'it'], 0)],
#  93: [],
#  94: [],
#  95: [(['we', 'our'], 0)],
#  96: [(['turkey!if Greece', 'its'], 0),
#   (['@EastMedMonitor 4 million migrants', 'them', 'they'], 0)],
#  97: [(['the borders', 'them'], 0), (['You', 'You', 'you'], 1)],
#  98: [],
#  99: [(['This', 'this'], 1),
#   (['Greece', 'Greece'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (['any case', 'it'], 0)],
#  100: [(['greece and europe', 'their', 'them'], 0),
#   (['he', 'he', 'Eedogan'], 2)],
#  101: [(['you', 'you'], 1), (['@Nionios1908', 'it'], 0), (['my', 'I'], 1)],
#  102: [(['you', 'you', 'you', 'you'], 1)],
#  103: [(['you', 'you'], 1),
#   (['I', 'I', 'I'], 1),
#   (['Iraq', 'Iraq'], 0),
#   (['Greece', 'Greece'], 0)],
#  104: [],
#  105: [],
#  106: [],
#  107: [(['the bosses', 'they'], 0)],
#  108: [(['their', '@cappsperhaps @pritipatel @BritishRedCross', 'they'], 1)],
#  109: [],
#  110: [(['you', 'your', 'you'], 0)],
#  111: [],
#  112: [(['them', 'people'], 1), (['it', 'Greece', 'it'], 1)],
#  113: [(['I', 'My', 'I', 'my', 'I', 'my', 'I'], 1)],
#  114: [(['they', 'They', 'they', 'Those illegally coming by dinghy'], 3)],
#  115: [(['@RESCUEorg Anastasía Sikiaridi', 'her'], 0)],
#  116: [(['others', 'their'], 0),
#   (['Our', 'we'], 0),
#   (['all those', 'them'], 0)],
#  117: [],
#  118: [],
#  119: [],
#  120: [(['you', 'you'], 0)],
#  121: [(['I', 'I'], 0), (['them all', 'they', 'the asylum seekers'], 2)],
#  122: [],
#  123: [(['I', 'you'], 0)],
#  124: [(['it', 'the EU'], 1)],
#  125: [],
#  126: [],
#  127: [(['you', 'you'], 0),
#   (['@LeeMitc_80 @brim90 @GaryLineker @RESCUE_UK Not exactly fair', 'it'], 0),
#   (['them', 'the migrants'], 1)],
#  128: [],
#  129: [(['vulnerable children', 'their'], 0)],
#  130: [(['that', '5 billion euros'], 1),
#   (['you', 'you'], 0),
#   (['they', 'they', 'they', 'refugees'], 3)],
#  131: [(['@MughalLife1 @pacifier8141 turkey', 'they'], 0)],
#  132: [],
#  133: [],
#  134: [(['I', 'I'], 0),
#   (['it', 'The situation'], 1),
#   (['very few people saying it', 'their'], 0)],
#  135: [(['Greece', 'Greece', 'Greece'], 2),
#   (['the refugees', 'they', 'their'], 0)],
#  136: [],
#  137: [],
#  138: [(['Turkey', 'Turkey'], 1)],
#  139: [(['him', 'Mr Stoltenberg'], 1),
#   (['they', '@antouan_hellas @jensstoltenberg Greece', 'They', 'they'], 1),
#   (['EU', 'EU'], 0)],
#  140: [],
#  141: [(['Moria migrant camp on Lesbos',
#     'the overcrowded migrant camp of Moria on the island of Lesbos and the … https://t.co/O31oc3V6j0'],
#    1),
#   (['Moria', 'Moria'], 1),
#   (['Lesbos', 'Lesbos'], 0),
#   (['Sept 2 ( Reuters ) - Greece', 'its'], 0)],
#  142: [(['you', 'I', 'i'], 2), (['they', 'they', 'they', 'they'], 1)],
#  143: [],
#  144: [(['Most people', 'their'], 0), (['you', 'you'], 1)],
#  145: [(['the U.K.', 'the U.K.', 'the U.K.'], 0)],
#  146: [],
#  147: [(['them', 'children and pregnant women'], 1),
#   (['.@MSF', 'its', 'we'], 0)],
#  148: [],
#  149: [(['I', 'i', 'I'], 1), (['the EU', 'the French / EU'], 1)],
#  150: [],
#  151: [],
#  152: [],
#  153: [(['you', 'you', 'your'], 0),
#   (['Turkey', 'Turkey'], 0),
#   (['they', 'they', '6 million Syrian refugees in Turkey', 'these refugees'],
#    2),
#   (['greece', 'Greece'], 1)],
#  154: [(['@oulosP @tabula_rassa_ Central Europe', 'it', 'it'], 0),
#   (['their', 'their'], 1),
#   (['it', 'Greece'], 1)],
#  155: [(['the UK', 'the UK'], 1)],
#  156: [(['you', 'you'], 1), (['them', 'they', 'they', 'they', 'everyone'], 4)],
#  157: [],
#  158: [],
#  159: [],
#  160: [],
#  161: [],
#  162: [(['Turkey', 'Turkey', 'Turkey'], 0),
#   (['@ragipsoylu Greece', 'Greece', 'Greece'], 0)],
#  163: [(['we', 'our'], 0),
#   (['the UK', 'the UK'], 0),
#   (['My', '@Matt_Dean1994 @DavidLammy Matt', 'I', 'I', 'I', 'my', 'my'], 1)],
#  164: [(['@ldgd881 @pritipatel F', 'it'], 0),
#   (['refugees', 'they'], 0),
#   (['the uk', 'the uk'], 1)],
#  165: [(['it', 'It', 'Moria'], 2)],
#  166: [(['you', 'your'], 0),
#   (['Everyone', 'their'], 0),
#   (['your money', 'it'], 0),
#   (['We', 'ourselves'], 0)],
#  167: [],
#  168: [(['we', 'the EU', "the EU 's"], 2),
#   (['you', 'you'], 0),
#   (["the EU 's member countries", 'them'], 0)],
#  169: [(['the camp', 'the overcrowded #Moria camp'], 1)],
#  170: [(['This', 'This'], 0)],
#  171: [(['just for unidentified migrant bodies from the Mediterranean',
#     'these unnamed bodies'],
#    0)],
#  172: [(['He', 'him'], 0),
#   (['my',
#     '@AnwarNillufary @UNHCRGreece @AP @apt_geneva',
#     'they',
#     'me',
#     'I',
#     'them',
#     'I'],
#    1)],
#  173: [],
#  174: [],
#  175: [(['our', 'our', 'our'], 2)],
#  176: [(['WE', 'our'], 0), (['@RuhiLoren', 'they'], 0)],
#  177: [(['YOU', 'you'], 0), (['us', 'our'], 0)],
#  178: [(['Greece', 'it'], 0),
#   (['He', 'Erdogan'], 1),
#   (['we', 'its', 'MSM', 'the problem'], 2)],
#  179: [],
#  180: [(['we', 'we'], 0)],
#  181: [(['Spring', 'spring'], 0)],
#  182: [],
#  183: [],
#  184: [],
#  185: [(['its citizens', 'their'], 0), (['Greece', 'its', 'its'], 0)],
#  186: [],
#  187: [],
#  188: [(['@ash_quash16 @NonhleBeryl Greece', 'they'], 0)],
#  189: [(['Moria Camp', 'the camp'], 0),
#   (['the first confirmed case of Covid - 19', 'it', 'it'], 0)],
#  190: [],
#  191: [(['they', 'them', 'they'], 0), (['these Problems', 'the problems'], 1)],
#  192: [(['you', 'I', 'you'], 0), (['it', 'The EU', 'They', 'they'], 1)],
#  193: [(['the need for teacher compassion', 'It'], 0), (['me', 'I', 'my'], 0)],
#  194: [(['UNHCR', 'UNHCR'], 1)],
#  195: [(['Greece', 'its', 'support Greece ’s'], 2)],
#  196: [(['today', 'today'], 0)],
#  197: [(['@Thrumber Omfg', 'its'], 0),
#   (['you', 'you', 'you'], 2),
#   (['They', 'italian immigrants in greece'], 1)],
#  198: [],
#  199: [(['them', 'them'], 0)],
#  200: [],
#  201: [],
#  202: [],
#  203: [(['us', 'our', 'we', 'we'], 2)],
#  204: [],
#  205: [(['Greece', 'Greece'], 1),
#   (['@LeftBrexit Tbh', 'they', 'them'], 0),
#   (['EU', 'EU'], 0)],
#  206: [(['I', 'my'], 0), (['migrants arriving from the sea', 'them'], 0)],
#  207: [],
#  208: [(['We', 'our', 'our'], 0)],
#  209: [(['Greece', 'Greece'], 1),
#   (['@Makis_Kevrekidi @nupelnet @Berna_Sharpe', 'He', 'him', 'him', 'he'], 0)],
#  210: [(['Greece', 'Greece'], 1),
#   (['they', '@UNHCRGreece @AndrejMahecic @Refugees Muslims', 'them', 'they'],
#    1)],
#  211: [(['all this people', 'their'], 0)],
#  212: [],
#  213: [(['@geoff19542 @StevenOKane2 @pritipatel Where for example',
#     'it',
#     'it',
#     'its'],
#    0),
#   (['it', 'the EU'], 1)],
#  214: [(['the Bucks', 'it'], 0), (['He', 'he', 'his'], 0)],
#  215: [],
#  216: [(['him', 'Erdogan', 'his', 'him'], 1),
#   (['them', 'them', 'them', '4.5 million innocent refugees'], 3),
#   (['you', 'you'], 0)],
#  217: [(['@pritipatel', 'it'], 0)],
#  218: [],
#  219: [(['she', 'herself', 'nine - year - old Rosie', 'Rosie', 'she', 'her'],
#    2)],
#  220: [],
#  221: [(['We', 'we', 'our', 'us'], 3)],
#  222: [(['the whole country', 'that'], 0)],
#  223: [(['They', 'they', 'they'], 2)],
#  224: [(['@SevgiAkarcesme', 'They', 'their'], 0)],
#  225: [],
#  226: [],
#  227: [(['They', 'they', 'They', 'them', 'them', 'their'], 0),
#   (['50 billion dollars', 'it'], 0)],
#  228: [(['Two reporters working for German broadcaster ARD',
#     'The journalists'],
#    0)],
#  229: [],
#  230: [],
#  231: [(['our', 'our'], 1), (['our soldiers', 'our neighbors'], 1)],
#  232: [(['people', 'their', 'they'], 0)],
#  233: [],
#  234: [(['greece', 'greece'], 0),
#   (['@Jasonsnapsback @emptycitysquare @jensstoltenberg @RTErdogan @NATO', 'I'],
#    0),
#   (['you', 'you', 'you', 'you'], 3)],
#  235: [(['you', 'your', 'you'], 2), (['their', 'they'], 1)],
#  236: [(['@OG_Whisper @drjanaway @Nigel_Farage', 'it'], 0)],
#  237: [],
#  238: [(['Moria', 'Moria'], 0), (['We', 'We', 'we', 'we'], 3)],
#  239: [],
#  240: [(['I', 'I'], 0)],
#  241: [(['People', 'they'], 0)],
#  242: [(['I', 'I', 'I', 'I', 'me', 'I'], 3),
#   (['Afghanistan', 'the country'], 0)],
#  243: [(['they', 'Turkish reporters'], 1)],
#  244: [(['we', 'we', 'we', 'we'], 0), (['this house', 'a broken house'], 1)],
#  245: [(['asylum', 'asylum'], 0), (['Those in France', 'they'], 0)],
#  246: [(['You', 'you'], 0),
#   (['they', 'they', 'them', 'the run away Turks who ask for Asylum in Greece'],
#    3)],
#  247: [],
#  248: [(['So many Greeks and Turks', 'they'], 0),
#   (['This', 'the Greek refugees from Turkey'], 1),
#   (['I', 'me', 'me'], 0)],
#  249: [(['THEY', 'SPAIN', 'they'], 1)],
#  250: [(['you', 'Your', 'your'], 1)],
#  251: [(['@Nonehoda @BoltRondo Greece', 'it'], 0)],
#  252: [],
#  253: [],
#  254: [(['#Moria camp ＊ ＊ Lesvos', 'the Moria refugee camp'], 1)],
#  255: [(['I', 'I', 'I', 'my'], 2)],
#  256: [(['many refugees in my country from Greece', 'them'], 0),
#   (['Greece', 'Greece'], 1)],
#  257: [(['them', '#Refugees in Greece'], 1)],
#  258: [(['UNHR', 'our'], 0)],
#  259: [],
#  260: [(['@viking_northern @JoeCar82793574 @mikeclifton65 @benphillips76',
#     'it'],
#    0),
#   (['the immigrants', 'they', 'they'], 0)],
#  261: [(['you', 'your'], 0), (['They', 'They', 'them'], 0)],
#  262: [(['They', 'their', 'Your anchestors', 'them', 'them', 'they'], 2),
#   (['Your', 'your', 'You'], 0),
#   (['Greece', 'Greece'], 0)],
#  263: [],
#  264: [],
#  265: [(['their', 'these'], 1), (['their', 'the ECtHR'], 1)],
#  266: [(['its', 'the Greek island of Lesbos'], 1)],
#  267: [],
#  268: [],
#  269: [(['Greece', 'Greece'], 1),
#   (['them', 'they', 'them'], 2),
#   (['You', 'You', 'you', 'your', 'you'], 0),
#   (['them', 'them'], 1)],
#  270: [(['you', 'you'], 0)],
#  271: [(['their', 'pro-government people'], 1)],
#  272: [(['they', 'Syrian refugees', 'them'], 1), (['the EU', 'EU'], 0)],
#  273: [],
#  274: [],
#  275: [(['You', 'you'], 0)],
#  276: [(['They', 'they', 'they'], 0)],
#  277: [(['You', 'You', 'you'], 1)],
#  278: [(['He', 'European Union ( EU ) Commission spokesperson Adalbert Jahnz'],
#    1),
#   (['EU', 'EU ) Commission'], 1),
#   (['Greece', 'Greece'], 0)],
#  279: [],
#  280: [],
#  281: [],
#  282: [(['@DTessers @g_mastropavlos', 'they'], 0)],
#  283: [(['Some lucky academics', 'They'], 0)],
#  284: [(['he', 'him', 'him'], 0)],
#  285: [],
#  286: [(['I', 'I'], 0), (['this', 'It', 'it'], 0)],
#  287: [],
#  288: [(['Greece', 'Greece'], 1), (['Europe', 'Europe'], 1)],
#  289: [(['UNITED NATIONS', 'THE UNITED STATES'], 1)],
#  290: [],
#  291: [],
#  292: [(['This',
#     'inhumane measures that violate EU and international law Greece'],
#    1),
#   (['it',
#     'a package of inhumane measures that violate EU and international law Greece'],
#    1)],
#  293: [(['You', 'you', 'you'], 0)],
#  294: [],
#  295: [(['individual member states', 'themselves'], 0)],
#  296: [],
#  297: [(['@ExBulletinUk #ErDOGan', 'him'], 0)],
#  298: [(['their', 'they'], 0),
#   (['them', 'some countries like Greece'], 1),
#   (['You', 'your', 'you'], 1)],
#  299: [],
#  300: [(['she', 'she', 'her', 'German Chancellor Angela Merkel'], 3)],
#  301: [],
#  302: [],
#  303: [],
#  304: [(["Kurz 's", "#Austria 's Sebastian Kurz", 'his'], 1)],
#  305: [(['Moria refugee camp', 'Moria refugee camp'], 1)],
#  306: [],
#  307: [(['@kendi_halimdee @atinadann Btw Turks', 'them'], 0),
#   (['Greece', 'it', 'Greece'], 2)],
#  308: [(['our', 'us'], 1)],
#  309: [(['you', 'you', 'you'], 1), (['they', 'they'], 1)],
#  310: [(['the overcrowded moria refugee camp', 'the camp'], 0)],
#  311: [(['#Refugees in #Greece 🇬🇷 , at Love Welcomes', 'their', 'them'], 0)],
#  312: [(['Greece', 'Greece', 'greece', 'greece'], 0),
#   (['libya', 'libya', 'libya'], 2)],
#  313: [(['Many refugees in Greece struggle', 'they', 'They'], 0)],
#  314: [(['refugees in slow plastic boats', 'them', 'they'], 0)],
#  315: [(['it', 'the right'], 1),
#   (['you', 'you'], 0),
#   (['they', 'they', 'they', 'they'], 0)],
#  316: [],
#  317: [(['I', 'my'], 0)],
#  318: [(['Moria refugee camp', 'its'], 0)],
#  319: [(['the NBA', 'NBA'], 0),
#   (['Masai', 'Masai', 'his', 'Masai'], 0),
#   (['it', 'It'], 1),
#   (['his', 'him'], 1)],
#  320: [(['Greece', 'its'], 0)],
#  321: [(['Greece', 'Greece'], 0)],
#  322: [(['I', 'I'], 0)],
#  323: [],
#  324: [(['it', 'It'], 0)],
#  325: [(["Greece 's migration minister", 'his'], 0),
#   (['them', 'refugee camps'], 1),
#   (["Greece 's", "Greece 's"], 0)],
#  326: [],
#  327: [],
#  328: [],
#  329: [(['you', 'you'], 1)],
#  330: [(['and European asylum law', 'the law'], 0),
#   (['The EU on Thursday', 'EU'], 0)],
#  331: [],
#  332: [(['They', 'they'], 0)],
#  333: [],
#  334: [(['info', 'it'], 0),
#   (['me', 'I', 'I', 'I', 'I', 'I'], 4),
#   (['they', 'they'], 1)],
#  335: [(['@mehmetcelik_43 Greece', 'they'], 0)],
#  336: [(['you', 'you', 'you'], 0), (['greek people', 'their'], 0)],
#  337: [(['Wed.', 'its', 'the migration ministry', 'its'], 0),
#   (['its largest migrant camp of Moria on #Lesbos island', 'the camp'], 0)],
#  338: [(['asylum seekers', 'them'], 0),
#   (['Greece', 'It'], 0),
#   (['its', 'these countries'], 1)],
#  339: [(['@gecekanadi', 'It', 'it'], 0)],
#  340: [],
#  341: [(['He', 'our son in the UK', 'his'], 1)],
#  342: [],
#  343: [],
#  344: [(['you', 'you'], 0)],
#  345: [(['you', 'you'], 0)],
#  346: [(['a trickle', 'it'], 0)],
#  347: [(['TV ‘ Gambia and Nigeria ’', 'Both'], 0)],
#  348: [],
#  349: [],
#  350: [(['they', 'Both migrants & refugees', 'they'], 1)],
#  351: [(['our', 'the DRC', 'our'], 1)],
#  352: [(['themselves',
#     'refugees seeking a new life in Europe',
#     'them',
#     'them'],
#    1)],
#  353: [(['them', 'them', 'asylum seekers'], 2)],
#  354: [],
#  355: [(['Greece', '@AnnoyedMad @fahrettinaltun Greece', 'Greece', 'Greece'],
#    1)],
#  356: [(['They', 'They', 'them', 'they', 'these economic migrants'], 4)],
#  357: [(['Asylum seekers , including #children with disabilities',
#     'them',
#     'their'],
#    0)],
#  358: [(['refugees', 'them'], 0), (['You', 'your'], 0)],
#  359: [(['PKK', 'PKK'], 0),
#   (['thier lands', 'thier lands'], 0),
#   (['Greece', 'Greece', 'Greece'], 0),
#   (['They', 'them'], 0),
#   (['thousands of Turks', 'they'], 0)],
#  360: [(['they', '@suemcdonald342 @GowTolson', 'they', 'their'], 1)],
#  361: [],
#  362: [],
#  363: [(['we', 'our', 'Alan and his brother'], 0)],
#  364: [(['People', 'them'], 0)],
#  365: [(['you', 'You'], 1), (['yourself', 'empathy'], 1)],
#  366: [],
#  367: [],
#  368: [(['Your', 'Your', 'You', 'you', 'you'], 2)],
#  369: [],
#  370: [(['@landofthepower @thisgirlhatestw @doIIyyy @TCB_Green @KsooPreacher @byMadisonHall @trannydiaries Man',
#     'I'],
#    0),
#   (['Anybody with a grain of brain', 'they'], 0),
#   (['It', 'It'], 0)],
#  371: [],
#  372: [],
#  373: [],
#  374: [(['EU', 'EU'], 0), (['UK', 'UK'], 1)],
#  375: [(['He', 'he', 'he'], 0)],
#  376: [(['Europe', 'Europe'], 0)],
#  377: [(['You', 'your', 'You'], 0), (['I', 'me'], 0)],
#  378: [],
#  379: [(['you', 'you', 'your', 'you', 'you'], 0)],
#  380: [],
#  381: [],
#  382: [(['50000 refugees', 'the refugees'], 0)],
#  383: [],
#  384: [],
#  385: [(['& caregivers', 'their'], 0)],
#  386: [(['them', 'Turkish citizens'], 1), (['We', 'We'], 0)],
#  387: [],
#  388: [(['You', 'your', 'you', 'you', 'you'], 3), (['I', 'I', 'my'], 0)],
#  389: [],
#  390: [],
#  391: [(['Greece', 'Greece', 'it'], 1),
#   (['those migrants', 'migrants'], 0),
#   (['you', 'your'], 0)],
#  392: [(['@Nateo20 @gurdubuim @AnneHerzberg14 @Jerusalem_Post Sure', 'it'], 0),
#   (['they', 'all the NGOs'], 1)],
#  393: [(['These countries', 'they'], 0)],
#  394: [],
#  395: [],
#  396: [(['we', 'we'], 0)],
#  397: [],
#  398: [],
#  399: [(['you', 'you', 'your'], 1),
#   (['This', 'The first case of Covid - 19', 'this'], 1)],
#  400: [(['Greece', 'Greece'], 1),
#   (['UK', 'UK', 'UK'], 1),
#   (['he', 'his', 'him', 'him'], 1),
#   (['EU', 'EU'], 1)],
#  401: [(['Turkey', 'turkey'], 0),
#   (['it', 'anything'], 1),
#   (['them', 'they', 'them'], 2)],
#  402: [(['@terrychristian Our border', 'it'], 0), (['you', 'you'], 1)],
#  403: [(['Turkey', 'Turkey'], 1)],
#  404: [(['they', 'Turkey', 'them'], 1)],
#  405: [],
#  406: [(['@KevMonynys @damocrat @J_Britain_8888 @DavidLammy @GaryLineker As a remainer',
#     'it'],
#    0),
#   (['you', 'your'], 0)],
#  407: [],
#  408: [(['the frauds', 'them'], 0),
#   (['him', 'he'], 0),
#   (['It', '@Minister_Cocoa @DavidLammy @GaryLineker', 'It'], 1)],
#  409: [(['our', 'we'], 1)],
#  410: [],
#  411: [(['This', 'it', 'this'], 2)],
#  412: [(['we', 'the EU'], 1),
#   (['they',
#     'it',
#     '@veryangryhobbit @richard53149126 @AmandeepBhogal @BorisJohnson @pritipatel',
#     'them',
#     'they',
#     'them'],
#    2)],
#  413: [],
#  414: [],
#  415: [],
#  416: [(['They', 'They'], 0)],
#  417: [],
#  418: [(['@daphnetoli', 'it'], 0)],
#  419: [],
#  420: [],
#  421: [],
#  422: [],
#  423: [],
#  424: [],
#  425: [(['migrants', 'them', 'them'], 0), (['our', 'we'], 1)],
#  426: [],
#  427: [],
#  428: [(['We', 'our'], 0),
#   (['Turkey', 'Turkey'], 1),
#   (['The journalists', 'they', 'they'], 0)],
#  429: [(['GER', 'GER'], 1)],
#  430: [(['Greece', 'Greece'], 1),
#   (['they', 'they'], 0),
#   (['Turkey', 'Turkey'], 1)],
#  431: [],
#  432: [(['the UK', 'to the UK'], 1),
#   (['asylum seekers', 'they', 'they', 'they'], 0)],
#  433: [(['me', 'I'], 1), (['It', 'a cursory google search'], 1)],
#  434: [(['you', 'you', 'your'], 0), (['we', 'we'], 0)],
#  435: [],
#  436: [(['the government', 'it'], 0)],
#  437: [(['you', 'you'], 1),
#   (['they', 'these scrounging parasites', 'them'], 1)],
#  438: [(['their', 'Greece 🇬🇷', 'they'], 1)],
#  439: [],
#  440: [],
#  441: [],
#  442: [(['they', 'Italy , Greece and Spain'], 1)],
#  443: [],
#  444: [],
#  445: [(['He', 'His', 'His FATHER'], 2), (['your research', 'it'], 0)],
#  446: [(['His', 'Lineker'], 1)],
#  447: [(['The UK', 'the UK'], 1),
#   (['The first countries', 'they', 'them', 'they'], 0)],
#  448: [(['this', 'it'], 0)],
#  449: [(['the World', 'its'], 0),
#   (['Your', 'Your', 'you', 'your'], 0),
#   (['PKK , ISIS , FETO', 'PKK'], 1)],
#  450: [(['Greece', 'its'], 0)],
#  451: [],
#  452: [(['her',
#     'She',
#     'Yusra Mardini , fleeing the Syrian war',
#     'Yusra',
#     'her'],
#    2)],
#  453: [(['the city', 'Athens'], 1)],
#  454: [(['Lineker', 'he', 'he'], 0),
#   (['it', 'the plight of refugees', 'it'], 1)],
#  455: [(['the EU', 'it'], 0),
#   (['We', 'we'], 0),
#   (['it', 'it', 'the absolute bare minimum'], 2)],
#  456: [],
#  457: [],
#  458: [],
#  459: [],
#  460: [(['Turkey ’s', 'Turkey', 'it'], 0),
#   (['they', 'the EU countries', 'they'], 1)],
#  461: [],
#  462: [(['about 6000 native residents', 'They'], 0)],
#  463: [(['Erdogan', 'his'], 0), (['they', 'the two journos'], 1)],
#  464: [],
#  465: [(['we', 'we', 'our'], 0)],
#  466: [],
#  467: [(['It', 'Dear Minister @nmitarakis , COVID19 in #Moria'], 1)],
#  468: [],
#  469: [],
#  470: [(['I', 'my'], 0), (['my Somali brothers and sisters', 'they'], 0)],
#  471: [(['My', 'My'], 0),
#   (['My mother', 'her mother , 25'], 1),
#   (['Her', 'My grandmother', 'She', 'her'], 1)],
#  472: [],
#  473: [],
#  474: [(['us', 'refugees', 'they', 'they', 'they', 'they', 'they'], 1)],
#  475: [(['them', 'Migrants'], 1)],
#  476: [],
#  477: [],
#  478: [],
#  479: [(['They', 'them', 'these refugees'], 2)],
#  480: [(['them', '1000 immigrants'], 1)],
#  481: [(['Greece', 'Lesbos Greece', 'the island of Lesbos'], 1),
#   (['his', 'the infected man'], 1)],
#  482: [],
#  483: [(['#Greece', 'its'], 0)],
#  484: [],
#  485: [],
#  486: [],
#  487: [(['@CaliShirogane', 'it'], 0)],
#  488: [],
#  489: [],
#  490: [(['This', "my father - in - law 's parents"], 1)],
#  491: [(['Things', 'they', 'they', 'them', 'they', 'their', 'their'], 0)],
#  492: [],
#  493: [(['We', 'Our'], 0)],
#  494: [(['you', 'you', 'your'], 0),
#   (['We', 'we'], 1),
#   (['These journalists', 'they'], 0)],
#  495: [(['@The_Turk1923 @yrys88 @fank7 @mpparloglou @NathalieTocci @ConvSix @michaeltanchum No',
#     'it'],
#    0),
#   (['their', 'they'], 1)],
#  496: [(['Turkey', 'Turkey'], 1)],
#  497: [],
#  498: [(['they',
#     'they',
#     'they',
#     '@dspalding74 @CowenJones2 @Nigel_Farage Greece',
#     'they',
#     'they',
#     'them'],
#    3),
#   (['you', 'you'], 1)],
#  499: [(['baby Alan', 'Alan Kurdi'], 1)],
#  500: [(['you', 'You', 'you'], 2), (['they', 'they'], 0)],
#  501: [],
#  502: [(['Our', 'Our'], 0)],
#  503: [(['They', 'They', 'them'], 1)],
#  504: [],
#  505: [(['themselves',
#     'refugees seeking a new life in Europe',
#     'them',
#     'them'],
#    1)],
#  506: [],
#  507: [(['They',
#     'Illegal immigrants',
#     'their',
#     'them',
#     'their',
#     'they',
#     'they',
#     'they'],
#    1)],
#  508: [(['I', 'I'], 0),
#   (['@nutts_mutts @AndrewBooton', 'it', 'it'], 0),
#   (['you', 'you'], 0)],
#  509: [(['@MSF', 'its', 'its'], 0)],
#  510: [(['others', 'their'], 0)],
#  511: [],
#  512: [],
#  513: [],
#  514: [(['1,000 refugees', 'them'], 0)],
#  515: [(['they', 'they', 'Turks'], 2)],
#  516: [],
#  517: [(['them', 'Syrians', 'them', 'they'], 1)],
#  518: [(['it', '@DrHuseyin_Demir @yurdunutamseven @oulosP', 'it'], 1),
#   (['them', "anyway.Also Greece 's borders"], 1),
#   (['we', 'we'], 0)],
#  519: [],
#  520: [(['they', 'illegal immigrants'], 1), (['you', 'you'], 0)],
#  521: [(['us', 'our'], 1), (['you', 'your'], 0)],
#  522: [(['you', 'You', 'you', 'you', 'you'], 2), (['We all', 'Our'], 0)],
#  523: [(['they',
#     '@RobertN51219021 @Betty35143876 @Rosemarie593 @PatriotActive66',
#     'they',
#     'their',
#     'they',
#     'they',
#     'their'],
#    1)],
#  524: [(['the refugees', 'refugees'], 0),
#   (['you', 'you', 'your', 'your'], 0),
#   (['This Country', 'The country'], 0)],
#  525: [(['Moria refugee camp under quarantine', 'the Moria refugee camp'], 1)],
#  526: [(['UK', 'UK'], 1)],
#  527: [(['the cases', 'this'], 0),
#   (['we', 'ICJ'], 1),
#   (['@DrManha84708484 @kostaslondon21 @oppopopo7 @michaeltanchum', 'it'], 0)],
#  528: [],
#  529: [],
#  530: [],
#  531: [],
#  532: [],
#  533: [(['us', 'The Turks', 'The Turks'], 1)],
#  534: [],
#  535: [(['toilet papet', 'their'], 0)],
#  536: [],
#  537: [],
#  538: [(['Sea Between Turkey', 'Sea Between Turkey'], 1),
#   (['Greece', 'Greece'], 1),
#   (['Refugees', 'Refugees'], 0)],
#  539: [(['it',
#     '@ikalush2 @fank7 @NathalieTocci @ConvSix @michaeltanchum Turkey',
#     'it'],
#    1)],
#  540: [(['them', 'about 1 million Syrian Kurds refugees'], 1),
#   (['you', 'you', 'your'], 0)],
#  541: [(['#Lesvos #Greece', 'its'], 0),
#   (['the #Moria camp in #Lesvos #Greece', 'this refugee camp'], 0)],
#  542: [(['them', 'them', 'they', 'them', 'them'], 2)],
#  543: [],
#  544: [(['it', 'it', 'it'], 1)],
#  545: [(['they', 'both the French & British governments', 'them'], 1),
#   (['@cmlconsultants', 'It', 'it'], 0)],
#  546: [],
#  547: [],
#  548: [(['it',
#     'An overcrowded migrant camp on the Greek island of Lesbos',
#     'the Moria migrant camp',
#     'its'],
#    1),
#   (['Lesbos', 'its'], 0)],
#  549: [(['Greece', 'Greece'], 0)],
#  550: [],
#  551: [(['Most people', 'they', 'them'], 0)],
#  552: [(['England', "England 's"], 1)],
#  553: [(['France',
#     '@lliksmar @jackbeaumontt @Nigel_Farage France',
#     'they',
#     'they',
#     'it'],
#    1)],
#  554: [(['@NadiaWhittomeMP @paulmasonnews', 'they'], 0)],
#  555: [],
#  556: [],
#  557: [(['the Law', 'it'], 0)],
#  558: [],
#  559: [],
#  560: [],
#  561: [],
#  562: [(['the refugee camp of Moria', 'an overcrowded refugee camp'], 1)],
#  563: [],
#  564: [(['the laughing stock', 'its', 'its'], 0),
#   (['I', 'I', 'I'], 1),
#   (['we', 'we', 'We'], 1),
#   (['these immigrants', 'them', 'them'], 0)],
#  565: [(['https://t.co/yeoriiasEZ', 'it'], 0)],
#  566: [(['Greek', 'Greek'], 0), (['Turks', 'Turks'], 0)],
#  567: [(['@OnlyGodwjudgeme @koertdebeuf', 'It', 'i', 'it', 'he'], 0)],
#  568: [(['migrants', 'them'], 0)],
#  569: [],
#  570: [(['we', 'our'], 0)],
#  571: [],
#  572: [(['@Bella___Trixxx Safe and legal routes',
#     'they',
#     'these people',
#     'they',
#     'they',
#     'they'],
#    0)],
#  573: [(['@NadiaWhittomeMP', 'They', 'They', 'they'], 0)],
#  574: [(['our', 'We', 'we'], 1),
#   (['@Panagiotiso @koertdebeuf', 'It'], 0),
#   (['them', 'they', 'they'], 0)],
#  575: [(['@ShawseyColin @Paul_Robinson01 @lindsaypuppyd @NadiaWhittomeMP',
#     'I'],
#    0)],
#  576: [],
#  577: [],
#  578: [],
#  579: [(['@NadiaWhittomeMP Rubbish', 'they'], 0)],
#  580: [(['you', 'you'], 0),
#   (['great bussines with NGO and immigrant.Stop', 'them'], 0)],
#  581: [(['they', '@TasoulisKostas @trtbreaking Same as in Greece there'], 1)],
#  582: [(['We', 'We', 'we'], 0)],
#  583: [(["IRC 's", 'we'], 0)],
#  584: [],
#  585: [],
#  586: [],
#  587: [],
#  588: [(['you', 'your'], 0),
#   (['we', 'our', 'our', 'our'], 0),
#   (['It', 'our work'], 1)],
#  589: [],
#  590: [],
#  591: [(['Moria camp', 'it'], 0), (['15 thousand refugees in it', 'this'], 0)],
#  592: [(['He', 'he'], 1)],
#  593: [],
#  594: [(['you', 'You', 'you', 'you'], 1),
#   (['Greeks', 'greeks', 'we', 'we'], 0)],
#  595: [],
#  596: [(['It', '@NathalieTocci @ConvSix @michaeltanchum Greece'], 1)],
#  597: [],
#  598: [],
#  599: [],
#  600: [(['He', "#Greece 's Shipping Minister @G_Plakiotakis"], 1)],
#  601: [(['you', 'you'], 1)],
#  602: [],
#  603: [(['Moria Camp', 'its'], 0)],
#  604: [],
#  605: [(['Greece', 'Greece'], 0)],
#  606: [(['He', 'he', 'his'], 1)],
#  607: [(['Greece', 'Greece'], 1)],
#  608: [],
#  609: [],
#  610: [(['They', 'the greeks'], 1)],
#  611: [],
#  612: [],
#  613: [],
#  614: [(['The IRC', 'its'], 0)],
#  615: [(['the Syrian refugee crisis', 'it'], 0),
#   (['They', 'thousands of refugees'], 1)],
#  616: [],
#  617: [],
#  618: [(['BVMN', 'We'], 0)],
#  619: [(['The image of the little boy', 'It'], 0),
#   (['Aylan Kurdi , a Syrian refugee toddler', 'the little boy', 'his', 'his'],
#    0)],
#  620: [],
#  621: [],
#  622: [(['High crime', 'it'], 0)],
#  623: [],
#  624: [(['you', 'your'], 0)],
#  625: [],
#  626: [],
#  627: [(['it', 'a hard deal'], 1)],
#  628: [(["the boys '",
#     'two boys who drowned in the Mediterranean Sea after a boat loaded with Syrians'],
#    1)],
#  629: [(["Alan Kurdi 's", 'Syrian boy Alan Kurdi'], 1)],
#  630: [(['The camp', 'the camp'], 0)],
#  631: [(['the camp', 'its', 'Greece ’s Moria migrant camp'], 2)],
#  632: [(['he', 'he'], 0)],
#  633: [],
#  634: [],
#  635: [],
#  636: [(['I', 'I'], 1)],
#  637: [(['he', 'him', 'Giannis', 'he', 'he'], 2),
#   (['Italians who saw a picture of them sitting on a bench', 'them'], 0)],
#  638: [],
#  639: [],
#  640: [],
#  641: [(['EU', 'according to EU'], 1)],
#  642: [(['them', 'the Refugees', 'the Refugees'], 2)],
#  643: [(['you', 'you', 'You', 'you', 'your', 'your'], 2),
#   (['them', 'the fake refugees'], 1)],
#  644: [(['Greece', 'they'], 0)],
#  645: [(['I', 'I'], 0)],
#  646: [(['the refugee crisis', 'the crisis'], 0), (['This', 'this'], 1)],
#  647: [],
#  648: [(['They', '@Dim_vrou @patsopat1 @CVouzikas @dodobir @e_amyna Refugees'],
#    1)],
#  649: [(['they', 'Many white - collar Turks'], 1)],
#  650: [(['Greece', 'Greece'], 0),
#   (['They',
#     'Their',
#     '@Dim_vrou @patsopat1 @CVouzikas @dodobir @e_amyna Refugees',
#     'them',
#     'they'],
#    2)],
#  651: [],
#  652: [],
#  653: [(['their', 'them', 'beating up innocent refugees'], 2)],
#  654: [],
#  655: [],
#  656: [(['our', 'our', 'our'], 0)],
#  657: [(['Greece', 'Greece', 'Greece'], 0)],
#  658: [(['we', 'EU'], 1)],
#  659: [],
#  660: [],
#  661: [],
#  662: [],
#  663: [],
#  664: [(['them', 'them'], 1)],
#  665: [(['you', 'you', 'you'], 0)],
#  666: [(['we', 'we'], 1), (['this commitment', 'that commitment'], 0)],
#  667: [(['they', 'Malta , Italy , Spain & Greece', 'them', 'they'], 1)],
#  668: [],
#  669: [(['@ayeemandaa7 Whites in Ancient Greece', 'They', 'their'], 0),
#   (['their', 'the native population', 'they'], 1),
#   (['their gods', 'their Gods'], 1)],
#  670: [],
#  671: [],
#  672: [],
#  673: [],
#  674: [(['we', 'we'], 1), (['they', 'them'], 0)],
#  675: [],
#  676: [(['it', 'a country'], 1)],
#  677: [],
#  678: [],
#  679: [(['Africa', 'Africa'], 0),
#   (['their', 'migrants from Africa', 'they'], 1)],
#  680: [(['we', 'we'], 0)],
#  681: [(['its', 'https://t.co/UEOCZSeZZP Greece'], 1)],
#  682: [],
#  683: [(['3 - year - old Syrian refugee #AlanKurdi', 'his'], 0)],
#  684: [],
#  685: [(['their',
#     'them',
#     'Doctors Without Borders from the end of July',
#     'their'],
#    2)],
#  686: [],
#  687: [(['he', 'The man', 'He'], 1)],
#  688: [(['both sides', 'that'], 0),
#   (['@SouthMacedon @NemesisGRE @michaeltanchum Hamas', 'them', "'em", 'them'],
#    0),
#   (['our', "Turkey 's"], 1)],
#  689: [(['migrants', 'their', 'them'], 0)],
#  690: [(['we', 'We', 'we', 'we'], 2),
#   (['Greece', 'Greece'], 0),
#   (['them', 'them', 'them', 'them', 'they'], 2)],
#  691: [(['Greece on Wednesday', 'its'], 0),
#   (['The case',
#     'its first #coronavirus case in the #Moria migrant camp on the island of Lesbos'],
#    1)],
#  692: [],
#  693: [(['Migrant camp in #Greece', 'its'], 0)],
#  694: [(['Greece', 'Greece'], 1), (['them', 'them', 'they'], 1)],
#  695: [],
#  696: [(['He',
#     'He',
#     '@RusticStoat @nstamouli The 40 year old man from Somalia'],
#    2)],
#  697: [],
#  698: [],
#  699: [],
#  700: [(['this country', 'its'], 0)],
#  701: [(['this country', 'its'], 0)],
#  702: [(['I', 'I'], 0)],
#  703: [],
#  704: [(['Turkey', 'Turkey'], 1)],
#  705: [],
#  706: [],
#  707: [(['Greece', "the country 's"], 0),
#   (['more than 1,000 migrants', 'them', 'them'], 0)],
#  708: [],
#  709: [],
#  710: [],
#  711: [(['#Moria camp', 'the camp'], 0)],
#  712: [],
#  713: [(['Moria camp on Greek island of Lesvos', 'the camp'], 0)],
#  714: [],
#  715: [],
#  716: [],
#  717: [(['Turkey', 'Turkey'], 1), (['they', 'them', 'Kurds'], 2)],
#  718: [],
#  719: [(['I', 'my'], 0)],
#  720: [(['you', 'you'], 0),
#   (['@finance_econom @Darksign0 @MechanismThat @YusufErim34 @SNoutso',
#     'they',
#     'They',
#     'They',
#     'them',
#     'they'],
#    0)],
#  721: [],
#  722: [(['Turkey', 'Turkey', 'Turkey'], 0), (['Greece', 'Greece'], 1)],
#  723: [],
#  724: [(['asylum seekers', 'them'], 0)],
#  725: [(['the camp', 'Moria Refugee Camp'], 1)],
#  726: [(['It', 'it', 'it'], 0),
#   (['Brissy', 'it'], 0),
#   (['I', 'I', 'My', 'My', 'I'], 0)],
#  727: [(['the places', 'they'], 0), (['you', 'your'], 1)],
#  728: [(['it',
#     'it',
#     '@MARIOSAN110 @Axios_Esti @WIONews @ronurerim @SaroyaHem turkey'],
#    2),
#   (['them', 'havock in the region , plus refugees'], 1)],
#  729: [],
#  730: [(['I', 'My'], 0),
#   (['My Greek uncle', 'him'], 0),
#   (['We', 'us', 'we'], 1)],
#  731: [],
#  732: [(['this', 'it', 'it'], 0)],
#  733: [(["Europe 's", 'Europe'], 0), (['them', 'them', 'they', 'them'], 1)],
#  734: [(['#Moria camp', 'the camp'], 0)],
#  735: [(['He',
#     'he',
#     'A 40 - year - old man from Somalia who has been granted asylum'],
#    2)],
#  736: [],
#  737: [(['the refugee camp of #Moria in Greece', 'the camp'], 0)],
#  738: [(['Athens', 'Athens'], 1)],
#  739: [(['the others.This mindset', 'itself'], 0),
#   (['They', 'them', 'theirs'], 0)],
#  740: [],
#  741: [],
#  742: [(['@GreekAnalyst Moria', 'it'], 0),
#   (['Greece', 'Greece'], 0),
#   (['they', 'Murderers in Greece'], 1)],
#  743: [(['ISIS', 'Syria , Iraq & Libya'], 0)],
#  744: [(['over 1000 African immigrants men , women and children', 'them'], 0)],
#  745: [],
#  746: [(['It', 'the first case of COVID - 19'], 1)],
#  747: [(['Greece', 'Greece'], 1), (['you', 'you'], 0)],
#  748: [(['1,000 refugees', 'them'], 0)],
#  749: [],
#  750: [],
#  751: [],
#  752: [],
#  753: [(['the mainland', 'the mainland'], 1), (['Asylum seekers', 'they'], 0)],
#  754: [(['@matthewcassel', 'I'], 0)],
#  755: [(['Israelis', 'Israelis', 'they', 'Israelis', 'they'], 1)],
#  756: [],
#  757: [(['He', 'A 40 year old man', 'he'], 1)],
#  758: [(['This', 'One 40 - yo man'], 1)],
#  759: [(['immigrants', 'They'], 0)],
#  760: [(['you', 'you', 'you'], 2)],
#  761: [(['we', 'we'], 0), (['others', 'they', 'they'], 0)],
#  762: [(['you', 'your', 'you'], 1),
#   (['my dream , clever and educated turk', 'your dream'], 0)],
#  763: [(['Greece', 'Greece'], 1), (['I', 'I', 'I', 'I'], 0)],
#  764: [(['we', 'we', 'ourselves', 'our'], 1)],
#  765: [(['we', 'we'], 1)],
#  766: [(['them', 'We', 'Yunus Cansu and his 3 yo son Hasan'], 2)],
#  767: [(['other #European countries', 'them'], 0)],
#  768: [(['its', '#Greece'], 1)],
#  769: [(['Pontians who came to Greece via the 1923 Lausanne Convention',
#     'they'],
#    0),
#   (['Greece', 'Greece', 'Greece'], 1)],
#  770: [],
#  771: [(['@PaulineHansonOz', 'it'], 0)],
#  772: [(['it', 'asylum', 'it'], 1),
#   (['Greece', 'Greece', 'Greece'], 2),
#   (['them', 'European countries', 'them', 'them'], 1)],
#  773: [(['Greece', '#Greece'], 0)],
#  774: [(['more than 1,000 migrants', 'them'], 0)],
#  775: [],
#  776: [],
#  777: [(['Them', 'women', 'Them'], 1)],
#  778: [],
#  779: [(['the refugees', '@ErsaiaGR @GAITAMIMI1 Refugees in Saudia'], 1)],
#  780: [(['Greece', "Greece 's"], 1), (['you', 'you'], 1)],
#  781: [],
#  782: [(['those 100.000 Karamanlides', 'Karamanlides', 'he'], 0)],
#  783: [(['me', 'I', 'me', 'I', 'my'], 1),
#   (['it', 'it'], 0),
#   (['He', 'he', 'him'], 1)],
#  784: [(['they', 'they'], 1),
#   (['the refugee camps in Greece', 'the camps'], 0)],
#  785: [(['I', 'My'], 1), (['you', 'your'], 1)],
#  786: [],
#  787: [],
#  788: [(['it', 'Lesbos', 'its'], 1)],
#  789: [],
#  790: [(['@WilliamBedling1 @terrychristian', 'it'], 0),
#   (['they', 'Italy and Greece'], 1)],
#  791: [],
#  792: [],
#  793: [(['more than 1,000 asylum seekers', 'them'], 0)],
#  794: [],
#  795: [(['the Aegean', 'the Aegean'], 1)],
#  796: [],
#  797: [],
#  798: [],
#  799: [(['Europe', 'Europe'], 0)],
#  800: [],
#  801: [],
#  802: [(['Turkey', '@Amazing96152100 @maanlichtt Uhm Turkey'], 1),
#   (['the refugees EU', 'EU'], 0)],
#  803: [],
#  804: [(['Solidarity', 'our'], 0)],
#  805: [(['them', 'they'], 0)],
#  806: [(["Europe 's", 'Europe'], 0), (['Greece', 'Greece', 'Greece'], 2)],
#  807: [],
#  808: [(['me', 'my'], 1),
#   (['them',
#     'they',
#     'they',
#     'they',
#     'Cameroonian asylum seekers in #Cyprus',
#     'they'],
#    4)],
#  809: [],
#  810: [(['@Bornabrit1', 'It'], 0)],
#  811: [(['Greece', 'Greece'], 1), (['we', 'our'], 0)],
#  812: [(['you', 'you', 'you', 'you', 'you'], 1)],
#  813: [(["Turkey 's", 'Turkey', 'Turkey'], 0),
#   (['EU', 'the EU', 'the EU'], 1),
#   (['Greece', 'It'], 0)],
#  814: [(['all refugees', 'they'], 0)],
#  815: [(['a reason for it', 'it'], 0),
#   (['it', 'a safe zone in Syria eu countries'], 1),
#   (["Turkey 's", 'turkey'], 0)],
#  816: [(['@mandradevazquez @Cengeg @HomoSapienser @JosepBorrellF Everbody',
#     'its'],
#    0),
#   (['their', 'refugees'], 1),
#   (['EU', 'EU'], 0)],
#  817: [(['the virus', 'its'], 0)],
#  818: [(["Greece 's", 'Greece'], 0),
#   (['You', 'you', 'you'], 1),
#   (['@giannis_kalyvas @ragipsoylu', 'it', 'it'], 0)],
#  819: [(['England', 'England'], 0),
#   (['The Scottish and Welsh governments', 'their'], 0)],
#  820: [(['he', 'Donald Trump'], 1)],
#  821: [],
#  822: [(['They', 'they'], 1)],
#  823: [(['them', 'so Greek citizens'], 1)],
#  824: [(['EU', 'the EU'], 1),
#   (['It', '@sfysnkszykln @KalenteridisSav Turkey', 'Turkey', 'it'], 1)],
#  825: [(['their', 'refugees'], 1), (['Syria', 'Syria'], 1)],
#  826: [(['lots of refugee / migrant children', 'they'], 0),
#   (['@TARGARYEN888 Hanks', 'I'], 0)],
#  827: [],
#  828: [(['it', "someone else 's country"], 1)],
#  829: [],
#  830: [],
#  831: [(['Ceren', 'She'], 0), (['My', 'I', 'my'], 0), (['you', 'your'], 0)],
#  832: [],
#  833: [(['Greece', 'greece'], 0)],
#  834: [],
#  835: [(['They',
#     '@Tannie66364346 @abdullahadam @jihadwatchRS @YasMohammedxx Africans'],
#    1)],
#  836: [(['Greece', 'Greece'], 0)],
#  837: [(['@Fattma_20 @cynaegeirus', 'it'], 0), (['You', 'you', 'you'], 0)],
#  838: [(['their', 'they'], 1)],
#  839: [(['Thessaloniki', 'Thessaloniki'], 0), (['We', 'our'], 0)],
#  840: [(['you', 'You'], 0)],
#  841: [],
#  842: [],
#  843: [],
#  844: [(['Germany', 'it'], 0),
#   (['migrants crossing the Mediterranean Sea', 'them', 'their'], 0)],
#  845: [(['#Greece', "the country 's"], 0),
#   (['them', 'more than 1,000 #migrants', 'them'], 1)],
#  846: [(['you', 'You', 'you', 'You'], 1),
#   (['@LeftheriotisC @andreasmoun', 'they', 'them'], 0)],
#  847: [(['We', 'we', 'we', "OCC 's"], 3)],
#  848: [(['the beaches', 'them'], 0)],
#  849: [(['the Sea', 'the sea'], 0),
#   (['their', 'at least 1,072 migrants', 'them'], 1)],
#  850: [(['Greece', 'Greece'], 1),
#   (['@NicAthens @welt', 'It'], 0),
#   (['you', 'you'], 0),
#   (['They', 'them'], 0)],
#  851: [],
#  852: [(['you', 'your'], 0),
#   (['His', 'his'], 0),
#   (['His family', 'they', 'and his family'], 2)],
#  853: [(['I', 'I', 'me'], 0), (['them', 'their', 'they', 'they'], 2)],
#  854: [],
#  855: [(['his', 'Erdogan', 'His', 'he', 'his'], 1),
#   (['His attempt', 'his attempt'], 0)],
#  856: [(['she', 'a white woman', 'she'], 1)],
#  857: [],
#  858: [(['her', 'she'], 0)],
#  859: [(['the UK', 'the UK'], 1)],
#  860: [(['you', 'your', 'you'], 1),
#   (['it', '@TasoulisKostas @YusufErim34 @FerizKsphc @LNationalism', 'it'], 1),
#   (['Greece', 'Greece'], 0)],
#  861: [],
#  862: [],
#  863: [(['our', 'we'], 0)],
#  864: [],
#  865: [],
#  866: [(['the channel', 'the channel'], 1),
#   (['them', 'migrants crossing the channel'], 1)],
#  867: [],
#  868: [(['Turkey', 'TURKEY'], 1),
#   (['Bulgaria', 'Bulgaria', 'Bulgaria'], 2),
#   (['those few thousand refugees', 'them'], 0),
#   (['Greece', 'Greece', 'GREECE'], 0)],
#  869: [(['Greece', 'Greece'], 0), (['EU', 'EU', 'it'], 0)],
#  870: [],
#  871: [(['@BoxingWorldUk @DragonSpirit77', 'they'], 0)],
#  872: [(['@SteveLaws19', 'it'], 0), (['them', 'them', 'them'], 1)],
#  873: [(['them', 'our most modern missile frigates'], 1),
#   (['we', 'our', 'we', 'France and Greece'], 0)],
#  874: [(['It', 'it'], 0)],
#  875: [],
#  876: [(['them', 'them', 'refugees'], 2), (['Greece', 'greece'], 0)],
#  877: [],
#  878: [(['Greece', 'Greece'], 1),
#   (['they', 'refugees', 'them', 'You', 'you', 'them'], 1)],
#  879: [],
#  880: [(['Finland', 'Finland'], 0), (['Greece', 'Greece'], 0)],
#  881: [(['Greece', 'it'], 0), (['you', 'your', 'you'], 0)],
#  882: [(['Turkey', 'Turkey'], 0), (['You', 'You', 'You'], 1)],
#  883: [(['it', 'it'], 1), (['they', 'the EU', 'they'], 1)],
#  884: [(['claiming Paedophilia as a mental illness', 'it'], 0)],
#  885: [(['the country', 'the country'], 0),
#   (['your', 'you'], 0),
#   (['Greece', 'Greece'], 0),
#   (['This', 'More than 3.000.000 illegal immigrants'], 1)],
#  886: [(['they', '@FredKanis @K2Sym @gorfanorfan @sfrantzman @Jerusalem_Post'],
#    1),
#   (['Many Greeks from Anatolia', 'They'], 0)],
#  887: [(['he', 'he', '@Bahriye_Subayi', 'he', 'it'], 2)],
#  888: [(['Greece', 'Greece'], 1),
#   (['UK', 'UK'], 1),
#   (['them', 'these migrants'], 1)],
#  889: [(['it', 'it'], 0)],
#  890: [],
#  891: [(['more than 1,000 migrants', 'them', 'them'], 0),
#   (['Greece', "the country 's", 'THIS', 'THIS', 'THIS'], 0)],
#  892: [(['@Konstan75009430 @the1hierophant Greeks and Arabs', 'they'], 0)],
#  893: [],
#  894: [],
#  895: [],
#  896: [],
#  897: [(['themselves', 'the EU'], 1)],
#  898: [(['EU', 'EU'], 0),
#   (['Turkey', 'Turkey', 'Turkey'], 1),
#   (['They', 'They', 'they'], 0)],
#  899: [(['They', 'they'], 0), (['EU', 'EU'], 0), (['Turkey', 'Turkey'], 0)],
#  900: [],
#  901: [(['you', 'you', 'you'], 1)],
#  902: [],
#  903: [(['Greece', 'its'], 0), (['them', 'these people'], 1)],
#  904: [(['Assad', 'he', 'him', 'his'], 0)],
#  905: [],
#  906: [(['Afghanistan', 'Afghanistan'], 0),
#   (['they',
#     'They',
#     'they',
#     '@AnwarNillufary @UNHCRGreece @FilippoGrandi @UN_HRC @UNGeneva @UN @GRUN_NY @GreekAsylum @Refugees_EU @UNHumanRightsEU @UNHumanRights @UNmigration'],
#    3)],
#  907: [(['they',
#     'They',
#     'they',
#     '@AnwarNillufary @UNHCRGreece @FilippoGrandi @UN_HRC @UNGeneva @UN @GRUN_NY @GreekAsylum @Refugees_EU @UNHumanRightsEU @UNHumanRights @UNmigration'],
#    3)],
#  908: [(['Greece', 'Greece'], 0)],
#  909: [(['he', 'he'], 0)],
#  910: [(['you', 'you'], 0)],
#  911: [],
#  912: [(['@DarrylWhitwort3 @BBCWorld', 'It'], 0)],
#  913: [(['Greece', 'Greece', 'they'], 1)],
#  914: [(['Greece',
#     '@MustafaBB49 @Fattma_20 @finance_econom @anadoluagency Greece'],
#    1),
#   (['your', 'you', 'you'], 1)],
#  915: [(['We', 'We'], 0)],
#  916: [],
#  917: [(['Question kurds', 'they', 'their', 'they', 'their'], 0),
#   (['their countries', 'their countries'], 1)],
#  918: [(['Greece', 'Greece'], 0), (['them', 'migrants'], 1)],
#  919: [],
#  920: [],
#  921: [(['yours', 'you'], 1)],
#  922: [(['You', 'you'], 0), (['Erdogan', 'Erdogan'], 1)],
#  923: [],
#  924: [],
#  925: [(['your', 'you'], 1), (['Greece', 'its'], 0)],
#  926: [(['it', 'It', 'this'], 2)],
#  927: [],
#  928: [(['The refugees', 'them', 'refugees'], 0)],
#  929: [],
#  930: [(['the local greek old timers', 'them', 'them'], 0)],
#  931: [(['its', 'UAE'], 1)],
#  932: [(['they',
#     '@vance_gary @UnC0mm0nS3nse @Treetux @theonlyrymac @motSANTORO @ValHomesby boats'],
#    1)],
#  933: [],
#  934: [(['Turkey', '@EviEvakii @ThePunisher_tur @anadoluagency Turkey'], 1),
#   (['You', 'you'], 0),
#   (['them', 'millions of refugees', 'them'], 1)],
#  935: [],
#  936: [],
#  937: [],
#  938: [(['They', 'their', 'them', 'they'], 2)],
#  939: [(['I', 'I', 'I'], 1)],
#  940: [(['WE', 'our'], 0)],
#  941: [],
#  942: [],
#  943: [],
#  944: [],
#  945: [],
#  946: [],
#  947: [(['our', 'PKK', 'PKK'], 1), (['iraqi government', 'they'], 0)],
#  948: [],
#  949: [(['Greece , Italy and every country in between',
#     'They',
#     'they',
#     'they',
#     'they',
#     'their'],
#    0)],
#  950: [(['you', 'you'], 0),
#   (['it', 'it', 'Greece', 'Greece', 'its', 'its', 'its'], 3)],
#  951: [],
#  952: [(['@Panagiotiso @OnlyGodwjudgeme @koertdebeuf', 'them', 'PKK'], 0),
#   (['Syria', 'Syria'], 1)],
#  953: [],
#  954: [],
#  955: [],
#  956: [(['You', 'You', 'your', 'you', 'your'], 0), (['They both', 'them'], 0)],
#  957: [(['its', 'Turkey'], 1)],
#  958: [],
#  959: [(['We', 'we'], 0)],
#  960: [],
#  961: [],
#  962: [],
#  963: [(['the coup attempt', 'the coup attempt'], 1),
#   (['Greece', 'Greece'], 0)],
#  964: [],
#  965: [],
#  966: [],
#  967: [(['We', 'We', 'our'], 1),
#   (['Greece', 'Greece'], 1),
#   (['EU', 'EU', 'EU'], 0)],
#  968: [(['It', 'It', 'turkey', 'it'], 2)],
#  969: [(['Greece', 'Greece'], 1)],
#  970: [],
#  971: [(['greece', 'Greece'], 0)],
#  972: [(['I', 'I'], 0)],
#  973: [(['You', 'you'], 1), (['their', 'them'], 0)],
#  974: [(['Alan Kurdi and Ghalib', 'their'], 0)],
#  975: [(['they', '@CBSNews', 'their'], 1)],
#  976: [],
#  977: [(['these masks', '10,000 cloth masks'], 1)],
#  978: [(['these people', 'people', 'they'], 0)],
#  979: [],
#  980: [(['my', 'I', 'I', 'i', 'I', 'my', 'my'], 2),
#   (['them', 'the Assad and Russia who killed civilians at my border'], 1)],
#  981: [(['@Harryslaststand', 'It'], 0)],
#  982: [(['they', 'his brother and mother'], 1), (['Sarah Nachar', 'I'], 0)],
#  983: [(['greece', 'its'], 0), (['you', 'You', 'you', 'you'], 1)],
#  984: [(['Greece', 'Greece'], 1),
#   (['Turkey', 'Turkey'], 1),
#   (['them', 'giving Greece refugees', 'them'], 1)],
#  985: [(['it', 'It', 'the vulnerable half of society'], 2),
#   (['refugees', 'their'], 0)],
#  986: [(['Turkey', 'Turkey', 'Turkey'], 0), (['Nazis', 'them'], 0)],
#  987: [(['them', 'them', 'migrants', 'them'], 2)],
#  988: [(['the men', 'they'], 0)],
#  989: [],
#  990: [(['it', 'it'], 0), (['they', 'They'], 1)],
#  991: [],
#  992: [(['Africans', 'them', 'Africans'], 0),
#   (['we', 'we'], 0),
#   (['I', 'I', 'my'], 0)],
#  993: [(['Which country', 'which country', 'which country', 'which country'],
#    0),
#   (['Turkey', 'Turkey', 'Turkey', 'Turkey'], 0)],
#  994: [(['@BBCWorld @bbclysedoucet So obvious immigration', 'it'], 0)],
#  995: [],
#  996: [],
#  997: [(['Greece', 'Greece'], 0), (['They', 'they'], 1)],
#  998: [(['I', 'I'], 0), (['They', 'the southern states'], 1)],
#  999: [(['This', 'this'], 0)],
#  ...}

# %% [markdown]
# ## 11. We determine candidate's type for representative mentions of coref candidates (in batches)

# %%
# Load NPs from pickle file
import pickle

with open(r"moria_tweet_corefs", "rb") as input_file:
    corefs = pickle.load(input_file)

# %%
corefs_list = []

#pick out only the representative mention as the candidate's rep. phrase
for tweet_corefs in dict_of_tweet_corefs:
        tw_corefs = [coref[0][coref[1]] for coref in dict_of_tweet_corefs[tweet_corefs]] 
        # empty list would cause problems in the following steps, that is why we append 'no_candidate' to empty lists
        corefs_list.append(tw_corefs) if len(tw_corefs) != 0 else corefs_list.append(['no_candidate'])

corefs_list
# Out:
# [['No law'],
#  ['You'],
#  ['no_candidate'],
#  ['the law'],
#  ['the asylum seekers'],
#  ['I', 'aesthetic'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Birmingham'],
#  ['you', 'Turkey'],
#  ['Isaac Bessudos', 'Raquel Bessudo'],
#  ['them'],
#  ['you', 'it', 'they'],
#  ['no_candidate'],
#  ['Greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Both men'],
#  ['10 refugees , including three children with disabilities', 'Greece'],
#  ['UN Refugee Agency'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['we'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Enterprise Greece'],
#  ['no_candidate'],
#  ['they'],
#  ['He'],
#  ['Erdoan'],
#  ['UK', 'UK size'],
#  ['no_candidate'],
#  ['The infected person , a 40 year old man', 'the camp', 'Moria', "Didn '"],
#  ['no_candidate'],
#  ['Greece', 'Protection & Operations , @GillianTriggs & @RaoufMazou'],
#  ['greece', 'I', 'you'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['Turkey'],
#  ['I'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ["Don '",
#   'Greece',
#   'Those who seek refuge in Greece , those who want to make a coup',
#   'freedom of expression'],
#  ['no_candidate'],
#  ['2040', 'EU'],
#  ['this poor nation', 'People', 'me'],
#  ['Erdogan', 'Syrian refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['it'],
#  ['your'],
#  ['the 5 + million refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['it', 'you'],
#  ['Greece', 'Assad'],
#  ['the supply of ready - made food'],
#  ['Nigeria', 'He'],
#  ['no_candidate'],
#  ['Assad', 'Greece'],
#  ['We'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['no_candidate'],
#  ['Greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['the uk', "the world ' s refugees"],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Greek immigrants', 'our', 'our culture'],
#  ['You', 'your so called poor refugees'],
#  ['Turkey'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['The funniest thing'],
#  ['I', 'refugees'],
#  ['people', 'i', 'you', 'the EU'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['these people', 'a responsibility'],
#  ['Athens'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['we'],
#  ['Greece', '4 million migrants'],
#  ['the borders', 'You'],
#  ['no_candidate'],
#  ['both aegean and kastelorizo eez', 'Greece', 'Turkey', "this didn '"],
#  ['greece and europe', 'Eedogan'],
#  ['you', 'I'],
#  ['you'],
#  ['you', 'I', 'Iraq', 'Greece'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Eastern Europe'],
#  ['the bosses'],
#  ['they'],
#  ['no_candidate'],
#  ['you'],
#  ['no_candidate'],
#  ['people', 'NYT'],
#  ['My'],
#  ['Those illegally coming by dinghy'],
#  ['Anastasa Sikiaridi'],
#  ['others', 'Our', 'all those'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you'],
#  ['the asylum seekers'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['the asylum system'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you', 'the migrants'],
#  ['no_candidate'],
#  ['vulnerable children'],
#  ['5 billion euros', 'you', 'they'],
#  ['turkey'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['I', 'The situation', 'very few people saying it'],
#  ['t blame Greece', 'the refugees'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Turkey'],
#  ['Mr Stoltenberg', 'Greece', 'EU'],
#  ['no_candidate'],
#  ['the overcrowded migrant camp of Moria on the island of Lesbos',
#   'Moria',
#   'Lesbos',
#   'Sept 2 ( Reuters ) - Greece'],
#  ['i', 'france Germany and Greece'],
#  ['no_candidate'],
#  ['Most people', 'you'],
#  ['the U.K.'],
#  ['no_candidate'],
#  ['children and pregnant women', '@MSF'],
#  ['no_candidate'],
#  ['i', 'the French / EU'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['you', 'Turkey', '6 million Syrian refugees in Turkey', 'Greece'],
#  ['Greece', 'Central Europe', 'their'],
#  ['the UK'],
#  ['everyone', 'you'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Turkey', 'Greece'],
#  ['we', 'the UK', 'Matt'],
#  ['the uk', 'refugees'],
#  ['Moria'],
#  ['you', 'Everyone', 'your money', 'We'],
#  ['no_candidate'],
#  ["the EU '", 'you', "the EU ' s member countries"],
#  ['the overcrowded moria camp'],
#  ['This'],
#  ['just for unidentified migrant bodies from the Mediterranean'],
#  ['I', 'He', 'they'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['our'],
#  ['WE', '@RuhiLoren'],
#  ['us', 'YOU'],
#  ['Erdogan', 'MSM', 'Greece'],
#  ['no_candidate'],
#  ['we'],
#  ['Spring'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['its citizens', 'Its'],
#  ['no_candidate'],
#  ['no_candidate'],
#  ['Greece'],
#  ['Moria Camp',
#   "the first confirmed case of Covid - 19 within the camp ' s population"],
#  ['no_candidate'],
#  ['they', 'Luvvie Flakes'],
#  ['you', 'The EU'],
#  ['the need for teacher compassion', 'me'],
#  ['no_candidate'],
#  ['Greece'],
#  ['no_candidate'],
#  ['Omfg', 'italian immigrants in greece'],
#  ['no_candidate'],
#  ['them']]

# %%
#tag all tweets and save them in a list    
tagged_coref_cands = [] 
batched_coref_list = cand_prep.prep_candlist_for_batching(corefs_list)
print(batched_coref_list)
for tagged_cand in tqdm(batch(batched_coref_list, en_nlp, batch_size=6000)): # Default batch size is 32
        tagged_coref_cands.append(tagged_cand)
        
coref_cand_heads = cand_prep.get_cand_heads(tagged_coref_cands)
coref_cand_heads
# Out:
# 0it [00:00, ?it/s]
# ['No law', 'You', 'no_candidate', 'the law', 'the asylum seekers', 'I\n\naesthetic', 'no_candidate', 'no_candidate', 'Birmingham', 'you\n\nTurkey', 'Isaac Bessudos\n\nRaquel Bessudo', 'them', 'you\n\nit\n\nthey', 'no_candidate', 'Greece', 'no_candidate', 'no_candidate', 'Both men', '10 refugees , including three children with disabilities\n\nGreece', 'UN Refugee Agency', 'no_candidate', 'no_candidate', 'no_candidate', 'we', 'no_candidate', 'no_candidate', 'no_candidate', 'Enterprise Greece', 'no_candidate', 'they', 'He', 'Erdoan', 'UK\n\nUK size', 'no_candidate', "The infected person , a 40 year old man\n\nthe camp\n\nMoria\n\nDidn '", 'no_candidate', 'Greece\n\nProtection & Operations , @GillianTriggs & @RaoufMazou', 'greece\n\nI\n\nyou', 'no_candidate', 'no_candidate', 'no_candidate', 'no_candidate', 'no_candidate', 'you', 'Turkey', 'I', 'no_candidate', 'no_candidate', "Don '\n\nGreece\n\nThose who seek refuge in Greece , those who want to make a coup\n\nfreedom of expression", 'no_candidate', '2040\n\nEU', 'this poor nation\n\nPeople\n\nme', 'Erdogan\n\nSyrian refugees', 'no_candidate', 'no_candidate', 'no_candidate', 'it', 'your', 'the 5 + million refugees', 'no_candidate', 'no_candidate', 'no_candidate', 'no_candidate', 'it\n\nyou', 'Greece\n\nAssad', 'the supply of ready - made food', 'Nigeria\n\nHe', 'no_candidate', 'Assad\n\nGreece', 'We', 'no_candidate', 'no_candidate', 'you', 'no_candidate', 'Greece', 'no_candidate', 'no_candidate', 'no_candidate', "the uk\n\nthe world ' s refugees", 'no_candidate', 'no_candidate', 'Greek immigrants\n\nour\n\nour culture', 'You\n\nyour so called poor refugees', 'Turkey', 'no_candidate', 'no_candidate', 'The funniest thing', 'I\n\nrefugees', 'people\n\ni\n\nyou\n\nthe EU', 'no_candidate', 'no_candidate', 'these people\n\na responsibility', 'Athens', 'no_candidate', 'no_candidate', 'we', 'Greece\n\n4 million migrants', 'the borders\n\nYou', 'no_candidate', "both aegean and kastelorizo eez\n\nGreece\n\nTurkey\n\nthis didn '", 'greece and europe\n\nEedogan', 'you\n\nI', 'you', 'you\n\nI\n\nIraq\n\nGreece', 'no_candidate', 'no_candidate', 'Eastern Europe', 'the bosses', 'they', 'no_candidate', 'you', 'no_candidate', 'people\n\nNYT', 'My', 'Those illegally coming by dinghy', 'Anastasa Sikiaridi', 'others\n\nOur\n\nall those', 'no_candidate', 'no_candidate', 'no_candidate', 'you', 'the asylum seekers', 'no_candidate', 'no_candidate', 'the asylum system', 'no_candidate', 'no_candidate', 'you\n\nthe migrants', 'no_candidate', 'vulnerable children', '5 billion euros\n\nyou\n\nthey', 'turkey', 'no_candidate', 'no_candidate', 'I\n\nThe situation\n\nvery few people saying it', 't blame Greece\n\nthe refugees', 'no_candidate', 'no_candidate', 'Turkey', 'Mr Stoltenberg\n\nGreece\n\nEU', 'no_candidate', 'the overcrowded migrant camp of Moria on the island of Lesbos\n\nMoria\n\nLesbos\n\nSept 2 ( Reuters ) - Greece', 'i\n\nfrance Germany and Greece', 'no_candidate', 'Most people\n\nyou', 'the U.K.', 'no_candidate', 'children and pregnant women\n\n@MSF', 'no_candidate', 'i\n\nthe French / EU', 'no_candidate', 'no_candidate', 'no_candidate', 'you\n\nTurkey\n\n6 million Syrian refugees in Turkey\n\nGreece', 'Greece\n\nCentral Europe\n\ntheir', 'the UK', 'everyone\n\nyou', 'no_candidate', 'no_candidate', 'no_candidate', 'no_candidate', 'no_candidate', 'Turkey\n\nGreece', 'we\n\nthe UK\n\nMatt', 'the uk\n\nrefugees', 'Moria', 'you\n\nEveryone\n\nyour money\n\nWe', 'no_candidate', "the EU '\n\nyou\n\nthe EU ' s member countries", 'the overcrowded moria camp', 'This', 'just for unidentified migrant bodies from the Mediterranean', 'I\n\nHe\n\nthey', 'no_candidate', 'no_candidate', 'our', 'WE\n\n@RuhiLoren', 'us\n\nYOU', 'Erdogan\n\nMSM\n\nGreece', 'no_candidate', 'we', 'Spring', 'no_candidate', 'no_candidate', 'no_candidate', 'its citizens\n\nIts', 'no_candidate', 'no_candidate', 'Greece', "Moria Camp\n\nthe first confirmed case of Covid - 19 within the camp ' s population", 'no_candidate', 'they\n\nLuvvie F ...
# 200it [00:13, 14.92it/s]
# [[[{'law'}, ['law']]],
#  [[{'You'}, ['You']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'law'}, ['law']]],
#  [[{'seekers'}, ['seekers']]],
#  [[{'I'}, ['I']], [{'aesthetic'}, ['aesthetic']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Birmingham'}, ['Birmingham']]],
#  [[{'you'}, ['you']], [{'Turkey'}, ['Turkey']]],
#  [[{'Bessudos', 'Isaac'}, ['Isaac']], [{'Bessudo', 'Raquel'}, ['Raquel']]],
#  [[{'them'}, ['them']]],
#  [[{'you'}, ['you']], [{'it'}, ['it']], [{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'men'}, ['men']]],
#  [[{'children', 'disabilities', 'refugees'}, ['refugees']],
#   [{'Greece'}, ['Greece']]],
#  [[{'Agency'}, ['Agency']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'they'}, ['they']]],
#  [[{'He'}, ['He']]],
#  [[{'Erdoan'}, ['Erdoan']]],
#  [[{'UK'}, ['UK']], [{'size'}, ['size']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'man', 'old', 'person', 'year'}, ['person']],
#   [{'camp'}, ['camp']],
#   [{'Moria'}, ['Moria']],
#   [{"'", 'Didn'}, ['Didn']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Mazou'}, ['Mazou']],
#   [{'Greece'}, ['Greece']],
#   [{'@Raouf', 'GillianTriggs', 'Operations', 'Protection'}, ['Protection']]],
#  [[{'greece'}, ['greece']], [{'I'}, ['I']], [{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'Turkey'}, ['Turkey']]],
#  [[{'I'}, ['I']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{"'", 'Don'}, ['Don']],
#   [{'Greece'}, ['Greece']],
#   [{'Greece', 'Those', 'coup', 'make', 'seek', 'those', 'want'}, ['Those']],
#   [{'expression', 'freedom'}, ['freedom']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'2040'}, ['2040']], [{'EU'}, ['EU']]],
#  [[{'nation'}, ['nation']], [{'People'}, ['People']], [{'me'}, ['me']]],
#  [[{'Erdogan'}, ['Erdogan']], [{'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'it'}, ['it']]],
#  [[{'your'}, ['your']]],
#  [[{'million', 'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'it'}, ['it']], [{'you'}, ['you']]],
#  [[{'Greece'}, ['Greece']], [{'Assad'}, ['Assad']]],
#  [[{'food', 'made', 'supply'}, ['supply']]],
#  [[{'Nigeria'}, ['Nigeria']], [{'He'}, ['He']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Assad'}, ['Assad']], [{'Greece'}, ['Greece']]],
#  [[{'We'}, ['We']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'uk'}, ['uk']], [{'refugees', 'world'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'immigrants'}, ['immigrants']],
#   [{'our'}, ['our']],
#   [{'culture'}, ['culture']]],
#  [[{'You'}, ['You']], [{'called', 'refugees'}, ['refugees']]],
#  [[{'Turkey'}, ['Turkey']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'thing'}, ['thing']]],
#  [[{'I'}, ['I']], [{'refugees'}, ['refugees']]],
#  [[{'people'}, ['people']],
#   [{'i'}, ['i']],
#   [{'you'}, ['you']],
#   [{'EU'}, ['EU']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'responsibility'}, ['responsibility']]],
#  [[{'Athens'}, ['Athens']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'Greece'}, ['Greece']], [{'migrants', 'million'}, ['migrants']]],
#  [[{'borders'}, ['borders']], [{'You'}, ['You']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'aegean', 'eez', 'kastelorizo'}, ['eez']],
#   [{'Greece'}, ['Greece']],
#   [{'Turkey'}, ['Turkey']],
#   [{"'", 'didn'}, ['didn']]],
#  [[{'europe', 'greece'}, ['greece']], [{'Eedogan'}, ['Eedogan']]],
#  [[{'you'}, ['you']], [{'I'}, ['I']]],
#  [[{'you'}, ['you']]],
#  [[{'you'}, ['you']],
#   [{'I'}, ['I']],
#   [{'Iraq'}, ['Iraq']],
#   [{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Europe'}, ['Europe']]],
#  [[{'bosses'}, ['bosses']]],
#  [[{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'NYT'}, ['NYT']]],
#  [[{'My'}, ['My']]],
#  [[{'Those', 'coming', 'dinghy'}, ['Those']]],
#  [[{'Anastasa', 'Sikiaridi'}, ['Anastasa']]],
#  [[{'others'}, ['others']], [{'Our'}, ['Our']], [{'those'}, ['those']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']]],
#  [[{'seekers'}, ['seekers']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'system'}, ['system']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']], [{'migrants'}, ['migrants']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'children'}, ['children']]],
#  [[{'billion', 'euros'}, ['euros']], [{'you'}, ['you']], [{'they'}, ['they']]],
#  [[{'turkey'}, ['turkey']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'I'}, ['I']],
#   [{'situation'}, ['situation']],
#   [{'few', 'it', 'people', 'saying'}, ['people']]],
#  [[{'Greece', 'blame'}, ['blame']], [{'refugees'}, ['refugees']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Turkey'}, ['Turkey']]],
#  [[{'Mr', 'Stoltenberg'}, ['Mr']], [{'Greece'}, ['Greece']], [{'EU'}, ['EU']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Lesbos', 'Moria', 'camp', 'island'}, ['camp']],
#   [{'Moria'}, ['Moria']],
#   [{'Lesbos'}, ['Lesbos']],
#   [{'Greece', 'Reuters', 'Sept'}, ['Sept']]],
#  [[{'i'}, ['i']], [{'Germany', 'Greece'}, ['Germany']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'people'}, ['people']], [{'you'}, ['you']]],
#  [[{'.', 'U.K'}, ['U.K']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'children', 'women'}, ['children']], [{'@MSF'}, ['@MSF']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'i'}, ['i']], [{'EU', 'French'}, ['French']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'you'}, ['you']],
#   [{'Turkey'}, ['Turkey']],
#   [{'Turkey', 'million', 'refugees'}, ['refugees']],
#   [{'Greece'}, ['Greece']]],
#  [[{'Greece'}, ['Greece']], [{'Europe'}, ['Europe']], [{'their'}, ['their']]],
#  [[{'UK'}, ['UK']]],
#  [[{'everyone'}, ['everyone']], [{'you'}, ['you']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Turkey'}, ['Turkey']], [{'Greece'}, ['Greece']]],
#  [[{'we'}, ['we']], [{'UK'}, ['UK']], [{'Matt'}, ['Matt']]],
#  [[{'uk'}, ['uk']], [{'refugees'}, ['refugees']]],
#  [[{'Moria'}, ['Moria']]],
#  [[{'you'}, ['you']],
#   [{'Everyone'}, ['Everyone']],
#   [{'money'}, ['money']],
#   [{'We'}, ['We']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{"'", 'EU'}, ['EU']],
#   [{'you'}, ['you']],
#   [{'EU', 'countries'}, ['countries']]],
#  [[{'camp'}, ['camp']]],
#  [[{'This'}, ['This']]],
#  [[{'Mediterranean', 'bodies'}, ['bodies']]],
#  [[{'I'}, ['I']], [{'He'}, ['He']], [{'they'}, ['they']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'our'}, ['our']]],
#  [[{'WE'}, ['WE']], [{'@RuhiLoren'}, ['@RuhiLoren']]],
#  [[{'us'}, ['us']], [{'YOU'}, ['YOU']]],
#  [[{'Erdogan'}, ['Erdogan']], [{'MSM'}, ['MSM']], [{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'we'}, ['we']]],
#  [[{'Spring'}, ['Spring']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'citizens'}, ['citizens']], [{'Its'}, ['Its']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Greece'}, ['Greece']]],
#  [[{'Camp'}, ['Camp']], [{'Covid', 'camp', 'case', 'population'}, ['case']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'they'}, ['they']], [{'Flakes'}, ['Flakes']]],
#  [[{'you'}, ['you']], [{'EU'}, ['EU']]],
#  [[{'compassion', 'need'}, ['need']], [{'me'}, ['me']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Greece'}, ['Greece']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'Omfg'}, ['Omfg']], [{'greece', 'immigrants'}, ['immigrants']]],
#  [[{'no_candidate'}, ['no_candidate']]],
#  [[{'them'}, ['them']]]]

# %%
coref_and_cand_list = cand_prep.get_cand_type(corefs_list, coref_cand_heads, tweet_tags, cand_types_dict, corefs=True)


print(coref_and_cand_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 636.95it/s]
# [[('No law', 'law', {'law'}, 'misc')], [('You', 'You', {'You'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('the law', 'law', {'law'}, 'misc')], [('the asylum seekers', 'seekers', {'seekers'}, 'person-nns')], [('I', 'I', {'I'}, 'misc'), ('aesthetic', 'aesthetic', {'aesthetic'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('Birmingham', 'Birmingham', {'Birmingham'}, 'loc-ne')], [('you', 'you', {'you'}, 'misc'), ('Turkey', 'Turkey', {'Turkey'}, 'loc-ne')], [('Isaac Bessudos', 'Isaac', {'Bessudos', 'Isaac'}, 'person-ne'), ('Raquel Bessudo', 'Raquel', {'Bessudo', 'Raquel'}, 'person-ne')], [('them', 'them', {'them'}, 'misc')], [('you', 'you', {'you'}, 'misc'), ('it', 'it', {'it'}, 'misc'), ('they', 'they', {'they'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('Greece', 'Greece', {'Greece'}, 'loc-ne')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('Both men', 'men', {'men'}, 'group')], [('10 refugees , including three children with disabilities', 'refugees', {'children', 'disabilities', 'refugees'}, 'person-nes'), ('Greece', 'Greece', {'Greece'}, 'loc-ne')], [('UN Refugee Agency', 'Agency', {'Agency'}, 'group-ne')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('we', 'we', {'we'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('Enterprise Greece', 'Greece', {'Greece'}, 'group-ne')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('they', 'they', {'they'}, 'misc')], [('He', 'He', {'He'}, 'misc')], [('Erdoan', 'Erdoan', {'Erdoan'}, 'person-ne')], [('UK', 'UK', {'UK'}, 'loc-ne'), ('UK size', 'size', {'size'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('The infected person , a 40 year old man', 'person', {'man', 'person', 'year', 'old'}, 'person-ne'), ('the camp', 'camp', {'camp'}, 'group'), ('Moria', 'Moria', {'Moria'}, 'loc-ne'), ("Didn '", 'Didn', {"'", 'Didn'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('Greece', 'Mazou', {'Mazou'}, 'group-ne'), ('Protection & Operations , @GillianTriggs & @RaoufMazou', 'Greece', {'Greece'}, 'loc-ne')], [('greece', 'greece', {'greece'}, 'misc'), ('I', 'I', {'I'}, 'misc'), ('you', 'you', {'you'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('you', 'you', {'you'}, 'misc')], [('Turkey', 'Turkey', {'Turkey'}, 'loc-ne')], [('I', 'I', {'I'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [("Don '", 'Don', {"'", 'Don'}, 'person-nn'), ('Greece', 'Greece', {'Greece'}, 'loc-ne'), ('Those who seek refuge in Greece , those who want to make a coup', 'Those', {'Greece', 'coup', 'make', 'want', 'those', 'seek', 'Those'}, 'misc'), ('freedom of expression', 'freedom', {'expression', 'freedom'}, 'misc')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('2040', '2040', {'2040'}, 'misc'), ('EU', 'EU', {'EU'}, 'group-ne')], [('this poor nation', 'nation', {'nation'}, 'group'), ('People', 'People', {'People'}, 'misc'), ('me', 'me', {'me'}, 'misc')], [('Erdogan', 'Erdogan', {'Erdogan'}, 'person-ne'), ('Syrian refugees', 'refugees', {'refugees'}, 'person-nes')], [('no_candidate', 'no_candidate', {'no_candidate'}, 'misc')], [('no_candidate', 'no_candidate', {' ...

# %% [markdown]
# ## 12. We combine the candidate lists for candidate merging
#
# We organize candidates in a list sorted by their number of phrases

# %%
#concatenate corefs and noun phrase lists
nps_cands = [cand for cands in np_and_cand_list for cand in cands]
crf_cands = [cand for cands in coref_and_cand_list for cand in cands]
#candidate_list = coref_and_cand_list + np_and_cand_list
#print(f'Len = {len(candidate_list)} should be 2x amount of tweets')
print(len(nps_cands), len(crf_cands))
#unpack list of lists into one list
candidate_list = nps_cands + crf_cands
print(f'The amount of all candidates is {len(candidate_list)}')
# Out:
# 1432 288
# The amount of all candidates is 1720

# %%
nps_tagged = [sent for tagged_cand in tagged_np_cands for sent in tagged_cand.sentences ]
crf_tagged = [sent for tagged_cand in tagged_coref_cands for sent in tagged_cand.sentences ]
print(len(nps_tagged), len(crf_tagged))
all_cands_tagged = nps_tagged + crf_tagged
# Out:
# 1439 289
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-395-696f0f97d118> in <module>
#       8 cand_df = pd.DataFrame(
#       9     {'candidates': candidate_list,
# ---> 10      'cand_tags': all_cands_tagged
#      11     })
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
print(len(candidate_list))
print(len(all_cands_tagged))
# Out:
# 1720
# 1728

# %%
all_cands_tagged.remove(all_cands_tagged[number+1])
#all_cands_tagged[number].text = all_cands_tagged[number].text + all_cands_tagged[number+1].text

# %%
number = 1477
print(all_cands_tagged[number].text)
print(candidate_list[number][0])
# Out:
# no_candidate
# no_candidate

# %%
indices_to_remove = set()
for i in range(len(all_cands_tagged)):
    #print(f'{i}: {candidate_list[i][0]} = {all_cands_tagged[i].text}')
    #print(indices_to_remove)
    if candidate_list[i][0] != all_cands_tagged[i].text:
        print(indices_to_remove)
        indices_to_remove.add(i)

print(indices_to_remove)
# Out:
# set()

# %%
cand_df = pd.DataFrame(
    {'candidates': candidate_list,
     'cand_tags': all_cands_tagged
    })

cand_df['cand_text'] = cand_df.candidates.apply(lambda x: x[0])
cand_df['cand_len'] = cand_df.cand_text.apply(lambda x: len(x.split()))
cand_df.columns = cand_df.columns.str.strip()
cand_df
# Out:
#                                              candidates  \
# 0     (Morocco Tunisia Libya Greece Turkey Each one ...
# 1     (population & children for 39%, of whom more t...
# 2     (access to territory & asylum, living conditio...
# 3     (conditions + reduce overcrowding at the recep...
# 4     (economic migrants who cross developed nations...
# ...                                                 ...
# 1715                (they, any, {countries, any}, misc)
# 1716         (connector, connector, {connector}, group)
# 1717             (barriers, barriers, {barriers}, misc)
# 1718                   (others, others, {others}, misc)
# 1719                         (them, them, {them}, misc)
#
#                                               cand_tags  \
# 0     [\n  {\n    "id": 1,\n    "text": "it",\n    "...
# 1     [\n  {\n    "id": 1,\n    "text": "asylum",\n ...
# 2     [\n  {\n    "id": 1,\n    "text": "3",\n    "l...
# 3     [\n  {\n    "id": 1,\n    "text": "HU",\n    "...
# 4     [\n  {\n    "id": 1,\n    "text": "They",\n   ...
# ...                                                 ...
# 1715  [\n  {\n    "id": 1,\n    "text": "no_candidat...
# 1716  [\n  {\n    "id": 1,\n    "text": "Omfg",\n   ...
# 1717  [\n  {\n    "id": 1,\n    "text": "italian",\n...
# 1718  [\n  {\n    "id": 1,\n    "text": "no_candidat...
# 1719  [\n  {\n    "id": 1,\n    "text": "them",\n   ...
#
#                                               cand_text  cand_len
# 0     Morocco Tunisia Libya Greece Turkey Each one o...        19
# 1     population & children for 39%, of whom more th...        19
# 2     access to territory & asylum, living condition...        19
# 3     conditions + reduce overcrowding at the recept...        19
# 4     economic migrants who cross developed nations ...        19
# ...                                                 ...       ...
# 1715                                               they         1
# 1716                                          connector         1
# 1717                                           barriers         1
# 1718                                             others         1
# 1719                                               them         1
#
# [1720 rows x 4 columns]

# %%
for cand in cand_df['cand_text']:
    print(cand,'\n')
# Out:
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
#
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
#
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
#
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
#
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
#
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
#
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
#
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
#
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
#
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
#
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
#
# a people who have competed with the PKK over the issue of being more lowness
#
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
#
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
#
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
#
# its a fact that ISIS member find a passage through illegal immigration in Europe
#
# Its a stain on Europe to hold people in such conditions for so long.
#
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
#
# a given, more or less a basic human right like water and food
#
# More bad than good it' s supplied by a private/public joint venture .
#
# part of European culture & heritage, so it' s not worthy of protection
#
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
#
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
#
# Neither the Greek state nor the [boss] care about our lives or health
#
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
#
# A photo to give you an impression of the food in moria .
#
# the second year that we have supported this Appeal for Hope and Kindness
#
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
#
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
#
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
#
# the Voices in refugee education conference yesterday, & especially interesting discussions
#
# him and some others and the riot police who had guns
#
# the ones who want to contribute and have something to offer
#
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
#
# its the result of an entire continent acting in its perceived
#
# critical issues that must be addressed, incl the urgent need 2
#
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
#
# The new Greek Asylum Service microsite () that replaces .
#
# a recent lack of cooperation from the Turkish coast guard
#
# its 12 mile maritime territory all turkey needs to do
#
# It' s a shame Greece learned that too late .
#
# I' m very interested in how you know their systems
#
# the best ideas in our online event innowise challenge labs
#
# Greece : 1/2 of UK size, twice of asylum seekers.
#
# a potential embellishments of hard facts and harsh reality
#
# a chance to crack down on the unwanted visitors
#
# Cemeteries just for unidentified migrant bodies from the Mediterranean
#
# The infected person , a 40 year old man
#
# a country that has been your dreams for centuries
#
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
#
# Two high ranking UN Refugee Agency officials on Friday
#
# if there will be an EU or what it
#
# refugees, discussed with authorities and NGOs refugee protection challenges
#
# Portugal and parts of Greek Island on the list
#
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
#
# the way who hosted me and spoke to me
#
# refuge in a 3 rd class eastern European country
#
# 7000 Turks from the beginning of the year
#
# top of your $20,000 salary to see what
#
# 1984 the loive of kidnapping are with rene
#
# This idea that the uk is being overwhelmed
#
# the heavy handed tactics on peaceful turkish protestors
#
# the increasingly militaristic regime of Recep Tayyip Erdogan
#
# any, but the xenophobic, right wing nut jobs,
#
# scapegoating UK citizens with our migrant history
#
# First COVID-19 Case in Moria Refugee Camp
#
# territory for those in need of protection
#
# the life you could not even imagine
#
# sheap kidnap pay for e vew jeer
#
# precious & the only means of contact
#
# libya & east med (greece cyprus turkey)
#
# people crossing sea' s in little boats
#
# all the challenges the country has faced
#
# their own countries, and pro-islamic extremism/illegal migration
#
# You' re likely to get your head
#
# a new Ottoman Empire it might seem
#
# the supply of ready - made food
#
# That' s how a waterless region
#
# the latter claim (HRW & NGOs)
#
# great solidarity towards 1 0 0
#
# muslim britherhood and political islam expansionism
#
# less than 72 hours, all thanks
#
# the chance of breeding bird behaviour
#
# m not defending them after it
#
# the same colour passport as you
#
# Your sneaky political game didn' t
#
# no . . . . .
#
# a hole in Syrian Refugees' boats
#
# the island of Lesbos and the
#
# isis terrorists they trade with israel
#
# the poor quality of the it
#
# the only foreign language you know
#
# Turkish military & a refugee woman
#
# their strategic partnership with @eBay
#
# the work of refugee-led groups
#
# their many services and resources
#
# a hell of a lot
#
# the weapons of mass migration
#
# Pakistan and Afghanistan and Bagladesh
#
# Somali migrant infected with coronavirus
#
# us & our partners joy
#
# the end of the year
#
# Mujtaba and Im from Afganistan
#
# very constructive and open exchanges
#
# m Greek, many in America
#
# part of the new normal
#
# both aegean and kastelorizo eez
#
# the climate of the south
#
# the exploitation of migrant workers
#
# the Cordon Sanitaire & more
#
# the catch an ISIS member
#
# her phenomenal team in greece
#
# Their stories matter too .
#
# a way to political threat
#
# UNHCR & other agencies
#
# no immigrant in Birmingham
#
# s Hell) Closed camps
#
# closed and controlled structures
#
# the integration of women
#
# animals for manipulating refuges
#
# 2 claims in NYT
#
# Surly a smallish length
#
# control over the media
#
# Roger biland Daniele Francois
#
# a stronger, motivated govt
#
# Grandmother who I knew
#
# the city of Rome
#
# the RICs very low
#
# a local mini market
#
# figures from Italian government
#
# your army and people
#
# the 2 k goal
#
# the correct moral response
#
# gift much needed shoes
#
# room, roommate, work, collaboration
#
# leaver no one behind
#
# Nigerian embassy in Athens
#
# Greek militans kil .
#
# families who are struggling
#
# the one their fled
#
# uncertain fates in europe
#
# your line of reasoning
#
# safe heaven for Hamas
#
# My Gr .
#
# @vonderleyen @NachoSAmor @hrw
#
# 3 EU members
#
# Refugee virus cases
#
# a sensible solution
#
# Greece dosnt melt
#
# plans in place
#
# the migrant route
#
# end migrant deaths
#
# a toy factory
#
# the United Kingdom
#
# this poor nation
#
# european union values
#
# 1 st covid
#
# . . .
#
# 200,000 lone child
#
# development news update
#
# Erdogans ersatz invaders
#
# The Trump family
#
# the full article
#
# a larger presence
#
# @PerilOfAfrica newsdeck COVID-19
#
# Isaac Bessudos widow
#
# the coronavirus pandemic
#
# an example and
#
# a long journey
#
# ' caring' acts
#
# our clinic doors
#
# its a term
#
# the other side
#
# your general stateme
#
# refugee covid 19
#
# Greece iwo men
#
# Sexual assault ect
#
# photo gr apy
#
# five for hope
#
# parts of Syria
#
# @RaoufMazou and @UNHCRGreece
#
# absolute pure dogshite
#
# UN Refugee Agency
#
# the UN convention
#
# w/Asst High Commissioners
#
# Little Ringed Plovers
#
# the immigrants card
#
# the Greece event
#
# top of that
#
# a distant memory
#
# devastating consequences
#
# friday motivation
#
# The situation
#
# white westerners
#
# Don' t
#
# great hospitality
#
# Giannis story
#
# Bertelsmann study
#
# Priti Patel
#
# its obvious
#
# Muslim factions
#
# my fieldwork
#
# migration fluxes
#
# you officials
#
# Lesbos latest
#
# your workplaces
#
# a flashpoint
#
# ready dumbfuck
#
# the spread
#
# Didn '
#
# The Bessudos
#
# this burden
#
# Polish Jews
#
# the government
#
# The transfer
#
# a scoop
#
# Raquel Bessudo
#
# bird photography
#
# terrorist propaganda
#
# some brain
#
# olive branches
#
# a crime
#
# an excuse
#
# 59 turks
#
# severe claustrophobia
#
# our culture
#
# @tr724 araclyla
#
# their Fathers
#
# the start
#
# Dear sir
#
# the US
#
# europeans latinos
#
# Refugee Covid
#
# NO BORDERS
#
# t discriminate
#
# a tent
#
# the entrance
#
# the U.K.
#
# pro-government opinion
#
# a definition
#
# My names
#
# their visit
#
# gas Exploration
#
# awful thogh
#
# bombs Iraq
#
# its arms
#
# the call
#
# the same
#
# More evidence
#
# raw realism
#
# a necessity
#
# deadly attacks
#
# whos existence
#
# Mr Stoltenberg
#
# my data
#
# The impossible
#
# an email
#
# URGENT FUNDS
#
# this effort
#
# nothing &
#
# your help
#
# Greek SMEs
#
# SAFE France
#
# Refugee Camps
#
# Refugee Covid
#
# 2018
#
# He
#
# Anarchy
#
# Nobody
#
# access
#
# Illyrians
#
# @MSF
#
# negotiations
#
# HAHAHA
#
# Details
#
# Siktir
#
# refugeeovercrowding
#
# flow
#
# aesthetic
#
# ManfredWeber
#
# Leeds
#
# 1914
#
# HU
#
# 1/3
#
# @scwacy
#
# comparisons
#
# IRC
#
# COVID-19
#
# EIT
#
# Donations
#
# safety
#
# No-one
#
# connector
#
# GdnDevelopment
#
# G
#
# today
#
# Asylum
#
# Questions
#
# mercenaries
#
# documents
#
# Matt
#
# Wed
#
# Ill
#
# God
#
# Here
#
# covid
#
# unemployment
#
# /
#
# we
#
# Omfg
#
# COVID-19
#
# Doctors
#
# 10000
#
# @CERCmigration
#
# return
#
# Spring
#
# 10,000
#
# Borders/MSF
#
# moria
#
# parents/carers
#
# SOS
#
# Ubtil
#
# lesvos
#
# 2040
#
# @akrokentrwos
#
# charge
#
# islands
#
# Wales
#
# attention!!!!
#
# 2040
#
# danger
#
# lesbos
#
# History
#
# Obama
#
# soufli
#
# flood
#
# WE
#
# riots!
#
# who
#
# MSM
#
# 2040
#
# Greece

# %%
# we sort the candidates by their length

cand_df.sort_values('cand_len', ascending=False,inplace=True)

cand_df = cand_df[cand_df.cand_text not in  ['no_candidate', 'candidate_to_be_removed']]

cand_df.reset_index(drop=True, inplace = True)
cand_df
#all_cands_tagged.sort(reverse=True,key=get_cand_len(candidate_list))
# Out:
#                                              candidates  \
# 0     (Morocco Tunisia Libya Greece Turkey Each one ...
# 1     (access to territory & asylum, living conditio...
# 2     (conditions + reduce overcrowding at the recep...
# 3     (economic migrants who cross developed nations...
# 4     (population & children for 39%, of whom more t...
# ...                                                 ...
# 1715                         (This, This, {This}, misc)
# 1716                               (me, me, {me}, misc)
# 1717                 (Greece, Mazou, {Mazou}, group-ne)
# 1718  (no_candidate, no_candidate, {no_candidate}, m...
# 1719                         (them, them, {them}, misc)
#
#                                               cand_tags  \
# 0     [\n  {\n    "id": 1,\n    "text": "it",\n    "...
# 1     [\n  {\n    "id": 1,\n    "text": "3",\n    "l...
# 2     [\n  {\n    "id": 1,\n    "text": "HU",\n    "...
# 3     [\n  {\n    "id": 1,\n    "text": "They",\n   ...
# 4     [\n  {\n    "id": 1,\n    "text": "asylum",\n ...
# ...                                                 ...
# 1715  [\n  {\n    "id": 1,\n    "text": "it",\n    "...
# 1716  [\n  {\n    "id": 1,\n    "text": "Its",\n    ...
# 1717  [\n  {\n    "id": 1,\n    "text": "you",\n    ...
# 1718  [\n  {\n    "id": 1,\n    "text": "your",\n   ...
# 1719  [\n  {\n    "id": 1,\n    "text": "them",\n   ...
#
#                                               cand_text  cand_len
# 0     Morocco Tunisia Libya Greece Turkey Each one o...        19
# 1     access to territory & asylum, living condition...        19
# 2     conditions + reduce overcrowding at the recept...        19
# 3     economic migrants who cross developed nations ...        19
# 4     population & children for 39%, of whom more th...        19
# ...                                                 ...       ...
# 1715                                               This         1
# 1716                                                 me         1
# 1717                                             Greece         1
# 1718                                       no_candidate         1
# 1719                                               them         1
#
# [1720 rows x 4 columns]

# %%
print(len(cand_df))
cand_df = cand_df[cand_df.cand_text != 'candidate_to_be_removed']
len(cand_df)
cand_df.reset_index(drop=True,inplace=True)
# Out:
# 368

# %% [markdown]
# ### First merging step

# %%
#
# THIS IS THE FIRST MERGING STEP
#
        
def merging_step1(candidate_list):
    """
    In the first merging step, we merge two candidates if the head of each of their representative phrase 
     is identical by string comparison.
    """
    indices_to_remove = set()
    for longer_cand in range(len(candidate_list)):     
        for cand in range(longer_cand+1,len(candidate_list)): 
            #print(f'for index {candidate_list[longer_cand][1]} checking the index {candidate_list[cand][1]}')

            #performing merging only for NE candidates of the same type
            if 'ne' in candidate_list[longer_cand][3]:
                #mark for merging if the head and its head's cand type is the same for 2 candidates
                #print(candidate_list[cand])
                if candidate_list[longer_cand][1] == candidate_list[cand][1] and candidate_list[longer_cand][3] == candidate_list[cand][3]:
                    print(f'matching "{longer_cand}" with "{cand}"')
                    #print(f'{candidate_list[longer_cand][1]} ===== {candidate_list[cand][1]}')
                    indices_to_remove.add(cand)
    return indices_to_remove

def merge_indices(cand_df,indices_to_remove):                

    print(f'Initial amount of candidates: {len(cand_df)}')                
    #print(len(sorted(indices_to_remove)))

    for index in reversed(sorted(indices_to_remove)):
        cand_df.drop([index],inplace=True)
        
    cand_df.reset_index(drop=True,inplace=True)
    print(f'Amount of candidates: {len(cand_df)}, after removing {len(sorted(indices_to_remove))} indices') 
    return cand_df


cand_df = merge_indices(cand_df, merging_step1(cand_df['candidates']))
# Out:
# Initial amount of candidates: 1459
# Amount of candidates: 1459, after removing 0 indices

# %%
cand_df['candidates'][250][0]
# Out:
# '13,000 migrants & asylum seekers'

# %% [markdown]
# ### Second merging step
#
# We merge 2 candidates if their sets of phrases heads are semantically similar

# %%
import gensim

#load the GoogleNews 300dim model (fix path)
model = gensim.models.KeyedVectors.load_word2vec_format(r'C:\Users\nikodemicek\Dropbox (CBS)\Master thesis data\GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine
import numpy as np

#adjust for sets of phrases in the candidate
def merging_step2(candidate_list):
    
    indices_to_remove = set()
    for longer_cand in tqdm(range(len(candidate_list))):     
        i = candidate_list[longer_cand]
        long_cand_mean_vec = phrase_heads_avg_vector(candidate_list[longer_cand][2])
        for cand in range(longer_cand+1,len(candidate_list)): 
            #print(f'for index {candidate_list.index(longer_cand)} checking the index {candidate_list.index(cand)}')
            #if candidate_list[longer_cand][1] == candidate_list[cand][1]:
                #print(f'matching "{longer_cand}" with "{cand}"')
            cand_mean_vec = phrase_heads_avg_vector(candidate_list[cand][2])

            if candidate_list[longer_cand][3] == candidate_list[cand][3]:
                try:
                    #print(1-cosine(long_cand_mean_vec,cand_mean_vec))
                    #print(long_cand_mean_vec.reshape(-1,1).shape, cand_mean_vec.reshape(1,-1).shape)
                    if 1-cosine(long_cand_mean_vec.reshape(-1,1),cand_mean_vec.reshape(-1,1)) >= 0.5:
                        #print(f'matching "{longer_cand}" with "{cand}"') 
                        indices_to_remove.add(cand)
                except AttributeError:
                    pass

            else:
                try:
                    if 1-cosine(long_cand_mean_vec.reshape(-1,1),cand_mean_vec.reshape(-1,1)) >= 0.7:
                        #print(f'matching "{longer_cand}" with "{cand}"') 
                        indices_to_remove.add(cand)
                        
                except AttributeError:
                    pass


    return indices_to_remove

def phrase_heads_avg_vector(phrase_set):
    phrase_head_vectors = []
    for phrase_head in phrase_set:    
        try:
            phrase_head_vectors.append(model[phrase_head])
        except KeyError:
            pass
    #phrase_head_vectors = [model[phrase_head] for phrase_head in phrase_set]
    if len(phrase_head_vectors) != 0:
        return np.mean(phrase_head_vectors,axis=0)
    else: 
        return np.NaN

        

cand_df = merge_indices(cand_df, merging_step2(cand_df['candidates']))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 509/509 [00:18<00:00, 27.75it/s]
# Initial amount of candidates: 509
# Amount of candidates: 509, after removing 0 indices

# %%
cand_df['candidates'][63][2]
# Out:
# {'camps', 'conditions', 'improvement', 'refugees'}

# %% [markdown]
# ## Third merging step representative labeling
#
# currently working on average cosine similarity of each phrase in the candidate - maybe not optimal, maybe it will be better with a different threshold

# %%
from sklearn.cluster import AffinityPropagation

from sklearn.metrics.pairwise import cosine_similarity

def merging_step3(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:  
        #the head of noun phrase is marked with value 0 for the word.head
        np_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]
        #np_pos_tags = {word.text: word.xpos for sent in doc.sentences for word in sent.words}
        #print(np_heads_pos)
        cand_np_phrases = []
        for word, head, pos in np_heads_pos:
            #head-1 because the pointer to head does not use 0 index
            if (pos == 'JJ' or pos=='VBN') and 'NN' in np_heads_pos[head-1][2]:
                cand_np_phrases.append(f'{word}_{np_heads_pos[head-1][0]}')
        phrases.append(cand_np_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for longer_cand in range(len(candidate_list)):     
        i = candidate_list[longer_cand]
        long_cand_vectors = phrases_vectors(phrases[longer_cand])
        if len(long_cand_vectors)==0:
            pass
        else:
            for cand in range(longer_cand+1,len(candidate_list)): 
                short_cand_vectors = phrases_vectors(phrases[cand])
                if len(short_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(long_cand_vectors),len(short_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(long_cand_vectors)):
                        for j in range(len(short_cand_vectors)):

                            sim_matrix[i][j] = cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1))

                                
                    if np.mean(sim_matrix) > 0.3:
                        #print(f'{longer_cand} and {cand} are {numpy.mean(sim_matrix)} similar' )
                        indices_to_remove.add(cand)
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove
                


def phrases_vectors(cand_phrases):
    
#for cand_phrases in phrases:
    #print(cand_phrases)
    cand_phrase_vectors = []
    for phrase in cand_phrases:
        try:
            cand_phrase_vectors.append(model[phrase])
            #print(f'for existing phrase "{phrase}" the vector is {model[phrase][0]}')
        except KeyError:
            phrase_words = phrase.split('_')
            #print(model[phrase_words[1]])
            try:
                phrase_vectors = [model[phrase_word] for phrase_word in phrase_words]
                #print(f'for phrase "{phrase}" avg vector is "{sum(phrase_vectors)/len(phrase_vectors)}') 
                cand_phrase_vectors.append(sum(phrase_vectors)/len(phrase_vectors))
            except KeyError:
                pass
    #print(len(cand_phrase_vectors))
    return cand_phrase_vectors
    
    
cand_df = merge_indices(cand_df, merging_step3(cand_df))
#print(indices_to_remove)
# Out:
# Initial amount of candidates: 509
# Amount of candidates: 444, after removing 65 indices

# %%
for cand in cand_df['cand_text']:
    print(cand)
# Out:
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# UNHCRs Assistant High Commissioners for Protection and O . . .
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# all those rescued on an empty cruise ship
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# Syrian Refugees, which has stolen Refugees' money
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# purchase vital medication and equipment
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# The turkish coast guard arest
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Erdogan Greed for Gas
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# their point of view
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# guns and tear gas
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# enoug of a fu
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# the asylum system
# a sensible solution
# The right wing
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# a smart phone
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# their experiences
# refugee overcrowding
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# Rights groups
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# Anastasa Sikiaridi
# severe claustrophobia
# our culture
# <3 film
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# Heute ab
# gas Exploration
# my home
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# The answer
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# their taxes
# 2018
# He
# there
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Eedogan
# Donations
# self-interest
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# /
# Doctors
# 10000
# @CERCmigration
# Omfg
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece

# %% [markdown]
# ### Merging step 4

# %%
# missing the second method - we check for the lexical identity of specific stems in multiple candidates.

def merging_step4(cand_df):
    phrases = []
    indices_to_remove = set()
    # 1. first we find adj-nn phrases within the candidate
    for candidate in cand_df['cand_tags']:

        #the head of noun phrase is marked with value 0 for the word.head
        np_heads_pos = [(word.text, word.head, word.xpos) for word in candidate.words]

        #print(np_heads_pos)
        cand_np_phrases = []
        for word, head, pos in np_heads_pos:
            i = np_heads_pos.index((word, head, pos))
            #print(np_heads_pos)
            #print(np_heads_pos[i])
            #print(np_heads_pos[head-1])
            #'NN' in np_heads_pos[head-1][2] and
            try:
                if 'NN' in pos and 'NN' in np_heads_pos[i+1][2] : 
                    cand_np_phrases.append(f'{word}_{np_heads_pos[i+1][0]}')
                if 'NN' in pos and 'NN' in np_heads_pos[head-1][2]:
                    cand_np_phrases.append(f'{word}_{np_heads_pos[head-1][0]}')
            except IndexError:
                pass
        phrases.append(cand_np_phrases)
    
    candidate_list = cand_df['candidates']
    # 2. we compare the similarities of candidates' phrases
    for longer_cand in range(len(candidate_list)):     
        i = candidate_list[longer_cand]
        long_cand_vectors = phrases_vectors(phrases[longer_cand])
        if len(long_cand_vectors)==0:
            pass
        else:
            for cand in range(longer_cand+1,len(candidate_list)): 
                short_cand_vectors = phrases_vectors(phrases[cand])
                if len(short_cand_vectors)==0:
                    pass
                else:
                    sim_matrix = np.zeros((len(long_cand_vectors),len(short_cand_vectors)))
                    #print(sim_matrix)
                    for i in range(len(long_cand_vectors)):
                        for j in range(len(short_cand_vectors)):
                            #print(cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)))
                            sim_matrix[i][j] = cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1))
                            """if cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.4:                
                                sim_matrix[i][j] = 2
                            elif cosine_similarity(long_cand_vectors[i].reshape(1,-1),short_cand_vectors[j].reshape(1,-1)) > 0.2:
                                sim_matrix[i][j] = 1
                            else:
                                sim_matrix[i][j] = 0"""

                                
                    if np.mean(sim_matrix) > 0.6:
                        print(f'{longer_cand} and {cand} are {np.mean(sim_matrix)} similar' )
                        indices_to_remove.add(cand)
                    #else:
                        #print(f'{numpy.mean(sim_matrix)} is not similar' )
                    
    return indices_to_remove

cand_df = merge_indices(cand_df, merging_step4(cand_df))
#print(merging_step4(candidate_list))
# Out:
# Initial amount of candidates: 342
# Amount of candidates: 342, after removing 0 indices

# %%
for cand in cand_df['cand_text']:
    print(cand)
# Out:
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece

# %% [markdown]
# ### Merging step 5

# %%
for i in event_df['Tweet Raw'][:100]:
    print(i)
# Out:
# @sztiv5 @Juliivan_ Yes, why? Why it wasn’t good to apply for asylum in Greece, MAC, SER or CRO or BUL, together 3 EU members before HU? They must get help in the first safe country as asylum seeker,not in the 5th. No law says you can pick and choose and get it.
# @GoTurkey ISIS refuge. Wouldn't go to Turkey if I was paid. You're likely to get your head lopped off if you stray off the beaten track. Go to Christian Greece and be safe while enjoying a similar climate to islamic turkey
# Greece must improve refugee overcrowding, UN warns https://t.co/UDM4GDMcmo
# @ThisIsOzcan @Nervana_1 @EGozuguzelli 1/3 Law? Let the idle stuff. All rights of the Turkish minority in Greece were taken away. Where is the law? Refugees are not accepted into the EU. Where is the law? Western states divided the states in the Middle East and Africa for underground resources. Where is the law?
# @Juliivan_ @sztiv5 Anyway, how did the asylum seekers ended up at HU borders? They must have had a long journey through Greece, where they must apply for help, yet they travelled through multiple more countries, why?
# I never loved #photograpy pushing aesthetic into #news cause it is a potential embellishments of hard facts and harsh reality.I like raw realism. Did I pass this boundary using @FiLMiCPro #firstlight this week in #Lesbos infamous Moria #migrants camp? That’s a big question4me https://t.co/rlEZP5mXmd
# @YOsmanli1453 @ArisKallimachos @GreeceMFA ManfredWeber: It must be made clear that Europe and Germany are on the side of Greece. The German MFA must be careful not to be blackmailed in fear of a new refugee crisis.
# Refugee Covid case sparks 'closed camps' fears on Lesbos | Greece | The Guardian https://t.co/hp8JcOf8dB
# 9PM Coronavirus UK LIVE: Leeds on brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources | Photo via Evening Standard https://t.co/hrcDUI72DF #birmingham #coronavirus #coronavirusoutbreak https://t.co/FOn9kkanHn
# @Iceman070259590 @OPCW @realDonaldTrump @mikepompeo Are you sure you' re talking about France and not Turkey? Turkey has invaded parts of Syria, bombs Iraq, conducts a proxy war in Libya creating refugees. On top of that, it violates Greece's and Cyprus' sovereignties. Not to mention that it provides safe heaven for Hamas.
# @realPR_Phoenix @DrEstella @BravoTV Raquel Bessudo is Isaac Bessudo’s widow. The Bessudos were Sephardic Jewish immigrants from Salonica, Greece. Raquel’s parents were Polish Jews. Raquel is blonde and blue eyed though
# @Mproyklis @fragoua @LearnerLerner @mr_markjacobs Most of them immigrated to Greece by their will.
# @maskeIiyorum First you stuff they Turkey, then you bake it, and at last you eat it!!! Be kind to your women, they are very welcome to seek asylum in Greece just like your army and people are doing. Leaving crazy ruled Turkey. Ah Siktir
# Five years later: How September 5th, 2015, became a #Crossroads for the #Migration crisis | DW News - https://t.co/dLNMddqtBw - #Budapest #EU #Europe #European #EuropeanUnion #German #Greece #Turkey
# Record numbers of illegal migrants crossing into the United States as the United Kingdom right now and only Greece seems to keep the border under control. It worries me this is part of the new normal - @WashTimes https://t.co/1kcyzbLICS
# Refugee virus cases spark fears in Lesbos. (Guardian) Story: https://t.co/ocQHAk5gZf
# @fundabezos @dimi_par @Arda7517 @HSajwanization Illegal immigration is not a problem of GREECE or EUROPE.....
# @kaitlancollins 2. From severe claustrophobia his entire life. Both men were not losers they knew why they enlisted it was to appease their Fathers by giving thanks to America for taking them in as immigrants from Greece in 1914. The Trump family never once walking in military boots.
# Greece pushes back 10 refugees, including three children with disabilities. Those refugees were fleeing Erdogan. Greece is betraying european union values. @coe @Europarl_EN @vonderleyen @NachoSAmor @hrw https://t.co/ESiuIqr6jc @tr724 aracılığıyla
# https://t.co/L9k1uLNc97 Two high ranking UN Refugee Agency officials on Friday ended a visit to Greece calling for a drastic improvement in the living conditions of refugees in camps, Anadolu Agency reports. UNHCR’s Assistant High Commissioners for Protection and O ...
# UN: Greece must improve refugee overcrowding https://t.co/QArN0pGNlz
# @TerribleWyvern Switzerland? But honestly, I reckon its more likely to happen in the Balkans. Greece stranded a bunch of illegal immigrants in the middle of the sea. Plus theres the growing tension with Turkey. So a stronger, motivated govt might just start booting out Erdogans ersatz invaders.
# @ghost_wales To be fair, since when did the EU stop illegal immigration? I don't think the people of Greece got that particular memo.....
# For 4 years, we have offered high-quality, #trauma-sensitive, identity-informed #PSS & #education support to child & youth #refugees in northern Greece. With your help, we can continue this work for another 4 years in another 4 countries. Please donate: https://t.co/Gv3840hqCh
# Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/2EiOcJOBMf
# @Ishaxk0 @VinceVole @EmmanuelCohen65 @DonnyBoy12 So how do you explain mass immigration into Sweden, Austria, Norway, Finland, Denmark, Greece, or pressure on Poland, Bulgaria, Hungary, Slovenia, Serbia & other European countries to accept mass migration?
# @swissquiz @Paul_Phillips20 @chaipatel0 @Nigel_Farage In 2018, the #UK received applications for #Asylum for 37,453 people (including #dependants). This is far less than #Germany (162,000), #France (110,000), #Greece (65,000) and #Italy (49,000).
# Enterprise Greece is joining in this effort, as they aim to migrate their many services and resources online by the end of the year. And their strategic partnership with @eBay will further boost Greek SMEs, ensuring that they can access such a high-level international platform.
# UNHCR's Assistant High Commissioners visit Greece, discuss refugee protection challenges and urge more support https://t.co/narldvFNQ5 https://t.co/G0ntxgzdgG
# @McFaul I worked in a couple of refugee camps in Greece & WiFi there was a given, more or less a basic human right like water and food, as they were people who often had very few possessions with them but a smart phone was precious & the only means of contact to their relatives.
# @Complyordie4 @guardian He shouldn't be there. He was granted asylum and had left for Athens in July. In August he returned to Lesvos and lived in a tent next to the official camp. Anarchy reigns in Moria. Nobody follows the rules.There have been deadly attacks. This is why closed camps are a necessity.
# @NicAthens @ManfredWeber @HeikoMaas Erdoğan holds the cards. He can unless ya million refugees and what would Greece do
# @Richard021051 @MigrationWatch Belgium: 1/10 of UK size, 1/2 of asylum seekers. Greece: 1/2 of UK size, twice of asylum seekers.
# @1Fubar It was obvious many would be infected, that's the issue with the migrants Erdogan is pushing into Greece from Turkey.
# @guardian The infected person, a 40 year old man, was granted asylum. He left from the camp in July, went to Athens and returned to Moria in August, to live in a tent next to the camp. (Didn't think it's Hell) Closed camps will give an oversight and put an end to the anarchy in Moria!
# In Greece we have had very constructive and open exchanges with authorities on the need to safeguard the right to seek asylum, to ensure access to territory for those in need of protection and to investigate the reports of pushbacks at land and sea: https://t.co/8IUcI3sJCl
# Greece has opened its arms to thousands of refugees. However, critical issues urgently need to be addressed. Asst. High Commissioners for Protection & Operations, @GillianTriggs & @RaoufMazou, conclude their visit to 🇬🇷 with a message of solidarity. https://t.co/lfrOmvMDMg https://t.co/oFGzJj03bA
# @tomyork5 @trtworld Btw, why should I take refuge in a 3rd class eastern European country like #Greece, while I already living the life you could not even imagine, in a country that has been your dreams for centuries, let alone the economy of Greece that needs Turkish tourists? Welcome t real world. https://t.co/hriifehDf4
# @tomyork5 @trtworld speaking of which, this is how #Greece behave towards real refugees https://t.co/HbS7NW9WYO
# @tomyork5 @trtworld This is no surprise that Greece shelters those FETÖ members who attempted a failed coup in Turkey. Defining these fugitive terrorists as asylum seekers is precisely a definition worthy of a people who have competed with the PKK over the issue of being more lowness. https://t.co/SLFeNaztJs
# @MigrationWatch Greece seems to have a sensible solution not sure why this has not been suggested? Surly a smallish length would be enough to make the direct route not direct? https://t.co/tBV5XMso8O
# During their visit to Greece, UNHCR’s Assistant High Commissioners @GillianTriggs & @RaoufMazou met with refugees, discussed with authorities and NGOs refugee protection challenges & repeated the call for more support and EU solidarity. https://t.co/DmuUK7tRel
# @Dardanoi25 @protoALB @Arjan @bardylius @TeamAlbanians @Deni_Hoxha @FPodrimja More evidence comes out that Illyrian/Albanian migration into Greece has been happening for thousands of years (not just with Arvanites) and Illyrians may have had a larger presence in mainland Greece than previously thought.
# @vtaonmtdiyene @trtworld Feel good for you that you have pro-government opinion. Else you would be in prison, afraid to talk or asking asylum from Greece. https://t.co/OoVOPzR2Ug
# @WW3Info @NicAthens @AlexanKazamias @WilliamCDoll @TamelaTweets @Pirgakis @JFCrisp @RaphJustine @Rakinas_A #Gas Exploration have created tension between Turkey-Greece. This Dialogue won't work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset. Erdogan Greed for Gas will not end with Sanctions #ThirdWorldWar #RafaleJets #Mediterranean
# I covered the migrant crises in 2015, traveling the migrant route up through Greece to Macedonia and then near Kosovo border and to Serbia and Hungary. I met many nice local people on the way who hosted me and spoke to me.
# #covid19Gr #refugeesGr #Lesvos @MSFgreece on #Moria camp lockdown :Covid is used as an excuse to limit freedoms and rights of people seeking safety in Europe https://t.co/xIbCWkpyLL
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# @tomyork5 Those who seek refuge in Greece, those who want to make a coup. Because they know that Greece loves this kind of people. Use some brain. Don't always shout with your own perspective. What you call freedom of expression is terrorist propaganda and doing it is a crime.
# Authorities in Greece have placed the Moria #refugee camp on the island of Lesbos under quarantine after the confirmation of the first coronavirus infection in the notoriously overcrowded facility. https://t.co/7LIWIhTngH
# @229Leckie @MontgomeryClif8 @scot_unionist @paulmasonnews by 2040 the north shore of the med will have the climate of the south, no tomatoes in Spain, grain in Italy, grapes in south France or olives in Greece; Europe will have 200 million European climate refugees. Who even knows if there will be an EU or what it's rules are by 2040
# People should spare Greece for a moment but don't get me wrong. I'm not defending them after it emerged they threw 1000 immigrants into the ocean & left them to die.... but why should this poor nation carry this burden yet the world was silent when Obama destroyed Libya.
# @AmysGotBirds @DonaldJTrumpJr To start this war, Erdogan and Turkey (which is part of NATO) has allowed Syrian refugees into his country...only they aren't Syrian. They are Afghani, Somali, and Iraqi. He is allowing these refugees to flood into Greece, and Europe. They are armed with guns and tear gas.
# UNHCR’s Assistant High Commissioners visit #Greece, discuss #refugee protection challenges and issues relating to access to territory & asylum, living conditions on mainland & islands, the management of the #COVID19 response, integration https://t.co/0dZTraZGi3 https://t.co/E411e2Cp8P
# #DevelopmentNewsUpdate Over 200,000 lone #child #migrants left to #uncertain #fates in #Europe Read the full article at https://t.co/sv8bIVmKO0 #Europe #riskofexploitation #children #safety #Greece #detentionofchildren #conflict #protectionbeyondreach #migrants #twentylakhs https://t.co/lMiEC07BYe
# @realPR_Phoenix @DrEstella Estella’s family immigrated from Greece and Lithuania and became wealthy by owning a toy factory
# @Nicolas98869551 @Marflo66036248 @Esref_Doguu Who does say this? Is it a Greek? It is The Greece which has made a hole in Syrian Refugees' boats and which has beat Syrian Refugees, which has stolen Refugees' money. 😂😂😂
# If your kids have gone #BackToSchool, do you suddenly appreciate the time you have for other things? SOS provide childcare to families who are struggling, so parents/carers can study or find work. Find out more about our work in a refugee camp in Lesvos ➡️ https://t.co/t8GEChlGFg https://t.co/oWWet2GJex
# @devilxbrain @ragipsoylu Take the 5+ million refugees and then https://t.co/XXT3mjLDCs if you care for them.I can easily say they are living in much better conditions in Turkey compared to Greece.
# #Greece and its people have shown great hospitality for 100 of thousands #refugees and #migrants since 2015. But a lot remains to be done to meet critical needs and improve conditions on islands. We need continued solidarity from #EU and European States. https://t.co/LivzhA3RXL
# Wales has added Portugal and parts of Greek Island on the list not to visit, yet England does not #torychaos #Covid_19 Refugee Covid case sparks 'closed camps' fears on Lesbos https://t.co/jefOiklxow
# We’re all in this together and no one should be left behind! The #refugees in Greek islands must be urgently protected from #COVID19 – Take action now and send an email to Prime Minister of #Greece, @primeministergr to act immediately! #coronavirus https://t.co/NQOH3cOVbD
# #Attention!!!! Illegal immigrant try to steal a local mini market in #Soufli , #Greece!!! @akrokentrwos https://t.co/wiowPSF8pF
# A photo to give you an impression of the food in #Moria. If you guess what it is, it will be delivered free of charge for one month. #Delicious #EU #Refugees #LeaveNoOneBehind #SaveThem
# @griko84 @BwanaPjotr @fk_akis @MEMRIReports You said Muslim factions that Greece dosnt melt in betwen them it does so yea. Greece gives enoug of a fu* to support Assad and open realtionship with him so yea. If its our mess then EU should stop melding into it too. But it does so yea. Take the refugees then.
# #Moria: A food strike takes place. ~100 refugees have blocked the supply of ready-made food to protest against the poor quality of the it. More bad than good it's supplied by a private/public joint venture. #LeaverNoOneBehind #RefugeesGR
# @YinkaOgundipe @EmmanuelAcho Well obviously you don’t know Giannis story. He had nothing until he was 17. Because he was born in Greece and Nigerian embassy in Athens refused him a passport cause his parents left Nigeria as refugees.Only after Greece gave him one , Nigeria said they will suit
# Greece has shown great solidarity towards 1000s of refugees + asylum-seekers. There are critical gaps + issues that need addressing. Other EU States need to also show solidarity including by relocating vulnerable asylum seekers. The situation is manageable https://t.co/MWxUHH0sZb
# @YavuzBiH @fk_akis @MEMRIReports 1)EU is not supporting Assad 2) if you are gonna blame Greece for any ME wars (that Turkey takes part in), colonialism or anything else, try harder. By the way, less than 15% of current “refugees” in Greece are from Syria.
# 1st #Covid_19 case confirmed in #Moria. Within 10 days, #Coronavirus could sweep through the overcrowded #refugee camp, with devastating consequences. We need URGENT FUNDS to keep our clinic doors open and purchase vital medication and equipment. #DONATE: https://t.co/a1gCVgOdcR
# Lesbos refugee camp in quarantine due to Somali migrant infected with coronavirus https://t.co/qBdLXSjkdG
# @Tarzan35715351 @0khalodi0 Unfortunately it’s a fact that ISIS member find a passage through illegal immigration in Europe. And most likely you referring to some NATO members. Portugal never funded neither Greece as an example and neither agreed.
# @maximusmadham @EndGameWW3 Maybe you speak for Albanian greeks. I don't give a shit about anyone of them. I only support greeks that living in Greece not traitors and refugees
# There are critical issues that must be addressed, incl the urgent need 2 drastically improve living conditions +reduce overcrowding at the reception facilities on the Aegean Islands - @RaoufMazou on #Greece #asylum #Europe #Solidarity https://t.co/H3yhHqly4g via @refugees
# Greece and its people have shown tremendous solidarity and compassion with thousands of refugees and asylum-seekers, despite all the challenges the country has faced, including a severe economic crisis and now the COVID-19 pandemic - @RaoufMazou https://t.co/WDVFsQS0sk
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 https://t.co/j9bKQUVcBR #Greece #news
# @bethvaughan15 @SueSuezep @Jacob_Rees_Mogg Britain still done far less asylum applications than other European country, Germany, France and Greece did a hell of a lot more....
# fight for hope - the states should not push people seeking asylum back to unsafe countries! is this what happens in the Aegean sea? #migrants #refugees #AsylumSeekers #Turkey #Ankara #Greece #Syria #Iraq #MiddleEast #Pakistan #Afghanistan #Honduras #ElSalvador #Mexico #Guatemala https://t.co/ROQxjEgfjA
# @sarianpaul1 @pritipatel This idea that the uk is being overwhelmed is absolute pure dogshite. 85% of the world's refugees live in countries adjacent to the one their fled. The uk took 3 x less asylum applications than France last year, 4x less than Germany, 2x less than Spain and Greece. Get over it.
# @0khalodi0 In Greece the majority of immigrants are from Pakistan and Afghanistan and Bagladesh. It was not long ago when the catch an ISIS member in Spain. Guess from where passed first, Greece! Europe is in danger.
# Refugee Covid case sparks 'closed camps' fears on Lesbos | Global development | The Guardian : https://t.co/90q629G4gV #santé
# @no_eyed_ryan I'm Greek, many in America consider Greeks white because white westerners claimed our culture, history and ethnic heritage as theirs. Greek immigrants didn't leave their culture behind in fact they suffered under white supremacy both in Greece and in white colonised countries.
# @devilxbrain @ragipsoylu You are hypocritical. Greece closes the gates for your so called ‘poor’ refugees. So what makes them better ?
# @DrManha84708484 @Eos303 @Nervana_1 @EGozuguzelli Did you ever see Greeks that go to Turkey and ask for asylum? The answer is NO. But we see thousands of Turks every day that come to Greece and ask for asylum. What's wrong with Turkey?
# Migrant shelter for unsupervised minors in Greece quarantined following coronavirus outbreak — RT World News https://t.co/qeh1vETr89
# #COVID19 measures in #Greece #AsylumSeekers & #Refugees on #Lesbos. When will those poor people be rescued from this living hell? https://t.co/tzqE7pT812
# @gerdosi @paulmelzer1 @nmlinguaphile The funniest thing is no country closed its borders to stop it. It was to slow the spread. History (the Cordon Sanitaire&more), recent flare ups in TX&Florida (migrants from Mexico&Caribbean), Greece early closing vs Spain' s late 1,etc. are facts undermining your general stateme
# @lk2015r @LevidisStefanos When I started my fieldwork in İzmir in 2008 summer, pushed back refugees were telling me their experiences at sea. There were also sent back migrants according to the bilateral agreement who had detention experience in Greece.
# @DartmoorSounds @guyverhofstadt i'll be going to the Cayman Islands! FOR MY WINTER BREAK! Where you going in the EU, Sunlit EU beaches with dead migrants on you mean! due to the EU not caring about people crossing sea's in little boats! greece and now the Channel yet still they do nothing
# This is the second year that we have supported this Appeal for Hope and Kindness. All of the money will be used to provide nappies for babies in Refugee camps in #Greece. Donations will bring hope to a mother and comfort to her baby. #FiveForHope https://t.co/jWuPRixilI https://t.co/j99DHJ2ldK
# Current UNHCR numbers #Lesvos: 14,007 #refugeesgr reside on island. Majority from #Afghanistan (76%), #Syria (7%) and Democratic Republic of the #Congo (7%). Women account for 23% of population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old. /1 https://t.co/4OTIv9tk3X
# @CllrBarryLewis Anyway, we still have a responsibility to take at least some of these people in if they need it. Otherwise your line of reasoning suggests Italy and Greece, or the other primary landing countries, should basically take all the refugees, which hardly seems fair.
# Greece has a deadly new migration policy – and all of Europe is to blame | Every time Athens pushes a refugee boat away, it’s the result of an entire continent acting in its perceived self-interest https://t.co/9sEKKQ6tBy https://t.co/Im5ShhraQF
# COVID-19: Greece reports first coronavirus case in Moria migrant camp on Lesbos https://t.co/wWgaCNZ6UE
# @jensstoltenberg @EGozuguzelli @RTErdogan @NATO Greek militans kil.ling poor immigrants. Racist unlawfull greece. https://t.co/ZKkNKqDgXI
# War conflicts, migrations, diseases... That's how a waterless region is💧 From EIT we are facing that problem by getting together the best ideas in our online event #InnowiseChallengeLabs. Join the Greece event on 15 september at 4 PM! 🇬🇷
# @EastMedMonitor 4 million migrants housed in turkey!if Greece gets its 12 mile maritime territory all turkey needs to do is get them to walk into the sea and they are in the EU in many areas😂😂😂
# @_ErcanButun @LegendofBaba You are to be https://t.co/uQO4C8nZCw fooled all these poor people that the borders are open and you carried them by thousands to enter Greece.Your sneaky political game didn't succeed. You are animals for manipulating refuges.
# The first recorded coronavirus case in Moria refugee camp on Lesbos, where just under 13,000 people are l..... to leave. Check on https://t.co/5jbWReoMR1 @scwacy
# @hvvnfd @jedijig @KostasAntLavdas @jensstoltenberg I thing this didn't go on because Turkey want just the Aegean but Greece want both aegean and kastelorizo eez. In any case that are history now Greece propose it and Turkey refuge. This is the truth.

# %% [markdown]
# ## Frame identification

# %%
frame_properties = {'affection':['affection','attachment', 'devotion', 'fondness','love','passion'],
                    'refusal': ['refusal','declination','denial','disallowance','nay','no'],
                    'trustworthiness':['trustworthiness','integrity','accuracy','credibility','authenticity','fairness'],
                    'no trustworthiness':['falsehood','dishonesty','unfairness','deceit','corruption'],
                    'reason': ['reason','logic','sense','rationale','argument','justification'],
                    'unreason/irrationality': ['unreason','irrationality','fallaciousness','unsoundness'],
                    'easiness': ['easiness','simplicity','obviousness','ease','comfort'],
                    'difficulty': ['difficulty','adversity','hardship','crisis','obstacle','trouble' ],
                    'honor': ['honor', 'dignity','esteem','reputation','praise'],
                    'dishonor': ['disgrace','dishonor','reproach','opprobrium']}


frame_properties = {'settlement':['settlement','accomodation','accommodated', 'military barrack','tent','camp'],
                   'reception':['quota', 'reception','together','asylum','receive'],
                    'security':['security', 'border','crossing','fence','control','flow'],
                    'criminality':['officer','crime','offense','police','trafficking','suspect'],
                    'economisation':['euro','economic','million','thousand','cost','money'],
                    'humanitarian':['humane','voluntary','help','support','aid','care','solidarity'],
                    'victimization':['islamic','fight','war','dead','rescued','state'],
                    'integration': ['labour','employed','unemployed','integration','positive']
                   
                   }
# Out:
# "                   'importance':\n                    'unimportance':\n                    'power/leadership':\n                    'weakness/passiveness':\n                    'good quality':\n                    'poor quality':\n                    'safety':\n                    'unsafety':\n                    'positive':\n                    'negative':\n                    \n                    \n                   }"

# %%
import conceptnet_lite as cn
import gensim.downloader as api


# to run on the server we should use larger model according to the paper - "conceptnet-numberbatch-17-06-300"
#model = api.load("glove-twitter-200")
# Out:
# [==================================================] 100.0% 758.5/758.5MB downloaded
# @Kkkk09240868
# @0khalodi0
# @POTUS
# Also,
# Eedogan
# has
# been
# documented
# using
# ISIS
# militants
# aka
# terrorists,
# he
# played
# the
# immigrants
# card
# as
# a
# way
# to
# political
# threat
# to
# Europe,
# he
# pushed
# immigrants
# to
# greece
# and
# europe
# for
# their
# own
# death,
# after
# letting
# them
# homeless
# for
# years
# As
# I
# said,
# All
# Muslims
# are
# guilty
# @Nionios1908
# @kitsikis
# Greece
# unable
# to
# cope
# with
# 60
# thousand
# refugees
# with
# a
# population
# of
# 10
# million.
# and
# the
# border
# next
# to
# it
# wants
# a
# country
# of
# 83
# million
# to
# be
# torn
# apart.
# God,
# I've
# never
# seen
# a
# fool
# like
# you
# together
# in
# my
# life.
# the
# problem
# is,
# you're
# all
# idiots.😂
# @hama_ashad
# @realDonaldTrump
# and
# from
# there
# you
# can
# try
# to
# pass
# Europe
# especially
# Greece
# there
# are
# lots
# of
# boats
# you
# know
# but
# you
# have
# to
# know
# you
# might
# die
# from
# all
# of
# that
# this
# refugge
# thing
# is
# very
# fishy
# @hama_ashad
# @realDonaldTrump
# I
# dont
# know.
# I
# dont
# live
# in
# Iraq.
# In
# Europe
# many
# migrants
# walked
# from
# Greece
# to
# Norway/sweden/Germany.
# I
# guess
# you
# can
# do
# the
# same.
# Just
# from
# Iraq
# to
# Greece.
# The
# life
# as
# migrant
# is
# awful
# thogh.
# Must
# live
# in
# awful
# camps
# too
# the
# government
# say
# you
# are
# a
# real
# refugee.
# #travel
# #news
# :
# Migrants:
# MSF,
# cruel
# quarantine
# of
# Moria
# on
# Lesbos
# https://t.co/ghNe7hYHgJ
# @Antignoramus
# @jensstoltenberg
# Happy
# to
# make
# you
# laugh.
# Unfortunately,
# a
# lot
# of
# the
# Turkish
# people,
# lawyers,
# teachers,
# officers,
# judges
# and
# civil
# servants
# are
# either
# in
# jail
# or
# seeking
# asylum
# in
# Europe
# (Greece
# as
# well)
# not
# laughing,
# because
# of
# Erdogan.
# Combined
# with
# his
# warmongering,
# comparisons
# are
# inevitable
# @LucieH20
# @MigrationWatch
# @RosinaFrance
# It's
# a
# shame
# Greece
# learned
# that
# too
# late.
# Where
# as
# Eastern
# Europe
# has
# had
# plans
# in
# place
# from
# the
# start.
# They
# know
# the
# endgame
# of
# allowing
# unmitigated/unchecked
# illegal
# migration
# from
# the
# Middle
# East
# and
# Africa.
# the
# bosses
# Roger
# biland
# Daniele
# Francois
# sins
# 1984
# the
# loive
# of
# kidnapping
# are
# with
# rene
# biland
# the
# kidnapper
# bosses
# they
# order
# sheap
# kidnap
# pay
# for
# e
# vew
# jeer
# arriving
# mountain
# cheese
# shieapnew
# zealand
# greece
# algeria
# club
# med
# migros
# jumbo
# deliveries
# BY
# SYSTEMATIC
# @cappsperhaps
# @pritipatel
# @BritishRedCross
# Why
# do
# they
# travel
# through
# 4/5
# other
# European
# countries
# though
# before
# exercising
# their
# right
# to
# claim
# asylum
# in
# the
# U.K.
# -
# what’s
# wrong
# with
# Greece
# ?
# GLOBALIST
# EU
# NO
# BORDERS:
# Refugee
# Covid
# case
# sparks
# 'closed
# camps'
# fears
# on
# Lesbos
# https://t.co/NXTFgIHBIF
# @RaoufMazou
# @GillianTriggs
# @UNHCRGreece
# Dear
# sir,
# are
# you
# having
# a
# nice
# holiday
# in
# Greece?
# $
# 700
# a
# day
# on
# top
# of
# your
# $
# 20,000
# salary
# to
# see
# what?
# Stay
# in
# Geneva
# and
# host
# 10
# refugees,
# so
# you
# will
# be
# concrete,
# hypocritical
# !!
# @MantiXrmanti
# @PanPan70738015
# @Antignoramus
# @jensstoltenberg
# Only
# thing
# Greece
# is
# now
# famous
# for
# is
# killing
# refugees
# and
# being
# bankrupt.
# @PauloNoggy
# @LegendofBaba
# 2
# claims
# in
# NYT:
# Greece
# is
# taking
# people
# from
# camps
# on
# land
# then
# dumping
# them
# &
# it
# is
# pushing
# back
# boats
# coming
# from
# Turkey
# (it
# is
# doing
# this,
# not
# all
# but
# some
# boats).
# Source
# back
# up
# the
# latter
# claim
# (HRW
# &
# NGOs).
# Former
# claim
# is
# backed
# by
# Turkish
# military
# &
# a
# refugee
# woman.
# Hello
# 🌎
# My
# names
# Mujtaba
# and
# I’m
# from
# Afganistan.
# I
# fled
# my
# home
# with
# my
# family
# seeking
# safety
# and
# I
# am
# now
# trapped
# in
# a
# refugee
# camp
# in
# Greece.
# I’m
# currently
# sat
# like
# thousands
# of
# others
# without
# access
# to…
# https://t.co/jUmepRRpG4
# @DMiliband
# @GaryLineker
# @yasminkadimusic
# @ColmansSeafood
# @RESCUE_UK
# No-one
# had
# issues
# with
# genuine
# refugees
# Those
# illegally
# coming
# by
# dinghy
# are
# NOT
# They
# are
# coming
# from
# SAFE
# France
# and
# should
# claim
# asylum
# there,
# or
# Italy
# or
# Spain
# or
# Greece
# or
# wherever
# they
# first
# reached
# any
# of
# the
# many
# SAFE
# countries
# they
# have
# passed
# through.
# @RESCUEorg
# Anastasía
# Sikiaridi
# is
# sharing
# her
# experience
# On
# the
# integration
# of
# women
# in
# Refugee
# Camps
# in
# Greece
# #iwomenconnector
# #coping2gather
# #Growing2gather
# #LeadingsResilience
# #WomenTechChangMakers
# #Inclusion
# #RefugeeWomen
# #Empowerment
# #NewWomenVoices4EU
# @Nygard776
# @MigrationWatch
# @RosinaFrance
# Countries
# like
# Greece
# &
# Hungary
# that
# have
# land
# borders
# have
# put
# up
# barriers
# to
# stop
# others
# illegally
# crossing
# into
# their
# country.
# Our
# problem
# is
# the
# same
# but
# harder
# to
# solve
# we
# should
# put
# all
# those
# rescued
# on
# an
# empty
# cruise
# ship
# &
# never
# let
# them
# land
# GdnDevelopment:
# Refugee
# Covid
# case
# sparks
# 'closed
# camps'
# fears
# on
# Lesbos
# https://t.co/e8TUfz9V0h
# @reeta_iceburg
# @MigrationWatch
# Hungary,
# Poland
# &
# Greece
# seem
# to
# have
# done
# something
# IRC
# calls
# for
# urgent
# evacuation
# of
# the
# most
# vulnerable
# refugees,
# as
# first
# Coronavirus
# case
# confirmed
# in
# Moria
# https://t.co/8X38yLjb3b
# And
# why
# come
# here
# instead
# of
# staying
# in
# France,
# Greece,
# Spain
# etc?
# If
# English
# is
# the
# only
# foreign
# language
# you
# know,
# you
# will
# have
# a
# better
# chance
# of
# integrating
# and
# understanding
# the
# whole
# asylum
# process.
# @jjstewart84
# @PaulDulson2
# I
# agree
# the
# asylum
# seekers
# matter
# too
# but
# that
# doesn’t
# mean
# we
# have
# to
# take
# them
# all
# no
# matter
# what
# ..
# they
# came
# through
# France
# Germany
# Italy
# Greece
# etc
# and
# I’m
# sure
# the
# ones
# who
# want
# to
# contribute
# and
# have
# something
# to
# offer
# will
# be
# processed
# successfully
# the
# rest
# go
# back
# Refugee
# Covid
# case
# sparks
# ‘closed
# camps’
# fears
# on
# Lesbos
# |
# Global
# development
# https://t.co/MUU9rd0gMr
# @morentinha
# So
# I
# do
# think
# even
# Greece
# has
# to
# be
# more
# tough.
# There’s
# no
# immigrant
# in
# Birmingham.
# Cause
# that’s
# on
# the
# other
# side.
# And
# even
# if
# you
# see
# 5
# in
# UK.
# Imagine
# how
# many
# are
# in
# the
# entrance
# 😉
# (hundreds
# of
# thousands).
# In
# a
# country
# of
# 10M
# people...
# Current
# #MigrationEU
# policies
# trap
# families
# with
# children
# in
# overcrowded
# +
# unsanitary
# camps
# like
# #Moria.
# 🇬🇷
# Greece
# +
# 🇪🇺
# the
# EU
# must
# overhaul
# the
# asylum
# system
# to
# do
# what
# it
# is
# meant
# to
# do:
# protect
# people
# seeking
# safety.
# 👉https://t.co/aB9PPY1kg5
# https://t.co/mYn5rh7Zw7
# Covid
# refugee
# case
# sparks
# fears
# of
# ‘closed
# camps’
# in
# Lesbos
# |
# Global
# development
# https://t.co/7x2PFXjQw5
# https://t.co/JG4XvGtU3Q
# Greece
# imposes
# dangerous
# lockdown
# of
# Moria
# refugee
# camp
# after
# first
# COVID-19
# case
# @LeeMitc_80
# @brim90
# @GaryLineker
# @RESCUE_UK
# Not
# exactly
# fair,
# is
# it?
# First
# safe
# country
# is
# NEVER
# the
# UK!
# Let
# them
# all
# stay
# in
# overcrowded
# camps
# in
# Greece
# or
# Italy,
# while
# we
# don't
# provide
# safe
# routes
# for
# genuine
# refugees?
# Seeking
# asylum
# is
# not
# illegal.
# Unless
# you
# have
# spoken
# to
# the
# migrants,
# you
# can't
# judge
# them!
# #Refugee
# #COVID19
# case
# sparks
# 'closed
# camps'
# fears
# on
# #Lesbos.
# Greek
# government
# suggests
# need
# for
# ‘closed
# and
# controlled’
# structures
# but
# #NGOs
# fear
# virus
# is
# pretext
# for
# increased
# restrictions
# https://t.co/OkANoHpMyT
# via
# @guardian
# #HumanRights
# #Health
# #Dignity
# A
# total
# of
# 118
# migrants
# flew
# from
# Greece
# to
# Germany
# yesterday.
# The
# transfer
# was
# part
# of
# a
# European
# effort
# to
# get
# hundreds
# of
# vulnerable
# children
# and
# their
# close
# family
# members
# out
# of
# camps
# on
# the
# Greek
# islands
# amid
# the
# coronavirus
# pandemic.
# https://t.co/PhJibrIjFx
# @mariathena
# @thedukeoriginal
# Unfair
# and
# condemnable
# that
# Greece
# has
# received
# 5
# billion
# euros
# for
# refugees
# and
# not
# only
# are
# you
# stealing
# that
# and
# they
# get
# none
# but
# you
# come
# and
# take
# photos
# when
# they
# look
# for
# the
# small
# amount
# they
# need
# to
# eat.
# @MughalLife1
# @pacifier8141
# turkey
# gives
# safe
# haven
# to
# israels
# isis
# terrorists
# they
# trade
# with
# israel
# ,
# threaten
# greece
# ,
# remember
# the
# heavy
# handed
# tactics
# on
# peaceful
# turkish
# protestors,
# too
# much
# control
# over
# the
# media
# ,
# threatens
# to
# flood
# europe
# with
# migrants
# Lesbos
# latest:
# The
# first
# recorded
# coronavirus
# case
# in
# Moria
# refugee
# camp
# on
# Lesbos,
# where
# just
# under
# 13,000
# people
# are
# living
# in
# a
# space
# designed
# for
# 3,000,
# has
# led
# to
# fears
# that
# the
# government
# will
# use
# the
# pandemic
# as
# a
# pretext
# to
# create
# closed
# camps.
# https://t.co/2L3TEu9me6
# @TJ97339066
# This
# is
# why
# places
# in
# South-Central
# Italy
# like
# Umbria
# and
# Marche,
# which
# were
# NEVER
# subjected
# to
# migration
# fluxes
# from
# the
# Middle
# East
# as
# the
# city
# of
# Rome,
# are
# genetically
# related
# to
# Southern
# Italy
# and
# Greece
# rather
# than
# to
# Tuscany
# and
# Northern
# Italy.
# @RBryan275
# @AndyEastAnglia
# @PaulCrackne11
# @JMPSimor
# @carolinenokes
# I've
# worked
# in
# Greece
# with
# refugees
# and
# I've
# been
# to
# the
# camps.
# The
# situation
# is
# much
# more
# significant
# there,
# yet
# you
# have
# very
# few
# people
# saying
# it
# is
# destroying
# their
# country.
# @M_a_t_t__O
# @AbuKarol
# @5COUS3
# @Geojblack
# @BarristerSecret
# Well
# if
# we
# supported
# Greece
# with
# a
# lot
# more
# money
# and
# a
# lot
# more
# safe
# transit
# of
# asylum
# seekers
# who
# keep
# rocking
# up
# there,
# the
# refugees
# might
# be
# safely
# processed
# in
# Greece
# before
# they
# come
# to
# the
# UK.
# I
# don't
# blame
# Greece
# for
# letting
# a
# bunch
# go
# on
# their
# way.
# to
# recruit
# mercenaries
# from
# refugee
# populations
# to
# fight
# in
# foreign
# wars.
# However,
# the
# increasingly
# militaristic
# regime
# of
# Recep
# Tayyip
# Erdogan
# has
# been
# hosting
# Hamas
# and
# pushing
# an
# agenda
# that
# has
# seen
# Turkey
# threaten
# Greece,
# France,
# Israel,
# Iraq,
# Syria,
# the
# United
# States
# and-
# @DiCastro2
# @baphometx
# @tvxs
# Greece
# has
# a
# deadly
# new
# migration
# policy
# –
# and
# all
# of
# Europe
# is
# to
# blame
# https://t.co/wfTXUdU6b9
# @gcindemir
# @karsi_dusunce
# @YusufErim34
# and
# how
# could
# there
# be
# a
# security
# issue
# for
# Turkey
# has
# all
# migrants
# coming
# out
# of
# lybia
# go
# to
# Italy's
# and
# Malta's
# waters
# first
# and
# to
# Greece's
# waters
# second
# ?
# I
# don't
# get
# your
# point.
# No
# threat
# at
# all
# for
# Turkey.
# @antouan_hellas
# @jensstoltenberg
# Greece
# has
# actually
# lied
# to
# Mr
# Stoltenberg.
# They
# told
# him,
# they
# are
# ready
# for
# negotiations,
# but
# then
# said
# they
# have
# did
# NOT
# do
# that.
# Well,
# as
# expected
# from
# a
# country,
# whos
# existence
# is
# entirety
# dependend
# of
# EU
# money.
# Wothout
# the
# EU
# greek
# people
# would
# seek
# refuge
# in
# Turkey.
# HAHAHA
# @Susan60190970
# @AndreAp0ll0
# @itvnews
# @emmamurphyitv
# Please
# tell
# me,
# what
# exactly
# do
# you
# know
# about
# the
# asylum
# seekers
# systems
# in
# countries
# like
# France,
# Germany
# and
# Greece?
# Details
# please.
# I'm
# very
# interested
# in
# how
# you
# know
# their
# systems
# are
# flawless
# and
# don't
# discriminate
# 🙃
# via
# @PerilOfAfrica
# #Newsdeck
# COVID-19:
# Greece
# reports
# first
# coronavirus
# case
# in
# Moria
# migrant
# camp
# on
# Lesbos:
# ATHENS,
# Sept
# 2
# (Reuters)
# -
# Greece
# recorded
# its
# first
# coronavirus
# case
# in
# the
# overcrowded
# migrant
# camp
# of
# Moria
# on
# the
# island
# of
# Lesbos
# and
# the…
# https://t.co/O31oc3V6j0
# https://t.co/24C6hWAyVz
# @BenTheSilent
# @AndreAp0ll0
# @itvnews
# @emmamurphyitv
# That's
# not
# what
# i
# said
# refugees
# who
# are
# brought
# in
# through
# the
# proper
# channels
# are
# vetted.
# Do
# you
# watch
# what's
# happening
# france
# Germany
# and
# Greece.
# If
# they
# were
# genuine
# they
# wouldn't
# have
# been
# refused
# asylum
# in
# the
# countries
# they've
# passed
# No
# I
# don't
# think
# they
# are
# all
# criminals
# @SputnikInt
# Greece
# are
# more
# likely
# to
# drown
# the
# refugees.
# Most
# people
# will
# say
# that
# this
# is
# absurd
# but
# if
# you
# closely
# watch
# their
# policies
# on
# #Libya
# &
# #EastMed
# (#Greece
# #Cyprus
# #Turkey)
# and
# on
# the
# migration
# matter
# in
# #Europe,
# you
# will
# realize
# that
# indirectly
# or
# directly
# support
# #MuslimBritherhood
# and
# #PoliticalIslam’
# expansionism.
# @BrendanWoodshed
# Then
# stay
# in
# Spain,
# Greece,
# or
# Italy
# and
# apply
# for
# asylum
# in
# the
# U.K.
# through
# the
# legal
# channels
# .
# Or
# hope
# that
# there
# are
# enough
# people
# in
# the
# U.K.
# willing
# to
# convince
# everyone
# else
# in
# the
# U.K.
# that
# trafficking
# through
# illegal
# routes
# is
# ok
# and
# the
# “correct”
# moral
# response.
# I
# know
# it
# is
# not
# a
# scoop,
# but
# are
# #EU
# countries
# using
# COVID-19
# to
# clamp
# down
# on
# #refugees?
# Rights
# groups
# say
# the
# coronavirus
# pandemic
# has
# given
# #Italy
# and
# #Greece
# a
# chance
# to
# crack
# down
# on
# the
# unwanted
# visitors.
# https://t.co/6TVByVbFYV
# .@MSF
# condemns
# attack
# on
# its
# pediatric
# clinic
# near
# Moria
# refugee
# camp
# in
# Greece
# |
# Lesvos
# field
# coordinator:
# “In
# what
# world
# do
# we
# live
# in
# where
# children
# and
# pregnant
# women
# being
# treated
# by
# doctors
# are
# subject
# to
# people
# throwing
# stones
# at
# them?”
# https://t.co/dKAEMPh1Fm
# https://t.co/UfA1zf5Skc
# @derekc78
# Any
# illegal
# English
# migrants
# trying
# to
# get
# into
# Greece
# https://t.co/8D4nUeJzxI
# @vultan2000
# @itvlondon
# i
# am
# Italian
# I
# am
# fluent
# in
# 4
# languages.
# I
# translate
# documents.
# These
# are
# figures
# from
# Italian
# government.
# Refugee,
# from
# the
# EU..
# really???
# why
# can't
# the
# French
# /EU
# provide
# it.
# To
# reach
# France
# they
# have
# come
# through
# Greece,
# Italy
# or
# Spain.
# All
# Safe
# countries

# %%
#manual_candidates = ['refugees', 'migrant', 'immigrant', 'greece', 'turkey','people']

# this dictionary is going to be - target_concept: [(frame1,weight1),(frame2,weight2)]
frame_dictionary = {}

tags = tag_tweets(tweets_corpus)


#print(tags)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:33<00:00,  1.16s/it]

# %%
cols = ['word'] + list(frame_properties.keys())

framed_words = pd.DataFrame.from_dict(cand_frames)

framed_words
# Out:
#                                                    settlement  \
# camp        [0.096779585, 0.096779585, 0.022478957, 0.0224...
# case        [0.044889618, 0.108972326, 0.108972326, 0.0219...
# 19          [0.0544194, 0.0544194, 0.0544194, 0.0544194, 0...
# migrant     [0.14113313, 0.14113313, 0.108972326, 0.108972...
# Covid        [0.28724444, 0.28724444, 0.28724444, 0.28724444]
# ...                                                       ...
# member                             [0.046724994, 0.046724994]
# struggling                                       [0.10712366]
# situation                                       [0.046724994]
# %                                  [0.008056514, 0.008056514]
# men                                                        []
#
#                                                  accomodation  \
# camp        [0.20433454, 0.20433454, 0.003927827, 0.003927...
# case        [0.1975876, -0.01711282, -0.01711282, 0.136996...
# 19          [-0.014394398, -0.014394398, -0.014394398, -0....
# migrant     [0.20153728, 0.20153728, -0.01711282, -0.01711...
# Covid       [0.0150301345, 0.0150301345, 0.0150301345, 0.0...
# ...                                                       ...
# member                             [0.045278594, 0.045278594]
# struggling                                      [0.052662566]
# situation                                       [0.045278594]
# %                                    [0.20469183, 0.20469183]
# men                                                        []
#
#                                                  accommodated  \
# camp        [0.027445737, 0.027445737, 0.17925097, 0.17925...
# case        [0.2931801, -0.030498743, -0.030498743, 0.0966...
# 19          [0.02126009, 0.02126009, 0.02126009, 0.0212600...
# migrant     [0.19091144, 0.19091144, -0.030498743, -0.0304...
# Covid       [0.072666705, 0.072666705, 0.072666705, 0.0726...
# ...                                                       ...
# member                               [0.20955454, 0.20955454]
# struggling                                      [0.052333802]
# situation                                        [0.20955454]
# %                                  [0.026824536, 0.026824536]
# men                                                        []
#
#            military barrack  \
# camp                     []
# case                     []
# 19                       []
# migrant                  []
# Covid                    []
# ...                     ...
# member                   []
# struggling               []
# situation                []
# %                        []
# men                      []
#
#                                                          tent  \
# camp        [-0.04001374, -0.04001374, -0.0020679757, -0.0...
# case        [0.0552354, 0.05133646, 0.05133646, 0.02544808...
# 19          [-0.03341804, -0.03341804, -0.03341804, -0.033...
# migrant     [0.43063366, 0.43063366, 0.05133646, 0.0513364...
# Covid        [0.04901067, 0.04901067, 0.04901067, 0.04901067]
# ...                                                       ...
# member                             [0.049148176, 0.049148176]
# struggling                                        [0.0796655]
# situation                                       [0.049148176]
# %                                  [0.015281253, 0.015281253]
# men                                                        []
#
#                                                          camp  \
# camp        [0.005917713, 0.005917713, 0.031675775, 0.0316...
# case        [0.13421468, 0.07666254, 0.07666254, 0.0297146...
# 19          [0.0919154, 0.0919154, 0.0919154, 0.0919154, 0...
# migrant     [1.0, 1.0, 0.07666254, 0.07666254, 0.10588831,...
# Covid                [0.098471, 0.098471, 0.098471, 0.098471]
# ...                                                       ...
# member                               [0.05835045, 0.05835045]
# struggling                                      [0.076842785]
# situation                                        [0.05835045]
# %                                [-0.034571387, -0.034571387]
# men                                                        []
#
#                                                         quota  \
# camp        [0.079393506, 0.079393506, -0.018778834, -0.01...
# case        [0.12676318, 0.020955017, 0.020955017, 0.07371...
# 19          [-0.015046243, -0.015046243, -0.015046243, -0....
# migrant     [0.09900418, 0.09900418, 0.020955017, 0.020955...
# Covid       [0.013520267, 0.013520267, 0.013520267, 0.0135...
# ...                                                       ...
# member                               [0.02326626, 0.02326626]
# struggling                                       [0.05853714]
# situation                                        [0.02326626]
# %                                  [0.078825526, 0.078825526]
# men                                                        []
#
#                                                     reception  \
# camp        [0.036053136, 0.036053136, 0.021431496, 0.0214...
# case        [0.12154389, 0.0066398564, 0.0066398564, 0.067...
# 19          [0.031472094, 0.031472094, 0.031472094, 0.0314...
# migrant     [0.12727246, 0.12727246, 0.0066398564, 0.00663...
# Covid        [0.02983211, 0.02983211, 0.02983211, 0.02983211]
# ...                                                       ...
# member                             [-0.03067905, -0.03067905]
# struggling                                      [0.020090828]
# situation                                       [-0.03067905]
# %                                  [0.023241833, 0.023241833]
# men                                                        []
#
#                                                      together  \
# camp        [0.0037784167, 0.0037784167, -0.011410972, -0....
# case        [0.05211144, -0.013627447, -0.013627447, 0.069...
# 19          [-0.02222292, -0.02222292, -0.02222292, -0.022...
# migrant     [0.02476906, 0.02476906, -0.013627447, -0.0136...
# Covid       [0.054004237, 0.054004237, 0.054004237, 0.0540...
# ...                                                       ...
# member                               [0.06304469, 0.06304469]
# struggling                                       [0.22240086]
# situation                                        [0.06304469]
# %                                    [0.05053803, 0.05053803]
# men                                                        []
#
#                                                        asylum  ...  \
# camp        [0.1519616, 0.1519616, -0.038508326, -0.038508...  ...
# case        [0.2248644, 0.062638074, 0.062638074, 0.035149...  ...
# 19          [0.04686284, 0.04686284, 0.04686284, 0.0468628...  ...
# migrant     [0.19039115, 0.19039115, 0.062638074, 0.062638...  ...
# Covid        [0.12780023, 0.12780023, 0.12780023, 0.12780023]  ...
# ...                                                       ...  ...
# member                             [0.049595706, 0.049595706]  ...
# struggling                                       [0.07690313]  ...
# situation                                       [0.049595706]  ...
# %                                    [0.18259677, 0.18259677]  ...
# men                                                        []  ...
#
#                                                         fight  \
# camp        [0.07469394, 0.07469394, 0.006586885, 0.006586...
# case        [0.08583819, -0.0119549185, -0.0119549185, 0.1...
# 19          [0.08653071, 0.08653071, 0.08653071, 0.0865307...
# migrant     [0.1417236, 0.1417236, -0.0119549185, -0.01195...
# Covid        [0.25302434, 0.25302434, 0.25302434, 0.25302434]
# ...                                                       ...
# member                             [0.046919152, 0.046919152]
# struggling                                       [0.11988971]
# situation                                       [0.046919152]
# %                                    [0.07092823, 0.07092823]
# men                                                        []
#
#                                                           war  \
# camp        [0.09578044, 0.09578044, -0.023129065, -0.0231...
# case        [0.02462985, 0.03602062, 0.03602062, 0.0396573...
# 19          [0.013281414, 0.013281414, 0.013281414, 0.0132...
# migrant     [0.14014623, 0.14014623, 0.03602062, 0.0360206...
# Covid        [0.16647193, 0.16647193, 0.16647193, 0.16647193]
# ...                                                       ...
# member                               [0.06789708, 0.06789708]
# struggling                                       [0.15207517]
# situation                                        [0.06789708]
# %                                    [0.09300359, 0.09300359]
# men                                                        []
#
#                                                          dead  \
# camp        [-0.024847355, -0.024847355, 0.13116385, 0.131...
# case        [0.31372595, 0.1105189, 0.1105189, 0.06011012,...
# 19          [0.12918106, 0.12918106, 0.12918106, 0.1291810...
# migrant     [0.06850475, 0.06850475, 0.1105189, 0.1105189,...
# Covid        [0.09083742, 0.09083742, 0.09083742, 0.09083742]
# ...                                                       ...
# member                               [0.09239874, 0.09239874]
# struggling                                       [0.16518636]
# situation                                        [0.09239874]
# %                              [-0.0017056912, -0.0017056912]
# men                                                        []
#
#                                                       rescued  \
# camp        [0.036126204, 0.036126204, 0.1757022, 0.175702...
# case        [0.3866048, 0.14275861, 0.14275861, 0.07378995...
# 19          [0.06322109, 0.06322109, 0.06322109, 0.0632210...
# migrant     [0.13938421, 0.13938421, 0.14275861, 0.1427586...
# Covid        [0.07353256, 0.07353256, 0.07353256, 0.07353256]
# ...                                                       ...
# member                             [0.100803845, 0.100803845]
# struggling                                       [0.09114686]
# situation                                       [0.100803845]
# %                                  [0.023498055, 0.023498055]
# men                                                        []
#
#                                                         state labour  \
# camp        [0.1324172, 0.1324172, 0.072251014, 0.07225101...     []
# case        [0.08103147, 0.074176654, 0.074176654, 0.04161...     []
# 19          [0.0953567, 0.0953567, 0.0953567, 0.0953567, 0...     []
# migrant     [0.0812741, 0.0812741, 0.074176654, 0.07417665...     []
# Covid        [0.15080929, 0.15080929, 0.15080929, 0.15080929]     []
# ...                                                       ...    ...
# member                                 [0.0603837, 0.0603837]     []
# struggling                                       [0.17694753]     []
# situation                                         [0.0603837]     []
# %                                  [0.019637551, 0.019637551]     []
# men                                                        []     []
#
#                                                      employed  \
# camp        [-0.045608632, -0.045608632, 0.18880078, 0.188...
# case        [0.16430435, 0.041758478, 0.041758478, 0.10444...
# 19          [0.05923778, 0.05923778, 0.05923778, 0.0592377...
# migrant     [0.04498983, 0.04498983, 0.041758478, 0.041758...
# Covid        [0.09731477, 0.09731477, 0.09731477, 0.09731477]
# ...                                                       ...
# member                               [0.15285343, 0.15285343]
# struggling                                       [0.09438409]
# situation                                        [0.15285343]
# %                                    [0.09812751, 0.09812751]
# men                                                        []
#
#                                                    unemployed  \
# camp        [0.114989236, 0.114989236, 0.0006968416, 0.000...
# case        [0.059248056, -0.013417903, -0.013417903, -0.0...
# 19          [-0.054391023, -0.054391023, -0.054391023, -0....
# migrant     [0.100330524, 0.100330524, -0.013417903, -0.01...
# Covid        [0.08290385, 0.08290385, 0.08290385, 0.08290385]
# ...                                                       ...
# member                             [0.024691502, 0.024691502]
# struggling                                       [0.07204249]
# situation                                       [0.024691502]
# %                                    [0.05106765, 0.05106765]
# men                                                        []
#
#                                                   integration  \
# camp        [0.18403187, 0.18403187, 0.075890444, 0.075890...
# case        [0.052662343, 0.0003894046, 0.0003894046, 0.02...
# 19          [0.09300181, 0.09300181, 0.09300181, 0.0930018...
# migrant     [-0.06051269, -0.06051269, 0.0003894046, 0.000...
# Covid        [0.03911755, 0.03911755, 0.03911755, 0.03911755]
# ...                                                       ...
# member                           [-0.009682907, -0.009682907]
# struggling                                      [0.018609447]
# situation                                      [-0.009682907]
# %                                    [0.10707511, 0.10707511]
# men                                                        []
#
#                                                      positive
# camp        [0.13560301, 0.13560301, 0.103027016, 0.103027...
# case        [0.141266, 0.12976848, 0.12976848, 0.0731404, ...
# 19          [0.22546183, 0.22546183, 0.22546183, 0.2254618...
# migrant     [0.10884626, 0.10884626, 0.12976848, 0.1297684...
# Covid        [0.08254479, 0.08254479, 0.08254479, 0.08254479]
# ...                                                       ...
# member                               [0.23670721, 0.23670721]
# struggling                                       [0.17996968]
# situation                                        [0.23670721]
# %                                      [0.0658559, 0.0658559]
# men                                                        []
#
# [193 rows x 47 columns]

# %%
cand_df
# Out:
#                                             candidates  \
# 0    (Morocco Tunisia Libya Greece Turkey Each one ...
# 1    (access to territory & asylum, living conditio...
# 2    (economic migrants who cross developed nations...
# 3    (population & children for 39%, of whom more t...
# 4    (brink of lockdown, outbreak at asylum seeker ...
# ..                                                 ...
# 337                  (riots!, riots, {!, riots}, misc)
# 338                           (who, who, {who}, group)
# 339                        (MSM, MSM, {MSM}, group-ne)
# 340                         (2040, 2040, {2040}, misc)
# 341                 (Greece, Mazou, {Mazou}, group-ne)
#
#                                              cand_tags  \
# 0    [\n  {\n    "id": 1,\n    "text": "it",\n    "...
# 1    [\n  {\n    "id": 1,\n    "text": "3",\n    "l...
# 2    [\n  {\n    "id": 1,\n    "text": "They",\n   ...
# 3    [\n  {\n    "id": 1,\n    "text": "asylum",\n ...
# 4    [\n  {\n    "id": 1,\n    "text": "help",\n   ...
# ..                                                 ...
# 337  [\n  {\n    "id": 1,\n    "text": "Greece",\n ...
# 338  [\n  {\n    "id": 1,\n    "text": "they",\n   ...
# 339  [\n  {\n    "id": 1,\n    "text": "candidate_t...
# 340  [\n  {\n    "id": 1,\n    "text": "2",\n    "l...
# 341  [\n  {\n    "id": 1,\n    "text": "you",\n    ...
#
#                                              cand_text  cand_len
# 0    Morocco Tunisia Libya Greece Turkey Each one o...        19
# 1    access to territory & asylum, living condition...        19
# 2    economic migrants who cross developed nations ...        19
# 3    population & children for 39%, of whom more th...        19
# 4    brink of lockdown, outbreak at asylum seeker h...        18
# ..                                                 ...       ...
# 337                                             riots!         1
# 338                                                who         1
# 339                                                MSM         1
# 340                                               2040         1
# 341                                             Greece         1
#
# [342 rows x 4 columns]

# %%
from nltk.corpus import stopwords

nltk_words = list(stopwords.words('english'))


tweets_corpus = list(preprocessing.preprocess_tweets(event_df['Tweet Raw'][200:300]))


word_properties = defaultdict(dict)
for i in tweets_corpus:
    tweet_words = [word  for word in i.split() if word not in nltk_words and len(word)>1]
    for word in tweet_words:
        #print(word)
        property_list = []
        #print(list(frame_properties.keys()))
        for prop in list(frame_properties.keys()):
            #print(frame_properties[prop])
            
            try:
                #print(f'sim of {word}, {prop} is {model.similarity(word, prop)}')
                weights = [model.similarity(word, seed) for seed in frame_properties[prop]]
                #print(weights)
                if max(weights)>0.4:
                    word_properties[word][prop] = max(weights)
            except KeyError:
                pass
            



print(word_properties)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 917.18it/s]
# defaultdict(<class 'dict'>, {'Greeces': {'economisation': 0.4905119}, 'get': {'reception': 0.50504476}, 'EU': {'economisation': 0.51138544}, 'Greece': {'economisation': 0.42833072}, 'currency': {'economisation': 0.633761}, 'need': {'humanitarian': 0.46502197}, 'money': {'economisation': 1.0}, 'give': {'reception': 0.5135118}, 'refugee': {'reception': 0.60989624}, 'murder': {'criminality': 0.53367186, 'victimization': 0.40415478}, 'migrants': {'reception': 0.4879586}, 'cash': {'economisation': 0.6151221}, 'Refugee': {'reception': 0.46804923}, 'support': {'humanitarian': 1.0}, 'refuge': {'reception': 0.41259414}, 'country': {'victimization': 0.43598586}, 'send': {'reception': 0.46330065}, 'Muslims': {'victimization': 0.4740045}, 'jihadists': {'victimization': 0.40899324}, 'Islam': {'victimization': 0.5393352}, 'gang': {'criminality': 0.48914832}, 'financial': {'economisation': 0.56026417}, 'needed': {'humanitarian': 0.50178003}, 'help': {'humanitarian': 1.0}, 'helped': {'humanitarian': 0.5614464}, 'million': {'economisation': 1.0}, 'saved': {'victimization': 0.45287922}, 'refugees': {'reception': 0.51550376}, 'immigrants': {'reception': 0.44639784}, 'arrive': {'reception': 0.41649738}, 'together': {'reception': 1.0}, 'fight': {'victimization': 0.99999994}, 'fled': {'criminality': 0.40912294}, 'apply': {'reception': 0.4702472}, 'asylum': {'reception': 1.0}, 'escaping': {'victimization': 0.42784286}, 'borders': {'security': 0.7178472}, 'billion': {'economisation': 0.80567366}, 'dollars': {'economisation': 0.62885237}, 'europe': {'victimization': 0.42174834}, 'detained': {'criminality': 0.4599186, 'victimization': 0.40719983}, 'arrested': {'criminality': 0.5608969}, 'border': {'security': 1.0}, 'terrorism': {'criminality': 0.4885409, 'victimization': 0.45032072}, 'soldiers': {'victimization': 0.41182545}, 'killed': {'victimization': 0.70920515}, 'try': {'humanitarian': 0.5073055}, 'defense': {'criminality': 0.5541691}, 'European': {'economisation': 0.47944316}, 'hundreds': {'economisation': 0.5586643}, 'thousands': {'economisation': 0.5717704}, 'escape': {'victimization': 0.42087197}, 'seek': {'reception': 0.42984623}, 'Muslim': {'victimization': 0.52780384}, 'political': {'economisation': 0.45409435}, 'nation': {'victimization': 0.4697637}, 'protection': {'security': 0.42394572}, 'economic': {'economisation': 1.0}, 'received': {'reception': 0.6799966}, 'Asylum': {'reception': 0.49217433}, 'Police': {'criminality': 0.8035108}, 'cruel': {'humanitarian': 0.4713152}, 'courage': {'humanitarian': 0.42972934}, 'spirit': {'humanitarian': 0.4039147}, 'gates': {'security': 0.41464096}, 'Border': {'security': 0.6046883}, 'government': {'victimization': 0.45800617}, 'thier': {'victimization': 0.4115634}, 'illegal': {'criminality': 0.45195127}, 'receive': {'reception': 1.0}, 'total': {'economisation': 0.5242376}, 'State': {'victimization': 0.544677}, 'reception': {'reception': 1.0}, 'syrian': {'victimization': 0.43796158}, 'care': {'humanitarian': 1.0}, 'millon': {'economisation': 0.71063304}, 'contribute': {'humanitarian': 0.4341417}, 'economically': {'economisation': 0.52699316}, 'smugglers': {'security': 0.45779204, 'criminality': 0.5098644}, 'smuggle': {'criminality': 0.44252563}, 'president': {'criminality': 0.45277518}, 'Deportation': {'reception': 0.43570113}, 'thousand': {'economisation': 1.0}, 'authorities': {'criminality': 0.57922405}, 'states': {'victimization': 0.45255753}, 'war': {'victimization': 1.0}, 'deported': {'reception': 0.59214413}, 'deport': {'reception': 0.5817115}, 'health': {'humanitarian': 0.466594}, 'nearly': {'economisation': 0.43894133}, 'fencing': {'security': 0.69528615}, 'humanitarian': {'humanitarian': 0.45422113}, 'cross': {'security': 0.53835654}, 'accept': {'reception': 0.45288754}, 'inhumane': {'humanitarian': 0.582819}, 'struggling': {'humanitarian': 0.419971}, 'Refugees': {'reception': 0.4376936}, 'visa': {'reception': 0.58391386}, 'qatar': {'victimization': 0.42679524}})

# %%
# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(tweets_corpus) 

all_tweets_list = all_tweets_list + ['Muslim refugees is government']

for tweet in range(len(all_tweets_list)):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if tweet_sentokenized == []:
        tweet_sentokenized.append('empty_tweet')
        print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=1000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text
# Out:
# 101it [00:30,  3.36it/s]
# 'Greeces Moria migrant camp quarantined after first Covid - 19 case via @TheNationalUAE'

# %%
from collections import defaultdict

cand_frames = defaultdict(list)

framed_words = pd.DataFrame(columns=['word',list(frame_properties.keys())])


for tweet_id in tqdm(range(len(tagged_tweets))):
    #print(tweet)
    np_heads = [[word.id, word.text,word.head] for sent in tagged_tweets[tweet_id].sentences for word in sent.words]
    #print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
    #print(np_heads)
    #print(len(cand_df['candidates']))
    for cand in cand_df['candidates']:
        print(cand[0])
        #print(get_head(str(cand)))
        for phrase_head in cand[2]:  
            
            #if str(cand[1]) in str(tweet):
            #print(phrase_head)
            if phrase_head in tagged_tweets[tweet_id].text and len(phrase_head)>1:
                #print(phrase_head)
                #find all dependencies of the phrase head
                for related in range(len(np_heads)):
                    #print(np_heads[related])
                    if phrase_head == np_heads[related][1]:
                        related_word = np_heads[np_heads[related][2]-1][1]
                        
                        print(f'\n\n checking {phrase_head}_{related_word}')
                
                        cand_frames['word'].append(phrase_head)
                        #cand_frames['word'].append(phrase_head)
                        for frame_property in list(frame_properties.keys()):
                            #print(frame_property)

                            try:
                                #print(word_properties[phrase_head][frame_property])
                                cand_frames[frame_property].append(word_properties[related_word][frame_property])
                                
                            except KeyError:
                                #print('Error')
                                #cand_frames[frame_property].append(word_properties['tent'][frame_property])
                                cand_frames[frame_property].append(None)
                
                    #print(len(cand_frames[frame_property]))
                    
                #print('\n')
                
                
                """for frame_property in list(frame_properties.keys()):
                    for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    #print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                            #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                        except KeyError:
                            pass"""
                        #[cand_frames[seed_word][cand].append(model.similarity(print(f'{cand} is related to {np_heads[np_heads[related][2]+1][1]}') if cand == np_heads[related][1] else print('nej') for related in range(len(np_heads))]
            #print(get_head(cand))
            #print(np_heads[19][1])
            #[f(x) if condition else g(x) for x in sequence]
            #[print(np_heads[np_heads[related][2]-1]) if get_head(cand)==np_heads[related][1] else print('hi') for related in range(len(np_heads))]

            
#became ___ (vb and vbx)
#(VP sit/VB (PP on/IN (NP the/DT mat/NN))))) 

#cand_frames
# Out:
#   2%|█▌                                                                                | 2/101 [00:00<00:05, 17.86it/s]
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
#
#
#  checking camp_Greeces
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
#
#
#  checking camp_Greeces
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
#
#
#  checking case_quarantined
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
#
#
#  checking 19_Covid
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
#
#
#  checking migrant_camp
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
#
#
#  checking 19_Covid
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
#
#
#  checking 19_Covid
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
#
#
#  checking Covid_case
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
#
#
#  checking Covid_case
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
#
#
#  checking 19_Covid
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
#
#
#  checking 19_Covid
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
#
#
#  checking covid_camp
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
#
#
#  checking camp_carried
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
#
#
#  checking camp_carried
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
#
#
#  checking be_carried
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
#
#
#  checking 19_tests
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
#
#
#  checking migrant_camp
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
#
#
#  checking covid_camp
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
#
#
#  checking 19_tests
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
#
#
#  checking 19_tests
#
#
#  checking covid_camp
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
#
#
#  checking 19_tests
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
#
#
#  checking covid_camp
# unemployment
# /
# we
# Omfg
# COVID-19
#
#
#  checking 19_tests
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
#
#
#  checking camp_reports
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
#
#
#  checking camp_reports
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
#
#
#  checking case_reports
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
#
#
#  checking coronavirus_case
#
#
#  checking migrant_reports
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
#
#
#  checking Greece_became
#
#
#  checking Germany_the
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
#
#
#  checking Greece_became
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
#
#
#  checking Greece_became
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
#
#
#  checking became_Nazis
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
#
#
#  checking EU_get
#
#
#  checking EU_time
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
#
#
#  checking give_the
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
#
#
#  checking need_Nazis
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
#
#
#  checking Greece_became
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
#
#
#  checking EU_get
#
#
#  checking EU_time
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
#
#
#  checking way_Greece
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
#
#
#  checking need_Nazis
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
#
#
#  checking get_time
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
#
#
#  checking the_time
#
#
#  checking the_Greece
#
#
#  checking the_own
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
#
#
#  checking us_.
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
#
#
#  checking way_Greece
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
#
#
#  checking and_in
#
#
#  checking and_.
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
#
#
#  checking that_we
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
#   5%|████                                                                              | 5/101 [00:00<00:05, 18.28it/s]
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
#
#
#  checking Greece_refugee
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
#
#
#  checking Greece_refugee
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
#
#
#  checking Greece_refugee
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
#
#
#  checking 2015_And
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
#
#
#  checking it_!
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
#
#
#  checking Greece_refugee
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
#
#
#  checking it_!
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
#
#
#  checking it_!
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
#
#
#  checking the_from
#
#
#  checking the_again
# isis terrorists they trade with israel
# the poor quality of the it
#
#
#  checking it_!
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# ...
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
#
#
#  checking Greece_.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
#
#
#  checking migration_over
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
#
#
#  checking migration_over
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
#
#
#  checking men_.
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece
# Morocco Tunisia Libya Greece Turkey Each one of these unnamed bodies represents a family searching endlessly for a lost
# access to territory & asylum, living conditions on mainland & islands, the management of the covid 19 response, integration
# economic migrants who cross developed nations such as Greece, Italy, Spain, Germany and France to come to the UK
# population & children for 39%, of whom more than 7 out of 10 are younger than 12 years old
# brink of lockdown, outbreak at asylum seeker hostel in Birmingham and Greece chaos Stories from 2 sources birmingham
# enough people in the U.K. willing to convince everyone else in the U.K. that trafficking through illegal routes
# The largest terrorist organization in the world, the names of the Syrian refugees, to enter Bulgaria to Greece
#
#
#  checking refugees_government
# t work as Earlier Greece have forcefully pushed migrants in Turkish water with which Turkey was Upset
# Its sounds more a kin to a penny dreadful sci fi novel than an economic treatise .
# camp on Lesbos, where just under 13,000 people are living in a space designed for 3,000,
# Five years later: How September 5th, 2015, became a crossroads for the migration crisis-- budapest
# a people who have competed with the PKK over the issue of being more lowness
# no surprise that Greece shelters those FET members who attempted a failed coup in Turkey
# WE' RE ECSTATIC to be able to release our 2 k matched funds for @RuhiLoren
# you' re going to keep supporting Turkey over 2 of the EU' s member countries
# its a fact that ISIS member find a passage through illegal immigration in Europe
# Its a stain on Europe to hold people in such conditions for so long.
# this boundary using @FiLMiCPro first light this week in lesbos infamous Moria migrants camp
# a given, more or less a basic human right like water and food
# More bad than good it' s supplied by a private/public joint venture .
# part of European culture & heritage, so it' s not worthy of protection
# a lot of the Turkish people, lawyers, teachers, officers, judges and civil servants
# the endgame of allowing unmitigated/unchecked illegal migration from the Middle East and Africa
# Neither the Greek state nor the [boss] care about our lives or health
# Refugee Covid case sparks' closed camps' fears on Lesbos | Global development: sant
# A photo to give you an impression of the food in moria .
# the second year that we have supported this Appeal for Hope and Kindness
# mountain cheese shieapnew zealand greece algeria club med migros jumbo deliveries BY
# recent flare ups in TX & Florida (migrants from Mexico & Caribbean)
# The bitter taste of Greek strawberries: The exploitation of unfree migrant labour
# the Voices in refugee education conference yesterday, & especially interesting discussions
# him and some others and the riot police who had guns
# the ones who want to contribute and have something to offer
# afghanistan (76%), syria (7%) and Democratic Republic of the congo (7%)
# its the result of an entire continent acting in its perceived
# critical issues that must be addressed, incl the urgent need 2
# Viotia Refugee Detention Camp in GREECE Locked Down for COVID-19 greece
# The new Greek Asylum Service microsite () that replaces .
# a recent lack of cooperation from the Turkish coast guard
# its 12 mile maritime territory all turkey needs to do
# It' s a shame Greece learned that too late .
# I' m very interested in how you know their systems
# the best ideas in our online event innowise challenge labs
# Greece : 1/2 of UK size, twice of asylum seekers.
# a potential embellishments of hard facts and harsh reality
# a chance to crack down on the unwanted visitors
# Cemeteries just for unidentified migrant bodies from the Mediterranean
# The infected person , a 40 year old man
# a country that has been your dreams for centuries
# germany (162,000), france (110,000), greece (65,000) and italy (49,000)
# Two high ranking UN Refugee Agency officials on Friday
# if there will be an EU or what it
# refugees, discussed with authorities and NGOs refugee protection challenges
#
#
#  checking refugees_government
# Portugal and parts of Greek Island on the list
# a severe economic crisis and now the COVID-19 pandemic-@RaoufMazou
# the way who hosted me and spoke to me
# refuge in a 3 rd class eastern European country
# 7000 Turks from the beginning of the year
# top of your $20,000 salary to see what
# 1984 the loive of kidnapping are with rene
# This idea that the uk is being overwhelmed
# the heavy handed tactics on peaceful turkish protestors
# the increasingly militaristic regime of Recep Tayyip Erdogan
# any, but the xenophobic, right wing nut jobs,
# scapegoating UK citizens with our migrant history
# First COVID-19 Case in Moria Refugee Camp
# territory for those in need of protection
# the life you could not even imagine
# sheap kidnap pay for e vew jeer
# precious & the only means of contact
# libya & east med (greece cyprus turkey)
# people crossing sea' s in little boats
# all the challenges the country has faced
# their own countries, and pro-islamic extremism/illegal migration
# You' re likely to get your head
# a new Ottoman Empire it might seem
# the supply of ready - made food
# That' s how a waterless region
# the latter claim (HRW & NGOs)
# great solidarity towards 1 0 0
# muslim britherhood and political islam expansionism
# less than 72 hours, all thanks
# the chance of breeding bird behaviour
# m not defending them after it
# the same colour passport as you
# Your sneaky political game didn' t
# no . . . . .
# a hole in Syrian Refugees' boats
# the island of Lesbos and the
# isis terrorists they trade with israel
# the poor quality of the it
# the only foreign language you know
# Turkish military & a refugee woman
# their strategic partnership with @eBay
# the work of refugee-led groups
# their many services and resources
# a hell of a lot
# the weapons of mass migration
# Pakistan and Afghanistan and Bagladesh
# Somali migrant infected with coronavirus
# us & our partners joy
# the end of the year
# Mujtaba and Im from Afganistan
# very constructive and open exchanges
# m Greek, many in America
# part of the new normal
# both aegean and kastelorizo eez
# the climate of the south
# the exploitation of migrant workers
# the Cordon Sanitaire & more
# the catch an ISIS member
# her phenomenal team in greece
# Their stories matter too .
# a way to political threat
# UNHCR & other agencies
# no immigrant in Birmingham
# s Hell) Closed camps
# closed and controlled structures
# the integration of women
# animals for manipulating refuges
# 2 claims in NYT
# Surly a smallish length
# control over the media
# Roger biland Daniele Francois
# a stronger, motivated govt
# Grandmother who I knew
# the city of Rome
# the RICs very low
# a local mini market
# figures from Italian government
#
#
#  checking government_government
# your army and people
# the 2 k goal
# the correct moral response
# gift much needed shoes
# room, roommate, work, collaboration
# leaver no one behind
# Nigerian embassy in Athens
# Greek militans kil .
# families who are struggling
# the one their fled
# uncertain fates in europe
# your line of reasoning
# safe heaven for Hamas
# My Gr .
# @vonderleyen @NachoSAmor @hrw
# 3 EU members
# Refugee virus cases
# a sensible solution
# Greece dosnt melt
# plans in place
# the migrant route
# end migrant deaths
# a toy factory
# the United Kingdom
# this poor nation
# european union values
# 1 st covid
# . . .
# 200,000 lone child
# development news update
# Erdogans ersatz invaders
# The Trump family
# the full article
# a larger presence
# @PerilOfAfrica newsdeck COVID-19
# Isaac Bessudos widow
# the coronavirus pandemic
# an example and
# a long journey
# ' caring' acts
# our clinic doors
# its a term
# the other side
# your general stateme
# refugee covid 19
# Greece iwo men
# Sexual assault ect
# photo gr apy
# five for hope
# parts of Syria
# @RaoufMazou and @UNHCRGreece
# absolute pure dogshite
# UN Refugee Agency
# the UN convention
# w/Asst High Commissioners
# Little Ringed Plovers
# the immigrants card
# the Greece event
# top of that
# a distant memory
# devastating consequences
# friday motivation
# The situation
# white westerners
# Don' t
# great hospitality
# Giannis story
# Bertelsmann study
# Priti Patel
# its obvious
# Muslim factions
# my fieldwork
# migration fluxes
# you officials
# Lesbos latest
# your workplaces
# a flashpoint
# ready dumbfuck
# the spread
# Didn '
# The Bessudos
# this burden
# Polish Jews
# the government
#
#
#  checking government_government
# The transfer
# a scoop
# Raquel Bessudo
# bird photography
# terrorist propaganda
# some brain
# olive branches
# a crime
# an excuse
# 59 turks
# severe claustrophobia
# our culture
# @tr724 araclyla
# their Fathers
# the start
# Dear sir
# the US
# europeans latinos
# Refugee Covid
# NO BORDERS
# t discriminate
# a tent
# the entrance
# the U.K.
# pro-government opinion
# a definition
# My names
# their visit
# gas Exploration
# awful thogh
# bombs Iraq
# its arms
# the call
# the same
# More evidence
# raw realism
# a necessity
# deadly attacks
# whos existence
# Mr Stoltenberg
# my data
# The impossible
# an email
# URGENT FUNDS
# this effort
# nothing &
# your help
# Greek SMEs
# SAFE France
# Refugee Camps
# Refugee Covid
# 2018
# He
# Anarchy
# Nobody
# access
# Illyrians
# @MSF
# negotiations
# HAHAHA
# Details
# Siktir
# refugeeovercrowding
# flow
# aesthetic
# ManfredWeber
# Leeds
# 1914
# HU
# 1/3
# @scwacy
# comparisons
# IRC
# COVID-19
# EIT
# Donations
# safety
# No-one
# connector
# GdnDevelopment
# G
# today
# Asylum
# Questions
# mercenaries
# documents
# Matt
# Wed
# Ill
# God
# Here
# covid
# unemployment
# /
# we
# Omfg
# COVID-19
# Doctors
# 10000
# @CERCmigration
# return
# Spring
# 10,000
# Borders/MSF
# moria
# parents/carers
# SOS
# Ubtil
# lesvos
# 2040
# @akrokentrwos
# charge
# islands
# Wales
# attention!!!!
# 2040
# danger
# lesbos
# History
# Obama
# soufli
# flood
# WE
# riots!
# who
# MSM
# 2040
# Greece

# %%
print(cand_frames.keys())

framed_words = pd.DataFrame.from_dict(cand_frames)

framed_words[framed_words['word']=='refugees'].tail(50)
# Out:
# dict_keys(['word', 'settlement', 'reception', 'security', 'criminality', 'economisation', 'humanitarian', 'victimization', 'integration'])
#           word settlement  reception  security  criminality  economisation  \
# 436   refugees       None        NaN       NaN          NaN            NaN
# 446   refugees       None        NaN       NaN          NaN            NaN
# 478   refugees       None        NaN       NaN     0.488541            NaN
# 479   refugees       None        NaN       NaN          NaN            NaN
# 485   refugees       None        NaN       NaN     0.488541            NaN
# 486   refugees       None        NaN       NaN          NaN            NaN
# 538   refugees       None        NaN       NaN          NaN            NaN
# 548   refugees       None        NaN       NaN          NaN            NaN
# 589   refugees       None        NaN       NaN          NaN            NaN
# 596   refugees       None        NaN       NaN          NaN            NaN
# 619   refugees       None        NaN       NaN          NaN            NaN
# 628   refugees       None        NaN       NaN          NaN            NaN
# 642   refugees       None        NaN       NaN          NaN            NaN
# 647   refugees       None        NaN       NaN          NaN            NaN
# 725   refugees       None        NaN       NaN          NaN            NaN
# 730   refugees       None        NaN       NaN          NaN            NaN
# 799   refugees       None        NaN       NaN          NaN            NaN
# 811   refugees       None        NaN       NaN          NaN            NaN
# 831   refugees       None        NaN       NaN          NaN            NaN
# 836   refugees       None        NaN       NaN          NaN            NaN
# 850   refugees       None        NaN       NaN          NaN            NaN
# 854   refugees       None        NaN       NaN          NaN            NaN
# 912   refugees       None        NaN       NaN          NaN            NaN
# 918   refugees       None        NaN       NaN          NaN            NaN
# 927   refugees       None        NaN       NaN          NaN            NaN
# 932   refugees       None        NaN       NaN          NaN            NaN
# 994   refugees       None        NaN       NaN          NaN            NaN
# 995   refugees       None        NaN       NaN          NaN            NaN
# 1000  refugees       None        NaN       NaN          NaN            NaN
# 1001  refugees       None        NaN       NaN          NaN            NaN
# 1009  refugees       None        NaN       NaN          NaN            NaN
# 1016  refugees       None        NaN       NaN          NaN            NaN
# 1022  refugees       None        NaN       NaN          NaN            NaN
# 1026  refugees       None        NaN       NaN          NaN            NaN
# 1080  refugees       None        NaN       NaN          NaN            NaN
# 1086  refugees       None        NaN       NaN          NaN            NaN
# 1094  refugees       None        NaN       NaN          NaN            NaN
# 1104  refugees       None        NaN       NaN          NaN            NaN
# 1195  refugees       None        NaN       NaN          NaN            NaN
# 1206  refugees       None        NaN       NaN          NaN            NaN
# 1235  refugees       None        NaN       NaN          NaN            NaN
# 1246  refugees       None        NaN       NaN          NaN            NaN
# 1256  refugees       None        NaN       NaN          NaN            NaN
# 1262  refugees       None        NaN       NaN          NaN            NaN
# 1466  refugees       None        NaN       NaN          NaN            NaN
# 1480  refugees       None        NaN       NaN          NaN            NaN
# 1603  refugees       None        NaN       NaN          NaN            NaN
# 1608  refugees       None        NaN       NaN          NaN            NaN
# 1626  refugees       None        NaN       NaN          NaN            NaN
# 1627  refugees       None        NaN       NaN          NaN            NaN
#
#       humanitarian  victimization integration
# 436            NaN            NaN        None
# 446            NaN            NaN        None
# 478            NaN       0.450321        None
# 479            NaN            NaN        None
# 485            NaN       0.450321        None
# 486            NaN            NaN        None
# 538            NaN            NaN        None
# 548            NaN            NaN        None
# 589            NaN            NaN        None
# 596            NaN            NaN        None
# 619            NaN            NaN        None
# 628            NaN            NaN        None
# 642            NaN            NaN        None
# 647            NaN            NaN        None
# 725            NaN            NaN        None
# 730            NaN            NaN        None
# 799            NaN            NaN        None
# 811            NaN            NaN        None
# 831            NaN            NaN        None
# 836            NaN            NaN        None
# 850            NaN            NaN        None
# 854            NaN            NaN        None
# 912            NaN            NaN        None
# 918            NaN            NaN        None
# 927            NaN            NaN        None
# 932            NaN            NaN        None
# 994            NaN            NaN        None
# 995            NaN            NaN        None
# 1000           NaN            NaN        None
# 1001           NaN            NaN        None
# 1009           NaN            NaN        None
# 1016           NaN            NaN        None
# 1022           NaN            NaN        None
# 1026           NaN            NaN        None
# 1080           NaN            NaN        None
# 1086           NaN            NaN        None
# 1094           NaN            NaN        None
# 1104           NaN            NaN        None
# 1195           NaN            NaN        None
# 1206           NaN            NaN        None
# 1235           NaN            NaN        None
# 1246           NaN            NaN        None
# 1256           NaN            NaN        None
# 1262           NaN            NaN        None
# 1466           NaN            NaN        None
# 1480           NaN            NaN        None
# 1603           NaN            NaN        None
# 1608           NaN            NaN        None
# 1626           NaN       0.458006        None
# 1627           NaN       0.458006        None

# %%
#print(cand_df['candidates'])
for candidate in tqdm(tweets_corpus):
    for frame in list(frame_properties.keys()):      
        print(f'communication bias towards {candidate.split()[1]} in the frame {frame}  is {np.mean(cand_frames[frame][candidate.split()[1]])}')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 632.92it/s]
# communication bias towards Moria in the frame settlement  is nan
# communication bias towards Moria in the frame reception  is nan
# communication bias towards Moria in the frame security  is nan
# communication bias towards Moria in the frame criminality  is nan
# communication bias towards Moria in the frame economisation  is nan
# communication bias towards Moria in the frame humanitarian  is nan
# communication bias towards Moria in the frame victimization  is nan
# communication bias towards Moria in the frame integration  is nan
# communication bias towards covid in the frame settlement  is 0.14751476049423218
# communication bias towards covid in the frame reception  is 0.049112480133771896
# communication bias towards covid in the frame security  is 0.12066757678985596
# communication bias towards covid in the frame criminality  is nan
# communication bias towards covid in the frame economisation  is nan
# communication bias towards covid in the frame humanitarian  is nan
# communication bias towards covid in the frame victimization  is nan
# communication bias towards covid in the frame integration  is 0.05935339257121086
# communication bias towards overcrowded in the frame settlement  is nan
# communication bias towards overcrowded in the frame reception  is nan
# communication bias towards overcrowded in the frame security  is nan
# communication bias towards overcrowded in the frame criminality  is nan
# communication bias towards overcrowded in the frame economisation  is nan
# communication bias towards overcrowded in the frame humanitarian  is nan
# communication bias towards overcrowded in the frame victimization  is nan
# communication bias towards overcrowded in the frame integration  is nan
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards art! in the frame settlement  is nan
# communication bias towards art! in the frame reception  is nan
# communication bias towards art! in the frame security  is nan
# communication bias towards art! in the frame criminality  is nan
# communication bias towards art! in the frame economisation  is nan
# communication bias towards art! in the frame humanitarian  is nan
# communication bias towards art! in the frame victimization  is nan
# communication bias towards art! in the frame integration  is nan
# communication bias towards they in the frame settlement  is nan
# communication bias towards they in the frame reception  is nan
# communication bias towards they in the frame security  is nan
# communication bias towards they in the frame criminality  is nan
# communication bias towards they in the frame economisation  is nan
# communication bias towards they in the frame humanitarian  is nan
# communication bias towards they in the frame victimization  is nan
# communication bias towards they in the frame integration  is nan
# communication bias towards have in the frame settlement  is 0.07397420704364777
# communication bias towards have in the frame reception  is 0.034676287323236465
# communication bias towards have in the frame security  is 0.10511930286884308
# communication bias towards have in the frame criminality  is nan
# communication bias towards have in the frame economisation  is nan
# communication bias towards have in the frame humanitarian  is nan
# communication bias towards have in the frame victimization  is nan
# communication bias towards have in the frame integration  is 0.07595645636320114
# communication bias towards First in the frame settlement  is nan
# communication bias towards First in the frame reception  is nan
# communication bias towards First in the frame security  is nan
# communication bias towards First in the frame criminality  is nan
# communication bias towards First in the frame economisation  is nan
# communication bias towards First in the frame humanitarian  is nan
# communication bias towards First in the frame victimization  is nan
# communication bias towards First in the frame integration  is nan
# communication bias towards - in the frame settlement  is nan
# communication bias towards - in the frame reception  is nan
# communication bias towards - in the frame security  is nan
# communication bias towards - in the frame criminality  is nan
# communication bias towards - in the frame economisation  is nan
# communication bias towards - in the frame humanitarian  is nan
# communication bias towards - in the frame victimization  is nan
# communication bias towards - in the frame integration  is nan
# communication bias towards is in the frame settlement  is nan
# communication bias towards is in the frame reception  is nan
# communication bias towards is in the frame security  is nan
# communication bias towards is in the frame criminality  is nan
# communication bias towards is in the frame economisation  is nan
# communication bias towards is in the frame humanitarian  is nan
# communication bias towards is in the frame victimization  is nan
# communication bias towards is in the frame integration  is nan
# communication bias towards not in the frame settlement  is nan
# communication bias towards not in the frame reception  is nan
# communication bias towards not in the frame security  is nan
# communication bias towards not in the frame criminality  is nan
# communication bias towards not in the frame economisation  is nan
# communication bias towards not in the frame humanitarian  is nan
# communication bias towards not in the frame victimization  is nan
# communication bias towards not in the frame integration  is nan
# communication bias towards not in the frame settlement  is nan
# communication bias towards not in the frame reception  is nan
# communication bias towards not in the frame security  is nan
# communication bias towards not in the frame criminality  is nan
# communication bias towards not in the frame economisation  is nan
# communication bias towards not in the frame humanitarian  is nan
# communication bias towards not in the frame victimization  is nan
# communication bias towards not in the frame integration  is nan
# communication bias towards overcrowded in the frame settlement  is nan
# communication bias towards overcrowded in the frame reception  is nan
# communication bias towards overcrowded in the frame security  is nan
# communication bias towards overcrowded in the frame criminality  is nan
# communication bias towards overcrowded in the frame economisation  is nan
# communication bias towards overcrowded in the frame humanitarian  is nan
# communication bias towards overcrowded in the frame victimization  is nan
# communication bias towards overcrowded in the frame integration  is nan
# communication bias towards for in the frame settlement  is nan
# communication bias towards for in the frame reception  is nan
# communication bias towards for in the frame security  is nan
# communication bias towards for in the frame criminality  is nan
# communication bias towards for in the frame economisation  is nan
# communication bias towards for in the frame humanitarian  is nan
# communication bias towards for in the frame victimization  is nan
# communication bias towards for in the frame integration  is nan
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards distancing in the frame settlement  is nan
# communication bias towards distancing in the frame reception  is nan
# communication bias towards distancing in the frame security  is nan
# communication bias towards distancing in the frame criminality  is nan
# communication bias towards distancing in the frame economisation  is nan
# communication bias towards distancing in the frame humanitarian  is nan
# communication bias towards distancing in the frame victimization  is nan
# communication bias towards distancing in the frame integration  is nan
# communication bias towards and in the frame settlement  is 0.06575877964496613
# communication bias towards and in the frame reception  is 0.04645365849137306
# communication bias towards and in the frame security  is 0.0953652560710907
# communication bias towards and in the frame criminality  is nan
# communication bias towards and in the frame economisation  is nan
# communication bias towards and in the frame humanitarian  is nan
# communication bias towards and in the frame victimization  is nan
# communication bias towards and in the frame integration  is 0.06482560187578201
# communication bias towards there in the frame settlement  is nan
# communication bias towards there in the frame reception  is nan
# communication bias towards there in the frame security  is nan
# communication bias towards there in the frame criminality  is nan
# communication bias towards there in the frame economisation  is nan
# communication bias towards there in the frame humanitarian  is nan
# communication bias towards there in the frame victimization  is nan
# communication bias towards there in the frame integration  is nan
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards nine in the frame settlement  is nan
# communication bias towards nine in the frame reception  is nan
# communication bias towards nine in the frame security  is nan
# communication bias towards nine in the frame criminality  is nan
# communication bias towards nine in the frame economisation  is nan
# communication bias towards nine in the frame humanitarian  is nan
# communication bias towards nine in the frame victimization  is nan
# communication bias towards nine in the frame integration  is nan
# communication bias towards Greece in the frame settlement  is 0.0794055163860321
# communication bias towards Greece in the frame reception  is 0.06073588505387306
# communication bias towards Greece in the frame security  is 0.09139971435070038
# communication bias towards Greece in the frame criminality  is nan
# communication bias towards Greece in the frame economisation  is nan
# communication bias towards Greece in the frame humanitarian  is nan
# communication bias towards Greece in the frame victimization  is nan
# communication bias towards Greece in the frame integration  is 0.06776897609233856
# communication bias towards weren' in the frame settlement  is nan
# communication bias towards weren' in the frame reception  is nan
# communication bias towards weren' in the frame security  is nan
# communication bias towards weren' in the frame criminality  is nan
# communication bias towards weren' in the frame economisation  is nan
# communication bias towards weren' in the frame humanitarian  is nan
# communication bias towards weren' in the frame victimization  is nan
# communication bias towards weren' in the frame integration  is nan
# communication bias towards 500 in the frame settlement  is nan
# communication bias towards 500 in the frame reception  is nan
# communication bias towards 500 in the frame security  is nan
# communication bias towards 500 in the frame criminality  is nan
# communication bias towards 500 in the frame economisation  is nan
# communication bias towards 500 in the frame humanitarian  is nan
# communication bias towards 500 in the frame victimization  is nan
# communication bias towards 500 in the frame integration  is nan
# communication bias towards so in the frame settlement  is nan
# communication bias towards so in the frame reception  is nan
# communication bias towards so in the frame security  is nan
# communication bias towards so in the frame criminality  is nan
# communication bias towards so in the frame economisation  is nan
# communication bias towards so in the frame humanitarian  is nan
# communication bias towards so in the frame victimization  is nan
# communication bias towards so in the frame integration  is nan
# communication bias towards can in the frame settlement  is nan
# communication bias towards can in the frame reception  is nan
# communication bias towards can in the frame security  is nan
# communication bias towards can in the frame criminality  is nan
# communication bias towards can in the frame economisation  is nan
# communication bias towards can in the frame humanitarian  is nan
# communication bias towards can in the frame victimization  is nan
# communication bias towards can in the frame integration  is nan
# communication bias towards Is in the frame settlement  is nan
# communication bias towards Is in the frame reception  is nan
# communication bias towards Is in the frame security  is nan
# communication bias towards Is in the frame criminality  is nan
# communication bias towards Is in the frame economisation  is nan
# communication bias towards Is in the frame humanitarian  is nan
# communication bias towards Is in the frame victimization  is nan
# communication bias towards Is in the frame integration  is nan
# communication bias towards urges in the frame settlement  is nan
# communication bias towards urges in the frame reception  is nan
# communication bias towards urges in the frame security  is nan
# communication bias towards urges in the frame criminality  is nan
# communication bias towards urges in the frame economisation  is nan
# communication bias towards urges in the frame humanitarian  is nan
# communication bias towards urges in the frame victimization  is nan
# communication bias towards urges in the frame integration  is nan
# communication bias towards s in the frame settlement  is 0.05049204081296921
# communication bias towards s in the frame reception  is 0.0628584772348404
# communication bias towards s in the frame security  is 0.054590702056884766
# communication bias towards s in the frame criminality  is nan
# communication bias towards s in the frame economisation  is nan
# communication bias towards s in the frame humanitarian  is nan
# communication bias towards s in the frame victimization  is nan
# communication bias towards s in the frame integration  is 0.034712858498096466
# communication bias towards reporters in the frame settlement  is nan
# communication bias towards reporters in the frame reception  is nan
# communication bias towards reporters in the frame security  is nan
# communication bias towards reporters in the frame criminality  is nan
# communication bias towards reporters in the frame economisation  is nan
# communication bias towards reporters in the frame humanitarian  is nan
# communication bias towards reporters in the frame victimization  is nan
# communication bias towards reporters in the frame integration  is nan
# communication bias towards in in the frame settlement  is nan
# communication bias towards in in the frame reception  is nan
# communication bias towards in in the frame security  is nan
# communication bias towards in in the frame criminality  is nan
# communication bias towards in in the frame economisation  is nan
# communication bias towards in in the frame humanitarian  is nan
# communication bias towards in in the frame victimization  is nan
# communication bias towards in in the frame integration  is nan
# communication bias towards this in the frame settlement  is nan
# communication bias towards this in the frame reception  is nan
# communication bias towards this in the frame security  is nan
# communication bias towards this in the frame criminality  is nan
# communication bias towards this in the frame economisation  is nan
# communication bias towards this in the frame humanitarian  is nan
# communication bias towards this in the frame victimization  is nan
# communication bias towards this in the frame integration  is nan
# communication bias towards with in the frame settlement  is nan
# communication bias towards with in the frame reception  is nan
# communication bias towards with in the frame security  is nan
# communication bias towards with in the frame criminality  is nan
# communication bias towards with in the frame economisation  is nan
# communication bias towards with in the frame humanitarian  is nan
# communication bias towards with in the frame victimization  is nan
# communication bias towards with in the frame integration  is nan
# communication bias towards / in the frame settlement  is 0.09531041234731674
# communication bias towards / in the frame reception  is 0.016196755692362785
# communication bias towards / in the frame security  is 0.06486573070287704
# communication bias towards / in the frame criminality  is nan
# communication bias towards / in the frame economisation  is nan
# communication bias towards / in the frame humanitarian  is nan
# communication bias towards / in the frame victimization  is nan
# communication bias towards / in the frame integration  is -0.007674798369407654
# communication bias towards most in the frame settlement  is nan
# communication bias towards most in the frame reception  is nan
# communication bias towards most in the frame security  is nan
# communication bias towards most in the frame criminality  is nan
# communication bias towards most in the frame economisation  is nan
# communication bias towards most in the frame humanitarian  is nan
# communication bias towards most in the frame victimization  is nan
# communication bias towards most in the frame integration  is nan
# communication bias towards hope in the frame settlement  is 0.09748245030641556
# communication bias towards hope in the frame reception  is 0.10289794206619263
# communication bias towards hope in the frame security  is 0.09817317873239517
# communication bias towards hope in the frame criminality  is nan
# communication bias towards hope in the frame economisation  is nan
# communication bias towards hope in the frame humanitarian  is nan
# communication bias towards hope in the frame victimization  is nan
# communication bias towards hope in the frame integration  is 0.08326320350170135
# communication bias towards convenient in the frame settlement  is nan
# communication bias towards convenient in the frame reception  is nan
# communication bias towards convenient in the frame security  is nan
# communication bias towards convenient in the frame criminality  is nan
# communication bias towards convenient in the frame economisation  is nan
# communication bias towards convenient in the frame humanitarian  is nan
# communication bias towards convenient in the frame victimization  is nan
# communication bias towards convenient in the frame integration  is nan
# communication bias towards do in the frame settlement  is 0.043382398784160614
# communication bias towards do in the frame reception  is 0.06754586100578308
# communication bias towards do in the frame security  is 0.06726808100938797
# communication bias towards do in the frame criminality  is nan
# communication bias towards do in the frame economisation  is nan
# communication bias towards do in the frame humanitarian  is nan
# communication bias towards do in the frame victimization  is nan
# communication bias towards do in the frame integration  is 0.04135347902774811
# communication bias towards island in the frame settlement  is 0.07425373047590256
# communication bias towards island in the frame reception  is 0.053230926394462585
# communication bias towards island in the frame security  is 0.08861897140741348
# communication bias towards island in the frame criminality  is nan
# communication bias towards island in the frame economisation  is nan
# communication bias towards island in the frame humanitarian  is nan
# communication bias towards island in the frame victimization  is nan
# communication bias towards island in the frame integration  is 0.0612906813621521
# communication bias towards camp in the frame settlement  is 0.09135812520980835
# communication bias towards camp in the frame reception  is 0.04558759182691574
# communication bias towards camp in the frame security  is 0.11882442235946655
# communication bias towards camp in the frame criminality  is nan
# communication bias towards camp in the frame economisation  is nan
# communication bias towards camp in the frame humanitarian  is nan
# communication bias towards camp in the frame victimization  is nan
# communication bias towards camp in the frame integration  is 0.052749425172805786
# communication bias towards of in the frame settlement  is nan
# communication bias towards of in the frame reception  is nan
# communication bias towards of in the frame security  is nan
# communication bias towards of in the frame criminality  is nan
# communication bias towards of in the frame economisation  is nan
# communication bias towards of in the frame humanitarian  is nan
# communication bias towards of in the frame victimization  is nan
# communication bias towards of in the frame integration  is nan
# communication bias towards wouldn' in the frame settlement  is nan
# communication bias towards wouldn' in the frame reception  is nan
# communication bias towards wouldn' in the frame security  is nan
# communication bias towards wouldn' in the frame criminality  is nan
# communication bias towards wouldn' in the frame economisation  is nan
# communication bias towards wouldn' in the frame humanitarian  is nan
# communication bias towards wouldn' in the frame victimization  is nan
# communication bias towards wouldn' in the frame integration  is nan
# communication bias towards happens in the frame settlement  is nan
# communication bias towards happens in the frame reception  is nan
# communication bias towards happens in the frame security  is nan
# communication bias towards happens in the frame criminality  is nan
# communication bias towards happens in the frame economisation  is nan
# communication bias towards happens in the frame humanitarian  is nan
# communication bias towards happens in the frame victimization  is nan
# communication bias towards happens in the frame integration  is nan
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards reason in the frame settlement  is nan
# communication bias towards reason in the frame reception  is nan
# communication bias towards reason in the frame security  is nan
# communication bias towards reason in the frame criminality  is nan
# communication bias towards reason in the frame economisation  is nan
# communication bias towards reason in the frame humanitarian  is nan
# communication bias towards reason in the frame victimization  is nan
# communication bias towards reason in the frame integration  is nan
# communication bias towards we in the frame settlement  is nan
# communication bias towards we in the frame reception  is nan
# communication bias towards we in the frame security  is nan
# communication bias towards we in the frame criminality  is nan
# communication bias towards we in the frame economisation  is nan
# communication bias towards we in the frame humanitarian  is nan
# communication bias towards we in the frame victimization  is nan
# communication bias towards we in the frame integration  is nan
# communication bias towards seeking in the frame settlement  is nan
# communication bias towards seeking in the frame reception  is nan
# communication bias towards seeking in the frame security  is nan
# communication bias towards seeking in the frame criminality  is nan
# communication bias towards seeking in the frame economisation  is nan
# communication bias towards seeking in the frame humanitarian  is nan
# communication bias towards seeking in the frame victimization  is nan
# communication bias towards seeking in the frame integration  is nan
# communication bias towards forgot in the frame settlement  is nan
# communication bias towards forgot in the frame reception  is nan
# communication bias towards forgot in the frame security  is nan
# communication bias towards forgot in the frame criminality  is nan
# communication bias towards forgot in the frame economisation  is nan
# communication bias towards forgot in the frame humanitarian  is nan
# communication bias towards forgot in the frame victimization  is nan
# communication bias towards forgot in the frame integration  is nan
# communication bias towards Without in the frame settlement  is nan
# communication bias towards Without in the frame reception  is nan
# communication bias towards Without in the frame security  is nan
# communication bias towards Without in the frame criminality  is nan
# communication bias towards Without in the frame economisation  is nan
# communication bias towards Without in the frame humanitarian  is nan
# communication bias towards Without in the frame victimization  is nan
# communication bias towards Without in the frame integration  is nan
# communication bias towards have in the frame settlement  is 0.07397420704364777
# communication bias towards have in the frame reception  is 0.034676287323236465
# communication bias towards have in the frame security  is 0.10511930286884308
# communication bias towards have in the frame criminality  is nan
# communication bias towards have in the frame economisation  is nan
# communication bias towards have in the frame humanitarian  is nan
# communication bias towards have in the frame victimization  is nan
# communication bias towards have in the frame integration  is 0.07595645636320114
# communication bias towards SPAIN in the frame settlement  is nan
# communication bias towards SPAIN in the frame reception  is nan
# communication bias towards SPAIN in the frame security  is nan
# communication bias towards SPAIN in the frame criminality  is nan
# communication bias towards SPAIN in the frame economisation  is nan
# communication bias towards SPAIN in the frame humanitarian  is nan
# communication bias towards SPAIN in the frame victimization  is nan
# communication bias towards SPAIN in the frame integration  is nan
# communication bias towards dictator in the frame settlement  is nan
# communication bias towards dictator in the frame reception  is nan
# communication bias towards dictator in the frame security  is nan
# communication bias towards dictator in the frame criminality  is nan
# communication bias towards dictator in the frame economisation  is nan
# communication bias towards dictator in the frame humanitarian  is nan
# communication bias towards dictator in the frame victimization  is nan
# communication bias towards dictator in the frame integration  is nan
# communication bias towards throws in the frame settlement  is nan
# communication bias towards throws in the frame reception  is nan
# communication bias towards throws in the frame security  is nan
# communication bias towards throws in the frame criminality  is nan
# communication bias towards throws in the frame economisation  is nan
# communication bias towards throws in the frame humanitarian  is nan
# communication bias towards throws in the frame victimization  is nan
# communication bias towards throws in the frame integration  is nan
# communication bias towards s in the frame settlement  is 0.05049204081296921
# communication bias towards s in the frame reception  is 0.0628584772348404
# communication bias towards s in the frame security  is 0.054590702056884766
# communication bias towards s in the frame criminality  is nan
# communication bias towards s in the frame economisation  is nan
# communication bias towards s in the frame humanitarian  is nan
# communication bias towards s in the frame victimization  is nan
# communication bias towards s in the frame integration  is 0.034712858498096466
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards is in the frame settlement  is nan
# communication bias towards is in the frame reception  is nan
# communication bias towards is in the frame security  is nan
# communication bias towards is in the frame criminality  is nan
# communication bias towards is in the frame economisation  is nan
# communication bias towards is in the frame humanitarian  is nan
# communication bias towards is in the frame victimization  is nan
# communication bias towards is in the frame integration  is nan
# communication bias towards am in the frame settlement  is nan
# communication bias towards am in the frame reception  is nan
# communication bias towards am in the frame security  is nan
# communication bias towards am in the frame criminality  is nan
# communication bias towards am in the frame economisation  is nan
# communication bias towards am in the frame humanitarian  is nan
# communication bias towards am in the frame victimization  is nan
# communication bias towards am in the frame integration  is nan
# communication bias towards are in the frame settlement  is nan
# communication bias towards are in the frame reception  is nan
# communication bias towards are in the frame security  is nan
# communication bias towards are in the frame criminality  is nan
# communication bias towards are in the frame economisation  is nan
# communication bias towards are in the frame humanitarian  is nan
# communication bias towards are in the frame victimization  is nan
# communication bias towards are in the frame integration  is nan
# communication bias towards to in the frame settlement  is nan
# communication bias towards to in the frame reception  is nan
# communication bias towards to in the frame security  is nan
# communication bias towards to in the frame criminality  is nan
# communication bias towards to in the frame economisation  is nan
# communication bias towards to in the frame humanitarian  is nan
# communication bias towards to in the frame victimization  is nan
# communication bias towards to in the frame integration  is nan
# communication bias towards . in the frame settlement  is 0.06154055893421173
# communication bias towards . in the frame reception  is 0.04512004181742668
# communication bias towards . in the frame security  is 0.08667024970054626
# communication bias towards . in the frame criminality  is nan
# communication bias towards . in the frame economisation  is nan
# communication bias towards . in the frame humanitarian  is nan
# communication bias towards . in the frame victimization  is nan
# communication bias towards . in the frame integration  is 0.043273065239191055
# communication bias towards First in the frame settlement  is nan
# communication bias towards First in the frame reception  is nan
# communication bias towards First in the frame security  is nan
# communication bias towards First in the frame criminality  is nan
# communication bias towards First in the frame economisation  is nan
# communication bias towards First in the frame humanitarian  is nan
# communication bias towards First in the frame victimization  is nan
# communication bias towards First in the frame integration  is nan
# communication bias towards it in the frame settlement  is 0.07048776745796204
# communication bias towards it in the frame reception  is 0.06211468204855919
# communication bias towards it in the frame security  is 0.10510031878948212
# communication bias towards it in the frame criminality  is nan
# communication bias towards it in the frame economisation  is nan
# communication bias towards it in the frame humanitarian  is nan
# communication bias towards it in the frame victimization  is nan
# communication bias towards it in the frame integration  is 0.05162123218178749
# communication bias towards ancestors in the frame settlement  is nan
# communication bias towards ancestors in the frame reception  is nan
# communication bias towards ancestors in the frame security  is nan
# communication bias towards ancestors in the frame criminality  is nan
# communication bias towards ancestors in the frame economisation  is nan
# communication bias towards ancestors in the frame humanitarian  is nan
# communication bias towards ancestors in the frame victimization  is nan
# communication bias towards ancestors in the frame integration  is nan
# communication bias towards anchestors in the frame settlement  is nan
# communication bias towards anchestors in the frame reception  is nan
# communication bias towards anchestors in the frame security  is nan
# communication bias towards anchestors in the frame criminality  is nan
# communication bias towards anchestors in the frame economisation  is nan
# communication bias towards anchestors in the frame humanitarian  is nan
# communication bias towards anchestors in the frame victimization  is nan
# communication bias towards anchestors in the frame integration  is nan
# communication bias towards Finnish in the frame settlement  is nan
# communication bias towards Finnish in the frame reception  is nan
# communication bias towards Finnish in the frame security  is nan
# communication bias towards Finnish in the frame criminality  is nan
# communication bias towards Finnish in the frame economisation  is nan
# communication bias towards Finnish in the frame humanitarian  is nan
# communication bias towards Finnish in the frame victimization  is nan
# communication bias towards Finnish in the frame integration  is nan
# communication bias towards first in the frame settlement  is nan
# communication bias towards first in the frame reception  is nan
# communication bias towards first in the frame security  is nan
# communication bias towards first in the frame criminality  is nan
# communication bias towards first in the frame economisation  is nan
# communication bias towards first in the frame humanitarian  is nan
# communication bias towards first in the frame victimization  is nan
# communication bias towards first in the frame integration  is nan
# communication bias towards . in the frame settlement  is 0.06154055893421173
# communication bias towards . in the frame reception  is 0.04512004181742668
# communication bias towards . in the frame security  is 0.08667024970054626
# communication bias towards . in the frame criminality  is nan
# communication bias towards . in the frame economisation  is nan
# communication bias towards . in the frame humanitarian  is nan
# communication bias towards . in the frame victimization  is nan
# communication bias towards . in the frame integration  is 0.043273065239191055
# communication bias towards overcrowded in the frame settlement  is nan
# communication bias towards overcrowded in the frame reception  is nan
# communication bias towards overcrowded in the frame security  is nan
# communication bias towards overcrowded in the frame criminality  is nan
# communication bias towards overcrowded in the frame economisation  is nan
# communication bias towards overcrowded in the frame humanitarian  is nan
# communication bias towards overcrowded in the frame victimization  is nan
# communication bias towards overcrowded in the frame integration  is nan
# communication bias towards am in the frame settlement  is nan
# communication bias towards am in the frame reception  is nan
# communication bias towards am in the frame security  is nan
# communication bias towards am in the frame criminality  is nan
# communication bias towards am in the frame economisation  is nan
# communication bias towards am in the frame humanitarian  is nan
# communication bias towards am in the frame victimization  is nan
# communication bias towards am in the frame integration  is nan
# communication bias towards worst in the frame settlement  is nan
# communication bias towards worst in the frame reception  is nan
# communication bias towards worst in the frame security  is nan
# communication bias towards worst in the frame criminality  is nan
# communication bias towards worst in the frame economisation  is nan
# communication bias towards worst in the frame humanitarian  is nan
# communication bias towards worst in the frame victimization  is nan
# communication bias towards worst in the frame integration  is nan
# communication bias towards when in the frame settlement  is nan
# communication bias towards when in the frame reception  is nan
# communication bias towards when in the frame security  is nan
# communication bias towards when in the frame criminality  is nan
# communication bias towards when in the frame economisation  is nan
# communication bias towards when in the frame humanitarian  is nan
# communication bias towards when in the frame victimization  is nan
# communication bias towards when in the frame integration  is nan
# communication bias towards sea in the frame settlement  is 0.04691508039832115
# communication bias towards sea in the frame reception  is 0.11714433878660202
# communication bias towards sea in the frame security  is 0.07266245037317276
# communication bias towards sea in the frame criminality  is nan
# communication bias towards sea in the frame economisation  is nan
# communication bias towards sea in the frame humanitarian  is nan
# communication bias towards sea in the frame victimization  is nan
# communication bias towards sea in the frame integration  is 0.07013874500989914
# communication bias towards the in the frame settlement  is 0.07567689567804337
# communication bias towards the in the frame reception  is 0.06256013363599777
# communication bias towards the in the frame security  is 0.09304524213075638
# communication bias towards the in the frame criminality  is nan
# communication bias towards the in the frame economisation  is nan
# communication bias towards the in the frame humanitarian  is nan
# communication bias towards the in the frame victimization  is nan
# communication bias towards the in the frame integration  is 0.06043316051363945
# communication bias towards has in the frame settlement  is nan
# communication bias towards has in the frame reception  is nan
# communication bias towards has in the frame security  is nan
# communication bias towards has in the frame criminality  is nan
# communication bias towards has in the frame economisation  is nan
# communication bias towards has in the frame humanitarian  is nan
# communication bias towards has in the frame victimization  is nan
# communication bias towards has in the frame integration  is nan
# communication bias towards many? in the frame settlement  is nan
# communication bias towards many? in the frame reception  is nan
# communication bias towards many? in the frame security  is nan
# communication bias towards many? in the frame criminality  is nan
# communication bias towards many? in the frame economisation  is nan
# communication bias towards many? in the frame humanitarian  is nan
# communication bias towards many? in the frame victimization  is nan
# communication bias towards many? in the frame integration  is nan
# communication bias towards was in the frame settlement  is nan
# communication bias towards was in the frame reception  is nan
# communication bias towards was in the frame security  is nan
# communication bias towards was in the frame criminality  is nan
# communication bias towards was in the frame economisation  is nan
# communication bias towards was in the frame humanitarian  is nan
# communication bias towards was in the frame victimization  is nan
# communication bias towards was in the frame integration  is nan
# communication bias towards are in the frame settlement  is nan
# communication bias towards are in the frame reception  is nan
# communication bias towards are in the frame security  is nan
# communication bias towards are in the frame criminality  is nan
# communication bias towards are in the frame economisation  is nan
# communication bias towards are in the frame humanitarian  is nan
# communication bias towards are in the frame victimization  is nan
# communication bias towards are in the frame integration  is nan
# communication bias towards can in the frame settlement  is nan
# communication bias towards can in the frame reception  is nan
# communication bias towards can in the frame security  is nan
# communication bias towards can in the frame criminality  is nan
# communication bias towards can in the frame economisation  is nan
# communication bias towards can in the frame humanitarian  is nan
# communication bias towards can in the frame victimization  is nan
# communication bias towards can in the frame integration  is nan
# communication bias towards re in the frame settlement  is 0.026861902326345444
# communication bias towards re in the frame reception  is -0.005633445456624031
# communication bias towards re in the frame security  is 0.012167979031801224
# communication bias towards re in the frame criminality  is nan
# communication bias towards re in the frame economisation  is nan
# communication bias towards re in the frame humanitarian  is nan
# communication bias towards re in the frame victimization  is nan
# communication bias towards re in the frame integration  is 0.008754216134548187
# communication bias towards expects in the frame settlement  is nan
# communication bias towards expects in the frame reception  is nan
# communication bias towards expects in the frame security  is nan
# communication bias towards expects in the frame criminality  is nan
# communication bias towards expects in the frame economisation  is nan
# communication bias towards expects in the frame humanitarian  is nan
# communication bias towards expects in the frame victimization  is nan
# communication bias towards expects in the frame integration  is nan
# communication bias towards occurrence in the frame settlement  is nan
# communication bias towards occurrence in the frame reception  is nan
# communication bias towards occurrence in the frame security  is nan
# communication bias towards occurrence in the frame criminality  is nan
# communication bias towards occurrence in the frame economisation  is nan
# communication bias towards occurrence in the frame humanitarian  is nan
# communication bias towards occurrence in the frame victimization  is nan
# communication bias towards occurrence in the frame integration  is nan
# communication bias towards s in the frame settlement  is 0.05049204081296921
# communication bias towards s in the frame reception  is 0.0628584772348404
# communication bias towards s in the frame security  is 0.054590702056884766
# communication bias towards s in the frame criminality  is nan
# communication bias towards s in the frame economisation  is nan
# communication bias towards s in the frame humanitarian  is nan
# communication bias towards s in the frame victimization  is nan
# communication bias towards s in the frame integration  is 0.034712858498096466
# communication bias towards thousand in the frame settlement  is nan
# communication bias towards thousand in the frame reception  is nan
# communication bias towards thousand in the frame security  is nan
# communication bias towards thousand in the frame criminality  is nan
# communication bias towards thousand in the frame economisation  is nan
# communication bias towards thousand in the frame humanitarian  is nan
# communication bias towards thousand in the frame victimization  is nan
# communication bias towards thousand in the frame integration  is nan
# communication bias towards fact in the frame settlement  is 0.13212735950946808
# communication bias towards fact in the frame reception  is 0.138065367937088
# communication bias towards fact in the frame security  is 0.04403098300099373
# communication bias towards fact in the frame criminality  is nan
# communication bias towards fact in the frame economisation  is nan
# communication bias towards fact in the frame humanitarian  is nan
# communication bias towards fact in the frame victimization  is nan
# communication bias towards fact in the frame integration  is 0.004159876145422459
# communication bias towards feel in the frame settlement  is nan
# communication bias towards feel in the frame reception  is nan
# communication bias towards feel in the frame security  is nan
# communication bias towards feel in the frame criminality  is nan
# communication bias towards feel in the frame economisation  is nan
# communication bias towards feel in the frame humanitarian  is nan
# communication bias towards feel in the frame victimization  is nan
# communication bias towards feel in the frame integration  is nan
# communication bias towards Mr in the frame settlement  is 0.012000305578112602
# communication bias towards Mr in the frame reception  is 0.07671001553535461
# communication bias towards Mr in the frame security  is 0.19252446293830872
# communication bias towards Mr in the frame criminality  is nan
# communication bias towards Mr in the frame economisation  is nan
# communication bias towards Mr in the frame humanitarian  is nan
# communication bias towards Mr in the frame victimization  is nan
# communication bias towards Mr in the frame integration  is 0.021597638726234436
# communication bias towards First in the frame settlement  is nan
# communication bias towards First in the frame reception  is nan
# communication bias towards First in the frame security  is nan
# communication bias towards First in the frame criminality  is nan
# communication bias towards First in the frame economisation  is nan
# communication bias towards First in the frame humanitarian  is nan
# communication bias towards First in the frame victimization  is nan
# communication bias towards First in the frame integration  is nan
# communication bias towards am in the frame settlement  is nan
# communication bias towards am in the frame reception  is nan
# communication bias towards am in the frame security  is nan
# communication bias towards am in the frame criminality  is nan
# communication bias towards am in the frame economisation  is nan
# communication bias towards am in the frame humanitarian  is nan
# communication bias towards am in the frame victimization  is nan
# communication bias towards am in the frame integration  is nan
# communication bias towards nearly in the frame settlement  is nan
# communication bias towards nearly in the frame reception  is nan
# communication bias towards nearly in the frame security  is nan
# communication bias towards nearly in the frame criminality  is nan
# communication bias towards nearly in the frame economisation  is nan
# communication bias towards nearly in the frame humanitarian  is nan
# communication bias towards nearly in the frame victimization  is nan
# communication bias towards nearly in the frame integration  is nan
# communication bias towards thinking in the frame settlement  is nan
# communication bias towards thinking in the frame reception  is nan
# communication bias towards thinking in the frame security  is nan
# communication bias towards thinking in the frame criminality  is nan
# communication bias towards thinking in the frame economisation  is nan
# communication bias towards thinking in the frame humanitarian  is nan
# communication bias towards thinking in the frame victimization  is nan
# communication bias towards thinking in the frame integration  is nan
# communication bias towards NATIONS in the frame settlement  is nan
# communication bias towards NATIONS in the frame reception  is nan
# communication bias towards NATIONS in the frame security  is nan
# communication bias towards NATIONS in the frame criminality  is nan
# communication bias towards NATIONS in the frame economisation  is nan
# communication bias towards NATIONS in the frame humanitarian  is nan
# communication bias towards NATIONS in the frame victimization  is nan
# communication bias towards NATIONS in the frame integration  is nan
# communication bias towards could in the frame settlement  is nan
# communication bias towards could in the frame reception  is nan
# communication bias towards could in the frame security  is nan
# communication bias towards could in the frame criminality  is nan
# communication bias towards could in the frame economisation  is nan
# communication bias towards could in the frame humanitarian  is nan
# communication bias towards could in the frame victimization  is nan
# communication bias towards could in the frame integration  is nan
# communication bias towards Spain, in the frame settlement  is nan
# communication bias towards Spain, in the frame reception  is nan
# communication bias towards Spain, in the frame security  is nan
# communication bias towards Spain, in the frame criminality  is nan
# communication bias towards Spain, in the frame economisation  is nan
# communication bias towards Spain, in the frame humanitarian  is nan
# communication bias towards Spain, in the frame victimization  is nan
# communication bias towards Spain, in the frame integration  is nan
# communication bias towards Greece in the frame settlement  is 0.0794055163860321
# communication bias towards Greece in the frame reception  is 0.06073588505387306
# communication bias towards Greece in the frame security  is 0.09139971435070038
# communication bias towards Greece in the frame criminality  is nan
# communication bias towards Greece in the frame economisation  is nan
# communication bias towards Greece in the frame humanitarian  is nan
# communication bias towards Greece in the frame victimization  is nan
# communication bias towards Greece in the frame integration  is 0.06776897609233856
# communication bias towards yea in the frame settlement  is nan
# communication bias towards yea in the frame reception  is nan
# communication bias towards yea in the frame security  is nan
# communication bias towards yea in the frame criminality  is nan
# communication bias towards yea in the frame economisation  is nan
# communication bias towards yea in the frame humanitarian  is nan
# communication bias towards yea in the frame victimization  is nan
# communication bias towards yea in the frame integration  is nan
# communication bias towards know in the frame settlement  is 0.14923441410064697
# communication bias towards know in the frame reception  is 0.07637099921703339
# communication bias towards know in the frame security  is 0.16532303392887115
# communication bias towards know in the frame criminality  is nan
# communication bias towards know in the frame economisation  is nan
# communication bias towards know in the frame humanitarian  is nan
# communication bias towards know in the frame victimization  is nan
# communication bias towards know in the frame integration  is 0.0746789425611496
# communication bias towards situation in the frame settlement  is 0.046724993735551834
# communication bias towards situation in the frame reception  is -0.03067905083298683
# communication bias towards situation in the frame security  is 0.030373170971870422
# communication bias towards situation in the frame criminality  is nan
# communication bias towards situation in the frame economisation  is nan
# communication bias towards situation in the frame humanitarian  is nan
# communication bias towards situation in the frame victimization  is nan
# communication bias towards situation in the frame integration  is -0.009682906791567802
# communication bias towards Today' in the frame settlement  is nan
# communication bias towards Today' in the frame reception  is nan
# communication bias towards Today' in the frame security  is nan
# communication bias towards Today' in the frame criminality  is nan
# communication bias towards Today' in the frame economisation  is nan
# communication bias towards Today' in the frame humanitarian  is nan
# communication bias towards Today' in the frame victimization  is nan
# communication bias towards Today' in the frame integration  is nan
# communication bias towards do in the frame settlement  is 0.043382398784160614
# communication bias towards do in the frame reception  is 0.06754586100578308
# communication bias towards do in the frame security  is 0.06726808100938797
# communication bias towards do in the frame criminality  is nan
# communication bias towards do in the frame economisation  is nan
# communication bias towards do in the frame humanitarian  is nan
# communication bias towards do in the frame victimization  is nan
# communication bias towards do in the frame integration  is 0.04135347902774811
# communication bias towards your in the frame settlement  is nan
# communication bias towards your in the frame reception  is nan
# communication bias towards your in the frame security  is nan
# communication bias towards your in the frame criminality  is nan
# communication bias towards your in the frame economisation  is nan
# communication bias towards your in the frame humanitarian  is nan
# communication bias towards your in the frame victimization  is nan
# communication bias towards your in the frame integration  is nan
# communication bias towards migration in the frame settlement  is 0.04176187515258789
# communication bias towards migration in the frame reception  is 0.03497542440891266
# communication bias towards migration in the frame security  is 0.143999382853508
# communication bias towards migration in the frame criminality  is nan
# communication bias towards migration in the frame economisation  is nan
# communication bias towards migration in the frame humanitarian  is nan
# communication bias towards migration in the frame victimization  is nan
# communication bias towards migration in the frame integration  is 0.12239348888397217

# %%
for frame in list(frame_properties.keys()):
    print(f'for {frame} bias is {np.mean(cand_frames[frame]["refugees"])}')
# Out:
# for settlement bias is nan
# for reception bias is nan
# for security bias is nan
# for criminality bias is nan
# for economisation bias is nan
# for humanitarian bias is nan
# for victimization bias is nan
# for integration bias is nan

# %% [markdown]
# # TESTING:

# %%
# batching the tweets speeds the model considerably and is enabled by splitting sentences using '\n\n' 
from stanza_batch import batch
from nltk.tokenize import sent_tokenize

# the sampled_df series should be converted to list and sentences separated with "\n\n"
all_tweets_list = list(tweets_corpus) 
for tweet in range(len(all_tweets_list)):
    tweet_sentokenized = sent_tokenize(all_tweets_list[tweet])
    if tweet_sentokenized == []:
        tweet_sentokenized.append('empty_tweet')
        print(f'empty tweet at index {tweet}')
    all_tweets_list[tweet] = "\n\n".join(tweet_sentokenized)


#tag all tweets and save them in a list    
tagged_tweets = [] 
for tweet in tqdm(batch(all_tweets_list, en_nlp, batch_size=1000)): # Default batch size is 32
        tagged_tweets.append(tweet)

# the tweet text can now be accessed using .text method        
tagged_tweets[0].text
# Out:
# 100it [00:28,  3.51it/s]
# 'Greeces Moria migrant camp quarantined after first Covid - 19 case via @TheNationalUAE'

# %%
for tweet in tqdm(range(len(tweets_corpus))):
    print(tweets_corpus[tweet])
    np_heads = [[word.id, word.text,word.head,word.deprel] for sent in tagged_tweets[tweet].sentences for word in sent.words]
    print(*[f'id: {word.id}\tword: {word.text:<15}head id: {word.head:<5}head: {sent.words[word.head-1].text if word.head > 0 else "root":<10}deprel: {word.deprel}' for sent in tagged_tweets[tweet].sentences for word in sent.words], sep='\n')
    #print(np_heads)
    ph_ids = set([np_heads[i][2] for i in range(len(np_heads))])
    ph_words = [np_heads[i-1][1] for i in ph_ids]

    word_pairs = [(np_heads[word][1], np_heads[np_heads[word][2]-1][1]) for word in range(len(np_heads)) if np_heads[word][2] != 0]
    #print(word_pairs)
    
    compounds = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='compound']
    print(compounds)
    
    amods = [[np_heads[i][1]+'_'+np_heads[np_heads[i][2]-1][1]] for i in range(len(np_heads)) if np_heads[i][3]=='amod']
    print(amods)
    for pair in word_pairs:
        phrase = pair[0]+'_'+pair[1]

    #print(model.most_similar('illegal_immigrant'))

    
    """#print(len(cand_df['candidates']))
    candidate_list = cand_df['candidates']
    for cand in cand_df['candidates']:
        #print(cand[2])
        #print(get_head(str(cand)))
        for phrase_head in cand[2]:
            #print(phrase_head)
            #if str(cand[1]) in str(tweet):
            if str(phrase_head) in str(tweet) and len(phrase_head)>2:
                #print(phrase_head)
                ph_words = [np_heads[i-1][1] for i in phrase_heads]
                #print(ph_words)
                for related in range(len(np_heads)):
                    if phrase_head == np_heads[related][1]:
                        pass
                        #print(f'checking {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                  for frame_property in list(frame_properties.keys()):
                        for seed_word in frame_properties[frame_property]:
                        try:
                            for related in range(len(np_heads)):
                                #print(np_heads[related])
                                #if cand[1] == np_heads[related][1]:
                                if phrase_head == np_heads[related][1]:
                                    print(f'checking {seed_word} and {phrase_head}_{np_heads[np_heads[related][2]-1][1]}')
                                    #cand_frames[seed_word][phrase_head].append(model.similarity(seed_word,np_heads[np_heads[related][2]-1][1]))
                                #[cand_frames[seed_word][cand].append(model.similarity(seed_word,np_heads[np_heads[related][2]+1][1])) if cand == np_heads[related][1] else print('') for related in range(len(np_heads))]
                                except KeyError:
                                pass"""
# Out:
#  29%|███████████████████████▏                                                        | 29/100 [00:00<00:00, 287.14it/s]
# Greeces Moria migrant camp quarantined after first Covid - 19 case via @TheNationalUAE
# id: 1	word: Greeces        head id: 0    head: root      deprel: root
# id: 2	word: Moria          head id: 1    head: Greeces   deprel: flat
# id: 3	word: migrant        head id: 4    head: camp      deprel: amod
# id: 4	word: camp           head id: 1    head: Greeces   deprel: appos
# id: 5	word: quarantined    head id: 4    head: camp      deprel: acl
# id: 6	word: after          head id: 11   head: case      deprel: case
# id: 7	word: first          head id: 11   head: case      deprel: amod
# id: 8	word: Covid          head id: 11   head: case      deprel: compound
# id: 9	word: -              head id: 8    head: Covid     deprel: punct
# id: 10	word: 19             head id: 8    head: Covid     deprel: nummod
# id: 11	word: case           head id: 5    head: quarantineddeprel: obl
# id: 12	word: via            head id: 14   head: TheNationalUAEdeprel: case
# id: 13	word: @              head id: 14   head: TheNationalUAEdeprel: case
# id: 14	word: TheNationalUAE head id: 5    head: quarantineddeprel: obl
# [['Covid_case']]
# [['migrant_camp'], ['first_case']]
# 2,000 covid - 19 tests will be carried out at Moria migrant camp
# id: 1	word: 2,000          head id: 2    head: covid     deprel: compound
# id: 2	word: covid          head id: 0    head: root      deprel: root
# id: 3	word: -              head id: 2    head: covid     deprel: punct
# id: 4	word: 19             head id: 5    head: tests     deprel: nummod
# id: 5	word: tests          head id: 8    head: carried   deprel: nsubj:pass
# id: 6	word: will           head id: 8    head: carried   deprel: aux
# id: 7	word: be             head id: 8    head: carried   deprel: aux:pass
# id: 8	word: carried        head id: 2    head: covid     deprel: parataxis
# id: 9	word: out            head id: 8    head: carried   deprel: compound:prt
# id: 10	word: at             head id: 13   head: camp      deprel: case
# id: 11	word: Moria          head id: 13   head: camp      deprel: compound
# id: 12	word: migrant        head id: 13   head: camp      deprel: amod
# id: 13	word: camp           head id: 8    head: carried   deprel: obl
# [['2,000_covid'], ['Moria_camp']]
# [['migrant_camp']]
# Greeces overcrowded Moria migrant camp reports FIRST coronavirus case RT WorldNews
# id: 1	word: Greeces        head id: 0    head: root      deprel: root
# id: 2	word: overcrowded    head id: 6    head: reports   deprel: amod
# id: 3	word: Moria          head id: 6    head: reports   deprel: compound
# id: 4	word: migrant        head id: 6    head: reports   deprel: amod
# id: 5	word: camp           head id: 6    head: reports   deprel: compound
# id: 6	word: reports        head id: 1    head: Greeces   deprel: appos
# id: 7	word: FIRST          head id: 9    head: case      deprel: amod
# id: 8	word: coronavirus    head id: 9    head: case      deprel: amod
# id: 9	word: case           head id: 6    head: reports   deprel: appos
# id: 10	word: RT             head id: 9    head: case      deprel: appos
# id: 11	word: WorldNews      head id: 10   head: RT        deprel: flat
# [['Moria_reports'], ['camp_reports']]
# [['overcrowded_reports'], ['migrant_reports'], ['FIRST_case'], ['coronavirus_case']]
# From the time we get in EU Greece became poor . With our own currency we were way better . You need to learn where the free money go . To immigrants, banks and NGO of Soros . Germany bought everything in EU with this politic and never give us the gold that stolen from Nazis
# id: 1	word: From           head id: 3    head: time      deprel: case
# id: 2	word: the            head id: 3    head: time      deprel: det
# id: 3	word: time           head id: 9    head: became    deprel: obl
# id: 4	word: we             head id: 5    head: get       deprel: nsubj
# id: 5	word: get            head id: 3    head: time      deprel: acl:relcl
# id: 6	word: in             head id: 7    head: EU        deprel: case
# id: 7	word: EU             head id: 5    head: get       deprel: obl
# id: 8	word: Greece         head id: 9    head: became    deprel: nsubj
# id: 9	word: became         head id: 0    head: root      deprel: root
# id: 10	word: poor           head id: 9    head: became    deprel: xcomp
# id: 11	word: .              head id: 9    head: became    deprel: punct
# id: 1	word: With           head id: 4    head: currency  deprel: case
# id: 2	word: our            head id: 4    head: currency  deprel: nmod:poss
# id: 3	word: own            head id: 4    head: currency  deprel: amod
# id: 4	word: currency       head id: 8    head: better    deprel: obl
# id: 5	word: we             head id: 8    head: better    deprel: nsubj
# id: 6	word: were           head id: 8    head: better    deprel: cop
# id: 7	word: way            head id: 8    head: better    deprel: advmod
# id: 8	word: better         head id: 0    head: root      deprel: root
# id: 9	word: .              head id: 8    head: better    deprel: punct
# id: 1	word: You            head id: 2    head: need      deprel: nsubj
# id: 2	word: need           head id: 0    head: root      deprel: root
# id: 3	word: to             head id: 4    head: learn     deprel: mark
# id: 4	word: learn          head id: 2    head: need      deprel: xcomp
# id: 5	word: where          head id: 9    head: go        deprel: mark
# id: 6	word: the            head id: 8    head: money     deprel: det
# id: 7	word: free           head id: 8    head: money     deprel: amod
# id: 8	word: money          head id: 9    head: go        deprel: nsubj
# id: 9	word: go             head id: 4    head: learn     deprel: ccomp
# id: 10	word: .              head id: 2    head: need      deprel: punct
# id: 1	word: To             head id: 2    head: immigrantsdeprel: case
# id: 2	word: immigrants     head id: 0    head: root      deprel: root
# id: 3	word: ,              head id: 4    head: banks     deprel: punct
# id: 4	word: banks          head id: 2    head: immigrantsdeprel: conj
# id: 5	word: and            head id: 6    head: NGO       deprel: cc
# id: 6	word: NGO            head id: 2    head: immigrantsdeprel: conj
# id: 7	word: of             head id: 8    head: Soros     deprel: case
# id: 8	word: Soros          head id: 6    head: NGO       deprel: nmod
# id: 9	word: .              head id: 2    head: immigrantsdeprel: punct
# id: 1	word: Germany        head id: 2    head: bought    deprel: nsubj
# id: 2	word: bought         head id: 0    head: root      deprel: root
# id: 3	word: everything     head id: 2    head: bought    deprel: obj
# id: 4	word: in             head id: 5    head: EU        deprel: case
# id: 5	word: EU             head id: 3    head: everythingdeprel: nmod
# id: 6	word: with           head id: 8    head: politic   deprel: case
# id: 7	word: this           head id: 8    head: politic   deprel: det
# id: 8	word: politic        head id: 2    head: bought    deprel: obl
# id: 9	word: and            head id: 11   head: give      deprel: cc
# id: 10	word: never          head id: 11   head: give      deprel: advmod
# id: 11	word: give           head id: 2    head: bought    deprel: conj
# id: 12	word: us             head id: 11   head: give      deprel: iobj
# id: 13	word: the            head id: 14   head: gold      deprel: det
# id: 14	word: gold           head id: 11   head: give      deprel: obj
# id: 15	word: that           head id: 16   head: stolen    deprel: nsubj
# id: 16	word: stolen         head id: 14   head: gold      deprel: acl:relcl
# id: 17	word: from           head id: 18   head: Nazis     deprel: case
# id: 18	word: Nazis          head id: 16   head: stolen    deprel: obl
# []
# [['own_we'], ['free_Greece']]
# contemporary art! And again, mixed with contemporary displays, beach debris from the refugee wave in 2015, Greece . spotted by Ka vonSeiten in @ArtSpotsApp, check it out at Wanna add your own findings? Get the free ArtSpots App for Android :
# id: 1	word: contemporary   head id: 2    head: art       deprel: amod
# id: 2	word: art            head id: 0    head: root      deprel: root
# id: 3	word: !              head id: 2    head: art       deprel: punct
# id: 1	word: And            head id: 4    head: mixed     deprel: cc
# id: 2	word: again          head id: 4    head: mixed     deprel: advmod
# id: 3	word: ,              head id: 4    head: mixed     deprel: punct
# id: 4	word: mixed          head id: 0    head: root      deprel: root
# id: 5	word: with           head id: 7    head: displays  deprel: case
# id: 6	word: contemporary   head id: 7    head: displays  deprel: amod
# id: 7	word: displays       head id: 4    head: mixed     deprel: obl
# id: 8	word: ,              head id: 10   head: debris    deprel: punct
# id: 9	word: beach          head id: 10   head: debris    deprel: compound
# id: 10	word: debris         head id: 7    head: displays  deprel: conj
# id: 11	word: from           head id: 14   head: wave      deprel: case
# id: 12	word: the            head id: 14   head: wave      deprel: det
# id: 13	word: refugee        head id: 14   head: wave      deprel: compound
# id: 14	word: wave           head id: 4    head: mixed     deprel: obl
# id: 15	word: in             head id: 16   head: 2015      deprel: case
# id: 16	word: 2015           head id: 4    head: mixed     deprel: obl
# id: 17	word: ,              head id: 16   head: 2015      deprel: punct
# id: 18	word: Greece         head id: 16   head: 2015      deprel: appos
# id: 19	word: .              head id: 4    head: mixed     deprel: punct
# id: 1	word: spotted        head id: 0    head: root      deprel: root
# id: 2	word: by             head id: 3    head: Ka        deprel: case
# id: 3	word: Ka             head id: 1    head: spotted   deprel: obl
# id: 4	word: vonSeiten      head id: 3    head: Ka        deprel: flat
# id: 5	word: in             head id: 7    head: ArtSpots  deprel: case
# id: 6	word: @              head id: 7    head: ArtSpots  deprel: case
# id: 7	word: ArtSpots       head id: 1    head: spotted   deprel: obl
# id: 1	word: App            head id: 3    head: check     deprel: vocative
# id: 2	word: ,              head id: 3    head: check     deprel: punct
# id: 3	word: check          head id: 0    head: root      deprel: root
# id: 4	word: it             head id: 3    head: check     deprel: obj
# id: 5	word: out            head id: 3    head: check     deprel: compound:prt
# id: 6	word: at             head id: 7    head: Wanna     deprel: case
# id: 7	word: Wanna          head id: 3    head: check     deprel: obl
# id: 8	word: add            head id: 3    head: check     deprel: advcl
# id: 9	word: your           head id: 11   head: findings  deprel: nmod:poss
# id: 10	word: own            head id: 11   head: findings  deprel: amod
# id: 11	word: findings       head id: 8    head: add       deprel: obj
# id: 12	word: ?              head id: 1    head: App       deprel: punct
# id: 1	word: Get            head id: 0    head: root      deprel: root
# id: 2	word: the            head id: 5    head: App       deprel: det
# id: 3	word: free           head id: 5    head: App       deprel: amod
# id: 4	word: ArtSpots       head id: 5    head: App       deprel: compound
# id: 5	word: App            head id: 1    head: Get       deprel: obj
# id: 6	word: for            head id: 7    head: Android   deprel: case
# id: 7	word: Android        head id: 1    head: Get       deprel: obl
# id: 8	word: :              head id: 1    head: Get       deprel: punct
# [['beach_displays'], ['refugee_from'], ['ArtSpots_again']]
# [['contemporary_art'], ['contemporary_mixed'], ['own_,'], ['free_again']]
# Tbh, they r more likely to ditch Greece . Greece is used by EU to murder & imprison migrants without getting hands dirty, but theres only so much that is worth to them imo? Turkey almost took that job even! (And a stack of EU cash )
# id: 1	word: Tbh            head id: 6    head: likely    deprel: discourse
# id: 2	word: ,              head id: 6    head: likely    deprel: punct
# id: 3	word: they           head id: 6    head: likely    deprel: nsubj
# id: 4	word: r              head id: 6    head: likely    deprel: cop
# id: 5	word: more           head id: 6    head: likely    deprel: advmod
# id: 6	word: likely         head id: 0    head: root      deprel: root
# id: 7	word: to             head id: 8    head: ditch     deprel: mark
# id: 8	word: ditch          head id: 6    head: likely    deprel: xcomp
# id: 9	word: Greece         head id: 8    head: ditch     deprel: obj
# id: 10	word: .              head id: 6    head: likely    deprel: punct
# id: 1	word: Greece         head id: 3    head: used      deprel: nsubj:pass
# id: 2	word: is             head id: 3    head: used      deprel: aux:pass
# id: 3	word: used           head id: 0    head: root      deprel: root
# id: 4	word: by             head id: 5    head: EU        deprel: case
# id: 5	word: EU             head id: 3    head: used      deprel: obl
# id: 6	word: to             head id: 7    head: murder    deprel: mark
# id: 7	word: murder         head id: 3    head: used      deprel: xcomp
# id: 8	word: &              head id: 9    head: imprison  deprel: cc
# id: 9	word: imprison       head id: 7    head: murder    deprel: conj
# id: 10	word: migrants       head id: 7    head: murder    deprel: obj
# id: 11	word: without        head id: 12   head: getting   deprel: mark
# id: 12	word: getting        head id: 7    head: murder    deprel: advcl
# id: 13	word: hands          head id: 14   head: dirty     deprel: compound
# id: 14	word: dirty          head id: 12   head: getting   deprel: xcomp
# id: 15	word: ,              head id: 17   head: theres    deprel: punct
# id: 16	word: but            head id: 17   head: theres    deprel: cc
# id: 17	word: theres         head id: 3    head: used      deprel: conj
# id: 18	word: only           head id: 20   head: much      deprel: advmod
# id: 19	word: so             head id: 20   head: much      deprel: advmod
# id: 20	word: much           head id: 23   head: worth     deprel: advmod
# id: 21	word: that           head id: 23   head: worth     deprel: nsubj
# id: 22	word: is             head id: 23   head: worth     deprel: cop
# id: 23	word: worth          head id: 17   head: theres    deprel: ccomp
# id: 24	word: to             head id: 25   head: them      deprel: case
# id: 25	word: them           head id: 23   head: worth     deprel: obl
# id: 26	word: imo            head id: 23   head: worth     deprel: advmod
# id: 27	word: ?              head id: 3    head: used      deprel: punct
# id: 1	word: Turkey         head id: 3    head: took      deprel: nsubj
# id: 2	word: almost         head id: 3    head: took      deprel: advmod
# id: 3	word: took           head id: 0    head: root      deprel: root
# id: 4	word: that           head id: 5    head: job       deprel: det
# id: 5	word: job            head id: 3    head: took      deprel: obj
# id: 6	word: even           head id: 3    head: took      deprel: advmod
# id: 7	word: !              head id: 3    head: took      deprel: punct
# id: 1	word: (              head id: 4    head: stack     deprel: punct
# id: 2	word: And            head id: 4    head: stack     deprel: cc
# id: 3	word: a              head id: 4    head: stack     deprel: det
# id: 4	word: stack          head id: 0    head: root      deprel: root
# id: 5	word: of             head id: 7    head: cash      deprel: case
# id: 6	word: EU             head id: 7    head: cash      deprel: compound
# id: 7	word: cash           head id: 4    head: stack     deprel: nmod
# id: 8	word: )              head id: 4    head: stack     deprel: punct
# [['hands_by'], ['EU_to']]
# []
# I have written this yesterday . And in today news: Greece reshifting migrants arriving from the sea, as Lampedusa island cannot take in any more of them . And guess where! On ships! Saw video with Afro migrants walking up on big ship! Not the first time that my Tweets became true.
# id: 1	word: I              head id: 3    head: written   deprel: nsubj
# id: 2	word: have           head id: 3    head: written   deprel: aux
# id: 3	word: written        head id: 0    head: root      deprel: root
# id: 4	word: this           head id: 3    head: written   deprel: obj
# id: 5	word: yesterday      head id: 3    head: written   deprel: obl:tmod
# id: 6	word: .              head id: 3    head: written   deprel: punct
# id: 1	word: And            head id: 19   head: take      deprel: cc
# id: 2	word: in             head id: 4    head: news      deprel: case
# id: 3	word: today          head id: 4    head: news      deprel: compound
# id: 4	word: news           head id: 0    head: root      deprel: root
# id: 5	word: :              head id: 4    head: news      deprel: punct
# id: 6	word: Greece         head id: 8    head: migrants  deprel: compound
# id: 7	word: reshifting     head id: 8    head: migrants  deprel: amod
# id: 8	word: migrants       head id: 4    head: news      deprel: appos
# id: 9	word: arriving       head id: 8    head: migrants  deprel: acl
# id: 10	word: from           head id: 12   head: sea       deprel: case
# id: 11	word: the            head id: 12   head: sea       deprel: det
# id: 12	word: sea            head id: 9    head: arriving  deprel: obl
# id: 13	word: ,              head id: 19   head: take      deprel: punct
# id: 14	word: as             head id: 19   head: take      deprel: mark
# id: 15	word: Lampedusa      head id: 16   head: island    deprel: compound
# id: 16	word: island         head id: 19   head: take      deprel: nsubj
# id: 17	word: can            head id: 19   head: take      deprel: aux
# id: 18	word: not            head id: 19   head: take      deprel: advmod
# id: 19	word: take           head id: 7    head: reshiftingdeprel: advcl
# id: 20	word: in             head id: 19   head: take      deprel: compound:prt
# id: 21	word: any            head id: 22   head: more      deprel: det
# id: 22	word: more           head id: 19   head: take      deprel: obj
# id: 23	word: of             head id: 24   head: them      deprel: case
# id: 24	word: them           head id: 22   head: more      deprel: obl
# id: 25	word: .              head id: 4    head: news      deprel: punct
# id: 1	word: And            head id: 2    head: guess     deprel: cc
# id: 2	word: guess          head id: 0    head: root      deprel: root
# id: 3	word: where          head id: 2    head: guess     deprel: mark
# id: 4	word: !              head id: 2    head: guess     deprel: punct
# id: 1	word: On             head id: 2    head: ships     deprel: case
# id: 2	word: ships          head id: 0    head: root      deprel: root
# id: 3	word: !              head id: 2    head: ships     deprel: punct
# id: 1	word: Saw            head id: 0    head: root      deprel: root
# id: 2	word: video          head id: 1    head: Saw       deprel: obj
# id: 3	word: with           head id: 5    head: migrants  deprel: case
# id: 4	word: Afro           head id: 5    head: migrants  deprel: amod
# id: 5	word: migrants       head id: 2    head: video     deprel: nmod
# id: 6	word: walking        head id: 5    head: migrants  deprel: acl
# id: 7	word: up             head id: 6    head: walking   deprel: compound:prt
# id: 8	word: on             head id: 10   head: ship      deprel: case
# id: 9	word: big            head id: 10   head: ship      deprel: amod
# id: 10	word: ship           head id: 6    head: walking   deprel: obl
# id: 11	word: !              head id: 1    head: Saw       deprel: punct
# id: 1	word: Not            head id: 4    head: time      deprel: advmod
# id: 2	word: the            head id: 4    head: time      deprel: det
# id: 3	word: first          head id: 4    head: time      deprel: amod
# id: 4	word: time           head id: 0    head: root      deprel: root
# id: 5	word: that           head id: 8    head: became    deprel: mark
# id: 6	word: my             head id: 7    head: Tweets    deprel: nmod:poss
# id: 7	word: Tweets         head id: 8    head: became    deprel: nsubj
# id: 8	word: became         head id: 4    head: time      deprel: acl:relcl
# id: 9	word: true           head id: 8    head: became    deprel: xcomp
# id: 10	word: .              head id: 4    head: time      deprel: punct
# [['today_this'], ['Greece_in'], ['Lampedusa_from']]
# [['reshifting_in'], ['Afro_yesterday'], ['big_news'], ['first_this']]
# After First COVID - 19 Case in Moria Refugee Camp, Greece Imposes Dangerou . . . @YouTube
# id: 1	word: After          head id: 6    head: Case      deprel: case
# id: 2	word: First          head id: 6    head: Case      deprel: compound
# id: 3	word: COVID          head id: 6    head: Case      deprel: compound
# id: 4	word: -              head id: 3    head: COVID     deprel: punct
# id: 5	word: 19             head id: 3    head: COVID     deprel: nummod
# id: 6	word: Case           head id: 13   head: Imposes   deprel: obl
# id: 7	word: in             head id: 10   head: Camp      deprel: case
# id: 8	word: Moria          head id: 10   head: Camp      deprel: compound
# id: 9	word: Refugee        head id: 10   head: Camp      deprel: compound
# id: 10	word: Camp           head id: 6    head: Case      deprel: nmod
# id: 11	word: ,              head id: 6    head: Case      deprel: punct
# id: 12	word: Greece         head id: 13   head: Imposes   deprel: nsubj
# id: 13	word: Imposes        head id: 0    head: root      deprel: root
# id: 14	word: Dangerou       head id: 13   head: Imposes   deprel: obj
# id: 15	word: .              head id: 13   head: Imposes   deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: @YouTube       head id: 0    head: root      deprel: root
# [['First_Case'], ['COVID_Case'], ['Moria_Camp'], ['Refugee_Camp']]
# []
# Thessaloniki - Migration Completed - We have completed our migration of our services in Thessaloniki, Greece . Please contact support if youre experiencing any issues.
# id: 1	word: Thessaloniki   head id: 0    head: root      deprel: root
# id: 2	word: -              head id: 1    head: Thessalonikideprel: punct
# id: 3	word: Migration      head id: 4    head: Completed deprel: nsubj
# id: 4	word: Completed      head id: 1    head: Thessalonikideprel: parataxis
# id: 5	word: -              head id: 1    head: Thessalonikideprel: punct
# id: 1	word: We             head id: 3    head: completed deprel: nsubj
# id: 2	word: have           head id: 3    head: completed deprel: aux
# id: 3	word: completed      head id: 0    head: root      deprel: root
# id: 4	word: our            head id: 5    head: migration deprel: nmod:poss
# id: 5	word: migration      head id: 3    head: completed deprel: obj
# id: 6	word: of             head id: 8    head: services  deprel: case
# id: 7	word: our            head id: 8    head: services  deprel: nmod:poss
# id: 8	word: services       head id: 5    head: migration deprel: nmod
# id: 9	word: in             head id: 10   head: Thessalonikideprel: case
# id: 10	word: Thessaloniki   head id: 3    head: completed deprel: obl
# id: 11	word: ,              head id: 10   head: Thessalonikideprel: punct
# id: 12	word: Greece         head id: 10   head: Thessalonikideprel: appos
# id: 13	word: .              head id: 3    head: completed deprel: punct
# id: 1	word: Please         head id: 2    head: contact   deprel: discourse
# id: 2	word: contact        head id: 0    head: root      deprel: root
# id: 3	word: support        head id: 2    head: contact   deprel: obj
# id: 4	word: if             head id: 6    head: experiencingdeprel: mark
# id: 5	word: youre          head id: 6    head: experiencingdeprel: nsubj
# id: 6	word: experiencing   head id: 2    head: contact   deprel: advcl
# id: 7	word: any            head id: 8    head: issues    deprel: det
# id: 8	word: issues         head id: 6    head: experiencingdeprel: obj
# id: 9	word: .              head id: 2    head: contact   deprel: punct
# []
# []
# He is refuge but Greece doesnt accepted to him he want to go to the another country maybe Greece want to send to him back killer to Iran
# id: 1	word: He             head id: 3    head: refuge    deprel: nsubj
# id: 2	word: is             head id: 3    head: refuge    deprel: cop
# id: 3	word: refuge         head id: 0    head: root      deprel: root
# id: 4	word: but            head id: 7    head: accepted  deprel: cc
# id: 5	word: Greece         head id: 7    head: accepted  deprel: nsubj
# id: 6	word: doesnt         head id: 7    head: accepted  deprel: aux
# id: 7	word: accepted       head id: 3    head: refuge    deprel: conj
# id: 8	word: to             head id: 9    head: him       deprel: case
# id: 9	word: him            head id: 7    head: accepted  deprel: obl
# id: 10	word: he             head id: 11   head: want      deprel: nsubj
# id: 11	word: want           head id: 3    head: refuge    deprel: parataxis
# id: 12	word: to             head id: 13   head: go        deprel: mark
# id: 13	word: go             head id: 11   head: want      deprel: xcomp
# id: 14	word: to             head id: 17   head: country   deprel: case
# id: 15	word: the            head id: 17   head: country   deprel: det
# id: 16	word: another        head id: 17   head: country   deprel: det
# id: 17	word: country        head id: 13   head: go        deprel: obl
# id: 18	word: maybe          head id: 20   head: want      deprel: advmod
# id: 19	word: Greece         head id: 20   head: want      deprel: nsubj
# id: 20	word: want           head id: 13   head: go        deprel: advcl
# id: 21	word: to             head id: 22   head: send      deprel: mark
# id: 22	word: send           head id: 20   head: want      deprel: xcomp
# id: 23	word: to             head id: 24   head: him       deprel: case
# id: 24	word: him            head id: 22   head: send      deprel: obl
# id: 25	word: back           head id: 26   head: killer    deprel: advmod
# id: 26	word: killer         head id: 22   head: send      deprel: obj
# id: 27	word: to             head id: 28   head: Iran      deprel: case
# id: 28	word: Iran           head id: 26   head: killer    deprel: nmod
# []
# []
# Muslims not welcome in Greece are jihadists and they have countries but they want to destabilize Greece . We will not give them chance to survive . . Islam is a cancee
# id: 1	word: Muslims        head id: 7    head: jihadists deprel: nsubj
# id: 2	word: not            head id: 3    head: welcome   deprel: advmod
# id: 3	word: welcome        head id: 1    head: Muslims   deprel: amod
# id: 4	word: in             head id: 5    head: Greece    deprel: case
# id: 5	word: Greece         head id: 3    head: welcome   deprel: obl
# id: 6	word: are            head id: 7    head: jihadists deprel: cop
# id: 7	word: jihadists      head id: 0    head: root      deprel: root
# id: 8	word: and            head id: 10   head: have      deprel: cc
# id: 9	word: they           head id: 10   head: have      deprel: nsubj
# id: 10	word: have           head id: 7    head: jihadists deprel: conj
# id: 11	word: countries      head id: 10   head: have      deprel: obj
# id: 12	word: but            head id: 14   head: want      deprel: cc
# id: 13	word: they           head id: 14   head: want      deprel: nsubj
# id: 14	word: want           head id: 7    head: jihadists deprel: conj
# id: 15	word: to             head id: 16   head: destabilizedeprel: mark
# id: 16	word: destabilize    head id: 14   head: want      deprel: xcomp
# id: 17	word: Greece         head id: 16   head: destabilizedeprel: obj
# id: 18	word: .              head id: 7    head: jihadists deprel: punct
# id: 1	word: We             head id: 4    head: give      deprel: nsubj
# id: 2	word: will           head id: 4    head: give      deprel: aux
# id: 3	word: not            head id: 4    head: give      deprel: advmod
# id: 4	word: give           head id: 0    head: root      deprel: root
# id: 5	word: them           head id: 4    head: give      deprel: iobj
# id: 6	word: chance         head id: 4    head: give      deprel: obj
# id: 7	word: to             head id: 8    head: survive   deprel: mark
# id: 8	word: survive        head id: 6    head: chance    deprel: acl
# id: 9	word: .              head id: 4    head: give      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: Islam          head id: 4    head: cancee    deprel: nsubj
# id: 2	word: is             head id: 4    head: cancee    deprel: cop
# id: 3	word: a              head id: 4    head: cancee    deprel: det
# id: 4	word: cancee         head id: 0    head: root      deprel: root
# []
# [['welcome_Muslims']]
# Greece not jobs for foreigners all this people should return back to their home countries coming back . Islam is a gang as per the courts in a lot of countries like Hungary Greece Angola so those Muslims considered aa constitution of gang . . Islam nor acceptable in Greece
# id: 1	word: Greece         head id: 10   head: return    deprel: nsubj
# id: 2	word: not            head id: 3    head: jobs      deprel: advmod
# id: 3	word: jobs           head id: 10   head: return    deprel: nsubj
# id: 4	word: for            head id: 5    head: foreignersdeprel: case
# id: 5	word: foreigners     head id: 3    head: jobs      deprel: nmod
# id: 6	word: all            head id: 8    head: people    deprel: det:predet
# id: 7	word: this           head id: 8    head: people    deprel: det
# id: 8	word: people         head id: 5    head: foreignersdeprel: appos
# id: 9	word: should         head id: 10   head: return    deprel: aux
# id: 10	word: return         head id: 0    head: root      deprel: root
# id: 11	word: back           head id: 10   head: return    deprel: advmod
# id: 12	word: to             head id: 15   head: countries deprel: case
# id: 13	word: their          head id: 15   head: countries deprel: nmod:poss
# id: 14	word: home           head id: 15   head: countries deprel: compound
# id: 15	word: countries      head id: 11   head: back      deprel: obl
# id: 16	word: coming         head id: 15   head: countries deprel: acl
# id: 17	word: back           head id: 16   head: coming    deprel: advmod
# id: 18	word: .              head id: 10   head: return    deprel: punct
# id: 1	word: Islam          head id: 4    head: gang      deprel: nsubj
# id: 2	word: is             head id: 4    head: gang      deprel: cop
# id: 3	word: a              head id: 4    head: gang      deprel: det
# id: 4	word: gang           head id: 0    head: root      deprel: root
# id: 5	word: as             head id: 8    head: courts    deprel: case
# id: 6	word: per            head id: 8    head: courts    deprel: case
# id: 7	word: the            head id: 8    head: courts    deprel: det
# id: 8	word: courts         head id: 4    head: gang      deprel: nmod
# id: 9	word: in             head id: 11   head: lot       deprel: case
# id: 10	word: a              head id: 11   head: lot       deprel: det
# id: 11	word: lot            head id: 4    head: gang      deprel: nmod
# id: 12	word: of             head id: 13   head: countries deprel: case
# id: 13	word: countries      head id: 11   head: lot       deprel: nmod
# id: 14	word: like           head id: 15   head: Hungary   deprel: case
# id: 15	word: Hungary        head id: 17   head: Angola    deprel: compound
# id: 16	word: Greece         head id: 17   head: Angola    deprel: compound
# id: 17	word: Angola         head id: 13   head: countries deprel: nmod
# id: 18	word: so             head id: 21   head: considereddeprel: advmod
# id: 19	word: those          head id: 20   head: Muslims   deprel: det
# id: 20	word: Muslims        head id: 21   head: considereddeprel: nsubj
# id: 21	word: considered     head id: 4    head: gang      deprel: parataxis
# id: 22	word: aa             head id: 23   head: constitutiondeprel: det
# id: 23	word: constitution   head id: 21   head: considereddeprel: obj
# id: 24	word: of             head id: 25   head: gang      deprel: case
# id: 25	word: gang           head id: 23   head: constitutiondeprel: nmod
# id: 26	word: .              head id: 4    head: gang      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: Islam          head id: 0    head: root      deprel: root
# id: 2	word: nor            head id: 3    head: acceptabledeprel: cc
# id: 3	word: acceptable     head id: 1    head: Islam     deprel: conj
# id: 4	word: in             head id: 5    head: Greece    deprel: case
# id: 5	word: Greece         head id: 1    head: Islam     deprel: nmod
# [['home_countries'], ['Hungary_back'], ['Greece_back']]
# []
# Greeces overcrowded Moria migrant camp reports FIRST coronavirus case First Published on September 2, 2020 @6 : 03am news
# id: 1	word: Greeces        head id: 6    head: reports   deprel: compound
# id: 2	word: overcrowded    head id: 6    head: reports   deprel: amod
# id: 3	word: Moria          head id: 6    head: reports   deprel: compound
# id: 4	word: migrant        head id: 6    head: reports   deprel: amod
# id: 5	word: camp           head id: 6    head: reports   deprel: compound
# id: 6	word: reports        head id: 11   head: Published deprel: nsubj:pass
# id: 7	word: FIRST          head id: 9    head: case      deprel: amod
# id: 8	word: coronavirus    head id: 9    head: case      deprel: amod
# id: 9	word: case           head id: 6    head: reports   deprel: appos
# id: 10	word: First          head id: 11   head: Published deprel: advmod
# id: 11	word: Published      head id: 0    head: root      deprel: root
# id: 12	word: on             head id: 13   head: September deprel: case
# id: 13	word: September      head id: 11   head: Published deprel: obl
# id: 14	word: 2              head id: 13   head: September deprel: nummod
# id: 15	word: ,              head id: 13   head: September deprel: punct
# id: 16	word: 2020           head id: 13   head: September deprel: nummod
# id: 17	word: @              head id: 18   head: 6         deprel: case
# id: 18	word: 6              head id: 11   head: Published deprel: obl
# id: 19	word: :              head id: 22   head: news      deprel: punct
# id: 20	word: 03             head id: 21   head: am        deprel: nummod
# id: 21	word: am             head id: 22   head: news      deprel: compound
# id: 22	word: news           head id: 11   head: Published deprel: obl
# [['Greeces_reports'], ['Moria_reports'], ['camp_reports'], ['am_news']]
# [['overcrowded_reports'], ['migrant_reports'], ['FIRST_case'], ['coronavirus_case']]
# Where for example was the EU when Greece was in financial shtook . On, could it be it wasn' t in charge of its own currency? Where was the EU when Italy needed help (which by the way it will need a massive bailout soon) when the migrants landed there?
# id: 1	word: Where          head id: 6    head: EU        deprel: advmod
# id: 2	word: for            head id: 3    head: example   deprel: case
# id: 3	word: example        head id: 1    head: Where     deprel: obl
# id: 4	word: was            head id: 6    head: EU        deprel: cop
# id: 5	word: the            head id: 6    head: EU        deprel: det
# id: 6	word: EU             head id: 0    head: root      deprel: root
# id: 7	word: when           head id: 12   head: shtook    deprel: mark
# id: 8	word: Greece         head id: 12   head: shtook    deprel: nsubj
# id: 9	word: was            head id: 12   head: shtook    deprel: cop
# id: 10	word: in             head id: 12   head: shtook    deprel: case
# id: 11	word: financial      head id: 12   head: shtook    deprel: amod
# id: 12	word: shtook         head id: 6    head: EU        deprel: advcl
# id: 13	word: .              head id: 6    head: EU        deprel: punct
# id: 1	word: On             head id: 5    head: be        deprel: advmod
# id: 2	word: ,              head id: 5    head: be        deprel: punct
# id: 3	word: could          head id: 5    head: be        deprel: aux
# id: 4	word: it             head id: 5    head: be        deprel: nsubj
# id: 5	word: be             head id: 0    head: root      deprel: root
# id: 6	word: it             head id: 5    head: be        deprel: expl
# id: 7	word: wasn           head id: 9    head: t         deprel: cop
# id: 8	word: '              head id: 9    head: t         deprel: punct
# id: 9	word: t              head id: 5    head: be        deprel: ccomp
# id: 10	word: in             head id: 11   head: charge    deprel: case
# id: 11	word: charge         head id: 9    head: t         deprel: nmod
# id: 12	word: of             head id: 15   head: currency  deprel: case
# id: 13	word: its            head id: 15   head: currency  deprel: nmod:poss
# id: 14	word: own            head id: 15   head: currency  deprel: amod
# id: 15	word: currency       head id: 11   head: charge    deprel: nmod
# id: 16	word: ?              head id: 5    head: be        deprel: punct
# id: 1	word: Where          head id: 0    head: root      deprel: root
# id: 2	word: was            head id: 1    head: Where     deprel: cop
# id: 3	word: the            head id: 4    head: EU        deprel: det
# id: 4	word: EU             head id: 1    head: Where     deprel: nsubj
# id: 5	word: when           head id: 7    head: needed    deprel: mark
# id: 6	word: Italy          head id: 7    head: needed    deprel: nsubj
# id: 7	word: needed         head id: 1    head: Where     deprel: advcl
# id: 8	word: help           head id: 7    head: needed    deprel: obj
# id: 9	word: (              head id: 16   head: need      deprel: punct
# id: 10	word: which          head id: 16   head: need      deprel: nsubj
# id: 11	word: by             head id: 13   head: way       deprel: case
# id: 12	word: the            head id: 13   head: way       deprel: det
# id: 13	word: way            head id: 16   head: need      deprel: obl
# id: 14	word: it             head id: 16   head: need      deprel: nsubj
# id: 15	word: will           head id: 16   head: need      deprel: aux
# id: 16	word: need           head id: 8    head: help      deprel: acl:relcl
# id: 17	word: a              head id: 19   head: bailout   deprel: det
# id: 18	word: massive        head id: 19   head: bailout   deprel: amod
# id: 19	word: bailout        head id: 16   head: need      deprel: obj
# id: 20	word: soon           head id: 16   head: need      deprel: advmod
# id: 21	word: )              head id: 16   head: need      deprel: punct
# id: 22	word: when           head id: 25   head: landed    deprel: mark
# id: 23	word: the            head id: 24   head: migrants  deprel: det
# id: 24	word: migrants       head id: 25   head: landed    deprel: nsubj
# id: 25	word: landed         head id: 16   head: need      deprel: advcl
# id: 26	word: there          head id: 25   head: landed    deprel: advmod
# id: 27	word: ?              head id: 1    head: Where     deprel: punct
# []
# [['financial_shtook'], ['own_,'], ['massive_it']]
# If the Bucks dont make it to past the Heat is there any chance of Giannis moving to the Raptors?? He must be tight with Masai after he apparently helped his family migrate to Greece
# id: 1	word: If             head id: 5    head: make      deprel: mark
# id: 2	word: the            head id: 3    head: Bucks     deprel: det
# id: 3	word: Bucks          head id: 5    head: make      deprel: nsubj
# id: 4	word: dont           head id: 5    head: make      deprel: aux
# id: 5	word: make           head id: 11   head: is        deprel: advcl
# id: 6	word: it             head id: 5    head: make      deprel: obj
# id: 7	word: to             head id: 10   head: Heat      deprel: mark
# id: 8	word: past           head id: 10   head: Heat      deprel: case
# id: 9	word: the            head id: 10   head: Heat      deprel: det
# id: 10	word: Heat           head id: 5    head: make      deprel: obl
# id: 11	word: is             head id: 0    head: root      deprel: root
# id: 12	word: there          head id: 11   head: is        deprel: expl
# id: 13	word: any            head id: 14   head: chance    deprel: det
# id: 14	word: chance         head id: 11   head: is        deprel: nsubj
# id: 15	word: of             head id: 16   head: Giannis   deprel: case
# id: 16	word: Giannis        head id: 14   head: chance    deprel: nmod
# id: 17	word: moving         head id: 16   head: Giannis   deprel: acl
# id: 18	word: to             head id: 20   head: Raptors   deprel: case
# id: 19	word: the            head id: 20   head: Raptors   deprel: det
# id: 20	word: Raptors        head id: 17   head: moving    deprel: obl
# id: 21	word: ??             head id: 11   head: is        deprel: punct
# id: 1	word: He             head id: 4    head: tight     deprel: nsubj
# id: 2	word: must           head id: 4    head: tight     deprel: aux
# id: 3	word: be             head id: 4    head: tight     deprel: cop
# id: 4	word: tight          head id: 0    head: root      deprel: root
# id: 5	word: with           head id: 6    head: Masai     deprel: case
# id: 6	word: Masai          head id: 4    head: tight     deprel: obl
# id: 7	word: after          head id: 10   head: helped    deprel: mark
# id: 8	word: he             head id: 10   head: helped    deprel: nsubj
# id: 9	word: apparently     head id: 10   head: helped    deprel: advmod
# id: 10	word: helped         head id: 4    head: tight     deprel: advcl
# id: 11	word: his            head id: 12   head: family    deprel: nmod:poss
# id: 12	word: family         head id: 13   head: migrate   deprel: nsubj
# id: 13	word: migrate        head id: 10   head: helped    deprel: xcomp
# id: 14	word: to             head id: 15   head: Greece    deprel: case
# id: 15	word: Greece         head id: 13   head: migrate   deprel: obl
# []
# []
# Social distancing & basic hygiene measures like handwashing are simply impossible to adhere to in Moria, says IRC' s Dimitra Kalogeropoulou . As covid 19 reaches Moria refugee camp in Lesvos, Greece we' re calling for urgent support . More in @Reuters :
# id: 1	word: Social         head id: 2    head: distancingdeprel: amod
# id: 2	word: distancing     head id: 11   head: impossibledeprel: nsubj
# id: 3	word: &              head id: 6    head: measures  deprel: cc
# id: 4	word: basic          head id: 5    head: hygiene   deprel: amod
# id: 5	word: hygiene        head id: 6    head: measures  deprel: compound
# id: 6	word: measures       head id: 2    head: distancingdeprel: conj
# id: 7	word: like           head id: 8    head: handwashingdeprel: case
# id: 8	word: handwashing    head id: 6    head: measures  deprel: nmod
# id: 9	word: are            head id: 11   head: impossibledeprel: cop
# id: 10	word: simply         head id: 11   head: impossibledeprel: advmod
# id: 11	word: impossible     head id: 18   head: says      deprel: ccomp
# id: 12	word: to             head id: 13   head: adhere    deprel: mark
# id: 13	word: adhere         head id: 11   head: impossibledeprel: xcomp
# id: 14	word: to             head id: 13   head: adhere    deprel: obl
# id: 15	word: in             head id: 16   head: Moria     deprel: case
# id: 16	word: Moria          head id: 13   head: adhere    deprel: obl
# id: 17	word: ,              head id: 18   head: says      deprel: punct
# id: 18	word: says           head id: 0    head: root      deprel: root
# id: 19	word: IRC            head id: 22   head: Dimitra   deprel: nmod:poss
# id: 20	word: '              head id: 19   head: IRC       deprel: case
# id: 21	word: s              head id: 19   head: IRC       deprel: case
# id: 22	word: Dimitra        head id: 18   head: says      deprel: nsubj
# id: 23	word: Kalogeropoulou head id: 22   head: Dimitra   deprel: flat
# id: 24	word: .              head id: 18   head: says      deprel: punct
# id: 1	word: As             head id: 4    head: reaches   deprel: mark
# id: 2	word: covid          head id: 4    head: reaches   deprel: nsubj
# id: 3	word: 19             head id: 2    head: covid     deprel: flat
# id: 4	word: reaches        head id: 15   head: calling   deprel: advcl
# id: 5	word: Moria          head id: 7    head: camp      deprel: compound
# id: 6	word: refugee        head id: 7    head: camp      deprel: compound
# id: 7	word: camp           head id: 4    head: reaches   deprel: obj
# id: 8	word: in             head id: 9    head: Lesvos    deprel: case
# id: 9	word: Lesvos         head id: 7    head: camp      deprel: nmod
# id: 10	word: ,              head id: 12   head: we        deprel: punct
# id: 11	word: Greece         head id: 12   head: we        deprel: compound
# id: 12	word: we             head id: 15   head: calling   deprel: nsubj
# id: 13	word: '              head id: 12   head: we        deprel: punct
# id: 14	word: re             head id: 0    head: root      deprel: root
# id: 15	word: calling        head id: 14   head: re        deprel: xcomp
# id: 16	word: for            head id: 18   head: support   deprel: case
# id: 17	word: urgent         head id: 18   head: support   deprel: amod
# id: 18	word: support        head id: 15   head: calling   deprel: obl
# id: 19	word: .              head id: 15   head: calling   deprel: punct
# id: 1	word: More           head id: 0    head: root      deprel: root
# id: 2	word: in             head id: 4    head: Reuters   deprel: case
# id: 3	word: @              head id: 4    head: Reuters   deprel: case
# id: 4	word: Reuters        head id: 1    head: More      deprel: obl
# id: 5	word: :              head id: 1    head: More      deprel: punct
# [['hygiene_measures'], ['Moria_like'], ['refugee_like'], ['Greece_to']]
# [['Social_distancing'], ['basic_hygiene'], ['urgent_says']]
# Erdogan and his country Turkey is hosting 4.5 million innocent refugees, saved them, shaltered them, protected them . While Italy and Greece were trying to sank refugees boats . If world be fair place you would not call him fascist you would nominate him to Nobel Peace Prize
# id: 1	word: Erdogan        head id: 7    head: hosting   deprel: nsubj
# id: 2	word: and            head id: 4    head: country   deprel: cc
# id: 3	word: his            head id: 4    head: country   deprel: nmod:poss
# id: 4	word: country        head id: 1    head: Erdogan   deprel: conj
# id: 5	word: Turkey         head id: 1    head: Erdogan   deprel: conj
# id: 6	word: is             head id: 7    head: hosting   deprel: aux
# id: 7	word: hosting        head id: 0    head: root      deprel: root
# id: 8	word: 4.5            head id: 9    head: million   deprel: compound
# id: 9	word: million        head id: 11   head: refugees  deprel: nummod
# id: 10	word: innocent       head id: 11   head: refugees  deprel: amod
# id: 11	word: refugees       head id: 7    head: hosting   deprel: obj
# id: 12	word: ,              head id: 13   head: saved     deprel: punct
# id: 13	word: saved          head id: 7    head: hosting   deprel: conj
# id: 14	word: them           head id: 13   head: saved     deprel: obj
# id: 15	word: ,              head id: 16   head: shaltered deprel: punct
# id: 16	word: shaltered      head id: 13   head: saved     deprel: conj
# id: 17	word: them           head id: 16   head: shaltered deprel: obj
# id: 18	word: ,              head id: 19   head: protected deprel: punct
# id: 19	word: protected      head id: 7    head: hosting   deprel: conj
# id: 20	word: them           head id: 19   head: protected deprel: obj
# id: 21	word: .              head id: 7    head: hosting   deprel: punct
# id: 1	word: While          head id: 6    head: trying    deprel: mark
# id: 2	word: Italy          head id: 6    head: trying    deprel: nsubj
# id: 3	word: and            head id: 4    head: Greece    deprel: cc
# id: 4	word: Greece         head id: 2    head: Italy     deprel: conj
# id: 5	word: were           head id: 6    head: trying    deprel: aux
# id: 6	word: trying         head id: 0    head: root      deprel: root
# id: 7	word: to             head id: 8    head: sank      deprel: mark
# id: 8	word: sank           head id: 6    head: trying    deprel: xcomp
# id: 9	word: refugees       head id: 10   head: boats     deprel: compound
# id: 10	word: boats          head id: 8    head: sank      deprel: obj
# id: 11	word: .              head id: 6    head: trying    deprel: punct
# id: 1	word: If             head id: 5    head: place     deprel: mark
# id: 2	word: world          head id: 5    head: place     deprel: nsubj
# id: 3	word: be             head id: 5    head: place     deprel: cop
# id: 4	word: fair           head id: 5    head: place     deprel: amod
# id: 5	word: place          head id: 9    head: call      deprel: advcl
# id: 6	word: you            head id: 9    head: call      deprel: nsubj
# id: 7	word: would          head id: 9    head: call      deprel: aux
# id: 8	word: not            head id: 9    head: call      deprel: advmod
# id: 9	word: call           head id: 0    head: root      deprel: root
# id: 10	word: him            head id: 9    head: call      deprel: obj
# ...
# id: 6	word: are            head id: 7    head: barbars   deprel: cop
# id: 7	word: barbars        head id: 3    head: saw       deprel: ccomp
# id: 8	word: .              head id: 3    head: saw       deprel: punct
# []
# []
# you know that Turkish people come to Greece and ask for asylum right? what' s wrong with Turkey?
# id: 1	word: you            head id: 2    head: know      deprel: nsubj
# id: 2	word: know           head id: 0    head: root      deprel: root
# id: 3	word: that           head id: 6    head: come      deprel: mark
# id: 4	word: Turkish        head id: 5    head: people    deprel: amod
# id: 5	word: people         head id: 6    head: come      deprel: nsubj
# id: 6	word: come           head id: 2    head: know      deprel: ccomp
# id: 7	word: to             head id: 8    head: Greece    deprel: case
# id: 8	word: Greece         head id: 6    head: come      deprel: obl
# id: 9	word: and            head id: 10   head: ask       deprel: cc
# id: 10	word: ask            head id: 6    head: come      deprel: conj
# id: 11	word: for            head id: 12   head: asylum    deprel: case
# id: 12	word: asylum         head id: 10   head: ask       deprel: obl
# id: 13	word: right          head id: 10   head: ask       deprel: advmod
# id: 14	word: ?              head id: 2    head: know      deprel: punct
# id: 1	word: what           head id: 0    head: root      deprel: root
# id: 2	word: '              head id: 4    head: wrong     deprel: punct
# id: 3	word: s              head id: 4    head: wrong     deprel: cop
# id: 4	word: wrong          head id: 1    head: what      deprel: nsubj
# id: 5	word: with           head id: 6    head: Turkey    deprel: case
# id: 6	word: Turkey         head id: 4    head: wrong     deprel: obl
# id: 7	word: ?              head id: 1    head: what      deprel: punct
# []
# [['Turkish_people']]
# This situation has changed little in Europe since the early 2 0 0 0 s . Why has the European Union not adopted a unified approach to asylum? Instead individual member states are left to fend for themselves and some (Italy, Greece) are struggling to cope.
# id: 1	word: This           head id: 2    head: situation deprel: det
# id: 2	word: situation      head id: 4    head: changed   deprel: nsubj
# id: 3	word: has            head id: 4    head: changed   deprel: aux
# id: 4	word: changed        head id: 0    head: root      deprel: root
# id: 5	word: little         head id: 4    head: changed   deprel: obj
# id: 6	word: in             head id: 7    head: Europe    deprel: case
# id: 7	word: Europe         head id: 4    head: changed   deprel: obl
# id: 8	word: since          head id: 14   head: 0         deprel: case
# id: 9	word: the            head id: 14   head: 0         deprel: det
# id: 10	word: early          head id: 14   head: 0         deprel: amod
# id: 11	word: 2              head id: 14   head: 0         deprel: compound
# id: 12	word: 0              head id: 14   head: 0         deprel: compound
# id: 13	word: 0              head id: 14   head: 0         deprel: compound
# id: 14	word: 0              head id: 4    head: changed   deprel: obl
# id: 15	word: s              head id: 14   head: 0         deprel: case
# id: 16	word: .              head id: 4    head: changed   deprel: punct
# id: 1	word: Why            head id: 7    head: adopted   deprel: advmod
# id: 2	word: has            head id: 7    head: adopted   deprel: aux
# id: 3	word: the            head id: 5    head: Union     deprel: det
# id: 4	word: European       head id: 5    head: Union     deprel: amod
# id: 5	word: Union          head id: 7    head: adopted   deprel: nsubj
# id: 6	word: not            head id: 7    head: adopted   deprel: advmod
# id: 7	word: adopted        head id: 0    head: root      deprel: root
# id: 8	word: a              head id: 10   head: approach  deprel: det
# id: 9	word: unified        head id: 10   head: approach  deprel: amod
# id: 10	word: approach       head id: 7    head: adopted   deprel: obj
# id: 11	word: to             head id: 12   head: asylum    deprel: case
# id: 12	word: asylum         head id: 7    head: adopted   deprel: obl
# id: 13	word: ?              head id: 7    head: adopted   deprel: punct
# id: 1	word: Instead        head id: 6    head: left      deprel: advmod
# id: 2	word: individual     head id: 4    head: states    deprel: amod
# id: 3	word: member         head id: 4    head: states    deprel: compound
# id: 4	word: states         head id: 6    head: left      deprel: nsubj:pass
# id: 5	word: are            head id: 6    head: left      deprel: aux:pass
# id: 6	word: left           head id: 0    head: root      deprel: root
# id: 7	word: to             head id: 8    head: fend      deprel: mark
# id: 8	word: fend           head id: 6    head: left      deprel: xcomp
# id: 9	word: for            head id: 10   head: themselvesdeprel: case
# id: 10	word: themselves     head id: 8    head: fend      deprel: obl
# id: 11	word: and            head id: 19   head: strugglingdeprel: cc
# id: 12	word: some           head id: 19   head: strugglingdeprel: nsubj
# id: 13	word: (              head id: 14   head: Italy     deprel: punct
# id: 14	word: Italy          head id: 12   head: some      deprel: appos
# id: 15	word: ,              head id: 16   head: Greece    deprel: punct
# id: 16	word: Greece         head id: 14   head: Italy     deprel: conj
# id: 17	word: )              head id: 14   head: Italy     deprel: punct
# id: 18	word: are            head id: 19   head: strugglingdeprel: aux
# id: 19	word: struggling     head id: 6    head: left      deprel: conj
# id: 20	word: to             head id: 21   head: cope      deprel: mark
# id: 21	word: cope           head id: 19   head: strugglingdeprel: xcomp
# id: 22	word: .              head id: 6    head: left      deprel: punct
# [['2_0'], ['0_0'], ['0_0'], ['member_changed']]
# [['early_0'], ['European_little'], ['unified_early'], ['individual_changed']]
# Visapourlimage: Today' s screening is live! The program includes the Chronological News Review for March & April '20, @ByronSmithphoto' s report Refugees in Greece, @RearickAnne' s project True West @cinque_ale work Peru, a Toxic State & more: visa po
# id: 1	word: Visapourlimage head id: 0    head: root      deprel: root
# id: 2	word: :              head id: 1    head: Visapourlimagedeprel: punct
# id: 3	word: Today          head id: 6    head: screening deprel: nmod:poss
# id: 4	word: '              head id: 3    head: Today     deprel: case
# id: 5	word: s              head id: 3    head: Today     deprel: case
# id: 6	word: screening      head id: 8    head: live      deprel: nsubj
# id: 7	word: is             head id: 8    head: live      deprel: cop
# id: 8	word: live           head id: 1    head: Visapourlimagedeprel: appos
# id: 9	word: !              head id: 1    head: Visapourlimagedeprel: punct
# id: 1	word: The            head id: 2    head: program   deprel: det
# id: 2	word: program        head id: 3    head: includes  deprel: nsubj
# id: 3	word: includes       head id: 0    head: root      deprel: root
# id: 4	word: the            head id: 7    head: Review    deprel: det
# id: 5	word: Chronological  head id: 6    head: News      deprel: compound
# id: 6	word: News           head id: 7    head: Review    deprel: compound
# id: 7	word: Review         head id: 3    head: includes  deprel: obj
# id: 8	word: for            head id: 9    head: March     deprel: case
# id: 9	word: March          head id: 7    head: Review    deprel: nmod
# id: 10	word: &              head id: 11   head: April     deprel: cc
# id: 11	word: April          head id: 9    head: March     deprel: conj
# id: 12	word: '              head id: 9    head: March     deprel: punct
# id: 13	word: 20             head id: 11   head: April     deprel: nummod
# id: 14	word: ,              head id: 20   head: Refugees  deprel: punct
# id: 15	word: @              head id: 20   head: Refugees  deprel: case
# id: 16	word: ByronSmithphotohead id: 20   head: Refugees  deprel: nmod:poss
# id: 17	word: '              head id: 20   head: Refugees  deprel: punct
# id: 18	word: s              head id: 16   head: ByronSmithphotodeprel: case
# id: 19	word: report         head id: 20   head: Refugees  deprel: compound
# id: 20	word: Refugees       head id: 3    head: includes  deprel: obl
# id: 21	word: in             head id: 22   head: Greece    deprel: case
# id: 22	word: Greece         head id: 20   head: Refugees  deprel: nmod
# id: 23	word: ,              head id: 29   head: project   deprel: punct
# id: 24	word: @              head id: 29   head: project   deprel: case
# id: 25	word: Rearick        head id: 26   head: Anne      deprel: compound
# id: 26	word: Anne           head id: 29   head: project   deprel: nmod:poss
# id: 27	word: '              head id: 26   head: Anne      deprel: case
# id: 28	word: s              head id: 26   head: Anne      deprel: case
# id: 29	word: project        head id: 3    head: includes  deprel: obl
# id: 30	word: True           head id: 34   head: Peru      deprel: amod
# id: 31	word: West           head id: 34   head: Peru      deprel: compound
# id: 32	word: @cinque_ale    head id: 34   head: Peru      deprel: compound
# id: 33	word: work           head id: 34   head: Peru      deprel: compound
# id: 34	word: Peru           head id: 29   head: project   deprel: appos
# id: 35	word: ,              head id: 38   head: State     deprel: punct
# id: 36	word: a              head id: 38   head: State     deprel: det
# id: 37	word: Toxic          head id: 38   head: State     deprel: amod
# id: 38	word: State          head id: 34   head: Peru      deprel: appos
# id: 39	word: &              head id: 40   head: more      deprel: cc
# id: 40	word: more           head id: 38   head: State     deprel: conj
# id: 41	word: :              head id: 43   head: po        deprel: punct
# id: 42	word: visa           head id: 43   head: po        deprel: compound
# id: 43	word: po             head id: 29   head: project   deprel: appos
# [['Chronological_screening'], ['News_is'], ['report_April'], ["Rearick_'"], ['West_Rearick'], ['@cinque_ale_Rearick'], ['work_Rearick'], ['visa_Peru']]
# [['True_Rearick'], ['Toxic_project']]
# er do gan can be glad if qatar give him asylum when the war between greece and turkey is over . . .
# id: 1	word: er             head id: 6    head: glad      deprel: discourse
# id: 2	word: do             head id: 6    head: glad      deprel: aux
# id: 3	word: gan            head id: 6    head: glad      deprel: nsubj
# id: 4	word: can            head id: 6    head: glad      deprel: aux
# id: 5	word: be             head id: 6    head: glad      deprel: cop
# id: 6	word: glad           head id: 0    head: root      deprel: root
# id: 7	word: if             head id: 9    head: give      deprel: mark
# id: 8	word: qatar          head id: 9    head: give      deprel: nsubj
# id: 9	word: give           head id: 6    head: glad      deprel: advcl
# id: 10	word: him            head id: 9    head: give      deprel: iobj
# id: 11	word: asylum         head id: 9    head: give      deprel: obj
# id: 12	word: when           head id: 20   head: over      deprel: mark
# id: 13	word: the            head id: 14   head: war       deprel: det
# id: 14	word: war            head id: 20   head: over      deprel: nsubj
# id: 15	word: between        head id: 16   head: greece    deprel: case
# id: 16	word: greece         head id: 14   head: war       deprel: nmod
# id: 17	word: and            head id: 18   head: turkey    deprel: cc
# id: 18	word: turkey         head id: 16   head: greece    deprel: conj
# id: 19	word: is             head id: 20   head: over      deprel: cop
# id: 20	word: over           head id: 9    head: give      deprel: advcl
# id: 21	word: .              head id: 6    head: glad      deprel: punct
# id: 1	word: .              head id: 0    head: root      deprel: root
# id: 1	word: .              head id: 0    head: root      deprel: root
# []
# []
# And your point . Were you there to check their id and where they landed first . You do realise some countries like Greece actually put refugees back in boats and set them adrift . Dont change the narrative
# id: 1	word: And            head id: 3    head: point     deprel: cc
# id: 2	word: your           head id: 3    head: point     deprel: nmod:poss
# id: 3	word: point          head id: 0    head: root      deprel: root
# id: 4	word: .              head id: 3    head: point     deprel: punct
# id: 1	word: Were           head id: 3    head: there     deprel: cop
# id: 2	word: you            head id: 3    head: there     deprel: nsubj
# id: 3	word: there          head id: 0    head: root      deprel: root
# id: 4	word: to             head id: 5    head: check     deprel: mark
# id: 5	word: check          head id: 3    head: there     deprel: xcomp
# id: 6	word: their          head id: 7    head: id        deprel: nmod:poss
# id: 7	word: id             head id: 5    head: check     deprel: obj
# id: 8	word: and            head id: 11   head: landed    deprel: cc
# id: 9	word: where          head id: 11   head: landed    deprel: mark
# id: 10	word: they           head id: 11   head: landed    deprel: nsubj
# id: 11	word: landed         head id: 5    head: check     deprel: conj
# id: 12	word: first          head id: 11   head: landed    deprel: advmod
# id: 13	word: .              head id: 3    head: there     deprel: punct
# id: 1	word: You            head id: 3    head: realise   deprel: nsubj
# id: 2	word: do             head id: 3    head: realise   deprel: aux
# id: 3	word: realise        head id: 0    head: root      deprel: root
# id: 4	word: some           head id: 5    head: countries deprel: det
# id: 5	word: countries      head id: 9    head: put       deprel: nsubj
# id: 6	word: like           head id: 7    head: Greece    deprel: case
# id: 7	word: Greece         head id: 5    head: countries deprel: nmod
# id: 8	word: actually       head id: 9    head: put       deprel: advmod
# id: 9	word: put            head id: 3    head: realise   deprel: ccomp
# id: 10	word: refugees       head id: 9    head: put       deprel: obj
# id: 11	word: back           head id: 9    head: put       deprel: advmod
# id: 12	word: in             head id: 13   head: boats     deprel: case
# id: 13	word: boats          head id: 9    head: put       deprel: obl
# id: 14	word: and            head id: 15   head: set       deprel: cc
# id: 15	word: set            head id: 9    head: put       deprel: conj
# id: 16	word: them           head id: 15   head: set       deprel: obj
# id: 17	word: adrift         head id: 15   head: set       deprel: xcomp
# id: 18	word: .              head id: 3    head: realise   deprel: punct
# id: 1	word: Dont           head id: 2    head: change    deprel: aux
# id: 2	word: change         head id: 0    head: root      deprel: root
# id: 3	word: the            head id: 4    head: narrative deprel: det
# id: 4	word: narrative      head id: 2    head: change    deprel: obj
# []
# []
# Mass migration all over . Greece . UK . Germany 95% organized men Australia.
# id: 1	word: Mass           head id: 2    head: migration deprel: amod
# id: 2	word: migration      head id: 4    head: over      deprel: nsubj
# id: 3	word: all            head id: 4    head: over      deprel: advmod
# id: 4	word: over           head id: 0    head: root      deprel: root
# id: 5	word: .              head id: 4    head: over      deprel: punct
# id: 1	word: Greece         head id: 0    head: root      deprel: root
# id: 2	word: .              head id: 1    head: Greece    deprel: punct
# id: 1	word: UK             head id: 0    head: root      deprel: root
# id: 2	word: .              head id: 1    head: UK        deprel: punct
# id: 1	word: Germany        head id: 5    head: men       deprel: compound
# id: 2	word: 95             head id: 3    head: %         deprel: nummod
# id: 3	word: %              head id: 5    head: men       deprel: compound
# id: 4	word: organized      head id: 5    head: men       deprel: amod
# id: 5	word: men            head id: 0    head: root      deprel: root
# id: 6	word: Australia      head id: 5    head: men       deprel: appos
# id: 7	word: .              head id: 5    head: men       deprel: punct
# [['Germany_.'], ['%_.']]
# [['Mass_migration'], ['organized_.']]

# %%
# %debug
# Out:
# > <ipython-input-731-c1fc653e00ae>(34)<listcomp>()
#      32             if str(phrase_head) in str(tweet) and len(phrase_head)>2:
#      33                 #print(phrase_head)
# ---> 34                 ph_words = [np_heads[i-1][1] for i in phrase_heads]
#      35                 #print(ph_words)
#      36                 for related in range(len(np_heads)):
#
# ipdb> np_heads
# [[1, 'Greeces', 0, 'root'], [2, 'overcrowded', 6, 'amod'], [3, 'Moria', 6, 'compound'], [4, 'migrant', 6, 'amod'], [5, 'camp', 6, 'compound'], [6, 'reports', 1, 'appos'], [7, 'FIRST', 9, 'amod'], [8, 'coronavirus', 9, 'amod'], [9, 'case', 6, 'appos'], [10, 'RT', 9, 'appos'], [11, 'WorldNews', 10, 'flat']]
# ipdb> len(np_heads)
# 11
# ipdb> i
# 13
# ipdb> len(phrase_heads)
# 5
# ipdb> phrase_heads
# {0, 2, 5, 8, 13}
# ipdb> q
