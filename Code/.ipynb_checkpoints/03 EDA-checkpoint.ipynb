# %% [markdown]
# # EDA

# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from ast import literal_eval

from collections import defaultdict

# %%
def get_hashtag_counts(json):
    
    # Create empty dict where values are stored
    hashtag_count = defaultdict(int)
    
    # Iterate over all tweets, retrieve their hashtags and increment the counter by one
    for tweet in json["data"]:
        try:
            hashtags = tweet["entities"]["hashtags"]
            for hashtag in hashtags:
                hashtag_count[hashtag["tag"]] +=1
        except KeyError:
            continue
            
    return hashtag_count

def get_annotation_counts(json):
    
    annotation_count = defaultdict(int)

    for tweet in json["data"]:
        try:
            annotations = tweet["entities"]["annotations"]
            for annotation in annotations:
                annotation_count[annotation["normalized_text"]] +=1
        except KeyError:
            continue
            
    return annotation_count

# %%
def get_entity_count(series):
    dict_count = defaultdict(int)
    
    for entities in series:
        for entity in entities:
            if len(entity) > 0:
                dict_count[entity] += 1
            
    return dict_count

# %%
def get_entity_count_by_interval(df,interval,entity_type):
    entity_df = pd.DataFrame()
    
    if interval == "week":
        col_name = "year_calendar_week"
    elif interval == "month":
        col_name = "year_month"
        
    entity_type = entity_type.lower()
        
    df_sorted = df.sort_values(["created_at"])
    periods = list(df_sorted[col_name].drop_duplicates())
    
    for period in periods:
        df_sliced = df[df[col_name] == period]
        entity_count = get_entity_count(df_sliced[entity_type])
        entity_count_sorted = sorted(entity_count.items(), key=lambda x: x[1], reverse=True)
        
        entity_df[period] = pd.DataFrame(entity_count_sorted[:15]).iloc[:,0]
        
    return entity_df

# %%
def group_df(df,interval):
    
    if interval == "week":
        col_name = "year_calendar_week"
    elif interval == "month":
        col_name = "year_month"
    
    
    df_grouped = df.groupby([col_name])[['refugee', 'migrant', 'immigrant', 'asylum_seeker', 'other']].sum()
    df_grouped["total"] = df_grouped.sum(axis=1)
    
    return df_grouped

# %%
def plot_event_timeline(df, interval):
    
    df_grouped = group_df(df,interval)
    
    plt.figure(figsize=(16, 8))
    plt.plot(df_grouped["total"])
    plt.title(f"Number of tweets about refugees and related groups by {interval}")
    plt.xticks(rotation=90)
    plt.show()
    
    plt.figure(figsize=(16, 8))
    plt.plot(df_grouped["refugee"], label ="refugee")
    plt.plot(df_grouped["migrant"], label ="migrant")
    plt.plot(df_grouped["immigrant"], label ="immigrant")
    plt.plot(df_grouped["asylum_seeker"], label ="asylum seeker")
    plt.plot(df_grouped["other"], label ="other")
    plt.title(f"Grouped number of tweets about refugees and related groups by {interval}")
    plt.xticks(rotation=90)
    plt.legend()
    plt.show()

# %%
def plot_entity_timeline(df, interval, entity_list, entity_type):
    
    plt.figure(figsize=(16, 8))
    
    if interval == "week":
        col_name = "year_calendar_week"
    elif interval == "month":
        col_name = "year_month"    
    
    #df_to_plot = pd.DataFrame()
    df_to_plot = pd.DataFrame(index=df[col_name].drop_duplicates().values)
    
    #for entity in entity_list:
    #    
    #    df_entity = df[df[entity_type].apply(lambda x: element_in_list(x,[entity]))]
    #    df_grouped = group_df(df_entity,interval)
    #    plt.plot(df_grouped["total"], label = entity)
    
    for entity in entity_list:
        df_entity = df[df[entity_type].apply(lambda x: element_in_list(x,[entity]))]
        df_grouped = group_df(df_entity,interval)["total"]
        df_to_plot[entity] = df_grouped
    
    plt.plot(df_to_plot)
    
    plt.xticks(rotation=90)
    plt.legend(df_to_plot.columns)
    plt.show()

# %%
def filter_by_keywords(string, keywords):
    keywords_joined = " ".join(keywords)
    return any(word in string for word in keywords_joined)

# %%
def hashtag_check(df,entity_list,entity_type):
    plot_entity_timeline(df,"week",entity_list,entity_type)
    
    for entity in entity_list:
        df_entity = df[df[entity_type].apply(lambda x: element_in_list(x,[entity]))]

        hashtag_count = get_entity_count(df_entity[entity_type])
        hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)

        for hashtag,count in hashtag_count_sorted[:15]:
            print(hashtag,count)
        print("\n------------------------------------------\n")

# %%
def element_in_list(entities,qualifiers):

    return not(bool(set(entities).isdisjoint(set(qualifiers))))

# %%
# Read the tweets csv
df_tweets = pd.read_csv(r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data\df_tweets.csv",
                        converters={"hashtags": lambda x: x.strip("[]").replace("'","").split(", "),
                                    "mentions": lambda x: x.strip("[]").replace("'","").split(", "),
                                    "annotations": lambda x: x.strip("[]").replace("'","").split(", ")})

# Drop unnecessary index column
df_tweets.drop("Unnamed: 0", axis=1, inplace=True)

# Rename columns
#df_tweets = df_tweets.rename(columns={'public_metrics.retweet_count': 'retweet_count',
#                                      'public_metrics.reply_count': 'reply_count',
#                                      'public_metrics.like_count': 'like_count',
#                                      'public_metrics.quote_count': 'quote_count'})
df_tweets.head()
# Out:
#                 source                                               text  \
# 0  Twitter for Android  There are too many reliable reports and first-...
# 1      Twitter Web App  Despite repeated requests, @Refugees and other...
# 2  Twitter for Android  “When the air bombing and the attacks began, I...
# 3      Twitter Web App  "ongoing insecurity &amp; allegations of grave...
# 4   Twitter for iPhone  MOTHER \n\nMother, I do not cry who cries, \nm...
#
#   lang                   id                created_at            author_id  \
# 0   en  1350390669043499013  2021-01-16T10:33:19.000Z  1327278886380515328
# 1   en  1350390657576300544  2021-01-16T10:33:16.000Z  1323903491044188161
# 2   en  1350390643986599937  2021-01-16T10:33:13.000Z  1324130252008816640
# 3   en  1350390618695020546  2021-01-16T10:33:07.000Z           1112761003
# 4   en  1350390607928295424  2021-01-16T10:33:04.000Z  1212824799107375105
#
#    retweet_count  reply_count  like_count  quote_count  \
# 0              1            0           0            0
# 1              0            0           0            0
# 2              0            0           1            0
# 3              0            0           0            0
# 4              0            1           0            0
#
#                                             hashtags  \
# 0  [eritrea, bidentakeaction, stopwarontigray, ti...
# 1  [tigray, stopwarontigray, tigraygenocide, bide...
# 2                                  [bidentakeaction]
# 3     [tigraygenocide, bidenactnow, protectrefugees]
# 4                                                 []
#
#                                             mentions          annotations
# 0                                         [joebiden]                   []
# 1                           [refugees, un, joebiden]  [shimelba, hitsats]
# 2          [joebiden, kamalaharris, yohannesabraham]                   []
# 3  [un, joebiden, eu_commission, refugees, josepb...            [eritrea]
# 4                                                 []                   []

# %%
df_tweets["text_clean"] = df_tweets["text"].apply(lambda x: x.lower().replace("#","").replace("@",""))

# %%
df_tweets = df_tweets.sort_values(by="created_at")

# %%
df_tweets.head()
# Out:
#                      source  \
# 2288193           TweetDeck
# 2288192           TweetDeck
# 2288190         True Anthem
# 2288191  Twitter for iPhone
# 2288189             dlvr.it
#
#                                                       text lang  \
# 2288193  Along the miles-long Minneapolis street where ...   en
# 2288192  Through exhibits and initiatives, here's how @...   en
# 2288190  .@SelenaGomez surprised grads and their famili...   en
# 2288191  @powrdragn My wife now works at a large school...   en
# 2288189  Illegal migrants could be treated leniently if...   en
#
#                           id                created_at           author_id  \
# 2288193  1267244468564045829  2020-06-01T00:00:00.000Z            27987151
# 2288192  1267244469021278209  2020-06-01T00:00:00.000Z  875113940866486272
# 2288190  1267244475514007560  2020-06-01T00:00:01.000Z            27891216
# 2288191  1267244473337229312  2020-06-01T00:00:01.000Z            99735089
# 2288189  1267244478449905664  2020-06-01T00:00:02.000Z           986750503
#
#          retweet_count  reply_count  like_count  quote_count  \
# 2288193              0            0           1            0
# 2288192              1            0           3            0
# 2288190              0            0           0            0
# 2288191              0            0           0            0
# 2288189              1            0           0            0
#
#                           hashtags                     mentions  \
# 2288193                         []                           []
# 2288192                         []  [nyhistory, tenementmuseum]
# 2288190                         []                [selenagomez]
# 2288191                         []                  [powrdragn]
# 2288189  [trafficking, slavetrade]                           []
#
#               annotations                                         text_clean
# 2288193     [minneapolis]  along the miles-long minneapolis street where ...
# 2288192                []  through exhibits and initiatives, here's how n...
# 2288190                []  .selenagomez surprised grads and their familie...
# 2288191        [columbus]  powrdragn my wife now works at a large school ...
# 2288189  [rob richardson]  illegal migrants could be treated leniently if...

# %% [markdown]
# ### Most frequent hashtags, mentions, and annotations

# %%
hashtag_count = get_entity_count(df_tweets["hashtags"])
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 75317),
#  ('tigraygenocide', 72300),
#  ('tigray', 61415),
#  ('covid19', 52651),
#  ('s386', 38500),
#  ('stopwarontigray', 33835),
#  ('migrants', 33357),
#  ('immigrants', 32076),
#  ('ethiopia', 26012),
#  ('immigration', 25445),
#  ('refugee', 23878),
#  ('iraqi_refugees_look_for_homeland', 23353),
#  ('dv2020', 20562),
#  ('dv2021', 20269),
#  ('worldrefugeeday', 17910),
#  ('unblocks386', 17321),
#  ('refugeeswelcome', 16179),
#  ('passs386', 13673),
#  ('eritrea', 13287),
#  ('allowaccesstotigray', 13147),
#  ('immigrant', 12955),
#  ('passhr1044', 12900),
#  ('sudan', 12234),
#  ('migration', 12084),
#  ('standwithiraqirefugees', 11995)]

# %%
mention_count = get_entity_count(df_tweets["mentions"])
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:25]
# Out:
# [('realdonaldtrump', 145428),
#  ('refugees', 129576),
#  ('joebiden', 95065),
#  ('pritipatel', 84930),
#  ('un', 66752),
#  ('potus', 62046),
#  ('nigel_farage', 60651),
#  ('change', 48592),
#  ('borisjohnson', 40016),
#  ('kamalaharris', 36178),
#  ('hrw', 31772),
#  ('senatordurbin', 30059),
#  ('vp', 26087),
#  ('unhumanrights', 25801),
#  ('senrickscott', 24826),
#  ('amnesty', 24228),
#  ('youtube', 23672),
#  ('filippograndi', 23551),
#  ('eu_commission', 23530),
#  ('repzoelofgren', 22316),
#  ('cnn', 22062),
#  ('skynews', 21293),
#  ('aoc', 20592),
#  ('ukhomeoffice', 18801),
#  ('abiyahmedali', 18796)]

# %%
annotation_count = get_entity_count(df_tweets["annotations"])
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:25]
# Out:
# [('trump', 418727),
#  ('us', 224256),
#  ('uk', 217712),
#  ('america', 199747),
#  ('biden', 156215),
#  ('france', 95267),
#  ('turkey', 91664),
#  ('canada', 90024),
#  ('europe', 89927),
#  ('u.s.', 81832),
#  ('india', 73542),
#  ('americans', 70829),
#  ('usa', 69697),
#  ('obama', 63827),
#  ('mexico', 56439),
#  ('china', 55380),
#  ('eu', 53286),
#  ('germany', 52830),
#  ('britain', 44080),
#  ('greece', 41866),
#  ('united states', 41590),
#  ('democrats', 41420),
#  ('australia', 39665),
#  ('god', 38349),
#  ('sudan', 36979)]

# %% [markdown]
# ### Add additional date columns (Year, Month, Calendar Week, etc)

# %%
df_tweets["created_at"] = pd.to_datetime(df_tweets["created_at"])

# %%
str(df_tweets["created_at"].dt.year[0])
# Out:
# '2021'

# %%
df_tweets["year"] = df_tweets["created_at"].dt.year.astype(str)
df_tweets["calendar_week"] = df_tweets["created_at"].apply(lambda x: x.strftime("%W")) #Monday considered as first day of the week
df_tweets["year_month"] = df_tweets["year"] + "_" + df_tweets["created_at"].dt.month.astype(str)
df_tweets["year_calendar_week"] = df_tweets["year"] + "_" + df_tweets["calendar_week"]

# %%
df_tweets.head()
# Out:
#                      source  \
# 2288193           TweetDeck
# 2288192           TweetDeck
# 2288190         True Anthem
# 2288191  Twitter for iPhone
# 2288189             dlvr.it
#
#                                                       text lang  \
# 2288193  Along the miles-long Minneapolis street where ...   en
# 2288192  Through exhibits and initiatives, here's how @...   en
# 2288190  .@SelenaGomez surprised grads and their famili...   en
# 2288191  @powrdragn My wife now works at a large school...   en
# 2288189  Illegal migrants could be treated leniently if...   en
#
#                           id                created_at           author_id  \
# 2288193  1267244468564045829 2020-06-01 00:00:00+00:00            27987151
# 2288192  1267244469021278209 2020-06-01 00:00:00+00:00  875113940866486272
# 2288190  1267244475514007560 2020-06-01 00:00:01+00:00            27891216
# 2288191  1267244473337229312 2020-06-01 00:00:01+00:00            99735089
# 2288189  1267244478449905664 2020-06-01 00:00:02+00:00           986750503
#
#          retweet_count  reply_count  like_count  quote_count  \
# 2288193              0            0           1            0
# 2288192              1            0           3            0
# 2288190              0            0           0            0
# 2288191              0            0           0            0
# 2288189              1            0           0            0
#
#                           hashtags                     mentions  \
# 2288193                         []                           []
# 2288192                         []  [nyhistory, tenementmuseum]
# 2288190                         []                [selenagomez]
# 2288191                         []                  [powrdragn]
# 2288189  [trafficking, slavetrade]                           []
#
#               annotations                                         text_clean  \
# 2288193     [minneapolis]  along the miles-long minneapolis street where ...
# 2288192                []  through exhibits and initiatives, here's how n...
# 2288190                []  .selenagomez surprised grads and their familie...
# 2288191        [columbus]  powrdragn my wife now works at a large school ...
# 2288189  [rob richardson]  illegal migrants could be treated leniently if...
#
#          year calendar_week year_month year_calendar_week
# 2288193  2020            22     2020_6            2020_22
# 2288192  2020            22     2020_6            2020_22
# 2288190  2020            22     2020_6            2020_22
# 2288191  2020            22     2020_6            2020_22
# 2288189  2020            22     2020_6            2020_22

# %%
#df_tweets["refugee"] = df_tweets["text"].apply(lambda x: ("refugee" or "refugees") in x.lower().split(" "))
#df_tweets["migrant"] = df_tweets["text"].apply(lambda x: ("migrant" or "migrants") in x.lower().split(" "))
#df_tweets["immigrant"] = df_tweets["text"].apply(lambda x: ("immigrant" or "immigrants") in x.lower().split(" "))
#df_tweets["asylum_seeker"] = df_tweets["text"].apply(lambda x: ("asylum" and ("seeker" or "seekers")) in x.lower().split(" "))
#df_tweets["other"] = df_tweets["text"].apply(lambda x: (("displaced" or "stateless") and ("people" or "person" or "persons")) in x.lower().split(" "))
# -----------------
#df_tweets["refugee"] = df_tweets["text"].apply(lambda x: element_in_list(x.lower().split(" "),["refugee","refugees"]))
#df_tweets["migrant"] = df_tweets["text"].apply(lambda x: element_in_list(x.lower().split(" "),["migrant","migrants"]))
#df_tweets["immigrant"] = df_tweets["text"].apply(lambda x: element_in_list(x.lower().split(" "),["immigrant","immigrants"]))
#df_tweets["asylum_seeker"] = df_tweets["text"].apply(lambda x: element_in_list(x.lower().split(" "),["asylum"]) and  element_in_list(x.lower().split(" "),["seeker","seekers"]))
#df_tweets["other"] = df_tweets["text"].apply(lambda x: element_in_list(x.lower().split(" "),["displaced","stateless"]) and  element_in_list(x.lower().split(" "),["people","person","persons"]))

# %%
df_tweets["refugee"] = df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),["refugee","refugees"]))
df_tweets["migrant"] = df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),["migrant","migrants"]))
df_tweets["immigrant"] = df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),["immigrant","immigrants"]))
df_tweets["asylum_seeker"] = df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),["asylum"]) and  element_in_list(x.split(" "),["seeker","seekers"]))
df_tweets["other"] = df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),["displaced","stateless"]) and  element_in_list(x.split(" "),["people","person","persons"]))

# %%
check = df_tweets[(df_tweets["refugee"] == False) & (df_tweets["migrant"] == False) & (df_tweets["immigrant"] == False) & (df_tweets["asylum_seeker"] == False) & (df_tweets["other"] == False)]
check.shape
# there are still almost 2,000,000 tweets that contain neither of the keywords, this is because the keywords are heading the article to which those tweets link
# Out:
# (1842493, 23)

# %%
sum(df_tweets["refugee"]) + sum(df_tweets["migrant"]) + sum(df_tweets["immigrant"]) + sum(df_tweets["asylum_seeker"]) + sum(df_tweets["other"])
# Out:
# 5116251

# %%
df_tweets.head()
# Out:
#                      source  \
# 2288193           TweetDeck
# 2288192           TweetDeck
# 2288190         True Anthem
# 2288191  Twitter for iPhone
# 2288189             dlvr.it
#
#                                                       text lang  \
# 2288193  Along the miles-long Minneapolis street where ...   en
# 2288192  Through exhibits and initiatives, here's how @...   en
# 2288190  .@SelenaGomez surprised grads and their famili...   en
# 2288191  @powrdragn My wife now works at a large school...   en
# 2288189  Illegal migrants could be treated leniently if...   en
#
#                           id                created_at           author_id  \
# 2288193  1267244468564045829 2020-06-01 00:00:00+00:00            27987151
# 2288192  1267244469021278209 2020-06-01 00:00:00+00:00  875113940866486272
# 2288190  1267244475514007560 2020-06-01 00:00:01+00:00            27891216
# 2288191  1267244473337229312 2020-06-01 00:00:01+00:00            99735089
# 2288189  1267244478449905664 2020-06-01 00:00:02+00:00           986750503
#
#          retweet_count  reply_count  like_count  quote_count  ...  \
# 2288193              0            0           1            0  ...
# 2288192              1            0           3            0  ...
# 2288190              0            0           0            0  ...
# 2288191              0            0           0            0  ...
# 2288189              1            0           0            0  ...
#
#                                                 text_clean  year  \
# 2288193  along the miles-long minneapolis street where ...  2020
# 2288192  through exhibits and initiatives, here's how n...  2020
# 2288190  .selenagomez surprised grads and their familie...  2020
# 2288191  powrdragn my wife now works at a large school ...  2020
# 2288189  illegal migrants could be treated leniently if...  2020
#
#         calendar_week year_month year_calendar_week refugee migrant immigrant  \
# 2288193            22     2020_6            2020_22   False    True     False
# 2288192            22     2020_6            2020_22   False   False      True
# 2288190            22     2020_6            2020_22   False   False     False
# 2288191            22     2020_6            2020_22   False   False     False
# 2288189            22     2020_6            2020_22   False    True     False
#
#          asylum_seeker  other
# 2288193          False  False
# 2288192          False  False
# 2288190          False  False
# 2288191          False  False
# 2288189          False  False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Frequency of Tweets over Time (also seperated by refugee/migrant/etc.)

# %%
df_tweets_by_week = group_df(df_tweets,"week")
df_tweets_by_week.head()
# Out:
#                     refugee  migrant  immigrant  asylum_seeker  other   total
# year_calendar_week
# 2020_22               28795    57077      72667           3795   1659  163993
# 2020_23               28516    42250      53033           3867   1440  129106
# 2020_24               66333    32267      65138           8730   3285  175753
# 2020_25               41702    33287      61632          14703   1557  152881
# 2020_26               30956    25432      56617           5417   1492  119914

# %%
plot_event_timeline(df_tweets,"week")

# %% [markdown]
# ### Most frequent entities per month

# %%
get_entity_count_by_interval(df_tweets[df_tweets["refugee"]],"month","hashtags")
# Out:
#                     2020_6                  2020_7                  2020_8  \
# 0          worldrefugeeday                refugees                refugees
# 1                 refugees                 covid19         refugeeswelcome
# 2                  covid19                 refugee                 refugee
# 3          refugeeweek2020  standwithiraqirefugees                 covid19
# 4                  refugee             yemencrisis                   unhcr
# 5              yemencrisis                rohingya                malaysia
# 6      palestinianrefugees             humanrights  standwithiraqirefugees
# 7        deportallrefugees    karabakhisazerbaijan                    help
# 8             withrefugees                   syria                   peace
# 9   sendbackafghanrefugees                  auspol                children
# 10  standwithiraqirefugees             coronavirus                rohingya
# 11             refugeeweek  stoparmenianoccupation               community
# 12     worldrefugeeday2020           7yearstoolong                migrants
# 13                rohingya                gameover                    love
# 14         refugeeswelcome                  turkey             swedenriots
#
#                               2020_9                           2020_10  \
# 0                           refugees                          refugees
# 1                   stopicetransfers                           armenia
# 2   iraqi_refugees_look_for_homeland                           refugee
# 3                                bjp                           artsakh
# 4                            refugee                               bjp
# 5                              moria              karabakhisazerbaijan
# 6                            covid19  iraqi_refugees_look_for_homeland
# 7                             greece            stoparmenianaggression
# 8                    refugeeswelcome                   refugeeswelcome
# 9                           rohingya                dontbelievearmenia
# 10                            lesbos                        azerbaijan
# 11                                eu                          karabakh
# 12     لاجئيين_عراقيين_يبحثون_عن_وطن                           covid19
# 13                          migrants                  armenianfoodbank
# 14                   sabraandshatila            stoparmenianoccupation
#
#                              2020_11                           2020_12  \
# 0                           refugees                            tigray
# 1                             tigray                   stopwarontigray
# 2                           ethiopia                          refugees
# 3                    stopwarontigray                          ethiopia
# 4                            refugee                    tigraygenocide
# 5                     tigraygenocide                             sudan
# 6   iraqi_refugees_look_for_homeland                   protectrefugees
# 7                           stopabiy                          stopabiy
# 8                              sudan                           refugee
# 9                            armenia                           eritrea
# 10                           covid19  iraqi_refugees_look_for_homeland
# 11                             legal                          rohingya
# 12                        azerbaijan                          eritrean
# 13                               bjp                   reconnecttigray
# 14                             syria                               war
#
#                               2021_1                             2021_2
# 0                     tigraygenocide                     tigraygenocide
# 1                             tigray                             tigray
# 2                        bidenactnow                allowaccesstotigray
# 3                    stopwarontigray                   unityforethiopia
# 4                           refugees                           refugees
# 5                           ethiopia                     shameonamnesty
# 6                    bidentakeaction                               tplf
# 7                            eritrea                           ethiopia
# 8                         unscactnow             getethiopianfactsright
# 9   iraqi_refugees_look_for_homeland  tigraiopen4humanitarianassistance
# 10                             sudan               uplifttigraiethiopia
# 11                           refugee                         unscactnow
# 12                eritreaoutoftigray                            eritrea
# 13                               blm                        tigrayfacts
# 14                            famine               stoptheliehelptigrai

# %%
df_hashtags_month = get_entity_count_by_interval(df_tweets,"month","hashtags")
df_hashtags_month
# Out:
#                  2020_6                       2020_7  \
# 0       worldrefugeeday                         s386
# 1               covid19                     passs386
# 2              refugees                      covid19
# 3              migrants      durbinliesimmigrantsdie
# 4       refugeeweek2020                     refugees
# 5           immigration                   immigrants
# 6      blacklivesmatter                  immigration
# 7                  s386                  unblocks386
# 8            immigrants  immigrantsdiewhendurbinlies
# 9               refugee                     migrants
# 10                 daca                    migration
# 11            migration                      refugee
# 12    deportallrefugees                  humanrights
# 13          coronavirus                  coronavirus
# 14  palestinianrefugees                    mignation
#
#                          2020_8                            2020_9  \
# 0                      refugees                          refugees
# 1                       covid19                        s386isfair
# 2                      migrants                rickcantonesescott
# 3                   unblocks386                           covid19
# 4                          s386                              s386
# 5               refugeeswelcome  iraqi_refugees_look_for_homeland
# 6   immigrantsdiewhendurbinlies                          migrants
# 7                    immigrants                             moria
# 8    durbinfightsoutsourcerslie                  stopicetransfers
# 9                  webackdurbin                       unblocks386
# 10                      refugee                            greece
# 11                  immigration                        immigrants
# 12                        unhcr                   refugeeswelcome
# 13                           uk                               bjp
# 14                       brexit                           refugee
#
#                              2020_10                           2020_11  \
# 0                           refugees                          refugees
# 1                            armenia                            tigray
# 2                            covid19                           covid19
# 3                            artsakh                        immigrants
# 4                           migrants                   stopwarontigray
# 5                         immigrants                          ethiopia
# 6                        debates2020  iraqi_refugees_look_for_homeland
# 7   iraqi_refugees_look_for_homeland                          migrants
# 8                        immigration                    tigraygenocide
# 9                            refugee                       immigration
# 10              karabakhisazerbaijan                           refugee
# 11                       unblocks386                              s386
# 12                          genocide                       unblocks386
# 13                              s386                         immigrant
# 14                               war                          stopabiy
#
#                              2020_12                            2021_1  \
# 0                             tigray                    tigraygenocide
# 1                    stopwarontigray                            tigray
# 2                         passhr1044                   stopwarontigray
# 3                           refugees                       bidenactnow
# 4                           ethiopia                            dv2021
# 5                     hr1044good4usa                            dv2020
# 6                     tigraygenocide                   bidentakeaction
# 7                     hr1044mustpass                          ethiopia
# 8                    keepyourpromise                          refugees
# 9                              sudan                             noban
# 10                          stopabiy  iraqi_refugees_look_for_homeland
# 11                   protectrefugees                           eritrea
# 12                           covid19                        familyvisa
# 13                           eritrea                           covid19
# 14  iraqi_refugees_look_for_homeland                        immigrants
#
#                               2021_2
# 0                     tigraygenocide
# 1                             tigray
# 2                allowaccesstotigray
# 3                             dv2020
# 4                             dv2021
# 5                            pp10014
# 6                           refugees
# 7                   unityforethiopia
# 8                               tplf
# 9                           ethiopia
# 10                    shameonamnesty
# 11                        immigrants
# 12                           eritrea
# 13  iraqi_refugees_look_for_homeland
# 14            getethiopianfactsright

# %%
df_mentions_month = get_entity_count_by_interval(df_tweets,"month","mentions")
df_mentions_month
# Out:
#              2020_6           2020_7           2020_8           2020_9  \
# 0            change  realdonaldtrump       pritipatel  realdonaldtrump
# 1   realdonaldtrump    senatordurbin     nigel_farage     senrickscott
# 2          refugees              dnc  realdonaldtrump       pritipatel
# 3      nigel_farage       dncwarroom     borisjohnson      garylineker
# 4        pritipatel         refugees          skynews         refugees
# 5          sonusood     nigel_farage         refugees     nigel_farage
# 6     senatordurbin       pritipatel         joebiden    chrishartline
# 7      narendramodi           change      bettemidler     borisjohnson
# 8      borisjohnson         joebiden    senatordurbin         joebiden
# 9          joebiden    iamjohnoliver   benandjerrysuk           change
# 10               un     borisjohnson     kamalaharris          youtube
# 11   marcomendicino        goyafoods              lbc     ukhomeoffice
# 12         ukchange          youtube     ukhomeoffice          skynews
# 13          skynews              cnn          bbcnews     narendramodi
# 14         pmoindia               un      piersmorgan               un
#
#             2020_10          2020_11          2020_12         2021_1  \
# 0   realdonaldtrump  realdonaldtrump         refugees       joebiden
# 1          joebiden         refugees    repzoelofgren       refugees
# 2          refugees         joebiden               un             un
# 3        pritipatel       pritipatel       senmikelee   kamalaharris
# 4    laurenwitzkede     kamalaharris  realdonaldtrump          potus
# 5            flotus               un              hrw       ablinken
# 6                un              hrw           unocha       lindat_g
# 7      senrickscott    unhumanrights         joebiden     pritipatel
# 8           youtube     borisjohnson    filippograndi             vp
# 9      borisjohnson     abiyahmedali     abiyahmedali  unhumanrights
# 10     kamalaharris          amnesty    unreliefchief            hrw
# 11      garylineker     nigel_farage    unhumanrights   abiyahmedali
# 12     ukhomeoffice     senrickscott          kenroth    alimayorkas
# 13          nbcnews              aoc          eu_echo   nigel_farage
# 14    speakerpelosi    filippograndi    janezlenarcic           usun
#
#            2021_2
# 0           potus
# 1        refugees
# 2              vp
# 3              un
# 4      secblinken
# 5         amnesty
# 6        joebiden
# 7   eu_commission
# 8             hrw
# 9     alimayorkas
# 10  unhumanrights
# 11      statedept
# 12  filippograndi
# 13     pritipatel
# 14  justintrudeau

# %%
df_annotations_month = get_entity_count_by_interval(df_tweets,"month","annotations")
df_annotations_month
# Out:
#            2020_6         2020_7   2020_8     2020_9    2020_10    2020_11  \
# 0           trump          trump       uk      trump      trump      trump
# 1              us             us    trump         uk         us         us
# 2         america        america   france         us    america    america
# 3              uk             uk       us    america         uk      biden
# 4           india         canada  america     europe      biden         uk
# 5          turkey         turkey   europe     greece     france     europe
# 6          canada           u.s.  britain     turkey       u.s.     canada
# 7          europe            usa       eu     france      obama      obama
# 8            u.s.          india   turkey     canada     canada     turkey
# 9   supreme court      americans   canada         eu     europe      sudan
# 10            usa         europe    india       u.s.     turkey     france
# 11          china  united states  germany      biden     mexico       u.s.
# 12      americans          china    obama      india  americans  americans
# 13          obama          obama   greece  americans      india        usa
# 14       pakistan         france      usa    germany        usa     mexico
#
#      2020_12     2021_1     2021_2
# 0      trump      trump      biden
# 1         us      biden      trump
# 2         uk         us         us
# 3    america    america    america
# 4      sudan         uk         uk
# 5     turkey     tigray     mexico
# 6     canada  americans       u.s.
# 7    germany     turkey     tigray
# 8   ethiopia       u.s.   ethiopia
# 9      biden        usa      texas
# 10    tigray     canada  americans
# 11    europe      sudan     turkey
# 12    france   ethiopia    eritrea
# 13     india     mexico        usa
# 14      u.s.     europe     canada

# %% [markdown]
# ### Most frequent entities per week

# %%
df_hashtags_week = get_entity_count_by_interval(df_tweets,"week","hashtags")
df_hashtags_week
# Out:
#              2020_22                2020_23                 2020_24  \
# 0            covid19                covid19         worldrefugeeday
# 1   blacklivesmatter               refugees                refugees
# 2           migrants               migrants         refugeeweek2020
# 3           refugees       blacklivesmatter                 covid19
# 4     migrantworkers            immigration     palestinianrefugees
# 5        coronavirus                   s386                    daca
# 6        immigration            coronavirus            withrefugees
# 7          migration              migration             yemencrisis
# 8         immigrants             immigrants             refugeeweek
# 9               s386   patientsnotpassports     worldrefugeeday2020
# 10          sonusood         migrantworkers                 refugee
# 11             naksa  bengalrejectsamitshah              refugeeday
# 12         mignation              mignation             immigration
# 13           migrant      शर्म_करो_अमित_शाह  standwithiraqirefugees
# 14           refugee                refugee                migrants
#
#                    2020_25                     2020_26      2020_27  \
# 0        deportallrefugees                     covid19      covid19
# 1   sendbackafghanrefugees                    refugees     refugees
# 2                  covid19                        s386  immigration
# 3                 refugees                 yemencrisis   immigrants
# 4              immigration                 immigration         s386
# 5                     s386                  immigrants        india
# 6               immigrants                    migrants     migrants
# 7                 migrants                   migration    migration
# 8   standwithiraqirefugees  deportallrefugeesfromsindh    mignation
# 9                migration                     refugee      refugee
# 10         worldrefugeeday      standwithiraqirefugees      migrant
# 11             coronavirus                   mignation   abolishice
# 12                 refugee                hamiltonfilm   bangladesh
# 13               mignation                 coronavirus  coronavirus
# 14               immigrant                   hamilfilm  boycottgoya
#
#                    2020_28                  2020_29  \
# 0                  covid19                     s386
# 1     karabakhisazerbaijan                 passs386
# 2                 refugees  durbinliesimmigrantsdie
# 3              humanrights                  covid19
# 4                     osce                 refugees
# 5   stoparmenianoccupation              immigration
# 6              immigration               immigrants
# 7   stoparmenianaggression                    trump
# 8               immigrants                migration
# 9                 migrants              freethemall
# 10                    s386                 migrants
# 11               ireli2020                  refugee
# 12               migration                mignation
# 13                 refugee                      gop
# 14             coronavirus                    putin
#
#                         2020_30                     2020_31  ...  \
# 0   immigrantsdiewhendurbinlies                     covid19  ...
# 1                   unblocks386                    refugees  ...
# 2                          s386                    migrants  ...
# 3    durbinfightsoutsourcerslie                        s386  ...
# 4                  webackdurbin             refugeeswelcome  ...
# 5                       covid19                  immigrants  ...
# 6                      refugees                webackdurbin  ...
# 7                      passs386  durbinfightsoutsourcerslie  ...
# 8                    immigrants                 immigration  ...
# 9                      migrants           immigrationnation  ...
# 10            করোনায়ব্যর্থমমতা                      brexit  ...
# 11                  immigration                     refugee  ...
# 12                      refugee                     lebanon  ...
# 13          hbdrealherosonusood                      beirut  ...
# 14                  freethemall                  lifttheban  ...
#
#                              2020_52                           2021_00  \
# 0                    stopwarontigray                    tigraygenocide
# 1                     tigraygenocide                            tigray
# 2                             tigray                   stopwarontigray
# 3                           ethiopia                          ethiopia
# 4                           refugees                            dv2021
# 5                           stopabiy                          djibouti
# 6                         opentigray                               blm
# 7                        warontigray                         ethiopian
# 8                            eritrea                          refugees
# 9                                blm  iraqi_refugees_look_for_homeland
# 10  iraqi_refugees_look_for_homeland                            dv2020
# 11                           covid19                        immigrants
# 12                   protectrefugees                             noban
# 13                        immigrants                         alnejashi
# 14                           refugee                         immigrant
#
#                              2021_01                           2021_02  \
# 0                     tigraygenocide                    tigraygenocide
# 1                             tigray                            tigray
# 2                    stopwarontigray                   bidentakeaction
# 3                           ethiopia                            dv2021
# 4                           refugees                            dv2020
# 5   iraqi_refugees_look_for_homeland                       bidenactnow
# 6                            eritrea                             noban
# 7                              sudan                   stopwarontigray
# 8                                blm                        familyvisa
# 9                             famine                          refugees
# 10                           covid19                           eritrea
# 11              humanitariancorridor                          ethiopia
# 12                        immigrants  iraqi_refugees_look_for_homeland
# 13                    risingethiopia                           covid19
# 14                          migrants                             sudan
#
#                              2021_03                           2021_04  \
# 0                     tigraygenocide                    tigraygenocide
# 1                        bidenactnow                            dv2020
# 2                             tigray                            dv2021
# 3                         unscactnow                       bidenactnow
# 4                    bidentakeaction                          refugees
# 5                           refugees                            tigray
# 6                 eritreaoutoftigray  iraqi_refugees_look_for_homeland
# 7                             dv2020                     trudeauactnow
# 8   iraqi_refugees_look_for_homeland                   stopwarontigray
# 9                           ethiopia                           pp10014
# 10                           eritrea                           covid19
# 11                        immigrants                        immigrants
# 12                            dv2021                          migrants
# 13                             noban                           eritrea
# 14                            isaias                           refugee
#
#                               2021_05                2021_06  \
# 0                      tigraygenocide         tigraygenocide
# 1                              tigray                 dv2020
# 2                 allowaccesstotigray    allowaccesstotigray
# 3                              dv2020                 dv2021
# 4                            ethiopia                pp10014
# 5                             pp10014                 tigray
# 6                              dv2021               refugees
# 7   tigraiopen4humanitarianassistance      100daysofgenocide
# 8                uplifttigraiethiopia         tigraycantwait
# 9                          unscactnow             immigrants
# 10               stoptheliehelptigrai                  noban
# 11                      trudeauactnow  boycottethiopianroses
# 12                 eritreaoutoftigray                   tplf
# 13                           refugees         tplfisthecause
# 14                   unityforethiopia  nomorerefugeesinsindh
#
#                              2021_07                 2021_08
# 0                     tigraygenocide          shameonamnesty
# 1                             tigray          tigraygenocide
# 2                             dv2021        unityforethiopia
# 3                             dv2020                    tplf
# 4                            pp10014                  tigray
# 5                allowaccesstotigray  amnestyusedtplfsources
# 6                           refugees                refugees
# 7                  savediversityvisa          tplfisthecause
# 8             getethiopianfactsright  getethiopianfactsright
# 9              drabiygovistryinghard             tigrayfacts
# 10                       tigrayfacts           letusbacktonz
# 11  iraqi_refugees_look_for_homeland        fakeaxummassacre
# 12           whatshappeninginmyanmar                ethiopia
# 13                        immigrants                 eritrea
# 14                              tplf        sanctionethiopia
#
# [15 rows x 40 columns]

# %%
df_mentions_week = get_entity_count_by_interval(df_tweets,"week","mentions")
df_mentions_week
# Out:
#             2020_22          2020_23          2020_24          2020_25  \
# 0            change           change         refugees  realdonaldtrump
# 1   realdonaldtrump  realdonaldtrump  realdonaldtrump     nigel_farage
# 2          sonusood         refugees           change         refugees
# 3          refugees       pritipatel   marcomendicino       pritipatel
# 4          ukchange         sonusood               un     borisjohnson
# 5      nigel_farage     narendramodi         joebiden           change
# 6        pritipatel         amitshah    senatordurbin          skynews
# 7      narendramodi    senatordurbin       pritipatel    senatordurbin
# 8          pmoindia     borisjohnson     borisjohnson         joebiden
# 9         cdnchange      rahulgandhi     narendramodi          nytimes
# 10    senatordurbin         pmoindia     nigel_farage               un
# 11      rahulgandhi      matthancock      refugeeweek   nicolasturgeon
# 12     borisjohnson       38_degrees    filippograndi     narendramodi
# 13   arvindkejriwal      unhcrcanada        mattgaetz       whitehouse
# 14         amitshah              cnn          skynews    breitbartnews
#
#             2020_26          2020_27          2020_28          2020_29  \
# 0   realdonaldtrump  realdonaldtrump  realdonaldtrump    senatordurbin
# 1            change           change     nigel_farage              dnc
# 2          refugees        goyafoods         refugees       dncwarroom
# 3        pritipatel         refugees       pritipatel  realdonaldtrump
# 4          joebiden         joebiden    senatordurbin       pritipatel
# 5    marcomendicino    senatordurbin          youtube         refugees
# 6     senatordurbin          ilhanmn         joebiden         joebiden
# 7     conservatives       pritipatel              aoc     borisjohnson
# 8        whitehouse       whitehouse          ilhanmn     nigel_farage
# 9          uklabour               un          thehill    txcivilrights
# 10          youtube    displaced_atx   projectlincoln              cnn
# 11     borisjohnson              cnn              gop          youtube
# 12               un          tedcruz               un       dickdurbin
# 13     narendramodi     nigel_farage     borisjohnson       senmikelee
# 14        change_br              aoc      ivankatrump  behrouzboochani
#
#             2020_30          2020_31  ...          2020_52          2021_00  \
# 0     senatordurbin       pritipatel  ...         refugees               un
# 1     iamjohnoliver     nigel_farage  ...               un         refugees
# 2               dnc     borisjohnson  ...              hrw      nowthisnews
# 3      nigel_farage  realdonaldtrump  ...     nigel_farage     abiyahmedali
# 4   realdonaldtrump          skynews  ...  realdonaldtrump         joebiden
# 5        dickdurbin       mouthwaite  ...         joebiden    unhumanrights
# 6        pritipatel           change  ...    unhumanrights         7piliers
# 7      borisjohnson          bbcnews  ...     kamalaharris           unesco
# 8          sonusood    senatordurbin  ...    toryboypierce              hrw
# 9          refugees              lbc  ...     abiyahmedali     nigel_farage
# 10              aoc         joebiden  ...        mbachelet  realdonaldtrump
# 11         joebiden         refugees  ...  antonioguterres        mwlorg_en
# 12          youtube              gmb  ...    unreliefchief     kamalaharris
# 13        talkradio        talkradio  ...          nytimes   ismailoguelleh
# 14              cnn     senrickscott  ...             usun  antonioguterres
#
#             2021_01        2021_02         2021_03          2021_04  \
# 0                un       joebiden        joebiden            potus
# 1          refugees             un    kamalaharris               vp
# 2     unhumanrights       refugees           potus         joebiden
# 3               hrw       ablinken        refugees       pritipatel
# 4   realdonaldtrump   kamalaharris        lindat_g         refugees
# 5              usun       lindat_g        ablinken       secblinken
# 6          joebiden    alimayorkas              un       whitehouse
# 7      abiyahmedali      travelgov       pmtunisia         ablinken
# 8   antonioguterres   ailanational       gopleader         presssec
# 9          wfpchief  filippograndi              vp               un
# 10     nigel_farage  jakejsullivan  irishmissionun    justintrudeau
# 11    intlcrimcourt     pritipatel       secpompeo  cynical_refugee
# 12       pritipatel   nigel_farage      pritipatel      marcgarneau
# 13              aoc    ronaldklain       niger_onu      alimayorkas
# 14    unreliefchief  josepborrellf         foxnews     kamalaharris
#
#           2021_05        2021_06        2021_07        2021_08
# 0           potus          potus          potus       refugees
# 1              vp       refugees       refugees        amnesty
# 2        refugees             un     secblinken          potus
# 3              un            hrw             vp  eu_commission
# 4      secblinken     secblinken       joebiden      statedept
# 5   justintrudeau             vp             un     voaamharic
# 6        joebiden  eu_commission    alimayorkas    marcgarneau
# 7         amnesty       joebiden            hrw             vp
# 8   unhumanrights    alimayorkas            cnn   nigel_farage
# 9     alimayorkas        amnesty  filippograndi             un
# 10       lindat_g            cnn         dhsgov     pritipatel
# 11  eu_commission       presssec  eu_commission       joebiden
# 12   abiyahmedali     whitehouse       presssec     secblinken
# 13     whitehouse            aoc        tedcruz            aoc
# 14       presssec      eucouncil  unhumanrights        voanews
#
# [15 rows x 40 columns]

# %%
df_annotations_week = get_entity_count_by_interval(df_tweets,"week","annotations")
df_annotations_week
# Out:
#       2020_22          2020_23            2020_24        2020_25    2020_26  \
# 0       trump            trump              trump          trump      trump
# 1       india          america      supreme court             us    america
# 2     america               us             turkey             uk         us
# 3          us            india                 us        america         uk
# 4          uk               uk            america           u.s.     canada
# 5      canada           turkey                 uk         turkey     turkey
# 6      europe           canada  world refugee day        glasgow  americans
# 7      turkey           europe              india          india      india
# 8         usa             u.s.             canada          sindh     europe
# 9       delhi              bjp               daca         canada      china
# 10      china            delhi               u.s.         europe  hong kong
# 11      bihar              usa             europe            usa        usa
# 12      obama            china              china       pakistan       u.s.
# 13        god  donald j. trump                usa      americans         eu
# 14  americans        americans              obama  supreme court     mexico
#
#           2020_27    2020_28      2020_29         2020_30    2020_31  ...  \
# 0           trump      trump        trump           trump         uk  ...
# 1         america         us           us              us     france  ...
# 2              us    america      america              uk      trump  ...
# 3   united states         uk       canada         america         us  ...
# 4          turkey     turkey           uk             usa    lebanon  ...
# 5              uk     canada          usa          france    america  ...
# 6            u.s.       u.s.         u.s.          canada         eu  ...
# 7          canada     europe       turkey          europe    britain  ...
# 8       americans      india        india           india     europe  ...
# 9             usa  americans       europe            u.s.     brexit  ...
# 10          india     france    americans          turkey     canada  ...
# 11          obama      china  new zealand           spain    germany  ...
# 12         europe        usa    australia  tommy robinson     farage  ...
# 13         mexico      obama        obama       americans      india  ...
# 14          china      biden        china         germany  americans  ...
#
#                  2020_52        2021_00    2021_01    2021_02    2021_03  \
# 0                     uk          sudan      trump      trump      biden
# 1                  trump         tigray    america      biden      trump
# 2                     us          trump         us         us         us
# 3                america             uk         uk    america    america
# 4             brexit day             us      biden         uk  americans
# 5            stewart lee       ethiopia     turkey     tigray       u.s.
# 6          kent refugees        america     canada   ethiopia  joe biden
# 7                 canada         turkey      sudan  guatemala         uk
# 8                twitter      um rakuba     tigray    eritrea        usa
# 9                 tigray       djibouti        usa        usa     mexico
# 10  asian dub foundation             eu  americans     canada      china
# 11              ethiopia         europe     europe       u.s.     turkey
# 12                turkey         canada     mexico     turkey    eritrea
# 13                    eu          biden       u.s.  americans  guatemala
# 14                europe  daniel yemane      china     europe      sudan
#
#             2021_04    2021_05    2021_06    2021_07   2021_08
# 0             biden      biden      biden      biden     biden
# 1             trump      trump         us         us     trump
# 2                us         us      trump    america        us
# 3                uk    america    america      trump        uk
# 4           america     tigray     mexico     mexico   america
# 5            turkey    eritrea         uk      texas  ethiopia
# 6            europe   ethiopia       u.s.         uk    tigray
# 7              u.s.         uk        usa       u.s.      u.s.
# 8   napier barracks       u.s.  americans     turkey    europe
# 9            canada      sudan     turkey  americans     qatar
# 10              usa     turkey     canada     canada   eritrea
# 11           mexico        usa   shimelba        usa     sudan
# 12        americans  americans    hitsats  democrats    mexico
# 13           tigray     mexico      china     europe     texas
# 14        australia     canada   ethiopia      sudan    canada
#
# [15 rows x 40 columns]

# %% [markdown]
# ## Identification of Events

# %% [markdown]
# ### s386

# %% [markdown]
# #### Find all relevant hashtags

# %%
s386_hashtags_1 = ["s386","passs386","unblocks386","s386isfair"]

# %%
df_tweets_s386_1 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,s386_hashtags_1))]
df_tweets_s386_1.shape
# Out:
# (50324, 23)

# %%
hashtag_count = get_entity_count(df_tweets_s386_1["hashtags"])

# Remove hashtags that are already in list
for hashtag in s386_hashtags_1:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('durbinliesimmigrantsdie', 8369),
#  ('immigrantsdiewhendurbinlies', 8260),
#  ('rickcantonesescott', 6373),
#  ('rickbeijingscott', 6153),
#  ('s386isgoodforamerica', 1825),
#  ('nos386', 1743),
#  ('hr1044', 1690),
#  ('yess386', 1468),
#  ('s386eliminatesdiscrimination', 1155),
#  ('immigrants', 1052),
#  ('gcbacklog', 994),
#  ('homeishere', 856),
#  ('fairness', 826),
#  ('neverforget', 744),
#  ('dirtypolitics', 743),
#  ('disappointed', 742),
#  ('passhr1044', 731),
#  ('s386isnotfair', 648),
#  ('senatemustpasss386', 584),
#  ('standwithscott', 521),
#  ('rosettarick', 498),
#  ('ilpol', 477),
#  ('nos386noharassment', 454),
#  ('s386blockedflprotected', 449),
#  ('s386outsourcingbill', 444)]

# %%
s386_hashtags_2 = s386_hashtags_1 + ["durbinliesimmigrantsdie","immigrantsdiewhendurbinlies","rickcantonesescott",
                                     "rickbeijingscott","s386isgoodforamerica","nos386","hr1044","yess386",
                                     "s386eliminatesdiscrimination","gcbacklog","passhr1044","s386isnotfair",
                                     "senatemustpasss386","standwithscott","nos386noharassment","s386blockedflprotected",
                                     "s386outsourcingbill"]

# %%
df_tweets_s386_2 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,s386_hashtags_2))]
df_tweets_s386_2.shape
# Out:
# (70389, 23)

# %%
hashtag_count = get_entity_count(df_tweets_s386_2["hashtags"])

# Remove hashtags that are already in list
for hashtag in s386_hashtags_2:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('hr1044good4usa', 8608),
#  ('immigrants', 1286),
#  ('webackdurbin', 1155),
#  ('durbinfightsoutsourcerslie', 978),
#  ('imwithdurbin', 904),
#  ('homeishere', 870),
#  ('fairness', 836),
#  ('standwithdurbin', 807),
#  ('neverforget', 744),
#  ('dirtypolitics', 743),
#  ('disappointed', 742),
#  ('stophr1044', 529),
#  ('academichalt', 511),
#  ('h4kids', 503),
#  ('rosettarick', 498),
#  ('housebanschinese', 483),
#  ('ilpol', 480),
#  ('stops386', 457),
#  ('checks4techs', 411),
#  ('equality', 409),
#  ('daca', 398),
#  ('uniplung', 397),
#  ('h1b', 396),
#  ('h4eaddelays', 326),
#  ('racist', 314)]

# %%
s386_hashtags_3 = s386_hashtags_2 + ["hr1044good4usa", "webackdurbin", "durbinfightsoutsourcerslie", "imwithdurbin",
                                     "standwithdurbin", "stophr1044", "academichalt","rosettarick","housebanschinese",
                                     "stops386", "checks4techs"]

# %%
df_tweets_s386_3 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,s386_hashtags_3))]
df_tweets_s386_3.shape
# Out:
# (74954, 23)

# %%
s386_hashtag_qualifier = s386_hashtags_3

# %%
s386_hashtag_qualifier
# Out:
# ['s386',
#  'passs386',
#  'unblocks386',
#  's386isfair',
#  'durbinliesimmigrantsdie',
#  'immigrantsdiewhendurbinlies',
#  'rickcantonesescott',
#  'rickbeijingscott',
#  's386isgoodforamerica',
#  'nos386',
#  'hr1044',
#  'yess386',
#  's386eliminatesdiscrimination',
#  'gcbacklog',
#  'passhr1044',
#  's386isnotfair',
#  'senatemustpasss386',
#  'standwithscott',
#  'nos386noharassment',
#  's386blockedflprotected',
#  's386outsourcingbill',
#  'hr1044good4usa',
#  'webackdurbin',
#  'durbinfightsoutsourcerslie',
#  'imwithdurbin',
#  'standwithdurbin',
#  'stophr1044',
#  'academichalt',
#  'rosettarick',
#  'housebanschinese',
#  'stops386',
#  'checks4techs']

# %% [markdown]
# #### Create event qualifier

# %%
annotation_count = get_entity_count(df_tweets_s386_3["annotations"])

# Sort hashtags by frequency
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:40]
# Out:
# [('america', 5773),
#  ('us', 5760),
#  ('usa', 5513),
#  ('india', 2253),
#  ('congress', 961),
#  ('china', 879),
#  ('daca', 874),
#  ('indians', 750),
#  ('durbin', 728),
#  ('senator durbin', 713),
#  ('us congress', 685),
#  ('civilrightsact', 665),
#  ('richard russell', 664),
#  ('americans', 456),
#  ('u.s.', 449),
#  ('nǐ hǎo', 421),
#  ('texas', 404),
#  ('africa', 385),
#  ('trump', 325),
#  ('ms. hegar', 324),
#  ('sen. durbin', 292),
#  ('sen. rick scott', 287),
#  ('mike lee', 279),
#  ('florida', 251),
#  ('dol', 242),
#  ('john lewis', 227),
#  ('god', 208),
#  ('united', 204),
#  ('senator cornyn', 194),
#  ('united states', 184),
#  ('rick scott', 179),
#  ('sen durbin', 163),
#  ('democrats', 158),
#  ('bill', 156),
#  ('south america', 153),
#  ('senate', 152),
#  ('dick durbin', 148),
#  ('american hospital association', 124),
#  ('biden', 113),
#  ('us-born', 111)]

# %%
mention_count = get_entity_count(df_tweets_s386_3["mentions"])

# Sort hashtags by frequency
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:40]
# Out:
# [('senatordurbin', 24915),
#  ('senrickscott', 21967),
#  ('senmikelee', 15335),
#  ('repzoelofgren', 13994),
#  ('dnc', 13476),
#  ('dncwarroom', 7811),
#  ('chrishartline', 6746),
#  ('iamjohnoliver', 5944),
#  ('dickdurbin', 5556),
#  ('senatedems', 4355),
#  ('joebiden', 2774),
#  ('realdonaldtrump', 2666),
#  ('senategop', 2364),
#  ('scottforflorida', 2174),
#  ('kamalaharris', 1704),
#  ('speakerpelosi', 1428),
#  ('ailanational', 1127),
#  ('housedemocrats', 1125),
#  ('cnn', 1042),
#  ('potus', 815),
#  ('housegop', 770),
#  ('gcbcoalition', 721),
#  ('immivoice', 721),
#  ('senschumer', 712),
#  ('jaredkushner', 624),
#  ('alimayorkas', 493),
#  ('foxnews', 476),
#  ('uscis', 465),
#  ('whitehouse', 441),
#  ('mitindc', 423),
#  ('vp', 418),
#  ('housejudiciary', 411),
#  ('johncornyn', 399),
#  ('tim_cook', 390),
#  ('gop', 379),
#  ('ckuck', 370),
#  ('miamiherald', 355),
#  ('nicolasmaduro', 353),
#  ('aauniversities', 341),
#  ('mjhegar', 338)]

# %%
s386_event_qualifier = ["s386","durbin","hr1044", "scott"]

# %% [markdown]
# #### Create event dataset

# %%
s386_qualifier = set(s386_event_qualifier + s386_hashtag_qualifier)

# %%
df_tweets_s386 = df_tweets[df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),s386_qualifier))]

# %%
df_tweets_s386.shape
# Out:
# (62503, 23)

# %% [markdown]
# #### Visualize event

# %%
plot_event_timeline(df_tweets_s386,"week")

# %% [markdown]
# ### Moria

# %% [markdown]
# #### Find all relevant hashtags

# %%
moria_hashtags_1 = ["moria", "greece"]

# %%
df_tweets_moria_1 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,moria_hashtags_1))]
df_tweets_moria_1.shape
# Out:
# (12351, 23)

# %%
hashtag_count = get_entity_count(df_tweets_moria_1["hashtags"])

# Remove hashtags that are already in list
for hashtag in moria_hashtags_1:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 2582),
#  ('migrants', 1117),
#  ('lesbos', 1110),
#  ('turkey', 1066),
#  ('eu', 914),
#  ('lesvos', 891),
#  ('news', 717),
#  ('refugeesgr', 598),
#  ('refugee', 576),
#  ('leavenoonebehind', 540),
#  ('moriacamp', 510),
#  ('refugeeswelcome', 504),
#  ('covid19', 491),
#  ('europe', 487),
#  ('fire', 450),
#  ('germany', 357),
#  ('migration', 314),
#  ('humanrights', 302),
#  ('greek', 283),
#  ('coronavirus', 264),
#  ('mitsotakis', 261),
#  ('asylum', 245),
#  ('asylumseekers', 241),
#  ('karatepe', 224),
#  ('migrant', 196)]

# %%
moria_hashtags_2 = moria_hashtags_1 + ["lesbos","lesvos","refugeesgr","moriacamp","fire","greek","mitsotakis","karatepe"]

# %%
hashtag_check(df_tweets,["turkey","leavenoonebehind","fire","humanrights"],"hashtags")
# Out:
# turkey 7860
# refugees 3390
# syria 1863
# eu 1830
# erdogan 1590
# uk 1354
# muslim 1338
# jihadists 1319
# standwithiraqirefugees 1061
# greece 1029
# pleasehelp 897
# legal 878
# iraqi_refugees_look_for_homeland 838
# iraqi 728
# covid19 690
#
# ------------------------------------------
#
# leavenoonebehind 4346
# refugeeswelcome 1949
# covid19 793
# moria 502
# worldngoday 310
# refugees 270
# refugeesgr 137
# moria2 111
# karatepe 79
# greece 72
# humanrights 56
# wirhabenplatz 55
# migrants 54
# freealicanalbayrakandhuseyinsahin 51
# moriacamp 50
#
# ------------------------------------------
#
# fire 722
# greece 392
# moria 348
# mitsotakis 237
# refugees 105
# lesbos 104
# migrants 67
# refugee 63
# camp 45
# refugeecamp 39
# migrant 33
# greek 33
# lesvos 28
# coronavirus 25
# moriacamp 23
#
# ------------------------------------------
#
# humanrights 10057
# refugees 2505
# migrants 1250
# karabakhisazerbaijan 967
# osce 925
# stoparmenianoccupation 827
# stoparmenianaggression 515
# refugee 473
# humanrightsviolations 471
# covid19 460
# minskgroup 447
# ireli2020 410
# asylumseekers 404
# nkaze 366
# eu 342
#
# ------------------------------------------

# %%
df_tweets_moria_2 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,moria_hashtags_2))]
df_tweets_moria_2.shape
# Out:
# (16019, 23)

# %%
hashtag_count = get_entity_count(df_tweets_moria_2["hashtags"])

# Remove hashtags that are already in list
for hashtag in moria_hashtags_2:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 3299),
#  ('migrants', 1399),
#  ('turkey', 1155),
#  ('eu', 1044),
#  ('refugee', 794),
#  ('news', 730),
#  ('leavenoonebehind', 634),
#  ('refugeeswelcome', 588),
#  ('covid19', 573),
#  ('europe', 561),
#  ('germany', 402),
#  ('migration', 389),
#  ('humanrights', 380),
#  ('asylum', 324),
#  ('coronavirus', 313),
#  ('asylumseekers', 295),
#  ('migrant', 269),
#  ('athens', 242),
#  ('immigrants', 220),
#  ('samos', 203),
#  ('syria', 202),
#  ('moria2', 191),
#  ('pushbacks', 183),
#  ('turkish', 152),
#  ('freethekids', 142)]

# %%
moria_hashtags_3 = moria_hashtags_2 + ["moria2","athens","samos"]

# %%
hashtag_check(df_tweets,["asylumseekers","samos","freethekids","pushbacks"],"hashtags")
# Out:
# asylumseekers 5839
# refugees 2765
# migrants 903
# immigration 431
# humanrights 404
# asylum 368
# immigrants 355
# auspol 352
# covid19 306
# migration 290
# refugeeswelcome 267
# children 236
# refugee 193
# greece 179
# uk 146
#
# ------------------------------------------
#
# samos 334
# greece 94
# refugees 66
# moria 42
# refugeesgr 41
# lesvos 38
# vathy 32
# refugee 29
# greek 19
# migrants 17
# fire 17
# lesbos 15
# chios 15
# kos 11
# earthquake 11
#
# ------------------------------------------
#
# freethekids 176
# greece 142
# covid19 132
# abolishice 5
# freethemall 4
# blacklivesmatter 2
# closethecamps 2
# freethefamilies 2
# kidsincages 2
# children 2
# takeaction 1
# policebrutality 1
# stopice 1
# libertad 1
# cantbebannedfromstolenland 1
#
# ------------------------------------------
#
# pushbacks 552
# greece 131
# migrants 123
# refugees 121
# refugeesgr 78
# eu 72
# frontex 62
# humanrights 54
# asylum 34
# migration 30
# croatia 27
# libya 25
# turkey 22
# refugee 22
# greek 21
#
# ------------------------------------------

# %%
df_tweets_moria_3 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,moria_hashtags_3))]
df_tweets_moria_3.shape
# Out:
# (16439, 23)

# %%
moria_hashtag_qualifier = moria_hashtags_3

# %% [markdown]
# #### Create event qualifier

# %%
annotation_count = get_entity_count(df_tweets_moria_3["annotations"])

# Sort hashtags by frequency
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:25]
# Out:
# [('greece', 2452),
#  ('europe', 910),
#  ('moria', 768),
#  ('lesbos', 753),
#  ('eu', 528),
#  ('turkey', 496),
#  ('lesvos', 374),
#  ('germany', 323),
#  ('prime minister', 253),
#  ('athens', 205),
#  ('kara tepe', 138),
#  ('syria', 119),
#  ('uk', 98),
#  ('aegean', 67),
#  ('amazon', 63),
#  ('berlin', 62),
#  ('erdogan', 61),
#  ('afghanistan', 61),
#  ('france', 59),
#  ('turkish', 58),
#  ('chios', 55),
#  ('samos', 54),
#  ('aegean sea', 52),
#  ('unhcr', 44),
#  ('moria camp', 39)]

# %%
moria_annotation_qualifier = ["greece","moria","lesbos","lesvos","athens","kara tepe","aegean","chios","samos",
                              "aegean sea","moria camp"]

# %%
mention_count = get_entity_count(df_tweets_moria_3["mentions"])

# Sort hashtags by frequency
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:40]
# Out:
# [('primeministergr', 578),
#  ('refugees', 389),
#  ('euhomeaffairs', 288),
#  ('eu_commission', 277),
#  ('bmi_bund', 251),
#  ('nmitarakis', 242),
#  ('ukhomeoffice', 241),
#  ('ministeriejenv', 238),
#  ('interieur_gouv', 228),
#  ('hrw', 203),
#  ('vonderleyen', 160),
#  ('ylvajohansson', 135),
#  ('unhcrgreece', 117),
#  ('kmitsotakis', 106),
#  ('nytimes', 105),
#  ('un', 86),
#  ('frontex', 73),
#  ('msf', 68),
#  ('europarl_en', 62),
#  ('amnesty', 60),
#  ('unmigration', 51),
#  ('f_grillmeier', 49),
#  ('dwnews', 49),
#  ('msf_sea', 48),
#  ('guardian', 48),
#  ('eucopresident', 48),
#  ('margschinas', 48),
#  ('emmanuelmacron', 47),
#  ('amnestyireland', 47),
#  ('bbcworld', 45),
#  ('hcoastguard', 43),
#  ('rspaegean', 42),
#  ('unhumanrights', 41),
#  ('youtube', 41),
#  ('chooselove', 41),
#  ('katymfallon', 39),
#  ('bbcnews', 39),
#  ('eva_cosse', 37),
#  ('eucouncil', 36),
#  ('gcrefugees', 36)]

# %%
moria_mention_qualifier = ["primeministergr","nmitarakis","unhcrgreece","kmitsotakis","hcoastguard","rspaegean","gcrefugees"]

# %% [markdown]
# #### Create event dataset

# %%
moria_qualifier = set(moria_hashtag_qualifier + moria_annotation_qualifier + moria_mention_qualifier)

# %%
df_tweets_moria = df_tweets[df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),moria_qualifier))]

# %%
df_tweets_moria.shape
# Out:
# (92830, 23)

# %% [markdown]
# #### Visualize event

# %%
plot_event_timeline(df_tweets_moria,"week")

# %%
plot_entity_timeline(df_tweets_moria, "week", list(moria_qualifier)[:5], "hashtags")

# %% [markdown]
# ### Tigray

# %% [markdown]
# #### Find all relevant hashtags

# %%
tigray_hashtags_1 = ["tigraygenocide","tigray","allowaccesstotigray","tigrayfacts","stopwarontigray","eritreaoutoftigray"]

# %%
df_tweets_tigray_1 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,tigray_hashtags_1))]
df_tweets_tigray_1.shape
# Out:
# (111961, 23)

# %%
hashtag_count = get_entity_count(df_tweets_tigray_1["hashtags"])

# Remove hashtags that are already in list
for hashtag in tigray_hashtags_1:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('ethiopia', 18394),
#  ('bidenactnow', 11036),
#  ('eritrea', 10724),
#  ('sudan', 8727),
#  ('stopabiy', 6966),
#  ('bidentakeaction', 6437),
#  ('protectrefugees', 5722),
#  ('unscactnow', 5606),
#  ('refugees', 5010),
#  ('trudeauactnow', 3849),
#  ('warontigray', 3375),
#  ('getethiopianfactsright', 3202),
#  ('tigraycantwait', 2969),
#  ('unsc', 2666),
#  ('eritrean', 2573),
#  ('war', 2554),
#  ('humanitariancorridor', 2429),
#  ('tigraiopen4humanitarianassistance', 2401),
#  ('uplifttigraiethiopia', 2385),
#  ('stoptheliehelptigrai', 2308),
#  ('isaias', 2218),
#  ('blm', 2168),
#  ('famine', 1860),
#  ('r2ptigray', 1766),
#  ('tplfisthecause', 1683)]

# %%
tigray_hashtags_2 = tigray_hashtags_1 + ["ethiopia","bidenactnow","eritrea","sudan","stopabiy","bidentakeaction",
                                         "protectrefugees","unscactnow","trudeauactnow","warontigray","getethiopianfactsright",
                                         "tigraycantwait","unsc","eritrean","humanitariancorridor","tigraiopen4humanitarianassistance",
                                         "uplifttigraiethiopia","stoptheliehelptigrai","isaias","r2ptigray","tplfisthecause"]

# %% [markdown]
# blm and famine have to potentially be added as well

# %%
hashtag_check(df_tweets,["bidenactnow","sudan","protectrefugees","unsc","isaias","blm","humanitariancorridor","famine"],"hashtags")
# Out:
# bidenactnow 11531
# tigraygenocide 10195
# tigray 4362
# ethiopia 1370
# eritrea 1163
# stopwarontigray 838
# bidentakeaction 811
# humanitariancorridor 808
# famine 616
# warontigray 613
# allowaccesstotigray 588
# tigraycantwait 547
# protectrefugees 314
# eritreantroops 268
# saveourgirls 268
#
# ------------------------------------------
#
# sudan 12234
# tigray 7262
# stopwarontigray 5990
# ethiopia 4223
# refugees 3520
# tigraygenocide 2017
# protectrefugees 1864
# stopabiy 1195
# eritrea 1138
# war 1135
# refugee 865
# unsc 773
# r2p 743
# tplf 731
# ethiopiaprevails 512
#
# ------------------------------------------
#
# protectrefugees 5780
# tigray 5265
# stopwarontigray 4735
# sudan 1864
# ethiopia 1824
# tigraygenocide 1611
# eritrea 1525
# refugees 1037
# war 484
# stopabiy 479
# bidenactnow 314
# refugee 295
# warontigray 289
# bombardment 282
# nazi 180
#
# ------------------------------------------
#
# unsc 3082
# tigray 1444
# tigraygenocide 1444
# stopwarontigray 1215
# refugees 805
# sudan 773
# r2p 767
# war 748
# allowaccesstotigray 559
# blm 218
# bidentakeaction 202
# ethiopia 192
# blacklivesmatter 153
# eritrea 152
# r2ptigray 74
#
# ------------------------------------------
#
# isaias 2284
# tigray 1826
# eritreaoutoftigray 1534
# unscactnow 1529
# eritrea 491
# abiy 422
# tigraygenocide 377
# stopwarontigray 296
# warcrimes 226
# fascistisaias 224
# eritreanarmy 114
# ethiopianarmy 113
# ethiopia 23
# eritrean 21
# abiyahmedali 18
#
# ------------------------------------------
#
# blm 6935
# tigraygenocide 1946
# tigray 1758
# stopwarontigray 1396
# immigrants 477
# stopabiy 452
# opentigray 450
# ethiopian 439
# refugees 419
# famine 418
# humanitariancorridor 418
# blacklivesmatter 404
# racism 231
# sudan 224
# war 221
#
# ------------------------------------------
#
# humanitariancorridor 2506
# tigray 2431
# tigraygenocide 2256
# famine 1154
# bidenactnow 808
# trudeauactnow 440
# blm 418
# stopwarontigray 354
# bidentakeaction 154
# tigraycantwait 83
# eritreaoutoftigray 81
# reconnecttigray 80
# allowaccesstotigray 75
# ethiopia 74
# unscactnow 70
#
# ------------------------------------------
#
# tigray 2148
# famine 1933
# tigraygenocide 1844
# humanitariancorridor 1154
# bidenactnow 616
# trudeauactnow 429
# blm 418
# refugees 30
# poverty 16
# bidentakeaction 14
# war 11
# covid19 10
# refugee 10
# yemen 9
# un 8
#
# ------------------------------------------

# %%
df_tweets_tigray_2 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,tigray_hashtags_2))]
df_tweets_tigray_2.shape
# Out:
# (128701, 23)

# %%
hashtag_count = get_entity_count(df_tweets_tigray_2["hashtags"])

# Remove hashtags that are already in list
for hashtag in tigray_hashtags_2:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 6364),
#  ('tplf', 4146),
#  ('war', 2590),
#  ('unityforethiopia', 2513),
#  ('blm', 2178),
#  ('ethiopian', 2128),
#  ('famine', 1862),
#  ('refugee', 1726),
#  ('reconnecttigray', 1624),
#  ('drabiygovistryinghard', 1599),
#  ('un', 1530),
#  ('unhcr', 1427),
#  ('abiymustgo', 1389),
#  ('r2p', 1366),
#  ('100daysofgenocide', 1341),
#  ('tigrayans', 1312),
#  ('warcrimes', 1277),
#  ('abiy', 1210),
#  ('boycottethiopianroses', 1165),
#  ('opentigray', 1163),
#  ('superbowl', 1019),
#  ('sanctionethiopia', 890),
#  ('famineontigray', 863),
#  ('djibouti', 862),
#  ('ethiopiaprevails', 856)]

# %%
hashtag_check(df_tweets,["tplf","famine","drabiygovistryinghard","abiymustgo","r2p","100daysofgenocide","djibouti"],"hashtags")
# Out:
# tplf 7901
# unityforethiopia 2970
# eritrea 1594
# tigray 1503
# shameonamnesty 1392
# ethiopia 1282
# allowaccesstotigray 741
# sudan 721
# ethiopiaprevails 664
# fakeaxummassacre 657
# stoptheliehelptigrai 560
# tigraiopen4humanitarianassistance 558
# uplifttigraiethiopia 555
# refugees 489
# justice4maikadra 431
#
# ------------------------------------------
#
# tigray 2148
# famine 1933
# tigraygenocide 1844
# humanitariancorridor 1154
# bidenactnow 616
# trudeauactnow 429
# blm 418
# refugees 30
# poverty 16
# bidentakeaction 14
# war 11
# covid19 10
# refugee 10
# yemen 9
# un 8
#
# ------------------------------------------
#
# drabiygovistryinghard 1616
# getethiopianfactsright 1581
# tigrayfacts 1564
# tplf 20
# tplfisthecause 11
# ethiopiaprevails 11
# ethiopia 10
# unityforethiopia 8
# tigray 4
# ethiopians 2
# maikadra 2
# ethiopian 2
# tigrayregion 2
# eritrea 1
# allowaccesstotigray 1
#
# ------------------------------------------
#
# abiymustgo 1521
# tigraygenocide 1332
# tigray 1193
# ethiopia 155
# stopwarontigray 96
# bidenactnow 85
# africaisbleeding 84
# istandwithtigray 48
# united 47
# oromoprotests 42
# stopabiy 37
# stopthewarontigray 34
# r2ptigray 34
# saynotowar 33
# uk 31
#
# ------------------------------------------
#
# r2p 1417
# stopwarontigray 1103
# refugees 935
# unsc 767
# sudan 743
# war 742
# tigray 543
# stopabiy 450
# warcrimes 244
# uae 230
# genocide 227
# blm 216
# r2ptigray 202
# eritrea 188
# stopwaronethiopia 185
#
# ------------------------------------------
#
# 100daysofgenocide 1390
# tigraygenocide 1252
# stopwarontigray 193
# eritrea 134
# tigray 118
# allowaccesstotigray 76
# ethiopia 39
# tigraycantwait 38
# eritreaoutoftigray 33
# abiymustgo 21
# genocide 20
# bidentakeactionnow 19
# eritreantroopsoutoftigray 11
# bidentakeaction 7
# abiyahmedali 6
#
# ------------------------------------------
#
# djibouti 995
# tigray 777
# ethiopia 521
# tigraygenocide 313
# yemen 30
# stopwarontigray 26
# eritrea 22
# somalia 20
# kenya 19
# migrants 16
# sudan 16
# refugees 15
# covid19 14
# africa 11
# unhcr 11
#
# ------------------------------------------

# %%
tigray_hashtags_3 = tigray_hashtags_2 + ["tplf","unityforethiopia","ethiopian","famine","reconnecttigray",
                                         "drabiygovistryinghard","abiymustgo","r2p","100daysofgenocide",
                                         "tigrayans","abiy","boycottethiopianroses","opentigray","sanctionethiopia",
                                         "famineontigray","djibouti","ethiopiaprevails"]

# %%
df_tweets_tigray_3 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,tigray_hashtags_3))]
df_tweets_tigray_3.shape
# Out:
# (136857, 23)

# %%
tigray_hashtag_qualifier = tigray_hashtags_3

# %% [markdown]
# #### Create event qualifier

# %%
annotation_count = get_entity_count(df_tweets_tigray_3["annotations"])

# Sort hashtags by frequency
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:25]
# Out:
# [('tigray', 20015),
#  ('ethiopia', 17812),
#  ('sudan', 17705),
#  ('eritrea', 13679),
#  ('shimelba', 3619),
#  ('hitsats', 3314),
#  ('eritrean', 1861),
#  ('un', 1678),
#  ('shire', 1629),
#  ('abiy', 1617),
#  ('tigray refugee camps', 1510),
#  ('djibouti', 1267),
#  ('tigrayans', 1038),
#  ('isaias afewerki', 951),
#  ('ethiopian', 875),
#  ('um rakuba', 854),
#  ('mai kadra', 739),
#  ('abiy ahmed', 724),
#  ('united nations', 723),
#  ('hamdayet', 717),
#  ('um raquba', 687),
#  ('us', 654),
#  ('filippo grandi', 642),
#  ('fano', 639),
#  ('daniel yemane', 589)]

# %%
tigray_annotation_qualifier = ["tigray","ethiopia","sudan","eritrea","shimelba","hitsats","eritrean","shire","abiy",
                               "djibouti","tigrayans","isaias afewerki","ethiopian","um rakuba","mai kadra","hamdayet",
                               "um raquba","fano"]

# %%
mention_count = get_entity_count(df_tweets_tigray_3["mentions"])

# Sort hashtags by frequency
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:25]
# Out:
# [('refugees', 38702),
#  ('un', 38096),
#  ('hrw', 18139),
#  ('joebiden', 15293),
#  ('amnesty', 15187),
#  ('eu_commission', 14621),
#  ('abiyahmedali', 13932),
#  ('unhumanrights', 13112),
#  ('potus', 12434),
#  ('filippograndi', 12034),
#  ('lindat_g', 11790),
#  ('unocha', 8914),
#  ('ablinken', 8881),
#  ('usun', 8640),
#  ('vp', 7893),
#  ('antonioguterres', 7878),
#  ('unreliefchief', 7343),
#  ('secblinken', 6097),
#  ('statedept', 5861),
#  ('unhcrethiopia', 5566),
#  ('kamalaharris', 5336),
#  ('marcgarneau', 5283),
#  ('justintrudeau', 4924),
#  ('josepborrellf', 4728),
#  ('kenroth', 4549)]

# %%
tigray_mention_qualifier = ["abiyahmedali"]

# %% [markdown]
# #### Create event dataset

# %%
tigray_qualifier = set(tigray_hashtag_qualifier + tigray_mention_qualifier + tigray_annotation_qualifier)

# %%
df_tweets_tigray = df_tweets[df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),tigray_qualifier))]

# %%
df_tweets_tigray.shape
# Out:
# (180779, 23)

# %% [markdown]
# #### Visualize event

# %%
plot_event_timeline(df_tweets_tigray,"week")

# %%
plot_entity_timeline(df_tweets_tigray, "week", list(tigray_qualifier)[:5], "hashtags")

# %% [markdown]
# ### Beirut Blast

# %% [markdown]
# #### Find all relevant hashtags

# %%
beirut_hashtags_1 = ["beirut","lebanon"]

# %%
df_tweets_beirut_1 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,beirut_hashtags_1))]
df_tweets_beirut_1.shape
# Out:
# (6021, 23)

# %%
hashtag_count = get_entity_count(df_tweets_beirut_1["hashtags"])

# Remove hashtags that are already in list
for hashtag in beirut_hashtags_1:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 1237),
#  ('syria', 965),
#  ('azerbaijani', 464),
#  ('syrian', 420),
#  ('covid19', 401),
#  ('refugee', 384),
#  ('armenia', 293),
#  ('civilians', 265),
#  ('jordan', 255),
#  ('palestinian', 206),
#  ('palestine', 201),
#  ('shelling', 198),
#  ('beirutblast', 188),
#  ('beirutexplosion', 183),
#  ('pkk', 175),
#  ('turkey', 140),
#  ('lebanese', 120),
#  ('iraq', 109),
#  ('migrants', 98),
#  ('coronavirus', 97),
#  ('kafala', 94),
#  ('israel', 88),
#  ('cyprus', 83),
#  ('yemen', 79),
#  ('unhcr', 78)]

# %%
beirut_hashtags_2 = beirut_hashtags_1 + ["beirutblast","beirutexplosion","lebanese"]

# %%
hashtag_check(df_tweets,["azerbaijani","armenia","jordan","palestine","shelling","kafala"],"hashtags")
# Out:
# azerbaijani 1543
# armenia 1313
# legal 1050
# refugees 870
# karabakh 494
# azerbaijan 475
# idp 345
# unresolutions 336
# stoparmenianoccupation 299
# civilians 270
# lebanon 265
# syria 265
# idps 215
# dontbelievearmenia 212
# shelling 199
#
# ------------------------------------------
#
# armenia 8517
# artsakh 3795
# refugees 2960
# genocide 1983
# war 1951
# azerbaijan 1882
# people 1822
# azerbaijani 1138
# armenianfoodbank 1055
# legal 1046
# karabakh 803
# stoparmenianoccupation 606
# karabakhisazerbaijan 539
# stoparmenianaggression 439
# idp 352
#
# ------------------------------------------
#
# jordan 1622
# refugees 458
# covid19 282
# lebanon 255
# syria 203
# refugee 182
# syrian 138
# turkey 85
# amman 65
# iraq 62
# coronavirus 61
# palestine 60
# palestinian 46
# worldrefugeeday 40
# withrefugees 36
#
# ------------------------------------------
#
# palestine 1931
# refugees 359
# israel 248
# gaza 230
# lebanon 205
# syria 163
# unrwa 150
# palestinian 148
# palestinians 107
# refugee 100
# freepalestine 92
# yemen 81
# covid19 76
# kashmir 72
# bds 72
#
# ------------------------------------------
#
# azerbaijani 398
# shelling 201
# refugees 200
# civilians 200
# armenia 198
# lebanon 198
# syria 198
# pkk 108
# risk 1
# coronavirus 1
# outbreak 1
# troops 1
# hunker 1
# trenches 1
# bunkers 1
#
# ------------------------------------------
#
# kafala 250
# lebanon 92
# qatar 28
# saudiarabia 20
# migrantworkers 17
# humanrights 17
# thisiskafala 13
# migrants 12
# racism 12
# migrant 10
# slavery 10
# domesticworkers 9
# saudi 9
# abolishkafala 7
# endkafala 7
#
# ------------------------------------------

# %%
df_tweets_beirut_2 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,beirut_hashtags_2))]
df_tweets_beirut_2.shape
# Out:
# (6545, 23)

# %%
hashtag_count = get_entity_count(df_tweets_beirut_2["hashtags"])

# Remove hashtags that are already in list
for hashtag in beirut_hashtags_2:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 1305),
#  ('syria', 980),
#  ('azerbaijani', 464),
#  ('syrian', 462),
#  ('covid19', 424),
#  ('refugee', 396),
#  ('armenia', 295),
#  ('civilians', 265),
#  ('jordan', 255),
#  ('palestinian', 220),
#  ('palestine', 204),
#  ('shelling', 198),
#  ('pkk', 175),
#  ('turkey', 141),
#  ('iraq', 110),
#  ('migrants', 109),
#  ('coronavirus', 103),
#  ('kafala', 97),
#  ('israel', 92),
#  ('cyprus', 90),
#  ('abolishkafala', 84),
#  ('yemen', 81),
#  ('unhcr', 79),
#  ('لبنان', 79),
#  ('education', 76)]

# %%
beirut_hashtags_3 = beirut_hashtags_2 + []

# %%
df_tweets_beirut_3 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,beirut_hashtags_3))]
df_tweets_beirut_3.shape
# Out:
# (6545, 23)

# %%
beirut_hashtag_qualifier = beirut_hashtags_3

# %% [markdown]
# #### Create event qualifier

# %%
annotation_count = get_entity_count(df_tweets_beirut_3["annotations"])

# Sort hashtags by frequency
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:25]
# Out:
# [('lebanon', 973),
#  ('beirut', 356),
#  ('armenia', 134),
#  ('syria', 117),
#  ('syrian', 57),
#  ('unrwa', 52),
#  ('palestine', 51),
#  ('israel', 48),
#  ('unhcr', 39),
#  ('allah', 38),
#  ('un', 37),
#  ('azerbaijani', 37),
#  ('us', 35),
#  ('azerbaijan', 33),
#  ('syrians', 31),
#  ('europe', 31),
#  ('cyprus', 30),
#  ('shatila', 28),
#  ('eu', 28),
#  ('tripoli', 28),
#  ('arsal', 27),
#  ('hezbollah', 25),
#  ('bekaa valley', 24),
#  ('uk', 23),
#  ('god', 22)]

# %%
beirut_annotation_qualifier = ["lebanon","beirut"]

# %%
mention_count = get_entity_count(df_tweets_beirut_3["mentions"])

# Sort hashtags by frequency
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:25]
# Out:
# [('refugees', 225),
#  ('un', 159),
#  ('hrw', 148),
#  ('nasimiaghayev', 122),
#  ('cenkuygur', 116),
#  ('anakasparian', 110),
#  ('theyoungturks', 110),
#  ('tytpolitics', 110),
#  ('antonioguterres', 80),
#  ('kenroth', 70),
#  ('filippograndi', 68),
#  ('unhcrlebanon', 67),
#  ('unrwa', 64),
#  ('coe', 63),
#  ('ocse', 62),
#  ('tytinvestigates', 58),
#  ('aghavalyan', 56),
#  ('tyt', 52),
#  ('avillaraigosa', 52),
#  ('unmigration', 43),
#  ('rescueorg', 34),
#  ('wfp', 29),
#  ('unicef', 29),
#  ('uniceflebanon', 27),
#  ('basmehzeitooneh', 26)]

# %%
beirut_mention_qualifier = ["unhcrlebanon","uniceflebanon"]

# %% [markdown]
# #### Create event dataset

# %%
beirut_qualifier = set(beirut_hashtag_qualifier + beirut_annotation_qualifier + beirut_mention_qualifier)

# %%
df_tweets_beirut = df_tweets[df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),beirut_qualifier))]

# %%
df_tweets_beirut.shape
# Out:
# (24535, 23)

# %% [markdown]
# #### Visualize event

# %%
plot_event_timeline(df_tweets_beirut,"week")

# %%
plot_entity_timeline(df_tweets_beirut, "week", list(beirut_qualifier)[:5], "hashtags")

# %% [markdown]
# ---

# %%
# top hashtags for week 32 for refugeeswelcome

# %%
df_32 = df_tweets[df_tweets["year_calendar_week"] == "2020_32"]

# %%
df_32_wel = df_32[df_32["hashtags"].apply(lambda x: element_in_list(x,["refugeeswelcome"]))]

# %%
hashtag_count = get_entity_count(df_32_wel["hashtags"])

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:50]
# Out:
# [('refugeeswelcome', 1872),
#  ('refugees', 658),
#  ('unhcr', 421),
#  ('malaysia', 418),
#  ('community', 415),
#  ('safepassage', 266),
#  ('help', 194),
#  ('peace', 192),
#  ('love', 191),
#  ('children', 191),
#  ('migrants', 67),
#  ('refugee', 50),
#  ('asylumseekers', 41),
#  ('refugeeswelcomehere', 32),
#  ('brexit', 22),
#  ('migrantcrisis', 22),
#  ('pritipatel', 21),
#  ('covid19', 20),
#  ('blacklivesmatter', 20),
#  ('skynews', 19),
#  ('channelcrossings', 17),
#  ('benandjerrys', 15),
#  ('racism', 14),
#  ('withrefugees', 13),
#  ('chooselove', 13),
#  ('immigration', 13),
#  ('asylum', 12),
#  ('immigrants', 12),
#  ('alllivesmatter', 11),
#  ('englishchannel', 11),
#  ('brexitreality', 10),
#  ('immigrationnation', 10),
#  ('channel4news', 9),
#  ('itvnews', 9),
#  ('communitysponsorship', 9),
#  ('uk', 9),
#  ('humanrights', 8),
#  ('nigelfarage', 8),
#  ('bbcnews', 8),
#  ('coronavirus', 8),
#  ('calais', 8),
#  ('torycorruption', 7),
#  ('nohumanisillegal', 7),
#  ('bbcbreakfast', 7),
#  ('nooneisillegal', 7),
#  ('borisjohnson', 7),
#  ('recession', 7),
#  ('greece', 7),
#  ('auspol', 6),
#  ('euronews', 6)]

# %%
ann_count = get_entity_count(df_32_wel["channelcrossings","brexit","englishchannel"])

# %%
a = sorted(ann_count.items(), key=lambda x: x[1], reverse=True)
a[:25]
# Out:
# [('uk', 184),
#  ('britain', 32),
#  ('france', 26),
#  ('priti patel', 25),
#  ('u.k.', 15),
#  ('bbc', 15),
#  ('ben', 14),
#  ('jerry', 14),
#  ('england', 13),
#  ('eu', 12),
#  ('tories', 12),
#  ('calais', 12),
#  ('europe', 11),
#  ('syria', 11),
#  ('greece', 11),
#  ('farage', 10),
#  ('iraq', 10),
#  ('johnson', 9),
#  ('germany', 8),
#  ('home office', 8),
#  ('brexit', 8),
#  ('twitter', 8),
#  ('the bell hotel', 7),
#  ('epping', 7),
#  ('essex', 7)]

# %% [markdown]
# ---

# %% [markdown]
# ### Channel Crossings

# %% [markdown]
# #### Find all relevant hashtags

# %%
channel_hashtags_1 = ["channelcrossings","brexit","englishchannel"]

# %%
df_tweets_channel_1 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,channel_hashtags_1))]
df_tweets_channel_1.shape
# Out:
# (6661, 23)

# %%
hashtag_count = get_entity_count(df_tweets_channel_1["hashtags"])

# Remove hashtags that are already in list
for hashtag in channel_hashtags_1:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('uk', 816),
#  ('migrants', 687),
#  ('refugees', 597),
#  ('eu', 463),
#  ('immigrants', 448),
#  ('british', 433),
#  ('illegal', 257),
#  ('borders', 256),
#  ('turkey', 255),
#  ('mediterranean', 249),
#  ('legal', 245),
#  ('standwithiraqirefugees', 244),
#  ('iraqi_refugees_look_for_homeland', 238),
#  ('immigration', 207),
#  ('covid19', 199),
#  ('brexitreality', 184),
#  ('france', 141),
#  ('britain', 132),
#  ('nigelfarage', 126),
#  ('dover', 101),
#  ('tory', 98),
#  ('covid', 94),
#  ('pritipatel', 92),
#  ('nhs', 91),
#  ('brexitshambles', 90)]

# %%
channel_hashtags_2 = channel_hashtags_1 + ["uk","british","brexitreality","france","britain","nigelfarage","dover","tory",
                                           "pritipatel","nhs","brexitshambles"]

# %%
hashtag_check(df_tweets,["uk","france","nigelfarage","tory","pritipatel","nhs"],"hashtags")
# Out:
# uk 7174
# refugees 2013
# eu 1847
# syria 1396
# turkey 1352
# muslim 1332
# erdogan 1319
# jihadists 1314
# migrants 756
# brexit 713
# british 512
# france 456
# immigration 379
# immigrants 268
# news 263
#
# ------------------------------------------
#
# france 3877
# migrants 886
# uk 460
# refugees 385
# katyayan 276
# racism 275
# islamophobia 256
# eu 253
# paris 252
# macron 234
# blacklivesmatter 229
# europe 223
# germany 179
# humanrights 163
# charliehebdo 150
#
# ------------------------------------------
#
# nigelfarage 530
# brexit 118
# uk 92
# britain 75
# ukip 72
# tory 69
# eu 69
# nodealbrexit 66
# wto 66
# brexitfarce 64
# migrants 63
# brexitinnameonly 59
# brino 56
# pritipatel 48
# borisjohnson 39
#
# ------------------------------------------
#
# tory 532
# brexit 97
# uk 88
# britain 73
# nodealbrexit 72
# eu 70
# nigelfarage 69
# ukip 69
# wto 67
# brexitfarce 65
# brexitinnameonly 60
# brino 57
# refugees 41
# pritipatel 39
# migrants 26
#
# ------------------------------------------
#
# pritipatel 2096
# migrants 299
# borisjohnson 233
# refugees 203
# uk 130
# homeoffice 108
# asylumseekers 100
# immigration 96
# refugeeswelcome 76
# immigrants 67
# brexit 65
# france 61
# politics 54
# dover 49
# nigelfarage 48
#
# ------------------------------------------
#
# nhs 1480
# healthcare 233
# capitalist 211
# convicts 211
# addicts 211
# beauty 211
# philosophies 211
# immigrants 202
# migrants 195
# thoughts 154
# privatization 154
# freehealthcare 153
# world 153
# sick 153
# eu 137
#
# ------------------------------------------

# %%
df_tweets_channel_2 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,channel_hashtags_2))]
df_tweets_channel_2.shape
# Out:
# (22558, 23)

# %%
hashtag_count = get_entity_count(df_tweets_channel_2["hashtags"])

# Remove hashtags that are already in list
for hashtag in channel_hashtags_2:
    hashtag_count.pop(hashtag)

# Sort hashtags by frequency
hashtag_count_sorted = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
hashtag_count_sorted[:25]
# Out:
# [('refugees', 3322),
#  ('migrants', 2844),
#  ('eu', 2498),
#  ('turkey', 1691),
#  ('syria', 1483),
#  ('muslim', 1385),
#  ('erdogan', 1340),
#  ('jihadists', 1316),
#  ('immigrants', 1180),
#  ('immigration', 801),
#  ('covid19', 668),
#  ('illegal', 422),
#  ('borisjohnson', 413),
#  ('europe', 409),
#  ('racism', 407),
#  ('refugee', 393),
#  ('asylumseekers', 388),
#  ('migrant', 376),
#  ('migration', 375),
#  ('asylum', 367),
#  ('refugeeswelcome', 327),
#  ('usa', 317),
#  ('humanrights', 317),
#  ('news', 309),
#  ('politics', 306)]

# %%
channel_hashtags_3 = channel_hashtags_2 + ["borisjohnson"]

# %%
hashtag_check(df_tweets,["borisjohnson"],"hashtags")
# Out:
# borisjohnson 833
# pritipatel 233
# migrants 134
# uk 83
# brexit 71
# refugees 59
# immigrants 49
# immigration 48
# covid19 43
# nigelfarage 39
# boris 38
# france 32
# refugeeswelcome 29
# tories 29
# eu 28
#
# ------------------------------------------

# %%
df_tweets_channel_3 = df_tweets[df_tweets["hashtags"].apply(lambda x: element_in_list(x,channel_hashtags_3))]
df_tweets_channel_3.shape
# Out:
# (22978, 23)

# %%
channel_hashtag_qualifier = channel_hashtags_3

# %% [markdown]
# #### Create event qualifier

# %%
annotation_count = get_entity_count(df_tweets_channel_3["annotations"])

# Sort hashtags by frequency
annotation_count_sorted = sorted(annotation_count.items(), key=lambda x: x[1], reverse=True)
annotation_count_sorted[:40]
# Out:
# [('uk', 4721),
#  ('france', 1435),
#  ('islamising europe', 1314),
#  ('eu', 692),
#  ('britain', 621),
#  ('europe', 414),
#  ('nhs', 383),
#  ('brexit', 375),
#  ('us', 327),
#  ('priti patel', 324),
#  ('kent refugees support network', 262),
#  ('dover', 208),
#  ('england', 201),
#  ('germany', 185),
#  ('paris', 174),
#  ('calais', 156),
#  ('u.k.', 146),
#  ('spain', 138),
#  ('kent refugees action network', 134),
#  ('tories', 128),
#  ('kent', 128),
#  ('london', 116),
#  ('farage', 113),
#  ('boris johnson', 112),
#  ('kent refugees', 105),
#  ('boris', 97),
#  ('trump', 95),
#  ('home office', 91),
#  ('nigel farage', 87),
#  ('belgium', 85),
#  ('hong kong', 84),
#  ('tory', 84),
#  ('syria', 83),
#  ('india', 82),
#  ('turkey', 80),
#  ('dublin', 78),
#  ('johnson', 76),
#  ('covid', 70),
#  ('bbc news', 67),
#  ('bbc', 65)]

# %%
channel_annotation_qualifier = ["uk","france","britain","priti patel","kent refugees support network","dover","england",
                                "paris","calais","u.k.","kent refugees action network","tories","kent","london","farage",
                                "boris johnson","kent refugees","nigel farage","tory","bbc"]

# %%
mention_count = get_entity_count(df_tweets_channel_3["mentions"])

# Sort hashtags by frequency
mention_count_sorted = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
mention_count_sorted[:25]
# Out:
# [('pritipatel', 1292),
#  ('borisjohnson', 849),
#  ('nigel_farage', 697),
#  ('refugees', 401),
#  ('conservatives', 291),
#  ('ukhomeoffice', 263),
#  ('bbcnews', 250),
#  ('unhcrturkey', 244),
#  ('skynews', 198),
#  ('emmanuelmacron', 153),
#  ('mailonline', 121),
#  ('realdonaldtrump', 118),
#  ('guardian', 116),
#  ('10downingstreet', 111),
#  ('lbc', 97),
#  ('un', 89),
#  ('uklabour', 85),
#  ('youtube', 84),
#  ('matthancock', 80),
#  ('leaveeuofficial', 77),
#  ('migrationwatch', 72),
#  ('dominicraab', 70),
#  ('simonjonesnews', 69),
#  ('royalfamily', 68),
#  ('kensingtonroyal', 64)]

# %%
channel_mention_qualifier = ["pritipatel","borisjohnson","nigel_farage","conservatives","ukhomeoffice","bbcnews","skynews",
                             "emmanuelmacron","mailonline","guardian","10downingstreet","lbc", "uklabour","matthancock",
                             "leaveeuofficial","dominicraab","simonjonesnews","royalfamily","kensingtonroyal"]

# %% [markdown]
# #### Create event dataset

# %%
channel_qualifier = set(channel_hashtag_qualifier + channel_annotation_qualifier + channel_mention_qualifier)

# %%
df_tweets_channel = df_tweets[df_tweets["text_clean"].apply(lambda x: element_in_list(x.split(" "),channel_qualifier))]

# %%
df_tweets_channel.shape
# Out:
# (604536, 23)

# %% [markdown]
# #### Visualize event

# %%
plot_event_timeline(df_tweets_channel,"week")

# %%
plot_entity_timeline(df_tweets_channel, "week", list(channel_qualifier)[:5], "hashtags")

# %% [markdown]
# ---
# ## Overview of events

# %%
    df_grouped = group_df(df,interval)
    
    plt.figure(figsize=(16, 8))
    plt.plot(df_grouped["total"])
    plt.title(f"Number of tweets about refugees and related groups by {interval}")
    plt.xticks(rotation=90)
    plt.show()

# %%
df_tweets_grouped = group_df(df_tweets,"week")
df_tweets_channel_grouped = group_df(df_tweets_channel,"week")
df_tweets_beirut_grouped = group_df(df_tweets_beirut,"week")
df_tweets_moria_grouped = group_df(df_tweets_moria,"week")
df_tweets_tigray_grouped = group_df(df_tweets_tigray,"week")

# %%
plt.figure(figsize=(16, 8))
plt.plot(df_tweets_grouped["total"], label = "Total")
plt.plot(df_tweets_channel_grouped["total"], label = "Channel")
plt.plot(df_tweets_beirut_grouped["total"], label = "Beirut")
plt.plot(df_tweets_moria_grouped["total"], label = "Moria")
plt.plot(df_tweets_tigray_grouped["total"], label = "Tigray")
plt.title(f"Number of tweets about refugees and related groups by week")
plt.xticks(rotation=90)
plt.legend()
plt.show()
