# %% [markdown]
# # Twitter User Fetch
# https://developer.twitter.com/en/docs/twitter-api/early-access

# %% [markdown]
# ### Import relevant libraries

# %%
import requests
import os
import json
import re

import time
import datetime

from collections import defaultdict

import matplotlib.pyplot as plt
import pandas as pd

# %%
#searchtweets-v2
# https://github.com/twitterdev/search-tweets-python/tree/v2

# %% [markdown]
# ### Set static variables

# %%
#consumer_key = "nFLuWKu9TJJnZqFrGG1oDUjfN"
#consumer_secret = "COoAwWDANn8K8zzmqN6hJaGIPqj6oJxRmO6KCtJ7kq3ukYq6Xf"
#access_token = "1259532157703380992-ijiLvGO3gK9NlxKtZ4EkzJb2HMOxSU"
#access_token_secret = "xBM7aIrKWWsacX1GgPgZzk5181fl43bEK9fquBYuJE78G"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAANxrNAEAAAAAYdSsKk0mhqqWBoM39zZCiTx5%2FBA%3DyzXLwPs1pLxTqBn8iXfKqluGsJSnKqevzbJ0l2fPvTsX4oPY6s"
#file_path = "/Users/Janiwo/Dropbox/Master thesis data/"
FILE_PATH = r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data"
ENDPOINT = "https://api.twitter.com/2/users/:id/following"

# %% [markdown]
# ### Define Functions

# %%
def create_headers(bearer_token):
    headers = {"Authorization": f"Bearer {bearer_token}"}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    print(response.status_code)
    #print(response.headers)
    if response.status_code == 429:
        time_to_sleep = float(response.headers["x-rate-limit-reset"]) - time.time()
        print(f"Rate limit reached. Sleeping for {time_to_sleep} seconds...")
        time.sleep(time_to_sleep)
        
        response = requests.request("GET", url, headers=headers, params=params)
        print(response.status_code)
    
    elif response.status_code != 200:
        raise Exception(response.status_code, response.text)
          
    return response.json()

def write_to_json(response):
    
    with open(file, "a") as json_file:
        json_file.write(f"{json.dumps(response)}\n")

def main(endpoint):
    headers = create_headers(BEARER_TOKEN)
    json_response = connect_to_endpoint(endpoint, headers, query_params)
    write_to_json(json_response)
    #response_data_norm, response_includes_norm = create_csv(json_response)
    
    try:
        query_params["pagination_token"] = json_response["meta"]["pagination_token"]
        print(f'Next Token: {query_params["pagination_token"]}')
        time.sleep(1)
    
    except KeyError:
        global next_page
        next_page = False
        print("No further tokens available. Going to next user.")

def load_full_json(file):
    
    json_complete = {"data":list(),"users":list()}
    
    with open(file, "r") as json_file:
        for line in json_file:
            data = json.loads(line)
            json_complete["data"].extend(data["data"])
            json_complete["users"].extend(data["includes"]["users"])
    
    return json_complete

# %% [markdown]
# # Load User File

# %%
df_users = pd.read_csv(FILE_PATH + "\df_users.csv")
df_users.drop("Unnamed: 0", axis=1, inplace=True)
df_users.head()
# Out:
#                                          description       username  verified  \
# 0                       PhD Candidate at Engineering       GaKahsay     False
# 1                                   #STOPWARONTIGRAY    sayumek2020     False
# 2  ማርያም ፅዮን ምስ ወዳ ፅላል ትግራይ ትኩነልና \n#TigrayGenocid...  AbbyH06586436     False
# 3                                                NaN  MahfuzHussien     False
# 4  Journalists Standing up for human rights acros...      jonewales     False
#
#                     name                created_at                   id  url  \
# 0              Kahsay GA  2020-11-13T15:55:37.000Z  1327278886380515328  NaN
# 1                  Selam  2020-11-04T08:23:06.000Z  1323903491044188161  NaN
# 2  Abby |ዓይነይ-ትግራይ እንዲኺ|  2020-11-04T23:24:06.000Z  1324130252008816640  NaN
# 3         Mahfuz Hussien  2013-01-22T22:05:12.000Z           1112761003  NaN
# 4            William_Sea  2020-01-02T19:56:07.000Z  1212824799107375105  NaN
#
#    public_metrics.followers_count  public_metrics.following_count  \
# 0                             817                            1215
# 1                              43                             156
# 2                              54                             232
# 3                             151                             788
# 4                             315                            1913
#
#    public_metrics.tweet_count  public_metrics.listed_count     location
# 0                        4427                            0          NaN
# 1                        3531                            0          NaN
# 2                        1129                            1  New Zealand
# 3                        1455                            1          NaN
# 4                        2710                            3          NaN

# %%
df_users.shape
# Out:
# (1928500, 12)

# %%
df_users_100 = df_users[df_users["public_metrics.following_count"] >= 1000]

# %%
user_ids = set(df_users_100["id"])

# %%
len(user_ids)
# Out:
# 452973

# %% [markdown]
# # General Query

# %%
list(user_ids)[0]
# Out:
# 45088774

# %%
headers = create_headers(BEARER_TOKEN)

# %%
endpoint = connect_to_endpoint(f"https://api.twitter.com/2/users/{list(user_ids)[0]}/following", headers, query_params)
# Out:
# 400
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-35-890c20c67c29> in <module>
# ----> 1 endpoint = connect_to_endpoint(f"https://api.twitter.com/2/users/{list(user_ids)[0]}/following", headers, query_params)
#
# <ipython-input-26-0ccc5b264855> in connect_to_endpoint(url, headers, params)
#      17
#      18     elif response.status_code != 200:
# ---> 19         raise Exception(response.status_code, response.text)
#      20
#      21     return response.json()
#
# Exception: (400, '{"errors":[{"parameters":{"next_token":["H6I7E4BQB0M16ZZZ"]},"message":"The query parameter [next_token] is not one of [id,max_results,pagination_token,expansions,tweet.fields,user.fields]"}],"title":"Invalid Request","detail":"One or more parameters to your request was invalid.","type":"https://api.twitter.com/2/problems/invalid-request"}')

# %%
next_token = None
ctr = 0

query_params = {'max_results': 1000, #max number is 1,000
                'pagination_token': next_token}


file_ID = f'/batch1.txt'
file = FILE_PATH + file_ID


print("Starting...")
for user_id in list(user_ids)[:5]:
    username = df_users[df_users["id"] == user_id]["username"]
    following_count = df_users[df_users["id"] == user_id]["public_metrics.following_count"]
    
    next_page = True
    
    print(f"Retrieving Accounts followed by {username}. Total number of accounts: {following_count}.")
    endpoint = f"https://api.twitter.com/2/users/{user_id}/following"
    while next_page == True:
        main(endpoint)
# Out:
# Starting...
# Retrieving Accounts followed by 1170270    alexalderthay
# Name: username, dtype: object. Total number of accounts: 1170270    1044
# Name: public_metrics.following_count, dtype: int64.
# 200
# No further tokens available. End of Process.
# Retrieving Accounts followed by 705681    jack
# Name: username, dtype: object. Total number of accounts: 705681    4608
# Name: public_metrics.following_count, dtype: int64.
# 200
# No further tokens available. End of Process.
# Retrieving Accounts followed by 1699877    NutshellsGuy
# Name: username, dtype: object. Total number of accounts: 1699877    1361
# Name: public_metrics.following_count, dtype: int64.
# 200
# No further tokens available. End of Process.
# Retrieving Accounts followed by 823873    tonystubblebine
# Name: username, dtype: object. Total number of accounts: 823873    5780
# Name: public_metrics.following_count, dtype: int64.
# 200
# No further tokens available. End of Process.
# Retrieving Accounts followed by 936071    Photojett
# Name: username, dtype: object. Total number of accounts: 936071    1005
# Name: public_metrics.following_count, dtype: int64.
# 200
# No further tokens available. End of Process.

# %%
file
# Out:
# 'C:\\Users\\jawo19ad\\Dropbox (CBS)\\Master thesis data/batch1.txt'

# %%
json_complete = {"data":list()}
with open(file, "r") as json_file:
    for line in json_file:
        json_complete["data"].extend(data["data"])

# %%
json_complete["data"]
# Out:
# [{'id': '1192861100804575234', 'name': 'Katy', 'username': 'KatyJayne101'},
#  {'id': '16044025', 'name': 'Tour of Britain 🇬🇧', 'username': 'TourofBritain'},
#  {'id': '288369320',
#   'name': 'Mark Cooper-Jones',
#   'username': 'markcooperjones'},
#  {'id': '43919376', 'name': 'Jay Foreman', 'username': 'jayforeman'},
#  {'id': '19211352', 'name': 'Cherie Pridham', 'username': 'ChezPro'},
#  {'id': '22621511', 'name': 'Gary Delaney', 'username': 'GaryDelaney'},
#  {'id': '349083462',
#   'name': 'Tirreno Adriatico',
#   'username': 'TirrenAdriatico'},
#  {'id': '108441763', 'name': 'Ben Swift', 'username': 'swiftybswift'},
#  {'id': '3320963777', 'name': 'Conyers MFL', 'username': 'conyersmfl'},
#  {'id': '3224085551',
#   'name': 'Maillot à Pois E.Leclerc',
#   'username': 'maillotapois'},
#  {'id': '882284078', 'name': 'stycle_design', 'username': 'stycle_design'},
#  {'id': '507201572', 'name': 'Fleur Faure', 'username': 'FleurFaure'},
#  {'id': '3338835075',
#   'name': 'Maillot Distinctif.',
#   'username': 'MDistinctif'},
#  {'id': '2285051', 'name': 'Rob Manuel 🌭', 'username': 'robmanuel'},
#  {'id': '1080631375122837506',
#   'name': 'daemoncycling',
#   'username': 'daemoncycling'},
#  {'id': '4436617815', 'name': 'Myles', 'username': 'PusherOfPedals'},
#  {'id': '1100256855035703296',
#   'name': 'InternationElles',
#   'username': 'InternationEll2'},
#  {'id': '604767363', 'name': 'Ros Pritchard OBE', 'username': 'BHHPAros'},
#  {'id': '19533512', 'name': 'Samuel West 💙', 'username': 'exitthelemming'},
#  {'id': '2536057610', 'name': 'Marie-Fleur', 'username': 'MarieFleur3'},
#  {'id': '70707518', 'name': 'Cillian Kelly', 'username': 'irishpeloton'},
#  {'id': '1232783237623119872',
#   'name': "NASA's Perseverance Mars Rover",
#   'username': 'NASAPersevere'},
#  {'id': '1360878978211475458',
#   'name': 'Tour Haut Var',
#   'username': 'tourhautvar'},
#  {'id': '1246200438',
#   'name': 'Father Ted Quote of the Day',
#   'username': 'FrTedQOTD'},
#  {'id': '1358779937948327937',
#   'name': 'pro cycling trumps',
#   'username': 'procycletrumps'},
#  {'id': '15383064', 'name': 'Simon Wear', 'username': 'simonwear'},
#  {'id': '726742474568376320',
#   'name': 'La Bicicleta News',
#   'username': 'LaBicicletaNews'},
#  {'id': '109814286', 'name': 'Hannah Walker', 'username': 'spannawalker'},
#  {'id': '54816467', 'name': 'Mihai Simion', 'username': 'faustocoppi60'},
#  {'id': '34001965', 'name': 'Bob Jungels', 'username': 'BobJungels'},
#  {'id': '202740241', 'name': 'Emma Vardy', 'username': 'EmmaVardyTV'},
#  {'id': '953239759480147968',
#   'name': 'CyclingLegends',
#   'username': 'CyclingLegends1'},
#  {'id': '153121957', 'name': 'Laura Winter', 'username': 'lauracwinter'},
#  {'id': '71354971', 'name': 'cyclephotos', 'username': 'cyclephotos'},
#  {'id': '2229930931', 'name': 'Eva zu Beck', 'username': 'evabiankaz'},
#  {'id': '123015364', 'name': 'Allison Janney', 'username': 'AllisonBJanney'},
#  {'id': '1295397293340991494',
#   'name': 'The Late Brake Show',
#   'username': 'LateBrakeShow'},
#  {'id': '84035041', 'name': 'Christina Pagel', 'username': 'chrischirp'},
#  {'id': '959173934766837761',
#   'name': 'The Irish Border',
#   'username': 'BorderIrish'},
#  {'id': '1278485785713442818',
#   'name': 'Scottish Border 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#   'username': 'ScotBorderOG'},
#  {'id': '110509537', 'name': 'Thom Yorke', 'username': 'thomyorke'},
#  {'id': '939294302', 'name': 'Class Charts', 'username': 'Classcharts'},
#  {'id': '1207716502281080832',
#   'name': 'João Almeida',
#   'username': 'JooAlmeida98'},
#  {'id': '2569599561', 'name': 'Tom Haward', 'username': 'HawardTom'},
#  {'id': '1323730225067339784',
#   'name': 'The White House',
#   'username': 'WhiteHouse'},
#  {'id': '1349149096909668363', 'name': 'President Biden', 'username': 'POTUS'},
#  {'id': '1029331279022575617',
#   'name': 'TRINITY Racing',
#   'username': 'TrinityRacing_'},
#  {'id': '2168717730', 'name': 'Cameron Mason', 'username': 'camerooney_'},
#  {'id': '400953126', 'name': 'Hugo Gye', 'username': 'HugoGye'},
#  {'id': '162071541', 'name': 'Shaun Lintern', 'username': 'ShaunLintern'},
#  {'id': '718182124948426753',
#   'name': 'Elynor Backstedt',
#   'username': 'EBackstedt6'},
#  {'id': '1345309846690791424',
#   'name': 'Alpecin-Fenix Cycling Team',
#   'username': 'AlpecinFenix'},
#  {'id': '192892778', 'name': 'Lucrezia Millarini', 'username': 'lucrezianews'},
#  {'id': '155203891', 'name': "Naomi O'Leary", 'username': 'NaomiOhReally'},
#  {'id': '966701634',
#   'name': 'Lochfyne langoustines Ltd & Lochfyne seafarms Ltd',
#   'username': 'LochfyneLangous'},
#  {'id': '69080476', 'name': 'Jim Pickard', 'username': 'PickardJE'},
#  {'id': '246459126', 'name': 'Jonathan Portes', 'username': 'jdportes'},
#  {'id': '996078704', 'name': 'Lucy', 'username': 'LucyMannall'},
#  {'id': '151655222', 'name': 'Ben Kentish', 'username': 'BenKentish'},
#  {'id': '1346781110504747008',
#   'name': 'UK-EU Politics 🇪🇺🇬🇧',
#   'username': 'politics_eu'},
#  {'id': '229459251', 'name': 'Vick Hope', 'username': 'VickNHope'},
#  {'id': '500212522', 'name': 'Peter Mawson', 'username': 'HighFarndale'},
#  {'id': '253453519', 'name': '100%BRUMOTTI', 'username': 'brumottistar'},
#  {'id': '19916572', 'name': 'Jason Plato', 'username': 'jasonplato'},
#  {'id': '86093740', 'name': 'Badly Drawn Boy', 'username': 'badly_drawn_boy'},
#  {'id': '238706137',
#   'name': 'Dave Bradshaw 💙 #IhavehadOxfordAZvaccine',
#   'username': 'djbradshaw64'},
#  {'id': '300339564', 'name': 'WowHaus', 'username': 'WowHauser'},
#  {'id': '20427720', 'name': 'Simon McCoy', 'username': 'BBCSimonMcCoy'},
#  {'id': '33823446', 'name': 'michael sheen 💙', 'username': 'michaelsheen'},
#  {'id': '897343767610568704',
#   'name': 'Great Cycling Victories',
#   'username': 'gcvictories'},
#  {'id': '47854857', 'name': 'Alastair Leithead', 'username': 'aleithead'},
#  {'id': '1315053256343719936',
#   'name': 'Dr Julia Grace Patterson 💙',
#   'username': 'JujuliaGrace'},
#  {'id': '157044469', 'name': 'Hugh Pym', 'username': 'BBCHughPym'},
#  {'id': '2230539338', 'name': 'David Gauke', 'username': 'DavidGauke'},
#  {'id': '146526575',
#   'name': 'Mathieu Van der Poel',
#   'username': 'mathieuvdpoel'},
#  {'id': '1226113371482808321',
#   'name': 'Sebastian Fischer',
#   'username': 'SFischer_EU'},
#  {'id': '33840986',
#   'name': 'Château de Chambord',
#   'username': 'domainechambord'},
#  {'id': '18701897', 'name': 'Dino Sofos', 'username': 'dinosofos'},
#  {'id': '601172661', 'name': 'John Niven HQ', 'username': 'estellecostanza'},
#  {'id': '23813407', 'name': 'Jon Stone', 'username': 'joncstone'},
#  {'id': '138717046', 'name': 'Bruno Waterfield', 'username': 'BrunoBrussels'},
#  {'id': '545703074', 'name': 'Eric Mamer', 'username': 'MamerEric'},
#  {'id': '31101821', 'name': 'Larry Budd', 'username': 'larrybudd1'},
#  {'id': '1341465628746641408',
#   'name': 'Le French Border ⛔️🇫🇷',
#   'username': 'lefrenchborder'},
#  {'id': '31105922', 'name': 'Mr Paul Dunphy OBE', 'username': 'mrpauldunphy'},
#  {'id': '97621178', 'name': '🥃 Larry & Paul 🥃', 'username': 'larryandpaul'},
#  {'id': '4927450223', 'name': 'Night Lights', 'username': 'NightLights_AM'},
#  {'id': '42229043', 'name': 'Andrew Connell', 'username': 'andrewiconnell'},
#  {'id': '22352061', 'name': 'Anna Isaac', 'username': 'Annaisaac'},
#  {'id': '311397505', 'name': 'Luke Rowe', 'username': 'LukeRowe1990'},
#  {'id': '1141660959364308992',
#   'name': 'Catherine Colonna',
#   'username': 'AmbColonna'},
#  {'id': '2494186513', 'name': 'David Henig', 'username': 'DavidHenigUK'},
#  {'id': '965991485819817984',
#   'name': 'Dr Anna Jerzewska',
#   'username': 'AnnaJerzewska'},
#  {'id': '37188908', 'name': 'José Been', 'username': 'TourDeJose'},
#  {'id': '137295176', 'name': 'Henry Mance', 'username': 'henrymance'},
#  {'id': '174151902', 'name': 'Prof. Devi Sridhar', 'username': 'devisridhar'},
#  {'id': '3297800601',
#   'name': 'The Secret Barrister',
#   'username': 'BarristerSecret'},
#  {'id': '1060578475', 'name': 'Lionel Barber', 'username': 'lionelbarber'},
#  {'id': '72827013', 'name': 'Jennifer Williams', 'username': 'JenWilliamsMEN'},
#  {'id': '2723961543', 'name': 'BumTree', 'username': 'Bum_Tree_'},
#  {'id': '1143319274', 'name': 'Dr Elisabetta', 'username': 'ViralRNA'},
#  {'id': '20282205', 'name': 'Jeremy Powers', 'username': 'JeremyPowers'},
#  {'id': '939091', 'name': 'Joe Biden', 'username': 'JoeBiden'},
#  {'id': '955157661212987392',
#   'name': 'Parody Boris Johnson',
#   'username': 'BorisJohnson_MP'},
#  {'id': '17614849', 'name': 'Pierre Briançon', 'username': 'pierrebri'},
#  {'id': '1299686030875004928', 'name': 'Byline TV', 'username': 'BylineTV'},
#  {'id': '20973388', 'name': 'LBC', 'username': 'LBC'},
#  {'id': '1206388216338829315',
#   'name': 'Northern Independence Party \U0001f7e8\U0001f7e5',
#   'username': 'FreeNorthNow'},
#  {'id': '2382227424',
#   'name': 'Dr Rosena Allin-Khan 💙',
#   'username': 'DrRosena'},
#  {'id': '3189001238',
#   'name': 'Scientists for EU',
#   'username': 'Scientists4EU'},
#  {'id': '34247411',
#   'name': 'Dr Mike Galsworthy',
#   'username': 'mikegalsworthy'},
#  {'id': '39500950',
#   'name': 'Alexander De Croo',
#   'username': 'alexanderdecroo'},
#  {'id': '862259155599544320',
#   'name': 'Cyclocross24.com',
#   'username': 'cyclocross24'},
#  {'id': '870729813149048832',
#   'name': 'Florian Senechal-Staelens',
#   'username': 'flosenech'},
#  {'id': '335312037', 'name': 'Lewis Goodall', 'username': 'lewis_goodall'},
#  {'id': '906437834', 'name': 'Fre Pollentier', 'username': 'Fre_Pollentier'},
#  {'id': '120257330', 'name': 'Jill Rutter', 'username': 'jillongovt'},
#  {'id': '68213392', 'name': 'Georg von Harrach', 'username': 'georgvh'},
#  {'id': '423490958', 'name': 'Fell Top Assessors', 'username': 'LakesWeather'},
#  {'id': '210493917', 'name': 'JohnShirleyLtd', 'username': 'JohnShirleyLtd'},
#  {'id': '239548368', 'name': 'Theo Usherwood', 'username': 'theousherwood'},
#  {'id': '732958867106189312',
#   'name': 'Zoe Backstedt',
#   'username': 'Backstedt_Zoe'},
#  {'id': '58436094', 'name': 'Marina Purkiss', 'username': 'MarinaNigrelli'},
#  {'id': '19884529', 'name': 'Tom Peck', 'username': 'tompeck'},
#  {'id': '849400327', 'name': 'Chris Pritchard', 'username': 'chris_pritch'},
#  {'id': '30287543', 'name': 'Lawrence Carpenter', 'username': 'bikerlawrence'},
#  {'id': '2712345189',
#   'name': 'Cameron Jeffers',
#   'username': 'Cameron_Jeffers'},
#  {'id': '2808695603', 'name': 'Phil', 'username': 'Philmoorhouse76'},
#  {'id': '106182754', 'name': 'Richard Schiff', 'username': 'Richard_Schiff'},
#  {'id': '278528649', 'name': 'Marty MacDonald', 'username': 'MartyMacTV'},
#  {'id': '419773780', 'name': 'Fred Pye', 'username': 'NoughtPointFour'},
#  {'id': '4382647421',
#   'name': 'Ribble Weldtite Pro Cycling',
#   'username': 'RibbleWeldtite'},
#  {'id': '36777272', 'name': 'Biffy Clyro', 'username': 'BiffyClyro'},
#  {'id': '32521041', 'name': 'amylaurenjones', 'username': 'amylaurenjones'},
#  {'id': '23759767', 'name': 'Rachel Parris', 'username': 'rachelparris'},
#  {'id': '19313770',
#   'name': 'Nihal Arthanayake 🏳️\u200d🌈🇱🇰🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🇬🇧',
#   'username': 'TherealNihal'},
#  {'id': '108713959', 'name': 'Mary McCormack', 'username': 'marycmccormack'},
#  {'id': '3683068757',
#   'name': 'The West Wing Weekly',
#   'username': 'WestWingWeekly'},
#  {'id': '3290959528',
#   'name': 'The British Continental',
#   'username': 'BritishConti'},
#  {'id': '1715949703', 'name': 'David Guénel', 'username': 'davidguenel'},
#  {'id': '1323186509894328322',
#   'name': 'TheRidersUnion',
#   'username': 'TheRidersUnion'},
#  {'id': '1035528642305118210',
#   'name': 'CarltonBalls',
#   'username': 'CarltonBalls'},
#  {'id': '2904913023', 'name': 'James Felton', 'username': 'JimMFelton'},
#  {'id': '784826460481683456', 'name': 'Mark Donovan', 'username': 'markdon99'},
#  {'id': '3791398932', 'name': 'Michael Storer', 'username': 'mjstorer_au'},
#  {'id': '1322121949745696769',
#   'name': 'VilXVision',
#   'username': 'itsyaboiyeet6'},
#  {'id': '252743984',
#   'name': 'ProCyclingStats.com',
#   'username': 'ProCyclingStats'},
#  {'id': '20559491', 'name': 'Angela Scanlon', 'username': 'angelascanlon'},
#  {'id': '302854130', 'name': 'Russ Ellis', 'username': 'therussellellis'},
#  {'id': '3050854424', 'name': 'Nicholas Dlamini', 'username': 'nich_dlamini'},
#  {'id': '69469164', 'name': 'Phil Gaimon', 'username': 'philgaimon'},
#  {'id': '776843827990654976',
#   'name': 'Helicóptero de La Vuelta',
#   'username': 'HelicopteroLV'},
#  {'id': '237418237', 'name': 'Willie Smit', 'username': 'williesmurfy'},
#  {'id': '1112452968996110337',
#   'name': 'Cycling out of context',
#   'username': 'OutOfCycling'},
#  {'id': '1561086218', 'name': 'CafeRoubaix', 'username': 'CafeRoubaix'},
#  {'id': '1199650111980261376',
#   'name': 'Donald Tusk',
#   'username': 'donaldtuskEPP'},
#  {'id': '84125491', 'name': 'Ed Byrne', 'username': 'MrEdByrne'},
#  {'id': '774195721000087552',
#   'name': 'Bloomberg Brexit',
#   'username': 'Brexit'},
#  {'id': '2257898882',
#   'name': 'Cycling Bargains🔥🚲',
#   'username': 'CycleBargains'},
#  {'id': '1359068448', 'name': 'PHE North East', 'username': 'PHE_NorthEast'},
#  {'id': '19362912', 'name': 'Mikkel Condé v2.0', 'username': 'mrconde'},
#  {'id': '1652177576', 'name': 'Alex Taylor', 'username': 'AlexTaylorNews'},
#  {'id': '143779403', 'name': 'Andy Burnham', 'username': 'AndyBurnhamGM'},
#  {'id': '436862603', 'name': 'Tobias', 'username': 'TobiasDahlhaus'},
#  {'id': '1196357184201920512', 'name': 'GCN Racing', 'username': 'GcnRacing'},
#  {'id': '2222193802', 'name': 'James Thomas', 'username': 'bikefitjames'},
#  {'id': '88771714', 'name': 'Graham Watson', 'username': 'grahamwatson10'},
#  {'id': '708772298656972800',
#   'name': 'La Flamme Rouge',
#   'username': 'laflammerouge16'},
#  {'id': '1111660304210034688',
#   'name': 'We Hate Fly-Tipping',
#   'username': 'ClearWasteApp'},
#  {'id': '1724936154', 'name': 'Andy Preston Mayor', 'username': 'Tees_Issues'},
#  {'id': '281496426', 'name': 'Andy Preston', 'username': 'preston_andy'},
#  {'id': '400677370',
#   'name': 'Sofie Vanrafelghem',
#   'username': 'SVanrafelghem'},
#  {'id': '20136892', 'name': 'Stephen Mangan', 'username': 'StephenMangan'},
#  {'id': '111553960', 'name': 'UCI', 'username': 'UCI_cycling'},
#  {'id': '3510293175', 'name': 'Ginevra', 'username': 'ginevragarga'},
#  {'id': '1308758393373458437',
#   'name': 'The Kent Border',
#   'username': 'BorderKent'},
#  {'id': '382008647', 'name': 'Joe Mayes', 'username': 'Joe_Mayes'},
#  {'id': '2933525657', 'name': 'Tees Business', 'username': 'Tees_Business'},
#  {'id': '236467587', 'name': 'Tara Bennett', 'username': 'Tee4Tara'},
#  {'id': '773247114902134784',
#   'name': 'Tadej Pogačar',
#   'username': 'TamauPogi'},
#  {'id': '24107386', 'name': 'Guy Voisin', 'username': 'GuyNeb'},
#  {'id': '23305501', 'name': 'Matt Forde', 'username': 'mattforde'},
#  {'id': '827909929273016321', 'name': 'Brad Wiggins', 'username': 'SirWiggo'},
#  {'id': '1214902398',
#   'name': 'Amandine Bardet',
#   'username': 'AmandineBardet1'},
#  {'id': '49108112', 'name': 'Rebecca Front 💙', 'username': 'RebeccaFront'},
#  {'id': '63691776', 'name': 'Nicky Campbell', 'username': 'NickyAACampbell'},
#  {'id': '613832082', 'name': 'Marianna Spring', 'username': 'mariannaspring'},
#  {'id': '114422199', 'name': 'Vincenzo Nibali', 'username': 'vincenzonibali'},
#  {'id': '973876472', 'name': 'Pete', 'username': 'road_THEORY'},
#  {'id': '952428721', 'name': 'Hirschi Marc', 'username': 'MarcHirschi'},
#  {'id': '1142770220', 'name': 'Matt Winston', 'username': 'Mattw1nston'},
#  {'id': '364982048', 'name': 'Kévin', 'username': 'KevReza'},
#  {'id': '940990381671485440',
#   'name': 'SAINT PIRAN',
#   'username': 'saintpiran1'},
#  {'id': '1230135006594584576', 'name': 'Robyn', 'username': 'robynjournalist'},
#  {'id': '29609364',
#   'name': 'Intermarché-Wanty-Gobert',
#   'username': 'IntermarcheWG'},
#  {'id': '273275593', 'name': 'Team BikeExchange', 'username': 'GreenEDGEteam'},
#  {'id': '2390900551', 'name': 'Casquetteurs', 'username': 'casquetteurs'},
#  {'id': '91650622', 'name': 'Louise Gibson (loukew)', 'username': 'lougloug'},
#  {'id': '54991369', 'name': 'Phil Lowe', 'username': 'Lowe_Profile_'},
#  {'id': '517561066',
#   'name': 'Mr Mark Fairhurst',
#   'username': 'MrMarkFairhurst'},
#  {'id': '100267582', 'name': 'Laura Meseguer', 'username': 'Laura_Meseguer'},
#  {'id': '2361827984', 'name': 'Sepp Kuss', 'username': 'seppkuss'},
#  {'id': '1243865208826875904',
#   'name': 'Pro Cycling Memories',
#   'username': 'ClipsCycling'},
#  {'id': '1291472657049886723',
#   'name': 'Chrome Social Marketing',
#   'username': 'ChromeSocialM'},
#  {'id': '172432205', 'name': 'Diane Morgan', 'username': 'missdianemorgan'},
#  {'id': '241226293', 'name': 'Jake', 'username': 'jakey_stewart'},
#  {'id': '12513592', 'name': 'EF Pro Cycling', 'username': 'EFprocycling'},
#  {'id': '401320866', 'name': 'Pavel Sivakov', 'username': 'PavelSivakov'},
#  {'id': '2999447739',
#   'name': 'The UK in a Changing Europe',
#   'username': 'UKandEU'},
#  {'id': '875475686676455424',
#   'name': 'individuali',
#   'username': 'individuali_art'},
#  {'id': '136004952', 'name': 'Andrew Neil', 'username': 'afneil'},
#  {'id': '333502135',
#   'name': 'Bénédicte Paviot',
#   'username': 'BenedictePaviot'},
#  {'id': '1235685215810531330',
#   'name': 'Malcolm Elliott',
#   'username': 'malcolmelliott0'},
#  {'id': '1023888296018149376',
#   'name': 'Ollie Bridgewood',
#   'username': 'OllieGCN'},
#  {'id': '1145734481615212544',
#   'name': 'Julian Alaphilippe Officiel',
#   'username': 'alafpolak1'},
#  {'id': '16946023', 'name': 'Edward Pickering', 'username': 'EdwardPickering'},
#  {'id': '759041875592347648',
#   'name': 'Will Newton',
#   'username': 'InsidePeloton96'},
#  {'id': '2377589106', 'name': 'Lawrence Gilder', 'username': 'LawrenceGilder'},
#  {'id': '868302674', 'name': 'Fabio Jakobsen', 'username': 'FabioJakobsen'},
#  {'id': '3099178877', 'name': 'World Cycling Stats', 'username': 'wcsbike'},
#  {'id': '312567494',
#   'name': 'Florence Villeminot',
#   'username': 'FloVilleminot'},
#  {'id': '136063208', 'name': 'tom owen', 'username': 'tomowencc'},
#  {'id': '1100418318',
#   'name': 'Kirkby Stephen & Upper Eden',
#   'username': 'VisitUpperEden'},
#  {'id': '1581402338', 'name': 'Le Gruppetto', 'username': 'LeGruppetto'},
#  {'id': '20053718', 'name': 'Ralf Little 💙The NHS', 'username': 'RalfLittle'},
#  {'id': '1065999766977503232',
#   'name': 'From Italy with Love',
#   'username': 'ItalyWith'},
#  {'id': '338941390', 'name': 'Vuelta a Burgos', 'username': 'VueltaABurgos'},
#  {'id': '1270303637894582272',
#   'name': 'Bike Is Best',
#   'username': 'BikeIsBestHQ'},
#  {'id': '1243095262630903813',
#   'name': 'Bryony Burrell',
#   'username': 'lifeofbryony'},
#  {'id': '970954161729785856',
#   'name': 'DotWatcher.cc',
#   'username': 'dotwatcher'},
#  {'id': '21724093', 'name': 'Damian Hall', 'username': 'Ultra_Damo'},
#  {'id': '1231146469983432704',
#   'name': 'Peloton&Tales',
#   'username': 'peloton_tales'},
#  {'id': '3403948066', 'name': 'Fastfitness.Tips', 'username': 'fitnessradar'},
#  {'id': '14216436', 'name': 'Geoff Lloyd', 'username': 'GeoffLloyd'},
#  {'id': '1278523894446637057',
#   'name': 'James P',
#   'username': 'Professor_Punk1'},
#  {'id': '19742143', 'name': 'Alan Davies', 'username': 'alandavies1'},
#  {'id': '1254707039500144640', 'name': 'RS Archer', 'username': 'archer_rs'},
#  {'id': '3439784842', 'name': 'St-Feuillien', 'username': 'St_Feuillien'},
#  {'id': '15921675', 'name': 'TheLakesTony 🌳🌲', 'username': 'TheLakesTony'},
#  {'id': '2425571623', 'name': 'Keir Starmer', 'username': 'Keir_Starmer'},
#  {'id': '1081689886070063105',
#   'name': 'TheTimTraveller',
#   'username': 'TheTimTraveller'},
#  {'id': '167307558', 'name': 'Alkoholfreiday', 'username': 'Alkoholfreiday'},
#  {'id': '1227557188140486661',
#   'name': 'AndSoWeRode',
#   'username': 'AndSoWeRode'},
#  {'id': '423576379',
#   'name': 'Cleo Constantine Abram',
#   'username': 'cleoabram'},
#  {'id': '2690350327', 'name': 'Dean Benson', 'username': 'DeanBensonVS'},
#  {'id': '63133438', 'name': 'Franglaise', 'username': 'luxurygite'},
#  {'id': '19530624', 'name': 'Chris Addison💙', 'username': 'mrchrisaddison'},
#  {'id': '1229908256404967430',
#   'name': 'Retroglance7080',
#   'username': 'retroglance7080'},
#  {'id': '105979517', 'name': 'PINOT Thibaut', 'username': 'ThibautPinot'},
#  {'id': '324995650',
#   'name': 'Équipe Cycliste Groupama-FDJ',
#   'username': 'GroupamaFDJ'},
#  {'id': '310746442', 'name': 'Otto English', 'username': 'Otto_English'},
#  {'id': '366036821', 'name': 'Francis Cade', 'username': 'Francis_Cade'},
#  {'id': '19093709', 'name': 'Rory Mulholland', 'username': 'mulhollandrory'},
#  {'id': '1070681708826120192',
#   'name': 'Count Binface',
#   'username': 'CountBinface'},
#  {'id': '107398834', 'name': 'Anand Menon', 'username': 'anandMenon1'},
#  {'id': '34509290', 'name': 'Grace', 'username': 'thisisgrace'},
#  {'id': '29748038', 'name': 'ᒍOᑎ ᑕᗩᑎᑎIᑎGᔕ', 'username': 'jon_cannings'},
#  {'id': '1130021685351079938',
#   'name': 'Buitengebieden',
#   'username': 'buitengebieden_'},
#  {'id': '1258352022132346880',
#   'name': 'Matt Vickers MP',
#   'username': 'Matt_VickersMP'},
#  {'id': '2753626726', 'name': 'Mi5 Trumpton', 'username': 'mi5uk'},
#  {'id': '533315898', 'name': 'Kylie Prankerd', 'username': 'KyliePrankerd'},
#  {'id': '31173665', 'name': 'Richard Osman', 'username': 'richardosman'},
#  {'id': '1733132168', 'name': 'CJ', 'username': 'CJGinger'},
#  {'id': '194227467', 'name': 'Tony Diver', 'username': 'Tony_Diver'},
#  {'id': '130120037', 'name': 'Pippa Crerar', 'username': 'PippaCrerar'},
#  {'id': '162473641', 'name': 'Sebastian Payne', 'username': 'SebastianEPayne'},
#  {'id': '56349324',
#   'name': 'Michael Valgren Hundahl',
#   'username': 'MichaelValgren'},
#  {'id': '152656121', 'name': "James O'Brien", 'username': 'mrjamesob'},
#  {'id': '46640060', 'name': 'Halfords', 'username': 'Halfords_uk'},
#  {'id': '86429032', 'name': 'Ray Maker', 'username': 'dcrainmakerblog'},
#  {'id': '14824849', 'name': 'Steve Martin', 'username': 'SteveMartinToGo'},
#  {'id': '63114396', 'name': 'Matthew Holmes', 'username': 'MatthewHolmes51'},
#  {'id': '1148696928366006272',
#   'name': 'Jean-François Bernard',
#   'username': 'JFBernard58'},
#  {'id': '450080724', 'name': 'Janey Lowes', 'username': 'janeythevet'},
#  {'id': '1101487206840057856',
#   'name': 'Nick Stripe',
#   'username': 'NickStripe_ONS'},
#  {'id': '1007749631818821638',
#   'name': 'Fesshole 🙏 ⚫️',
#   'username': 'fesshole'},
#  {'id': '58471051', 'name': 'Eden Police', 'username': 'EdenPolice'},
#  {'id': '166192075', 'name': 'Vicki Young', 'username': 'BBCVickiYoung'},
#  {'id': '419471177',
#   'name': 'Cumbria Roads Police & ARVs',
#   'username': 'CumbriaRoadsPol'},
#  {'id': '1256925276530974721',
#   'name': 'Independent SAGE',
#   'username': 'IndependentSage'},
#  {'id': '287650752', 'name': 'Dr John Ferris', 'username': 'JDF_Keswick'},
#  {'id': '579603807', 'name': 'Patrick Lefevere', 'username': 'PatLefevere'},
#  {'id': '1256227427237445632',
#   'name': 'Imagine This Was Your Dad',
#   'username': 'Imagineyourdad'},
#  {'id': '260211154',
#   'name': 'Prof Alice Roberts💙',
#   'username': 'theAliceRoberts'},
#  {'id': '1205895160799879169',
#   'name': 'Cricket Shithousery',
#   'username': 'CricketRustling'},
#  {'id': '405788205',
#   'name': 'YourRoyalThighness_',
#   'username': 'RoyalThighness_'},
#  {'id': '1188149533370454019', 'name': 'Ed Andrews', 'username': 'EdAndrews6'},
#  {'id': '95636424',
#   'name': 'Great North Air Ambulance',
#   'username': 'GNairambulance'},
#  {'id': '20800770', 'name': 'Ivor Baddiel', 'username': 'Ivorbaddiel'},
#  {'id': '3010600643',
#   'name': 'Ramplkev - 3.5% 🕷 Want my rights & freedoms back',
#   'username': 'KevinRampling'},
#  {'id': '1242887487313391616',
#   'name': 'UK COVID-19',
#   'username': 'UKCovid19Stats'},
#  {'id': '76338150', 'name': 'Ryan Sidebottom 💙', 'username': 'RyanSidebottom'},
#  {'id': '219275799',
#   'name': 'Office for National Statistics (ONS)',
#   'username': 'ONS'},
#  {'id': '54766238', 'name': 'Dan Bell', 'username': 'DanBell__'},
#  {'id': '96092282', 'name': 'Shelagh Fogarty 💙', 'username': 'ShelaghFogarty'},
#  {'id': '133216607', 'name': 'Ginny Buckley', 'username': 'GinnyBuckley'},
#  {'id': '300262582', 'name': 'stuart whincup', 'username': 'stuartwhincup'},
#  {'id': '60687884',
#   'name': 'North Yorkshire Police',
#   'username': 'NYorksPolice'},
#  {'id': '1182908497064796161',
#   'name': 'Cricket Comedy',
#   'username': 'CricketComedyUK'},
#  {'id': '81656506', 'name': 'Dan Sweryt', 'username': 'swerytd'},
#  {'id': '20198793', 'name': 'Alex Horne', 'username': 'AlexHorne'},
#  {'id': '152785310', 'name': 'Nish Kumar', 'username': 'MrNishKumar'},
#  {'id': '1208571439',
#   'name': 'Cycling In Flanders',
#   'username': 'cyclingflanders'},
#  {'id': '43878033', 'name': 'John Burn-Murdoch', 'username': 'jburnmurdoch'},
#  {'id': '195737354', 'name': 'Eden Tourism Team', 'username': 'VisitEden'},
#  {'id': '87486158', 'name': 'Brad Sohner', 'username': 'bradsohner'},
#  {'id': '785162699248373760',
#   'name': 'Fred Wright',
#   'username': 'fred_wright0'},
#  {'id': '223879743', 'name': 'Sir Twonkalot', 'username': 'dribelad'},
#  {'id': '59250259', 'name': 'Matteo Trentin', 'username': 'MATTEOTRENTIN'},
#  {'id': '54495894', 'name': 'Felicity Hannah', 'username': 'FelicityHannah'},
#  {'id': '3163631777', 'name': 'Beefeater Bend🎶🍻', 'username': 'tdfbeefeaters'},
#  {'id': '93222172', 'name': 'Michael Spicer', 'username': 'MrMichaelSpicer'},
#  {'id': '473909981', 'name': 'Ben McPartland', 'username': 'McPBen'},
#  {'id': '26026540',
#   'name': 'Caravan and Motorhome Club',
#   'username': 'candmclub'},
#  {'id': '2687847924', 'name': 'Gyles Brandreth', 'username': 'GylesB1'},
#  {'id': '25049056', 'name': 'FRANCE 24 English', 'username': 'France24_en'},
#  {'id': '841924695859580928',
#   'name': 'TheYoungOnes',
#   'username': 'youngonesfan'},
#  {'id': '2890058226',
#   'name': 'Israel Start-Up Nation / Israel Cycling Academy',
#   'username': 'TeamIsraelSUN'},
#  {'id': '2760575236', 'name': 'Hugo Hofstetter', 'username': 'hugohofstetter'},
#  {'id': '20369619', 'name': 'Magnus Backstedt', 'username': 'Maggy_PR'},
#  {'id': '4838287403', 'name': 'cycling archives', 'username': 'mission753'},
#  {'id': '310960217', 'name': 'bob mortimer', 'username': 'RealBobMortimer'},
#  {'id': '17452429', 'name': 'Eaglescliffe', 'username': 'Eaglescliffe'},
#  {'id': '45847408', 'name': 'Dean Kirby', 'username': 'deankirby_'},
#  {'id': '38162820', 'name': 'Amol Rajan', 'username': 'amolrajan'},
#  {'id': '17540485', 'name': 'Red Bull', 'username': 'redbull'},
#  {'id': '6450622', 'name': 'Victoria Fritz', 'username': 'VFritzNews'},
#  {'id': '1190638225183924230', 'name': 'DumbSh💩t', 'username': 'Dumbsheat'},
#  {'id': '1146329871418843136',
#   'name': 'Ursula von der Leyen',
#   'username': 'vonderleyen'},
#  {'id': '1660468830', 'name': 'Hugh Laurie', 'username': 'hughlaurie'},
#  {'id': '432340760', 'name': 'Visit Luxembourg', 'username': 'luxembourginfo'},
#  {'id': '910152368926453761',
#   'name': 'Liane Lippert',
#   'username': 'LianeLippert'},
#  {'id': '28680544', 'name': 'Sandi Toksvig', 'username': 'sanditoksvig'},
#  {'id': '2831541294', 'name': 'Lords EU Committee', 'username': 'LordsEUCom'},
#  {'id': '950249762',
#   'name': 'UK House of Commons',
#   'username': 'HouseofCommons'},
#  {'id': '3131144855', 'name': 'Boris Johnson', 'username': 'BorisJohnson'},
#  {'id': '1013800166439124994',
#   'name': 'Grand Tour Art',
#   'username': 'grandtourart'},
#  {'id': '2793911566', 'name': 'UCI Cyclocross', 'username': 'UCI_CX'},
#  {'id': '18980276', 'name': 'Tim Minchin', 'username': 'timminchin'},
#  {'id': '166739404', 'name': 'Emma Watson', 'username': 'EmmaWatson'},
#  {'id': '257361295', 'name': 'The World of Cycling', 'username': 'twocGAME'},
#  {'id': '2698422738',
#   'name': 'Steve Bray #HoldThemToAccount #23JuneUKwideProtest',
#   'username': 'snb19692'},
#  {'id': '43876479', 'name': 'Viz Comic', 'username': 'vizcomic'},
#  {'id': '18668407', 'name': 'The Daily Mash', 'username': 'thedailymash'},
#  {'id': '19394186', 'name': 'Charlie Brooker', 'username': 'charltonbrooker'},
#  {'id': '21185021', 'name': 'NewsThump', 'username': 'newsthump'},
#  {'id': '19064312', 'name': 'Emma Barnett', 'username': 'Emmabarnett'},
#  {'id': '978613075535433729',
#   'name': 'Cecilie Uttrup Ludwig',
#   'username': 'CUttrupLudwig'},
#  {'id': '65770439', 'name': 'Jason Isaacs', 'username': 'jasonsfolly'},
#  {'id': '95399711', 'name': 'Gareth Thomas', 'username': 'gareththomas14'},
#  {'id': '121562670', 'name': 'Aisling Bea', 'username': 'WeeMissBea'},
#  {'id': '131102467', 'name': 'Rouleur', 'username': 'rouleur'},
#  {'id': '960564953982828550',
#   'name': 'My Flooring Jobs',
#   'username': 'TheFloorBoardUK'},
#  {'id': '2983074561', 'name': 'Yarm Taxis', 'username': 'YarmTaxis'},
#  {'id': '502071579', 'name': 'Tim Wellens', 'username': 'Tim_Wellens'},
#  {'id': '1019319160013250560',
#   'name': 'Ken Clarke',
#   'username': 'MrKennethClarke'},
#  {'id': '2799786822',
#   'name': 'Hutchinson Hobbs',
#   'username': 'HutchinsonHobbs'},
#  {'id': '3072190684',
#   'name': 'BBC Reality Check',
#   'username': 'BBCRealityCheck'},
#  {'id': '76351820', 'name': 'Louis Theroux', 'username': 'louistheroux'},
#  {'id': '485106733', 'name': 'Connor Swift', 'username': 'SwiftConnor'},
#  {'id': '3035081386',
#   'name': 'Stockton LibDems🔶',
#   'username': 'StocktonLibDems'},
#  {'id': '3009026375', 'name': 'Lauren Mayberry', 'username': 'laurenevemay'},
#  {'id': '38675278', 'name': 'Freeview', 'username': 'FreeviewTV'},
#  {'id': '1200985094', 'name': 'Zesdaagse Gent', 'username': 'zesdaagseGent'},
#  {'id': '1081531699958349825',
#   'name': 'Tees4Europe',
#   'username': 'Tees4Europe'},
#  {'id': '4545563913', 'name': 'NorthYorksWeather', 'username': 'northyorkswx'},
#  {'id': '21026930', 'name': 'Sarah Champion', 'username': 'SarahChampion'},
#  {'id': '17865252', 'name': 'Dom Joly', 'username': 'domjoly'},
#  {'id': '62223034', 'name': 'Daniel Oss', 'username': 'Daniel87Oss'},
#  {'id': '17062358', 'name': 'Krishnan Guru-Murthy', 'username': 'krishgm'},
#  {'id': '26518595', 'name': 'Joe Wilkinson', 'username': 'gillinghamjoe'},
#  {'id': '1541364193', 'name': 'Britain Elects', 'username': 'BritainElects'},
#  {'id': '309824548', 'name': 'Rafael Behr', 'username': 'rafaelbehr'},
#  {'id': '225443793', 'name': 'Nikos Chrysoloras', 'username': 'nchrysoloras'},
#  {'id': '146366133', 'name': 'Miranda Green', 'username': 'greenmiranda'},
#  {'id': '19338359',
#   'name': 'Amazon Prime Video UK',
#   'username': 'primevideouk'},
#  {'id': '281814030', 'name': 'Paul McNamara', 'username': 'PGMcNamara'},
#  {'id': '434504034', 'name': 'White Rose Classic', 'username': 'WRClassic'},
#  {'id': '4819582096', 'name': 'edoardo affini', 'username': 'edoardo_affini'},
#  {'id': '1004981802', 'name': 'NorthYorksPolice RPG', 'username': 'NYorksRPG'},
#  {'id': '25984418', 'name': 'Nick Robinson', 'username': 'bbcnickrobinson'},
#  {'id': '1409808276', 'name': 'Win Campbell', 'username': 'DCTyresExhausts'},
#  {'id': '48740370',
#   'name': 'AG2R CITROËN TEAM',
#   'username': 'AG2RCITROENTEAM'},
#  {'id': '748864401852145665',
#   'name': 'The New European',
#   'username': 'TheNewEuropean'},
#  {'id': '19365839', 'name': 'Anthony McCrossan', 'username': 'antmccrossan'},
#  {'id': '3019804545', 'name': 'Whirlpool UK', 'username': 'WhirlpoolUK'},
#  {'id': '1041238603651674112',
#   'name': 'Remco Evenepoel',
#   'username': 'EvenepoelRemco'},
#  {'id': '17948711', 'name': 'bobkeroll', 'username': 'bobkeroll'},
#  {'id': '205770556', 'name': 'i newspaper', 'username': 'theipaper'},
#  {'id': '17487476', 'name': 'Michel Barnier', 'username': 'MichelBarnier'},
#  {'id': '1976143068', 'name': 'Emmanuel Macron', 'username': 'EmmanuelMacron'},
#  {'id': '262672654', 'name': 'Naga Munchetty', 'username': 'TVNaga01'},
#  {'id': '348060815', 'name': 'Marcus Trescothick', 'username': 'Trescricket'},
#  {'id': '211793786', 'name': 'Audax United Kingdom', 'username': 'AudaxUK'},
#  {'id': '3292797886', 'name': 'Lucy Pittaway', 'username': 'lucypittawayart'},
#  {'id': '14190551', 'name': 'Tom Watson', 'username': 'tom_watson'},
#  {'id': '403576718', 'name': 'John O’Farrell', 'username': 'mrjohnofarrell'},
#  {'id': '506354393', 'name': 'James Knox', 'username': 'JamesKnoxx'},
#  {'id': '22814030', 'name': 'anita anand', 'username': 'tweeter_anita'},
#  {'id': '1111013304640638977',
#   'name': 'Sweary Bercow',
#   'username': 'BercowSweary'},
#  {'id': '1140916632983879680',
#   'name': 'Mortimer & Whitehouse: Gone Fishing',
#   'username': 'MWGoneFishing'},
#  {'id': '194030876', 'name': 'Lionel Birnie', 'username': 'lionelbirnie'},
#  {'id': '42371615', 'name': 'Alex Andreou', 'username': 'sturdyAlex'},
#  {'id': '94357028', 'name': 'Mark Steel', 'username': 'mrmarksteel'},
#  {'id': '77714495', 'name': 'Isa Guha', 'username': 'isaguha'},
#  {'id': '307765608', 'name': 'Bianchi', 'username': 'BianchiOfficial'},
#  {'id': '625022363', 'name': 'Gillian Anderson', 'username': 'GillianA'},
#  {'id': '227687574', 'name': 'Race Radio', 'username': 'TheRaceRadio'},
#  {'id': '104509023',
#   'name': 'Cleveland Police',
#   'username': 'ClevelandPolice'},
#  {'id': '107677551', 'name': 'Simon the Puncheur', 'username': 'thepuncheur'},
#  {'id': '22907871', 'name': 'Stuart Maconie', 'username': 'StuartMaconie'},
#  {'id': '299160581', 'name': 'British Cycling', 'username': 'BritishCycling'},
#  {'id': '2459387244', 'name': 'Affligembeer', 'username': 'Affligembeer'},
#  {'id': '550355781',
#   'name': 'vintage bike shop',
#   'username': 'bike_parts_shop'},
#  {'id': '151005980', 'name': 'William Fotheringham', 'username': 'willfoth'},
#  {'id': '1113011011194404864',
#   'name': 'LG UK Customer Care',
#   'username': 'LGUKCare'},
#  {'id': '14953060', 'name': 'LG UK', 'username': 'LGUK'},
#  {'id': '1049358061440315392',
#   'name': 'Miroir du Cyclisme',
#   'username': 'Miroir2Cyclisme'},
#  {'id': '85329224', 'name': 'WorldBeerAwards', 'username': 'worldbeerawards'},
#  {'id': '469602963', 'name': 'Chad Haga', 'username': 'ChadHaga'},
#  {'id': '131926473', 'name': 'Rory Stewart', 'username': 'RoryStewartUK'},
#  {'id': '1098595052903899138', 'name': '🌷VisitYarm🌷', 'username': 'visityarm'},
#  {'id': '19644592', 'name': 'ALASTAIR CAMPBELL', 'username': 'campbellclaret'},
#  {'id': '1542960584',
#   'name': 'Huawei Mobile UK',
#   'username': 'HuaweiMobileUK'},
#  {'id': '25084872', 'name': 'Orla Chennaoui', 'username': 'SportsOrla'},
#  {'id': '17872077', 'name': 'Virgin Media', 'username': 'virginmedia'},
#  {'id': '362144301', 'name': 'Brian Moore', 'username': 'brianmoore666'},
#  {'id': '222468030',
#   'name': 'Environment Agency - Yorkshire & North East',
#   'username': 'EnvAgencyYNE'},
#  {'id': '22361946', 'name': 'primoz roglic', 'username': 'rogla'},
#  {'id': '89483276', 'name': 'INEOS Grenadiers', 'username': 'INEOSGrenadiers'},
#  {'id': '272048289', 'name': 'Julien Bernard', 'username': 'JulienBernard17'},
#  {'id': '846037320667217921',
#   'name': 'Best for Britain',
#   'username': 'BestForBritain'},
#  {'id': '393637870', 'name': 'Katya Adler', 'username': 'BBCkatyaadler'},
#  {'id': '952902103818784769',
#   'name': 'Little Clogs Holidays',
#   'username': 'little_clogs'},
#  {'id': '36334366', 'name': 'Alex Forsyth', 'username': 'AlexForsythBBC'},
#  {'id': '1243272524', 'name': 'Paris-Roubaix', 'username': 'Paris_Roubaix'},
#  {'id': '790950921253552128',
#   'name': "Yesterday's Drive",
#   'username': 'YesterdaysDrive'},
#  {'id': '21416493', 'name': 'Simon Yates', 'username': 'SimonYatess'},
#  {'id': '29720818', 'name': 'Adam Yates', 'username': 'AdamYates7'},
#  {'id': '272134678', 'name': 'Rob Hayles', 'username': 'robhayles1'},
#  {'id': '37650988', 'name': 'Tao Geoghegan Hart', 'username': 'taogeoghegan'},
#  {'id': '1073606435580325889',
#   'name': 'Led By Donkeys',
#   'username': 'ByDonkeys'},
#  {'id': '794171324746833921',
#   'name': 'Met Office Leeming',
#   'username': 'MetOLeeming'},
#  {'id': '46422935', 'name': 'Yorkshire Tea', 'username': 'YorkshireTea'},
#  {'id': '1027067377', 'name': 'classicretro', 'username': 'classicretro'},
#  {'id': '856010760', 'name': 'Guy Verhofstadt', 'username': 'guyverhofstadt'},
#  {'id': '1104832555449307138',
#   'name': 'Yarm Fun Run',
#   'username': 'yarmfunrun'},
#  {'id': '228135677', 'name': 'Tamlynn Laird', 'username': 'tamlynnlaird'},
#  {'id': '143691818', 'name': 'Elia Viviani', 'username': 'eliaviviani'},
#  {'id': '4009372913', 'name': 'Le ßeau Vélo', 'username': 'Le_Beau_Velo'},
#  {'id': '4343382327', 'name': 'Catie Munnings', 'username': 'catierallye1'},
#  {'id': '28333098', 'name': 'Cyclingnews.com', 'username': 'Cyclingnewsfeed'},
#  {'id': '196994616', 'name': 'Charles Michel', 'username': 'eucopresident'},
#  {'id': '124977900', 'name': 'KATUSHA', 'username': 'katushacycling'},
#  {'id': '1092054063863218176',
#   'name': 'fortnutbeast',
#   'username': 'fortnutbeast'},
#  {'id': '1243296234',
#   'name': 'Liège-Bastogne-Liège',
#   'username': 'LiegeBastogneL'},
#  {'id': '944609408', 'name': 'Stockton Wheelers', 'username': 'StonWheelers'},
#  {'id': '77982952', 'name': 'Meteociel', 'username': 'meteociel'},
#  {'id': '15454011', 'name': 'Adam Fleming', 'username': 'adamfleming'},
#  {'id': '132923130', 'name': 'Performance Chef', 'username': 'AlanMurchison'},
#  {'id': '40642369',
#   'name': 'Deceuninck-QuickStep',
#   'username': 'deceuninck_qst'},
#  {'id': '1050037369464938497',
#   'name': 'Dicks Builder Mate',
#   'username': 'Stainle65616960'},
#  {'id': '964344902', 'name': 'billywhizz', 'username': 'BillyMonger'},
#  {'id': '61183568', 'name': 'Laura Kuenssberg', 'username': 'bbclaurak'},
#  {'id': '701387667007807489',
#   'name': 'The Chateau',
#   'username': 'thechateautv'},
#  {'id': '84291656', 'name': 'Dick Strawbridge', 'username': 'dickstrawbridge'},
#  {'id': '106118793', 'name': 'norman smith', 'username': 'Thehackandhound'},
#  {'id': '166712218', 'name': 'James Landale', 'username': 'BBCJLandale'},
#  {'id': '18716851', 'name': 'Paul_Rose', 'username': 'Paul_Rose'},
#  {'id': '22460658', 'name': 'Chris Mason', 'username': 'ChrisMasonBBC'},
#  {'id': '143145579', 'name': 'The Poke', 'username': 'ThePoke'},
#  {'id': '29739553',
#   'name': 'Victoria Coren Mitchell',
#   'username': 'VictoriaCoren'},
#  {'id': '54974060', 'name': 'Tom ‘Wookie’ Ford', 'username': 'tomwookieford'},
#  {'id': '757337387689181189',
#   'name': 'La Vie Claire Fan 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f 🇫🇷',
#   'username': 'lavieclaire1986'},
#  {'id': '738341549302550529',
#   'name': 'U.K Snow Updates',
#   'username': 'UKsnow_updates'},
#  {'id': '118685634', 'name': 'the Inner Ring', 'username': 'inrng'},
#  {'id': '1038684084388737029',
#   'name': 'MyFlooringJobsUK',
#   'username': 'flooringjobsuk'},
#  {'id': '59487557', 'name': 'Carpet Roles UK', 'username': 'CarpetRolesUK'},
#  {'id': '112733139',
#   'name': 'Ebony Rainford-Brent',
#   'username': 'ejrainfordbrent'},
#  {'id': '86664924', 'name': 'Jay Rayner', 'username': 'jayrayner1'},
#  {'id': '2706072331',
#   'name': 'Sir Geoffrey Boycott',
#   'username': 'GeoffreyBoycott'},
#  {'id': '470357978', 'name': 'Mia Stålnacke', 'username': 'AngryTheInch'},
#  {'id': '74177227', 'name': 'Larry Warbasse', 'username': 'larrywarbasse'},
#  {'id': '49605149', 'name': 'Tony Livesey', 'username': 'tonylivesey'},
#  {'id': '381431945', 'name': 'Team DSM', 'username': 'TeamDSM'},
#  {'id': '110056427', 'name': 'Alex Dowsett', 'username': 'alexdowsett'},
#  {'id': '315439784', 'name': 'Conor Dunne', 'username': 'conordunnealot'},
#  {'id': '2275096473',
#   'name': 'Visit Wakefield™',
#   'username': 'Visit_Wakefield'},
#  {'id': '966458868', 'name': 'Sean Yates', 'username': 'SeanYatesCoach'},
#  {'id': '2220024959', 'name': 'Keeley Hawes', 'username': 'Misskeeleyhawes'},
#  {'id': '1023856287673737216',
#   'name': 'NifcoUK_Jobs',
#   'username': 'NifcoUK_Jobs'},
#  {'id': '369993105', 'name': 'Oliver naesen', 'username': 'OliverNaesen'},
#  {'id': '578098244', 'name': 'Jonathan Harris-Bass', 'username': 'Jono_HB'},
#  {'id': '2881357498', 'name': 'Velon CC', 'username': 'VelonCC'},
#  {'id': '1276052881', 'name': 'Abbey Westmalle', 'username': 'abbeywestmalle'},
#  {'id': '724507227294412800',
#   'name': 'Tour of Slovenia',
#   'username': 'TourOfSlovenia'},
#  {'id': '1901273077',
#   'name': 'Kenny Van Vlaminck',
#   'username': 'KVanVlaminck'},
#  {'id': '993466760',
#   'name': 'Team Jumbo-Visma cycling',
#   'username': 'JumboVismaRoad'},
#  {'id': '3221068227', 'name': 'StravaWankers', 'username': 'stravawankers'},
#  {'id': '20841000', 'name': 'Jonny Smith', 'username': 'Carpervert'},
#  {'id': '1192861100804575234', 'name': 'Katy', 'username': 'KatyJayne101'},
#  {'id': '16044025', 'name': 'Tour of Britain 🇬🇧', 'username': 'TourofBritain'},
#  {'id': '288369320',
#   'name': 'Mark Cooper-Jones',
#   'username': 'markcooperjones'},
#  {'id': '43919376', 'name': 'Jay Foreman', 'username': 'jayforeman'},
#  {'id': '19211352', 'name': 'Cherie Pridham', 'username': 'ChezPro'},
#  {'id': '22621511', 'name': 'Gary Delaney', 'username': 'GaryDelaney'},
#  {'id': '349083462',
#   'name': 'Tirreno Adriatico',
#   'username': 'TirrenAdriatico'},
#  {'id': '108441763', 'name': 'Ben Swift', 'username': 'swiftybswift'},
#  {'id': '3320963777', 'name': 'Conyers MFL', 'username': 'conyersmfl'},
#  {'id': '3224085551',
#   'name': 'Maillot à Pois E.Leclerc',
#   'username': 'maillotapois'},
#  {'id': '882284078', 'name': 'stycle_design', 'username': 'stycle_design'},
#  {'id': '507201572', 'name': 'Fleur Faure', 'username': 'FleurFaure'},
#  {'id': '3338835075',
#   'name': 'Maillot Distinctif.',
#   'username': 'MDistinctif'},
#  {'id': '2285051', 'name': 'Rob Manuel 🌭', 'username': 'robmanuel'},
#  {'id': '1080631375122837506',
#   'name': 'daemoncycling',
#   'username': 'daemoncycling'},
#  {'id': '4436617815', 'name': 'Myles', 'username': 'PusherOfPedals'},
#  {'id': '1100256855035703296',
#   'name': 'InternationElles',
#   'username': 'InternationEll2'},
#  {'id': '604767363', 'name': 'Ros Pritchard OBE', 'username': 'BHHPAros'},
#  {'id': '19533512', 'name': 'Samuel West 💙', 'username': 'exitthelemming'},
#  {'id': '2536057610', 'name': 'Marie-Fleur', 'username': 'MarieFleur3'},
#  {'id': '70707518', 'name': 'Cillian Kelly', 'username': 'irishpeloton'},
#  {'id': '1232783237623119872',
#   'name': "NASA's Perseverance Mars Rover",
#   'username': 'NASAPersevere'},
#  {'id': '1360878978211475458',
#   'name': 'Tour Haut Var',
#   'username': 'tourhautvar'},
#  {'id': '1246200438',
#   'name': 'Father Ted Quote of the Day',
#   'username': 'FrTedQOTD'},
#  {'id': '1358779937948327937',
#   'name': 'pro cycling trumps',
#   'username': 'procycletrumps'},
#  {'id': '15383064', 'name': 'Simon Wear', 'username': 'simonwear'},
#  {'id': '726742474568376320',
#   'name': 'La Bicicleta News',
#   'username': 'LaBicicletaNews'},
#  {'id': '109814286', 'name': 'Hannah Walker', 'username': 'spannawalker'},
#  {'id': '54816467', 'name': 'Mihai Simion', 'username': 'faustocoppi60'},
#  {'id': '34001965', 'name': 'Bob Jungels', 'username': 'BobJungels'},
#  {'id': '202740241', 'name': 'Emma Vardy', 'username': 'EmmaVardyTV'},
#  {'id': '953239759480147968',
#   'name': 'CyclingLegends',
#   'username': 'CyclingLegends1'},
#  {'id': '153121957', 'name': 'Laura Winter', 'username': 'lauracwinter'},
#  {'id': '71354971', 'name': 'cyclephotos', 'username': 'cyclephotos'},
#  {'id': '2229930931', 'name': 'Eva zu Beck', 'username': 'evabiankaz'},
#  {'id': '123015364', 'name': 'Allison Janney', 'username': 'AllisonBJanney'},
#  {'id': '1295397293340991494',
#   'name': 'The Late Brake Show',
#   'username': 'LateBrakeShow'},
#  {'id': '84035041', 'name': 'Christina Pagel', 'username': 'chrischirp'},
#  {'id': '959173934766837761',
#   'name': 'The Irish Border',
#   'username': 'BorderIrish'},
#  {'id': '1278485785713442818',
#   'name': 'Scottish Border 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#   'username': 'ScotBorderOG'},
#  {'id': '110509537', 'name': 'Thom Yorke', 'username': 'thomyorke'},
#  {'id': '939294302', 'name': 'Class Charts', 'username': 'Classcharts'},
#  {'id': '1207716502281080832',
#   'name': 'João Almeida',
#   'username': 'JooAlmeida98'},
#  {'id': '2569599561', 'name': 'Tom Haward', 'username': 'HawardTom'},
#  {'id': '1323730225067339784',
#   'name': 'The White House',
#   'username': 'WhiteHouse'},
#  {'id': '1349149096909668363', 'name': 'President Biden', 'username': 'POTUS'},
#  {'id': '1029331279022575617',
#   'name': 'TRINITY Racing',
#   'username': 'TrinityRacing_'},
#  {'id': '2168717730', 'name': 'Cameron Mason', 'username': 'camerooney_'},
#  {'id': '400953126', 'name': 'Hugo Gye', 'username': 'HugoGye'},
#  {'id': '162071541', 'name': 'Shaun Lintern', 'username': 'ShaunLintern'},
#  {'id': '718182124948426753',
#   'name': 'Elynor Backstedt',
#   'username': 'EBackstedt6'},
#  {'id': '1345309846690791424',
#   'name': 'Alpecin-Fenix Cycling Team',
#   'username': 'AlpecinFenix'},
#  {'id': '192892778', 'name': 'Lucrezia Millarini', 'username': 'lucrezianews'},
#  {'id': '155203891', 'name': "Naomi O'Leary", 'username': 'NaomiOhReally'},
#  {'id': '966701634',
#   'name': 'Lochfyne langoustines Ltd & Lochfyne seafarms Ltd',
#   'username': 'LochfyneLangous'},
#  {'id': '69080476', 'name': 'Jim Pickard', 'username': 'PickardJE'},
#  {'id': '246459126', 'name': 'Jonathan Portes', 'username': 'jdportes'},
#  {'id': '996078704', 'name': 'Lucy', 'username': 'LucyMannall'},
#  {'id': '151655222', 'name': 'Ben Kentish', 'username': 'BenKentish'},
#  {'id': '1346781110504747008',
#   'name': 'UK-EU Politics 🇪🇺🇬🇧',
#   'username': 'politics_eu'},
#  {'id': '229459251', 'name': 'Vick Hope', 'username': 'VickNHope'},
#  {'id': '500212522', 'name': 'Peter Mawson', 'username': 'HighFarndale'},
#  {'id': '253453519', 'name': '100%BRUMOTTI', 'username': 'brumottistar'},
#  {'id': '19916572', 'name': 'Jason Plato', 'username': 'jasonplato'},
#  {'id': '86093740', 'name': 'Badly Drawn Boy', 'username': 'badly_drawn_boy'},
#  {'id': '238706137',
#   'name': 'Dave Bradshaw 💙 #IhavehadOxfordAZvaccine',
#   'username': 'djbradshaw64'},
#  {'id': '300339564', 'name': 'WowHaus', 'username': 'WowHauser'},
#  {'id': '20427720', 'name': 'Simon McCoy', 'username': 'BBCSimonMcCoy'},
#  {'id': '33823446', 'name': 'michael sheen 💙', 'username': 'michaelsheen'},
#  {'id': '897343767610568704',
#   'name': 'Great Cycling Victories',
#   'username': 'gcvictories'},
#  {'id': '47854857', 'name': 'Alastair Leithead', 'username': 'aleithead'},
#  {'id': '1315053256343719936',
#   'name': 'Dr Julia Grace Patterson 💙',
#   'username': 'JujuliaGrace'},
#  {'id': '157044469', 'name': 'Hugh Pym', 'username': 'BBCHughPym'},
#  {'id': '2230539338', 'name': 'David Gauke', 'username': 'DavidGauke'},
#  {'id': '146526575',
#   'name': 'Mathieu Van der Poel',
#   'username': 'mathieuvdpoel'},
#  {'id': '1226113371482808321',
#   'name': 'Sebastian Fischer',
#   'username': 'SFischer_EU'},
#  {'id': '33840986',
#   'name': 'Château de Chambord',
#   'username': 'domainechambord'},
#  {'id': '18701897', 'name': 'Dino Sofos', 'username': 'dinosofos'},
#  {'id': '601172661', 'name': 'John Niven HQ', 'username': 'estellecostanza'},
#  {'id': '23813407', 'name': 'Jon Stone', 'username': 'joncstone'},
#  {'id': '138717046', 'name': 'Bruno Waterfield', 'username': 'BrunoBrussels'},
#  {'id': '545703074', 'name': 'Eric Mamer', 'username': 'MamerEric'},
#  {'id': '31101821', 'name': 'Larry Budd', 'username': 'larrybudd1'},
#  {'id': '1341465628746641408',
#   'name': 'Le French Border ⛔️🇫🇷',
#   'username': 'lefrenchborder'},
#  {'id': '31105922', 'name': 'Mr Paul Dunphy OBE', 'username': 'mrpauldunphy'},
#  {'id': '97621178', 'name': '🥃 Larry & Paul 🥃', 'username': 'larryandpaul'},
#  {'id': '4927450223', 'name': 'Night Lights', 'username': 'NightLights_AM'},
#  {'id': '42229043', 'name': 'Andrew Connell', 'username': 'andrewiconnell'},
#  {'id': '22352061', 'name': 'Anna Isaac', 'username': 'Annaisaac'},
#  {'id': '311397505', 'name': 'Luke Rowe', 'username': 'LukeRowe1990'},
#  {'id': '1141660959364308992',
#   'name': 'Catherine Colonna',
#   'username': 'AmbColonna'},
#  {'id': '2494186513', 'name': 'David Henig', 'username': 'DavidHenigUK'},
#  {'id': '965991485819817984',
#   'name': 'Dr Anna Jerzewska',
#   'username': 'AnnaJerzewska'},
#  {'id': '37188908', 'name': 'José Been', 'username': 'TourDeJose'},
#  {'id': '137295176', 'name': 'Henry Mance', 'username': 'henrymance'},
#  {'id': '174151902', 'name': 'Prof. Devi Sridhar', 'username': 'devisridhar'},
#  {'id': '3297800601',
#   'name': 'The Secret Barrister',
#   'username': 'BarristerSecret'},
#  {'id': '1060578475', 'name': 'Lionel Barber', 'username': 'lionelbarber'},
#  {'id': '72827013', 'name': 'Jennifer Williams', 'username': 'JenWilliamsMEN'},
#  {'id': '2723961543', 'name': 'BumTree', 'username': 'Bum_Tree_'},
#  {'id': '1143319274', 'name': 'Dr Elisabetta', 'username': 'ViralRNA'},
# ...
#  {'id': '60687884',
#   'name': 'North Yorkshire Police',
#   'username': 'NYorksPolice'},
#  {'id': '1182908497064796161',
#   'name': 'Cricket Comedy',
#   'username': 'CricketComedyUK'},
#  {'id': '81656506', 'name': 'Dan Sweryt', 'username': 'swerytd'},
#  {'id': '20198793', 'name': 'Alex Horne', 'username': 'AlexHorne'},
#  {'id': '152785310', 'name': 'Nish Kumar', 'username': 'MrNishKumar'},
#  {'id': '1208571439',
#   'name': 'Cycling In Flanders',
#   'username': 'cyclingflanders'},
#  {'id': '43878033', 'name': 'John Burn-Murdoch', 'username': 'jburnmurdoch'},
#  {'id': '195737354', 'name': 'Eden Tourism Team', 'username': 'VisitEden'},
#  {'id': '87486158', 'name': 'Brad Sohner', 'username': 'bradsohner'},
#  {'id': '785162699248373760',
#   'name': 'Fred Wright',
#   'username': 'fred_wright0'},
#  {'id': '223879743', 'name': 'Sir Twonkalot', 'username': 'dribelad'},
#  {'id': '59250259', 'name': 'Matteo Trentin', 'username': 'MATTEOTRENTIN'},
#  {'id': '54495894', 'name': 'Felicity Hannah', 'username': 'FelicityHannah'},
#  {'id': '3163631777', 'name': 'Beefeater Bend🎶🍻', 'username': 'tdfbeefeaters'},
#  {'id': '93222172', 'name': 'Michael Spicer', 'username': 'MrMichaelSpicer'},
#  {'id': '473909981', 'name': 'Ben McPartland', 'username': 'McPBen'},
#  {'id': '26026540',
#   'name': 'Caravan and Motorhome Club',
#   'username': 'candmclub'},
#  {'id': '2687847924', 'name': 'Gyles Brandreth', 'username': 'GylesB1'},
#  {'id': '25049056', 'name': 'FRANCE 24 English', 'username': 'France24_en'},
#  {'id': '841924695859580928',
#   'name': 'TheYoungOnes',
#   'username': 'youngonesfan'},
#  {'id': '2890058226',
#   'name': 'Israel Start-Up Nation / Israel Cycling Academy',
#   'username': 'TeamIsraelSUN'},
#  {'id': '2760575236', 'name': 'Hugo Hofstetter', 'username': 'hugohofstetter'},
#  {'id': '20369619', 'name': 'Magnus Backstedt', 'username': 'Maggy_PR'},
#  {'id': '4838287403', 'name': 'cycling archives', 'username': 'mission753'},
#  {'id': '310960217', 'name': 'bob mortimer', 'username': 'RealBobMortimer'},
#  {'id': '17452429', 'name': 'Eaglescliffe', 'username': 'Eaglescliffe'},
#  {'id': '45847408', 'name': 'Dean Kirby', 'username': 'deankirby_'},
#  {'id': '38162820', 'name': 'Amol Rajan', 'username': 'amolrajan'},
#  {'id': '17540485', 'name': 'Red Bull', 'username': 'redbull'},
#  {'id': '6450622', 'name': 'Victoria Fritz', 'username': 'VFritzNews'},
#  {'id': '1190638225183924230', 'name': 'DumbSh💩t', 'username': 'Dumbsheat'},
#  {'id': '1146329871418843136',
#   'name': 'Ursula von der Leyen',
#   'username': 'vonderleyen'},
#  {'id': '1660468830', 'name': 'Hugh Laurie', 'username': 'hughlaurie'},
#  {'id': '432340760', 'name': 'Visit Luxembourg', 'username': 'luxembourginfo'},
#  {'id': '910152368926453761',
#   'name': 'Liane Lippert',
#   'username': 'LianeLippert'},
#  {'id': '28680544', 'name': 'Sandi Toksvig', 'username': 'sanditoksvig'},
#  {'id': '2831541294', 'name': 'Lords EU Committee', 'username': 'LordsEUCom'},
#  {'id': '950249762',
#   'name': 'UK House of Commons',
#   'username': 'HouseofCommons'},
#  {'id': '3131144855', 'name': 'Boris Johnson', 'username': 'BorisJohnson'},
#  {'id': '1013800166439124994',
#   'name': 'Grand Tour Art',
#   'username': 'grandtourart'},
#  {'id': '2793911566', 'name': 'UCI Cyclocross', 'username': 'UCI_CX'},
#  {'id': '18980276', 'name': 'Tim Minchin', 'username': 'timminchin'},
#  {'id': '166739404', 'name': 'Emma Watson', 'username': 'EmmaWatson'},
#  {'id': '257361295', 'name': 'The World of Cycling', 'username': 'twocGAME'},
#  {'id': '2698422738',
#   'name': 'Steve Bray #HoldThemToAccount #23JuneUKwideProtest',
#   'username': 'snb19692'},
#  {'id': '43876479', 'name': 'Viz Comic', 'username': 'vizcomic'},
#  {'id': '18668407', 'name': 'The Daily Mash', 'username': 'thedailymash'},
#  {'id': '19394186', 'name': 'Charlie Brooker', 'username': 'charltonbrooker'},
#  {'id': '21185021', 'name': 'NewsThump', 'username': 'newsthump'},
#  {'id': '19064312', 'name': 'Emma Barnett', 'username': 'Emmabarnett'},
#  {'id': '978613075535433729',
#   'name': 'Cecilie Uttrup Ludwig',
#   'username': 'CUttrupLudwig'},
#  {'id': '65770439', 'name': 'Jason Isaacs', 'username': 'jasonsfolly'},
#  {'id': '95399711', 'name': 'Gareth Thomas', 'username': 'gareththomas14'},
#  {'id': '121562670', 'name': 'Aisling Bea', 'username': 'WeeMissBea'},
#  {'id': '131102467', 'name': 'Rouleur', 'username': 'rouleur'},
#  {'id': '960564953982828550',
#   'name': 'My Flooring Jobs',
#   'username': 'TheFloorBoardUK'},
#  {'id': '2983074561', 'name': 'Yarm Taxis', 'username': 'YarmTaxis'},
#  {'id': '502071579', 'name': 'Tim Wellens', 'username': 'Tim_Wellens'},
#  {'id': '1019319160013250560',
#   'name': 'Ken Clarke',
#   'username': 'MrKennethClarke'},
#  {'id': '2799786822',
#   'name': 'Hutchinson Hobbs',
#   'username': 'HutchinsonHobbs'},
#  {'id': '3072190684',
#   'name': 'BBC Reality Check',
#   'username': 'BBCRealityCheck'},
#  {'id': '76351820', 'name': 'Louis Theroux', 'username': 'louistheroux'},
#  {'id': '485106733', 'name': 'Connor Swift', 'username': 'SwiftConnor'},
#  {'id': '3035081386',
#   'name': 'Stockton LibDems🔶',
#   'username': 'StocktonLibDems'},
#  {'id': '3009026375', 'name': 'Lauren Mayberry', 'username': 'laurenevemay'},
#  {'id': '38675278', 'name': 'Freeview', 'username': 'FreeviewTV'},
#  {'id': '1200985094', 'name': 'Zesdaagse Gent', 'username': 'zesdaagseGent'},
#  {'id': '1081531699958349825',
#   'name': 'Tees4Europe',
#   'username': 'Tees4Europe'},
#  {'id': '4545563913', 'name': 'NorthYorksWeather', 'username': 'northyorkswx'},
#  {'id': '21026930', 'name': 'Sarah Champion', 'username': 'SarahChampion'},
#  {'id': '17865252', 'name': 'Dom Joly', 'username': 'domjoly'},
#  {'id': '62223034', 'name': 'Daniel Oss', 'username': 'Daniel87Oss'},
#  {'id': '17062358', 'name': 'Krishnan Guru-Murthy', 'username': 'krishgm'},
#  {'id': '26518595', 'name': 'Joe Wilkinson', 'username': 'gillinghamjoe'},
#  {'id': '1541364193', 'name': 'Britain Elects', 'username': 'BritainElects'},
#  {'id': '309824548', 'name': 'Rafael Behr', 'username': 'rafaelbehr'},
#  {'id': '225443793', 'name': 'Nikos Chrysoloras', 'username': 'nchrysoloras'},
#  {'id': '146366133', 'name': 'Miranda Green', 'username': 'greenmiranda'},
#  {'id': '19338359',
#   'name': 'Amazon Prime Video UK',
#   'username': 'primevideouk'},
#  {'id': '281814030', 'name': 'Paul McNamara', 'username': 'PGMcNamara'},
#  {'id': '434504034', 'name': 'White Rose Classic', 'username': 'WRClassic'},
#  {'id': '4819582096', 'name': 'edoardo affini', 'username': 'edoardo_affini'},
#  {'id': '1004981802', 'name': 'NorthYorksPolice RPG', 'username': 'NYorksRPG'},
#  {'id': '25984418', 'name': 'Nick Robinson', 'username': 'bbcnickrobinson'},
#  {'id': '1409808276', 'name': 'Win Campbell', 'username': 'DCTyresExhausts'},
#  {'id': '48740370',
#   'name': 'AG2R CITROËN TEAM',
#   'username': 'AG2RCITROENTEAM'},
#  {'id': '748864401852145665',
#   'name': 'The New European',
#   'username': 'TheNewEuropean'},
#  {'id': '19365839', 'name': 'Anthony McCrossan', 'username': 'antmccrossan'},
#  {'id': '3019804545', 'name': 'Whirlpool UK', 'username': 'WhirlpoolUK'},
#  {'id': '1041238603651674112',
#   'name': 'Remco Evenepoel',
#   'username': 'EvenepoelRemco'},
#  {'id': '17948711', 'name': 'bobkeroll', 'username': 'bobkeroll'},
#  {'id': '205770556', 'name': 'i newspaper', 'username': 'theipaper'},
#  {'id': '17487476', 'name': 'Michel Barnier', 'username': 'MichelBarnier'},
#  {'id': '1976143068', 'name': 'Emmanuel Macron', 'username': 'EmmanuelMacron'},
#  {'id': '262672654', 'name': 'Naga Munchetty', 'username': 'TVNaga01'},
#  {'id': '348060815', 'name': 'Marcus Trescothick', 'username': 'Trescricket'},
#  {'id': '211793786', 'name': 'Audax United Kingdom', 'username': 'AudaxUK'},
#  {'id': '3292797886', 'name': 'Lucy Pittaway', 'username': 'lucypittawayart'},
#  {'id': '14190551', 'name': 'Tom Watson', 'username': 'tom_watson'},
#  {'id': '403576718', 'name': 'John O’Farrell', 'username': 'mrjohnofarrell'},
#  {'id': '506354393', 'name': 'James Knox', 'username': 'JamesKnoxx'},
#  {'id': '22814030', 'name': 'anita anand', 'username': 'tweeter_anita'},
#  {'id': '1111013304640638977',
#   'name': 'Sweary Bercow',
#   'username': 'BercowSweary'},
#  {'id': '1140916632983879680',
#   'name': 'Mortimer & Whitehouse: Gone Fishing',
#   'username': 'MWGoneFishing'},
#  {'id': '194030876', 'name': 'Lionel Birnie', 'username': 'lionelbirnie'},
#  {'id': '42371615', 'name': 'Alex Andreou', 'username': 'sturdyAlex'},
#  {'id': '94357028', 'name': 'Mark Steel', 'username': 'mrmarksteel'},
#  {'id': '77714495', 'name': 'Isa Guha', 'username': 'isaguha'},
#  {'id': '307765608', 'name': 'Bianchi', 'username': 'BianchiOfficial'},
#  {'id': '625022363', 'name': 'Gillian Anderson', 'username': 'GillianA'},
#  {'id': '227687574', 'name': 'Race Radio', 'username': 'TheRaceRadio'},
#  {'id': '104509023',
#   'name': 'Cleveland Police',
#   'username': 'ClevelandPolice'},
#  {'id': '107677551', 'name': 'Simon the Puncheur', 'username': 'thepuncheur'},
#  {'id': '22907871', 'name': 'Stuart Maconie', 'username': 'StuartMaconie'},
#  {'id': '299160581', 'name': 'British Cycling', 'username': 'BritishCycling'},
#  {'id': '2459387244', 'name': 'Affligembeer', 'username': 'Affligembeer'},
#  {'id': '550355781',
#   'name': 'vintage bike shop',
#   'username': 'bike_parts_shop'},
#  {'id': '151005980', 'name': 'William Fotheringham', 'username': 'willfoth'},
#  {'id': '1113011011194404864',
#   'name': 'LG UK Customer Care',
#   'username': 'LGUKCare'},
#  {'id': '14953060', 'name': 'LG UK', 'username': 'LGUK'},
#  {'id': '1049358061440315392',
#   'name': 'Miroir du Cyclisme',
#   'username': 'Miroir2Cyclisme'},
#  {'id': '85329224', 'name': 'WorldBeerAwards', 'username': 'worldbeerawards'},
#  {'id': '469602963', 'name': 'Chad Haga', 'username': 'ChadHaga'},
#  {'id': '131926473', 'name': 'Rory Stewart', 'username': 'RoryStewartUK'},
#  {'id': '1098595052903899138', 'name': '🌷VisitYarm🌷', 'username': 'visityarm'},
#  {'id': '19644592', 'name': 'ALASTAIR CAMPBELL', 'username': 'campbellclaret'},
#  {'id': '1542960584',
#   'name': 'Huawei Mobile UK',
#   'username': 'HuaweiMobileUK'},
#  {'id': '25084872', 'name': 'Orla Chennaoui', 'username': 'SportsOrla'},
#  {'id': '17872077', 'name': 'Virgin Media', 'username': 'virginmedia'},
#  {'id': '362144301', 'name': 'Brian Moore', 'username': 'brianmoore666'},
#  {'id': '222468030',
#   'name': 'Environment Agency - Yorkshire & North East',
#   'username': 'EnvAgencyYNE'},
#  {'id': '22361946', 'name': 'primoz roglic', 'username': 'rogla'},
#  {'id': '89483276', 'name': 'INEOS Grenadiers', 'username': 'INEOSGrenadiers'},
#  {'id': '272048289', 'name': 'Julien Bernard', 'username': 'JulienBernard17'},
#  {'id': '846037320667217921',
#   'name': 'Best for Britain',
#   'username': 'BestForBritain'},
#  {'id': '393637870', 'name': 'Katya Adler', 'username': 'BBCkatyaadler'},
#  {'id': '952902103818784769',
#   'name': 'Little Clogs Holidays',
#   'username': 'little_clogs'},
#  {'id': '36334366', 'name': 'Alex Forsyth', 'username': 'AlexForsythBBC'},
#  {'id': '1243272524', 'name': 'Paris-Roubaix', 'username': 'Paris_Roubaix'},
#  {'id': '790950921253552128',
#   'name': "Yesterday's Drive",
#   'username': 'YesterdaysDrive'},
#  {'id': '21416493', 'name': 'Simon Yates', 'username': 'SimonYatess'},
#  {'id': '29720818', 'name': 'Adam Yates', 'username': 'AdamYates7'},
#  {'id': '272134678', 'name': 'Rob Hayles', 'username': 'robhayles1'},
#  {'id': '37650988', 'name': 'Tao Geoghegan Hart', 'username': 'taogeoghegan'},
#  {'id': '1073606435580325889',
#   'name': 'Led By Donkeys',
#   'username': 'ByDonkeys'},
#  {'id': '794171324746833921',
#   'name': 'Met Office Leeming',
#   'username': 'MetOLeeming'},
#  {'id': '46422935', 'name': 'Yorkshire Tea', 'username': 'YorkshireTea'},
#  {'id': '1027067377', 'name': 'classicretro', 'username': 'classicretro'},
#  {'id': '856010760', 'name': 'Guy Verhofstadt', 'username': 'guyverhofstadt'},
#  {'id': '1104832555449307138',
#   'name': 'Yarm Fun Run',
#   'username': 'yarmfunrun'},
#  {'id': '228135677', 'name': 'Tamlynn Laird', 'username': 'tamlynnlaird'},
#  {'id': '143691818', 'name': 'Elia Viviani', 'username': 'eliaviviani'},
#  {'id': '4009372913', 'name': 'Le ßeau Vélo', 'username': 'Le_Beau_Velo'},
#  {'id': '4343382327', 'name': 'Catie Munnings', 'username': 'catierallye1'},
#  {'id': '28333098', 'name': 'Cyclingnews.com', 'username': 'Cyclingnewsfeed'},
#  {'id': '196994616', 'name': 'Charles Michel', 'username': 'eucopresident'},
#  {'id': '124977900', 'name': 'KATUSHA', 'username': 'katushacycling'},
#  {'id': '1092054063863218176',
#   'name': 'fortnutbeast',
#   'username': 'fortnutbeast'},
#  {'id': '1243296234',
#   'name': 'Liège-Bastogne-Liège',
#   'username': 'LiegeBastogneL'},
#  {'id': '944609408', 'name': 'Stockton Wheelers', 'username': 'StonWheelers'},
#  {'id': '77982952', 'name': 'Meteociel', 'username': 'meteociel'},
#  {'id': '15454011', 'name': 'Adam Fleming', 'username': 'adamfleming'},
#  {'id': '132923130', 'name': 'Performance Chef', 'username': 'AlanMurchison'},
#  {'id': '40642369',
#   'name': 'Deceuninck-QuickStep',
#   'username': 'deceuninck_qst'},
#  {'id': '1050037369464938497',
#   'name': 'Dicks Builder Mate',
#   'username': 'Stainle65616960'},
#  {'id': '964344902', 'name': 'billywhizz', 'username': 'BillyMonger'},
#  {'id': '61183568', 'name': 'Laura Kuenssberg', 'username': 'bbclaurak'},
#  {'id': '701387667007807489',
#   'name': 'The Chateau',
#   'username': 'thechateautv'},
#  {'id': '84291656', 'name': 'Dick Strawbridge', 'username': 'dickstrawbridge'},
#  {'id': '106118793', 'name': 'norman smith', 'username': 'Thehackandhound'},
#  {'id': '166712218', 'name': 'James Landale', 'username': 'BBCJLandale'},
#  {'id': '18716851', 'name': 'Paul_Rose', 'username': 'Paul_Rose'},
#  {'id': '22460658', 'name': 'Chris Mason', 'username': 'ChrisMasonBBC'},
#  {'id': '143145579', 'name': 'The Poke', 'username': 'ThePoke'},
#  {'id': '29739553',
#   'name': 'Victoria Coren Mitchell',
#   'username': 'VictoriaCoren'},
#  {'id': '54974060', 'name': 'Tom ‘Wookie’ Ford', 'username': 'tomwookieford'},
#  {'id': '757337387689181189',
#   'name': 'La Vie Claire Fan 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f 🇫🇷',
#   'username': 'lavieclaire1986'},
#  {'id': '738341549302550529',
#   'name': 'U.K Snow Updates',
#   'username': 'UKsnow_updates'},
#  {'id': '118685634', 'name': 'the Inner Ring', 'username': 'inrng'},
#  {'id': '1038684084388737029',
#   'name': 'MyFlooringJobsUK',
#   'username': 'flooringjobsuk'},
#  {'id': '59487557', 'name': 'Carpet Roles UK', 'username': 'CarpetRolesUK'},
#  {'id': '112733139',
#   'name': 'Ebony Rainford-Brent',
#   'username': 'ejrainfordbrent'},
#  {'id': '86664924', 'name': 'Jay Rayner', 'username': 'jayrayner1'},
#  {'id': '2706072331',
#   'name': 'Sir Geoffrey Boycott',
#   'username': 'GeoffreyBoycott'},
#  {'id': '470357978', 'name': 'Mia Stålnacke', 'username': 'AngryTheInch'},
#  {'id': '74177227', 'name': 'Larry Warbasse', 'username': 'larrywarbasse'},
#  {'id': '49605149', 'name': 'Tony Livesey', 'username': 'tonylivesey'},
#  {'id': '381431945', 'name': 'Team DSM', 'username': 'TeamDSM'},
#  {'id': '110056427', 'name': 'Alex Dowsett', 'username': 'alexdowsett'},
#  {'id': '315439784', 'name': 'Conor Dunne', 'username': 'conordunnealot'},
#  {'id': '2275096473',
#   'name': 'Visit Wakefield™',
#   'username': 'Visit_Wakefield'},
#  {'id': '966458868', 'name': 'Sean Yates', 'username': 'SeanYatesCoach'},
#  {'id': '2220024959', 'name': 'Keeley Hawes', 'username': 'Misskeeleyhawes'},
#  {'id': '1023856287673737216',
#   'name': 'NifcoUK_Jobs',
#   'username': 'NifcoUK_Jobs'},
#  {'id': '369993105', 'name': 'Oliver naesen', 'username': 'OliverNaesen'},
#  {'id': '578098244', 'name': 'Jonathan Harris-Bass', 'username': 'Jono_HB'},
#  {'id': '2881357498', 'name': 'Velon CC', 'username': 'VelonCC'},
#  {'id': '1276052881', 'name': 'Abbey Westmalle', 'username': 'abbeywestmalle'},
#  {'id': '724507227294412800',
#   'name': 'Tour of Slovenia',
#   'username': 'TourOfSlovenia'},
#  {'id': '1901273077',
#   'name': 'Kenny Van Vlaminck',
#   'username': 'KVanVlaminck'},
#  {'id': '993466760',
#   'name': 'Team Jumbo-Visma cycling',
#   'username': 'JumboVismaRoad'},
#  {'id': '3221068227', 'name': 'StravaWankers', 'username': 'stravawankers'},
#  {'id': '20841000', 'name': 'Jonny Smith', 'username': 'Carpervert'},
#  ...]

# %%
    json_complete = {"data":list(),"users":list()}
    
    with open(file, "r") as json_file:
        for line in json_file:
            data = json.loads(line)
            json_complete["data"].extend(data["data"])
            json_complete["users"].extend(data["includes"]["users"])

# %%
next_token = None
next_page = True
ctr = 0

query_params = {'max_results': 500, #max value is 500
                'pagination_token': next_token}


file_ID = f'\batch1.txt'
file = FILE_PATH + file_ID


print("Starting...")
#while next_page == True:
#    main()
#    ctr += 1
#    print(f'Retrieved Tweets: {query_params["max_results"] * ctr}')
# Out:
# Starting...

# %%
file
# Out:
# '/Users/Janiwo/Desktop/CBS/4. Semester/Thesis/Files/all_refugee_02_2021-02-01T00:00:00Z_2021-03-01T00:00:00Z.txt'

# %%
json_complete = load_full_json(file)

# %%
df = pd.json_normalize(json_complete["data"])

# %%
max(df["created_at"])
# Out:
# '2020-07-31T23:59:58.000Z'

# %%
min(df["created_at"])
# Out:
# '2020-07-13T19:14:52.000Z'

# %%
df[df["created_at"]<"2020-09-09T00:00:00.000Z"].shape
# Out:
# (1224, 22)

# %%
df[df["created_at"]>"2020-09-09T00:00:00.000Z"].shape
# Out:
# (26443, 22)

# %%
hashtag_count = get_hashtag_counts(json_complete)
sort_hash_count = sorted(hashtag_count.items(), key=lambda x: x[1], reverse=True)
sort_hash_count[:100]
# Out:
# [('refugees', 4335),
#  ('Tigray', 3943),
#  ('COVID19', 3366),
#  ('StopWarOnTigray', 3203),
#  ('Iraqi_Refugees_Look_For_Homeland', 3045),
#  ('Ethiopia', 3002),
#  ('Refugees', 2966),
#  ('TigrayGenocide', 2627),
#  ('migrants', 2498),
#  ('immigrants', 2258),
#  ('S386', 2118),
#  ('UnblockS386', 2037),
#  ('refugee', 1766),
#  ('immigration', 1728),
#  ('StopAbiy', 1652),
#  ('RickBeijingScott', 1611),
#  ('NoS386', 1558),
#  ('Sudan', 1530),
#  ('Election2020', 1450),
#  ('DV2021', 1403),
#  ('Immigrants', 1316),
#  ('Armenia', 1257),
#  ('Azerbaijan', 1170),
#  ('Immigrant', 1055),
#  ('BidenHarris2020', 1055),
#  ('Syria', 1043),
#  ('Biden', 1008),
#  ('DV2020', 967),
#  ('RefugeesWelcome', 966),
#  ('immigrant', 935),
#  ('S386OutsourcingBill', 923),
#  ('Trump', 892),
#  ('BJP', 879),
#  ('LEGAL', 853),
#  ('KarabakhisAzerbaijan', 840),
#  ('EU', 829),
#  ('StandWithIraqiRefugees', 800),
#  ('Turkey', 792),
#  ('Immigration', 777),
#  ('Karabakh', 750),
#  ('SmartNews', 698),
#  ('DontBelieveArmenia', 695),
#  ('migrant', 683),
#  ('terrorist', 664),
#  ('France', 654),
#  ('Democrats', 653),
#  ('Eritrea', 650),
#  ('auspol', 628),
#  ('migration', 613),
#  ('BlackLivesMatter', 610),
#  ('Europe', 609),
#  ('Rohingya', 604),
#  ('Libya', 596),
#  ('Canada', 592),
#  ('HumanRights', 587),
#  ('S386IsNotFair', 556),
#  ('UNHCR', 550),
#  ('Vienna', 549),
#  ('USA', 522),
#  ('لاجئيين_عراقيين_يبحثون_عن_وطن', 521),
#  ('Congratulations', 507),
#  ('UN', 490),
#  ('EbarBanglayBJP', 488),
#  ('R2PTigray', 479),
#  ('Genocide', 472),
#  ('PassS386', 468),
#  ('Refugee', 462),
#  ('Azerbaijani', 458),
#  ('Greece', 454),
#  ('Migrants', 445),
#  ('UK', 436),
#  ('FreedomTogether', 435),
#  ('WorldChildrensDay', 421),
#  ('ADOS', 418),
#  ('asylum', 417),
#  ('BidenHarris', 413),
#  ('Iraqi_Refugees_Look_For_Homelandyears', 411),
#  ('TPLF', 410),
#  ('Elections2020', 388),
#  ('GivingTuesday', 385),
#  ('KamalaHarris', 381),
#  ('Armenian', 373),
#  ('Artsakh', 372),
#  ('racism', 369),
#  ('WarCrimes', 364),
#  ('StopArmenianOccupation', 363),
#  ('cdnpoli', 362),
#  ('DACA', 358),
#  ('bidenharis2020', 356),
#  ('UAE', 355),
#  ('JoeBiden', 352),
#  ('Bangladesh', 351),
#  ('Vote', 350),
#  ('coronavirus', 343),
#  ('MAGA', 337),
#  ('Covid19', 331),
#  ('IDP', 326),
#  ('VOTE', 326),
#  ('racist', 319),
#  ('ElectionDay', 319)]
