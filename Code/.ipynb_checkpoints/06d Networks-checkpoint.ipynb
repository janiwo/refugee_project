# %% [markdown]
# # Network Analysis

# %%
# https://programminghistorian.org/en/lessons/exploring-and-analyzing-network-data-with-python

# %%
import pandas as pd
from collections import defaultdict
import itertools

import networkx as nx
#import nxviz
#from nxviz.plots import MatrixPlot, ArcPlot, CircosPlot
import matplotlib.pyplot as plt


from community import community_louvain

from pyvis.network import Network
#import plotly.offline as py
#import plotly.graph_objects as go

# %%
def create_edgelist(entity_list, retweets):
    """
    Creates a weighted edgelist based on entity co-occurence.
    
        Parameters:
            entity_list (list): List of lists of entities occuring together.
        
        Returns:
            df_edgelist (dataframe): Pandas dataframe that shows number of co-occurances of different entities. 
    """
    
    print("\nCreating Edgelist...\n\n")
    
    cooccurence_dict = defaultdict(lambda: defaultdict(int))
    
    # Iterate over all entity co-occurences
    for cooccurence, retweet in zip(entity_list,retweets):
    
    # Check whether more than one entity is available
        if len(cooccurence) > 1:
    
        # Get all possible combinations of entities
            combinations = list(itertools.combinations(sorted(cooccurence), 2))
            
    
            # Increment count of entity co-occurences by retweet count + 1
            for combination in combinations:
                cooccurence_dict[combination]["Co_Occurence"] += 1
                cooccurence_dict[combination]["Retweet"] += (retweet+1)             
        
    # Convert dict to dataframe
    #df_edgelist = pd.Series(cooccurance_dict).reset_index()
    #df_edgelist.columns = ['Entity_1', 'Entity_2', 'Weight']
    
    df_edgelist = pd.DataFrame.from_dict(cooccurence_dict, orient="index")
    df_edgelist.reset_index(inplace=True)
    df_edgelist.rename({"level_0":"Entity_1","level_1":"Entity_2"},axis=1, inplace=True)
    df_edgelist = df_edgelist[df_edgelist["Entity_1"] != df_edgelist["Entity_2"]]
    
    # Return edgelist dataframe
    return df_edgelist

# %%
def get_entity_count(series):
    dict_count = defaultdict(int)
    
    for entities in series:
        for entity in entities:
            if len(entity) > 0:
                dict_count[entity] += 1
            
    return dict_count

# %%
def create_overall_graph(df,df_edgelist,entity = "hashtags"):
    print("\nCreating the Overall Graph...\n\n")

    G = nx.Graph()
    
    for entity_1,entity_2,weight in zip(df_edgelist["Entity_1"],
                                        df_edgelist["Entity_2"],
                                        df_edgelist["Weight"]):
        G.add_edge(entity_1,entity_2, weight = weight, width=weight)
    
    
    print(nx.info(G))
    print("\n----------------------------------------------\n\n")

    entity_count = get_entity_count(df[entity])
    degree_centrality = nx.degree_centrality(G)
    eigenvector_centrality = nx.eigenvector_centrality(G, weight = "weight")
    size = {k:v/max(degree_centrality.values())*30 for (k,v) in degree_centrality.items()}

    nx.set_node_attributes(G, entity_count, "entity_count" )
    nx.set_node_attributes(G, degree_centrality, "Degree Centrality")
    nx.set_node_attributes(G, eigenvector_centrality, "Eigenvector Centrality")
    nx.set_node_attributes(G, size, "size")
    
    df_node_attributes = pd.DataFrame.from_dict(dict(G.nodes(data=True)),
                                            orient="index").reset_index().rename({"index":"entity"}, axis = 1)
    df_node_attributes = df_node_attributes.sort_values(by="Degree Centrality", ascending=False).reset_index(drop=True)
    
    print(f"Most important {entity} in the network:")
    print(df_node_attributes[["entity","entity_count","Degree Centrality"]].head(15))
    print("\n----------------------------------------------\n\n")
    
    return G, df_node_attributes

# %%
def create_subgraph(df_node_attributes, G, node_count = 50, filename = "abc.html"):
    print("\nCreating Subgraph...\n\n")
    
    cut_off = df_node_attributes.loc[node_count,"Degree Centrality"]
    selected_nodes = [n for n,v in G.nodes(data=True) if v["Degree Centrality"]>cut_off]
    
    G_sub = G.subgraph(selected_nodes)
    
    partition = community_louvain.best_partition(G_sub, random_state=42)
    print(f"Identified {len(set(partition.values()))} clusters.")
    
    colors_partition = {k:v for (k,v) in colors.items() if k < len(set(partition.values()))}
    
    node_colors = {k:colors_partition[v] for (k,v) in partition.items()}
    
    nx.set_node_attributes(G_sub, partition, "Partiton")
    nx.set_node_attributes(G_sub, node_colors, "color")
    
    print("\nPlotting Graph...\n\n")
    n = Network(height = "1500px", width ="100%", font_color ="#616a6b ")
    #n.show_buttons()
    n.from_nx(G_sub)
    n.barnes_hut()
    n.show_buttons(filter_=["nodes","edges","physics"])
    n.show(filename)
    print("\nGraph succesfully plotted\n\n")

# %%
def all_in_one(df, entity, filename,node_count=50, weighting = "Retweet"):
    
    df_edgelist = create_edgelist(list(df[entity]), list(df["retweet_count_sum"]))
    df_edgelist["Weight"] = df_edgelist[weighting]/(max(df_edgelist[weighting])/25)
    df_edgelist = df_edgelist.sort_values(by="Weight", ascending=False)
    
    print(f"Most frequently co-occuring hashtags sorted by {weighting}:")
    print(df_edgelist[["Entity_1","Entity_2","Co_Occurence","Retweet"]].head(15))
    print("\n----------------------------------------------\n\n")
    
    G, df_node_attributes = create_overall_graph(df,
                                                 df_edgelist,
                                                 entity = entity)
    
    create_subgraph(df_node_attributes, G, node_count = node_count, filename = filename)

# %%
colors = {0:"#6495ED",
          1:"#9FE2BF",
          2:"#FFBF00",
          3:"#717d7e",
          4:"#cb4335",
          5:"#7d3c98",
          6:"#273746",
          7:"#196f3d "}

# %% [markdown]
# ## Import the data

# %%
df_greece = pd.read_csv(r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data\Event Dataframes\Clean\df_greece_clean.csv",
                        converters = {"hashtags": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "mentions": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "annotations": lambda x: x.strip("[]").replace("'","").split(", ")})
# Drop unnecessary index column
df_greece.drop("Unnamed: 0", axis=1, inplace=True)
df_greece.head()
# Out:
#                source                                               text lang  \
# 0      Hootsuite Inc.  PA Ambassador in Bosnia &amp; Herzegovina says...   en
# 1          u.fooo.ooo  [🔴 NEWS] Greece plans floating sea border wall...   en
# 2  Twitter Web Client  Latest Battle for Idlib Could Send Another Wav...   en
# 3           Tweepsmap  UNHCR calls for decisive action to end alarmin...   en
# 4  Twitter for iPhone  It is not your own feet sinking in the mud, bo...   en
#
#                     id                 created_at            author_id  \
# 0  1227019550912372737  2020-02-11 00:00:32+00:00             81136269
# 1  1227019556167864321  2020-02-11 00:00:33+00:00  1052191553802854407
# 2  1227021374780313601  2020-02-11 00:07:47+00:00             18570470
# 3  1227021789525614594  2020-02-11 00:09:26+00:00             62632306
# 4  1227022233484308481  2020-02-11 00:11:12+00:00           2729959018
#
#    retweet_count  reply_count  like_count  quote_count  ...  migrant  \
# 0              1            0           1            0  ...    False
# 1              0            0           0            0  ...    False
# 2              0            0           1            1  ...    False
# 3              0            0           0            0  ...    False
# 4              9            1          29            1  ...    False
#
#   immigrant asylum_seeker  other        date  \
# 0     False         False  False  2020-02-11
# 1     False         False  False  2020-02-11
# 2     False         False  False  2020-02-11
# 3     False         False  False  2020-02-11
# 4     False         False  False  2020-02-11
#
#                                        text_coherent  retweet_count_sum count  \
# 0  PA Ambassador in Bosnia & Herzegovina says lif...                  1     1
# 1  [ NEWS] Greece plans floating sea border wall ...                  0     1
# 2  Latest Battle for Idlib Could Send Another Wav...                  8     5
# 3  UNHCR calls for decisive action to end alarmin...                  9     3
# 4   It is not your own feet sinking in the mud, boy.                  9     1
#
#                                        text_alphanum  \
# 0  pa ambassador in bosnia  herzegovina says life...
# 1   news greece plans floating sea border wall to...
# 2  latest battle for idlib could send another wav...
# 3  unhcr calls for decisive action to end alarmin...
# 4    it is not your own feet sinking in the mud boy.
#
#                                             text_stm
# 0  ambassador bosnia herzegovina say life europe ...
# 1         news greece plan floating border wall keep
# 2  latest battle idlib could send another wave eu...
# 3  unhcr call decisive action alarming condition ...
# 4                                       foot sinking
#
# [5 rows x 30 columns]

# %%
df_channel = pd.read_csv(r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data\Event Dataframes\Clean\df_channel_clean.csv",
                         converters = {"hashtags": lambda x: x.strip("[]").replace("'","").split(", "),
                                       "mentions": lambda x: x.strip("[]").replace("'","").split(", "),
                                       "annotations": lambda x: x.strip("[]").replace("'","").split(", ")})
# Drop unnecessary index column
df_channel.drop("Unnamed: 0", axis=1, inplace=True)
df_channel.head()
# Out:
#                source                                               text lang  \
# 0       WordPress.com  CHANNEL MIGRANT CRISIS – TODAYS VIDEOS FROM DO...   en
# 1     Twitter Web App  “Chinese immorality [and] eccentricities … are...   en
# 2  Twitter for iPhone  @chrisgregson123 @VeuveK @CharlieHicks90 @Rudy...   en
# 3  Twitter for iPhone  @SkyNews It never will if uk keeps bring in hu...   en
# 4  Twitter for iPhone  How many illegal immigrants this week in #Dove...   en
#
#                     id                 created_at            author_id  \
# 0  1284639846930227200  2020-07-19 00:03:01+00:00  1039171425364520960
# 1  1284640070855729163  2020-07-19 00:03:55+00:00            153438157
# 2  1284640230499328000  2020-07-19 00:04:33+00:00            503070765
# 3  1284640911788576770  2020-07-19 00:07:15+00:00  1276420769384402944
# 4  1284641481576402945  2020-07-19 00:09:31+00:00   755084846783950848
#
#    retweet_count  reply_count  like_count  quote_count  ...  refugee migrant  \
# 0              0            0           0            0  ...    False    True
# 1             22            1          37            0  ...    False   False
# 2              0            0           0            1  ...    False   False
# 3              1            1           3            1  ...    False    True
# 4              0            0           0            0  ...    False   False
#
#   immigrant asylum_seeker  other  \
# 0     False         False  False
# 1      True         False  False
# 2     False         False  False
# 3     False          True  False
# 4      True         False  False
#
#                                        text_coherent  retweet_count_sum count  \
# 0    CHANNEL MIGRANT CRISIS TODAYS VIDEOS FROMDOVER.                  0     1
# 1  Chinese immorality [and] eccentricities are ab...                 22     1
# 2  O / c Leavers voted for what they believed was...                  0     1
# 3  It never will if uk keeps bring in hundreds of...                  1     1
# 4  How many illegal immigrants this week in dover...                  0     1
#
#                                        text_alphanum  \
# 0    channel migrant crisis todays videos fromdover.
# 1  chinese immorality and eccentricities are abho...
# 2  o  c leavers voted for what they believed was ...
# 3  it never will if uk keeps bring in hundreds of...
# 4  how many illegal immigrants this week in dover...
#
#                                             text_stm
# 0               channel crisis today video fromdover
# 1  chinese immorality eccentricity abhorrent arya...
# 2  leaver voted believed best england wale howeve...
# 3  never keep bring hundred asylum seeker giving ...
# 4                            many illegal week dover
#
# [5 rows x 30 columns]

# %%
df_tigray = pd.read_csv(r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data\Event Dataframes\Clean\df_tigray_clean.csv",
                        converters = {"hashtags": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "mentions": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "annotations": lambda x: x.strip("[]").replace("'","").split(", ")})
# Drop unnecessary index column
df_tigray.drop("Unnamed: 0", axis=1, inplace=True)
df_tigray.head()
# Out:
#                source                                               text lang  \
# 0     Twitter Web App  @FilippoGrandi Thank you for your statement......   en
# 1  Twitter for iPhone  Action Now\n#HumanitarianCorridor Now\n#HumanR...   en
# 2     Twitter Web App  "@AUC_MoussaFaki has disregarded and violated ...   en
# 3  Twitter for iPhone  @Refugees @zeaxumawit @FilippoGrandi But @anto...   en
# 4     Twitter Web App  We call for global solidarity to STOP killings...   en
#
#                     id                 created_at            author_id  \
# 0  1349868943800897537  2021-01-15 00:00:10+00:00  1325094884680765445
# 1  1349868980102696963  2021-01-15 00:00:18+00:00           1296598454
# 2  1349869527773933569  2021-01-15 00:02:29+00:00  1331304034230292482
# 3  1349870752070311936  2021-01-15 00:07:21+00:00  1325975568882479104
# 4  1349871059835744256  2021-01-15 00:08:34+00:00  1327215334097608704
#
#    retweet_count  reply_count  like_count  quote_count  ...  migrant  \
# 0              1            0           1            0  ...    False
# 1              1            0           1            1  ...    False
# 2              0            0           0            0  ...    False
# 3              0            0           0            0  ...    False
# 4              4            0           8            1  ...    False
#
#   immigrant asylum_seeker  other        date  \
# 0     False         False  False  2021-01-15
# 1     False         False  False  2021-01-15
# 2     False         False  False  2021-01-15
# 3     False         False  False  2021-01-15
# 4     False         False  False  2021-01-15
#
#                                        text_coherent  retweet_count_sum count  \
# 0  Thank you for your statement . . . Now what AC...                  1     1
# 1               Action Now humanitarian corridor Now                  1     1
# 2  " Moussa Faki Mahamat has disregarded and viol...                 73    55
# 3  But António Guterres said there are no Eritrea...                  0     1
# 4  We call for global solidarity to STOP killings...                  4     1
#
#                                        text_alphanum  \
# 0  thank you for your statement . . . now what ac...
# 1               action now humanitarian corridor now
# 2   moussa faki mahamat has disregarded and viola...
# 3  but antnio guterres said there are no eritrean...
# 4  we call for global solidarity to stop killings...
#
#                                             text_stm
# 0  thank statement action taken civilian tigray u...
# 1                       action humanitarian corridor
# 2  moussa faki mahamat disregarded violated inter...
# 3  guterres said eritrean troop ethiopia need ret...
# 4  call global solidarity stop killing abduction ...
#
# [5 rows x 30 columns]

# %%
df_rohingya = pd.read_csv(r"C:\Users\jawo19ad\Dropbox (CBS)\Master thesis data\Event Dataframes\Clean\df_rohingya_clean.csv",
                        converters = {"hashtags": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "mentions": lambda x: x.strip("[]").replace("'","").split(", "),
                                      "annotations": lambda x: x.strip("[]").replace("'","").split(", ")})
# Drop unnecessary index column
df_rohingya.drop("Unnamed: 0", axis=1, inplace=True)
df_rohingya.head()
# Out:
#                 source                                               text  \
# 0      Twitter Web App  For #Rohingya Survivors in Bangladesh, Artwork...
# 1              dlvr.it  AstraZeneca dispels Indonesian Muslim concerns...
# 2  Twitter for Android  @prabha_j @MehHarshil @derekobrienmp I think u...
# 3  Twitter for Android  India seals Myanmar border amid strains over r...
# 4   Twitter for iPhone  Fleeing coup, Myanmar police refugees in India...
#
#   lang                   id                 created_at            author_id  \
# 0   en  1373792416126402560  2021-03-22 00:23:30+00:00             77844813
# 1   en  1373800977778700288  2021-03-22 00:57:31+00:00           1898083759
# 2   en  1373802051524730880  2021-03-22 01:01:47+00:00  1209116380257112064
# 3   en  1373802536579174401  2021-03-22 01:03:43+00:00  1032998054297780224
# 4   en  1373804367757807619  2021-03-22 01:10:59+00:00             15552861
#
#    retweet_count  reply_count  like_count  quote_count  ...  refugee migrant  \
# 0              2            1           2            0  ...     True   False
# 1              1            0           0            0  ...     True   False
# 2              0            0           1            0  ...    False    True
# 3              0            0           0            0  ...     True   False
# 4              1            0           1            0  ...     True   False
#
#   immigrant asylum_seeker  other  \
# 0     False         False  False
# 1     False         False  False
# 2     False         False  False
# 3     False         False  False
# 4     False         False  False
#
#                                        text_coherent  retweet_count_sum count  \
# 0  For rohingya Survivors in Bangladesh, Artwork ...                  2     1
# 1  AstraZeneca dispels Indonesian Muslim concerns...                  1     1
# 2  I think u are one of the illegally migrant Roh...                  0     1
# 3  India seals Myanmar border amid strains over r...                  0     1
# 4  Fleeing coup, Myanmar police refugees in India...                  1     1
#
#                                        text_alphanum  \
# 0  for rohingya survivors in bangladesh artwork b...
# 1  astrazeneca dispels indonesian muslim concerns...
# 2  i think u are one of the illegally migrant roh...
# 3  india seals myanmar border amid strains over r...
# 4  fleeing coup myanmar police refugees in india ...
#
#                                             text_stm
# 0  rohingya survivor bangladesh artwork bear witn...
# 1  astrazeneca dispels indonesian muslim concern ...
# 2  think illegally rohingya bangladesh better kee...
# 3       india seal myanmar border amid strain crisis
# 4  fleeing coup myanmar police india seek asylum ...
#
# [5 rows x 30 columns]

# %%
all_in_one(df_greece,"hashtags","nw_greece_hashtags.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#                 Entity_1          Entity_2  Co_Occurence  Retweet
# 48                greece            turkey          3955    44678
# 575               greece          refugees          2645    19062
# 1373            refugees            turkey          2586    15474
# 102                syria            turkey          2345    16120
# 291                   eu            turkey          1820     9683
# 107             refugees             syria          1686     8280
# 218                   eu            greece          1543    12143
# 226                idlib             syria          1468    12428
# 37                europe            turkey          1401     9012
# 1496             erdogan            turkey          1312    15234
# 170               greece          migrants          1288     6837
# 155                   eu          refugees          1232     5203
# 202             migrants            turkey          1141     5297
# 37115  greeceunderattack  istandwithgreece          1104    30038
# 27                europe            greece          1099     6356
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 11470
# Number of edges: 108084
# Average degree:  18.8464
#
# ----------------------------------------------
#
#
# Most important hashtags in the network:
#                entity  entity_count  Degree Centrality
# 0            refugees          7346           0.360101
# 1              turkey          9362           0.305955
# 2              greece         10173           0.304037
# 3               syria          5982           0.262795
# 4                  eu          4772           0.230099
# 5              europe          3388           0.222600
# 6            migrants          2796           0.185108
# 7             erdogan          2563           0.131746
# 8             refugee          1275           0.120063
# 9               idlib          2943           0.115878
# 10              greek          1836           0.111605
# 11   istandwithgreece          4715           0.103409
# 12             syrian          1243           0.096870
# 13        coronavirus          1103           0.088412
# 14  greeceunderattack          2314           0.079867
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 3 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_greece,"mentions","nw_greece_mentions_retweet.html",weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#               Entity_1         Entity_2  Co_Occurence  Retweet
# 21961    eucopresident      vonderleyen           522     3471
# 1209     eu_commission      vonderleyen           470     1471
# 52728    eucopresident  primeministergr           341      726
# 125           refugees               un           321      863
# 21990     ep_president      vonderleyen           303      713
# 74193     ep_president    eucopresident           270      632
# 1180           skynews    stone_skynews           259      330
# 29609    eu_commission    eucopresident           249      632
# 1082   mindedmusically       the_leaver           210      227
# 969        jag11814459  mindedmusically           210      227
# 977        jag11814459       the_leaver           210      227
# 425         begentle50         dw2essex           209      226
# 872           dw2essex       the_leaver           209      226
# 437         begentle50  mindedmusically           209      226
# 1084   mindedmusically           veuvek           209      226
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 32834
# Number of edges: 161352
# Average degree:   9.8283
#
# ----------------------------------------------
#
#
# Most important mentions in the network:
#              entity  entity_count  Degree Centrality
# 0          refugees          1481           0.039137
# 1     eu_commission          1488           0.034386
# 2                un          1038           0.033960
# 3   realdonaldtrump           808           0.031462
# 4       vonderleyen          1623           0.030335
# 5              nato           702           0.027290
# 6   primeministergr          1465           0.022538
# 7         rterdogan           798           0.019645
# 8               hrw           713           0.019127
# 9     eucopresident           941           0.019097
# 10     borisjohnson           390           0.018975
# 11         bbcworld           534           0.017482
# 12          amnesty           687           0.015503
# 13          skynews           728           0.015411
# 14   emmanuelmacron           297           0.015381
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 5 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_channel,"hashtags","nw_channel_hashtags.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#       Entity_1         Entity_2  Co_Occurence  Retweet
# 1739  migrants               uk           266      746
# 20    migrants         refugees           215     1995
# 123     france               uk           201     1012
# 2885    france         migrants           194      512
# 1413  refugees  refugeeswelcome           168      503
# 1400  refugees               uk           167      574
# 2207    brexit         migrants           164      887
# 1884  migrants       pritipatel           159      907
# 387         eu         refugees           156      938
# 370         eu         migrants           153     1180
# 2235   bbcnews          skynews           147      487
# 15      europe         refugees           132     1500
# 1314     dover         migrants           131      662
# 1779    brexit               eu           128      425
# 1390        eu               uk           123      903
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 7618
# Number of edges: 51902
# Average degree:  13.6261
#
# ----------------------------------------------
#
#
# Most important hashtags in the network:
#              entity  entity_count  Degree Centrality
# 0          migrants          2045           0.230800
# 1          refugees          1587           0.206249
# 2                uk          1445           0.189051
# 3                eu          1103           0.140081
# 4            france           797           0.127478
# 5            europe           608           0.120520
# 6            brexit          1467           0.115137
# 7        immigrants           413           0.102796
# 8       immigration           403           0.088092
# 9           covid19           464           0.087042
# 10  refugeeswelcome           971           0.073257
# 11       pritipatel           713           0.072995
# 12          refugee           286           0.067743
# 13        migration           259           0.060916
# 14          migrant           294           0.060129
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 3 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_channel,"mentions","nw_channel_mentions_retweet.html",weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#                Entity_1       Entity_2  Co_Occurence  Retweet
# 755        borisjohnson     pritipatel          5505    30845
# 3905       nigel_farage     pritipatel          3689    10659
# 111609   benandjerrysuk     pritipatel          2860     4009
# 4088       borisjohnson   nigel_farage          1706     6488
# 1230         pritipatel   ukhomeoffice          1639     6109
# 13670        davidlammy     pritipatel          1148     1860
# 746     10downingstreet   borisjohnson           778     3346
# 2541       borisjohnson  conservatives           741     3023
# 2724      conservatives     pritipatel           729     2922
# 750     10downingstreet     pritipatel           715     2815
# 2525            bbcnews        skynews           626     2046
# 4943       nigel_farage   ukhomeoffice           565     3465
# 6501              iromg      talkradio           442     1052
# 37665       britishalba     pritipatel           413      478
# 59461       glos_police     pritipatel           406      856
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 47085
# Number of edges: 203915
# Average degree:   8.6616
#
# ----------------------------------------------
#
#
# Most important mentions in the network:
#              entity  entity_count  Degree Centrality
# 0        pritipatel         29361           0.168146
# 1      nigel_farage         11475           0.104367
# 2      borisjohnson         12763           0.098632
# 3           bbcnews          4726           0.045769
# 4           skynews          3413           0.040014
# 5    benandjerrysuk          3681           0.027993
# 6      ukhomeoffice          2602           0.025911
# 7               lbc          1863           0.021706
# 8     conservatives          1263           0.018074
# 9   realdonaldtrump           382           0.016694
# 10           afneil          1195           0.016248
# 11         refugees           421           0.014272
# 12            iromg          1116           0.014230
# 13  10downingstreet          1260           0.014039
# 14   simonjonesnews          1175           0.013699
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 4 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_tigray,"hashtags","nw_tigray_hashtags.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#                  Entity_1        Entity_2  Co_Occurence  Retweet
# 5                  tigray  tigraygenocide          2139    25528
# 41               ethiopia          tigray          1201    16951
# 393       bidentakeaction  tigraygenocide          1175    10580
# 6876  allowaccesstotigray  tigraygenocide          1131    15116
# 147        tigraycantwait  tigraygenocide           773     6211
# 174               eritrea          tigray           735    11428
# 4         stopwarontigray  tigraygenocide           681     6864
# 195    eritreaoutoftigray  tigraygenocide           622     3319
# 114               eritrea        ethiopia           615     7998
# 6875  allowaccesstotigray          tigray           568     8503
# 681           bidenactnow  tigraygenocide           548    14479
# 301              ethiopia  tigraygenocide           541     6632
# 691       bidentakeaction          tigray           506     4754
# 3317       tigraygenocide      unscactnow           453     5690
# 175               eritrea  tigraygenocide           394     5324
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 2623
# Number of edges: 16390
# Average degree:  12.4971
#
# ----------------------------------------------
#
#
# Most important hashtags in the network:
#                  entity  entity_count  Degree Centrality
# 0                tigray          5046           0.383295
# 1              ethiopia          2484           0.340961
# 2        tigraygenocide          5994           0.300534
# 3               eritrea          1338           0.194127
# 4              refugees           491           0.179252
# 5                  tplf          1075           0.144546
# 6       bidentakeaction          1395           0.142639
# 7                 sudan           578           0.142258
# 8   allowaccesstotigray          1818           0.139969
# 9              eritrean           756           0.125858
# 10      stopwarontigray           939           0.110221
# 11   eritreaoutoftigray           876           0.105645
# 12          bidenactnow           707           0.091533
# 13       tigraycantwait           839           0.091152
# 14            ethiopian           317           0.087719
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 2 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_tigray,"mentions","nw_tigray_mentions.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#               Entity_1       Entity_2  Co_Occurence  Retweet
# 19            refugees             un          2045    12206
# 20            refugees  unhumanrights          1498    13573
# 1105               hrw       refugees          1337     8642
# 1983           amnesty       refugees          1161    14280
# 3      antonioguterres       refugees          1046     5202
# 1107               hrw             un          1019    10910
# 83            refugees         unocha           926     4518
# 12169            potus       refugees           881     2892
# 257           joebiden       refugees           875     5634
# 4      antonioguterres             un           851     5322
# 82            refugees       ungeneva           818     2581
# 2065           amnesty            hrw           796     6522
# 9        filippograndi       refugees           785     9982
# 14070            potus             un           752     9966
# 21                  un  unhumanrights           746     1953
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 5008
# Number of edges: 65590
# Average degree:  26.1941
#
# ----------------------------------------------
#
#
# Most important mentions in the network:
#              entity  entity_count  Degree Centrality
# 0          refugees          5557           0.429199
# 1                un          3291           0.275614
# 2               hrw          1878           0.214300
# 3     unhumanrights          1711           0.206511
# 4      abiyahmedali          1442           0.186339
# 5   antonioguterres          1499           0.180547
# 6           amnesty          1402           0.173757
# 7          joebiden          1831           0.173557
# 8        secblinken          1251           0.165368
# 9          ablinken          1342           0.163172
# 10            potus          1532           0.160176
# 11    eu_commission          1199           0.151188
# 12           unocha          1062           0.143599
# 13         ungeneva           947           0.143000
# 14    josepborrellf           998           0.140803
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 4 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_rohingya,"hashtags","nw_rohingya_hashtags.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#                     Entity_1                 Entity_2  Co_Occurence  Retweet
# 13                bangladesh                 rohingya           942    21172
# 7956               mar30coup  whatshappeninginmyanmar           574     9375
# 1440         milkteaalliance  whatshappeninginmyanmar           532    15335
# 896                    karen  whatshappeninginmyanmar           507    16567
# 15202     noflyzoneinmyanmar  whatshappeninginmyanmar           500    11277
# 52                   myanmar  whatshappeninginmyanmar           487    37565
# 11699               apr4coup  whatshappeninginmyanmar           464    15053
# 22                  refugees                 rohingya           424    10678
# 1492        internetshutdown  whatshappeninginmyanmar           380     5774
# 2                    myanmar                 rohingya           374    10212
# 108                  refugee                 rohingya           342     7376
# 10948               apr2coup  whatshappeninginmyanmar           340     3776
# 6626               mar29coup  whatshappeninginmyanmar           331     6726
# 9343               mar31coup  whatshappeninginmyanmar           278     7766
# 304    crimesagainsthumanity  whatshappeninginmyanmar           254     5686
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 3094
# Number of edges: 19845
# Average degree:  12.8281
#
# ----------------------------------------------
#
#
# Most important hashtags in the network:
#                      entity  entity_count  Degree Centrality
# 0                  rohingya          2637           0.374717
# 1                bangladesh          1400           0.310378
# 2                   myanmar          1945           0.305205
# 3   whatshappeninginmyanmar          7762           0.247333
# 4                  refugees           771           0.239573
# 5                   refugee           541           0.153573
# 6                     india           294           0.103136
# 7                  thailand           598           0.102489
# 8                     karen           732           0.086001
# 9   whatshappeninglnmyanmar           990           0.082768
# 10          milkteaalliance           711           0.076625
# 11              savemyanmar           402           0.076301
# 12              humanrights            90           0.071452
# 13                     fire           128           0.066602
# 14                       un           105           0.066602
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 3 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %%
all_in_one(df_rohingya,"mentions","nw_rohingya_mentions.html", weighting="Co_Occurence")
# Out:
# Creating Edgelist...
#
#
# Most frequently co-occuring hashtags sorted by Co_Occurence:
#             Entity_1         Entity_2  Co_Occurence  Retweet
# 682         refugees               un           440      790
# 263     rapporteurun  schranerburgen1           412     1017
# 41          refugees           un_hrc           374      576
# 206         refugees    unhumanrights           360     1316
# 39      rapporteurun         refugees           359     4270
# 40      rapporteurun           un_hrc           313      632
# 318     rapporteurun               un           302      665
# 240       freya_cole     rapporteurun           295      572
# 343               un           un_hrc           281     1235
# 416         refugees  schranerburgen1           278      491
# 267  schranerburgen1           un_hrc           243      519
# 253          kenroth     rapporteurun           229      402
# 238       freya_cole          kenroth           221      410
# 332  schranerburgen1               un           210      442
# 345               un    unhumanrights           203      478
#
# ----------------------------------------------
#
#
#
# Creating the Overall Graph...
#
#
# Name:
# Type: Graph
# Number of nodes: 4202
# Number of edges: 31287
# Average degree:  14.8915
#
# ----------------------------------------------
#
#
# Most important mentions in the network:
#              entity  entity_count  Degree Centrality
# 0          refugees          1655           0.188527
# 1                un          1223           0.128303
# 2               hrw           273           0.101881
# 3      rapporteurun           934           0.100928
# 4     unhumanrights           525           0.098548
# 5            un_hrc           781           0.094977
# 6   schranerburgen1           572           0.086646
# 7        freya_cole           492           0.069507
# 8   antonioguterres           330           0.068793
# 9       drsasa22222           278           0.065937
# 10            potus           259           0.065223
# 11          mfathai           448           0.062604
# 12         poppymcp           312           0.062128
# 13           unicef           318           0.062128
# 14          kenroth           377           0.061414
#
# ----------------------------------------------
#
#
#
# Creating Subgraph...
#
#
# Identified 4 clusters.
#
# Plotting Graph...
#
#
#
# Graph succesfully plotted

# %% [markdown]
# ## Create edgelist

# %%
df_edgelist_hash = create_edgelist(list(df_greece["hashtags"]), list(df_greece["retweet_count_sum"]))
df_edgelist_hash["Co_Occurence_Norm"] = df_edgelist_hash["Co_Occurence"]/(max(df_edgelist_hash["Co_Occurence"])/10)
df_edgelist_hash["Retweet_Norm"] = df_edgelist_hash["Retweet"]/(max(df_edgelist_hash["Retweet"])/10)
df_edgelist_hash

# %%
#df_edgelist_hash = create_edgelist(list(df_greece["hashtags"])).sort_values(by="Weight",ascending=False).reset_index()
#df_edgelist_hash = df_edgelist_hash[df_edgelist_hash["Entity_1"] != df_edgelist_hash["Entity_2"]]

# %% [markdown]
# ## Create graph

# %%
G_hashtag = nx.Graph()
for entity_1,entity_2,weight in zip(df_edgelist_hash["Entity_1"],
                                    df_edgelist_hash["Entity_2"],
                                    df_edgelist_hash["Co_Occurence_Norm"]):
    G_hashtag.add_edge(entity_1,entity_2, weight = weight, width=weight) #0.005

# %%
print(nx.info(G_hashtag))

# %% [markdown]
# ## Provide node metadata

# %%
hashtag_count = get_entity_count(df_greece["hashtags"])

# Degree Centrality: 
degree_centrality = nx.degree_centrality(G_hashtag)

eigenvector_centrality = nx.eigenvector_centrality(G_hashtag, weight = "weight")

#size = {k:v*100 for (k,v) in degree_centrality.items()}
size = {k:v/max(degree_centrality.values())*10 for (k,v) in degree_centrality.items()}

# %%
# ?nx.degree_centrality

# %%
max(degree_centrality.values())

# %%
nx.set_node_attributes(G_hashtag, hashtag_count, "hashtag_count" )
nx.set_node_attributes(G_hashtag, degree_centrality, "Degree Centrality")
nx.set_node_attributes(G_hashtag, eigenvector_centrality, "Eigenvector Centrality")
nx.set_node_attributes(G_hashtag, size, "size")

# %% [markdown]
# ## Calculate network measures

# %%
# Density: Ratio of actual edges in the network to all possible edges
#density = nx.density(G_hashtag)
# Transitivity: Ration of all triangles over all possible triangles (triadic closure)
#trans = nx.transitivity(G_hashtag)
# Reciprocity:
#reci = nx.reciprocity(G_hashtag)

#print(f"Density: {density}\nTransitivity: {trans}\nReciprocity: {reci}")

# %%
# Diameter: Longest of all shortest paths in network
#nx.is_connected(G_hashtag)
# nx.diameter(G_hashtag)
# nx.average_shortest_path_length(G)

#components = nx.connected_components(G_hashtag)
#largest_component = max(components, key=len)
#subgraph = G_hashtag.subgraph(largest_component)
#diameter = nx.diameter(subgraph)
#print("Network diameter of largest component:", diameter)

# %% [markdown]
# ## Create df with node attributes

# %%
df_node_attributes = pd.DataFrame.from_dict(dict(G_hashtag.nodes(data=True)),
                                            orient="index").reset_index().rename({"index":"hashtag"}, axis = 1)
df_node_attributes = df_node_attributes.sort_values(by="Degree Centrality", ascending=False).reset_index(drop=True)
df_node_attributes.head(15)

# %% [markdown]
# ## Create subgraph that only consists of top 50 nodes with highest degree centrality

# %%
cut_off = df_node_attributes.loc[50,"Degree Centrality"]
selected_nodes = [n for n,v in G_hashtag.nodes(data=True) if v["Degree Centrality"]>cut_off]

# %%
G_hashtag_sub = G_hashtag.subgraph(selected_nodes)

# %% [markdown]
# ## Identify clusters

# %%
partition = community_louvain.best_partition(G_hashtag_sub, random_state=42)
print(f"Identified {len(set(partition.values()))} clusters.")

# %%
colors_partition = {k:v for (k,v) in colors.items() if k < len(set(partition.values()))}

# %%
node_colors = {k:colors_partition[v] for (k,v) in partition.items()}

# %%
nx.set_node_attributes(G_hashtag_sub, partition, "Partiton")
nx.set_node_attributes(G_hashtag_sub, node_colors, "color")

# %% [markdown]
# ## Draw network graph

# %%
G_hashtag_sub.nodes(data=True)

# %%
n = Network(height = "1500px", width ="100%", font_color ="#616a6b ")
#n.show_buttons()
n.from_nx(G_hashtag_sub)
n.barnes_hut()
n.show_buttons(filter_=["nodes","edges","physics"])
n.show("network_test.html")
