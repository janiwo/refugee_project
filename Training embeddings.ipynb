# %% [markdown]
# # Candidate merging and related preprocessing

# %% [markdown]
# Import relevant packages for the following parts

# %%
#python libraries
import numpy as np
import pandas as pd
import os
import re
import gensim

import time
from tqdm import tqdm

from collections import Counter, defaultdict


# self written modules
import preprocessing


# storing python objects in the desired locations using pickle
import pickle

def pickle_file(file_name, file_to_dump):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path +  fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, 'wb') as fp:
        pickle.dump(file_to_dump, fp)

def load_pickle(file_name):
    directory_path = os.getcwd() + "/../../../"
    folder_name = file_name.split('_')[0]
    file_path = directory_path + fr"Dropbox (CBS)/Master thesis data/Candidate Data/{folder_name}/{file_name}"
    with open(file_path, "rb") as input_file:
        return pickle.load(input_file)
# Out:
# Reading english - 1grams ...
# Reading english - 1grams ...
# Reading english - 2grams ...
# C:\ProgramData\Anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# ## 1. Import the data

# %%
tigray_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_tigray.csv" # location of Tigray dataset
greece_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_greece.csv" # location of Greece dataset
rohingya_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_rohingya.csv" # location of Rohingya dataset
moria_url = r"Dropbox (CBS)/Master thesis data/Event Dataframes/df_moria.csv" # location of Rohingya dataset
all_url = r"Dropbox (CBS)/Master thesis data/df_tweets.csv" # for all tweets

def read_event_df(data_url):
    directory_path = os.getcwd() + "/../../../" + data_url 
    event_df = pd.read_csv(directory_path, index_col=0)
    event_df.reset_index(drop=True, inplace=True)
    print(f'loaded {event_df.shape[0]} tweets!')
    return event_df

# pick the df 
event_df = read_event_df(moria_url)
#channel_df = read_event_df(channel_url)
tqdm.pandas()
event_df['text_clean'] = event_df['text'].progress_apply(preprocessing.preprocess_tweets)
# Out:
#   0%|                                                                                       | 0/118696 [00:00<?, ?it/s]
# loaded 118696 tweets!
# 100%|████████████████████████████████████████████████████████████████████████| 118696/118696 [00:46<00:00, 2578.01it/s]

# %%
FILE_PATH = os.getcwd() + "/../../../Dropbox (CBS)/Master thesis data"
USERS_PATH = FILE_PATH + "/df_users.csv"
# Read the users csv

print("loading users dataframe...")
df_users = pd.read_csv(USERS_PATH)

# Drop unnecessary index column
df_users.drop("Unnamed: 0", axis=1, inplace=True)

df_users.head()

# Create dict that maps usernames to actual names
mapping = dict(df_users[["username","name"]].values)
mapping = {f'@{key}': value for key, value in mapping.items()}


def resolve_username_to_name(text):
    new_text = text
    for word in text.split(" "):
        if word in mapping:
            new_text = new_text.replace(word,mapping[word])
    return new_text

#tqdm.pandas()
event_df['text_clean'] = event_df['text_clean'].progress_apply(resolve_username_to_name)
# Out:
# loading users dataframe...
# 100%|██████████████████████████████████████████████████████████████████████| 118696/118696 [00:01<00:00, 106453.17it/s]

# %% [markdown]
# ## Train our own event-specific Word2Vec model

# %%
#fuzzy duplicate removal (removes 100% duplicates before more expensive operations) 
#done on dataframe level, we want to keep the ID column to match later on

# the comparison will be done on lowercased texts consisting of only letters, digits and spaces
event_df['text_clean'] = event_df['text_clean'].progress_apply(lambda tweet:re.sub(r'[^A-Za-z0-9.!? ]+', '', tweet.lower()))
unique_tweets_df = preprocessing.fuzzy_duplicate_removal(event_df)
unique_tweets_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 118696/118696 [00:00<00:00, 126360.21it/s]
# Tweets at the start: 118696
# Tweets after 100% duplicates removed: 91787
# calculating similarities across documents...
# 6982it [00:00, 34779.43it/s]
# Similarity calculation completed in 682.0573885440826 seconds
# removing fuzzy duplicates...
# 167311it [00:04, 37236.79it/s]
# C:\Users\nikodemicek\Documents\GitHub\refugee_project\preprocessing.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dupl_removed['is_dup'][i] = True
# 81327 tweets left after 70.0% similar tweets (by cosine similarity) removed
#                      source  \
# 0         saperduper_robots
# 1                    Loomly
# 2           Twitter Web App
# 3            Hootsuite Inc.
# 4        Twitter for iPhone
# ...                     ...
# 118688  Twitter for Android
# 118689              dlvr.it
# 118691      Twitter Web App
# 118694            Tweepsmap
# 118695      Twitter Web App
#
#                                                      text lang  \
# 0       Migrants clash with Greek police as they exit ...   en
# 1       NATO urges Syria, Russia to halt airstrikes as...   en
# 2       Good on Greece!!....Close all OUR Borders!!......   en
# 3       Increased risk of #MaternalDeath in immigrants...   en
# 4       @OhGodPlsNOO @ilknurdarendeli @AFP Europe has ...   en
# ...                                                   ...  ...
# 118688  @AngeloDDuca @GiuseppeConteIT @IslamSeries @Mi...   en
# 118689  Coronavirus risks taking heavy toll on migrant...   en
# 118691  @ConanOBrien @TheEllenShow @IngrahamAngle @Nob...   en
# 118694  RT @WRRoute\n\nNatasha Dailiani calls upon med...   en
# 118695  @CBlighty @AlynSmith Huge difference. If comin...   en
#
#                          id                 created_at            author_id  \
# 0       1233904804134555649  2020-03-01 00:00:04+00:00            108944513
# 1       1233904855774683136  2020-03-01 00:00:17+00:00           4717892303
# 2       1233904867078393856  2020-03-01 00:00:19+00:00  1067006507189886976
# 3       1233904894425419776  2020-03-01 00:00:26+00:00           3397107171
# 4       1233904905108283393  2020-03-01 00:00:28+00:00  1188172981530435584
# ...                     ...                        ...                  ...
# 118688  1241511809389137920  2020-03-21 23:47:36+00:00   738486583725305857
# 118689  1241512682513002497  2020-03-21 23:51:04+00:00           2985565615
# 118691  1241513000147664896  2020-03-21 23:52:20+00:00            309530329
# 118694  1241514169532321793  2020-03-21 23:56:58+00:00             62632306
# 118695  1241514217905291266  2020-03-21 23:57:10+00:00  1016605258448080898
#
#         retweet_count  reply_count  like_count  quote_count  ...  year  \
# 0                   3            0           1            1  ...  2020
# 1                  12            5          14            3  ...  2020
# 2                   2            1           4            0  ...  2020
# 3                   1            0           2            0  ...  2020
# 4                   0            0           0            1  ...  2020
# ...               ...          ...         ...          ...  ...   ...
# 118688              2            0           0            0  ...  2020
# 118689              0            0           0            0  ...  2020
# 118691              0            2           1            0  ...  2020
# 118694              3            0           1            0  ...  2020
# 118695              0            1           5            0  ...  2020
#
#        calendar_week year_month year_calendar_week refugee  migrant  \
# 0                  8     2020_3            2020_08   False     True
# 1                  8     2020_3            2020_08   False     True
# 2                  8     2020_3            2020_08   False    False
# 3                  8     2020_3            2020_08   False    False
# 4                  8     2020_3            2020_08    True    False
# ...              ...        ...                ...     ...      ...
# 118688            11     2020_3            2020_11    True    False
# 118689            11     2020_3            2020_11   False     True
# 118691            11     2020_3            2020_11   False    False
# 118694            11     2020_3            2020_11   False    False
# 118695            11     2020_3            2020_11    True    False
#
#         immigrant asylum_seeker  other  is_dup
# 0           False         False  False   False
# 1           False         False  False   False
# 2           False         False  False   False
# 3            True         False  False   False
# 4           False         False  False   False
# ...           ...           ...    ...     ...
# 118688      False         False  False   False
# 118689      False         False  False   False
# 118691      False         False  False   False
# 118694      False         False  False   False
# 118695      False         False  False   False
#
# [81327 rows x 25 columns]

# %%
from gensim.models.phrases import Phrases,ENGLISH_CONNECTOR_WORDS

tweet_corpus_tokens = [tweet.split() for tweet in unique_tweets_df['text_clean']]
#tweet_corpus_tokens
bigram = Phrases(tweet_corpus_tokens, min_count=10, threshold=10,connector_words=ENGLISH_CONNECTOR_WORDS) # higher threshold, fewer phrases.
trigram = Phrases(bigram[tweet_corpus_tokens],min_count=10, threshold=10,connector_words=ENGLISH_CONNECTOR_WORDS) 


trigram.vocab
# Out:
# {'thank_you': 353,
#  'your': 1132,
#  'thank_you_for_your': 23,
#  'statement': 109,
#  'your_statement': 2,
#  'now': 2122,
#  'statement_now': 1,
#  'what': 1114,
#  'now_what': 10,
#  'action': 855,
#  'what_action': 2,
#  'is': 7358,
#  'action_is': 16,
#  'being': 723,
#  'is_being': 83,
#  'taken': 192,
#  'being_taken': 11,
#  'get': 429,
#  'taken_to_get': 1,
#  'aid': 828,
#  'get_aid': 9,
#  'all': 1503,
#  'aid_to_all': 3,
#  'refugees': 6441,
#  'all_refugees': 63,
#  'civilians': 630,
#  'refugees_and_civilians': 5,
#  'tigray': 15900,
#  'civilians_in_tigray': 36,
#  'unhcr_the_un': 1508,
#  'tigray_unhcr_the_un': 36,
#  'refugee_agency': 1606,
#  'unhcr_the_un_refugee_agency': 1489,
#  'united_nations': 1330,
#  'refugee_agency_united_nations': 56,
#  'michelle_bachelet': 86,
#  'united_nations_michelle_bachelet': 2,
#  'antnio_guterres': 364,
#  'michelle_bachelet_antnio_guterres': 8,
#  'united_nationshumanrights': 129,
#  'antnio_guterres_united_nationshumanrights': 2,
#  'un_ocha': 27,
#  'united_nationshumanrights_un_ocha': 1,
#  'ethiopia': 4823,
#  'un_ocha_ethiopia': 26,
#  'filippo_grandi': 352,
#  'ethiopia_filippo_grandi': 2,
#  'but': 1224,
#  'but_antnio_guterres': 1,
#  'said': 693,
#  'antnio_guterres_said': 2,
#  'there': 1254,
#  'said_there': 12,
#  'are': 6477,
#  'there_are': 338,
#  'no': 1277,
#  'are_no': 33,
#  'eritrean_troops': 571,
#  'no_eritrean_troops': 8,
#  'eritrean_troops_in_ethiopia': 5,
#  'he': 795,
#  'ethiopia_he': 10,
#  'needs': 290,
#  'he_needs': 4,
#  'retract': 4,
#  'needs_to_retract': 1,
#  'his': 594,
#  'retract_his': 2,
#  'his_statement': 2,
#  'withdraw': 81,
#  'statement_withdraw': 1,
#  'withdraw_his': 1,
#  'bid': 3,
#  'his_bid': 1,
#  'second': 55,
#  'bid_for_second': 1,
#  'term': 22,
#  'second_term': 1,
#  'term_tigray': 2,
#  'genocide': 4040,
#  'tigray_genocide': 3069,
#  'we': 1581,
#  'call': 191,
#  'we_call': 19,
#  'global': 68,
#  'call_for_global': 1,
#  'solidarity': 31,
#  'global_solidarity': 2,
#  'stop': 1195,
#  'solidarity_to_stop': 1,
#  'killings_abductions': 25,
#  'stop_killings_abductions': 1,
#  'starvation': 407,
#  'killings_abductions_starvation': 1,
#  'starvation_of_civilians': 9,
#  'civilians_and_refugees': 25,
#  'ethiopian': 1583,
#  'refugees_by_ethiopian': 1,
#  'eritrean_army': 237,
#  'ethiopian_and_eritrean_army': 7,
#  'lord': 24,
#  'eritrean_army_lord': 1,
#  'tariqahmad': 3,
#  'lord_tariqahmad': 3,
#  'wimbledon': 5,
#  'tariqahmad_of_wimbledon': 3,
#  'marisepayne': 5,
#  'wimbledon_marisepayne': 1,
#  'mona': 3,
#  'marisepayne_mona': 1,
#  'juul': 1,
#  'mona_juul': 1,
#  'brbel': 1,
#  'juul_brbel': 1,
#  'kofler': 1,
#  'brbel_kofler': 1,
#  'mdb': 1,
#  'kofler_mdb': 1,
#  'annika': 1,
#  'mdb_annika': 1,
#  'ben': 12,
#  'annika_ben': 1,
#  'david': 9,
#  'ben_david': 1,
#  'minnaliina': 1,
#  'david_minnaliina': 1,
#  'lind': 2,
#  'minnaliina_lind': 1,
#  'marc_garneau': 63,
#  'lind_marc_garneau': 1,
#  'un': 1492,
#  'un_refugees': 8,
#  'chief': 42,
#  'refugees_chief': 1,
#  'trippin': 1,
#  'chief_trippin': 1,
#  'eritrean_refugees': 2615,
#  'trippin_the_eritrean_refugees': 1,
#  'who': 1516,
#  'eritrean_refugees_who': 93,
#  'were': 1520,
#  'who_were': 137,
#  'living': 241,
#  'were_living': 31,
#  'shimelba_hitsats': 49,
#  'living_at_shimelba_hitsats': 2,
#  'have_been': 1037,
#  'shimelba_hitsats_have_been': 4,
#  'attacked': 198,
#  'have_been_attacked': 6,
#  'tplf_militants': 24,
#  'attacked_by_tplf_militants': 4,
#  'tplf_militants_the_refugees': 2,
#  'run_away': 15,
#  'refugees_run_away': 4,
#  'found': 123,
#  'run_away_and_found': 2,
#  'shelter': 103,
#  'found_shelter': 4,
#  'gonder': 15,
#  'shelter_in_gonder': 2,
#  'here': 306,
#  'gonder_here': 2,
#  'here_is': 69,
#  'their': 1351,
#  'is_their': 22,
#  'voices': 21,
#  'their_voices': 4,
#  'they': 2621,
#  'voices_and_they': 2,
#  'they_said': 22,
#  'said_they': 33,
#  'don_t': 295,
#  'they_don_t': 33,
#  'want': 240,
#  'don_t_want': 29,
#  'go_back': 34,
#  'want_go_back': 2,
#  'tigrai': 214,
#  'go_back_to_tigrai': 2,
#  'out': 637,
#  '9million': 1,
#  'out_of_9million': 1,
#  'tigray_ans': 203,
#  '9million_tigray_ans': 1,
#  'over': 787,
#  'tigray_ans_over': 1,
#  '45_million': 337,
#  'over_45_million': 29,
#  'people': 3953,
#  '45_million_people': 149,
#  'face': 87,
#  'people_face': 2,
#  'famine': 542,
#  'face_famine': 3,
#  'government': 638,
#  'famine_the_government': 1,
#  'government_is': 54,
#  'killing': 513,
#  'is_killing': 27,
#  'unarmed': 22,
#  'killing_unarmed': 3,
#  'unarmed_civilians': 7,
#  'their_own': 133,
#  'civilians_in_their_own': 2,
#  'homes': 36,
#  'their_own_homes': 3,
#  'places': 76,
#  'homes_and_places': 1,
#  'birth': 27,
#  'places_of_birth': 1,
#  'destroying': 117,
#  'birth_destroying': 1,
#  'everything': 112,
#  'destroying_everything': 1,
#  'everything_in_their': 1,
#  'path': 13,
#  'their_path': 1,
#  'eritrean_soldiers': 288,
#  'path_eritrean_soldiers': 1,
#  'eritrean_soldiers_are': 42,
#  'rapeing': 2,
#  'are_rapeing': 1,
#  'women_children': 54,
#  'rapeing_women_children': 1,
#  'women_children_destroying': 1,
#  'our': 714,
#  'destroying_our': 1,
#  'heritage_sites': 15,
#  'our_heritage_sites': 1,
#  'churches_mosques': 22,
#  'heritage_sites_churches_mosques': 1,
#  'tigray_is': 377,
#  'fighting': 241,
#  'is_fighting': 15,
#  'keep': 93,
#  'fighting_to_keep': 1,
#  'democracy': 37,
#  'keep_democracy': 1,
#  'alive': 29,
#  'democracy_alive': 1,
#  'as': 1861,
#  'alive_as': 1,
#  'abiy_ahmed': 986,
#  'as_abiy_ahmed': 6,
#  'abiy_ahmed_is': 31,
#  'dictator': 172,
#  'is_a_dictator': 2,
#  'dictator_destroying': 1,
#  'any': 418,
#  'destroying_any': 1,
#  'progress': 38,
#  'any_progress': 1,
#  'hes': 31,
#  'progress_hes': 1,
#  'thrown': 6,
#  'hes_thrown': 1,
#  'thrown_out': 2,
#  'constitution': 13,
#  'out_the_constitution': 1,
#  'laws': 33,
#  'constitution_laws': 1,
#  'protected': 66,
#  'laws_protected': 1,
#  'it': 2010,
#  'protected_by_it': 1,
#  'it_he': 6,
#  'doesnt': 51,
#  'he_doesnt': 5,
#  'follow': 42,
#  'doesnt_follow': 1,
#  'international_laws': 15,
#  'follow_international_laws': 1,
#  'lost': 116,
#  'international_laws_lost': 1,
#  'lost_all': 2,
#  'control': 88,
#  'all_control': 1,
#  'do_you': 197,
#  'control_do_you': 1,
#  'prefer': 16,
#  'do_you_prefer': 1,
#  'horn': 43,
#  'prefer_the_horn': 1,
#  'become': 86,
#  'horn_to_become': 1,
#  'home': 221,
#  'become_a_home': 1,
#  'terrorists': 58,
#  'home_for_terrorists': 1,
#  'b_c': 55,
#  'terrorists_b_c': 1,
#  'b_c_were': 1,
#  'were_there': 5,
#  'safe_access': 46,
#  'ethiopia_safe_access': 18,
#  'swift_action': 84,
#  'safe_access_and_swift_action': 36,
#  'needed': 159,
#  'swift_action_needed': 41,
#  'needed_for_refugees': 36,
#  'refugees_in_tigray': 221,
#  'conflict': 592,
#  'tigray_the_conflict': 1,
#  'between': 160,
#  'conflict_between': 3,
#  'between_the_ethiopian': 1,
#  'yeah': 14,
#  'fucking': 16,
#  'yeah_the_fucking': 1,
#  'world': 815,
#  'fucking_world': 1,
#  'world_is': 70,
#  'descendants': 5,
#  'is_descendants': 1,
#  'immigrants': 305,
#  'descendants_of_immigrants': 1,
#  'immigrants_we': 1,
#  'should': 466,
#  'we_should': 13,
#  'should_all': 4,
#  'all_go_back': 1,
#  'go_back_to_ethiopia': 7,
#  'when_will': 64,
#  'this': 2189,
#  'when_will_this': 3,
#  'talking': 36,
#  'this_talking': 1,
#  'ends': 12,
#  'talking_ends': 1,
#  'ends_and_action': 1,
#  'begins': 7,
#  'action_begins': 1,
#  'fact': 150,
#  'begins_fact': 1,
#  'words': 78,
#  'fact_words': 1,
#  'words_are': 5,
#  'not': 1768,
#  'are_not': 163,
#  'saving': 18,
#  'not_saving': 3,
#  'lives': 237,
#  'saving_lives': 3,
#  'lives_in_tigray': 13,
#  'tigray_tigray': 280,
#  'genocide_is': 110,
#  'happening': 208,
#  'is_happening': 87,
#  'happening_at_your': 1,
#  'watch': 483,
#  'your_watch': 14,
#  'act': 280,
#  'watch_act': 2,
#  'before': 385,
#  'act_before': 2,
#  'its': 801,
#  'before_its': 10,
#  'too_late': 43,
#  'its_too_late': 11,
#  'un_refugee': 167,
#  'un_refugee_chief': 7,
#  'very_worried': 32,
#  'chief_very_worried': 2,
#  'eritreans': 532,
#  'very_worried_for_eritreans': 1,
#  'eritreans_in_ethiopia': 3,
#  'international_community': 155,
#  'allowed': 110,
#  'international_community_allowed': 1,
#  'allowed_this': 7,
#  'happened': 102,
#  'this_to_happened': 1,
#  'tigrinya': 19,
#  'happened_in_tigrinya': 1,
#  'tigrinya_ethiopian': 1,
#  'major_violations': 135,
#  'international_law': 246,
#  'major_violations_of_international_law': 121,
#  'international_law_at_tigray': 83,
#  'refugee_camps': 1620,
#  'tigray_refugee_camps': 138,
#  'u_n': 135,
#  'refugee_camps_u_n': 56,
#  'inhindi': 1,
#  'u_n_inhindi': 1,
#  'moussa_faki': 18,
#  'mahamat': 18,
#  'moussa_faki_mahamat': 18,
#  'has': 1299,
#  'mahamat_has': 2,
#  'disregarded': 7,
#  'has_disregarded': 2,
#  'violated': 41,
#  'disregarded_and_violated': 2,
#  'international': 521,
#  'violated_international': 3,
#  'conventions': 16,
#  'international_conventions': 3,
#  'legal': 43,
#  'conventions_legal': 1,
#  'instruments': 3,
#  'legal_instruments': 2,
#  'that': 2781,
#  'instruments_that': 2,
#  'address': 45,
#  'that_address': 2,
#  'need': 683,
#  'address_the_need': 2,
#  'settle': 10,
#  'need_to_settle': 2,
#  'violent': 12,
#  'settle_violent': 2,
#  'conflicts': 33,
#  'violent_conflicts': 2,
#  'peacefully': 17,
#  'conflicts_peacefully': 2,
#  'peacefully_tigray': 3,
#  'result': 19,
#  'is_a_result': 2,
#  'negligence': 7,
#  'result_of_negligence': 2,
#  'towards': 52,
#  'negligence_towards': 2,
#  'towards_refugees': 4,
#  'refugees_and_the_genocide': 2,
#  'genocide_conventions': 2,
#  'conventions_united_nations': 2,
#  'blm': 13,
#  'united_nations_blm': 2,
#  'ethiopian_govt': 63,
#  'ethiopian_govt_is': 11,
#  'blocking': 65,
#  'is_blocking': 10,
#  'blocking_un': 1,
#  'entering': 24,
#  'un_from_entering': 1,
#  'entering_tigray': 7,
#  'assist': 28,
#  'tigray_to_assist': 2,
#  'assist_refugees': 1,
#  'millions': 511,
#  'refugees_and_millions': 2,
#  'civillians': 11,
#  'millions_of_civillians': 1,
#  'stuck': 16,
#  'civillians_stuck': 1,
#  'war_zone': 44,
#  'stuck_in_a_war_zone': 2,
#  'tigray_un': 29,
#  'news': 295,
#  'un_news': 17,
#  'via': 236,
#  'news_via': 2,
#  'gary': 2,
#  'via_gary': 2,
#  'skinner': 2,
#  'gary_skinner': 2,
#  'have': 1782,
#  'we_have': 142,
#  'credible': 40,
#  'have_credible': 5,
#  'evidence': 206,
#  'credible_evidence': 5,
#  'shi_melba': 15,
#  'evidence_shi_melba': 1,
#  'hits': 4,
#  'shi_melba_hits': 2,
#  'ats': 10,
#  'hits_ats': 4,
#  'ats_refugee_camps': 4,
#  'refugee_camps_have_been': 15,
#  'destroyed': 562,
#  'have_been_destroyed': 25,
#  'eritrea': 2247,
#  'destroyed_by_eritrea': 6,
#  'troops': 388,
#  'eritrea_troops': 48,
#  'troops_and_the_refugees': 3,
#  'refugees_have_been': 45,
#  'killed_abducted': 19,
#  'have_been_killed_abducted': 11,
#  'forcefully_returned': 28,
#  'killed_abducted_and_forcefully_returned': 1,
#  'back': 220,
#  'forcefully_returned_back': 1,
#  'eritria': 7,
#  'back_to_eritria': 1,
#  'empty': 38,
#  'cries': 5,
#  'empty_cries': 1,
#  'dont': 230,
#  'cries_dont': 1,
#  'fix': 10,
#  'dont_fix': 1,
#  'anything': 68,
#  'fix_anything': 1,
#  'tplf': 2743,
#  'anything_tplf': 1,
#  'cannot_be': 29,
#  'tplf_cannot_be': 1,
#  'resuscitated': 1,
#  'cannot_be_resuscitated': 1,
#  'work': 205,
#  'resuscitated_work': 1,
#  'ethiopian_government': 308,
#  'work_with_the_ethiopian_government': 2,
#  'deliver': 31,
#  'ethiopian_government_and_deliver': 2,
#  'deliver_your': 1,
#  'services': 115,
#  'your_services': 1,
#  'i': 1030,
#  'services_i': 1,
#  'mean': 66,
#  'i_mean': 13,
#  'if_you': 224,
#  'mean_if_you': 1,
#  'if_you_mean': 2,
#  'do': 408,
#  'mean_to_do': 1,
#  'genuine': 18,
#  'do_a_genuine': 1,
#  'refugee': 1248,
#  'genuine_refugee': 1,
#  'refugee_services': 1,
#  'services_stop': 1,
#  'these': 671,
#  'stop_these': 12,
#  'unsubstantiated': 6,
#  'these_unsubstantiated': 1,
#  'reports': 344,
#  'unsubstantiated_reports': 1,
#  'propaganda': 122,
#  'reports_and_propaganda': 1,
#  'via_yahoo': 16,
#  'u_n_via_yahoo': 1,
#  'via_yahoo_news': 8,
#  'you': 2851,
#  'you_taken': 1,
#  'abi': 16,
#  'taken_abi': 1,
#  'ahmed': 76,
#  'abi_ahmed': 6,
#  's': 1398,
#  'ahmed_s': 1,
#  'media': 189,
#  's_media': 1,
#  'media_words': 1,
#  'words_tigray': 1,
#  'genocide_abi': 1,
#  'air': 28,
#  'abi_air': 1,
#  'strikes': 11,
#  'air_strikes': 3,
#  'strikes_civilians': 1,
#  'mosques': 8,
#  'civilians_mosques': 1,
#  'churchs': 2,
#  'mosques_churchs': 1,
#  'churchs_and_all': 1,
#  'stories': 86,
#  'all_the_stories': 1,
#  'refugee_camp': 508,
#  'stories_from_refugee_camp': 1,
#  'sudan': 1927,
#  'refugee_camp_in_sudan': 61,
#  'sudan_and_you': 2,
#  'telling': 75,
#  'you_telling': 3,
#  'me': 223,
#  'telling_me': 5,
#  'me_you': 3,
#  'you_have': 111,
#  'have_not': 43,
#  'seen': 127,
#  'not_seen': 5,
#  'seen_tigray': 1,
#  'tigray_civilians': 35,
#  'harmed': 5,
#  'civilians_harmed': 1,
#  'harmed_if_you': 1,
#  'hearing': 29,
#  'if_you_hearing': 1,
#  'hearing_to_abi': 1,
#  'ahmed_people': 1,
#  'people_you': 21,
#  'you_are': 322,
#  'getting': 134,
#  'not_getting': 5,
#  'truth': 263,
#  'getting_the_truth': 1,
#  'satellite_images': 93,
#  'satellite_images_dont': 1,
#  'lie': 112,
#  'dont_lie': 5,
#  'lie_evidence': 1,
#  'destruction': 306,
#  'evidence_of_the_destruction': 1,
#  'destruction_of_refugee_camps': 21,
#  'refugee_camps_in_the_tigray': 15,
#  'region': 1553,
#  'tigray_region': 1049,
#  'region_of_ethiopia': 196,
#  'must_be': 219,
#  'ethiopia_must_be': 26,
#  'must_be_taken': 8,
#  'seriously': 16,
#  'taken_seriously': 2,
#  'such': 133,
#  'seriously_such': 1,
#  'atrocities': 294,
#  'such_atrocities': 1,
#  'must': 356,
#  'atrocities_must': 1,
#  'must_have': 7,
#  'consequences': 28,
#  'have_consequences': 2,
#  'gang': 23,
#  'gang_of_tigray': 2,
#  'which': 404,
#  'tigray_which': 19,
#  'allegedly': 18,
#  'which_allegedly': 2,
#  'represent': 9,
#  'allegedly_represent': 2,
#  '5': 114,
#  'represent_5': 2,
#  'population': 145,
#  '5_of_the_population': 2,
#  'can': 589,
#  'population_can': 2,
#  'will': 763,
#  'can_will': 3,
#  'will_not': 86,
#  'blackmail': 8,
#  'not_blackmail': 2,
#  '105': 13,
#  'blackmail_105': 2,
#  '105_millions': 2,
#  'ethiopians': 276,
#  'millions_ethiopians': 2,
#  'ever': 90,
#  'ethiopians_for_ever': 2,
#  '27_years': 40,
#  'ever_27_years': 2,
#  'lotting': 7,
#  '27_years_of_lotting': 1,
#  'lotting_killing': 1,
#  'massacring': 40,
#  'killing_and_massacring': 2,
#  'amharas': 56,
#  'massacring_of_amharas': 1,
#  'oromos': 15,
#  'amharas_oromos': 1,
#  'oromos_are': 1,
#  'are_over': 12,
#  'overdue': 5,
#  'over_overdue': 2,
#  'justices': 12,
#  'overdue_justices': 2,
#  'justices_are': 2,
#  'are_in_progress': 2,
#  'disaster': 37,
#  'ethiopia_disaster': 1,
#  'disaster_tigray': 2,
#  'tigray_refugees': 177,
#  'refugees_in_sudan': 371,
#  'recount': 7,
#  'sudan_recount': 1,
#  'brutal': 70,
#  'recount_brutal': 1,
#  'combating': 2,
#  'brutal_combating': 1,
#  'my': 461,
#  'combating_my': 1,
#  'press': 46,
#  'my_press': 1,
#  'press_news': 1,
#  'news_my': 1,
#  'health': 80,
#  'my_health': 1,
#  'funda': 1,
#  'health_funda': 1,
#  'style': 15,
#  'funda_style': 1,
#  'up': 376,
#  'style_up': 1,
#  'up_now': 3,
#  'mag': 1,
#  'now_mag': 1,
#  'planet': 5,
#  'mag_planet': 1,
#  'com': 11,
#  'planet_com': 1,
#  'eritrean_refugees_must_be': 3,
#  'must_be_protected': 5,
#  'protected_but': 2,
#  'but_their': 3,
#  'plight': 37,
#  'their_plight': 3,
#  'pales': 2,
#  'plight_pales': 1,
#  'when': 573,
#  'pales_when': 1,
#  'compared': 16,
#  'when_compared': 1,
#  'compared_to_the_millions': 1,
#  'millions_of_people': 58,
#  'people_in_tigray': 187,
#  'tigray_who': 42,
#  'who_have_been': 33,
#  'blockaded': 2,
#  'have_been_blockaded': 1,
#  'dictator_abiy': 47,
#  'blockaded_by_dictator_abiy': 1,
#  'dictator_abiy_ahmed': 10,
#  'ahmed_the_tigray': 1,
#  'beyond': 50,
#  'is_beyond': 15,
#  'description': 2,
#  'beyond_description': 1,
#  'description_and_the_un': 1,
#  'european_commission': 398,
#  'un_european_commission': 2,
#  'nato': 7,
#  'european_commission_and_nato': 1,
#  'will_be': 246,
#  'nato_will_be': 1,
#  'responsible': 156,
#  'will_be_responsible': 7,
#  'responsible_for_not': 1,
#  'taking': 132,
#  'not_taking': 13,
#  'taking_action': 9,
#  'tributes': 2,
#  'paid': 72,
#  'tributes_paid': 2,
#  'paid_to_ethiopian': 2,
#  'ethiopian_refugee': 50,
#  'farmer': 4,
#  'refugee_farmer': 2,
#  'farmer_who': 3,
#  'championed': 2,
#  'who_championed': 2,
#  'integration': 7,
#  'championed_integration': 2,
#  'italy': 25,
#  'integration_in_italy': 2,
#  'evidence_the_refugee_camps': 1,
#  'refugee_camps_hits': 1,
#  'ats_shi_melba': 1,
#  'shi_melba_have_been': 1,
#  'eritrea_ethiopia': 76,
#  'ethiopia_troops': 8,
#  'forcely': 1,
#  'killed_abducted_and_forcely': 1,
#  'returned': 72,
#  'forcely_returned': 1,
#  'back_to_eritrea': 86,
#  'returned_back_to_eritrea': 3,
#  'reuters': 81,
#  'u_n_reuters': 6,
#  'chronlaw': 4,
#  'reuters_chronlaw': 2,
#  'chronlaw_international_law': 4,
#  'international_law_news': 4,
#  'excellencies': 2,
#  'your_excellencies': 2,
#  'whole_world': 22,
#  'excellencies_the_whole_world': 1,
#  'whole_world_is': 5,
#  'waiting': 83,
#  'is_waiting': 3,
#  'waiting_your': 1,
#  'country': 579,
#  'your_country': 23,
#  'country_to_act': 1,
#  'matter': 74,
#  'act_on_the_matter': 1,
#  'matter_your': 2,
#  'silence': 51,
#  'your_silence': 6,
#  'encouraged': 6,
#  'silence_encouraged': 1,
#  'killings': 130,
#  'encouraged_the_killings': 1,
#  'killings_of_the_tigray': 1,
#  'tigray_people': 335,
#  'people_and_the_eritrean_refugees': 2,
#  'please': 632,
#  'eritrean_refugees_please': 4,
#  'act_now': 252,
#  'please_act_now': 27,
#  'act_now_millions': 1,
#  'innocent': 322,
#  'millions_of_innocent': 7,
#  'innocent_people': 96,
#  'people_are': 381,
#  'being_killed': 99,
#  'are_being_killed': 37,
#  'invaders': 37,
#  'being_killed_by_invaders': 1,
#  'why': 623,
#  'thank_you_why': 1,
#  'looting': 316,
#  'why_looting': 1,
#  'confiscating': 1,
#  'looting_confiscating': 1,
#  'raping_killing': 37,
#  'confiscating_raping_killing': 1,
#  'demolishing': 3,
#  'raping_killing_demolishing': 1,
#  'joint': 28,
#  'demolishing_by_joint': 1,
#  'joint_ethiopian': 3,
#  'eritrean': 1494,
#  'ethiopian_and_eritrean': 39,
#  'armies': 43,
#  'eritrean_armies': 8,
#  'you_re': 61,
#  'allowing': 46,
#  'you_re_allowing': 1,
#  'isaias_afeworki': 104,
#  'allowing_isaias_afeworki': 1,
#  'isaias_afeworki_to_have': 1,
#  'field': 13,
#  'have_a_field': 1,
#  'day': 336,
#  'field_day': 1,
#  'kill': 192,
#  'day_kill': 1,
#  'kill_refugees': 8,
#  'who_fled': 159,
#  'refugees_who_fled': 57,
#  'who_fled_his': 1,
#  'prison': 39,
#  'his_prison': 1,
#  'prison_eritrea': 1,
#  'unless': 41,
#  'eritrea_unless': 3,
#  'someone': 45,
#  'unless_someone': 2,
#  'stops': 10,
#  'someone_stops': 1,
#  'him': 165,
#  'stops_him': 1,
#  'him_he': 2,
#  'he_will': 18,
#  'finish': 12,
#  'will_finish': 1,
#  'them': 1040,
#  'finish_them': 1,
#  'them_he': 3,
#  'he_has': 34,
#  'got': 110,
#  'has_got': 3,
#  'away': 101,
#  'got_away': 2,
#  'crimes_against': 155,
#  'away_with_crimes_against': 1,
#  'humanity': 228,
#  'crimes_against_humanity': 127,
#  'upto': 8,
#  'humanity_upto': 1,
#  'upto_now': 2,
#  'now_can': 2,
#  'unhcr': 808,
#  'can_unhcr': 2,
#  'do_something': 16,
#  'unhcr_do_something': 1,
#  'do_something_to_stop': 1,
#  'stop_this': 35,
#  'this_killing': 1,
#  'massacred': 251,
#  'killing_and_massacred': 1,
#  'massacred_please': 1,
#  'please_do_something': 5,
#  'this_is': 591,
#  'is_not': 312,
#  'dangerous': 39,
#  'not_a_dangerous': 1,
#  'violence': 271,
#  'dangerous_and_violence': 1,
#  'twitter': 48,
#  'violence_twitter': 1,
#  'twitter_s': 1,
#  'policy': 44,
#  's_policy': 2,
#  'policy_twitter': 1,
#  'twitter_it': 1,
#  'it_is': 530,
#  'thankful': 12,
#  'is_a_thankful': 1,
#  'letter': 20,
#  'thankful_letter': 1,
#  'sudanese': 141,
#  'letter_for_sudanese': 1,
#  'hospitality': 13,
#  'sudanese_hospitality': 1,
#  'love': 75,
#  'hospitality_love': 1,
#  'love_for_tigray': 1,
#  'refugees_who': 144,
#  'sought': 24,
#  'who_sought': 4,
#  'safety': 161,
#  'sought_for_safety': 1,
#  'amharahutumilitia': 1,
#  'safety_from_amharahutumilitia': 1,
#  'eritreansoldiers': 3,
#  'amharahutumilitia_eritreansoldiers': 1,
#  'ethiopiansoldiers': 1,
#  'eritreansoldiers_ethiopiansoldiers': 1,
#  'indiscriminately': 35,
#  'ethiopiansoldiers_indiscriminately': 1,
#  'killed': 1130,
#  'indiscriminately_killed': 1,
#  'killed_civilians': 13,
#  'civilians_tigray': 11,
#  'there_have_been': 38,
#  'have_been_major_violations': 9,
#  'two': 482,
#  'international_law_at_two': 8,
#  'two_refugee_camps': 150,
#  'ethiopias_northern': 12,
#  'refugee_camps_in_ethiopias_northern': 9,
#  'ethiopias_northern_tigray': 12,
#  'region_the_u_n': 5,
#  'u_n_s': 5,
#  's_refugee_agency': 10,
#  'refugee_agency_unhcr': 42,
#  'unhcr_said': 19,
#  'thursday': 21,
#  'said_on_thursday': 8,
#  'u_n_tigray': 1,
#  'stop_war': 367,
#  'genocide_stop_war': 78,
#  'stop_war_on_tigray': 332,
#  'tigray_via_yahoo': 2,
#  'there_is': 337,
#  'not_and_will': 1,
#  'single': 48,
#  'not_a_single': 7,
#  'single_eritrean': 2,
#  'soldier': 32,
#  'eritrean_soldier': 5,
#  'soldier_in_ethiopian': 1,
#  'territory': 23,
#  'ethiopian_territory': 5,
#  'only': 459,
#  'territory_the_only': 1,
#  'only_eritrean': 2,
#  'stuff': 10,
#  'eritrean_stuff': 1,
#  'stuff_in_ethiopia': 1,
#  'ethiopia_at_this': 1,
#  'point': 65,
#  'this_point': 6,
#  'point_is': 5,
#  'military': 315,
#  'their_military': 4,
#  'uniform': 20,
#  'military_uniform': 4,
#  'uniform_that': 2,
#  'that_they': 99,
#  'give': 134,
#  'they_give': 4,
#  'give_to_ethiopian': 1,
#  'defense_forces': 17,
#  'ethiopian_defense_forces': 8,
#  'defense_forces_who': 1,
#  'survived': 17,
#  'who_survived': 3,
#  'survived_the_tigray': 1,
#  'criminal': 180,
#  'tigray_criminal': 1,
#  'gangs': 19,
#  'criminal_gangs': 2,
#  'massacre': 217,
#  'gangs_massacre': 1,
#  'ali': 771,
#  'abiy_ahmed_ali': 762,
#  'stated': 21,
#  'ali_stated': 1,
#  'nov': 65,
#  'stated_on_nov': 1,
#  '28': 17,
#  'nov_28': 7,
#  '2020': 72,
#  '28_2020': 1,
#  '2020_that': 2,
#  'war': 1508,
#  'that_the_war': 2,
#  'war_on_tigray': 303,
#  'was': 1189,
#  'tigray_was': 59,
#  'was_over': 7,
#  'over_but': 2,
#  'but_there': 18,
#  ...}

# %%
# OPTIONAL: use this if training of ngram models is complete, it only serves purpose of saving memory
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
from gensim.models import Word2Vec
from nltk.corpus import stopwords

model_phrases = [trigram_mod[tweet] for tweet in tweet_corpus_tokens]
print(model_phrases[:10])
# Out:
# [['thank_you', 'for', 'your', 'statement', 'now', 'what', 'action', 'is', 'being', 'taken', 'to', 'get', 'aid', 'to', 'all', 'refugees', 'and', 'civilians', 'in', 'tigray', 'unhcr_the_un', 'refugee_agency', 'united_nations', 'michelle', 'bachelet', 'antnio_guterres', 'united', 'nationshumanrights', 'un_ocha', 'ethiopia', 'filippo_grandi'], ['but', 'antnio_guterres', 'said', 'there', 'are', 'no', 'eritrean_troops', 'in', 'ethiopia', 'he', 'needs', 'to', 'retract', 'his', 'statement', 'withdraw', 'his', 'bid', 'for', 'second', 'term', 'tigray_genocide'], ['we', 'call', 'for', 'global', 'solidarity', 'to', 'stop', 'killings_abductions', 'starvation', 'of', 'civilians', 'and', 'refugees', 'by', 'ethiopian', 'and', 'eritrean_army', 'lord', 'tariqahmad', 'of', 'wimbledon', 'marisepayne', 'mona', 'juul', 'brbel', 'kofler', 'mdb', 'annika', 'ben', 'david', 'minnaliina', 'lind', 'marc', 'garneau'], ['un', 'refugees', 'chief', 'trippin', 'the', 'eritrean_refugees', 'who_were', 'living', 'at', 'shimelba_hitsats', 'have_been', 'attacked', 'by', 'tplf_militants', 'the', 'refugees', 'run_away', 'and', 'found', 'shelter', 'in', 'gonder', 'here', 'is', 'their', 'voices', 'and', 'they', 'said', 'they', 'don_t', 'want', 'go_back', 'to', 'tigrai'], ['out', 'of', '9million', 'tigray_ans', 'over', '45_million', 'people', 'face', 'famine', 'the', 'government', 'is', 'killing', 'unarmed', 'civilians', 'in', 'their_own', 'homes', 'and', 'places', 'of', 'birth', 'destroying', 'everything', 'in', 'their', 'path', 'eritrean_soldiers', 'are', 'rapeing', 'women_children', 'destroying', 'our', 'heritage_sites', 'churches_mosques'], ['tigray', 'is', 'fighting', 'to', 'keep', 'democracy', 'alive', 'as', 'abiy_ahmed', 'is', 'a', 'dictator', 'destroying', 'any', 'progress', 'hes', 'thrown', 'out', 'the', 'constitution', 'laws', 'protected', 'by', 'it', 'he', 'doesnt', 'follow', 'international_laws', 'lost', 'all', 'control', 'do_you', 'prefer', 'the', 'horn', 'to', 'become', 'a', 'home', 'for', 'terrorists', 'b_c', 'were', 'there'], ['ethiopia', 'safe_access', 'and', 'swift_action', 'needed', 'for', 'refugees', 'in', 'tigray', 'the', 'conflict', 'between', 'the', 'ethiopian'], ['yeah', 'the', 'fucking', 'world', 'is', 'descendants', 'of', 'immigrants', 'we', 'should', 'all', 'go_back', 'to', 'ethiopia'], ['when_will', 'this', 'talking', 'ends', 'and', 'action', 'begins', 'fact', 'words', 'are', 'not', 'saving', 'lives', 'in', 'tigray', 'tigray_genocide', 'is_happening', 'at', 'your', 'watch', 'act', 'before', 'its', 'too_late'], ['un_refugee', 'chief', 'very_worried', 'for', 'eritreans', 'in', 'ethiopia']]

# %%
# FINDING BEST PARAMETERS FOR WORD2VEC MODEL

#negatives = [5,10,20]
sizes = [100,200,300]
sgs=[0,1]
windows =[3,5] 
#cbow_means = [0,1]
#iters=[10]

for size in sizes:
        for window in windows:
            #print(f'\nfor params size={size},negative={neg},sg={sg},hs={hs},window={window},cbow_mean={cbow},iter={it}')
            print(f'\nfor params size={size},window={window}')
            model = Word2Vec(model_phrases,vector_size=size,window=window)
            print(model.wv.most_similar('refugees'))

# %%
import gensim.downloader as api
from gensim.models import Word2Vec

model = Word2Vec(model_phrases,vector_size=300,window=3)
print('first model done')
#model2 = api.load("glove-twitter-200")
#print('second model done')
#model3 = gensim.models.KeyedVectors.load_word2vec_format(r'C:\Users\nikodemicek\Dropbox (CBS)\Master thesis data\GoogleNews-vectors-negative300.bin.gz', binary=True)
#print('third model done')
# Out:
# first model done

# %%
model.wv.most_similar('refugees')
# Out:
# [('eritrean_refugees', 0.7808598875999451),
#  ('migrants', 0.7493160367012024),
#  ('60000_refugees', 0.7415494322776794),
#  ('have_fled', 0.717192530632019),
#  ('20000_refugees', 0.7117390036582947),
#  ('residents', 0.7110738754272461),
#  ('border', 0.7052704691886902),
#  ('eritrean_refugee', 0.7011108994483948),
#  ('refugee', 0.6936578750610352),
#  ('their_homes', 0.6899452209472656)]

# %%
model.wv.most_similar('refugees')
# Out:
# [('immigrants', 0.7028154730796814),
#  ('asylum_seekers', 0.6707106232643127),
#  ('illegal_migrants', 0.6094726324081421),
#  ('illegal_immigrants', 0.6072850227355957),
#  ('migrants', 0.6011469960212708),
#  ('people', 0.595695972442627),
#  ('syrians', 0.5859284400939941),
#  ('economic_migrants', 0.579109251499176),
#  ('these_people', 0.5709031224250793),
#  ('illegals', 0.5647295713424683)]

# %%
pickle_file('tigray_w2v_model',model)

# %% [markdown]
# ## FastText model

# %%
# FINDING BEST PARAMETERS FOR FASTTEXT MODEL
from gensim.models import FastText

sizes = [100,200,300]
#losses=['ns','hs','softmax']
windows =[3,5] 


for size in sizes:
        for window in windows:
            #for loss in losses:
                #print(f'\nfor params size={size},negative={neg},sg={sg},hs={hs},window={window},cbow_mean={cbow},iter={it}')
                print(f'\nfor params size={size}, window={window} ')
                model = FastText(model_phrases,vector_size=size,window=window, epochs=10)
                print(model.wv.most_similar('refugee'))
# Out:
# for params size=100, window=3
# [('refugee_kid', 0.9725989699363708), ('refugee_law', 0.9665269255638123), ('refugee_exodus', 0.9585047364234924), ('refugee_flows', 0.954691469669342), ('refuge', 0.9496657252311707), ('refugee_status', 0.9360215067863464), ('refugee_child', 0.9352647662162781), ('refugee_policy', 0.9234868884086609), ('refugee_committee', 0.9191840291023254), ('kid_refugee', 0.9133069515228271)]
#
# for params size=100, window=5
# [('refugee_kid', 0.9771548509597778), ('refugee_law', 0.9689993262290955), ('refugee_exodus', 0.960526704788208), ('refugee_flows', 0.9551403522491455), ('refuge', 0.9466025829315186), ('refugee_child', 0.9407798647880554), ('refugee_status', 0.9329602718353271), ('refugee_policy', 0.9241395592689514), ('refugee_committee', 0.9201054573059082), ('took_refuge', 0.909279465675354)]
#
# for params size=200, window=3
# [('refugee_kid', 0.9748549461364746), ('refugee_law', 0.9703011512756348), ('refugee_exodus', 0.9645267724990845), ('refugee_flows', 0.9556060433387756), ('refuge', 0.9503612518310547), ('refugee_child', 0.9400733113288879), ('refugee_status', 0.9376668930053711), ('refugee_committee', 0.9315598607063293), ('refugee_policy', 0.9302139282226562), ('kid_refugee', 0.9137229323387146)]
#
# for params size=200, window=5
# [('refugee_kid', 0.9768521785736084), ('refugee_law', 0.9700917601585388), ('refugee_exodus', 0.9631538391113281), ('refugee_flows', 0.9564229846000671), ('refuge', 0.946463406085968), ('refugee_child', 0.9406585693359375), ('refugee_status', 0.9357743859291077), ('refugee_committee', 0.9300172924995422), ('refugee_policy', 0.923314094543457), ('pregnant_refugee', 0.9102300405502319)]
#
# for params size=300, window=3
# [('refugee_kid', 0.968790590763092), ('refugee_law', 0.9657623767852783), ('refugee_exodus', 0.9577863812446594), ('refuge', 0.9523689150810242), ('refugee_flows', 0.9502414464950562), ('refugee_status', 0.933814287185669), ('refugee_child', 0.9275327324867249), ('refugee_policy', 0.9241487979888916), ('refugee_committee', 0.9176177978515625), ('kid_refugee', 0.914644181728363)]
#
# for params size=300, window=5
# [('refugee_kid', 0.9775657653808594), ('refugee_law', 0.9704881906509399), ('refugee_exodus', 0.9638486504554749), ('refugee_flows', 0.9572654962539673), ('refuge', 0.9489648342132568), ('refugee_status', 0.9457432627677917), ('refugee_child', 0.9352207183837891), ('refugee_committee', 0.9225418567657471), ('refugee_policy', 0.9216865301132202), ('took_refuge', 0.9132393598556519)]

# %%
from gensim.models import FastText

model2 = FastText(vector_size=300, window=3, sentences=model_phrases, min_n=4,max_n=6)

# %%
model2.wv.most_similar('refugee')
# Out:
# [('refuge', 0.9909552931785583),
#  ('refuges', 0.9901469349861145),
#  ('refugee_status', 0.9680262207984924),
#  ('danish_refugee', 0.9666343927383423),
#  ('refugee_said', 0.9661538600921631),
#  ('refugees', 0.9506486058235168),
#  ('un_refugee', 0.9475336670875549),
#  ('iraqi_refugees', 0.9409911632537842),
#  ('norwegian_refugee', 0.9401996731758118),
#  ('refugee_camp', 0.9324396252632141)]

# %%
model2.wv.most_similar('refugee')
# Out:
# [('refugeees', 0.9461631178855896),
#  ('refugee_girl', 0.9091788530349731),
#  ('jesuit_refugee', 0.9081748723983765),
#  ('imperilled_refugee', 0.8926677703857422),
#  ('renewed_refugee', 0.8882556557655334),
#  ('refugee_forum', 0.8876516222953796),
#  ('refugee_scandal', 0.886340320110321),
#  ('refugee_pact', 0.8844466209411621),
#  ('refugee_boy', 0.8822042346000671),
#  ('anti_refugee', 0.8774494528770447)]

# %%
model2.wv.similarity('refugee','migrant')
# Out:
# 0.6189612

# %%
pickle_file('tigray_ft_model', model2)

# %%
path = os.getcwd() + "/../../../" + fr"Dropbox (CBS)/Master thesis data/Candidate Data/greece/greece_ft_model.bin"
model2.save(path)

# %% [markdown]
# ## BERT embeddings

# %%
# train this model only after the first merging step to save both memory and time
event_cands = load_pickle('moria_short_cands')

# %%
event_cands
# Out:
#                                                candidates  \
# 0                      (greece, greece, {greece}, loc-ne)
# 1                  (refugees, refugees, {refugees}, misc)
# 2                              (fire, fire, {fire}, misc)
# 3                      (turkey, turkey, {turkey}, loc-ne)
# 4                  (migrants, migrants, {migrants}, misc)
# ...                                                   ...
# 186493                            (wwf, wwf, {wwf}, misc)
# 186494                (its china, china, {china}, loc-ne)
# 186495  (volunteers organizers and police, organizers,...
# 186496  (pik pa moria lesbos, lesbos, {lesbos, pik}, m...
# 186497                      (spree, spree, {spree}, misc)
#
#                                                 cand_tags  \
# 0       [\n  {\n    "id": 1,\n    "text": "Greece",\n ...
# 1       [\n  {\n    "id": 1,\n    "text": "refugees",\...
# 2       [\n  {\n    "id": 1,\n    "text": "fire",\n   ...
# 3       [\n  {\n    "id": 1,\n    "text": "Turkey",\n ...
# 4       [\n  {\n    "id": 1,\n    "text": "migrants",\...
# ...                                                   ...
# 186493  [\n  {\n    "id": 1,\n    "text": "wwf",\n    ...
# 186494  [\n  {\n    "id": 1,\n    "text": "its",\n    ...
# 186495  [\n  {\n    "id": 1,\n    "text": "volunteers,...
# 186496  [\n  {\n    "id": 1,\n    "text": "pik",\n    ...
# 186497  [\n  {\n    "id": 1,\n    "text": "spree",\n  ...
#
#                                cand_text  cand_len  cand_freq  string_len
# 0                                 greece         1      18978           6
# 1                               refugees         1      10656           8
# 2                                   fire         1       7477           4
# 3                                 turkey         1       4986           6
# 4                               migrants         1       4666           8
# ...                                  ...       ...        ...         ...
# 186493                               wwf         1          1           3
# 186494                         its china         2          1           9
# 186495  volunteers organizers and police         4          1          32
# 186496               pik pa moria lesbos         4          1          19
# 186497                             spree         1          1           5
#
# [186498 rows x 6 columns]

# %%
from time import time
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

bert_corpus = list(unique_tweets_df['text_clean']) + list(event_cands['cand_text'])


t0 = time()
document_embeddings = sbert_model.encode(bert_corpus)
print(f'Training embeddings took {time()-t0} seconds')
# Out:
# Embedding took 13004.31396651268 seconds

# %%
print(document_embeddings.shape)
print(unique_tweets_df['text_clean'].shape)
print(event_cands['cand_text'].shape)
# Out:
# (267825, 768)
# (81327,)
# (186498,)

# %%
from sklearn.metrics.pairwise import cosine_similarity
 
sims = cosine_similarity(
    [document_embeddings[1002]],
    document_embeddings[1003:]
)

sim_df = pd.DataFrame({'text': bert_corpus[1003:],'sim': list(sims[0])})

# %%
rows_list = []
for up_cand_id in tqdm(range(len(bert_corpus[1000:]))):
    for low_cand_id in range(up_cand_id+1,len(bert_corpus[1000:])):
        sim = cosine_similarity(
            document_embeddings[up_cand_id].reshape(1,-1),
            document_embeddings[low_cand_id].reshape(1,-1)
        )
        dict1 = {}
        # get input row in dictionary format
        # key = col_name
        dict1.update({'text': bert_corpus[up_cand_id], 'text_to_compare':bert_corpus[low_cand_id], 'sim':[sim[0]]}) 

        rows_list.append(dict1)

sim_df = pd.DataFrame(rows_list)
sim_df

# %%
pickle_file('moria_sim_df',sim_df)

# %%
print(f'most similar to "{bert_corpus[1001]}":')

sim_df.columns = sim_df.columns.str.strip()

sim_df.sort_values('sim', ascending=False).head(50)
# Out:
# most similar to "i keep thinking about the refugees in greece who are receiving so much violence for fleeing certain death  to all these children and families who are lost in an extremely violent world  what will happen tonight and tomorrow without food and shelter":
#                           text       sim
# 35                       fires  0.981077
# 456                     flames  0.953122
# 382                  this fire  0.948744
# 352                  fire guts  0.942461
# 470                      blaze  0.941246
# 13                      a fire  0.939005
# 132                 moria fire  0.908484
# 159                  the fires  0.907713
# 9                     the fire  0.907002
# 811                 the flames  0.902333
# 341                  the blaze  0.894754
# 669             the moria fire  0.879606
# 441                lesbos fire  0.837940
# 991             a massive fire  0.828681
# 562         a devastating fire  0.820698
# 108          the fire in moria  0.819840
# 929              fire at covid  0.815536
# 178           fire departments  0.789699
# 466               firefighters  0.786297
# 748             fire on lesbos  0.774673
# 516                  huge fire  0.769656
# 239                      arson  0.768699
# 542       the devastating fire  0.767865
# 593                a huge fire  0.767153
# 457                        gas  0.764626
# 773         a deadly tent fire  0.763162
# 685                  camp fire  0.755081
# 314                catastrophe  0.753824
# 580                police fire  0.726609
# 866         fire on the island  0.721465
# 422                 night fire  0.720262
# 238  night fire burning happen  0.719774
# 262                   tear gas  0.714120
# 977                       fuel  0.710758
# 686                       shit  0.707548
# 363                       hell  0.707207
# 607             cathedral fire  0.702620
# 675      the moria catastrophe  0.695591
# 993                     attack  0.694596
# 590                      force  0.692645
# 782                   the fuel  0.692418
# 480             fire in greece  0.690953
# 966                     matter  0.689430
# 406           camp fire forces  0.684428
# 706     greek camp fire sparks  0.684238
# 950                     trauma  0.678141
# 584          an apartment fire  0.676624
# 233               a house fire  0.672023
# 507                   pandemic  0.665090
# 627              moria tragedy  0.655075

# %%
# Out:
# array([[-0.25162622,  0.58416   ,  0.34161314, ..., -0.9051944 ,
#          0.07126287, -0.21723138],
#        [-0.28473833,  0.5902117 ,  0.8460189 , ..., -0.33095843,
#         -0.47118548,  0.47009197],
#        [-0.28960198,  1.0041703 ,  0.23169023, ..., -0.64314526,
#         -0.23541632,  0.28106663],
#        ...,
#        [-0.03950938, -0.24995442,  1.3851532 , ..., -0.31755453,
#          0.48770684, -0.23471756],
#        [ 0.06689067, -0.868989  ,  1.4205451 , ..., -0.2091172 ,
#          0.09321782, -0.24408102],
#        [ 0.11261851,  0.28545126,  1.4639302 , ...,  0.28329983,
#         -0.5337196 , -1.0075337 ]], dtype=float32)
